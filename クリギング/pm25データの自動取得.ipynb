# %%
import pandas as pd
import numpy as np

# %%
x={"Locations":[{"location_name":"Anand Kala Kshetram, Rajamahendravaram - APPCB","location_id":"site_1399","lat":"16.9872867","long":"81.7363176","pm25":"38"},{"location_name":"Tirumala, Tirupati - APPCB","location_id":"site_258","lat":"13.67","long":"79.35","pm25":"22"},{"location_name":"GVM Corporation, Visakhapatnam - APPCB","location_id":"site_260","lat":"17.72","long":"83.3","pm25":"33"},{"location_name":"Railway Colony, Guwahati - APCB","location_id":"site_5073","lat":"26.181742","long":"91.78063","pm25":"43"},{"location_name":"Collectorate, Gaya - BSPCB","location_id":"site_159","lat":"24.7955","long":"84.9994","pm25":"78"},{"location_name":"Muzaffarpur Collectorate, Muzaffarpur - BSPCB","location_id":"site_158","lat":"26.1209","long":"85.3647","pm25":"119"},{"location_name":"IGSC Planetarium Complex, Patna - BSPCB","location_id":"site_157","lat":"25.5941","long":"85.1376","pm25":"191"},{"location_name":"Sector-25, Chandigarh - CPCC","location_id":"site_5127","lat":"30.751462","long":"76.762879","pm25":"41"},{"location_name":"Alipur, Delhi - DPCC","location_id":"site_5024","lat":"28.815329","long":"77.153010","pm25":"77"},{"location_name":"Anand Vihar, Delhi - DPCC","location_id":"site_301","lat":"28.646835","long":"77.316032","pm25":"0"},{"location_name":"Ashok Vihar, Delhi - DPCC","location_id":"site_1420","lat":"28.695381","long":"77.181665","pm25":"112"},{"location_name":"Aya Nagar, Delhi - IMD","location_id":"site_108","lat":"28.4706914","long":"77.1099364","pm25":"42"},{"location_name":"Bawana, Delhi - DPCC","location_id":"site_1560","lat":"28.776200","long":"77.051074","pm25":"0"},{"location_name":"CRRI Mathura Road, Delhi - IMD","location_id":"site_103","lat":"28.5512005","long":"77.2735737","pm25":"90"},{"location_name":"DTU, Delhi - CPCB","location_id":"site_118","lat":"28.7500499","long":"77.1112615","pm25":"94"},{"location_name":"Dr. Karni Singh Shooting Range, Delhi - DPCC","location_id":"site_1421","lat":"28.498571","long":"77.264840","pm25":"85"},{"location_name":"Dwarka-Sector 8, Delhi - DPCC ","location_id":"site_1422","lat":"28.5710274","long":"77.0719006","pm25":"123"},{"location_name":"IGI Airport (T3), Delhi - IMD","location_id":"site_106","lat":"28.5627763","long":"77.1180053","pm25":"96"},{"location_name":"IHBAS, Dilshad Garden, Delhi - CPCB","location_id":"site_114","lat":"28.6811736","long":"77.3025234","pm25":"70"},{"location_name":"ITO, Delhi - CPCB","location_id":"site_117","lat":"28.6316945","long":"77.2494387","pm25":"81"},{"location_name":"Jahangirpuri, Delhi - DPCC","location_id":"site_1423","lat":"28.732820","long":"77.170633","pm25":"122"},{"location_name":"Jawaharlal Nehru Stadium, Delhi - DPCC","location_id":"site_1424","lat":"28.580280","long":"77.233829","pm25":"0"},{"location_name":"Lodhi Road, Delhi - IMD","location_id":"site_109","lat":"28.5918245","long":"77.2273074","pm25":"49"},{"location_name":"Major Dhyan Chand National Stadium, Delhi - DPCC","location_id":"site_1425","lat":"28.611281","long":"77.237738","pm25":"75"},{"location_name":"Mandir Marg, Delhi - DPCC","location_id":"site_122","lat":"28.636429","long":"77.201067","pm25":"53"},{"location_name":"Mundka, Delhi - DPCC","location_id":"site_1561","lat":"28.684678","long":"77.076574","pm25":"90"},{"location_name":"NSIT Dwarka, Delhi - CPCB","location_id":"site_115","lat":"28.60909","long":"77.0325413","pm25":"103"},{"location_name":"Najafgarh, Delhi - DPCC","location_id":"site_1427","lat":"28.570173","long":"76.933762","pm25":"79"},{"location_name":"Narela, Delhi - DPCC","location_id":"site_1426","lat":"28.822836","long":"77.101981","pm25":"85"},{"location_name":"Nehru Nagar, Delhi - DPCC","location_id":"site_1429","lat":"28.567890","long":"77.250515","pm25":"103"},{"location_name":"North Campus, DU, Delhi - IMD","location_id":"site_105","lat":"28.6573814","long":"77.1585447","pm25":"63"},{"location_name":"Okhla Phase-2, Delhi - DPCC","location_id":"site_1428","lat":"28.530785","long":"77.271255","pm25":"84"},{"location_name":"Patparganj, Delhi - DPCC","location_id":"site_1431","lat":"28.623748","long":"77.287205","pm25":"72"},{"location_name":"Punjabi Bagh, Delhi - DPCC","location_id":"site_125","lat":"28.674045","long":"77.131023","pm25":"78"},{"location_name":"Pusa, Delhi - DPCC","location_id":"site_1563","lat":"28.639645","long":"77.146262","pm25":"99"},{"location_name":"Pusa, Delhi - IMD","location_id":"site_107","lat":"28.639645","long":"77.146263","pm25":"62"},{"location_name":"R K Puram, Delhi - DPCC","location_id":"site_124","lat":"28.563262","long":"77.186937","pm25":"53"},{"location_name":"Rohini, Delhi - DPCC","location_id":"site_1430","lat":"28.732528","long":"77.119920","pm25":"100"},{"location_name":"Shadipur, Delhi - CPCB","location_id":"site_113","lat":"28.6514781","long":"77.1473105","pm25":"76"},{"location_name":"Sirifort, Delhi - CPCB","location_id":"site_119","lat":"28.5504249","long":"77.2159377","pm25":"65"},{"location_name":"Sonia Vihar, Delhi - DPCC","location_id":"site_1432","lat":"28.710508","long":"77.249485","pm25":"92"},{"location_name":"Sri Aurobindo Marg, Delhi - DPCC","location_id":"site_1562","lat":"28.531346","long":"77.190156","pm25":"77"},{"location_name":"Vivek Vihar, Delhi - DPCC","location_id":"site_1435","lat":"28.672342","long":"77.315260","pm25":"89"},{"location_name":"Wazirpur, Delhi - DPCC","location_id":"site_1434","lat":"28.699793","long":"77.165453","pm25":"122"},{"location_name":"Maninagar, Ahmedabad - GPCB","location_id":"site_308","lat":"23.002657","long":"72.591912","pm25":"46"},{"location_name":"GIDC, Ankleshwar - GPCB","location_id":"site_5065","lat":"21.613267","long":"73.010555","pm25":"0"},{"location_name":"Sector-10, Gandhinagar - GPCB","location_id":"site_5066","lat":"23.221714","long":"72.654328","pm25":"51"},{"location_name":"Phase-1 GIDC, Vapi - GPCB","location_id":"site_5071","lat":"20.362421","long":"72.918013","pm25":"82"},{"location_name":"Phase-4 GIDC, Vatva - GPCB","location_id":"site_5067","lat":"22.969611","long":"72.643500","pm25":"87"},{"location_name":"Patti Mehar, Ambala - HSPCB","location_id":"site_5052","lat":"30.379589","long":"76.778328","pm25":"82"},{"location_name":"Arya Nagar, Bahadurgarh - HSPCB","location_id":"site_5045","lat":"28.6701","long":"76.9254","pm25":"56"},{"location_name":"Nathu Colony, Ballabgarh - HSPCB","location_id":"site_5060","lat":"28.3419248","long":"77.319699","pm25":"70"},{"location_name":"H.B. Colony, Bhiwani - HSPCB","location_id":"site_5047","lat":"28.806223","long":"76.141105","pm25":"62"},{"location_name":"Sector- 16A, Faridabad - HSPCB","location_id":"site_263","lat":"28.4088421","long":"77.3099081","pm25":"71"},{"location_name":"Huda Sector, Fatehabad - HSPCB","location_id":"site_5054","lat":"29.503664","long":"75.467934","pm25":"101"},{"location_name":"NISE Gwal Pahari, Gurugram - IMD","location_id":"site_5025","lat":"28.422681","long":"77.148944","pm25":"43"},{"location_name":"Vikas Sadan, Gurugram - HSPCB","location_id":"site_146","lat":"28.4501238","long":"77.0263051","pm25":"43"},{"location_name":"Urban Estate-II, Hisar - HSPCB","location_id":"site_5057","lat":"29.140560","long":"75.744941","pm25":"107"},{"location_name":"Police Lines, Jind - HSPCB","location_id":"site_5056","lat":"29.307814","long":"76.337619","pm25":"82"},{"location_name":"Rishi Nagar, Kaithal - HSPCB","location_id":"site_5072","lat":"29.8006","long":"76.4155","pm25":"47"},{"location_name":"Lal Bahadur Shastri Nagar, Kalaburagi - KSPCB","location_id":"site_1565","lat":"17.321993","long":"76.822628","pm25":"35"},{"location_name":"Sector-12, Karnal - HSPCB","location_id":"site_5049","lat":"29.695300","long":"77.002700","pm25":"68"},{"location_name":"Sector-7, Kurukshetra - HSPCB","location_id":"site_5043","lat":"29.966942","long":"76.875879","pm25":"119"},{"location_name":"Sector-2 IMT, Manesar - HSPCB","location_id":"site_5039","lat":"28.360699","long":"76.936090","pm25":"230"},{"location_name":"Shastri Nagar, Narnaul - HSPCB","location_id":"site_5053","lat":"28.060249","long":"76.113115","pm25":"365"},{"location_name":"Sector-6, Panchkula - HSPCB ","location_id":"site_161","lat":"30.7057778","long":"76.8531805555555","pm25":"33"},{"location_name":"Sector-18, Panipat - HSPCB","location_id":"site_5048","lat":"29.497973","long":"76.993331","pm25":"0"},{"location_name":"MD University, Rohtak - HSPCB","location_id":"site_147","lat":"28.52123","long":"76.37138","pm25":"191"},{"location_name":"F-Block, Sirsa - HSPCB","location_id":"site_5051","lat":"29.536400","long":"75.015800","pm25":"46"},{"location_name":"Murthal, Sonipat - HSPCB","location_id":"site_5041","lat":"29.027200","long":"77.062100","pm25":"29"},{"location_name":"Gobind Pura, Yamuna Nagar - HSPCB","location_id":"site_5046","lat":"30.1480566","long":"77.2893471","pm25":"75"},{"location_name":"Tata Stadium, Jorapokhar - JSPCB","location_id":"site_254","lat":"23.707909","long":"86.414670","pm25":"41"},{"location_name":"BTM Layout, Bengaluru - CPCB","location_id":"site_162","lat":"12.9135218","long":"77.5950804","pm25":"11"},{"location_name":"BWSSB Kadabesanahalli, Bengaluru - CPCB","location_id":"site_164","lat":"12.9352049","long":"77.6814488","pm25":"8"},{"location_name":"Bapuji Nagar, Bengaluru - KSPCB","location_id":"site_1553","lat":"12.951913","long":"77.539784","pm25":"17"},{"location_name":"City Railway Station, Bengaluru - KSPCB","location_id":"site_165","lat":"12.9756843","long":"77.5660749","pm25":""},{"location_name":"Hebbal, Bengaluru - KSPCB","location_id":"site_1554","lat":"13.029152","long":"77.585901","pm25":"35"},{"location_name":"Hombegowda Nagar, Bengaluru - KSPCB","location_id":"site_1555","lat":"12.938539","long":"77.590100","pm25":"25"},{"location_name":"Jayanagar 5th Block, Bengaluru - KSPCB","location_id":"site_1556","lat":"12.920984","long":"77.584908","pm25":"25"},{"location_name":"Peenya, Bengaluru - CPCB","location_id":"site_163","lat":"13.0270199","long":"77.494094","pm25":"46"},{"location_name":"Silk Board, Bengaluru - KSPCB","location_id":"site_1558","lat":"12.917348","long":"77.622813","pm25":"32"},{"location_name":"Deshpande Nagar, Hubballi - KSPCB","location_id":"site_1447","lat":"15.351773","long":"75.140726","pm25":"16"},{"location_name":"Hebbal 1st Stage, Mysuru - KSPCB","location_id":"site_5125","lat":"12.21041","long":"76.37376","pm25":"27"},{"location_name":"Vijay Nagar, Ramanagara - KSPCB","location_id":"site_5255","lat":"12.733409","long":"77.298051","pm25":"17"},{"location_name":"Collector Office, Yadgir - KSPCB","location_id":"site_5254","lat":"16.7602","long":"77.1428","pm25":"32"},{"location_name":"Udyogamandal, Eloor - Kerala PCB","location_id":"site_5105","lat":"10.073232","long":"76.302765","pm25":"3"},{"location_name":"Plammoodu, Thiruvananthapuram - Kerala PCB","location_id":"site_252","lat":"8.5149093","long":"76.9435879","pm25":"0"},{"location_name":"T T Nagar, Bhopal - MPPCB","location_id":"site_5247","lat":"23.233584","long":"77.400574","pm25":"154"},{"location_name":"Shrivastav Colony, Damoh - MPPCB","location_id":"site_5040","lat":"23.81748678","long":"79.446246","pm25":"40"},{"location_name":"Bhopal Chauraha, Dewas - MPPCB","location_id":"site_1404","lat":"22.9682591","long":"76.064118","pm25":"64"},{"location_name":"Chhoti Gwaltoli, Indore - MPPCB","location_id":"site_5248","lat":"22.4310","long":"75.5213","pm25":"78"},{"location_name":"Marhatal, Jabalpur - MPPCB","location_id":"site_5249","lat":"23.168606","long":"79.932247","pm25":"60"},{"location_name":"Gole Bazar, Katni - MPPCB","location_id":"site_5250","lat":"23.833778","long":"80.391222","pm25":"66"},{"location_name":"Sahilara, Maihar - KJS Cements","location_id":"site_5068","lat":"24.2613009","long":"80.7231783","pm25":"10"},{"location_name":"Sector-D Industrial Area, Mandideep - MPPCB","location_id":"site_1403","lat":"23.108440","long":"77.511428","pm25":"21"},{"location_name":"Sector-2 Industrial Area, Pithampur - MPPCB","location_id":"site_1402","lat":"22.624758","long":"75.675238","pm25":"84"},{"location_name":"Shasthri Nagar, Ratlam - IPCA Lab","location_id":"site_5042","lat":"23.331731","long":"75.045981","pm25":"57"},{"location_name":"Bandhavgar Colony, Satna - Birla Cement","location_id":"site_1433","lat":"24.58434363","long":"80.8549414","pm25":"5"},{"location_name":"Vindhyachal STPS, Singrauli - MPPCB","location_id":"site_1401","lat":"24.108970","long":"82.645580","pm25":"125"},{"location_name":"Mahakaleshwar Temple, Ujjain - MPPCB","location_id":"site_1400","lat":"23.182719 ","long":"75.768218 ","pm25":"80"},{"location_name":"More Chowk Waluj, Aurangabad - MPCB","location_id":"site_198","lat":"19.8389439","long":"75.244448","pm25":"34"},{"location_name":"Chandrapur, Chandrapur - MPCB","location_id":"site_271","lat":"19.645324","long":"77.6345232","pm25":"29"},{"location_name":"MIDC Khutala, Chandrapur - MPCB","location_id":"site_295","lat":"19.9775302","long":"79.2337086","pm25":"24"},{"location_name":"Khadakpada, Kalyan - MPCB","location_id":"site_5118","lat":"19.25292","long":"73.142019","pm25":"16"},{"location_name":"Bandra, Mumbai - MPCB","location_id":"site_168","lat":"19.041847 ","long":"72.865513","pm25":"79"},{"location_name":"Borivali East, Mumbai - MPCB","location_id":"site_5113","lat":"19.2243333","long":"72.8658113","pm25":"45"},{"location_name":"Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB","location_id":"site_5107","lat":"19.10078","long":"72.87462","pm25":"37"},{"location_name":"Colaba, Mumbai - MPCB","location_id":"site_5120","lat":"18.910000","long":"72.820000","pm25":"32"},{"location_name":"Kurla, Mumbai - MPCB","location_id":"site_5104","lat":"19.0863","long":"72.8888","pm25":"42"},{"location_name":"Powai, Mumbai - MPCB","location_id":"site_5112","lat":"19.137500","long":"72.915056","pm25":"45"},{"location_name":"Sion, Mumbai - MPCB","location_id":"site_5119","lat":"19.047000","long":"72.874600","pm25":"40"},{"location_name":"Vile Parle West, Mumbai - MPCB","location_id":"site_5106","lat":"19.10861","long":"72.83622","pm25":"32"},{"location_name":"Worli, Mumbai - MPCB","location_id":"site_5115","lat":"18.9936162","long":"72.8128113","pm25":"29"},{"location_name":"Opp GPO Civil Lines, Nagpur - MPCB","location_id":"site_303","lat":"21.152875","long":"79.0517531","pm25":"26"},{"location_name":"Gangapur Road, Nashik - MPCB","location_id":"site_304","lat":"20.0073285","long":"73.7762427","pm25":"27"},{"location_name":"Airoli, Navi Mumbai - MPCB","location_id":"site_261","lat":"19.1494","long":"72.9986","pm25":""},{"location_name":"Mahape, Navi Mumbai - MPCB","location_id":"site_5114","lat":"19.1135051","long":"73.008978","pm25":"23"},{"location_name":"Nerul, Navi Mumbai - MPCB","location_id":"site_5103","lat":"19.008751","long":"73.016620","pm25":"22"},{"location_name":"Karve Road, Pune - MPCB","location_id":"site_292","lat":"18.5011743","long":"73.8165527","pm25":"67"},{"location_name":"Pimpleshwar Mandir, Thane - MPCB","location_id":"site_305","lat":"19.192056","long":"72.9585188","pm25":""},{"location_name":"Lumpyngngad, Shillong - Meghalaya PCB","location_id":"site_5131","lat":"25.5586","long":"91.8985","pm25":"29"},{"location_name":"GM Office, Brajrajnagar - OSPCB","location_id":"site_1410","lat":"21.8004996","long":"83.8396977","pm25":"60"},{"location_name":"Talcher Coalfields,Talcher - OSPCB","location_id":"site_1408","lat":"20.9360711","long":"85.1707021","pm25":"55"},{"location_name":"Golden Temple, Amritsar - PPCB","location_id":"site_256","lat":"31.62","long":"74.876512","pm25":"89"},{"location_name":"Hardev Nagar, Bathinda - PPCB","location_id":"site_1549","lat":"30.233011","long":"74.907758","pm25":"29"},{"location_name":"Civil Line, Jalandhar - PPCB","location_id":"site_1438","lat":"31.321907","long":"75.578914","pm25":"62"},{"location_name":"Kalal Majra, Khanna - PPCB","location_id":"site_1450","lat":"30.736056 ","long":"76.209694","pm25":"64"},{"location_name":"Punjab Agricultural University, Ludhiana - PPCB","location_id":"site_253","lat":"30.9028","long":"75.8086","pm25":"44"},{"location_name":"RIMT University, Mandi Gobindgarh - PPCB","location_id":"site_255","lat":"30.649961","long":"76.331442","pm25":"71"},{"location_name":"Model Town, Patiala - PPCB","location_id":"site_1437","lat":"30.349388","long":"76.366642","pm25":"46"},{"location_name":"Ratanpura, Rupnagar - Ambuja Cements","location_id":"site_1538","lat":"31.0325454","long":"76.5623046","pm25":"38"},{"location_name":"Moti Doongri, Alwar - RSPCB","location_id":"site_1390","lat":"27.554793","long":"76.611536","pm25":"29"},{"location_name":"RIICO Ind. Area III, Bhiwadi - RSPCB","location_id":"site_1391","lat":"28.194909","long":"76.862296","pm25":"85"},{"location_name":"Adarsh Nagar, Jaipur - RSPCB","location_id":"site_1393","lat":"26.902909","long":"75.836853","pm25":"32"},{"location_name":"Police Commissionerate, Jaipur - RSPCB","location_id":"site_134","lat":"26.9164092","long":"75.7994901","pm25":"0"},{"location_name":"Shastri Nagar, Jaipur - RSPCB","location_id":"site_1396","lat":"26.9502929","long":"75.730943","pm25":"40"},{"location_name":"Collectorate, Jodhpur - RSPCB","location_id":"site_136","lat":"26.268249","long":"73.0193853","pm25":"56"},{"location_name":"Shrinath Puram, Kota - RSPCB","location_id":"site_1394","lat":"25.14389","long":"75.821256","pm25":"43"},{"location_name":"Indira Colony Vistar, Pali - RSPCB","location_id":"site_1395","lat":"25.771061","long":" 73.340227","pm25":"38"},{"location_name":"Ashok Nagar, Udaipur - RSPCB","location_id":"site_1397","lat":"24.5886166","long":"73.6321397","pm25":"41"},{"location_name":"Alandur Bus Depot, Chennai - CPCB","location_id":"site_293","lat":"12.9099161","long":"80.1076538","pm25":"32"},{"location_name":"Manali Village, Chennai - TNPCB","location_id":"site_5092","lat":"13.1662","long":"80.2584","pm25":"33"},{"location_name":"Manali, Chennai - CPCB","location_id":"site_306","lat":"13.164544","long":"80.26285","pm25":"55"},{"location_name":"Velachery Res. Area, Chennai - CPCB","location_id":"site_288","lat":"13.0052189","long":"80.2398125","pm25":"16"},{"location_name":"SIDCO Kurichi, Coimbatore - TNPCB","location_id":"site_5094","lat":"10.942451","long":"76.978996","pm25":"23"},{"location_name":"Bollaram Industrial Area, Hyderabad - TSPCB","location_id":"site_199","lat":"17.540891","long":"78.358528","pm25":"79"},{"location_name":"Central University, Hyderabad - TSPCB","location_id":"site_262","lat":"17.460103","long":"78.334361","pm25":"11"},{"location_name":"ICRISAT Patancheru, Hyderabad - TSPCB","location_id":"site_251","lat":"17.4342359","long":"78.4170318","pm25":"18"},{"location_name":"IDA Pashamylaram, Hyderabad - TSPCB","location_id":"site_275","lat":"17.5316895","long":"78.218939","pm25":"0"},{"location_name":"Sanathnagar, Hyderabad - TSPCB","location_id":"site_294","lat":"17.4559458","long":"78.4332152","pm25":"40"},{"location_name":"Zoo Park, Hyderabad - TSPCB","location_id":"site_298","lat":"17.349694","long":"78.451437","pm25":"44"},{"location_name":"Sanjay Palace, Agra - UPPCB","location_id":"site_307","lat":"27.19865833","long":"78.00598056","pm25":"77"},{"location_name":"New Collectorate, Baghpat - UPPCB","location_id":"site_1569","lat":"28.974801","long":"77.213357","pm25":"73"},{"location_name":"Yamunapuram, Bulandshahr - UPPCB","location_id":"site_1542","lat":"28.406963","long":"77.849831","pm25":"29"},{"location_name":"Indirapuram, Ghaziabad - UPPCB","location_id":"site_5082","lat":"28.646233","long":"77.358075","pm25":"95"},{"location_name":"Sanjay Nagar, Ghaziabad - UPPCB","location_id":"site_5081","lat":"28.685382","long":"77.453839","pm25":"90"},{"location_name":"Vasundhara, Ghaziabad - UPPCB","location_id":"site_144","lat":"28.6603346","long":"77.3572563","pm25":"110"},{"location_name":"Knowledge Park - III, Greater Noida - UPPCB","location_id":"site_1541","lat":"28.47272","long":"77.482000","pm25":"173"},{"location_name":"Knowledge Park - V, Greater Noida - UPPCB","location_id":"site_5121","lat":"28.557054","long":"77.453663","pm25":"96"},{"location_name":"Nehru Nagar, Kanpur - UPPCB","location_id":"site_276","lat":"26.4703136","long":"80.3229863","pm25":"111"},{"location_name":"Central School, Lucknow - CPCB","location_id":"site_272","lat":"26.8821003","long":"80.9302753","pm25":"43"},{"location_name":"Gomti Nagar, Lucknow - UPPCB","location_id":"site_5128","lat":"26.868120","long":"81.005119","pm25":"82"},{"location_name":"Lalbagh, Lucknow - CPCB","location_id":"site_277","lat":"26.8458805","long":"80.9365541","pm25":"86"},{"location_name":"Talkatora District Industries Center, Lucknow - CPCB","location_id":"site_297","lat":"26.83399722","long":"80.8917361","pm25":"61"},{"location_name":"Lajpat Nagar, Moradabad - UPPCB","location_id":"site_1398","lat":"28.825341","long":"78.7213009","pm25":"0"},{"location_name":"New Mandi, Muzaffarnagar - UPPCB","location_id":"site_1550","lat":"29.4723508","long":"77.7194031","pm25":"46"},{"location_name":"Sector - 125, Noida - UPPCB","location_id":"site_153","lat":"28.5447608","long":"77.3231257","pm25":"85"},{"location_name":"Sector - 62, Noida - IMD","location_id":"site_111","lat":"28.6245479","long":"77.3577104","pm25":"93"},{"location_name":"Sector-1, Noida - UPPCB","location_id":"site_5123","lat":"28.5898","long":"77.3101","pm25":"118"},{"location_name":"Sector-116, Noida - UPPCB","location_id":"site_5122","lat":"28.569230","long":"77.393848","pm25":"101"},{"location_name":"Ardhali Bazar, Varanasi - UPPCB","location_id":"site_273","lat":"25.3505986","long":"82.9083074","pm25":"81"},{"location_name":"Asansol Court Area, Asansol - WBPCB","location_id":"site_1418","lat":"23.685297","long":"86.945968","pm25":"51"},{"location_name":"Belur Math, Howrah - WBPCB","location_id":"site_5101","lat":"22.629801","long":"88.352017","pm25":"63"},{"location_name":"Ghusuri, Howrah - WBPCB","location_id":"site_274","lat":"22.611968","long":"88.347422","pm25":"74"},{"location_name":"Padmapukur, Howrah - WBPCB","location_id":"site_1416","lat":"22.5687319","long":"88.2797276","pm25":"83"},{"location_name":"Fort William, Kolkata - WBPCB","location_id":"site_5110","lat":"22.556640","long":"88.342674","pm25":"75"},{"location_name":"Jadavpur, Kolkata - WBPCB","location_id":"site_5111","lat":"22.49929","long":"88.36917","pm25":"40"},{"location_name":"Rabindra Bharati University, Kolkata - WBPCB","location_id":"site_296","lat":"22.627847","long":"88.380669","pm25":"95"},{"location_name":"Rabindra Sarobar, Kolkata - WBPCB","location_id":"site_5126","lat":"22.51106","long":"88.35142","pm25":"66"},{"location_name":"Victoria, Kolkata - WBPCB","location_id":"site_309","lat":"22.5448082","long":"88.3403691","pm25":"76"},{"location_name":"Ward-32 Bapupara, Siliguri - WBPCB","location_id":"site_1419","lat":"26.6883049","long":"88.412668","pm25":"83"},{"location_name":"Haldia, Haldia - WBPCB","location_id":"site_300","lat":"22.06047","long":"88.109737","pm25":""},{"location_name":"Chikkaballapur Rural, Chikkaballapur - KSPCB","location_id":"site_1557","lat":"13.428828","long":"77.731418","pm25":"33"},{"location_name":"Sanegurava Halli, Bengaluru - KSPCB","location_id":"site_166","lat":"12.990328","long":"77.5431385","pm25":""},{"location_name":"General Hospital, Mandikhera - HSPCB","location_id":"site_5055","lat":"27.9002","long":"76.9938","pm25":"174"},{"location_name":"Vasai West, Mumbai - MPCB","location_id":"site_5102","lat":"19.383200","long":"72.820400","pm25":"47"},{"location_name":"Anand Vihar, Hapur - UPPCB","location_id":"site_5023","lat":"28.725645","long":"77.749675","pm25":"19"},{"location_name":"Secretariat, Amaravati - APPCB","location_id":"site_1406","lat":"16.5150833","long":"80.5181667","pm25":"28"},{"location_name":"Jai Bhim Nagar, Meerut - UPPCB","location_id":"site_5109","lat":"28.9535882","long":"77.7622941","pm25":"23"},{"location_name":"Loni, Ghaziabad - UPPCB","location_id":"site_5083","lat":"28.757294","long":"77.278792","pm25":"108"},{"location_name":"Ganga Nagar, Meerut - UPPCB","location_id":"site_5258","lat":"28.999264","long":"77.7590354","pm25":"32"},{"location_name":"Pallavpuram Phase 2, Meerut - UPPCB","location_id":"site_5257","lat":"29.063510","long":"77.709723","pm25":"52"},{"location_name":"East Arjun Nagar, Delhi - CPCB","location_id":"site_116","lat":"28.6556017","long":"77.2859318","pm25":""},{"location_name":"Civil Lines,  Ajmer - RSPCB","location_id":"site_1392","lat":"26.470859","long":"74.646594","pm25":"20"},{"location_name":"Municipal Corporation Office, Dharuhera -  HSPCB","location_id":"site_5044","lat":"28.206800","long":"76.799700","pm25":"54"},{"location_name":"Urban, Chamarajanagar - KSPCB","location_id":"site_5124","lat":"11.55358","long":"76.55521","pm25":"15"},{"location_name":"Muradpur, Patna - BSPCB","location_id":"site_5261","lat":"25.619651","long":"85.147382","pm25":"89"},{"location_name":"Rajbansi Nagar, Patna - BSPCB","location_id":"site_5262","lat":"25.599486","long":"85.113666","pm25":"99"},{"location_name":"Samanpura, Patna - BSPCB","location_id":"site_5263","lat":"25.596727","long":"85.085624","pm25":"125"},{"location_name":"Sector-7","location_id":"site_5043","lat":"29.966942","long":"76.875879","pm25":"119"},{"location_name":"Sector-2 IMT","location_id":"site_5039","lat":"28.360699","long":"76.936090","pm25":"230"},{"location_name":"Shastri Nagar","location_id":"site_5053","lat":"28.060249","long":"76.113115","pm25":"365"},{"location_name":"General Hospital","location_id":"site_5055","lat":"27.9002","long":"76.9938","pm25":"174"},{"location_name":"Shyam Nagar","location_id":"site_5050","lat":"28.1485564","long":"77.3320667","pm25":"260"},{"location_name":"Sector-18","location_id":"site_5048","lat":"29.497973","long":"76.993331","pm25":"0"},{"location_name":"MD University","location_id":"site_147","lat":"28.52123","long":"76.37138","pm25":"191"},{"location_name":"Bidhannagar, Kolkata - WBPCB","location_id":"site_5129","lat":"22.58157048","long":"88.41002457","pm25":"85"},{"location_name":"Ballygunge, Kolkata - WBPCB","location_id":"site_5238","lat":"22.5367507","long":"88.3638022","pm25":"62"},{"location_name":"16th and Whitmore","location_id":"5","lat":"41.32247","long":"-95.93799","pm25":""},{"location_name":"1\u53f7","location_id":"6","lat":"36.792","long":"119.952","pm25":""},{"location_name":"21 de Mayo","location_id":"7","lat":"-28.467794","long":"-71.227295","pm25":""},{"location_name":"22nd Street & Craycr","location_id":"8","lat":"32.205","long":"-110.8772","pm25":""},{"location_name":"22\u4e2d\u5357\u6821\u533a","location_id":"9","lat":"38.037777","long":"114.54806","pm25":""},{"location_name":"2912 Coffey","location_id":"11","lat":"41.133316","long":"-95.95608","pm25":""},{"location_name":"2LL Los Lunas","location_id":"12","lat":"34.8147","long":"-106.7397","pm25":""},{"location_name":"2\u53f7","location_id":"13","lat":"36.799","long":"119.976","pm25":""},{"location_name":"2\u53f7\u5b50\u7ad9","location_id":"14","lat":"35.872","long":"120.039","pm25":""},{"location_name":"60 Near Road","location_id":"27","lat":"34.0309","long":"-117.6174","pm25":""},{"location_name":"710 Near Road","location_id":"31","lat":"33.85966","long":"-118.20071","pm25":""},{"location_name":"77th and Dodge","location_id":"33","lat":"41.25948","long":"-96.03471","pm25":""},{"location_name":"7E Deming Airport","location_id":"34","lat":"32.2558","long":"-107.7228","pm25":""},{"location_name":"A Street","location_id":"35","lat":"64.84593","long":"-147.69328","pm25":""},{"location_name":"AD0942A","location_id":"36","lat":"42.509693","long":"1.539138","pm25":""},{"location_name":"AD0944A","location_id":"37","lat":"42.516945","long":"1.56525","pm25":""},{"location_name":"AD0945A","location_id":"38","lat":"42.53488","long":"1.716986","pm25":""},{"location_name":"ADEQ-DSR","location_id":"41","lat":"34.6811","long":"-92.3283","pm25":""},{"location_name":"AIR LAB","location_id":"43","lat":"35.9803","long":"-83.9306","pm25":""},{"location_name":"AJ Maintenance Yard","location_id":"44","lat":"33.4206","long":"-111.5033","pm25":""},{"location_name":"Algoma","location_id":"47","lat":"47.035","long":"-84.3811","pm25":""},{"location_name":"ALLEN PARK","location_id":"48","lat":"42.2283","long":"-83.2092","pm25":""},{"location_name":"ALSIP","location_id":"49","lat":"41.6708","long":"-87.7325","pm25":""},{"location_name":"AM1 Gda\u0144sk \u015ar\u00f3dmie\u015bcie","location_id":"51","lat":"54.353336","long":"18.635283","pm25":""},{"location_name":"AM10 Gdynia \u015ar\u00f3dmie\u015bcie","location_id":"52","lat":"54.525272","long":"18.536383","pm25":""},{"location_name":"AM11 S\u0142upsk Kniaziewicza","location_id":"53","lat":"54.46361","long":"17.046722","pm25":""},{"location_name":"AM12 Ko\u015bcierzyna Targowa","location_id":"54","lat":"54.120693","long":"17.97586","pm25":""},{"location_name":"AM15 Malbork Mickiewicza","location_id":"55","lat":"54.031246","long":"19.0329","pm25":""},{"location_name":"AM16 L\u0119bork Malczewskiego","location_id":"56","lat":"54.546165","long":"17.746195","pm25":""},{"location_name":"AM17 Liniewko Ko\u015bcierskie","location_id":"57","lat":"54.10411","long":"18.182972","pm25":""},{"location_name":"AM2 Gda\u0144sk Stogi","location_id":"58","lat":"54.36778","long":"18.70111","pm25":""},{"location_name":"AM3 Gda\u0144sk Nowy Port","location_id":"59","lat":"54.400833","long":"18.657497","pm25":""},{"location_name":"AM4 Gdynia Pog\u00f3rze","location_id":"60","lat":"54.560837","long":"18.493332","pm25":""},{"location_name":"AM5 Gda\u0144sk Szad\u00f3\u0142ki","location_id":"61","lat":"54.328335","long":"18.557781","pm25":""},{"location_name":"AM6 Sopot","location_id":"62","lat":"54.431667","long":"18.579721","pm25":""},{"location_name":"AM8 Gda\u0144sk Wrzeszcz","location_id":"63","lat":"54.38028","long":"18.620274","pm25":""},{"location_name":"AM9 Gdynia D\u0105browa","location_id":"64","lat":"54.46576","long":"18.46491","pm25":""},{"location_name":"APOLLO BEACH","location_id":"67","lat":"27.779713","long":"-82.41984","pm25":""},{"location_name":"APPLETON AAL","location_id":"68","lat":"44.3069","long":"-88.3956","pm25":""},{"location_name":"ASHBURN","location_id":"71","lat":"39.0244","long":"-77.49","pm25":""},{"location_name":"ATHENS","location_id":"73","lat":"35.4511","long":"-84.5992","pm25":""},{"location_name":"AURORA HILLS","location_id":"74","lat":"38.8594","long":"-77.0589","pm25":""},{"location_name":"AYLESFORD MOUNTAIN","location_id":"75","lat":"45.0061","long":"-65","pm25":""},{"location_name":"Abbotsford","location_id":"76","lat":"49.04278","long":"-122.30972","pm25":""},{"location_name":"Abbotsford Airport","location_id":"77","lat":"49.021507","long":"-122.32655","pm25":""},{"location_name":"Aberdeen","location_id":"78","lat":"57.15736","long":"-2.094278","pm25":""},{"location_name":"Aberdeen Union Street Roadside","location_id":"79","lat":"57.144554","long":"-2.106472","pm25":""},{"location_name":"Aberdeen Wellington Road","location_id":"80","lat":"57.13389","long":"-2.094198","pm25":""},{"location_name":"Aberdeen-Division St","location_id":"81","lat":"46.9772","long":"-123.8317","pm25":""},{"location_name":"Abington","location_id":"82","lat":"41.8402","long":"-72.01","pm25":""},{"location_name":"Abu Dhabi","location_id":"83","lat":"24.42431","long":"54.433872","pm25":""},{"location_name":"Acadia NP - McFarlan","location_id":"84","lat":"44.37705","long":"-68.2609","pm25":""},{"location_name":"Acquapendente","location_id":"86","lat":"42.73665","long":"11.876578","pm25":""},{"location_name":"Adams","location_id":"87","lat":"39.82839","long":"-104.93846","pm25":""},{"location_name":"Airponter Wieniec Zdr\u00f3j","location_id":"90","lat":"52.656864","long":"18.987368","pm25":""},{"location_name":"Ajo","location_id":"92","lat":"32.382034","long":"-112.85745","pm25":""},{"location_name":"Akron NIFH\/STEM","location_id":"93","lat":"41.07914","long":"-81.51627","pm25":""},{"location_name":"Alabama-Coushatta","location_id":"96","lat":"30.6681","long":"-94.6739","pm25":""},{"location_name":"Alamo Lake","location_id":"97","lat":"34.24389","long":"-113.55861","pm25":""},{"location_name":"Alatri","location_id":"99","lat":"41.73","long":"13.338333","pm25":""},{"location_name":"Albany","location_id":"100","lat":"31.5767","long":"-84.1002","pm25":""},{"location_name":"Albany - Calapooia S","location_id":"101","lat":"44.61569","long":"-123.09145","pm25":""},{"location_name":"Albemarle HS","location_id":"102","lat":"38.0766","long":"-78.504","pm25":""},{"location_name":"Albion Park Sth","location_id":"103","lat":"-34.580555","long":"150.78166","pm25":""},{"location_name":"Albury","location_id":"104","lat":"-36.051666","long":"146.97417","pm25":""},{"location_name":"Alerce","location_id":"107","lat":"-41.39917","long":"-72.89952","pm25":""},{"location_name":"Alhambra","location_id":"109","lat":"38.869","long":"-89.6228","pm25":""},{"location_name":"Allentown","location_id":"112","lat":"40.6119","long":"-75.4325","pm25":""},{"location_name":"Allumiere","location_id":"115","lat":"42.15774","long":"11.908744","pm25":""},{"location_name":"Allumiere - v.Aldo Moro","location_id":"116","lat":"42.160973","long":"11.900022","pm25":""},{"location_name":"Alnabru","location_id":"117","lat":"59.92773","long":"10.84633","pm25":""},{"location_name":"Alpine","location_id":"118","lat":"32.842297","long":"-116.768326","pm25":""},{"location_name":"Alto Hospicio","location_id":"120","lat":"-20.290466","long":"-70.10019","pm25":""},{"location_name":"Altoona","location_id":"121","lat":"40.515","long":"-78.3889","pm25":""},{"location_name":"Alvim","location_id":"123","lat":"59.273777","long":"11.0891905","pm25":""},{"location_name":"Amanda  Elementary","location_id":"125","lat":"39.478848","long":"-84.40768","pm25":""},{"location_name":"Amherst","location_id":"129","lat":"42.9925","long":"-78.7764","pm25":""},{"location_name":"Amman","location_id":"130","lat":"31.94502","long":"35.8805","pm25":""},{"location_name":"Amsterdam-A10 west","location_id":"131","lat":"52.3395","long":"4.84102","pm25":""},{"location_name":"Amsterdam-Einsteinweg","location_id":"132","lat":"52.3813","long":"4.84523","pm25":""},{"location_name":"Amsterdam-Haarlemmerweg","location_id":"133","lat":"52.3854","long":"4.87575","pm25":""},{"location_name":"Amsterdam-Hoogtij","location_id":"134","lat":"52.428","long":"4.77348","pm25":""},{"location_name":"Amsterdam-Jan van Galenstraat","location_id":"135","lat":"52.3748","long":"4.86032","pm25":""},{"location_name":"Amsterdam-Kantershof (Zuid Oost)","location_id":"136","lat":"52.3207","long":"4.9884","pm25":""},{"location_name":"Amsterdam-Nieuwendammerdijk","location_id":"137","lat":"52.3893","long":"4.94382","pm25":""},{"location_name":"Amsterdam-Oude Schans","location_id":"138","lat":"52.3721","long":"4.9044","pm25":""},{"location_name":"Amsterdam-Spaarnwoude","location_id":"139","lat":"52.3984","long":"4.72858","pm25":""},{"location_name":"Amsterdam-Sportpark Ookmeer (Osdorp)","location_id":"140","lat":"52.3668","long":"4.79334","pm25":""},{"location_name":"Amsterdam-Stadhouderskade","location_id":"141","lat":"52.358","long":"4.8997","pm25":""},{"location_name":"Amsterdam-Van Diemenstraat","location_id":"142","lat":"52.39","long":"4.88781","pm25":""},{"location_name":"Amsterdam-Vondelpark","location_id":"143","lat":"52.3597","long":"4.86621","pm25":""},{"location_name":"Amsterdam-Westerpark","location_id":"144","lat":"52.394","long":"4.87016","pm25":""},{"location_name":"Anacortes-202 Ave (S","location_id":"146","lat":"48.52059","long":"-122.61428","pm25":""},{"location_name":"Anacortes-Bartholome","location_id":"147","lat":"48.4654","long":"-122.56","pm25":""},{"location_name":"Anagni","location_id":"148","lat":"41.75","long":"13.149685","pm25":""},{"location_name":"Anaheim","location_id":"149","lat":"33.830585","long":"-117.93851","pm25":""},{"location_name":"Anaheim Near Road","location_id":"150","lat":"33.819305","long":"-117.91876","pm25":""},{"location_name":"Andacollo","location_id":"154","lat":"-30.227768","long":"-71.08613","pm25":""},{"location_name":"Anderson","location_id":"155","lat":"40.4531","long":"-122.2978","pm25":""},{"location_name":"Anderson-Eastside El","location_id":"156","lat":"40.125557","long":"-85.65222","pm25":""},{"location_name":"Andrew Johnson Elem.","location_id":"157","lat":"36.526417","long":"-82.52868","pm25":""},{"location_name":"Ann Arbor","location_id":"158","lat":"42.4164","long":"-83.9019","pm25":""},{"location_name":"Antelope - North Hig","location_id":"163","lat":"38.71209","long":"-121.38109","pm25":""},{"location_name":"Anthony","location_id":"164","lat":"32.0036","long":"-106.5992","pm25":""},{"location_name":"Antofagasta","location_id":"165","lat":"-23.613543","long":"-70.383316","pm25":""},{"location_name":"Apache Junction","location_id":"166","lat":"33.42","long":"-111.5042","pm25":""},{"location_name":"Apple Valley","location_id":"168","lat":"44.7383","long":"-93.2372","pm25":""},{"location_name":"Aprilia 2","location_id":"169","lat":"41.595345","long":"12.653581","pm25":""},{"location_name":"Aranyaprathet, Aranyaprathet","location_id":"172","lat":"13.689029","long":"102.50621","pm25":""},{"location_name":"Archbold Biomedical","location_id":"175","lat":"27.1889","long":"-81.3403","pm25":""},{"location_name":"Arden Arcade - Del P","location_id":"176","lat":"38.613804","long":"-121.368004","pm25":""},{"location_name":"Arendtsville","location_id":"179","lat":"39.9233","long":"-77.3081","pm25":""},{"location_name":"Arenula","location_id":"180","lat":"41.89402","long":"12.475368","pm25":""},{"location_name":"Arica","location_id":"181","lat":"-18.47684","long":"-70.28791","pm25":""},{"location_name":"Arlington Municipal","location_id":"182","lat":"32.6558","long":"-97.0886","pm25":""},{"location_name":"Armagh Roadside","location_id":"183","lat":"54.35373","long":"-6.654558","pm25":""},{"location_name":"Arvin - Di Giorgio S","location_id":"189","lat":"35.23918","long":"-118.78863","pm25":""},{"location_name":"Ascarate Park Southe","location_id":"192","lat":"31.7467","long":"-106.4028","pm25":""},{"location_name":"Ashgabat","location_id":"193","lat":"37.9415","long":"58.3879","pm25":""},{"location_name":"Ashland","location_id":"194","lat":"46.604","long":"-68.4135","pm25":""},{"location_name":"Ashland Fire Dept","location_id":"195","lat":"42.1941","long":"-122.7086","pm25":""},{"location_name":"Aston Hill","location_id":"201","lat":"52.50385","long":"-3.034178","pm25":""},{"location_name":"Atascadero2","location_id":"203","lat":"35.494556","long":"-120.66621","pm25":""},{"location_name":"Athabasca Valley","location_id":"205","lat":"56.7328","long":"-111.39","pm25":""},{"location_name":"Athens","location_id":"206","lat":"33.925","long":"-83.3575","pm25":""},{"location_name":"Auburn","location_id":"209","lat":"38.9378","long":"-121.1039","pm25":""},{"location_name":"Auchencorth Moss","location_id":"210","lat":"55.79216","long":"-3.2429","pm25":""},{"location_name":"Auckland Point","location_id":"211","lat":"-23.8351","long":"151.254","pm25":""},{"location_name":"Audubon C38","location_id":"212","lat":"30.483168","long":"-97.8723","pm25":""},{"location_name":"Augusta","location_id":"213","lat":"33.4333","long":"-82.0219","pm25":""},{"location_name":"August\u00f3w - mobilne ","location_id":"214","lat":"53.859528","long":"23.00075","pm25":""},{"location_name":"Aurelia","location_id":"215","lat":"42.137344","long":"11.793163","pm25":""},{"location_name":"Aurora East","location_id":"216","lat":"39.638542","long":"-104.56906","pm25":""},{"location_name":"Austin Northwest C3","location_id":"217","lat":"30.3542","long":"-97.76","pm25":""},{"location_name":"Avon","location_id":"223","lat":"39.7589","long":"-86.3972","pm25":""},{"location_name":"Azalea","location_id":"225","lat":"27.7858","long":"-82.74","pm25":""},{"location_name":"Azusa","location_id":"227","lat":"34.136475","long":"-117.923965","pm25":""},{"location_name":"A\u00e9roport de Montr\u00e9al","location_id":"228","lat":"45.468296","long":"-73.74119","pm25":""},{"location_name":"Bad River Tribal Sch","location_id":"230","lat":"46.6144","long":"-90.6986","pm25":""},{"location_name":"BADIA","location_id":"231","lat":"44.6582","long":"10.2894","pm25":""},{"location_name":"BALLIRANA","location_id":"232","lat":"44.5274","long":"11.9824","pm25":""},{"location_name":"BAR-PDLA - Parque de las Aguas","location_id":"233","lat":"6.4067135","long":"-75.41949","pm25":""},{"location_name":"BAR-TORR - Barbosa - Torre Social","location_id":"234","lat":"6.43696","long":"-75.3304","pm25":""},{"location_name":"BATHURST","location_id":"237","lat":"47.6094","long":"-65.6333","pm25":""},{"location_name":"BAY CITY","location_id":"238","lat":"43.5714","long":"-83.8908","pm25":""},{"location_name":"BAYROAD","location_id":"239","lat":"30.4744","long":"-88.1411","pm25":""},{"location_name":"BAYVIEW","location_id":"241","lat":"35.428","long":"-76.74","pm25":""},{"location_name":"BCSP","location_id":"242","lat":"39.8172","long":"-75.5639","pm25":""},{"location_name":"BDED","location_id":"243","lat":"35.6062","long":"-82.5844","pm25":""},{"location_name":"BEL-FEVE - Bello - I.E. Fernando V\u00e9lez","location_id":"245","lat":"6.33755","long":"-75.5678","pm25":""},{"location_name":"BEL-USBV - Universidad San Buenaventura","location_id":"246","lat":"6.330697","long":"-75.56867","pm25":""},{"location_name":"BELAL01","location_id":"247","lat":"51.236195","long":"4.385224","pm25":""},{"location_name":"BELAL03","location_id":"248","lat":"51.253963","long":"4.2014604","pm25":""},{"location_name":"BELAL04","location_id":"249","lat":"51.29067","long":"4.2933292","pm25":""},{"location_name":"BELAL05","location_id":"250","lat":"51.26312","long":"4.2788897","pm25":""},{"location_name":"BELHB23","location_id":"252","lat":"51.1703","long":"4.341005","pm25":""},{"location_name":"BELLD02","location_id":"254","lat":"51.120384","long":"5.021546","pm25":""},{"location_name":"BELLFNT2","location_id":"255","lat":"39.7739","long":"-75.4964","pm25":""},{"location_name":"BELMN01","location_id":"256","lat":"50.79347","long":"3.1096418","pm25":""},{"location_name":"BELOB01","location_id":"257","lat":"50.91723","long":"3.3073857","pm25":""},{"location_name":"BELOB02","location_id":"258","lat":"50.91495","long":"3.3762116","pm25":""},{"location_name":"BELR833","location_id":"259","lat":"51.32766","long":"4.362261","pm25":""},{"location_name":"BELRL01","location_id":"260","lat":"50.95318","long":"3.1211555","pm25":""},{"location_name":"BELSA04","location_id":"261","lat":"51.31393","long":"4.403868","pm25":""},{"location_name":"BELSZ01","location_id":"262","lat":"50.914577","long":"4.5041833","pm25":""},{"location_name":"BELSZ02","location_id":"263","lat":"50.91302","long":"4.512184","pm25":""},{"location_name":"BELWZ02","location_id":"264","lat":"51.1928","long":"5.2215343","pm25":""},{"location_name":"BESENZONE","location_id":"265","lat":"44.9895","long":"10.0192","pm25":""},{"location_name":"BETB004","location_id":"266","lat":"50.85081","long":"4.3485875","pm25":""},{"location_name":"BETB006","location_id":"267","lat":"50.83863","long":"4.374388","pm25":""},{"location_name":"BETB008","location_id":"268","lat":"50.84079","long":"4.376149","pm25":""},{"location_name":"BETB011","location_id":"269","lat":"50.858032","long":"4.2883363","pm25":""},{"location_name":"BETE007","location_id":"270","lat":"50.7953","long":"4.2526283","pm25":""},{"location_name":"BETE008","location_id":"271","lat":"50.926094","long":"4.39592","pm25":""},{"location_name":"BETE009","location_id":"272","lat":"50.954918","long":"4.435417","pm25":""},{"location_name":"BETE013","location_id":"273","lat":"50.811703","long":"4.328385","pm25":""},{"location_name":"BETE703","location_id":"274","lat":"51.190315","long":"3.6872957","pm25":""},{"location_name":"BETE704","location_id":"275","lat":"51.1761","long":"3.8699281","pm25":""},{"location_name":"BETE714","location_id":"276","lat":"51.278965","long":"3.248624","pm25":""},{"location_name":"BETE715","location_id":"277","lat":"51.245865","long":"3.1749842","pm25":""},{"location_name":"BETE716","location_id":"278","lat":"51.066986","long":"3.682813","pm25":""},{"location_name":"BETE814","location_id":"279","lat":"51.082188","long":"5.1297183","pm25":""},{"location_name":"BETH201","location_id":"280","lat":"50.624992","long":"5.547464","pm25":""},{"location_name":"BETM204","location_id":"282","lat":"50.611923","long":"5.61115","pm25":""},{"location_name":"BETM702","location_id":"283","lat":"51.166023","long":"3.7621374","pm25":""},{"location_name":"BETM705","location_id":"284","lat":"50.94536","long":"3.1524017","pm25":""},{"location_name":"BETM802","location_id":"285","lat":"51.26099","long":"4.424399","pm25":""},{"location_name":"BETMEU1","location_id":"286","lat":"50.8951","long":"4.392718","pm25":""},{"location_name":"BETN012","location_id":"287","lat":"51.254574","long":"3.362536","pm25":""},{"location_name":"BETN016","location_id":"288","lat":"51.233654","long":"5.163979","pm25":""},{"location_name":"BETN027","location_id":"289","lat":"51.133717","long":"5.6066594","pm25":""},{"location_name":"BETN029","location_id":"290","lat":"51.01628","long":"2.582323","pm25":""},{"location_name":"BETN035","location_id":"291","lat":"50.977543","long":"4.837618","pm25":""},{"location_name":"BETN040","location_id":"292","lat":"50.76814","long":"4.2251945","pm25":""},{"location_name":"BETN043","location_id":"293","lat":"50.88356","long":"4.382963","pm25":""},{"location_name":"BETN046","location_id":"294","lat":"50.882298","long":"5.618874","pm25":""},{"location_name":"BETN051","location_id":"295","lat":"50.798916","long":"3.9302933","pm25":""},{"location_name":"BETN052","location_id":"296","lat":"50.814873","long":"3.3224943","pm25":""},{"location_name":"BETN054","location_id":"297","lat":"50.711704","long":"5.1031585","pm25":""},{"location_name":"BETN060","location_id":"298","lat":"50.61672","long":"3.4576244","pm25":""},{"location_name":"BETN063","location_id":"299","lat":"50.655437","long":"4.668288","pm25":""},{"location_name":"BETN066","location_id":"300","lat":"50.62886","long":"6.002329","pm25":""},{"location_name":"BETN067","location_id":"301","lat":"50.612278","long":"5.9927526","pm25":""},{"location_name":"BETN070","location_id":"302","lat":"50.46519","long":"3.9397144","pm25":""},{"location_name":"BETN073","location_id":"303","lat":"50.502716","long":"4.988423","pm25":""},{"location_name":"BETN085","location_id":"304","lat":"50.303207","long":"6.001736","pm25":""},{"location_name":"BETN093","location_id":"305","lat":"50.27448","long":"5.235169","pm25":""},{"location_name":"BETN100","location_id":"306","lat":"50.095684","long":"4.594763","pm25":""},{"location_name":"BETN113","location_id":"307","lat":"50.027027","long":"5.593017","pm25":""},{"location_name":"BETN121","location_id":"308","lat":"49.87713","long":"5.202387","pm25":""},{"location_name":"BETN132","location_id":"309","lat":"49.71928","long":"5.630398","pm25":""},{"location_name":"BETR001","location_id":"310","lat":"50.849667","long":"4.33382","pm25":""},{"location_name":"BETR002","location_id":"311","lat":"50.825127","long":"4.384719","pm25":""},{"location_name":"BETR010","location_id":"312","lat":"50.86511","long":"4.428427","pm25":""},{"location_name":"BETR012","location_id":"313","lat":"50.79663","long":"4.358539","pm25":""},{"location_name":"BETR020","location_id":"314","lat":"50.941387","long":"4.436721","pm25":""},{"location_name":"BETR221","location_id":"315","lat":"50.658443","long":"5.627835","pm25":""},{"location_name":"BETR222","location_id":"316","lat":"50.613415","long":"5.570223","pm25":""},{"location_name":"BETR223","location_id":"317","lat":"50.62067","long":"5.516405","pm25":""},{"location_name":"BETR240","location_id":"318","lat":"50.583614","long":"5.397446","pm25":""},{"location_name":"BETR501","location_id":"319","lat":"50.40931","long":"4.452172","pm25":""},{"location_name":"BETR502","location_id":"320","lat":"50.428993","long":"4.458681","pm25":""},{"location_name":"BETR510","location_id":"321","lat":"50.416435","long":"4.52113","pm25":""},{"location_name":"BETR511","location_id":"322","lat":"50.37759","long":"4.4247","pm25":""},{"location_name":"BETR512","location_id":"323","lat":"50.40781","long":"4.395897","pm25":""},{"location_name":"BETR701","location_id":"324","lat":"51.05833","long":"3.729298","pm25":""},{"location_name":"BETR702","location_id":"325","lat":"51.040688","long":"3.7349715","pm25":""},{"location_name":"BETR710","location_id":"326","lat":"51.06128","long":"3.7752624","pm25":""},{"location_name":"BETR721","location_id":"327","lat":"51.08896","long":"3.7161193","pm25":""},{"location_name":"BETR731","location_id":"328","lat":"51.12469","long":"3.7395043","pm25":""},{"location_name":"BETR740","location_id":"329","lat":"51.150135","long":"3.808735","pm25":""},{"location_name":"BETR750","location_id":"330","lat":"51.196064","long":"3.82292","pm25":""},{"location_name":"BETR801","location_id":"331","lat":"51.209663","long":"4.431821","pm25":""},{"location_name":"BETR802","location_id":"332","lat":"51.20952","long":"4.4317923","pm25":""},{"location_name":"BETR803","location_id":"333","lat":"51.22863","long":"4.4284544","pm25":""},{"location_name":"BETR805","location_id":"334","lat":"51.20823","long":"4.4215593","pm25":""},{"location_name":"BETR811","location_id":"335","lat":"51.2521","long":"4.491362","pm25":""},{"location_name":"BETR817","location_id":"337","lat":"51.17713","long":"4.4179487","pm25":""},{"location_name":"BETR820","location_id":"338","lat":"51.320415","long":"4.4448104","pm25":""},{"location_name":"BETR822","location_id":"339","lat":"51.26429","long":"4.34128","pm25":""},{"location_name":"BETR830","location_id":"340","lat":"51.31823","long":"4.262634","pm25":""},{"location_name":"BETR831","location_id":"341","lat":"51.348797","long":"4.3397098","pm25":""},{"location_name":"BETR834","location_id":"342","lat":"51.092","long":"4.3801036","pm25":""},{"location_name":"BETR891","location_id":"343","lat":"51.255806","long":"4.38536","pm25":""},{"location_name":"BETR892","location_id":"344","lat":"51.26304","long":"4.27889","pm25":""},{"location_name":"BETR893","location_id":"345","lat":"51.28138","long":"4.385771","pm25":""},{"location_name":"BETR897","location_id":"347","lat":"51.250107","long":"4.3421044","pm25":""},{"location_name":"BETWOL1","location_id":"348","lat":"50.85658","long":"4.425704","pm25":""},{"location_name":"BKC","location_id":"349","lat":"44.531944","long":"18.654722","pm25":""},{"location_name":"BLAIR STREET","location_id":"350","lat":"38.65645","long":"-90.19855","pm25":""},{"location_name":"BOGOLESE","location_id":"352","lat":"44.8291","long":"10.3915","pm25":""},{"location_name":"BONDVILLE","location_id":"353","lat":"40.052242","long":"-88.37255","pm25":""},{"location_name":"BOSTON-KENMORE","location_id":"356","lat":"42.3489","long":"-71.0977","pm25":""},{"location_name":"BRAIDWD","location_id":"357","lat":"41.2222","long":"-88.1906","pm25":""},{"location_name":"BROADWAY (South)","location_id":"358","lat":"38.5425","long":"-90.26361","pm25":""},{"location_name":"BRYSON","location_id":"359","lat":"35.43477","long":"-83.44213","pm25":""},{"location_name":"BUTLER MANUF. CO NEA","location_id":"363","lat":"39.2828","long":"-78.0814","pm25":""},{"location_name":"Babylon","location_id":"367","lat":"40.7356","long":"-73.4061","pm25":""},{"location_name":"Badhoevedorp-Sloterweg","location_id":"372","lat":"52.334","long":"4.77401","pm25":""},{"location_name":"Badlands","location_id":"373","lat":"43.746944","long":"-101.94111","pm25":""},{"location_name":"Baghdad","location_id":"375","lat":"33.3128","long":"44.3615","pm25":""},{"location_name":"Baker City - Forest","location_id":"379","lat":"44.78822","long":"-117.8446","pm25":""},{"location_name":"Bakersfield - Califo","location_id":"380","lat":"35.356613","long":"-119.062614","pm25":""},{"location_name":"Bakersfield-Muni","location_id":"381","lat":"35.3313","long":"-119","pm25":""},{"location_name":"Bakke kirke","location_id":"382","lat":"63.43293","long":"10.41067","pm25":""},{"location_name":"Balk-Trophornsterweg","location_id":"383","lat":"52.9169","long":"5.57349","pm25":""},{"location_name":"Ballymena Ballykeel","location_id":"384","lat":"54.861595","long":"-6.250873","pm25":""},{"location_name":"Baltimore County Nea","location_id":"385","lat":"39.371677","long":"-76.74681","pm25":""},{"location_name":"Ban Dong, Mae Mo","location_id":"386","lat":"18.419424","long":"99.72704","pm25":""},{"location_name":"Ban Suan, Mueang","location_id":"387","lat":"13.360626","long":"100.98454","pm25":""},{"location_name":"Bang Kruai, Bang Kruai","location_id":"392","lat":"13.807158","long":"100.50632","pm25":""},{"location_name":"Bang Nak, Mueang","location_id":"393","lat":"6.427698","long":"101.82357","pm25":""},{"location_name":"Bang Phut, Pak Kret","location_id":"394","lat":"13.907827","long":"100.53565","pm25":""},{"location_name":"Bang Sao Thong, Bang Sao Thong","location_id":"395","lat":"13.567697","long":"100.789406","pm25":""},{"location_name":"Bangel\u00f8kka","location_id":"396","lat":"59.73325","long":"10.21187","pm25":""},{"location_name":"Bangna, Bangna","location_id":"397","lat":"13.666116","long":"100.60574","pm25":""},{"location_name":"Bangor MSS","location_id":"399","lat":"44.817398","long":"-68.77276","pm25":""},{"location_name":"Bankplassen","location_id":"400","lat":"61.11288","long":"10.46497","pm25":""},{"location_name":"Banning - South Hath","location_id":"401","lat":"33.920757","long":"-116.85842","pm25":""},{"location_name":"Bargo","location_id":"404","lat":"-34.3075","long":"150.58","pm25":""},{"location_name":"Barnsley Gawber","location_id":"405","lat":"53.56292","long":"-1.510436","pm25":""},{"location_name":"Barnstaple A39","location_id":"406","lat":"51.074795","long":"-4.041924","pm25":""},{"location_name":"Barrie","location_id":"408","lat":"44.3922","long":"-79.3922","pm25":""},{"location_name":"Barsbeek-De Veenen","location_id":"409","lat":"52.6541","long":"6.01757","pm25":""},{"location_name":"Barstow","location_id":"410","lat":"34.894054","long":"-117.02476","pm25":""},{"location_name":"Basin","location_id":"412","lat":"44.28","long":"-108.04111","pm25":""},{"location_name":"Batavia","location_id":"413","lat":"39.0828","long":"-84.1441","pm25":""},{"location_name":"Bathurst","location_id":"416","lat":"-33.40333","long":"149.57333","pm25":""},{"location_name":"Bay Oaks Park","location_id":"419","lat":"26.4489","long":"-81.9394","pm25":""},{"location_name":"Bayonne","location_id":"422","lat":"40.67025","long":"-74.12608","pm25":""},{"location_name":"Bayou Plaquemine","location_id":"423","lat":"30.2211","long":"-91.3153","pm25":""},{"location_name":"Bean","location_id":"430","lat":"39.4452","long":"-79.0691","pm25":""},{"location_name":"Beaufort","location_id":"431","lat":"34.8848","long":"-76.6203","pm25":""},{"location_name":"Beaumont C2\/C112","location_id":"432","lat":"30.0394","long":"-94.0747","pm25":""},{"location_name":"Beaver Falls","location_id":"433","lat":"40.7478","long":"-80.3167","pm25":""},{"location_name":"Beaverlodge","location_id":"434","lat":"55.1964","long":"-119.3967","pm25":""},{"location_name":"Beaverton - Highland","location_id":"435","lat":"45.4702","long":"-122.8159","pm25":""},{"location_name":"Beijing","location_id":"437","lat":"39.953354","long":"116.466255","pm25":""},{"location_name":"Beijing US Embassy","location_id":"438","lat":"39.95","long":"116.47","pm25":""},{"location_name":"Bekkestua","location_id":"439","lat":"59.9181","long":"10.5839","pm25":""},{"location_name":"Belfast Centre","location_id":"440","lat":"54.59965","long":"-5.928833","pm25":""},{"location_name":"Belfast Stockman's Lane","location_id":"441","lat":"54.572586","long":"-5.974944","pm25":""},{"location_name":"Belle Glade","location_id":"443","lat":"26.724167","long":"-80.663055","pm25":""},{"location_name":"Belleville","location_id":"444","lat":"44.1503","long":"-77.3956","pm25":""},{"location_name":"Bellevue-SE 12th","location_id":"446","lat":"47.600864","long":"-122.1484","pm25":""},{"location_name":"Bellingham Pacifc","location_id":"447","lat":"48.760036","long":"-122.45647","pm25":""},{"location_name":"Belsk-IGFPAN","location_id":"450","lat":"51.83512","long":"20.791555","pm25":""},{"location_name":"Beltsville","location_id":"451","lat":"39.0284","long":"-76.8172","pm25":""},{"location_name":"Bend - Pump Station","location_id":"454","lat":"44.063915","long":"-121.31255","pm25":""},{"location_name":"Bennington","location_id":"455","lat":"42.8875","long":"-73.2497","pm25":""},{"location_name":"Bercut Dr","location_id":"456","lat":"38.593327","long":"-121.50373","pm25":""},{"location_name":"Beresfield","location_id":"458","lat":"-32.798332","long":"151.66","pm25":""},{"location_name":"Bernalillo","location_id":"459","lat":"35.2994","long":"-106.5483","pm25":""},{"location_name":"Bethel","location_id":"461","lat":"60.79583","long":"-161.767","pm25":""},{"location_name":"Bethel Island","location_id":"462","lat":"38.00631","long":"-121.641914","pm25":""},{"location_name":"Beverwijk West-Creutzberglaan","location_id":"464","lat":"52.4893","long":"4.64053","pm25":""},{"location_name":"Bia\u0142aP-Orzechowa","location_id":"468","lat":"52.029194","long":"23.14939","pm25":""},{"location_name":"Bia\u0142ystok-Miejska","location_id":"469","lat":"53.12669","long":"23.155869","pm25":""},{"location_name":"Bia\u0142ystok-Warszawska","location_id":"470","lat":"53.129307","long":"23.181744","pm25":""},{"location_name":"Biddinghuizen-Kuilweg","location_id":"472","lat":"52.4232","long":"5.59338","pm25":""},{"location_name":"Bielsko-Bia\u0142a, ul. Kossak-Szczuckiej 19","location_id":"475","lat":"49.813465","long":"19.027317","pm25":""},{"location_name":"Bielsko-Bia\u0142a, ul.Partyzant\u00f3w","location_id":"476","lat":"49.802074","long":"19.04861","pm25":""},{"location_name":"Biest Houtakker-Biestsestraat","location_id":"477","lat":"51.5184","long":"5.14845","pm25":""},{"location_name":"Big Bend  NP","location_id":"478","lat":"29.3025","long":"-103.1781","pm25":""},{"location_name":"Big Piney","location_id":"480","lat":"42.486668","long":"-110.09917","pm25":""},{"location_name":"Bill Stanley","location_id":"483","lat":"36.3619","long":"-118.0108","pm25":""},{"location_name":"Billingham","location_id":"484","lat":"54.60537","long":"-1.275039","pm25":""},{"location_name":"Billings Coburn Rd","location_id":"485","lat":"45.78658","long":"-108.45878","pm25":""},{"location_name":"Billlings Lockwood","location_id":"487","lat":"45.80636","long":"-108.42655","pm25":""},{"location_name":"Birkenesobservatoriet","location_id":"488","lat":"58.38846","long":"8.2519","pm25":""},{"location_name":"Birkenhead Borough Road","location_id":"489","lat":"53.38851","long":"-3.025014","pm25":""},{"location_name":"Birmingham A4540 Roadside","location_id":"491","lat":"52.47609","long":"-1.875024","pm25":""},{"location_name":"Birmingham Acocks Green","location_id":"492","lat":"52.437164","long":"-1.829999","pm25":""},{"location_name":"Birney","location_id":"495","lat":"45.36615","long":"-106.48982","pm25":""},{"location_name":"Bishkek","location_id":"496","lat":"42.827625","long":"74.58384","pm25":""},{"location_name":"Bklyn - PS 314","location_id":"499","lat":"40.64182","long":"-74.01871","pm25":""},{"location_name":"Bklyn - PS274","location_id":"500","lat":"40.6944","long":"-73.9286","pm25":""},{"location_name":"Black Hawk","location_id":"501","lat":"44.155636","long":"-103.315765","pm25":""},{"location_name":"Blackburn Accrington Road","location_id":"502","lat":"53.74775","long":"-2.452724","pm25":""},{"location_name":"Blackpool Marton","location_id":"503","lat":"53.80489","long":"-3.007175","pm25":""},{"location_name":"Blackwater","location_id":"505","lat":"-23.5627","long":"148.881","pm25":""},{"location_name":"Blackwater NWR","location_id":"506","lat":"38.445","long":"-76.1114","pm25":""},{"location_name":"Blaine","location_id":"507","lat":"45.1425","long":"-93.2139","pm25":""},{"location_name":"Blind Services; 1185","location_id":"508","lat":"29.2069","long":"-81.0531","pm25":""},{"location_name":"Bloomfield","location_id":"509","lat":"36.7422","long":"-107.9769","pm25":""},{"location_name":"Blue Point Sheriff S","location_id":"512","lat":"33.5455","long":"-111.6093","pm25":""},{"location_name":"Blue Ridge I-70","location_id":"513","lat":"39.047913","long":"-94.450516","pm25":""},{"location_name":"Blythe","location_id":"514","lat":"33.61235","long":"-114.60209","pm25":""},{"location_name":"Boat Creek","location_id":"515","lat":"-23.8199","long":"151.154","pm25":""},{"location_name":"Bocatoma","location_id":"516","lat":"-36.803036","long":"-73.12053","pm25":""},{"location_name":"Boise Eastman","location_id":"518","lat":"43.61638","long":"-116.20382","pm25":""},{"location_name":"Boise Fire Station","location_id":"519","lat":"43.61889","long":"-116.21361","pm25":""},{"location_name":"Bondville","location_id":"520","lat":"40.0519","long":"-88.3724","pm25":""},{"location_name":"Bonifay","location_id":"521","lat":"30.8475","long":"-85.6044","pm25":""},{"location_name":"Bonner Lake","location_id":"522","lat":"49.3864","long":"-82.1214","pm25":""},{"location_name":"Boonville","location_id":"523","lat":"38.0519","long":"-87.2783","pm25":""},{"location_name":"Borowiec-Drapalka","location_id":"526","lat":"52.276794","long":"17.074114","pm25":""},{"location_name":"Borsukowizna-Wiejska","location_id":"527","lat":"53.215492","long":"23.642153","pm25":""},{"location_name":"Bory Tucholskie","location_id":"528","lat":"53.662117","long":"17.934017","pm25":""},{"location_name":"Boston - Roxbury","location_id":"530","lat":"42.3294","long":"-71.0825","pm25":""},{"location_name":"Boston-Von Hillern","location_id":"531","lat":"42.325195","long":"-71.05605","pm25":""},{"location_name":"Boulder","location_id":"534","lat":"42.7186","long":"-109.7531","pm25":""},{"location_name":"Boulder - CU - 2102","location_id":"535","lat":"40.0128","long":"-105.2667","pm25":""},{"location_name":"Boulder City","location_id":"536","lat":"35.97815","long":"-114.84631","pm25":""},{"location_name":"Boulder Creek","location_id":"537","lat":"37.125862","long":"-122.12212","pm25":""},{"location_name":"Boulder Reservoir","location_id":"538","lat":"40.070007","long":"-105.22023","pm25":""},{"location_name":"Bourassa","location_id":"541","lat":"45.5231","long":"-73.4939","pm25":""},{"location_name":"Bournemouth","location_id":"542","lat":"50.73957","long":"-1.826744","pm25":""},{"location_name":"Boyne Island","location_id":"545","lat":"-23.9408","long":"151.351","pm25":""},{"location_name":"Bozeman High School","location_id":"546","lat":"45.683765","long":"-111.05628","pm25":""},{"location_name":"Bradford Mayo Avenue","location_id":"549","lat":"53.771244","long":"-1.759774","pm25":""},{"location_name":"Brainerd","location_id":"551","lat":"46.3944","long":"-94.1433","pm25":""},{"location_name":"Branch Street","location_id":"552","lat":"38.65643","long":"-90.18977","pm25":""},{"location_name":"Brantford","location_id":"555","lat":"43.1403","long":"-80.2961","pm25":""},{"location_name":"Brawley - 220 Main S","location_id":"558","lat":"32.9783","long":"-115.5383","pm25":""},{"location_name":"Breda-Bastenakenstraat","location_id":"560","lat":"51.6031","long":"4.78102","pm25":""},{"location_name":"Breda-Tilburgseweg","location_id":"561","lat":"51.5935","long":"4.82494","pm25":""},{"location_name":"Bremerton-Spruce Ave","location_id":"563","lat":"47.592674","long":"-122.627396","pm25":""},{"location_name":"Breukelen-Snelweg","location_id":"564","lat":"52.2015","long":"4.98744","pm25":""},{"location_name":"Bridgeport","location_id":"567","lat":"41.1714","long":"-73.1953","pm25":""},{"location_name":"Brigantine","location_id":"569","lat":"39.46487","long":"-74.44874","pm25":""},{"location_name":"Brighton Preston Park","location_id":"571","lat":"50.840836","long":"-0.147572","pm25":""},{"location_name":"Brighton Township","location_id":"572","lat":"40.6847","long":"-80.3597","pm25":""},{"location_name":"Bringelly","location_id":"573","lat":"-33.919445","long":"150.76111","pm25":""},{"location_name":"Brisbane CBD","location_id":"574","lat":"-27.4774","long":"153.028","pm25":""},{"location_name":"Bristol","location_id":"576","lat":"40.1072","long":"-74.8822","pm25":""},{"location_name":"Bristol St Paul's","location_id":"577","lat":"51.462837","long":"-2.584482","pm25":""},{"location_name":"Broadus","location_id":"579","lat":"45.440296","long":"-105.37028","pm25":""},{"location_name":"Brockton","location_id":"580","lat":"42.06512","long":"-71.01269","pm25":""},{"location_name":"Bronx - IS52","location_id":"581","lat":"40.8161","long":"-73.9022","pm25":""},{"location_name":"Bronx - IS74","location_id":"582","lat":"40.8147","long":"-73.8867","pm25":""},{"location_name":"Brossard","location_id":"583","lat":"45.4431","long":"-73.4686","pm25":""},{"location_name":"Brownstown","location_id":"585","lat":"38.920834","long":"-86.08052","pm25":""},{"location_name":"Bruderheim","location_id":"588","lat":"53.800117","long":"-112.927795","pm25":""},{"location_name":"Bryn skole","location_id":"590","lat":"59.914104","long":"10.82263","pm25":""},{"location_name":"Buckeye","location_id":"592","lat":"33.37","long":"-112.6207","pm25":""},{"location_name":"Bufalotta","location_id":"593","lat":"41.947647","long":"12.533682","pm25":""},{"location_name":"Buffalo","location_id":"594","lat":"42.8781","long":"-78.8094","pm25":""},{"location_name":"Buffalo Near-road","location_id":"595","lat":"42.92111","long":"-78.76611","pm25":""},{"location_name":"Buick NE","location_id":"596","lat":"37.65214","long":"-91.11653","pm25":""},{"location_name":"Bukinje","location_id":"598","lat":"44.523613","long":"18.600277","pm25":""},{"location_name":"Bullhead City","location_id":"599","lat":"35.16611","long":"-114.56611","pm25":""},{"location_name":"Burbank-Maple Street","location_id":"602","lat":"46.2001","long":"-119.0084","pm25":""},{"location_name":"Burdens Creek","location_id":"603","lat":"35.8894","long":"-78.8747","pm25":""},{"location_name":"Burlington","location_id":"604","lat":"44.4761","long":"-73.2103","pm25":""},{"location_name":"Burnaby South","location_id":"605","lat":"49.21528","long":"-122.98556","pm25":""},{"location_name":"Burns - Washington S","location_id":"607","lat":"43.58925","long":"-119.0483","pm25":""},{"location_name":"Bury Whitefield Roadside","location_id":"608","lat":"53.55903","long":"-2.293772","pm25":""},{"location_name":"Bush Estate","location_id":"609","lat":"55.86228","long":"-3.205782","pm25":""},{"location_name":"Butte (Harrison Cour","location_id":"611","lat":"61.534164","long":"-149.03166","pm25":""},{"location_name":"Butte Greely School","location_id":"612","lat":"46.0024","long":"-112.50089","pm25":""},{"location_name":"Bydgoszcz Plac Pozna\u0144ski","location_id":"613","lat":"53.121765","long":"17.987906","pm25":""},{"location_name":"Bydgoszcz Warszawska","location_id":"614","lat":"53.134083","long":"17.995708","pm25":""},{"location_name":"Bygd\u00f8y Alle","location_id":"615","lat":"59.91898","long":"10.69707","pm25":""},{"location_name":"B\u00e9cancour (Ar\u00e9na)","location_id":"616","lat":"46.35","long":"-72.4333","pm25":""},{"location_name":"C GRANDE","location_id":"618","lat":"32.9544","long":"-111.7622","pm25":""},{"location_name":"CAL-JOAR - Caldas - E U Joaqu\u00edn Aristizabal","location_id":"620","lat":"6.0930777","long":"-75.637764","pm25":""},{"location_name":"CAL-LASA - Caldas - Corporacion Universitaria Lasallista","location_id":"621","lat":"6.0990806","long":"-75.638626","pm25":""},{"location_name":"CAORLE","location_id":"623","lat":"44.4193","long":"12.2254","pm25":""},{"location_name":"CARPENTER","location_id":"625","lat":"41.6031","long":"-93.6433","pm25":""},{"location_name":"CARTHAGE","location_id":"626","lat":"37.19822","long":"-94.31702","pm25":""},{"location_name":"CARY","location_id":"627","lat":"42.2211","long":"-88.2411","pm25":""},{"location_name":"CASTELLARANO","location_id":"629","lat":"44.5162","long":"10.7339","pm25":""},{"location_name":"CASTELLUCCIO","location_id":"630","lat":"44.1404","long":"10.9172","pm25":""},{"location_name":"CASTLE H","location_id":"631","lat":"34.364166","long":"-77.83861","pm25":""},{"location_name":"CASTLE ST. SAINT JO","location_id":"632","lat":"45.2803","long":"-66.0561","pm25":""},{"location_name":"CBD","location_id":"633","lat":"-28.756224","long":"32.04924","pm25":""},{"location_name":"CCNY","location_id":"634","lat":"40.8197","long":"-73.9481","pm25":""},{"location_name":"CC_Armory","location_id":"635","lat":"39.144802","long":"-119.76641","pm25":""},{"location_name":"CEN-TRAF - Estaci\u00f3n Tr\u00e1fico Centro","location_id":"637","lat":"6.252561","long":"-75.56958","pm25":""},{"location_name":"CENO","location_id":"638","lat":"45.0544","long":"9.7269","pm25":""},{"location_name":"CENTO","location_id":"640","lat":"44.733","long":"11.2997","pm25":""},{"location_name":"CH0002R","location_id":"641","lat":"46.8131","long":"6.9444804","pm25":""},{"location_name":"CH0003R","location_id":"642","lat":"47.479774","long":"8.904676","pm25":""},{"location_name":"CH0004R","location_id":"643","lat":"47.049515","long":"6.979209","pm25":""},{"location_name":"CH0005A","location_id":"644","lat":"47.402916","long":"8.613398","pm25":""},{"location_name":"CH0005R","location_id":"645","lat":"47.067387","long":"8.463334","pm25":""},{"location_name":"CH0008A","location_id":"646","lat":"47.541084","long":"7.5832696","pm25":""},{"location_name":"CH0010A","location_id":"647","lat":"47.377617","long":"8.530411","pm25":""},{"location_name":"CH0011A","location_id":"648","lat":"46.011112","long":"8.957173","pm25":""},{"location_name":"CH0013A","location_id":"649","lat":"47.386803","long":"8.539807","pm25":""},{"location_name":"CH0017A","location_id":"651","lat":"47.565914","long":"7.5820775","pm25":""},{"location_name":"CH0019A","location_id":"652","lat":"47.40699","long":"9.394312","pm25":""},{"location_name":"CH0021A","location_id":"653","lat":"47.370945","long":"8.523541","pm25":""},{"location_name":"CH0022A","location_id":"654","lat":"47.06769","long":"8.300675","pm25":""},{"location_name":"CH0024A","location_id":"655","lat":"46.13899","long":"7.148333","pm25":""},{"location_name":"CH0028A","location_id":"656","lat":"46.52201","long":"6.6397","pm25":""},{"location_name":"CH0029A","location_id":"657","lat":"47.567005","long":"7.594708","pm25":""},{"location_name":"CH0031A","location_id":"658","lat":"46.951","long":"7.4408712","pm25":""},{"location_name":"CH0033A","location_id":"659","lat":"46.160397","long":"8.933943","pm25":""},{"location_name":"CH0041A","location_id":"660","lat":"46.976383","long":"7.4787173","pm25":""},{"location_name":"CH0043A","location_id":"661","lat":"46.025894","long":"8.967523","pm25":""},{"location_name":"CH0044A","location_id":"662","lat":"47.438732","long":"8.57012","pm25":""},{"location_name":"CH0046A","location_id":"663","lat":"46.195602","long":"6.2112484","pm25":""},{"location_name":"CH0050A","location_id":"664","lat":"46.231094","long":"6.0741744","pm25":""},{"location_name":"CH0051A","location_id":"665","lat":"46.16257","long":"6.0051837","pm25":""},{"location_name":"CHARLESTON","location_id":"666","lat":"38.346256","long":"-81.62116","pm25":""},{"location_name":"CHARLOTTETOWN","location_id":"667","lat":"46.2406","long":"-63.1306","pm25":""},{"location_name":"CHERRYGR","location_id":"669","lat":"36.3028","long":"-79.4667","pm25":""},{"location_name":"CHICK.","location_id":"670","lat":"30.7697","long":"-88.0875","pm25":""},{"location_name":"CHICOPEE","location_id":"671","lat":"42.1944","long":"-72.5556","pm25":""},{"location_name":"CHIWAUKEE","location_id":"672","lat":"42.5047","long":"-87.8111","pm25":""},{"location_name":"CHI_COM","location_id":"673","lat":"41.7547","long":"-87.7136","pm25":""},{"location_name":"CHI_SWFP","location_id":"675","lat":"41.7558","long":"-87.5453","pm25":""},{"location_name":"CHI_TAFT","location_id":"676","lat":"41.9844","long":"-87.7919","pm25":""},{"location_name":"CICERO","location_id":"677","lat":"41.8553","long":"-87.7525","pm25":""},{"location_name":"CITTADELLA","location_id":"678","lat":"44.7924","long":"10.331","pm25":""},{"location_name":"CLEVELAND","location_id":"679","lat":"33.75083","long":"-90.73417","pm25":""},{"location_name":"COMBS","location_id":"685","lat":"33.2192","long":"-111.5608","pm25":""},{"location_name":"COP-CVID - Copacabana - Ciudadela Educativa La Vida","location_id":"686","lat":"6.34536","long":"-75.50475","pm25":""},{"location_name":"CORNER","location_id":"689","lat":"33.8017","long":"-86.9425","pm25":""},{"location_name":"CORTE BRUGNATELLA","location_id":"690","lat":"44.7347","long":"9.3669","pm25":""},{"location_name":"CTCLUSI Radar Hill-O","location_id":"693","lat":"43.381943","long":"-124.263885","pm25":""},{"location_name":"CZ0ABRE","location_id":"695","lat":"50.084385","long":"14.380116","pm25":""},{"location_name":"CZ0AKAL","location_id":"696","lat":"50.09424","long":"14.442049","pm25":""},{"location_name":"CZ0AKOB","location_id":"697","lat":"50.12219","long":"14.467578","pm25":""},{"location_name":"CZ0ALEG","location_id":"698","lat":"50.072388","long":"14.430673","pm25":""},{"location_name":"CZ0ALIB","location_id":"699","lat":"50.007305","long":"14.445933","pm25":""},{"location_name":"CZ0APRU","location_id":"700","lat":"50.062298","long":"14.53782","pm25":""},{"location_name":"CZ0AREP","location_id":"701","lat":"50.088066","long":"14.42922","pm25":""},{"location_name":"CZ0ARIE","location_id":"702","lat":"50.081482","long":"14.442692","pm25":""},{"location_name":"CZ0ASTO","location_id":"704","lat":"50.04613","long":"14.331413","pm25":""},{"location_name":"CZ0ASUC","location_id":"705","lat":"50.12653","long":"14.384639","pm25":""},{"location_name":"CZ0AVRS","location_id":"706","lat":"50.06643","long":"14.446152","pm25":""},{"location_name":"CZ0AVYN","location_id":"707","lat":"50.11108","long":"14.503096","pm25":""},{"location_name":"CZ0BBDN","location_id":"708","lat":"49.202724","long":"16.616287","pm25":""},{"location_name":"CZ0BBNI","location_id":"709","lat":"49.21321","long":"16.678024","pm25":""},{"location_name":"CZ0BBNV","location_id":"710","lat":"49.19809","long":"16.593643","pm25":""},{"location_name":"CZ0BBNY","location_id":"711","lat":"49.14897","long":"16.696217","pm25":""},{"location_name":"CZ0BKUC","location_id":"712","lat":"48.881355","long":"16.085817","pm25":""},{"location_name":"CZ0BMIS","location_id":"713","lat":"48.791767","long":"16.724497","pm25":""},{"location_name":"CZ0BZNO","location_id":"714","lat":"48.842957","long":"16.060127","pm25":""},{"location_name":"CZ0CCBD","location_id":"715","lat":"48.984386","long":"14.465684","pm25":""},{"location_name":"CZ0CCHU","location_id":"716","lat":"49.068436","long":"13.614801","pm25":""},{"location_name":"CZ0CHVO","location_id":"717","lat":"48.724197","long":"14.723382","pm25":""},{"location_name":"CZ0CKOC","location_id":"718","lat":"49.467243","long":"13.838234","pm25":""},{"location_name":"CZ0CPRA","location_id":"719","lat":"49.016087","long":"14.000444","pm25":""},{"location_name":"CZ0CTAB","location_id":"720","lat":"49.411232","long":"14.676389","pm25":""},{"location_name":"CZ0EMTP","location_id":"721","lat":"49.758995","long":"16.666721","pm25":""},{"location_name":"CZ0EPAO","location_id":"722","lat":"50.0422","long":"15.739414","pm25":""},{"location_name":"CZ0EPAU","location_id":"723","lat":"50.024036","long":"15.763549","pm25":""},{"location_name":"CZ0ESVR","location_id":"724","lat":"49.735085","long":"16.034197","pm25":""},{"location_name":"CZ0HHKB","location_id":"725","lat":"50.195362","long":"15.846376","pm25":""},{"location_name":"CZ0HHKO","location_id":"726","lat":"50.17763","long":"15.83839","pm25":""},{"location_name":"CZ0HPLO","location_id":"728","lat":"50.350277","long":"16.3225","pm25":""},{"location_name":"CZ0HTRT","location_id":"729","lat":"50.56588","long":"15.903927","pm25":""},{"location_name":"CZ0JJIH","location_id":"730","lat":"49.401596","long":"15.610246","pm25":""},{"location_name":"CZ0JKMY","location_id":"731","lat":"49.159153","long":"15.439048","pm25":""},{"location_name":"CZ0JKOS","location_id":"732","lat":"49.573395","long":"15.080278","pm25":""},{"location_name":"CZ0JTRE","location_id":"733","lat":"49.22344","long":"15.865778","pm25":""},{"location_name":"CZ0KCHM","location_id":"734","lat":"50.06586","long":"12.363442","pm25":""},{"location_name":"CZ0KPRB","location_id":"735","lat":"50.37248","long":"12.61538","pm25":""},{"location_name":"CZ0KSOM","location_id":"736","lat":"50.172825","long":"12.672818","pm25":""},{"location_name":"CZ0LCLM","location_id":"737","lat":"50.698044","long":"14.537345","pm25":""},{"location_name":"CZ0LFRT","location_id":"738","lat":"50.94065","long":"15.069817","pm25":""},{"location_name":"CZ0LLIL","location_id":"739","lat":"50.7551","long":"15.069967","pm25":""},{"location_name":"CZ0LSOU","location_id":"740","lat":"50.789646","long":"15.319683","pm25":""},{"location_name":"CZ0MJES","location_id":"741","lat":"50.24224","long":"17.19018","pm25":""},{"location_name":"CZ0MOLJ","location_id":"742","lat":"49.601463","long":"17.238073","pm25":""},{"location_name":"CZ0MPRR","location_id":"743","lat":"49.451656","long":"17.454159","pm25":""},{"location_name":"CZ0MPST","location_id":"744","lat":"49.467857","long":"17.114725","pm25":""},{"location_name":"CZ0PKUJ","location_id":"745","lat":"49.722","long":"13.618538","pm25":""},{"location_name":"CZ0PPLA","location_id":"746","lat":"49.73245","long":"13.402281","pm25":""},{"location_name":"CZ0PPLE","location_id":"747","lat":"49.74733","long":"13.381039","pm25":""},{"location_name":"CZ0PPLL","location_id":"748","lat":"49.770126","long":"13.368221","pm25":""},{"location_name":"CZ0PPLV","location_id":"749","lat":"49.768616","long":"13.423381","pm25":""},{"location_name":"CZ0PPRM","location_id":"750","lat":"49.669582","long":"12.677884","pm25":""},{"location_name":"CZ0SBER","location_id":"751","lat":"49.957928","long":"14.0583","pm25":""},{"location_name":"CZ0SKLM","location_id":"752","lat":"50.14386","long":"14.101784","pm25":""},{"location_name":"CZ0SKLS","location_id":"753","lat":"50.16741","long":"14.106048","pm25":""},{"location_name":"CZ0SMBO","location_id":"754","lat":"50.428646","long":"14.913859","pm25":""},{"location_name":"CZ0SONR","location_id":"755","lat":"49.913513","long":"14.782625","pm25":""},{"location_name":"CZ0SROR","location_id":"756","lat":"50.301983","long":"15.178303","pm25":""},{"location_name":"CZ0TBKR","location_id":"757","lat":"49.50261","long":"18.53856","pm25":""},{"location_name":"CZ0TCER","location_id":"758","lat":"49.77714","long":"17.541946","pm25":""},{"location_name":"CZ0TCTN","location_id":"759","lat":"49.74896","long":"18.609726","pm25":""},{"location_name":"CZ0TFMI","location_id":"760","lat":"49.67179","long":"18.35107","pm25":""},{"location_name":"CZ0THAR","location_id":"761","lat":"49.790977","long":"18.406836","pm25":""},{"location_name":"CZ0TKAR","location_id":"762","lat":"49.863796","long":"18.551453","pm25":""},{"location_name":"CZ0TOCB","location_id":"763","lat":"49.839848","long":"18.289976","pm25":""},{"location_name":"CZ0TOFF","location_id":"764","lat":"49.839188","long":"18.263689","pm25":""},{"location_name":"CZ0TOPO","location_id":"765","lat":"49.825294","long":"18.159275","pm25":""},{"location_name":"CZ0TOPR","location_id":"766","lat":"49.856262","long":"18.269756","pm25":""},{"location_name":"CZ0TOVK","location_id":"767","lat":"49.94499","long":"17.90953","pm25":""},{"location_name":"CZ0TOZR","location_id":"768","lat":"49.79604","long":"18.24718","pm25":""},{"location_name":"CZ0TSTD","location_id":"769","lat":"49.720936","long":"18.089306","pm25":""},{"location_name":"CZ0TTRK","location_id":"770","lat":"49.67238","long":"18.643038","pm25":""},{"location_name":"CZ0TTRO","location_id":"771","lat":"49.668114","long":"18.6778","pm25":""},{"location_name":"CZ0TVER","location_id":"772","lat":"49.92468","long":"18.422873","pm25":""},{"location_name":"CZ0UCHM","location_id":"773","lat":"50.46753","long":"13.412696","pm25":""},{"location_name":"CZ0UDCM","location_id":"774","lat":"50.77415","long":"14.218794","pm25":""},{"location_name":"CZ0UDOK","location_id":"775","lat":"50.458855","long":"14.170162","pm25":""},{"location_name":"CZ0UKRU","location_id":"776","lat":"50.69667","long":"13.847692","pm25":""},{"location_name":"CZ0ULOM","location_id":"777","lat":"50.585766","long":"13.673418","pm25":""},{"location_name":"CZ0ULTT","location_id":"778","lat":"50.540897","long":"14.119409","pm25":""},{"location_name":"CZ0UMED","location_id":"779","lat":"50.42759","long":"13.130143","pm25":""},{"location_name":"CZ0UMOM","location_id":"780","lat":"50.510365","long":"13.645272","pm25":""},{"location_name":"CZ0URVH","location_id":"781","lat":"50.579834","long":"13.419506","pm25":""},{"location_name":"CZ0USNZ","location_id":"782","lat":"50.789444","long":"14.086799","pm25":""},{"location_name":"CZ0UTPM","location_id":"783","lat":"50.64528","long":"13.85125","pm25":""},{"location_name":"CZ0UTUS","location_id":"784","lat":"50.376587","long":"13.327622","pm25":""},{"location_name":"CZ0UULD","location_id":"785","lat":"50.683125","long":"13.997873","pm25":""},{"location_name":"CZ0UULK","location_id":"786","lat":"50.683525","long":"14.041195","pm25":""},{"location_name":"CZ0UULM","location_id":"787","lat":"50.661095","long":"14.043063","pm25":""},{"location_name":"CZ0ZSNV","location_id":"788","lat":"49.047817","long":"18.007828","pm25":""},{"location_name":"CZ0ZTNV","location_id":"789","lat":"49.25939","long":"17.41056","pm25":""},{"location_name":"CZ0ZUHR","location_id":"790","lat":"49.06795","long":"17.466848","pm25":""},{"location_name":"CZ0ZVMZ","location_id":"791","lat":"49.472057","long":"17.966976","pm25":""},{"location_name":"CZ0ZZLN","location_id":"792","lat":"49.232906","long":"17.667175","pm25":""},{"location_name":"Cabauw-Wielsekade","location_id":"793","lat":"51.9745","long":"4.9233","pm25":""},{"location_name":"Caddo Valley","location_id":"794","lat":"34.1795","long":"-93.0988","pm25":""},{"location_name":"Calaveras Lake C59","location_id":"797","lat":"29.2753","long":"-98.3117","pm25":""},{"location_name":"Calexico - Ethel Str","location_id":"798","lat":"32.67618","long":"-115.48307","pm25":""},{"location_name":"Calgary Central2","location_id":"799","lat":"51.04761","long":"-114.075165","pm25":""},{"location_name":"Calgary Northwest","location_id":"800","lat":"51.0814","long":"-114.1403","pm25":""},{"location_name":"Cambridge Roadside","location_id":"803","lat":"52.20237","long":"0.124456","pm25":""},{"location_name":"Camden","location_id":"804","lat":"-34.041668","long":"150.69028","pm25":""},{"location_name":"Camden Kerbside","location_id":"805","lat":"51.54421","long":"-0.175269","pm25":""},{"location_name":"Camden Spruce St","location_id":"806","lat":"39.934444","long":"-75.12529","pm25":""},{"location_name":"Camp Bullis C58","location_id":"807","lat":"29.6322","long":"-98.565","pm25":""},{"location_name":"Camp Pendleton","location_id":"808","lat":"33.217026","long":"-117.39616","pm25":""},{"location_name":"Campbelltown West","location_id":"813","lat":"-34.066666","long":"150.79527","pm25":""},{"location_name":"Campo dell'Oro","location_id":"818","lat":"42.081825","long":"11.809336","pm25":""},{"location_name":"Candor","location_id":"820","lat":"35.26","long":"-79.84","pm25":""},{"location_name":"Candor FRO","location_id":"821","lat":"35.263165","long":"-79.83664","pm25":""},{"location_name":"Cannock A5190 Roadside","location_id":"823","lat":"52.687298","long":"-1.980821","pm25":""},{"location_name":"Cannon Hill","location_id":"824","lat":"-27.4654","long":"153.087","pm25":""},{"location_name":"Cannons Lane","location_id":"825","lat":"38.2286","long":"-85.6544","pm25":""},{"location_name":"Canterbury","location_id":"826","lat":"51.27399","long":"1.098061","pm25":""},{"location_name":"Canton","location_id":"827","lat":"40.800716","long":"-81.373","pm25":""},{"location_name":"Canton DRR","location_id":"829","lat":"35.534","long":"-82.853","pm25":""},{"location_name":"Canyonlands NP","location_id":"830","lat":"38.4583","long":"-109.8211","pm25":""},{"location_name":"Cape Coral Fire Stat","location_id":"831","lat":"26.5475","long":"-81.9797","pm25":""},{"location_name":"Cape Elizabeth","location_id":"832","lat":"43.561043","long":"-70.20732","pm25":""},{"location_name":"Cape Romain","location_id":"833","lat":"32.941","long":"-79.657","pm25":""},{"location_name":"Capitol","location_id":"834","lat":"30.4622","long":"-91.1769","pm25":""},{"location_name":"Cardiff Centre","location_id":"836","lat":"51.48178","long":"-3.17625","pm25":""},{"location_name":"Carlisle","location_id":"837","lat":"40.2464","long":"-77.1867","pm25":""},{"location_name":"Carlisle Roadside","location_id":"838","lat":"54.894833","long":"-2.945307","pm25":""},{"location_name":"Carlsbad","location_id":"839","lat":"32.38","long":"-104.2622","pm25":""},{"location_name":"Carlyss","location_id":"840","lat":"30.1433","long":"-93.3719","pm25":""},{"location_name":"Caroline","location_id":"843","lat":"51.95","long":"-114.7","pm25":""},{"location_name":"Carpinteria","location_id":"844","lat":"34.4028","long":"-119.4575","pm25":""},{"location_name":"Carrithers Middle Sc","location_id":"846","lat":"38.1825","long":"-85.5744","pm25":""},{"location_name":"Carrizo","location_id":"847","lat":"35.35474","long":"-120.04013","pm25":""},{"location_name":"Carrot Creek","location_id":"848","lat":"53.6072","long":"-115.8769","pm25":""},{"location_name":"Carville","location_id":"850","lat":"30.1975","long":"-91.1283","pm25":""},{"location_name":"Casa Grande Downtown","location_id":"851","lat":"32.877583","long":"-111.85222","pm25":""},{"location_name":"CasaBlanca","location_id":"852","lat":"33.11753","long":"-111.88491","pm25":""},{"location_name":"Caserne 17","location_id":"853","lat":"45.593327","long":"-73.63733","pm25":""},{"location_name":"Casino Center","location_id":"854","lat":"36.174366","long":"-115.13977","pm25":""},{"location_name":"Casper Gaseous","location_id":"855","lat":"42.82231","long":"-106.36501","pm25":""},{"location_name":"Cassino","location_id":"857","lat":"41.49","long":"13.83069","pm25":""},{"location_name":"Castel di Guido","location_id":"858","lat":"41.88944","long":"12.2663","pm25":""},{"location_name":"Castlegar Zinio Park","location_id":"859","lat":"49.3175","long":"-117.6617","pm25":""},{"location_name":"Catawba Indian Natio","location_id":"861","lat":"34.91263","long":"-80.87428","pm25":""},{"location_name":"Cata\u00f1o 40","location_id":"862","lat":"18.428389","long":"-66.141655","pm25":""},{"location_name":"Catemu","location_id":"863","lat":"-32.77921","long":"-70.959114","pm25":""},{"location_name":"Causeway Bay","location_id":"865","lat":"22.28","long":"114.185","pm25":""},{"location_name":"Cavaliere","location_id":"866","lat":"41.929382","long":"12.658363","pm25":""},{"location_name":"Cave Creek","location_id":"867","lat":"33.8217","long":"-112.0174","pm25":""},{"location_name":"Cave Junction Forest","location_id":"868","lat":"42.1617","long":"-123.64835","pm25":""},{"location_name":"Cayce City Hall","location_id":"869","lat":"33.969147","long":"-81.06629","pm25":""},{"location_name":"Ceccano","location_id":"872","lat":"41.57","long":"13.33719","pm25":""},{"location_name":"Cedar Bay","location_id":"873","lat":"30.43111","long":"-81.63194","pm25":""},{"location_name":"Cedar Bluff","location_id":"874","lat":"38.7703","long":"-99.7636","pm25":""},{"location_name":"Cedar Creek","location_id":"875","lat":"38.8795","long":"-80.8477","pm25":""},{"location_name":"Celje","location_id":"876","lat":"46.234474","long":"15.262438","pm25":""},{"location_name":"Centennial","location_id":"877","lat":"41.3642","long":"-106.2399","pm25":""},{"location_name":"Central","location_id":"880","lat":"22.281944","long":"114.15806","pm25":""},{"location_name":"Central Phoenix","location_id":"881","lat":"33.4579","long":"-112.046","pm25":""},{"location_name":"Central\/Western","location_id":"884","lat":"22.285","long":"114.14445","pm25":""},{"location_name":"Centro Quintero","location_id":"885","lat":"-32.787777","long":"-71.53228","pm25":""},{"location_name":"Cerrillos","location_id":"887","lat":"-33.492847","long":"-70.71944","pm25":""},{"location_name":"Cerro Merqu\u00edn","location_id":"888","lat":"-37.021183","long":"-73.14956","pm25":""},{"location_name":"Cerro Navia","location_id":"889","lat":"-33.43309","long":"-70.73215","pm25":""},{"location_name":"Chaco Culture Nation","location_id":"890","lat":"36.035","long":"-107.90417","pm25":""},{"location_name":"Chalmette Vista","location_id":"892","lat":"29.9431","long":"-89.9761","pm25":""},{"location_name":"Chamizal C41","location_id":"893","lat":"31.7656","long":"-106.455","pm25":""},{"location_name":"Chang Phueak, Mueang","location_id":"895","lat":"","long":"","pm25":""},{"location_name":"Channelview C15","location_id":"896","lat":"29.8025","long":"-95.1256","pm25":""},{"location_name":"Chanute","location_id":"898","lat":"37.67696","long":"-95.47594","pm25":""},{"location_name":"Chapais","location_id":"899","lat":"49.8222","long":"-74.9764","pm25":""},{"location_name":"Chaparral","location_id":"900","lat":"32.0411","long":"-106.4092","pm25":""},{"location_name":"Charette","location_id":"901","lat":"46.4425","long":"-72.8928","pm25":""},{"location_name":"Charleroi","location_id":"902","lat":"40.1469","long":"-79.9033","pm25":""},{"location_name":"Charlestown State Pa","location_id":"904","lat":"38.393833","long":"-85.66417","pm25":""},{"location_name":"Charlton Mackrell","location_id":"905","lat":"51.05625","long":"-2.68345","pm25":""},{"location_name":"Chatfield Park - 115","location_id":"906","lat":"39.5339","long":"-105.07","pm25":""},{"location_name":"Chatham","location_id":"907","lat":"42.4033","long":"-82.2086","pm25":""},{"location_name":"Chatham Roadside","location_id":"908","lat":"51.374264","long":"0.54797","pm25":""},{"location_name":"Cheeka Peak","location_id":"910","lat":"48.2867","long":"-124.6203","pm25":""},{"location_name":"Chehalis-Market Blvd","location_id":"911","lat":"46.66409","long":"-122.96732","pm25":""},{"location_name":"Chelan-Woodin Ave","location_id":"912","lat":"47.83861","long":"-120.02306","pm25":""},{"location_name":"Chelmsford","location_id":"913","lat":"42.6267","long":"-71.3622","pm25":""},{"location_name":"ChelmsfordNR","location_id":"914","lat":"42.612114","long":"-71.30752","pm25":""},{"location_name":"Cheney-Turnbull (SO)","location_id":"916","lat":"47.4164","long":"-117.5298","pm25":""},{"location_name":"Chengdu","location_id":"917","lat":"30.63","long":"104.07","pm25":""},{"location_name":"Chepstow A48","location_id":"919","lat":"51.638096","long":"-2.678731","pm25":""},{"location_name":"Cheshire","location_id":"920","lat":"38.949978","long":"-82.1101","pm25":""},{"location_name":"Chester","location_id":"921","lat":"40.78763","long":"-74.6763","pm25":""},{"location_name":"Chester BAM","location_id":"922","lat":"40.3019","long":"-121.235","pm25":""},{"location_name":"Chesterfield","location_id":"923","lat":"34.6153","long":"-80.1989","pm25":""},{"location_name":"Chesterfield Loundsley Green","location_id":"924","lat":"53.24413","long":"-1.454946","pm25":""},{"location_name":"Chesterfield Roadside","location_id":"925","lat":"53.231724","long":"-1.456944","pm25":""},{"location_name":"Cheyenne NCore","location_id":"927","lat":"41.18222","long":"-104.778336","pm25":""},{"location_name":"Che\u0142m ul.Po\u0142aniecka","location_id":"928","lat":"51.12219","long":"23.47287","pm25":""},{"location_name":"Chico -  East","location_id":"930","lat":"39.76168","long":"-121.84047","pm25":""},{"location_name":"Chilbolton Observatory","location_id":"932","lat":"51.149616","long":"-1.438228","pm25":""},{"location_name":"Children's Park Site","location_id":"933","lat":"32.2953","long":"-110.9822","pm25":""},{"location_name":"Chilliwack","location_id":"934","lat":"49.15611","long":"-121.94056","pm25":""},{"location_name":"Chiloquin","location_id":"935","lat":"42.541077","long":"-121.92164","pm25":""},{"location_name":"Chippewa Lake","location_id":"937","lat":"41.0604","long":"-81.9239","pm25":""},{"location_name":"Chiricahua NM","location_id":"938","lat":"32.0092","long":"-109.3892","pm25":""},{"location_name":"Choctaw","location_id":"940","lat":"35.4778","long":"-97.3022","pm25":""},{"location_name":"Chomedey","location_id":"941","lat":"45.5472","long":"-73.7472","pm25":""},{"location_name":"Chong Kham, Mueang","location_id":"942","lat":"19.3045","long":"97.97153","pm25":""},{"location_name":"Chong Nonsi, Yannawa","location_id":"943","lat":"13.708041","long":"100.54735","pm25":""},{"location_name":"Christchurch Barrack Road","location_id":"944","lat":"50.735455","long":"-1.780888","pm25":""},{"location_name":"Chula Vista","location_id":"945","lat":"32.63123","long":"-117.059074","pm25":""},{"location_name":"Chullora","location_id":"946","lat":"-33.89389","long":"151.04527","pm25":""},{"location_name":"Church","location_id":"947","lat":"36.159637","long":"-115.99626","pm25":""},{"location_name":"Ciampino","location_id":"948","lat":"41.79788","long":"12.607033","pm25":""},{"location_name":"Cicero2","location_id":"949","lat":"41.86433","long":"-87.748825","pm25":""},{"location_name":"Ciechocinek","location_id":"951","lat":"52.88842","long":"18.780909","pm25":""},{"location_name":"Cieszyn, ul. Mickiewicza 13","location_id":"952","lat":"49.738136","long":"18.639069","pm25":""},{"location_name":"Cincinnati Near Road","location_id":"953","lat":"39.146027","long":"-84.538376","pm25":""},{"location_name":"Cinecitta","location_id":"954","lat":"41.85772","long":"12.568665","pm25":""},{"location_name":"Cipreses","location_id":"955","lat":"-34.26191","long":"-70.46322","pm25":""},{"location_name":"Cipro","location_id":"956","lat":"41.906357","long":"12.447596","pm25":""},{"location_name":"Cisco Drive","location_id":"957","lat":"30.378166","long":"-81.84079","pm25":""},{"location_name":"City Park","location_id":"958","lat":"29.9933","long":"-90.1014","pm25":""},{"location_name":"Civ. Porto","location_id":"960","lat":"42.097054","long":"11.788354","pm25":""},{"location_name":"Civ. Via Morandi","location_id":"961","lat":"42.086803","long":"11.806498","pm25":""},{"location_name":"Civ. Via Roma","location_id":"962","lat":"42.094147","long":"11.795509","pm25":""},{"location_name":"Civ. Villa Albani","location_id":"963","lat":"42.09936","long":"11.798061","pm25":""},{"location_name":"Civita Castellana","location_id":"965","lat":"42.3018","long":"12.4132","pm25":""},{"location_name":"Civitavecchia","location_id":"966","lat":"42.09163","long":"11.802466","pm25":""},{"location_name":"Clarkston-13th St","location_id":"968","lat":"46.4256","long":"-117.0598","pm25":""},{"location_name":"Clarksville","location_id":"969","lat":"36.611412","long":"-87.38467","pm25":""},{"location_name":"Cleburne Airport C77","location_id":"972","lat":"32.353592","long":"-97.436745","pm25":""},{"location_name":"Clemmons Middle","location_id":"973","lat":"36.0261","long":"-80.3419","pm25":""},{"location_name":"Clermont","location_id":"975","lat":"28.525","long":"-81.7231","pm25":""},{"location_name":"Clinton","location_id":"978","lat":"-23.8701","long":"151.222","pm25":""},{"location_name":"Clinton C403","location_id":"979","lat":"29.7339","long":"-95.2575","pm25":""},{"location_name":"Clinton, Chancy Park","location_id":"981","lat":"41.8231","long":"-90.2119","pm25":""},{"location_name":"Clovis - N. Villa Av","location_id":"983","lat":"36.8192","long":"-119.7164","pm25":""},{"location_name":"Club de Empleados","location_id":"984","lat":"-37.501846","long":"-72.67641","pm25":""},{"location_name":"Coachline","location_id":"985","lat":"32.3806","long":"-111.1272","pm25":""},{"location_name":"Coastal Carolina","location_id":"986","lat":"33.8005","long":"-78.9941","pm25":""},{"location_name":"Coastguard","location_id":"987","lat":"-19.2526","long":"146.827","pm25":""},{"location_name":"Coffeeville","location_id":"989","lat":"34.0026","long":"-89.799","pm25":""},{"location_name":"Colbert-Greenbluff","location_id":"990","lat":"47.808228","long":"-117.34327","pm25":""},{"location_name":"Colerain","location_id":"992","lat":"39.21494","long":"-84.69086","pm25":""},{"location_name":"Colfax","location_id":"993","lat":"39.1003","long":"-120.9528","pm25":""},{"location_name":"Colleferro-Europa","location_id":"998","lat":"41.72501","long":"13.009575","pm25":""},{"location_name":"Colleferro-Oberdan","location_id":"999","lat":"41.73084","long":"13.00435","pm25":""},{"location_name":"Collins Park","location_id":"1001","lat":"41.663406","long":"-83.47596","pm25":""},{"location_name":"Colmo","location_id":"1002","lat":"-32.92955","long":"-71.440575","pm25":""},{"location_name":"Colombo","location_id":"1003","lat":"6.909445","long":"79.87534","pm25":""},{"location_name":"Colorado College","location_id":"1004","lat":"38.848","long":"-104.8286","pm25":""},{"location_name":"Colorado Springs - H","location_id":"1005","lat":"38.830894","long":"-104.83924","pm25":""},{"location_name":"Colorado Springs - U","location_id":"1006","lat":"38.9583","long":"-104.8167","pm25":""},{"location_name":"Columbia","location_id":"1007","lat":"40.924606","long":"-75.067825","pm25":""},{"location_name":"Columbia Falls","location_id":"1008","lat":"48.363693","long":"-114.18927","pm25":""},{"location_name":"Columbus - Fairgroun","location_id":"1009","lat":"40.002735","long":"-82.99441","pm25":""},{"location_name":"Columbus Airport","location_id":"1013","lat":"32.5214","long":"-84.9436","pm25":""},{"location_name":"Columbus NR - Smoky","location_id":"1014","lat":"40.11109","long":"-83.06538","pm25":""},{"location_name":"Colusa - Sunrise Blv","location_id":"1015","lat":"39.18919","long":"-121.99887","pm25":""},{"location_name":"Colville-E 1st St","location_id":"1016","lat":"48.54469","long":"-117.90322","pm25":""},{"location_name":"Colwood City Hall","location_id":"1017","lat":"48.4329","long":"-123.4928","pm25":""},{"location_name":"Compton","location_id":"1018","lat":"33.9014","long":"-118.205","pm25":""},{"location_name":"Concord","location_id":"1019","lat":"37.9383","long":"-122.025","pm25":""},{"location_name":"Conc\u00f3n","location_id":"1020","lat":"-32.92457","long":"-71.515396","pm25":""},{"location_name":"Congaree Bluff","location_id":"1021","lat":"33.8147","long":"-80.7811","pm25":""},{"location_name":"Conneaut","location_id":"1023","lat":"41.959694","long":"-80.57281","pm25":""},{"location_name":"Connecticut Hill","location_id":"1024","lat":"42.4006","long":"-76.6538","pm25":""},{"location_name":"Conroe Relocated C78","location_id":"1025","lat":"30.3503","long":"-95.425","pm25":""},{"location_name":"Consultorio - San Vicente","location_id":"1027","lat":"-36.723694","long":"-73.12366","pm25":""},{"location_name":"Convent","location_id":"1028","lat":"29.995","long":"-90.8172","pm25":""},{"location_name":"Converse County Long","location_id":"1029","lat":"43.1","long":"-105.5","pm25":""},{"location_name":"Copiap\u00f3","location_id":"1035","lat":"-27.360025","long":"-70.33","pm25":""},{"location_name":"Copper View","location_id":"1036","lat":"40.598057","long":"-111.894165","pm25":""},{"location_name":"Coquimbo","location_id":"1037","lat":"-29.97039","long":"-71.33604","pm25":""},{"location_name":"Coquitlam","location_id":"1038","lat":"49.28806","long":"-122.79139","pm25":""},{"location_name":"Cornwall","location_id":"1039","lat":"41.8331","long":"-73.3033","pm25":""},{"location_name":"Coronel Sur","location_id":"1040","lat":"-37.0317","long":"-73.13869","pm25":""},{"location_name":"Corpus Christi Dona","location_id":"1042","lat":"27.811813","long":"-97.4657","pm25":""},{"location_name":"Corpus Christi Tulos","location_id":"1043","lat":"27.8333","long":"-97.5558","pm25":""},{"location_name":"Corpus Christi West","location_id":"1044","lat":"27.765335","long":"-97.43425","pm25":""},{"location_name":"Corsicana C1051","location_id":"1045","lat":"32.0319","long":"-96.3992","pm25":""},{"location_name":"Cortez Ozone","location_id":"1046","lat":"37.34997","long":"-108.58737","pm25":""},{"location_name":"Corvallis - Circle B","location_id":"1048","lat":"44.5884","long":"-123.2673","pm25":""},{"location_name":"Cottage Grove City S","location_id":"1050","lat":"43.7995","long":"-123.0535","pm25":""},{"location_name":"County Sheriff Impou","location_id":"1053","lat":"29.1928","long":"-82.1733","pm25":""},{"location_name":"Courtenay Elementary","location_id":"1054","lat":"49.6825","long":"-124.9961","pm25":""},{"location_name":"Cove Mountain - GSMN","location_id":"1056","lat":"35.6967","long":"-83.6089","pm25":""},{"location_name":"Coventry Allesley","location_id":"1057","lat":"52.411564","long":"-1.560228","pm25":""},{"location_name":"Coweeta","location_id":"1058","lat":"35.0608","long":"-83.4306","pm25":""},{"location_name":"Coya Poblaci\u00f3n","location_id":"1059","lat":"-34.203526","long":"-70.529854","pm25":""},{"location_name":"Cranberry","location_id":"1062","lat":"36.1058","long":"-82.0454","pm25":""},{"location_name":"Craters of the Moon","location_id":"1064","lat":"43.4606","long":"-113.5622","pm25":""},{"location_name":"Credit Union","location_id":"1065","lat":"44.0874","long":"-103.27377","pm25":""},{"location_name":"Crestline - Lake Gre","location_id":"1066","lat":"34.243134","long":"-117.27228","pm25":""},{"location_name":"Crockett","location_id":"1067","lat":"37.9214","long":"-83.0662","pm25":""},{"location_name":"Crystal River Preser","location_id":"1070","lat":"28.958372","long":"-82.6431","pm25":""},{"location_name":"Curic\u00f3","location_id":"1076","lat":"-34.974926","long":"-71.23397","pm25":""},{"location_name":"Custer-Loomis (SO-AQ","location_id":"1077","lat":"48.9507","long":"-122.5544","pm25":""},{"location_name":"Cut Bank","location_id":"1078","lat":"48.607407","long":"-112.36384","pm25":""},{"location_name":"Cwmbran","location_id":"1079","lat":"51.6538","long":"-3.006953","pm25":""},{"location_name":"Czerwionka-Leszczyny, ul. Kopalniana","location_id":"1082","lat":"50.16385","long":"18.659977","pm25":""},{"location_name":"Cz\u0119stochowa, ul. AK\/Jana Paw\u0142a II","location_id":"1083","lat":"50.817677","long":"19.117426","pm25":""},{"location_name":"Cz\u0119stochowa, ul. Baczy\u0144skiego 2","location_id":"1084","lat":"50.836388","long":"19.130112","pm25":""},{"location_name":"DANIA_BEACH","location_id":"1085","lat":"26.0864","long":"-80.1114","pm25":""},{"location_name":"DAVIS ISLAND","location_id":"1086","lat":"27.9283","long":"-82.4547","pm25":""},{"location_name":"DCNearRoad","location_id":"1089","lat":"38.89475","long":"-76.95343","pm25":""},{"location_name":"DE AMICIS","location_id":"1090","lat":"44.3554","long":"11.7207","pm25":""},{"location_name":"DEARBORN","location_id":"1091","lat":"42.3075","long":"-83.15","pm25":""},{"location_name":"DEBB007","location_id":"1092","lat":"51.462734","long":"13.526796","pm25":""},{"location_name":"DEBB021","location_id":"1093","lat":"52.401352","long":"13.059945","pm25":""},{"location_name":"DEBB029","location_id":"1094","lat":"53.064262","long":"14.285139","pm25":""},{"location_name":"DEBB032","location_id":"1095","lat":"52.146263","long":"14.638166","pm25":""},{"location_name":"DEBB044","location_id":"1096","lat":"51.756477","long":"14.327998","pm25":""},{"location_name":"DEBB045","location_id":"1097","lat":"52.337337","long":"14.538595","pm25":""},{"location_name":"DEBB048","location_id":"1098","lat":"52.93189","long":"12.809481","pm25":""},{"location_name":"DEBB049","location_id":"1099","lat":"52.40931","long":"12.548376","pm25":""},{"location_name":"DEBB053","location_id":"1100","lat":"52.563835","long":"14.015252","pm25":""},{"location_name":"DEBB054","location_id":"1101","lat":"52.393932","long":"13.037474","pm25":""},{"location_name":"DEBB055","location_id":"1102","lat":"52.42044","long":"12.552303","pm25":""},{"location_name":"DEBB060","location_id":"1103","lat":"52.832466","long":"13.822211","pm25":""},{"location_name":"DEBB063","location_id":"1104","lat":"52.99875","long":"11.73846","pm25":""},{"location_name":"DEBB064","location_id":"1105","lat":"51.746346","long":"14.33455","pm25":""},{"location_name":"DEBB065","location_id":"1106","lat":"52.194225","long":"12.561389","pm25":""},{"location_name":"DEBB066","location_id":"1107","lat":"51.8976","long":"14.057064","pm25":""},{"location_name":"DEBB067","location_id":"1108","lat":"52.60861","long":"12.885194","pm25":""},{"location_name":"DEBB068","location_id":"1109","lat":"52.67765","long":"13.582269","pm25":""},{"location_name":"DEBB073","location_id":"1110","lat":"52.38887","long":"13.094618","pm25":""},{"location_name":"DEBB075","location_id":"1111","lat":"52.48417","long":"13.123698","pm25":""},{"location_name":"DEBB083","location_id":"1112","lat":"51.5645","long":"14.3764","pm25":""},{"location_name":"DEBB086","location_id":"1113","lat":"52.349705","long":"13.424304","pm25":""},{"location_name":"DEBB092","location_id":"1114","lat":"52.33468","long":"14.52596","pm25":""},{"location_name":"DEBE010","location_id":"1116","lat":"52.54304","long":"13.349326","pm25":""},{"location_name":"DEBE018","location_id":"1117","lat":"52.485813","long":"13.348775","pm25":""},{"location_name":"DEBE027","location_id":"1118","lat":"52.398407","long":"13.368103","pm25":""},{"location_name":"DEBE032","location_id":"1119","lat":"52.47319","long":"13.225144","pm25":""},{"location_name":"DEBE034","location_id":"1120","lat":"52.489452","long":"13.430844","pm25":""},{"location_name":"DEBE051","location_id":"1121","lat":"52.643524","long":"13.489531","pm25":""},{"location_name":"DEBE056","location_id":"1122","lat":"52.447697","long":"13.64705","pm25":""},{"location_name":"DEBE061","location_id":"1123","lat":"52.46361","long":"13.31825","pm25":""},{"location_name":"DEBE062","location_id":"1124","lat":"52.65327","long":"13.296081","pm25":""},{"location_name":"DEBE063","location_id":"1125","lat":"52.467533","long":"13.441654","pm25":""},{"location_name":"DEBE064","location_id":"1126","lat":"52.48171","long":"13.433967","pm25":""},{"location_name":"DEBE065","location_id":"1127","lat":"52.514072","long":"13.469931","pm25":""},{"location_name":"DEBE066","location_id":"1128","lat":"52.485294","long":"13.529504","pm25":""},{"location_name":"DEBE067","location_id":"1129","lat":"52.5066","long":"13.332972","pm25":""},{"location_name":"DEBE068","location_id":"1130","lat":"52.513607","long":"13.418833","pm25":""},{"location_name":"DEBE069","location_id":"1131","lat":"52.438114","long":"13.38772","pm25":""},{"location_name":"DEBW004","location_id":"1132","lat":"49.07655","long":"8.40666","pm25":""},{"location_name":"DEBW005","location_id":"1133","lat":"49.54408","long":"8.465281","pm25":""},{"location_name":"DEBW009","location_id":"1134","lat":"49.41953","long":"8.6767","pm25":""},{"location_name":"DEBW010","location_id":"1135","lat":"49.30073","long":"8.700103","pm25":""},{"location_name":"DEBW013","location_id":"1136","lat":"48.8088","long":"9.229745","pm25":""},{"location_name":"DEBW015","location_id":"1137","lat":"49.16551","long":"9.224786","pm25":""},{"location_name":"DEBW019","location_id":"1138","lat":"48.396835","long":"9.979031","pm25":""},{"location_name":"DEBW022","location_id":"1139","lat":"48.57818","long":"7.802317","pm25":""},{"location_name":"DEBW023","location_id":"1140","lat":"47.588154","long":"7.633271","pm25":""},{"location_name":"DEBW024","location_id":"1141","lat":"48.899235","long":"9.172792","pm25":""},{"location_name":"DEBW027","location_id":"1142","lat":"48.488888","long":"9.20732","pm25":""},{"location_name":"DEBW029","location_id":"1143","lat":"48.847916","long":"10.096292","pm25":""},{"location_name":"DEBW031","location_id":"1144","lat":"47.80989","long":"7.764528","pm25":""},{"location_name":"DEBW033","location_id":"1145","lat":"48.889038","long":"8.665536","pm25":""},{"location_name":"DEBW038","location_id":"1146","lat":"47.660057","long":"9.485675","pm25":""},{"location_name":"DEBW039","location_id":"1147","lat":"48.048656","long":"8.463597","pm25":""},{"location_name":"DEBW042","location_id":"1148","lat":"48.67807","long":"9.227769","pm25":""},{"location_name":"DEBW046","location_id":"1149","lat":"48.089886","long":"9.800325","pm25":""},{"location_name":"DEBW052","location_id":"1150","lat":"47.66436","long":"9.169289","pm25":""},{"location_name":"DEBW059","location_id":"1152","lat":"49.634842","long":"9.657919","pm25":""},{"location_name":"DEBW073","location_id":"1153","lat":"47.81902","long":"7.567969","pm25":""},{"location_name":"DEBW076","location_id":"1154","lat":"48.77307","long":"8.220214","pm25":""},{"location_name":"DEBW080","location_id":"1155","lat":"49.00796","long":"8.38719","pm25":""},{"location_name":"DEBW081","location_id":"1156","lat":"49.028595","long":"8.355628","pm25":""},{"location_name":"DEBW084","location_id":"1157","lat":"48.00151","long":"7.832122","pm25":""},{"location_name":"DEBW087","location_id":"1158","lat":"48.34578","long":"9.207639","pm25":""},{"location_name":"DEBW098","location_id":"1159","lat":"49.49256","long":"8.47204","pm25":""},{"location_name":"DEBW099","location_id":"1160","lat":"48.78313","long":"9.18072","pm25":""},{"location_name":"DEBW107","location_id":"1161","lat":"48.5077","long":"9.051178","pm25":""},{"location_name":"DEBW112","location_id":"1162","lat":"48.645607","long":"8.904442","pm25":""},{"location_name":"DEBW116","location_id":"1163","lat":"48.76871","long":"9.18449","pm25":""},{"location_name":"DEBW117","location_id":"1164","lat":"48.8892","long":"9.19003","pm25":""},{"location_name":"DEBW118","location_id":"1165","lat":"48.7881","long":"9.19101","pm25":""},{"location_name":"DEBW120","location_id":"1166","lat":"48.80102","long":"9.01652","pm25":""},{"location_name":"DEBW122","location_id":"1167","lat":"47.9882","long":"7.85992","pm25":""},{"location_name":"DEBW125","location_id":"1168","lat":"49.00371","long":"8.52628","pm25":""},{"location_name":"DEBW136","location_id":"1169","lat":"48.52023","long":"9.05802","pm25":""},{"location_name":"DEBW147","location_id":"1170","lat":"48.48933","long":"9.21079","pm25":""},{"location_name":"DEBW152","location_id":"1171","lat":"49.146","long":"9.22589","pm25":""},{"location_name":"DEBW156","location_id":"1172","lat":"48.22915","long":"8.39062","pm25":""},{"location_name":"DEBY001","location_id":"1173","lat":"49.30489","long":"10.572297","pm25":""},{"location_name":"DEBY002","location_id":"1174","lat":"50.058193","long":"12.18865","pm25":""},{"location_name":"DEBY004","location_id":"1175","lat":"49.869423","long":"9.171544","pm25":""},{"location_name":"DEBY005","location_id":"1176","lat":"49.991516","long":"9.117973","pm25":""},{"location_name":"DEBY006","location_id":"1177","lat":"48.36459","long":"10.895029","pm25":""},{"location_name":"DEBY007","location_id":"1178","lat":"48.376575","long":"10.88837","pm25":""},{"location_name":"DEBY009","location_id":"1179","lat":"49.89833","long":"10.887686","pm25":""},{"location_name":"DEBY012","location_id":"1180","lat":"48.177174","long":"12.829314","pm25":""},{"location_name":"DEBY013","location_id":"1181","lat":"48.182835","long":"12.781387","pm25":""},{"location_name":"DEBY014","location_id":"1182","lat":"50.26058","long":"10.959312","pm25":""},{"location_name":"DEBY020","location_id":"1183","lat":"50.32061","long":"11.897492","pm25":""},{"location_name":"DEBY021","location_id":"1184","lat":"48.769444","long":"11.428766","pm25":""},{"location_name":"DEBY026","location_id":"1185","lat":"48.76711","long":"11.63833","pm25":""},{"location_name":"DEBY028","location_id":"1186","lat":"48.90952","long":"11.879245","pm25":""},{"location_name":"DEBY030","location_id":"1187","lat":"48.90423","long":"11.948795","pm25":""},{"location_name":"DEBY031","location_id":"1188","lat":"47.72514","long":"10.306561","pm25":""},{"location_name":"DEBY032","location_id":"1189","lat":"50.103134","long":"11.442591","pm25":""},{"location_name":"DEBY033","location_id":"1190","lat":"48.539803","long":"12.157051","pm25":""},{"location_name":"DEBY035","location_id":"1191","lat":"47.557472","long":"9.688869","pm25":""},{"location_name":"DEBY037","location_id":"1192","lat":"48.137253","long":"11.564924","pm25":""},{"location_name":"DEBY039","location_id":"1193","lat":"48.154533","long":"11.554669","pm25":""},{"location_name":"DEBY047","location_id":"1194","lat":"50.323246","long":"11.721605","pm25":""},{"location_name":"DEBY049","location_id":"1195","lat":"48.85321","long":"11.777818","pm25":""},{"location_name":"DEBY052","location_id":"1196","lat":"48.39708","long":"10.008293","pm25":""},{"location_name":"DEBY053","location_id":"1197","lat":"49.44591","long":"11.088444","pm25":""},{"location_name":"DEBY056","location_id":"1198","lat":"49.47221","long":"10.984705","pm25":""},{"location_name":"DEBY058","location_id":"1199","lat":"49.46223","long":"11.0248","pm25":""},{"location_name":"DEBY062","location_id":"1200","lat":"48.9724","long":"13.128932","pm25":""},{"location_name":"DEBY063","location_id":"1201","lat":"49.015244","long":"12.101557","pm25":""},{"location_name":"DEBY067","location_id":"1202","lat":"49.321957","long":"12.128139","pm25":""},{"location_name":"DEBY068","location_id":"1203","lat":"50.048397","long":"10.232076","pm25":""},{"location_name":"DEBY072","location_id":"1204","lat":"49.438465","long":"12.548869","pm25":""},{"location_name":"DEBY075","location_id":"1205","lat":"49.67895","long":"12.159361","pm25":""},{"location_name":"DEBY077","location_id":"1206","lat":"49.804695","long":"9.95642","pm25":""},{"location_name":"DEBY079","location_id":"1207","lat":"47.723186","long":"12.858856","pm25":""},{"location_name":"DEBY088","location_id":"1208","lat":"48.021656","long":"12.538174","pm25":""},{"location_name":"DEBY089","location_id":"1209","lat":"48.173195","long":"11.648036","pm25":""},{"location_name":"DEBY093","location_id":"1210","lat":"49.487984","long":"11.786341","pm25":""},{"location_name":"DEBY099","location_id":"1211","lat":"48.32601","long":"10.903051","pm25":""},{"location_name":"DEBY109","location_id":"1212","lat":"47.968754","long":"11.220172","pm25":""},{"location_name":"DEBY110","location_id":"1213","lat":"48.370235","long":"10.896221","pm25":""},{"location_name":"DEBY111","location_id":"1214","lat":"49.943638","long":"11.570088","pm25":""},{"location_name":"DEBY113","location_id":"1215","lat":"49.605915","long":"10.963528","pm25":""},{"location_name":"DEBY115","location_id":"1216","lat":"48.149605","long":"11.536513","pm25":""},{"location_name":"DEBY118","location_id":"1217","lat":"48.573627","long":"13.422039","pm25":""},{"location_name":"DEBY119","location_id":"1218","lat":"49.790527","long":"9.947654","pm25":""},{"location_name":"DEBY120","location_id":"1219","lat":"49.44048","long":"11.036096","pm25":""},{"location_name":"DEBY121","location_id":"1220","lat":"47.64846","long":"12.188324","pm25":""},{"location_name":"DEBY122","location_id":"1221","lat":"47.518013","long":"10.404232","pm25":""},{"location_name":"DEBY124","location_id":"1222","lat":"49.44406","long":"10.325","pm25":""},{"location_name":"DEBY187","location_id":"1223","lat":"48.95218","long":"10.59772","pm25":""},{"location_name":"DEBY188","location_id":"1224","lat":"49.32273","long":"11.02792","pm25":""},{"location_name":"DEBY189","location_id":"1225","lat":"48.18169","long":"11.46445","pm25":""},{"location_name":"DEBY196","location_id":"1226","lat":"47.47706","long":"11.05722","pm25":""},{"location_name":"DECATUR","location_id":"1227","lat":"34.5286","long":"-86.9706","pm25":""},{"location_name":"DEER","location_id":"1228","lat":"35.8325","long":"-93.2192","pm25":""},{"location_name":"DEHB001","location_id":"1229","lat":"53.077152","long":"8.81578","pm25":""},{"location_name":"DEHB002","location_id":"1230","lat":"53.060043","long":"8.916966","pm25":""},{"location_name":"DEHB004","location_id":"1231","lat":"53.180946","long":"8.625456","pm25":""},{"location_name":"DEHB005","location_id":"1232","lat":"53.562454","long":"8.569405","pm25":""},{"location_name":"DEHB006","location_id":"1233","lat":"53.078663","long":"8.825173","pm25":""},{"location_name":"DEHB011","location_id":"1234","lat":"53.585262","long":"8.59876","pm25":""},{"location_name":"DEHB012","location_id":"1235","lat":"53.12456","long":"8.735047","pm25":""},{"location_name":"DEHB013","location_id":"1236","lat":"53.1177","long":"8.69506","pm25":""},{"location_name":"DEHE001","location_id":"1237","lat":"49.872303","long":"8.664619","pm25":""},{"location_name":"DEHE005","location_id":"1238","lat":"50.10175","long":"8.542517","pm25":""},{"location_name":"DEHE008","location_id":"1239","lat":"50.12533","long":"8.746343","pm25":""},{"location_name":"DEHE011","location_id":"1240","lat":"50.13577","long":"8.92157","pm25":""},{"location_name":"DEHE013","location_id":"1241","lat":"51.314247","long":"9.483397","pm25":""},{"location_name":"DEHE018","location_id":"1242","lat":"50.010326","long":"8.451527","pm25":""},{"location_name":"DEHE020","location_id":"1243","lat":"50.567184","long":"8.500619","pm25":""},{"location_name":"DEHE022","location_id":"1244","lat":"50.050343","long":"8.244949","pm25":""},{"location_name":"DEHE024","location_id":"1245","lat":"51.291756","long":"9.774588","pm25":""},{"location_name":"DEHE026","location_id":"1246","lat":"50.16443","long":"9.399441","pm25":""},{"location_name":"DEHE028","location_id":"1247","lat":"49.653465","long":"8.817251","pm25":""},{"location_name":"DEHE030","location_id":"1248","lat":"50.804256","long":"8.769324","pm25":""},{"location_name":"DEHE032","location_id":"1249","lat":"50.970024","long":"9.80026","pm25":""},{"location_name":"DEHE037","location_id":"1250","lat":"50.07719","long":"8.230316","pm25":""},{"location_name":"DEHE039","location_id":"1251","lat":"50.770382","long":"9.459402","pm25":""},{"location_name":"DEHE040","location_id":"1252","lat":"49.869457","long":"8.653745","pm25":""},{"location_name":"DEHE041","location_id":"1253","lat":"50.124588","long":"8.691911","pm25":""},{"location_name":"DEHE042","location_id":"1254","lat":"50.532967","long":"8.684397","pm25":""},{"location_name":"DEHE043","location_id":"1255","lat":"49.825165","long":"8.516798","pm25":""},{"location_name":"DEHE044","location_id":"1256","lat":"50.383217","long":"8.060998","pm25":""},{"location_name":"DEHE045","location_id":"1257","lat":"49.67251","long":"9.001981","pm25":""},{"location_name":"DEHE046","location_id":"1258","lat":"51.430897","long":"8.928171","pm25":""},{"location_name":"DEHE049","location_id":"1259","lat":"51.312077","long":"9.49112","pm25":""},{"location_name":"DEHE050","location_id":"1260","lat":"51.360756","long":"9.271233","pm25":""},{"location_name":"DEHE051","location_id":"1261","lat":"50.49771","long":"9.935862","pm25":""},{"location_name":"DEHE052","location_id":"1262","lat":"50.221943","long":"8.446079","pm25":""},{"location_name":"DEHE059","location_id":"1263","lat":"50.55003","long":"9.684854","pm25":""},{"location_name":"DEHE060","location_id":"1264","lat":"51.154842","long":"9.031754","pm25":""},{"location_name":"DEHE061","location_id":"1265","lat":"50.584106","long":"8.668579","pm25":""},{"location_name":"DEHE062","location_id":"1266","lat":"50.80702","long":"8.769396","pm25":""},{"location_name":"DEHE063","location_id":"1267","lat":"49.643238","long":"8.642","pm25":""},{"location_name":"DEHE112","location_id":"1268","lat":"50.07212","long":"8.228865","pm25":""},{"location_name":"DEHE116","location_id":"1269","lat":"50.101494","long":"8.784892","pm25":""},{"location_name":"DEHE131","location_id":"1270","lat":"50.386425","long":"8.059909","pm25":""},{"location_name":"DEHE134","location_id":"1271","lat":"50.546383","long":"9.680167","pm25":""},{"location_name":"DEHH008","location_id":"1272","lat":"53.56414","long":"9.967882","pm25":""},{"location_name":"DEHH015","location_id":"1273","lat":"53.523262","long":"10.021227","pm25":""},{"location_name":"DEHH016","location_id":"1274","lat":"53.52902","long":"10.081685","pm25":""},{"location_name":"DEHH026","location_id":"1275","lat":"53.56063","long":"9.957236","pm25":""},{"location_name":"DEHH033","location_id":"1276","lat":"53.63829","long":"9.998009","pm25":""},{"location_name":"DEHH047","location_id":"1277","lat":"53.63074","long":"10.110595","pm25":""},{"location_name":"DEHH050","location_id":"1278","lat":"53.480927","long":"9.857223","pm25":""},{"location_name":"DEHH059","location_id":"1279","lat":"53.50793","long":"9.990569","pm25":""},{"location_name":"DEHH064","location_id":"1280","lat":"53.5644","long":"9.94458","pm25":""},{"location_name":"DEHH068","location_id":"1281","lat":"53.5923","long":"10.053859","pm25":""},{"location_name":"DEHH070","location_id":"1282","lat":"53.555668","long":"9.943012","pm25":""},{"location_name":"DEHH072","location_id":"1283","lat":"53.535957","long":"9.84408","pm25":""},{"location_name":"DEHH073","location_id":"1284","lat":"53.532074","long":"9.832702","pm25":""},{"location_name":"DEHH079","location_id":"1285","lat":"53.54527","long":"9.944815","pm25":""},{"location_name":"DEHH081","location_id":"1286","lat":"53.52916","long":"9.981599","pm25":""},{"location_name":"DELTA CERVIA","location_id":"1287","lat":"44.2839","long":"12.3322","pm25":""},{"location_name":"DEMV003","location_id":"1288","lat":"53.559784","long":"13.26644","pm25":""},{"location_name":"DEMV004","location_id":"1289","lat":"53.817776","long":"12.064708","pm25":""},{"location_name":"DEMV007","location_id":"1290","lat":"54.161556","long":"12.174105","pm25":""},{"location_name":"DEMV012","location_id":"1291","lat":"53.520454","long":"14.257407","pm25":""},{"location_name":"DEMV017","location_id":"1292","lat":"53.302353","long":"11.362965","pm25":""},{"location_name":"DEMV019","location_id":"1293","lat":"53.78175","long":"12.175512","pm25":""},{"location_name":"DEMV020","location_id":"1294","lat":"54.092278","long":"12.141994","pm25":""},{"location_name":"DEMV021","location_id":"1295","lat":"54.17133","long":"12.080003","pm25":""},{"location_name":"DEMV022","location_id":"1296","lat":"54.09262","long":"12.099553","pm25":""},{"location_name":"DEMV023","location_id":"1297","lat":"53.631805","long":"11.398332","pm25":""},{"location_name":"DEMV024","location_id":"1298","lat":"53.396347","long":"12.463929","pm25":""},{"location_name":"DEMV025","location_id":"1299","lat":"54.31923","long":"13.08101","pm25":""},{"location_name":"DEMV026","location_id":"1300","lat":"54.323513","long":"13.342138","pm25":""},{"location_name":"DEMV028","location_id":"1301","lat":"53.90077","long":"11.4769","pm25":""},{"location_name":"DEMV031","location_id":"1302","lat":"54.17729","long":"12.09792","pm25":""},{"location_name":"DENI011","location_id":"1303","lat":"52.22694","long":"10.47364","pm25":""},{"location_name":"DENI016","location_id":"1304","lat":"51.90158","long":"10.48132","pm25":""},{"location_name":"DENI020","location_id":"1305","lat":"52.44081","long":"10.81638","pm25":""},{"location_name":"DENI028","location_id":"1306","lat":"51.50758","long":"10.23854","pm25":""},{"location_name":"DENI029","location_id":"1307","lat":"53.36235","long":"7.20726","pm25":""},{"location_name":"DENI031","location_id":"1308","lat":"53.59617","long":"8.09059","pm25":""},{"location_name":"DENI038","location_id":"1309","lat":"52.25534","long":"8.05286","pm25":""},{"location_name":"DENI041","location_id":"1310","lat":"52.17017","long":"9.06255","pm25":""},{"location_name":"DENI042","location_id":"1311","lat":"51.55107","long":"9.94976","pm25":""},{"location_name":"DENI043","location_id":"1312","lat":"52.49855","long":"7.31747","pm25":""},{"location_name":"DENI048","location_id":"1313","lat":"52.359478","long":"9.7155","pm25":""},{"location_name":"DENI051","location_id":"1314","lat":"51.75816","long":"10.61248","pm25":""},{"location_name":"DENI052","location_id":"1315","lat":"52.82943","long":"9.62295","pm25":""},{"location_name":"DENI053","location_id":"1316","lat":"52.99796","long":"7.94257","pm25":""},{"location_name":"DENI054","location_id":"1317","lat":"52.36292","long":"9.70612","pm25":""},{"location_name":"DENI058","location_id":"1318","lat":"53.7153","long":"7.21398","pm25":""},{"location_name":"DENI059","location_id":"1319","lat":"53.83017","long":"8.80122","pm25":""},{"location_name":"DENI060","location_id":"1320","lat":"52.95702","long":"11.16705","pm25":""},{"location_name":"DENI062","location_id":"1321","lat":"53.24696","long":"10.4565","pm25":""},{"location_name":"DENI063","location_id":"1322","lat":"53.52418","long":"9.68503","pm25":""},{"location_name":"DENI066","location_id":"1323","lat":"52.150776","long":"9.950223","pm25":""},{"location_name":"DENI067","location_id":"1324","lat":"52.2703","long":"8.04147","pm25":""},{"location_name":"DENI068","location_id":"1325","lat":"51.5302","long":"9.92833","pm25":""},{"location_name":"DENI070","location_id":"1326","lat":"52.15369","long":"10.45591","pm25":""},{"location_name":"DENI075","location_id":"1328","lat":"52.26673","long":"10.54055","pm25":""},{"location_name":"DENI077","location_id":"1329","lat":"51.70884","long":"9.55462","pm25":""},{"location_name":"DENI143","location_id":"1330","lat":"53.142838","long":"8.212084","pm25":""},{"location_name":"DENI157","location_id":"1331","lat":"52.427887","long":"10.793683","pm25":""},{"location_name":"DENW002","location_id":"1332","lat":"51.641384","long":"7.331405","pm25":""},{"location_name":"DENW006","location_id":"1333","lat":"51.592205","long":"7.569838","pm25":""},{"location_name":"DENW008","location_id":"1334","lat":"51.53691","long":"7.457463","pm25":""},{"location_name":"DENW010","location_id":"1335","lat":"51.547497","long":"7.693835","pm25":""},{"location_name":"DENW015","location_id":"1336","lat":"51.69896","long":"7.122713","pm25":""},{"location_name":"DENW021","location_id":"1337","lat":"51.525963","long":"6.976908","pm25":""},{"location_name":"DENW022","location_id":"1338","lat":"51.533646","long":"7.101786","pm25":""},{"location_name":"DENW024","location_id":"1339","lat":"51.49653","long":"6.981045","pm25":""},{"location_name":"DENW029","location_id":"1340","lat":"51.403004","long":"7.208572","pm25":""},{"location_name":"DENW030","location_id":"1341","lat":"51.67281","long":"6.629576","pm25":""},{"location_name":"DENW034","location_id":"1342","lat":"51.52402","long":"6.748402","pm25":""},{"location_name":"DENW038","location_id":"1343","lat":"51.45346","long":"6.865107","pm25":""},{"location_name":"DENW040","location_id":"1344","lat":"51.385254","long":"6.763001","pm25":""},{"location_name":"DENW042","location_id":"1345","lat":"51.33767","long":"6.640242","pm25":""},{"location_name":"DENW043","location_id":"1346","lat":"51.451176","long":"7.030603","pm25":""},{"location_name":"DENW053","location_id":"1347","lat":"51.019344","long":"6.884636","pm25":""},{"location_name":"DENW058","location_id":"1348","lat":"50.87612","long":"6.873789","pm25":""},{"location_name":"DENW059","location_id":"1349","lat":"50.889812","long":"6.985164","pm25":""},{"location_name":"DENW062","location_id":"1350","lat":"50.75364","long":"7.082676","pm25":""},{"location_name":"DENW064","location_id":"1351","lat":"50.653236","long":"6.281069","pm25":""},{"location_name":"DENW065","location_id":"1352","lat":"50.93033","long":"8.191932","pm25":""},{"location_name":"DENW066","location_id":"1353","lat":"51.326942","long":"6.195868","pm25":""},{"location_name":"DENW067","location_id":"1354","lat":"52.02317","long":"8.548389","pm25":""},{"location_name":"DENW068","location_id":"1355","lat":"51.570663","long":"8.148061","pm25":""},{"location_name":"DENW071","location_id":"1356","lat":"51.24921","long":"6.732383","pm25":""},{"location_name":"DENW074","location_id":"1357","lat":"50.883476","long":"6.469363","pm25":""},{"location_name":"DENW078","location_id":"1358","lat":"51.30392","long":"6.819967","pm25":""},{"location_name":"DENW079","location_id":"1359","lat":"51.028877","long":"7.005063","pm25":""},{"location_name":"DENW080","location_id":"1360","lat":"51.183773","long":"7.052634","pm25":""},{"location_name":"DENW081","location_id":"1361","lat":"51.862","long":"6.874554","pm25":""},{"location_name":"DENW082","location_id":"1362","lat":"51.21311","long":"6.782565","pm25":""},{"location_name":"DENW094","location_id":"1363","lat":"50.754704","long":"6.093923","pm25":""},{"location_name":"DENW095","location_id":"1364","lat":"51.936546","long":"7.611581","pm25":""},{"location_name":"DENW096","location_id":"1365","lat":"51.154613","long":"6.42571","pm25":""},{"location_name":"DENW101","location_id":"1367","lat":"51.519638","long":"7.464347","pm25":""},{"location_name":"DENW112","location_id":"1368","lat":"51.43771","long":"6.771801","pm25":""},{"location_name":"DENW114","location_id":"1369","lat":"51.277645","long":"7.231895","pm25":""},{"location_name":"DENW116","location_id":"1370","lat":"51.34256","long":"6.670195","pm25":""},{"location_name":"DENW133","location_id":"1371","lat":"51.362827","long":"7.46353","pm25":""},{"location_name":"DENW134","location_id":"1372","lat":"51.477932","long":"7.005278","pm25":""},{"location_name":"DENW136","location_id":"1373","lat":"51.523567","long":"7.483597","pm25":""},{"location_name":"DENW179","location_id":"1374","lat":"51.44876","long":"7.582295","pm25":""},{"location_name":"DENW181","location_id":"1375","lat":"51.443012","long":"8.360714","pm25":""},{"location_name":"DENW182","location_id":"1376","lat":"50.92711","long":"6.582205","pm25":""},{"location_name":"DENW188","location_id":"1377","lat":"51.47497","long":"6.863657","pm25":""},{"location_name":"DENW189","location_id":"1378","lat":"51.26068","long":"7.147401","pm25":""},{"location_name":"DENW200","location_id":"1379","lat":"52.005623","long":"8.552804","pm25":""},{"location_name":"DENW206","location_id":"1380","lat":"51.17615","long":"7.084069","pm25":""},{"location_name":"DENW207","location_id":"1381","lat":"50.773132","long":"6.095775","pm25":""},{"location_name":"DENW208","location_id":"1382","lat":"51.52788","long":"7.084597","pm25":""},{"location_name":"DENW211","location_id":"1383","lat":"50.962856","long":"7.00459","pm25":""},{"location_name":"DENW212","location_id":"1384","lat":"50.94737","long":"6.957701","pm25":""},{"location_name":"DENW247","location_id":"1385","lat":"51.406967","long":"6.965643","pm25":""},{"location_name":"DENW259","location_id":"1386","lat":"51.169437","long":"6.439975","pm25":""},{"location_name":"DENW260","location_id":"1387","lat":"51.953266","long":"7.619387","pm25":""},{"location_name":"DENW329","location_id":"1388","lat":"51.033833","long":"6.451483","pm25":""},{"location_name":"DENW337","location_id":"1389","lat":"51.097637","long":"6.469463","pm25":""},{"location_name":"DENW338","location_id":"1390","lat":"51.485493","long":"6.735431","pm25":""},{"location_name":"DENW355","location_id":"1391","lat":"51.03147","long":"7.010934","pm25":""},{"location_name":"DENW367","location_id":"1392","lat":"51.568054","long":"6.990945","pm25":""},{"location_name":"DERP001","location_id":"1394","lat":"49.515053","long":"8.402374","pm25":""},{"location_name":"DERP003","location_id":"1395","lat":"49.45538","long":"8.425833","pm25":""},{"location_name":"DERP007","location_id":"1396","lat":"50.01708","long":"8.216498","pm25":""},{"location_name":"DERP009","location_id":"1397","lat":"49.994976","long":"8.273965","pm25":""},{"location_name":"DERP010","location_id":"1398","lat":"50.000973","long":"8.261277","pm25":""},{"location_name":"DERP011","location_id":"1399","lat":"50.009953","long":"8.265563","pm25":""},{"location_name":"DERP013","location_id":"1401","lat":"49.423138","long":"7.293522","pm25":""},{"location_name":"DERP014","location_id":"1402","lat":"49.741035","long":"7.193486","pm25":""},{"location_name":"DERP015","location_id":"1403","lat":"50.2665","long":"6.3781","pm25":""},{"location_name":"DERP016","location_id":"1404","lat":"50.76675","long":"7.9735","pm25":""},{"location_name":"DERP017","location_id":"1405","lat":"49.270264","long":"7.826521","pm25":""},{"location_name":"DERP019","location_id":"1406","lat":"49.446","long":"7.7673","pm25":""},{"location_name":"DERP020","location_id":"1407","lat":"49.754192","long":"6.646762","pm25":""},{"location_name":"DERP021","location_id":"1408","lat":"50.424675","long":"7.481394","pm25":""},{"location_name":"DERP022","location_id":"1409","lat":"49.842136","long":"7.866208","pm25":""},{"location_name":"DERP023","location_id":"1410","lat":"49.6287","long":"8.3649","pm25":""},{"location_name":"DERP024","location_id":"1411","lat":"50.3544","long":"7.596583","pm25":""},{"location_name":"DERP025","location_id":"1412","lat":"49.052322","long":"8.253547","pm25":""},{"location_name":"DERP026","location_id":"1413","lat":"49.5333","long":"8.3553","pm25":""},{"location_name":"DERP028","location_id":"1414","lat":"50.4243","long":"7.7299","pm25":""},{"location_name":"DERP041","location_id":"1415","lat":"49.47869","long":"8.443654","pm25":""},{"location_name":"DERP045","location_id":"1416","lat":"50.359604","long":"7.592515","pm25":""},{"location_name":"DERP046","location_id":"1417","lat":"50.431396","long":"7.460812","pm25":""},{"location_name":"DERP047","location_id":"1418","lat":"49.783943","long":"6.690488","pm25":""},{"location_name":"DERP053","location_id":"1419","lat":"49.351143","long":"8.423005","pm25":""},{"location_name":"DERP060","location_id":"1420","lat":"49.191998","long":"7.614573","pm25":""},{"location_name":"DESH001","location_id":"1421","lat":"53.67055","long":"9.585874","pm25":""},{"location_name":"DESH008","location_id":"1422","lat":"54.09323","long":"10.240596","pm25":""},{"location_name":"DESH013","location_id":"1423","lat":"54.412987","long":"11.215994","pm25":""},{"location_name":"DESH014","location_id":"1424","lat":"54.32781","long":"8.603474","pm25":""},{"location_name":"DESH015","location_id":"1425","lat":"53.924713","long":"9.532635","pm25":""},{"location_name":"DESH016","location_id":"1426","lat":"53.570583","long":"10.214871","pm25":""},{"location_name":"DESH022","location_id":"1427","lat":"54.78143","long":"9.43809","pm25":""},{"location_name":"DESH023","location_id":"1428","lat":"53.83549","long":"10.695936","pm25":""},{"location_name":"DESH025","location_id":"1429","lat":"53.92803","long":"9.511769","pm25":""},{"location_name":"DESH027","location_id":"1430","lat":"54.304676","long":"10.135158","pm25":""},{"location_name":"DESH030","location_id":"1431","lat":"53.68199","long":"9.997256","pm25":""},{"location_name":"DESH035","location_id":"1432","lat":"53.89612","long":"9.156908","pm25":""},{"location_name":"DESH052","location_id":"1433","lat":"54.30424","long":"10.122364","pm25":""},{"location_name":"DESH053","location_id":"1434","lat":"53.862236","long":"10.67332","pm25":""},{"location_name":"DESH055","location_id":"1435","lat":"53.87453","long":"10.664881","pm25":""},{"location_name":"DESL001","location_id":"1436","lat":"49.263905","long":"6.687126","pm25":""},{"location_name":"DESL002","location_id":"1437","lat":"49.36205","long":"7.263234","pm25":""},{"location_name":"DESL003","location_id":"1438","lat":"49.35786","long":"6.73354","pm25":""},{"location_name":"DESL006","location_id":"1439","lat":"49.18361","long":"6.744856","pm25":""},{"location_name":"DESL010","location_id":"1440","lat":"49.244247","long":"6.948776","pm25":""},{"location_name":"DESL011","location_id":"1441","lat":"49.23723","long":"7.036322","pm25":""},{"location_name":"DESL012","location_id":"1442","lat":"49.233463","long":"6.987601","pm25":""},{"location_name":"DESL013","location_id":"1443","lat":"49.322647","long":"6.753639","pm25":""},{"location_name":"DESL017","location_id":"1444","lat":"49.254345","long":"6.867744","pm25":""},{"location_name":"DESL019","location_id":"1445","lat":"49.416885","long":"6.552037","pm25":""},{"location_name":"DESL020","location_id":"1446","lat":"49.23074","long":"7.003174","pm25":""},{"location_name":"DESN001","location_id":"1447","lat":"50.570873","long":"12.997278","pm25":""},{"location_name":"DESN004","location_id":"1448","lat":"51.17567","long":"14.443771","pm25":""},{"location_name":"DESN006","location_id":"1449","lat":"51.125","long":"12.493056","pm25":""},{"location_name":"DESN017","location_id":"1450","lat":"50.9163","long":"13.346826","pm25":""},{"location_name":"DESN019","location_id":"1451","lat":"50.826","long":"12.542056","pm25":""},{"location_name":"DESN020","location_id":"1452","lat":"51.1558","long":"14.973958","pm25":""},{"location_name":"DESN024","location_id":"1453","lat":"50.354782","long":"12.468739","pm25":""},{"location_name":"DESN025","location_id":"1454","lat":"51.344166","long":"12.377163","pm25":""},{"location_name":"DESN045","location_id":"1455","lat":"50.892376","long":"14.822846","pm25":""},{"location_name":"DESN049","location_id":"1456","lat":"50.43132","long":"12.611125","pm25":""},{"location_name":"DESN051","location_id":"1457","lat":"51.119514","long":"13.675005","pm25":""},{"location_name":"DESN052","location_id":"1458","lat":"50.73148","long":"13.75145","pm25":""},{"location_name":"DESN053","location_id":"1459","lat":"50.42849","long":"12.953459","pm25":""},{"location_name":"DESN059","location_id":"1460","lat":"51.317905","long":"12.297411","pm25":""},{"location_name":"DESN061","location_id":"1461","lat":"51.06493","long":"13.741397","pm25":""},{"location_name":"DESN074","location_id":"1462","lat":"50.659096","long":"13.465078","pm25":""},{"location_name":"DESN075","location_id":"1463","lat":"50.486137","long":"12.138054","pm25":""},{"location_name":"DESN076","location_id":"1464","lat":"51.303772","long":"13.009406","pm25":""},{"location_name":"DESN077","location_id":"1465","lat":"51.335873","long":"12.334686","pm25":""},{"location_name":"DESN079","location_id":"1466","lat":"51.285355","long":"14.749731","pm25":""},{"location_name":"DESN080","location_id":"1467","lat":"51.396095","long":"12.234054","pm25":""},{"location_name":"DESN081","location_id":"1468","lat":"50.48175","long":"12.130376","pm25":""},{"location_name":"DESN082","location_id":"1469","lat":"51.375988","long":"12.425748","pm25":""},{"location_name":"DESN083","location_id":"1470","lat":"50.84574","long":"12.903367","pm25":""},{"location_name":"DESN084","location_id":"1471","lat":"51.026295","long":"13.731608","pm25":""},{"location_name":"DESN091","location_id":"1472","lat":"50.720406","long":"12.486621","pm25":""},{"location_name":"DESN092","location_id":"1473","lat":"51.036106","long":"13.730205","pm25":""},{"location_name":"DESN093","location_id":"1474","lat":"50.608135","long":"12.211112","pm25":""},{"location_name":"DESPLNS","location_id":"1475","lat":"42.0603","long":"-87.8631","pm25":""},{"location_name":"DEST002","location_id":"1476","lat":"52.268353","long":"11.864763","pm25":""},{"location_name":"DEST011","location_id":"1477","lat":"51.839382","long":"10.790143","pm25":""},{"location_name":"DEST015","location_id":"1478","lat":"51.651165","long":"12.302866","pm25":""},{"location_name":"DEST028","location_id":"1479","lat":"51.054558","long":"12.141322","pm25":""},{"location_name":"DEST029","location_id":"1480","lat":"51.803535","long":"11.738962","pm25":""},{"location_name":"DEST039","location_id":"1481","lat":"51.79863","long":"10.618275","pm25":""},{"location_name":"DEST044","location_id":"1482","lat":"51.89698","long":"11.057442","pm25":""},{"location_name":"DEST050","location_id":"1483","lat":"51.496166","long":"11.979064","pm25":""},{"location_name":"DEST066","location_id":"1484","lat":"51.870853","long":"12.663663","pm25":""},{"location_name":"DEST077","location_id":"1486","lat":"52.1279","long":"11.611464","pm25":""},{"location_name":"DEST089","location_id":"1487","lat":"52.593136","long":"11.172327","pm25":""},{"location_name":"DEST090","location_id":"1488","lat":"51.321365","long":"12.032141","pm25":""},{"location_name":"DEST091","location_id":"1489","lat":"51.840576","long":"12.244764","pm25":""},{"location_name":"DEST092","location_id":"1490","lat":"51.86747","long":"12.59827","pm25":""},{"location_name":"DEST095","location_id":"1491","lat":"51.759556","long":"11.449438","pm25":""},{"location_name":"DEST098","location_id":"1492","lat":"51.662434","long":"11.043386","pm25":""},{"location_name":"DEST102","location_id":"1493","lat":"51.494755","long":"11.981314","pm25":""},{"location_name":"DEST103","location_id":"1494","lat":"52.12076","long":"11.632669","pm25":""},{"location_name":"DEST104","location_id":"1495","lat":"51.837307","long":"11.891412","pm25":""},{"location_name":"DEST105","location_id":"1496","lat":"52.602055","long":"11.850274","pm25":""},{"location_name":"DEST106","location_id":"1497","lat":"51.45607","long":"11.091078","pm25":""},{"location_name":"DEST108","location_id":"1498","lat":"51.19725","long":"11.96096","pm25":""},{"location_name":"DEST112","location_id":"1499","lat":"52.13174","long":"11.631919","pm25":""},{"location_name":"DET POLICE 4TH","location_id":"1500","lat":"42.312157","long":"-83.09194","pm25":""},{"location_name":"DETH005","location_id":"1501","lat":"50.65118","long":"11.368875","pm25":""},{"location_name":"DETH009","location_id":"1502","lat":"50.877316","long":"12.07471","pm25":""},{"location_name":"DETH011","location_id":"1503","lat":"50.98776","long":"12.437621","pm25":""},{"location_name":"DETH013","location_id":"1504","lat":"50.97829","long":"10.317236","pm25":""},{"location_name":"DETH018","location_id":"1505","lat":"51.497196","long":"10.791404","pm25":""},{"location_name":"DETH020","location_id":"1506","lat":"50.979454","long":"11.037924","pm25":""},{"location_name":"DETH026","location_id":"1507","lat":"50.561752","long":"10.375299","pm25":""},{"location_name":"DETH027","location_id":"1508","lat":"50.499954","long":"11.134593","pm25":""},{"location_name":"DETH036","location_id":"1509","lat":"50.65586","long":"12.205199","pm25":""},{"location_name":"DETH041","location_id":"1510","lat":"50.933514","long":"11.597062","pm25":""},{"location_name":"DETH042","location_id":"1511","lat":"51.333332","long":"10.867188","pm25":""},{"location_name":"DETH043","location_id":"1512","lat":"50.984875","long":"11.019353","pm25":""},{"location_name":"DETH061","location_id":"1514","lat":"50.791615","long":"11.661233","pm25":""},{"location_name":"DETH072","location_id":"1515","lat":"50.61153","long":"10.693092","pm25":""},{"location_name":"DETH081","location_id":"1516","lat":"50.972332","long":"11.010446","pm25":""},{"location_name":"DETH083","location_id":"1517","lat":"50.977463","long":"11.32607","pm25":""},{"location_name":"DETH091","location_id":"1518","lat":"51.205467","long":"10.448476","pm25":""},{"location_name":"DETH093","location_id":"1519","lat":"50.982544","long":"11.3204","pm25":""},{"location_name":"DETH095","location_id":"1520","lat":"51.207943","long":"10.450997","pm25":""},{"location_name":"DETH117","location_id":"1521","lat":"50.993126","long":"11.056578","pm25":""},{"location_name":"DETROIT - E 7 MILE","location_id":"1522","lat":"42.4308","long":"-83.0008","pm25":""},{"location_name":"DETROIT - SOUTHWEST","location_id":"1523","lat":"42.3042","long":"-83.1072","pm25":""},{"location_name":"DEUB001","location_id":"1525","lat":"54.92497","long":"8.308208","pm25":""},{"location_name":"DEUB004","location_id":"1526","lat":"47.913258","long":"7.908035","pm25":""},{"location_name":"DEUB005","location_id":"1527","lat":"52.800774","long":"10.756733","pm25":""},{"location_name":"DEUB028","location_id":"1528","lat":"54.436985","long":"12.721938","pm25":""},{"location_name":"DEUB029","location_id":"1529","lat":"50.654064","long":"10.769534","pm25":""},{"location_name":"DEUB030","location_id":"1530","lat":"53.141304","long":"13.031662","pm25":""},{"location_name":"DEUB046","location_id":"1531","lat":"48.947613","long":"13.420573","pm25":""},{"location_name":"DK0012R","location_id":"1532","lat":"55.694103","long":"12.088629","pm25":""},{"location_name":"DK0030A","location_id":"1533","lat":"55.698357","long":"12.553328","pm25":""},{"location_name":"DK0031A","location_id":"1534","lat":"55.394447","long":"10.393777","pm25":""},{"location_name":"DK0031R","location_id":"1535","lat":"56.29038","long":"8.427402","pm25":""},{"location_name":"DK0034A","location_id":"1536","lat":"55.674305","long":"12.571114","pm25":""},{"location_name":"DK0045A","location_id":"1537","lat":"55.70028","long":"12.561412","pm25":""},{"location_name":"DK0046A","location_id":"1538","lat":"55.39639","long":"10.389196","pm25":""},{"location_name":"DK0051A","location_id":"1539","lat":"56.15056","long":"10.200842","pm25":""},{"location_name":"DK0053A","location_id":"1540","lat":"57.046654","long":"9.930876","pm25":""},{"location_name":"DK0054A","location_id":"1541","lat":"54.746387","long":"10.736395","pm25":""},{"location_name":"DK0056A","location_id":"1542","lat":"56.159782","long":"10.193633","pm25":""},{"location_name":"DK0057A","location_id":"1543","lat":"55.631985","long":"12.463316","pm25":""},{"location_name":"DYERTEOM","location_id":"1547","lat":"36.0528","long":"-89.3819","pm25":""},{"location_name":"Dallas Hinton St. C4","location_id":"1548","lat":"32.82","long":"-96.86","pm25":""},{"location_name":"Dallas North C63","location_id":"1549","lat":"32.919205","long":"-96.808495","pm25":""},{"location_name":"Dallas Redbird Airpo","location_id":"1550","lat":"32.6767","long":"-96.8717","pm25":""},{"location_name":"Danbury","location_id":"1552","lat":"41.4014","long":"-73.4447","pm25":""},{"location_name":"Daniel South","location_id":"1554","lat":"42.7914","long":"-110.0547","pm25":""},{"location_name":"Danmarks plass","location_id":"1555","lat":"60.37408","long":"5.34042","pm25":""},{"location_name":"Darrington-Fir St","location_id":"1556","lat":"48.2468","long":"-121.6031","pm25":""},{"location_name":"Davenport, 10th & Vi","location_id":"1557","lat":"41.53","long":"-90.5875","pm25":""},{"location_name":"Davis - UCD Campus","location_id":"1561","lat":"38.53455","long":"-121.7734","pm25":""},{"location_name":"Dayton-W Main","location_id":"1564","lat":"46.318","long":"-117.985","pm25":""},{"location_name":"Dayville","location_id":"1565","lat":"37.9536","long":"-87.29","pm25":""},{"location_name":"De Rijp-Oostdijkje","location_id":"1566","lat":"52.5636","long":"4.8617","pm25":""},{"location_name":"De Zilk-Vogelaarsdreef","location_id":"1569","lat":"52.2966","long":"4.51082","pm25":""},{"location_name":"Death Valley NP","location_id":"1570","lat":"36.5092","long":"-116.8481","pm25":""},{"location_name":"Deception Bay","location_id":"1571","lat":"-27.4296","long":"153.158","pm25":""},{"location_name":"Deer Creek","location_id":"1572","lat":"39.6359","long":"-83.2605","pm25":""},{"location_name":"Del Norte","location_id":"1574","lat":"35.1353","long":"-106.5847","pm25":""},{"location_name":"Den Haag-Bleriotlaan","location_id":"1579","lat":"52.039","long":"4.35938","pm25":""},{"location_name":"Den Haag-Rebecquestraat","location_id":"1580","lat":"52.0771","long":"4.28919","pm25":""},{"location_name":"Den Haag-Veerkade","location_id":"1581","lat":"52.0751","long":"4.31587","pm25":""},{"location_name":"Denali NPP","location_id":"1582","lat":"63.7233","long":"-148.9675","pm25":""},{"location_name":"Denton Airport South","location_id":"1583","lat":"33.1944","long":"-97.1933","pm25":""},{"location_name":"Denver - CAMP - 2105","location_id":"1584","lat":"39.7511","long":"-104.9872","pm25":""},{"location_name":"Denver - NJH - 14th","location_id":"1585","lat":"39.7386","long":"-104.9394","pm25":""},{"location_name":"Derby St Alkmund's Way","location_id":"1587","lat":"52.92298","long":"-1.469507","pm25":""},{"location_name":"Derry Rosemount","location_id":"1589","lat":"55.00282","long":"-7.331179","pm25":""},{"location_name":"Des Sables","location_id":"1590","lat":"46.8214","long":"-71.2208","pm25":""},{"location_name":"Deschambault","location_id":"1591","lat":"46.6822","long":"-71.9678","pm25":""},{"location_name":"Desert View","location_id":"1592","lat":"31.7961","long":"-106.5839","pm25":""},{"location_name":"Detroit Lakes","location_id":"1594","lat":"46.8511","long":"-95.8467","pm25":""},{"location_name":"Devils Lake","location_id":"1596","lat":"43.4356","long":"-89.6803","pm25":""},{"location_name":"Dhahran","location_id":"1598","lat":"26.276861","long":"50.147232","pm25":""},{"location_name":"Dhaka","location_id":"1599","lat":"23.796373","long":"90.424614","pm25":""},{"location_name":"Diablo","location_id":"1600","lat":"33.3961","long":"-111.968","pm25":""},{"location_name":"Din Daeng Rd., Din Daeng","location_id":"1607","lat":"13.762406","long":"100.5506","pm25":""},{"location_name":"Din Daeng, Din Daeng","location_id":"1608","lat":"13.775373","long":"100.56893","pm25":""},{"location_name":"Dinosaur National Mo","location_id":"1609","lat":"40.4372","long":"-109.3047","pm25":""},{"location_name":"Dirty Socks","location_id":"1610","lat":"36.3261","long":"-117.9551","pm25":""},{"location_name":"Ditton","location_id":"1611","lat":"45.3733","long":"-71.2514","pm25":""},{"location_name":"Division Street","location_id":"1612","lat":"40.7142","long":"-73.995","pm25":""},{"location_name":"Dixie","location_id":"1613","lat":"32.6833","long":"-93.8617","pm25":""},{"location_name":"Doncaster A630 Cleveland Street","location_id":"1616","lat":"53.518867","long":"-1.138073","pm25":""},{"location_name":"Dordrecht-Bamendaweg","location_id":"1617","lat":"51.8007","long":"4.70824","pm25":""},{"location_name":"Dorset","location_id":"1620","lat":"45.2211","long":"-78.9314","pm25":""},{"location_name":"Douglas Red Cross","location_id":"1622","lat":"31.3492","long":"-109.53968","pm25":""},{"location_name":"Downtown Sacramento","location_id":"1625","lat":"38.56844","long":"-121.49311","pm25":""},{"location_name":"Drenas","location_id":"1628","lat":"42.62557","long":"20.89621","pm25":""},{"location_name":"Duluth-WDSE","location_id":"1630","lat":"46.8183","long":"-92.0892","pm25":""},{"location_name":"Dumbarton Roadside","location_id":"1631","lat":"55.943195","long":"-4.55973","pm25":""},{"location_name":"Dumfries","location_id":"1632","lat":"55.070034","long":"-3.614233","pm25":""},{"location_name":"Duncan","location_id":"1633","lat":"45.502647","long":"-73.66391","pm25":""},{"location_name":"Duncan 4804","location_id":"1634","lat":"48.786114","long":"-123.71731","pm25":""},{"location_name":"Dunkirk","location_id":"1638","lat":"42.4992","long":"-79.32","pm25":""},{"location_name":"Durango Complex","location_id":"1640","lat":"33.4265","long":"-112.1181","pm25":""},{"location_name":"Durham Armory","location_id":"1642","lat":"36.032955","long":"-78.90404","pm25":""},{"location_name":"Dushanbe","location_id":"1643","lat":"38.55767","long":"68.77592","pm25":""},{"location_name":"Duszniki-Zdr\u00f3j","location_id":"1644","lat":"50.402645","long":"16.393318","pm25":""},{"location_name":"Dutchtown","location_id":"1645","lat":"30.2294","long":"-90.9656","pm25":""},{"location_name":"Dysart","location_id":"1647","lat":"33.6369","long":"-112.3394","pm25":""},{"location_name":"Dzia\u0142oszyn","location_id":"1648","lat":"50.972168","long":"14.941319","pm25":""},{"location_name":"Dzier\u017coni\u00f3w - Pi\u0142sudskiego","location_id":"1649","lat":"50.73282","long":"16.64805","pm25":""},{"location_name":"D\u0105browa G\u00f3rnicza, ul. Tysi\u0105clecia 25a","location_id":"1650","lat":"50.32911","long":"19.231222","pm25":""},{"location_name":"D\u0119bica-Grottgera-WIOS","location_id":"1651","lat":"50.054787","long":"21.416256","pm25":""},{"location_name":"E Providence","location_id":"1652","lat":"41.8403","long":"-71.3617","pm25":""},{"location_name":"E Syracuse","location_id":"1653","lat":"43.0528","long":"-76.0597","pm25":""},{"location_name":"E. Milton - Blue Hil","location_id":"1655","lat":"42.2117","long":"-71.1144","pm25":""},{"location_name":"E6 Alna senter","location_id":"1659","lat":"59.92556","long":"10.850367","pm25":""},{"location_name":"E6-Tiller","location_id":"1660","lat":"63.3576","long":"10.3719","pm25":""},{"location_name":"EAGLEMT","location_id":"1662","lat":"34.4544","long":"-94.1433","pm25":""},{"location_name":"EAST BAY","location_id":"1664","lat":"27.853897","long":"-82.383415","pm25":""},{"location_name":"EAST VINTON ELEMENTA","location_id":"1666","lat":"37.2856","long":"-79.8842","pm25":""},{"location_name":"EDMUNDSTON QUEEN ST.","location_id":"1672","lat":"47.363194","long":"-68.3223","pm25":""},{"location_name":"Egbert","location_id":"1674","lat":"44.2325","long":"-79.7814","pm25":""},{"location_name":"ELDOSPGS","location_id":"1677","lat":"37.70097","long":"-94.03474","pm25":""},{"location_name":"EME F","location_id":"1680","lat":"-28.466423","long":"-71.22156","pm25":""},{"location_name":"EME M","location_id":"1681","lat":"-28.47034","long":"-71.21883","pm25":""},{"location_name":"ENV-HOSP - Envigado - E.S.E. Santa Gertrudis","location_id":"1683","lat":"6.168683","long":"-75.58197","pm25":""},{"location_name":"Erie","location_id":"1684","lat":"42.1428","long":"-80.0372","pm25":""},{"location_name":"ES0001R","location_id":"1685","lat":"39.54694","long":"-4.35056","pm25":""},{"location_name":"ES0005R","location_id":"1686","lat":"42.72056","long":"-8.92361","pm25":""},{"location_name":"ES0006R","location_id":"1687","lat":"39.87528","long":"4.31639","pm25":""},{"location_name":"ES0007R","location_id":"1688","lat":"37.23722","long":"-3.53417","pm25":""},{"location_name":"ES0008R","location_id":"1689","lat":"43.43917","long":"-4.85","pm25":""},{"location_name":"ES0009R","location_id":"1690","lat":"41.27417","long":"-3.1425","pm25":""},{"location_name":"ES0010R","location_id":"1691","lat":"42.31917","long":"3.31583","pm25":""},{"location_name":"ES0011R","location_id":"1692","lat":"38.47278","long":"-6.92361","pm25":""},{"location_name":"ES0012R","location_id":"1693","lat":"39.08278","long":"-1.10111","pm25":""},{"location_name":"ES0013R","location_id":"1694","lat":"41.23889","long":"-5.8975","pm25":""},{"location_name":"ES0014R","location_id":"1695","lat":"41.39389","long":"0.73472","pm25":""},{"location_name":"ES0016R","location_id":"1696","lat":"42.63472","long":"-7.70472","pm25":""},{"location_name":"ES0017R","location_id":"1697","lat":"37.05194","long":"-6.55528","pm25":""},{"location_name":"ES0041A","location_id":"1698","lat":"43.261112","long":"-2.9447222","pm25":""},{"location_name":"ES0110A","location_id":"1699","lat":"43.302776","long":"-2.9772222","pm25":""},{"location_name":"ES0115A","location_id":"1700","lat":"40.424168","long":"-3.7122223","pm25":""},{"location_name":"ES0118A","location_id":"1701","lat":"40.421665","long":"-3.6822221","pm25":""},{"location_name":"ES0120A","location_id":"1702","lat":"40.451668","long":"-3.6772223","pm25":""},{"location_name":"ES0124A","location_id":"1703","lat":"40.44","long":"-3.6391666","pm25":""},{"location_name":"ES0125A","location_id":"1704","lat":"40.346943","long":"-3.705","pm25":""},{"location_name":"ES0126A","location_id":"1705","lat":"40.394722","long":"-3.7319443","pm25":""},{"location_name":"ES0296A","location_id":"1706","lat":"39.74731","long":"3.01488","pm25":""},{"location_name":"ES0316A","location_id":"1707","lat":"40.94667","long":"-0.29083","pm25":""},{"location_name":"ES0556A","location_id":"1711","lat":"36.17943","long":"-5.37697","pm25":""},{"location_name":"ES0557A","location_id":"1712","lat":"36.18621","long":"-5.38081","pm25":""},{"location_name":"ES0584A","location_id":"1713","lat":"41.482018","long":"2.1882966","pm25":""},{"location_name":"ES0587A","location_id":"1714","lat":"43.320835","long":"-3.1130555","pm25":""},{"location_name":"ES0588A","location_id":"1715","lat":"43.320557","long":"-3.0738888","pm25":""},{"location_name":"ES0624A","location_id":"1716","lat":"36.84745","long":"-2.03819","pm25":""},{"location_name":"ES0629A","location_id":"1717","lat":"36.18562","long":"-5.48893","pm25":""},{"location_name":"ES0633A","location_id":"1718","lat":"36.1747","long":"-5.43277","pm25":""},{"location_name":"ES0634A","location_id":"1719","lat":"36.21204","long":"-5.43027","pm25":""},{"location_name":"ES0651A","location_id":"1720","lat":"37.603333","long":"-0.91333336","pm25":""},{"location_name":"ES0691A","location_id":"1721","lat":"41.40388","long":"2.2045226","pm25":""},{"location_name":"ES0692A","location_id":"1722","lat":"41.370502","long":"2.114973","pm25":""},{"location_name":"ES0694A","location_id":"1723","lat":"41.39216","long":"2.0098023","pm25":""},{"location_name":"ES0712A","location_id":"1724","lat":"36.17538","long":"-5.48083","pm25":""},{"location_name":"ES0785A","location_id":"1726","lat":"37.26725","long":"-6.91905","pm25":""},{"location_name":"ES0787A","location_id":"1727","lat":"37.19033","long":"-6.90453","pm25":""},{"location_name":"ES0805A","location_id":"1728","lat":"43.24111","long":"-2.8841667","pm25":""},{"location_name":"ES0813A","location_id":"1729","lat":"40.84194","long":"-0.0575","pm25":""},{"location_name":"ES0817A","location_id":"1730","lat":"37.38425","long":"-5.95962","pm25":""},{"location_name":"ES0822A","location_id":"1731","lat":"37.27964","long":"-6.93807","pm25":""},{"location_name":"ES0823A","location_id":"1732","lat":"37.18568","long":"-6.96414","pm25":""},{"location_name":"ES0824A","location_id":"1733","lat":"43.3069","long":"-5.705672","pm25":""},{"location_name":"ES0825A","location_id":"1734","lat":"43.306656","long":"-5.689716","pm25":""},{"location_name":"ES0827A","location_id":"1735","lat":"37.3154","long":"-6.84463","pm25":""},{"location_name":"ES0873A","location_id":"1736","lat":"28.03512","long":"-15.41631","pm25":""},{"location_name":"ES0879A","location_id":"1737","lat":"43.550304","long":"-5.89886","pm25":""},{"location_name":"ES0880A","location_id":"1738","lat":"43.5519","long":"-5.918","pm25":""},{"location_name":"ES0886A","location_id":"1739","lat":"28.029852","long":"-15.416086","pm25":""},{"location_name":"ES0890A","location_id":"1740","lat":"37.39452","long":"-6.0031","pm25":""},{"location_name":"ES0892A","location_id":"1741","lat":"37.19977","long":"-6.92027","pm25":""},{"location_name":"ES0893A","location_id":"1742","lat":"36.1821","long":"-5.41141","pm25":""},{"location_name":"ES0894A","location_id":"1743","lat":"36.20442","long":"-5.40471","pm25":""},{"location_name":"ES0926A","location_id":"1744","lat":"38.10814","long":"-4.9268","pm25":""},{"location_name":"ES0971A","location_id":"1745","lat":"41.450768","long":"1.9748873","pm25":""},{"location_name":"ES1018A","location_id":"1746","lat":"41.556114","long":"2.0074012","pm25":""},{"location_name":"ES1037A","location_id":"1747","lat":"43.3675","long":"-4.04278","pm25":""},{"location_name":"ES1038A","location_id":"1748","lat":"43.34639","long":"-4.06417","pm25":""},{"location_name":"ES1039A","location_id":"1749","lat":"43.35583","long":"-4.06361","pm25":""},{"location_name":"ES1044A","location_id":"1750","lat":"41.67028","long":"-0.87111","pm25":""},{"location_name":"ES1047A","location_id":"1751","lat":"41.65139","long":"-0.91611","pm25":""},{"location_name":"ES1067A","location_id":"1752","lat":"37.21925","long":"-6.88858","pm25":""},{"location_name":"ES1072A","location_id":"1753","lat":"36.15937","long":"-5.34836","pm25":""},{"location_name":"ES1074A","location_id":"1754","lat":"36.20388","long":"-5.38371","pm25":""},{"location_name":"ES1076A","location_id":"1755","lat":"36.19048","long":"-5.43576","pm25":""},{"location_name":"ES1090A","location_id":"1756","lat":"41.67417","long":"-0.86417","pm25":""},{"location_name":"ES1093A","location_id":"1757","lat":"39.78995","long":"3.07413","pm25":""},{"location_name":"ES1095A","location_id":"1759","lat":"39.89092","long":"4.252975","pm25":""},{"location_name":"ES1096A","location_id":"1760","lat":"42.351944","long":"-7.8769445","pm25":""},{"location_name":"ES1117A","location_id":"1761","lat":"41.11209","long":"1.1518244","pm25":""},{"location_name":"ES1120A","location_id":"1762","lat":"41.11588","long":"1.1919755","pm25":""},{"location_name":"ES1122A","location_id":"1763","lat":"41.19359","long":"1.2367028","pm25":""},{"location_name":"ES1123A","location_id":"1764","lat":"41.154922","long":"1.2177176","pm25":""},{"location_name":"ES1124A","location_id":"1765","lat":"41.15945","long":"1.2397038","pm25":""},{"location_name":"ES1125A","location_id":"1766","lat":"41.73028","long":"1.8253064","pm25":""},{"location_name":"ES1126A","location_id":"1767","lat":"41.47541","long":"1.9212034","pm25":""},{"location_name":"ES1130A","location_id":"1768","lat":"41.28833","long":"-0.32667","pm25":""},{"location_name":"ES1131A","location_id":"1769","lat":"28.462173","long":"-16.261894","pm25":""},{"location_name":"ES1135A","location_id":"1770","lat":"41.577625","long":"1.6258934","pm25":""},{"location_name":"ES1137A","location_id":"1771","lat":"42.219166","long":"-8.741944","pm25":""},{"location_name":"ES1138A","location_id":"1772","lat":"43.36778","long":"-8.418889","pm25":""},{"location_name":"ES1148A","location_id":"1773","lat":"41.42562","long":"2.2222447","pm25":""},{"location_name":"ES1160A","location_id":"1774","lat":"42.35083","long":"-3.67556","pm25":""},{"location_name":"ES1161A","location_id":"1775","lat":"42.60389","long":"-5.587222","pm25":""},{"location_name":"ES1162A","location_id":"1776","lat":"41.316387","long":"-4.909167","pm25":""},{"location_name":"ES1163A","location_id":"1777","lat":"42.684444","long":"-2.9175","pm25":""},{"location_name":"ES1169A","location_id":"1778","lat":"36.20879","long":"-5.39138","pm25":""},{"location_name":"ES1181A","location_id":"1779","lat":"39.48111","long":"-0.44722223","pm25":""},{"location_name":"ES1182A","location_id":"1780","lat":"38.966667","long":"-0.19","pm25":""},{"location_name":"ES1185A","location_id":"1781","lat":"39.66722","long":"-0.23472223","pm25":""},{"location_name":"ES1193A","location_id":"1782","lat":"40.42","long":"-3.7491667","pm25":""},{"location_name":"ES1201A","location_id":"1783","lat":"42.391975","long":"2.8421385","pm25":""},{"location_name":"ES1208A","location_id":"1784","lat":"41.15078","long":"1.1201719","pm25":""},{"location_name":"ES1215A","location_id":"1785","lat":"40.706707","long":"0.5816515","pm25":""},{"location_name":"ES1222A","location_id":"1786","lat":"41.691273","long":"2.440945","pm25":""},{"location_name":"ES1225A","location_id":"1787","lat":"41.615795","long":"0.6157259","pm25":""},{"location_name":"ES1231A","location_id":"1788","lat":"41.47677","long":"2.0889773","pm25":""},{"location_name":"ES1239A","location_id":"1789","lat":"39.456112","long":"-0.37583333","pm25":""},{"location_name":"ES1244A","location_id":"1790","lat":"43.2675","long":"-2.9183333","pm25":""},{"location_name":"ES1246A","location_id":"1791","lat":"38.91382","long":"1.41426","pm25":""},{"location_name":"ES1247A","location_id":"1792","lat":"38.90648","long":"1.43537","pm25":""},{"location_name":"ES1248A","location_id":"1793","lat":"42.40538","long":"1.13","pm25":""},{"location_name":"ES1253A","location_id":"1794","lat":"38.09293","long":"-3.78392","pm25":""},{"location_name":"ES1256A","location_id":"1795","lat":"37.26016","long":"-6.92546","pm25":""},{"location_name":"ES1258A","location_id":"1796","lat":"37.28156","long":"-6.83384","pm25":""},{"location_name":"ES1259A","location_id":"1797","lat":"37.35844","long":"-6.67846","pm25":""},{"location_name":"ES1262A","location_id":"1798","lat":"41.561176","long":"2.1014051","pm25":""},{"location_name":"ES1268A","location_id":"1799","lat":"43.35829","long":"-5.86643","pm25":""},{"location_name":"ES1269A","location_id":"1800","lat":"43.36653","long":"-5.83303","pm25":""},{"location_name":"ES1270A","location_id":"1801","lat":"43.535187","long":"-5.658337","pm25":""},{"location_name":"ES1271A","location_id":"1802","lat":"43.538864","long":"-5.698921","pm25":""},{"location_name":"ES1272A","location_id":"1803","lat":"43.52986","long":"-5.673498","pm25":""},{"location_name":"ES1275A","location_id":"1804","lat":"41.68905","long":"2.4957466","pm25":""},{"location_name":"ES1277A","location_id":"1805","lat":"38.68065","long":"-4.10832","pm25":""},{"location_name":"ES1278A","location_id":"1806","lat":"38.68925","long":"-4.11151","pm25":""},{"location_name":"ES1279A","location_id":"1807","lat":"38.68198","long":"-4.08858","pm25":""},{"location_name":"ES1287A","location_id":"1808","lat":"42.795277","long":"-4.840833","pm25":""},{"location_name":"ES1297A","location_id":"1809","lat":"42.802776","long":"-5.623611","pm25":""},{"location_name":"ES1310A","location_id":"1810","lat":"42.312077","long":"2.214273","pm25":""},{"location_name":"ES1311A","location_id":"1811","lat":"41.958675","long":"3.2128544","pm25":""},{"location_name":"ES1312A","location_id":"1812","lat":"41.10368","long":"1.200765","pm25":""},{"location_name":"ES1328A","location_id":"1814","lat":"37.25258","long":"-6.94219","pm25":""},{"location_name":"ES1339A","location_id":"1815","lat":"41.219036","long":"1.7212487","pm25":""},{"location_name":"ES1340A","location_id":"1816","lat":"37.25336","long":"-6.93514","pm25":""},{"location_name":"ES1346A","location_id":"1817","lat":"42.688057","long":"-2.9405556","pm25":""},{"location_name":"ES1347A","location_id":"1818","lat":"42.14326","long":"2.510207","pm25":""},{"location_name":"ES1348A","location_id":"1819","lat":"42.368317","long":"1.7767832","pm25":""},{"location_name":"ES1349A","location_id":"1820","lat":"43.144444","long":"-2.9633334","pm25":""},{"location_name":"ES1353A","location_id":"1821","lat":"43.294117","long":"-5.679632","pm25":""},{"location_name":"ES1358A","location_id":"1823","lat":"43.53777","long":"-5.646307","pm25":""},{"location_name":"ES1365A","location_id":"1824","lat":"38.70272","long":"-4.112","pm25":""},{"location_name":"ES1370A","location_id":"1825","lat":"36.74312","long":"-3.5173","pm25":""},{"location_name":"ES1379A","location_id":"1826","lat":"41.058205","long":"0.4397117","pm25":""},{"location_name":"ES1386A","location_id":"1827","lat":"40.01278","long":"-0.05722222","pm25":""},{"location_name":"ES1387A","location_id":"1828","lat":"39.962776","long":"-0.23333333","pm25":""},{"location_name":"ES1393A","location_id":"1829","lat":"36.84133","long":"-2.44672","pm25":""},{"location_name":"ES1396A","location_id":"1830","lat":"41.378803","long":"2.1330981","pm25":""},{"location_name":"ES1397A","location_id":"1831","lat":"42.003277","long":"2.287272","pm25":""},{"location_name":"ES1400A","location_id":"1832","lat":"41.50556","long":"-0.15194","pm25":""},{"location_name":"ES1417A","location_id":"1833","lat":"42.13611","long":"-0.40389","pm25":""},{"location_name":"ES1418A","location_id":"1834","lat":"41.76278","long":"-1.14333","pm25":""},{"location_name":"ES1421A","location_id":"1835","lat":"40.33639","long":"-1.10667","pm25":""},{"location_name":"ES1422A","location_id":"1836","lat":"40.419167","long":"-3.7033334","pm25":""},{"location_name":"ES1423A","location_id":"1837","lat":"37.69361","long":"-1.0647222","pm25":""},{"location_name":"ES1424A","location_id":"1838","lat":"43.55885","long":"-5.92748","pm25":""},{"location_name":"ES1425A","location_id":"1839","lat":"37.37525","long":"-6.00558","pm25":""},{"location_name":"ES1426A","location_id":"1840","lat":"40.408054","long":"-3.6452777","pm25":""},{"location_name":"ES1428A","location_id":"1841","lat":"39.959167","long":"-0.03611111","pm25":""},{"location_name":"ES1432A","location_id":"1842","lat":"43.1788","long":"-6.5527","pm25":""},{"location_name":"ES1433A","location_id":"1843","lat":"43.275635","long":"-5.59599","pm25":""},{"location_name":"ES1435A","location_id":"1844","lat":"40.416668","long":"-0.24916665","pm25":""},{"location_name":"ES1437A","location_id":"1845","lat":"40.691666","long":"0.08472222","pm25":""},{"location_name":"ES1438A","location_id":"1846","lat":"41.38534","long":"2.153822","pm25":""},{"location_name":"ES1441A","location_id":"1847","lat":"40.637222","long":"-0.09111111","pm25":""},{"location_name":"ES1442A","location_id":"1848","lat":"43.064167","long":"-2.49","pm25":""},{"location_name":"ES1443A","location_id":"1849","lat":"42.33611","long":"-3.63611","pm25":""},{"location_name":"ES1445A","location_id":"1850","lat":"39.981945","long":"0.01055555","pm25":""},{"location_name":"ES1450A","location_id":"1851","lat":"37.39831","long":"-5.95165","pm25":""},{"location_name":"ES1453A","location_id":"1852","lat":"41.44735","long":"2.2095113","pm25":""},{"location_name":"ES1472A","location_id":"1853","lat":"42.80722","long":"-1.65139","pm25":""},{"location_name":"ES1479A","location_id":"1854","lat":"36.50602","long":"-6.26857","pm25":""},{"location_name":"ES1480A","location_id":"1855","lat":"41.398743","long":"2.1533852","pm25":""},{"location_name":"ES1489A","location_id":"1856","lat":"42.87528","long":"-3.2313888","pm25":""},{"location_name":"ES1490A","location_id":"1857","lat":"43.172222","long":"-2.6358333","pm25":""},{"location_name":"ES1491A","location_id":"1858","lat":"43.406113","long":"-2.703889","pm25":""},{"location_name":"ES1492A","location_id":"1859","lat":"42.855556","long":"-2.6680555","pm25":""},{"location_name":"ES1494A","location_id":"1860","lat":"43.322777","long":"-1.9602778","pm25":""},{"location_name":"ES1498A","location_id":"1861","lat":"43.130833","long":"-2.0777779","pm25":""},{"location_name":"ES1499A","location_id":"1862","lat":"43.048332","long":"-2.191111","pm25":""},{"location_name":"ES1501A","location_id":"1863","lat":"43.18","long":"-2.2680554","pm25":""},{"location_name":"ES1502A","location_id":"1864","lat":"42.85472","long":"-2.6805556","pm25":""},{"location_name":"ES1516A","location_id":"1865","lat":"36.52283","long":"-6.22517","pm25":""},{"location_name":"ES1517A","location_id":"1866","lat":"39.83379","long":"3.1443","pm25":""},{"location_name":"ES1518A","location_id":"1867","lat":"39.83962","long":"3.02705","pm25":""},{"location_name":"ES1519A","location_id":"1868","lat":"37.42986","long":"-5.98039","pm25":""},{"location_name":"ES1521A","location_id":"1869","lat":"40.478333","long":"-3.7113888","pm25":""},{"location_name":"ES1525A","location_id":"1870","lat":"40.44528","long":"-3.706389","pm25":""},{"location_name":"ES1529A","location_id":"1871","lat":"43.46778","long":"-3.79028","pm25":""},{"location_name":"ES1530A","location_id":"1872","lat":"43.01194","long":"-4.13556","pm25":""},{"location_name":"ES1531A","location_id":"1873","lat":"43.15333","long":"-4.25306","pm25":""},{"location_name":"ES1532A","location_id":"1874","lat":"40.388054","long":"-3.651389","pm25":""},{"location_name":"ES1535A","location_id":"1875","lat":"38.97928","long":"-1.85213","pm25":""},{"location_name":"ES1536A","location_id":"1876","lat":"40.57099","long":"-3.26461","pm25":""},{"location_name":"ES1537A","location_id":"1877","lat":"40.62984","long":"-3.17159","pm25":""},{"location_name":"ES1542A","location_id":"1878","lat":"40.55472","long":"0.37277776","pm25":""},{"location_name":"ES1543A","location_id":"1879","lat":"40.735","long":"-0.16944444","pm25":""},{"location_name":"ES1544A","location_id":"1880","lat":"42.849167","long":"-2.4772222","pm25":""},{"location_name":"ES1549A","location_id":"1883","lat":"36.76972","long":"-2.81097","pm25":""},{"location_name":"ES1551A","location_id":"1884","lat":"41.512676","long":"2.1253836","pm25":""},{"location_name":"ES1560A","location_id":"1885","lat":"37.1961","long":"-3.61266","pm25":""},{"location_name":"ES1563A","location_id":"1886","lat":"40.47917","long":"-3.37778","pm25":""},{"location_name":"ES1564A","location_id":"1887","lat":"40.54056","long":"-3.64472","pm25":""},{"location_name":"ES1565A","location_id":"1888","lat":"40.28111","long":"-3.80167","pm25":""},{"location_name":"ES1567A","location_id":"1889","lat":"40.33972","long":"-3.73583","pm25":""},{"location_name":"ES1568A","location_id":"1890","lat":"40.32417","long":"-3.87639","pm25":""},{"location_name":"ES1569A","location_id":"1891","lat":"37.68889","long":"-1.7011111","pm25":""},{"location_name":"ES1572A","location_id":"1892","lat":"43.372677","long":"-5.872797","pm25":""},{"location_name":"ES1573A","location_id":"1893","lat":"28.133732","long":"-15.432823","pm25":""},{"location_name":"ES1576A","location_id":"1894","lat":"43.40444","long":"-3.84194","pm25":""},{"location_name":"ES1577A","location_id":"1895","lat":"43.42083","long":"-3.84111","pm25":""},{"location_name":"ES1578A","location_id":"1896","lat":"43.3825","long":"-3.22056","pm25":""},{"location_name":"ES1579A","location_id":"1897","lat":"43.26444","long":"-4.06278","pm25":""},{"location_name":"ES1580A","location_id":"1898","lat":"43.46056","long":"-3.80861","pm25":""},{"location_name":"ES1588A","location_id":"1899","lat":"41.906647","long":"1.1929748","pm25":""},{"location_name":"ES1593A","location_id":"1901","lat":"36.46059","long":"-6.20307","pm25":""},{"location_name":"ES1595A","location_id":"1902","lat":"43.298332","long":"-2.9302778","pm25":""},{"location_name":"ES1596A","location_id":"1903","lat":"41.66639","long":"-4.715","pm25":""},{"location_name":"ES1597A","location_id":"1904","lat":"41.683334","long":"-4.7411113","pm25":""},{"location_name":"ES1598A","location_id":"1905","lat":"43.213055","long":"-3.1344445","pm25":""},{"location_name":"ES1599A","location_id":"1906","lat":"43.250557","long":"-2.155","pm25":""},{"location_name":"ES1601A","location_id":"1907","lat":"38.88763","long":"-7.01145","pm25":""},{"location_name":"ES1602A","location_id":"1908","lat":"42.46389","long":"-2.42778","pm25":""},{"location_name":"ES1604A","location_id":"1909","lat":"39.56332","long":"2.62055","pm25":""},{"location_name":"ES1610A","location_id":"1910","lat":"39.57008","long":"2.65583","pm25":""},{"location_name":"ES1611A","location_id":"1911","lat":"40.03328","long":"-3.5916445","pm25":""},{"location_name":"ES1612A","location_id":"1912","lat":"40.44778","long":"-3.86722","pm25":""},{"location_name":"ES1613A","location_id":"1913","lat":"40.66639","long":"-3.77222","pm25":""},{"location_name":"ES1615A","location_id":"1914","lat":"39.47278","long":"-6.36028","pm25":""},{"location_name":"ES1616A","location_id":"1915","lat":"39.84917","long":"-5.93972","pm25":""},{"location_name":"ES1617A","location_id":"1916","lat":"39.15","long":"-0.45777777","pm25":""},{"location_name":"ES1618A","location_id":"1917","lat":"40.979168","long":"-5.665278","pm25":""},{"location_name":"ES1619A","location_id":"1918","lat":"39.478054","long":"-0.36833334","pm25":""},{"location_name":"ES1620A","location_id":"1919","lat":"36.66086","long":"-6.11449","pm25":""},{"location_name":"ES1623A","location_id":"1920","lat":"38.70639","long":"-0.46694443","pm25":""},{"location_name":"ES1624A","location_id":"1921","lat":"38.24222","long":"-0.68277776","pm25":""},{"location_name":"ES1625A","location_id":"1922","lat":"39.509445","long":"-0.41777778","pm25":""},{"location_name":"ES1627A","location_id":"1923","lat":"37.975555","long":"-1.2308333","pm25":""},{"location_name":"ES1630A","location_id":"1924","lat":"37.34075","long":"-6.04246","pm25":""},{"location_name":"ES1631A","location_id":"1925","lat":"41.645557","long":"-4.7302775","pm25":""},{"location_name":"ES1632A","location_id":"1926","lat":"41.620556","long":"-4.7466664","pm25":""},{"location_name":"ES1633A","location_id":"1927","lat":"37.99361","long":"-1.1447222","pm25":""},{"location_name":"ES1634A","location_id":"1928","lat":"36.17315","long":"-5.34194","pm25":""},{"location_name":"ES1635A","location_id":"1929","lat":"38.359444","long":"-0.47194445","pm25":""},{"location_name":"ES1636A","location_id":"1930","lat":"41.656113","long":"-4.733889","pm25":""},{"location_name":"ES1637A","location_id":"1931","lat":"36.16174","long":"-5.44255","pm25":""},{"location_name":"ES1638A","location_id":"1932","lat":"37.34719","long":"-5.97963","pm25":""},{"location_name":"ES1640A","location_id":"1933","lat":"37.34246","long":"-5.83372","pm25":""},{"location_name":"ES1641A","location_id":"1934","lat":"41.63528","long":"-0.89361","pm25":""},{"location_name":"ES1642A","location_id":"1935","lat":"41.935665","long":"2.2385683","pm25":""},{"location_name":"ES1643A","location_id":"1936","lat":"41.766666","long":"-2.4666667","pm25":""},{"location_name":"ES1644A","location_id":"1937","lat":"37.38808","long":"-5.99149","pm25":""},{"location_name":"ES1645A","location_id":"1938","lat":"40.474724","long":"-3.575","pm25":""},{"location_name":"ES1648A","location_id":"1939","lat":"36.23386","long":"-5.6635","pm25":""},{"location_name":"ES1649A","location_id":"1940","lat":"42.17583","long":"-1.74333","pm25":""},{"location_name":"ES1651A","location_id":"1941","lat":"43.25612","long":"-5.77594","pm25":""},{"location_name":"ES1653A","location_id":"1942","lat":"37.28449","long":"-5.91384","pm25":""},{"location_name":"ES1654A","location_id":"1943","lat":"37.99435","long":"-5.66687","pm25":""},{"location_name":"ES1656A","location_id":"1944","lat":"37.78255","long":"-3.78157","pm25":""},{"location_name":"ES1658A","location_id":"1945","lat":"37.27148","long":"-6.92462","pm25":""},{"location_name":"ES1661A","location_id":"1946","lat":"42.07472","long":"-1.62694","pm25":""},{"location_name":"ES1662A","location_id":"1947","lat":"42.30833","long":"-1.80833","pm25":""},{"location_name":"ES1664A","location_id":"1948","lat":"36.13623","long":"-5.45343","pm25":""},{"location_name":"ES1666A","location_id":"1949","lat":"41.11739","long":"1.2416497","pm25":""},{"location_name":"ES1670A","location_id":"1950","lat":"39.558613","long":"-1.2813889","pm25":""},{"location_name":"ES1671A","location_id":"1951","lat":"39.708057","long":"-0.83194447","pm25":""},{"location_name":"ES1672A","location_id":"1952","lat":"42.518333","long":"-2.6194444","pm25":""},{"location_name":"ES1673A","location_id":"1953","lat":"42.843613","long":"-2.6613889","pm25":""},{"location_name":"ES1675A","location_id":"1954","lat":"38.57139","long":"-0.14666666","pm25":""},{"location_name":"ES1677A","location_id":"1955","lat":"38.08472","long":"-0.8527778","pm25":""},{"location_name":"ES1679A","location_id":"1956","lat":"41.386414","long":"2.1874168","pm25":""},{"location_name":"ES1684A","location_id":"1957","lat":"41.492085","long":"2.0424972","pm25":""},{"location_name":"ES1685A","location_id":"1958","lat":"40.051945","long":"-0.18972223","pm25":""},{"location_name":"ES1687A","location_id":"1959","lat":"40.06222","long":"0.07277777","pm25":""},{"location_name":"ES1688A","location_id":"1960","lat":"39.892223","long":"-0.065","pm25":""},{"location_name":"ES1689A","location_id":"1961","lat":"40.054165","long":"-0.46833333","pm25":""},{"location_name":"ES1690A","location_id":"1962","lat":"40.269444","long":"-0.07888888","pm25":""},{"location_name":"ES1691A","location_id":"1963","lat":"39.930557","long":"-0.60333335","pm25":""},{"location_name":"ES1697A","location_id":"1964","lat":"43.309444","long":"-2.011111","pm25":""},{"location_name":"ES1709A","location_id":"1965","lat":"38.934723","long":"-0.44138888","pm25":""},{"location_name":"ES1711A","location_id":"1966","lat":"38.788055","long":"-0.69722223","pm25":""},{"location_name":"ES1712A","location_id":"1967","lat":"43.299168","long":"-2.9872222","pm25":""},{"location_name":"ES1713A","location_id":"1968","lat":"43.255","long":"-2.9022222","pm25":""},{"location_name":"ES1718A","location_id":"1969","lat":"38.174397","long":"-3.01022","pm25":""},{"location_name":"ES1740A","location_id":"1970","lat":"42.81222","long":"-1.64","pm25":""},{"location_name":"ES1741A","location_id":"1971","lat":"27.763653","long":"-15.563851","pm25":""},{"location_name":"ES1742A","location_id":"1972","lat":"27.772598","long":"-15.541881","pm25":""},{"location_name":"ES1744A","location_id":"1973","lat":"27.86907","long":"-15.38715","pm25":""},{"location_name":"ES1745A","location_id":"1974","lat":"27.897638","long":"-15.445028","pm25":""},{"location_name":"ES1746A","location_id":"1975","lat":"42.34167","long":"-2.23167","pm25":""},{"location_name":"ES1747A","location_id":"1976","lat":"42.82694","long":"-1.64944","pm25":""},{"location_name":"ES1749A","location_id":"1977","lat":"42.89444","long":"-2.16583","pm25":""},{"location_name":"ES1750A","location_id":"1978","lat":"36.71964","long":"-4.4475","pm25":""},{"location_name":"ES1751A","location_id":"1979","lat":"36.72956","long":"-4.46553","pm25":""},{"location_name":"ES1752A","location_id":"1980","lat":"40.455","long":"-3.48417","pm25":""},{"location_name":"ES1753A","location_id":"1981","lat":"42.34","long":"-2.05972","pm25":""},{"location_name":"ES1754A","location_id":"1982","lat":"40.643005","long":"0.28844598","pm25":""},{"location_name":"ES1755A","location_id":"1983","lat":"42.58056","long":"-1.2825","pm25":""},{"location_name":"ES1756A","location_id":"1984","lat":"28.376713","long":"-16.361929","pm25":""},{"location_name":"ES1759A","location_id":"1985","lat":"28.451021","long":"-16.277693","pm25":""},{"location_name":"ES1760A","location_id":"1986","lat":"28.112486","long":"-16.577578","pm25":""},{"location_name":"ES1761A","location_id":"1987","lat":"28.080008","long":"-16.559855","pm25":""},{"location_name":"ES1762A","location_id":"1988","lat":"28.047333","long":"-16.536049","pm25":""},{"location_name":"ES1763A","location_id":"1989","lat":"27.801277","long":"-15.461157","pm25":""},{"location_name":"ES1764A","location_id":"1990","lat":"28.380537","long":"-16.371986","pm25":""},{"location_name":"ES1765A","location_id":"1991","lat":"39.684723","long":"-0.27888888","pm25":""},{"location_name":"ES1766A","location_id":"1992","lat":"28.145094","long":"-16.523687","pm25":""},{"location_name":"ES1767A","location_id":"1993","lat":"28.07255","long":"-16.653023","pm25":""},{"location_name":"ES1768A","location_id":"1994","lat":"28.007738","long":"-16.655912","pm25":""},{"location_name":"ES1769A","location_id":"1995","lat":"28.111374","long":"-16.471624","pm25":""},{"location_name":"ES1772A","location_id":"1996","lat":"28.393408","long":"-16.3581","pm25":""},{"location_name":"ES1773A","location_id":"1997","lat":"41.202232","long":"1.6722","pm25":""},{"location_name":"ES1778A","location_id":"1998","lat":"41.779343","long":"2.3580189","pm25":""},{"location_name":"ES1779A","location_id":"1999","lat":"42.43889","long":"-2.25028","pm25":""},{"location_name":"ES1781A","location_id":"2000","lat":"36.68855","long":"-6.11724","pm25":""},{"location_name":"ES1785A","location_id":"2001","lat":"36.9231","long":"-2.46322","pm25":""},{"location_name":"ES1786A","location_id":"2002","lat":"36.86495","long":"-2.3905","pm25":""},{"location_name":"ES1790A","location_id":"2003","lat":"42.542778","long":"-6.584722","pm25":""},{"location_name":"ES1792A","location_id":"2004","lat":"37.13379","long":"-6.80745","pm25":""},{"location_name":"ES1793A","location_id":"2005","lat":"37.10409","long":"-6.73408","pm25":""},{"location_name":"ES1799A","location_id":"2006","lat":"37.89261","long":"-4.76234","pm25":""},{"location_name":"ES1800A","location_id":"2007","lat":"37.90274","long":"-4.77958","pm25":""},{"location_name":"ES1801A","location_id":"2008","lat":"40.30083","long":"-3.45889","pm25":""},{"location_name":"ES1802A","location_id":"2009","lat":"40.91028","long":"-3.46667","pm25":""},{"location_name":"ES1803A","location_id":"2010","lat":"40.63389","long":"-4.01333","pm25":""},{"location_name":"ES1805A","location_id":"2011","lat":"40.78083","long":"-3.7025","pm25":""},{"location_name":"ES1806A","location_id":"2012","lat":"40.28694","long":"-3.22222","pm25":""},{"location_name":"ES1807A","location_id":"2013","lat":"40.35853","long":"-3.54414","pm25":""},{"location_name":"ES1808A","location_id":"2014","lat":"40.36889","long":"-4.39694","pm25":""},{"location_name":"ES1809A","location_id":"2015","lat":"40.18528","long":"-3.67972","pm25":""},{"location_name":"ES1810A","location_id":"2016","lat":"40.25194","long":"-4.27472","pm25":""},{"location_name":"ES1811A","location_id":"2017","lat":"40.16722","long":"-3.27667","pm25":""},{"location_name":"ES1812A","location_id":"2018","lat":"41.27838","long":"1.1799166","pm25":""},{"location_name":"ES1813A","location_id":"2019","lat":"41.100693","long":"0.7551003","pm25":""},{"location_name":"ES1814A","location_id":"2020","lat":"41.549168","long":"2.21205","pm25":""},{"location_name":"ES1815A","location_id":"2021","lat":"41.346825","long":"1.6865755","pm25":""},{"location_name":"ES1816A","location_id":"2022","lat":"41.54716","long":"2.4432538","pm25":""},{"location_name":"ES1817A","location_id":"2023","lat":"41.526707","long":"2.1837952","pm25":""},{"location_name":"ES1818A","location_id":"2024","lat":"39.86806","long":"-4.02083","pm25":""},{"location_name":"ES1819A","location_id":"2025","lat":"38.9075","long":"-6.33806","pm25":""},{"location_name":"ES1820A","location_id":"2026","lat":"38.42917","long":"-6.395","pm25":""},{"location_name":"ES1821A","location_id":"2027","lat":"36.73975","long":"-5.74372","pm25":""},{"location_name":"ES1822A","location_id":"2028","lat":"36.79449","long":"-5.53162","pm25":""},{"location_name":"ES1824A","location_id":"2029","lat":"37.78444","long":"-3.81032","pm25":""},{"location_name":"ES1825A","location_id":"2030","lat":"38.99323","long":"1.30894","pm25":""},{"location_name":"ES1826A","location_id":"2031","lat":"39.551388","long":"-0.46083334","pm25":""},{"location_name":"ES1827A","location_id":"2032","lat":"39.67766","long":"2.68665","pm25":""},{"location_name":"ES1828A","location_id":"2033","lat":"40.00944","long":"3.85648","pm25":""},{"location_name":"ES1829A","location_id":"2034","lat":"39.6331","long":"2.63044","pm25":""},{"location_name":"ES1831A","location_id":"2035","lat":"38.93492","long":"1.43181","pm25":""},{"location_name":"ES1834A","location_id":"2038","lat":"39.988888","long":"-0.02611111","pm25":""},{"location_name":"ES1835A","location_id":"2039","lat":"36.95","long":"-1.96148","pm25":""},{"location_name":"ES1836A","location_id":"2040","lat":"41.64222","long":"-0.86194","pm25":""},{"location_name":"ES1837A","location_id":"2041","lat":"41.64833","long":"-0.88389","pm25":""},{"location_name":"ES1838A","location_id":"2042","lat":"40.59333","long":"-3.50306","pm25":""},{"location_name":"ES1845A","location_id":"2043","lat":"36.99678","long":"-1.89535","pm25":""},{"location_name":"ES1849A","location_id":"2044","lat":"38.259167","long":"-0.7175","pm25":""},{"location_name":"ES1851A","location_id":"2045","lat":"42.09791","long":"1.8482373","pm25":""},{"location_name":"ES1853A","location_id":"2046","lat":"41.24489","long":"1.6177046","pm25":""},{"location_name":"ES1854A","location_id":"2047","lat":"41.008213","long":"0.8310847","pm25":""},{"location_name":"ES1855A","location_id":"2048","lat":"41.009506","long":"0.91287583","pm25":""},{"location_name":"ES1856A","location_id":"2049","lat":"41.42608","long":"2.1479921","pm25":""},{"location_name":"ES1857A","location_id":"2050","lat":"38.99389","long":"-3.93778","pm25":""},{"location_name":"ES1858A","location_id":"2051","lat":"40.06185","long":"-2.12972","pm25":""},{"location_name":"ES1859A","location_id":"2052","lat":"39.95856","long":"-4.8457","pm25":""},{"location_name":"ES1860A","location_id":"2053","lat":"37.55502","long":"-6.03616","pm25":""},{"location_name":"ES1863A","location_id":"2054","lat":"28.97699","long":"-13.547584","pm25":""},{"location_name":"ES1864A","location_id":"2055","lat":"28.99031","long":"-13.51655","pm25":""},{"location_name":"ES1865A","location_id":"2056","lat":"28.500256","long":"-13.852395","pm25":""},{"location_name":"ES1866A","location_id":"2057","lat":"28.502762","long":"-13.8537","pm25":""},{"location_name":"ES1867A","location_id":"2058","lat":"43.480556","long":"-8.241389","pm25":""},{"location_name":"ES1868A","location_id":"2059","lat":"42.87583","long":"-8.559167","pm25":""},{"location_name":"ES1869A","location_id":"2060","lat":"40.43","long":"-3.54583","pm25":""},{"location_name":"ES1877A","location_id":"2061","lat":"39.94528","long":"-0.05638888","pm25":""},{"location_name":"ES1878A","location_id":"2062","lat":"37.0161","long":"-6.57042","pm25":""},{"location_name":"ES1879A","location_id":"2063","lat":"41.22528","long":"-0.36472","pm25":""},{"location_name":"ES1882A","location_id":"2064","lat":"38.114723","long":"-1.8686111","pm25":""},{"location_name":"ES1883A","location_id":"2065","lat":"42.45778","long":"0.18194","pm25":""},{"location_name":"ES1884A","location_id":"2066","lat":"39.634167","long":"-0.26583332","pm25":""},{"location_name":"ES1885A","location_id":"2067","lat":"39.480278","long":"-0.3363889","pm25":""},{"location_name":"ES1886A","location_id":"2068","lat":"39.427223","long":"-0.7838889","pm25":""},{"location_name":"ES1889A","location_id":"2069","lat":"40.960835","long":"-5.6397223","pm25":""},{"location_name":"ES1890A","location_id":"2070","lat":"40.34194","long":"-3.83389","pm25":""},{"location_name":"ES1891A","location_id":"2071","lat":"41.598667","long":"2.2871177","pm25":""},{"location_name":"ES1892A","location_id":"2072","lat":"41.443985","long":"2.2378752","pm25":""},{"location_name":"ES1897A","location_id":"2073","lat":"36.72785","long":"-4.56095","pm25":""},{"location_name":"ES1898A","location_id":"2074","lat":"36.9623","long":"-4.84483","pm25":""},{"location_name":"ES1899A","location_id":"2075","lat":"41.308403","long":"1.6473399","pm25":""},{"location_name":"ES1901A","location_id":"2076","lat":"42.88778","long":"-8.530833","pm25":""},{"location_name":"ES1903A","location_id":"2077","lat":"41.313477","long":"2.0138247","pm25":""},{"location_name":"ES1905A","location_id":"2078","lat":"42.998055","long":"-7.55","pm25":""},{"location_name":"ES1910A","location_id":"2079","lat":"41.303112","long":"1.991524","pm25":""},{"location_name":"ES1911A","location_id":"2080","lat":"39.705276","long":"-0.33666667","pm25":""},{"location_name":"ES1912A","location_id":"2081","lat":"39.4575","long":"-0.34277776","pm25":""},{"location_name":"ES1913A","location_id":"2082","lat":"38.451668","long":"-1.0647222","pm25":""},{"location_name":"ES1914A","location_id":"2083","lat":"38.454723","long":"-0.80333334","pm25":""},{"location_name":"ES1915A","location_id":"2084","lat":"38.34028","long":"-0.50666666","pm25":""},{"location_name":"ES1917A","location_id":"2085","lat":"40.099445","long":"-1.2538888","pm25":""},{"location_name":"ES1919A","location_id":"2086","lat":"28.003645","long":"-15.411851","pm25":""},{"location_name":"ES1920A","location_id":"2087","lat":"28.33722","long":"-16.39972","pm25":""},{"location_name":"ES1921A","location_id":"2088","lat":"37.603054","long":"-0.9752778","pm25":""},{"location_name":"ES1922A","location_id":"2089","lat":"42.019444","long":"-4.5383334","pm25":""},{"location_name":"ES1923A","location_id":"2090","lat":"41.846035","long":"2.2175756","pm25":""},{"location_name":"ES1924A","location_id":"2091","lat":"37.16568","long":"-3.6001","pm25":""},{"location_name":"ES1925A","location_id":"2092","lat":"36.1801","long":"-5.3825","pm25":""},{"location_name":"ES1927A","location_id":"2093","lat":"41.509724","long":"-5.746389","pm25":""},{"location_name":"ES1929A","location_id":"2094","lat":"41.321495","long":"2.0977252","pm25":""},{"location_name":"ES1930A","location_id":"2095","lat":"40.902695","long":"0.80979544","pm25":""},{"location_name":"ES1937A","location_id":"2096","lat":"40.398056","long":"-3.6866667","pm25":""},{"location_name":"ES1938A","location_id":"2097","lat":"40.439724","long":"-3.6902778","pm25":""},{"location_name":"ES1939A","location_id":"2098","lat":"40.40972","long":"-3.6855555","pm25":""},{"location_name":"ES1940A","location_id":"2099","lat":"40.46583","long":"-3.6883333","pm25":""},{"location_name":"ES1941A","location_id":"2100","lat":"40.372776","long":"-3.6119444","pm25":""},{"location_name":"ES1942A","location_id":"2101","lat":"40.4625","long":"-3.5805554","pm25":""},{"location_name":"ES1943A","location_id":"2102","lat":"40.384724","long":"-3.718611","pm25":""},{"location_name":"ES1944A","location_id":"2103","lat":"40.494167","long":"-3.6602778","pm25":""},{"location_name":"ES1945A","location_id":"2104","lat":"40.518055","long":"-3.7744443","pm25":""},{"location_name":"ES1946A","location_id":"2105","lat":"40.465","long":"-3.6088889","pm25":""},{"location_name":"ES1947A","location_id":"2106","lat":"40.500557","long":"-3.6897223","pm25":""},{"location_name":"ES1948A","location_id":"2107","lat":"40.939552","long":"0.831337","pm25":""},{"location_name":"ES1952A","location_id":"2108","lat":"28.111265","long":"-15.520924","pm25":""},{"location_name":"ES1954A","location_id":"2109","lat":"28.383097","long":"-16.57067","pm25":""},{"location_name":"ES1955A","location_id":"2110","lat":"28.96787","long":"-13.555856","pm25":""},{"location_name":"ES1956A","location_id":"2111","lat":"28.645395","long":"-17.771555","pm25":""},{"location_name":"ES1963A","location_id":"2112","lat":"40.11922","long":"-3.83279","pm25":""},{"location_name":"ES1964A","location_id":"2113","lat":"41.38664","long":"2.0573926","pm25":""},{"location_name":"ES1967A","location_id":"2114","lat":"40.955555","long":"-4.1105556","pm25":""},{"location_name":"ES1968A","location_id":"2115","lat":"38.351112","long":"-0.5138889","pm25":""},{"location_name":"ES1969A","location_id":"2116","lat":"39.823612","long":"-0.24444444","pm25":""},{"location_name":"ES1970A","location_id":"2117","lat":"39.45028","long":"-0.3963889","pm25":""},{"location_name":"ES1971A","location_id":"2118","lat":"38.13793","long":"-4.90397","pm25":""},{"location_name":"ES1972A","location_id":"2119","lat":"38.13246","long":"-4.80173","pm25":""},{"location_name":"ES1973A","location_id":"2120","lat":"37.13556","long":"-3.61925","pm25":""},{"location_name":"ES1974A","location_id":"2121","lat":"43.516586","long":"-5.67065","pm25":""},{"location_name":"ES1975A","location_id":"2122","lat":"28.45816","long":"-16.278776","pm25":""},{"location_name":"ES1976A","location_id":"2123","lat":"28.461788","long":"-16.27662","pm25":""},{"location_name":"ES1977A","location_id":"2124","lat":"27.89833","long":"-15.48833","pm25":""},{"location_name":"ES1978A","location_id":"2125","lat":"28.49838","long":"-13.86083","pm25":""},{"location_name":"ES1979A","location_id":"2126","lat":"28.667711","long":"-17.775553","pm25":""},{"location_name":"ES1980A","location_id":"2127","lat":"28.685984","long":"-17.764587","pm25":""},{"location_name":"ES1982A","location_id":"2128","lat":"42.051342","long":"0.72955567","pm25":""},{"location_name":"ES1983A","location_id":"2129","lat":"41.32177","long":"2.0821407","pm25":""},{"location_name":"ES1986A","location_id":"2130","lat":"41.665554","long":"-3.6888888","pm25":""},{"location_name":"ES1987A","location_id":"2131","lat":"42.951946","long":"-3.4752777","pm25":""},{"location_name":"ES1988A","location_id":"2132","lat":"42.57528","long":"-5.566389","pm25":""},{"location_name":"ES1989A","location_id":"2133","lat":"43.04139","long":"-5.089722","pm25":""},{"location_name":"ES1990A","location_id":"2134","lat":"40.56972","long":"-6.223889","pm25":""},{"location_name":"ES1991A","location_id":"2135","lat":"41.72361","long":"-2.8569443","pm25":""},{"location_name":"ES1992A","location_id":"2136","lat":"41.387486","long":"2.1151497","pm25":""},{"location_name":"ES1995A","location_id":"2137","lat":"39.54588","long":"2.69971","pm25":""},{"location_name":"ES1996A","location_id":"2138","lat":"37.19342","long":"-1.9854","pm25":""},{"location_name":"ES1997A","location_id":"2139","lat":"40.07778","long":"-6.14722","pm25":""},{"location_name":"ES1999A","location_id":"2140","lat":"41.976387","long":"2.8165474","pm25":""},{"location_name":"ES2000A","location_id":"2141","lat":"28.457954","long":"-16.26333","pm25":""},{"location_name":"ES2001A","location_id":"2142","lat":"39.260834","long":"-0.9344444","pm25":""},{"location_name":"ES2002A","location_id":"2143","lat":"28.52722","long":"-14.00444","pm25":""},{"location_name":"ES2003A","location_id":"2144","lat":"28.455376","long":"-16.27675","pm25":""},{"location_name":"ES2004A","location_id":"2145","lat":"28.026318","long":"-15.414657","pm25":""},{"location_name":"ES2007A","location_id":"2146","lat":"37.574444","long":"-0.9266667","pm25":""},{"location_name":"ES2008A","location_id":"2147","lat":"37.99111","long":"-0.69","pm25":""},{"location_name":"ES2010A","location_id":"2148","lat":"41.63","long":"-4.740556","pm25":""},{"location_name":"ES2011A","location_id":"2149","lat":"41.400772","long":"1.9996347","pm25":""},{"location_name":"ES2012A","location_id":"2150","lat":"41.415318","long":"1.9905212","pm25":""},{"location_name":"ES2014A","location_id":"2151","lat":"42.06167","long":"-7.4085417","pm25":""},{"location_name":"ES2015A","location_id":"2152","lat":"42.181427","long":"-8.523931","pm25":""},{"location_name":"ES2017A","location_id":"2153","lat":"40.55282","long":"0.5299825","pm25":""},{"location_name":"ES2018A","location_id":"2154","lat":"39.782223","long":"-0.35916665","pm25":""},{"location_name":"ES2019A","location_id":"2155","lat":"39.564724","long":"-0.6255556","pm25":""},{"location_name":"ES2020A","location_id":"2156","lat":"28.45666","long":"-16.271835","pm25":""},{"location_name":"ES2021A","location_id":"2157","lat":"28.46301","long":"-16.26488","pm25":""},{"location_name":"ES2022A","location_id":"2158","lat":"28.38016","long":"-16.36833","pm25":""},{"location_name":"ES2023A","location_id":"2159","lat":"28.8051","long":"-17.78255","pm25":""},{"location_name":"ES2024A","location_id":"2160","lat":"27.831766","long":"-17.92167","pm25":""},{"location_name":"ES2025A","location_id":"2161","lat":"28.50616","long":"-13.84898","pm25":""},{"location_name":"ES2026A","location_id":"2162","lat":"36.8951","long":"-2.04672","pm25":""},{"location_name":"ES2028A","location_id":"2163","lat":"40.31285","long":"-3.71724","pm25":""},{"location_name":"ES2029A","location_id":"2164","lat":"40.66472","long":"-4.70083","pm25":""},{"location_name":"ES2030A","location_id":"2165","lat":"36.511","long":"-4.863","pm25":""},{"location_name":"ES2031A","location_id":"2166","lat":"36.7073","long":"-4.446","pm25":""},{"location_name":"ES2034A","location_id":"2167","lat":"41.544106","long":"0.82993317","pm25":""},{"location_name":"ES2038A","location_id":"2169","lat":"28.459314","long":"-16.270206","pm25":""},{"location_name":"ES2040A","location_id":"2170","lat":"37.1388","long":"-1.8422","pm25":""},{"location_name":"ES2041A","location_id":"2171","lat":"41.91614","long":"0.191101","pm25":""},{"location_name":"ES2042A","location_id":"2172","lat":"41.61417","long":"-4.77222","pm25":""},{"location_name":"ES2044A","location_id":"2173","lat":"28.09905","long":"-17.12051","pm25":""},{"location_name":"ES2047A","location_id":"2174","lat":"37.8926","long":"-4.7801","pm25":""},{"location_name":"ES2051A","location_id":"2175","lat":"43.4015","long":"-5.80287","pm25":""},{"location_name":"ES2053A","location_id":"2176","lat":"28.09012","long":"-17.1181","pm25":""},{"location_name":"ES2054A","location_id":"2177","lat":"43.57045","long":"-5.95828","pm25":""},{"location_name":"ES2058A","location_id":"2179","lat":"43.2553","long":"-2.97344","pm25":""},{"location_name":"ES2061A","location_id":"2180","lat":"42.71648","long":"-8.644105","pm25":""},{"location_name":"ES2063A","location_id":"2181","lat":"42.2224","long":"-8.711082","pm25":""},{"location_name":"ES2064A","location_id":"2182","lat":"41.65917","long":"-0.9068","pm25":""},{"location_name":"ES2065A","location_id":"2183","lat":"39.830235","long":"2.9007194","pm25":""},{"location_name":"ES2066A","location_id":"2184","lat":"36.9581","long":"-2.1592","pm25":""},{"location_name":"ES2067A","location_id":"2185","lat":"37.0047","long":"-1.9344","pm25":""},{"location_name":"ES2068A","location_id":"2186","lat":"43.0819","long":"-1.9127","pm25":""},{"location_name":"ES2069A","location_id":"2187","lat":"43.5229","long":"-5.689452","pm25":""},{"location_name":"ES2074A","location_id":"2188","lat":"28.47544","long":"-16.25853","pm25":""},{"location_name":"ES2075A","location_id":"2189","lat":"43.34565","long":"-5.96967","pm25":""},{"location_name":"EST-HOSP - La Estrella - Hospital","location_id":"2190","lat":"6.1555305","long":"-75.64417","pm25":""},{"location_name":"ETOWN2","location_id":"2191","lat":"37.7064","long":"-85.8517","pm25":""},{"location_name":"Eagle Mountain Lake","location_id":"2194","lat":"32.9881","long":"-97.4764","pm25":""},{"location_name":"Ealing Horn Lane","location_id":"2196","lat":"51.51895","long":"-0.265617","pm25":""},{"location_name":"Earlwood","location_id":"2197","lat":"-33.917778","long":"151.13472","pm25":""},{"location_name":"East Chicago Post Of","location_id":"2200","lat":"41.628613","long":"-87.46139","pm25":""},{"location_name":"East Hartford","location_id":"2201","lat":"41.7847","long":"-72.6297","pm25":""},{"location_name":"East High School","location_id":"2202","lat":"41.063526","long":"-81.468956","pm25":""},{"location_name":"East Liverpool","location_id":"2203","lat":"40.631973","long":"-80.547295","pm25":""},{"location_name":"Eastbourne","location_id":"2206","lat":"50.80578","long":"0.271611","pm25":""},{"location_name":"Eastern","location_id":"2207","lat":"22.282778","long":"114.219444","pm25":""},{"location_name":"Eastlake","location_id":"2208","lat":"41.673004","long":"-81.422455","pm25":""},{"location_name":"Eastman Ross N Robin","location_id":"2209","lat":"36.532616","long":"-82.516304","pm25":""},{"location_name":"Eau Claire","location_id":"2212","lat":"44.7614","long":"-91.413","pm25":""},{"location_name":"Edgar Evins","location_id":"2215","lat":"36.0388","long":"-85.7331","pm25":""},{"location_name":"Edgewood","location_id":"2216","lat":"39.41","long":"-76.2967","pm25":""},{"location_name":"Edinburgh St Leonards","location_id":"2217","lat":"55.945587","long":"-3.182186","pm25":""},{"location_name":"Edison","location_id":"2218","lat":"35.345608","long":"-118.85182","pm25":""},{"location_name":"Edmonton Central","location_id":"2219","lat":"53.5453","long":"-113.4992","pm25":""},{"location_name":"Edmonton East","location_id":"2220","lat":"53.5472","long":"-113.3681","pm25":""},{"location_name":"Edmonton South","location_id":"2221","lat":"53.5028","long":"-113.6111","pm25":""},{"location_name":"Edmonton Woodcroft","location_id":"2222","lat":"53.56441","long":"-113.562584","pm25":""},{"location_name":"Edson","location_id":"2223","lat":"53.5936","long":"-116.3928","pm25":""},{"location_name":"Eibergen-Lintveldseweg","location_id":"2224","lat":"52.0918","long":"6.60537","pm25":""},{"location_name":"Eilif Dues vei","location_id":"2225","lat":"59.90608","long":"10.61195","pm25":""},{"location_name":"Eindhoven-Genovevalaan","location_id":"2226","lat":"51.4687","long":"5.47235","pm25":""},{"location_name":"Eindhoven-Noordbrabantlaan","location_id":"2227","lat":"51.4442","long":"5.44483","pm25":""},{"location_name":"Eisenhower Park","location_id":"2228","lat":"40.7447","long":"-73.5869","pm25":""},{"location_name":"El Bosque","location_id":"2232","lat":"-33.5471","long":"-70.66621","pm25":""},{"location_name":"El Cajon - Lexington","location_id":"2235","lat":"32.789562","long":"-116.94422","pm25":""},{"location_name":"El Centro - 9th Stre","location_id":"2237","lat":"32.7917","long":"-115.5617","pm25":""},{"location_name":"El Paso UTEP C12","location_id":"2239","lat":"31.768057","long":"-106.501114","pm25":""},{"location_name":"El Rio - Rio Mesa Sc","location_id":"2240","lat":"34.2653","long":"-119.1336","pm25":""},{"location_name":"Elgeseter","location_id":"2243","lat":"63.41924","long":"10.395945","pm25":""},{"location_name":"Eliza Howell- Roadwa","location_id":"2246","lat":"42.38599","long":"-83.26632","pm25":""},{"location_name":"Elizabeth","location_id":"2247","lat":"40.662388","long":"-74.21481","pm25":""},{"location_name":"Elizabeth Trailer","location_id":"2248","lat":"40.64144","long":"-74.20837","pm25":""},{"location_name":"Elk Grove","location_id":"2249","lat":"38.30259","long":"-121.42084","pm25":""},{"location_name":"Elk Island","location_id":"2250","lat":"53.6825","long":"-112.8686","pm25":""},{"location_name":"Elkhart-Prairie St.","location_id":"2252","lat":"41.656944","long":"-85.96833","pm25":""},{"location_name":"Elko","location_id":"2254","lat":"40.83833","long":"-115.76601","pm25":""},{"location_name":"Ellensburg-Ruby St","location_id":"2255","lat":"46.9936","long":"-120.545","pm25":""},{"location_name":"Ellyson Industrial P","location_id":"2256","lat":"30.525","long":"-87.2044","pm25":""},{"location_name":"Eloy","location_id":"2257","lat":"32.75764","long":"-111.55486","pm25":""},{"location_name":"Ely","location_id":"2258","lat":"47.9464","long":"-91.4953","pm25":""},{"location_name":"Emmetsburg, ILCC","location_id":"2260","lat":"43.1233","long":"-94.6933","pm25":""},{"location_name":"Emporia","location_id":"2261","lat":"40.0025","long":"-85.6569","pm25":""},{"location_name":"Enoch","location_id":"2265","lat":"37.747444","long":"-113.05553","pm25":""},{"location_name":"Enschede-Winkelhorst","location_id":"2266","lat":"52.2345","long":"6.91949","pm25":""},{"location_name":"Enterprise - US Fore","location_id":"2267","lat":"45.42635","long":"-117.29607","pm25":""},{"location_name":"Environment Park","location_id":"2269","lat":"-19.2629","long":"146.831","pm25":""},{"location_name":"Erda","location_id":"2272","lat":"40.600555","long":"-112.355","pm25":""},{"location_name":"Erie","location_id":"2278","lat":"41.644066","long":"-83.54625","pm25":""},{"location_name":"Eskdalemuir","location_id":"2281","lat":"55.31531","long":"-3.206111","pm25":""},{"location_name":"Essex","location_id":"2282","lat":"39.310833","long":"-76.47444","pm25":""},{"location_name":"Estaci\u00f3n Abasolo","location_id":"2283","lat":"20.450916","long":"-101.52869","pm25":""},{"location_name":"Estaci\u00f3n Bomberos","location_id":"2284","lat":"20.67495","long":"-101.35595","pm25":""},{"location_name":"Estaci\u00f3n CICEG","location_id":"2285","lat":"21.10179","long":"-101.6347","pm25":""},{"location_name":"Estaci\u00f3n Centro","location_id":"2286","lat":"-22.462145","long":"-68.92806","pm25":""},{"location_name":"Estaci\u00f3n Cruz Roja","location_id":"2287","lat":"20.578558","long":"-101.19886","pm25":""},{"location_name":"Estaci\u00f3n DIF","location_id":"2288","lat":"20.558153","long":"-101.20485","pm25":""},{"location_name":"Estaci\u00f3n Facultad de","location_id":"2289","lat":"21.133894","long":"-101.68025","pm25":""},{"location_name":"Estaci\u00f3n Guanajuato","location_id":"2290","lat":"21.017675","long":"-101.257515","pm25":""},{"location_name":"Estaci\u00f3n Hospital Ge","location_id":"2291","lat":"20.9479","long":"-101.4258","pm25":""},{"location_name":"Estaci\u00f3n Nativitas","location_id":"2292","lat":"20.565228","long":"-101.18824","pm25":""},{"location_name":"Estaci\u00f3n Pur\u00edsima de","location_id":"2293","lat":"21.03439","long":"-101.866585","pm25":""},{"location_name":"Estaci\u00f3n San Juanico","location_id":"2294","lat":"20.537683","long":"-100.83994","pm25":""},{"location_name":"Estaci\u00f3n San Luis de","location_id":"2295","lat":"21.298874","long":"-100.51557","pm25":""},{"location_name":"Estaci\u00f3n San Miguel","location_id":"2296","lat":"20.914812","long":"-100.74384","pm25":""},{"location_name":"Estaci\u00f3n Secundaria","location_id":"2297","lat":"20.6924","long":"-101.36487","pm25":""},{"location_name":"Estaci\u00f3n Seguridad P","location_id":"2298","lat":"20.518316","long":"-100.81591","pm25":""},{"location_name":"Estaci\u00f3n T21","location_id":"2299","lat":"21.108683","long":"-101.68863","pm25":""},{"location_name":"Estaci\u00f3n Tecnol\u00f3gico","location_id":"2300","lat":"20.545427","long":"-100.80707","pm25":""},{"location_name":"Estaci\u00f3n Te\u00f3dula","location_id":"2301","lat":"20.65794","long":"-101.34915","pm25":""},{"location_name":"Eugene - Amazon Park","location_id":"2303","lat":"44.0263","long":"-123.08377","pm25":""},{"location_name":"Eugene - Highway 99","location_id":"2304","lat":"44.067223","long":"-123.14135","pm25":""},{"location_name":"Eugene - Wilkes Dr.","location_id":"2305","lat":"44.1158","long":"-123.12107","pm25":""},{"location_name":"Evansville-Buena Vis","location_id":"2307","lat":"38.0133","long":"-87.5772","pm25":""},{"location_name":"Evansville-Lloyd","location_id":"2308","lat":"37.977222","long":"-87.59639","pm25":""},{"location_name":"Exeter Roadside","location_id":"2311","lat":"50.725082","long":"-3.532465","pm25":""},{"location_name":"Experimental Lakes","location_id":"2312","lat":"49.6639","long":"-93.7211","pm25":""},{"location_name":"FAB","location_id":"2313","lat":"39.9603","long":"-75.1424","pm25":""},{"location_name":"FBHWWTP","location_id":"2316","lat":"30.6575","long":"-81.464165","pm25":""},{"location_name":"FEBBIO","location_id":"2317","lat":"44.3007","long":"10.431","pm25":""},{"location_name":"FI00027","location_id":"2321","lat":"64.99473","long":"25.47926","pm25":""},{"location_name":"FI00066","location_id":"2322","lat":"60.98781","long":"25.64954","pm25":""},{"location_name":"FI00080","location_id":"2324","lat":"61.23807","long":"28.87369","pm25":""},{"location_name":"FI00179","location_id":"2325","lat":"61.33169","long":"22.1433","pm25":""},{"location_name":"FI00184","location_id":"2326","lat":"61.31495","long":"22.13671","pm25":""},{"location_name":"FI00208","location_id":"2328","lat":"60.313595","long":"24.689476","pm25":""},{"location_name":"FI00273","location_id":"2329","lat":"61.12838","long":"28.83776","pm25":""},{"location_name":"FI00280","location_id":"2330","lat":"61.05748","long":"28.24585","pm25":""},{"location_name":"FI00283","location_id":"2331","lat":"61.04082","long":"28.1765","pm25":""},{"location_name":"FI00301","location_id":"2332","lat":"65.04338","long":"25.4979","pm25":""},{"location_name":"FI00339","location_id":"2333","lat":"60.36005","long":"25.56605","pm25":""},{"location_name":"FI00349","location_id":"2334","lat":"59.77923","long":"21.37395","pm25":""},{"location_name":"FI00352","location_id":"2335","lat":"66.3217","long":"29.40157","pm25":""},{"location_name":"FI00356","location_id":"2336","lat":"67.96735","long":"24.112219","pm25":""},{"location_name":"FI00357","location_id":"2337","lat":"68.47701","long":"28.3031","pm25":""},{"location_name":"FI00370","location_id":"2339","lat":"60.28995","long":"25.03953","pm25":""},{"location_name":"FI00378","location_id":"2340","lat":"61.07194","long":"28.26409","pm25":""},{"location_name":"FI00397","location_id":"2341","lat":"63.67912","long":"22.71837","pm25":""},{"location_name":"FI00404","location_id":"2342","lat":"63.83764","long":"23.1316","pm25":""},{"location_name":"FI00424","location_id":"2343","lat":"61.18892","long":"28.77012","pm25":""},{"location_name":"FI00425","location_id":"2344","lat":"60.18739","long":"24.9506","pm25":""},{"location_name":"FI00428","location_id":"2345","lat":"63.1431","long":"31.04695","pm25":""},{"location_name":"FI00431","location_id":"2346","lat":"62.28999","long":"25.70917","pm25":""},{"location_name":"FI00433","location_id":"2347","lat":"61.15304","long":"28.81014","pm25":""},{"location_name":"FI00434","location_id":"2348","lat":"61.11709","long":"28.49849","pm25":""},{"location_name":"FI00438","location_id":"2349","lat":"60.51316","long":"26.94621","pm25":""},{"location_name":"FI00446","location_id":"2350","lat":"65.00997","long":"25.47132","pm25":""},{"location_name":"FI00455","location_id":"2351","lat":"60.96704","long":"25.65489","pm25":""},{"location_name":"FI00460","location_id":"2352","lat":"60.42532","long":"22.09611","pm25":""},{"location_name":"FI00465","location_id":"2354","lat":"63.09515","long":"21.61832","pm25":""},{"location_name":"FI00549","location_id":"2355","lat":"61.49873","long":"23.73569","pm25":""},{"location_name":"FI00558","location_id":"2356","lat":"62.8935","long":"27.6883","pm25":""},{"location_name":"FI00564","location_id":"2357","lat":"60.16964","long":"24.93924","pm25":""},{"location_name":"FI00570","location_id":"2358","lat":"64.68337","long":"24.48162","pm25":""},{"location_name":"FI00586","location_id":"2359","lat":"63.10121","long":"21.60407","pm25":""},{"location_name":"FI00606","location_id":"2361","lat":"61.05576","long":"28.18431","pm25":""},{"location_name":"FI00621","location_id":"2362","lat":"61.86111","long":"24.28333","pm25":""},{"location_name":"FI00761","location_id":"2363","lat":"60.25145","long":"24.06287","pm25":""},{"location_name":"FI00781","location_id":"2364","lat":"60.22393","long":"25.10244","pm25":""},{"location_name":"FI00801","location_id":"2365","lat":"61.4991","long":"23.80221","pm25":""},{"location_name":"FI00838","location_id":"2366","lat":"61.50854","long":"23.67583","pm25":""},{"location_name":"FI00839","location_id":"2367","lat":"62.88205","long":"27.66197","pm25":""},{"location_name":"FI00841","location_id":"2368","lat":"60.22024","long":"24.81133","pm25":""},{"location_name":"FI00867","location_id":"2369","lat":"60.97907","long":"25.59109","pm25":""},{"location_name":"FI00893","location_id":"2370","lat":"60.53002","long":"27.6754","pm25":""},{"location_name":"FI00902","location_id":"2371","lat":"60.19644","long":"24.95198","pm25":""},{"location_name":"FIVCO","location_id":"2372","lat":"38.4592","long":"-82.6339","pm25":""},{"location_name":"FLAMINIA","location_id":"2373","lat":"44.0521","long":"12.5757","pm25":""},{"location_name":"FLINT","location_id":"2374","lat":"43.0289","long":"-83.6694","pm25":""},{"location_name":"FOREST HILLS","location_id":"2376","lat":"45.3092","long":"-66.0092","pm25":""},{"location_name":"FORT ST JOHN LEARNIN","location_id":"2377","lat":"56.24472","long":"-120.85611","pm25":""},{"location_name":"FR01005","location_id":"2378","lat":"49.32472","long":"6.0761056","pm25":""},{"location_name":"FR01011","location_id":"2380","lat":"49.119427","long":"6.1808314","pm25":""},{"location_name":"FR01012","location_id":"2381","lat":"49.110256","long":"6.2233396","pm25":""},{"location_name":"FR01014","location_id":"2382","lat":"48.914993","long":"6.058337","pm25":""},{"location_name":"FR01015","location_id":"2383","lat":"48.8847","long":"6.051393","pm25":""},{"location_name":"FR01016","location_id":"2384","lat":"48.886414","long":"6.093614","pm25":""},{"location_name":"FR01018","location_id":"2385","lat":"49.10749","long":"6.122773","pm25":""},{"location_name":"FR01019","location_id":"2386","lat":"49.36861","long":"6.160835","pm25":""},{"location_name":"FR01020","location_id":"2387","lat":"49.358315","long":"6.156945","pm25":""},{"location_name":"FR01021","location_id":"2388","lat":"49.39446","long":"6.2013936","pm25":""},{"location_name":"FR01022","location_id":"2389","lat":"49.131126","long":"6.207224","pm25":""},{"location_name":"FR01059","location_id":"2390","lat":"49.33742","long":"6.0820704","pm25":""},{"location_name":"FR01060","location_id":"2391","lat":"49.168846","long":"6.2126675","pm25":""},{"location_name":"FR01064","location_id":"2392","lat":"49.125072","long":"6.1812177","pm25":""},{"location_name":"FR01065","location_id":"2393","lat":"49.16779","long":"5.3874574","pm25":""},{"location_name":"FR02001","location_id":"2394","lat":"43.485863","long":"5.171942","pm25":""},{"location_name":"FR02003","location_id":"2395","lat":"43.386974","long":"5.160282","pm25":""},{"location_name":"FR02004","location_id":"2396","lat":"43.41667","long":"5.043052","pm25":""},{"location_name":"FR02005","location_id":"2397","lat":"43.405186","long":"5.0514965","pm25":""},{"location_name":"FR02006","location_id":"2398","lat":"43.36112","long":"5.0247173","pm25":""},{"location_name":"FR02008","location_id":"2399","lat":"43.40225","long":"4.9822183","pm25":""},{"location_name":"FR02009","location_id":"2400","lat":"43.40029","long":"4.796393","pm25":""},{"location_name":"FR02011","location_id":"2401","lat":"43.43748","long":"4.9436088","pm25":""},{"location_name":"FR02012","location_id":"2402","lat":"43.509453","long":"4.982775","pm25":""},{"location_name":"FR02013","location_id":"2403","lat":"43.458874","long":"4.9341674","pm25":""},{"location_name":"FR02019","location_id":"2404","lat":"43.457245","long":"5.244302","pm25":""},{"location_name":"FR02020","location_id":"2405","lat":"43.51056","long":"5.2197237","pm25":""},{"location_name":"FR02021","location_id":"2406","lat":"43.331394","long":"5.117774","pm25":""},{"location_name":"FR02022","location_id":"2407","lat":"43.675556","long":"4.6286144","pm25":""},{"location_name":"FR02024","location_id":"2408","lat":"43.457222","long":"4.426667","pm25":""},{"location_name":"FR02026","location_id":"2409","lat":"43.58498","long":"5.006392","pm25":""},{"location_name":"FR02028","location_id":"2410","lat":"43.385994","long":"5.0269456","pm25":""},{"location_name":"FR02029","location_id":"2411","lat":"43.399574","long":"5.11472","pm25":""},{"location_name":"FR02033","location_id":"2412","lat":"43.34054","long":"5.058611","pm25":""},{"location_name":"FR02041","location_id":"2413","lat":"43.638966","long":"5.0999966","pm25":""},{"location_name":"FR03006","location_id":"2415","lat":"43.27635","long":"5.397671","pm25":""},{"location_name":"FR03014","location_id":"2416","lat":"43.348053","long":"5.3606515","pm25":""},{"location_name":"FR03021","location_id":"2417","lat":"43.524044","long":"5.449576","pm25":""},{"location_name":"FR03027","location_id":"2418","lat":"43.335182","long":"5.7273617","pm25":""},{"location_name":"FR03029","location_id":"2419","lat":"43.530296","long":"5.4413834","pm25":""},{"location_name":"FR03030","location_id":"2420","lat":"43.45346","long":"5.467102","pm25":""},{"location_name":"FR03032","location_id":"2421","lat":"43.29479","long":"5.571738","pm25":""},{"location_name":"FR03037","location_id":"2422","lat":"43.28315","long":"5.5120897","pm25":""},{"location_name":"FR03043","location_id":"2423","lat":"43.3061","long":"5.3957934","pm25":""},{"location_name":"FR03048","location_id":"2424","lat":"43.555756","long":"5.461802","pm25":""},{"location_name":"FR03060","location_id":"2425","lat":"43.101604","long":"5.875386","pm25":""},{"location_name":"FR03067","location_id":"2426","lat":"43.398724","long":"6.0761056","pm25":""},{"location_name":"FR03068","location_id":"2427","lat":"43.126785","long":"5.921937","pm25":""},{"location_name":"FR03069","location_id":"2428","lat":"43.119705","long":"6.131801","pm25":""},{"location_name":"FR03070","location_id":"2429","lat":"43.43781","long":"6.7683926","pm25":""},{"location_name":"FR03071","location_id":"2430","lat":"43.131046","long":"5.924237","pm25":""},{"location_name":"FR03080","location_id":"2431","lat":"43.949757","long":"4.8050795","pm25":""},{"location_name":"FR03084","location_id":"2432","lat":"43.960167","long":"4.8572087","pm25":""},{"location_name":"FR03086","location_id":"2433","lat":"43.880062","long":"5.362502","pm25":""},{"location_name":"FR03087","location_id":"2434","lat":"43.937077","long":"4.824932","pm25":""},{"location_name":"FR03088","location_id":"2435","lat":"44.06044","long":"5.0674233","pm25":""},{"location_name":"FR04002","location_id":"2436","lat":"48.92969","long":"2.2947195","pm25":""},{"location_name":"FR04004","location_id":"2437","lat":"48.89167","long":"2.346669","pm25":""},{"location_name":"FR04014","location_id":"2439","lat":"48.837242","long":"2.3939025","pm25":""},{"location_name":"FR04017","location_id":"2440","lat":"48.881393","long":"2.2780557","pm25":""},{"location_name":"FR04018","location_id":"2441","lat":"48.903896","long":"2.3847036","pm25":""},{"location_name":"FR04023","location_id":"2442","lat":"49.04641","long":"2.0430565","pm25":""},{"location_name":"FR04024","location_id":"2443","lat":"48.990856","long":"2.44472","pm25":""},{"location_name":"FR04029","location_id":"2444","lat":"48.799152","long":"2.1305523","pm25":""},{"location_name":"FR04031","location_id":"2445","lat":"48.868866","long":"2.3119402","pm25":""},{"location_name":"FR04034","location_id":"2446","lat":"48.775772","long":"2.3758013","pm25":""},{"location_name":"FR04037","location_id":"2447","lat":"48.82861","long":"2.3602786","pm25":""},{"location_name":"FR04038","location_id":"2448","lat":"48.581936","long":"1.883336","pm25":""},{"location_name":"FR04048","location_id":"2449","lat":"49.100258","long":"2.3438933","pm25":""},{"location_name":"FR04049","location_id":"2450","lat":"48.67942","long":"2.1655598","pm25":""},{"location_name":"FR04051","location_id":"2451","lat":"48.951405","long":"2.2236087","pm25":""},{"location_name":"FR04058","location_id":"2452","lat":"48.925266","long":"2.3566673","pm25":""},{"location_name":"FR04059","location_id":"2453","lat":"48.937244","long":"2.361671","pm25":""},{"location_name":"FR04060","location_id":"2454","lat":"48.8572","long":"2.2933","pm25":""},{"location_name":"FR04063","location_id":"2455","lat":"48.996395","long":"1.7032956","pm25":""},{"location_name":"FR04066","location_id":"2456","lat":"48.36414","long":"2.23694","pm25":""},{"location_name":"FR04069","location_id":"2457","lat":"48.54139","long":"2.6613848","pm25":""},{"location_name":"FR04071","location_id":"2458","lat":"48.856396","long":"2.3352783","pm25":""},{"location_name":"FR04098","location_id":"2459","lat":"48.84026","long":"2.6352797","pm25":""},{"location_name":"FR04099","location_id":"2460","lat":"48.840553","long":"2.4844437","pm25":""},{"location_name":"FR04100","location_id":"2461","lat":"48.881924","long":"2.5072248","pm25":""},{"location_name":"FR04101","location_id":"2462","lat":"48.81637","long":"2.5175016","pm25":""},{"location_name":"FR04118","location_id":"2463","lat":"48.870285","long":"2.3325026","pm25":""},{"location_name":"FR04122","location_id":"2464","lat":"48.528065","long":"2.6536143","pm25":""},{"location_name":"FR04123","location_id":"2465","lat":"48.90224","long":"2.3908303","pm25":""},{"location_name":"FR04131","location_id":"2466","lat":"48.873333","long":"2.330278","pm25":""},{"location_name":"FR04135","location_id":"2467","lat":"48.83795","long":"2.4080598","pm25":""},{"location_name":"FR04141","location_id":"2468","lat":"48.85279","long":"2.360557","pm25":""},{"location_name":"FR04142","location_id":"2469","lat":"49.028038","long":"2.750282","pm25":""},{"location_name":"FR04149","location_id":"2472","lat":"48.7067","long":"2.4571977","pm25":""},{"location_name":"FR04150","location_id":"2473","lat":"48.891376","long":"2.24056","pm25":""},{"location_name":"FR04156","location_id":"2474","lat":"48.902477","long":"2.4524996","pm25":""},{"location_name":"FR04158","location_id":"2475","lat":"49.063072","long":"1.8663847","pm25":""},{"location_name":"FR04173","location_id":"2476","lat":"48.805542","long":"3.0844464","pm25":""},{"location_name":"FR04179","location_id":"2477","lat":"48.830383","long":"2.26989","pm25":""},{"location_name":"FR04180","location_id":"2478","lat":"48.64091","long":"2.2687223","pm25":""},{"location_name":"FR04181","location_id":"2479","lat":"48.633728","long":"1.830533","pm25":""},{"location_name":"FR04319","location_id":"2480","lat":"48.955536","long":"2.5752814","pm25":""},{"location_name":"FR04323","location_id":"2481","lat":"48.627197","long":"2.4291704","pm25":""},{"location_name":"FR04324","location_id":"2482","lat":"48.76168","long":"3.0583324","pm25":""},{"location_name":"FR04328","location_id":"2483","lat":"48.35471","long":"2.6452959","pm25":""},{"location_name":"FR04329","location_id":"2484","lat":"48.838604","long":"2.412785","pm25":""},{"location_name":"FR05010","location_id":"2485","lat":"49.528923","long":"0.35873324","pm25":""},{"location_name":"FR05037","location_id":"2486","lat":"49.503906","long":"0.17573114","pm25":""},{"location_name":"FR05056","location_id":"2488","lat":"49.473736","long":"0.5261576","pm25":""},{"location_name":"FR05069","location_id":"2489","lat":"49.487682","long":"0.45175558","pm25":""},{"location_name":"FR05070","location_id":"2490","lat":"49.505013","long":"0.20169424","pm25":""},{"location_name":"FR05072","location_id":"2491","lat":"49.503845","long":"0.08461402","pm25":""},{"location_name":"FR05074","location_id":"2492","lat":"49.48961","long":"0.10070294","pm25":""},{"location_name":"FR05078","location_id":"2493","lat":"49.498302","long":"0.14270636","pm25":""},{"location_name":"FR05080","location_id":"2494","lat":"49.503613","long":"0.2668724","pm25":""},{"location_name":"FR05081","location_id":"2495","lat":"49.50402","long":"0.41159368","pm25":""},{"location_name":"FR05082","location_id":"2496","lat":"49.348015","long":"0.10925311","pm25":""},{"location_name":"FR05083","location_id":"2497","lat":"49.50274","long":"0.23248579","pm25":""},{"location_name":"FR05084","location_id":"2498","lat":"49.493343","long":"0.57185316","pm25":""},{"location_name":"FR05085","location_id":"2499","lat":"49.51213","long":"0.53903586","pm25":""},{"location_name":"FR05087","location_id":"2500","lat":"49.498295","long":"0.758833","pm25":""},{"location_name":"FR05088","location_id":"2501","lat":"49.74999","long":"0.4159002","pm25":""},{"location_name":"FR05089","location_id":"2502","lat":"49.50017","long":"0.11090331","pm25":""},{"location_name":"FR05090","location_id":"2503","lat":"49.514694","long":"0.100645445","pm25":""},{"location_name":"FR06001","location_id":"2504","lat":"50.35853","long":"3.508038","pm25":""},{"location_name":"FR06003","location_id":"2505","lat":"50.378242","long":"3.0658603","pm25":""},{"location_name":"FR06006","location_id":"2506","lat":"50.36426","long":"3.5227344","pm25":""},{"location_name":"FR06007","location_id":"2507","lat":"50.279377","long":"3.9769137","pm25":""},{"location_name":"FR06011","location_id":"2509","lat":"50.322754","long":"3.3959281","pm25":""},{"location_name":"FR06133","location_id":"2510","lat":"50.092266","long":"3.8500266","pm25":""},{"location_name":"FR06134","location_id":"2511","lat":"50.456486","long":"3.4279442","pm25":""},{"location_name":"FR07004","location_id":"2513","lat":"45.797264","long":"3.1138303","pm25":""},{"location_name":"FR07009","location_id":"2514","lat":"45.772144","long":"3.0875006","pm25":""},{"location_name":"FR07022","location_id":"2516","lat":"46.652645","long":"3.6006632","pm25":""},{"location_name":"FR07028","location_id":"2517","lat":"45.92932","long":"2.82981","pm25":""},{"location_name":"FR07031","location_id":"2518","lat":"45.104702","long":"3.2773595","pm25":""},{"location_name":"FR07034","location_id":"2520","lat":"45.775715","long":"3.0962503","pm25":""},{"location_name":"FR07039","location_id":"2521","lat":"45.774776","long":"3.0629675","pm25":""},{"location_name":"FR07048","location_id":"2523","lat":"46.659058","long":"3.249314","pm25":""},{"location_name":"FR07051","location_id":"2524","lat":"45.769012","long":"3.155","pm25":""},{"location_name":"FR07052","location_id":"2525","lat":"44.92009","long":"2.441082","pm25":""},{"location_name":"FR07053","location_id":"2526","lat":"45.780415","long":"3.1115935","pm25":""},{"location_name":"FR07054","location_id":"2527","lat":"45.03898","long":"3.8870013","pm25":""},{"location_name":"FR08003","location_id":"2528","lat":"43.611652","long":"3.864723","pm25":""},{"location_name":"FR08004","location_id":"2529","lat":"43.60502","long":"3.8745954","pm25":""},{"location_name":"FR08016","location_id":"2530","lat":"43.591553","long":"3.8868935","pm25":""},{"location_name":"FR08017","location_id":"2531","lat":"43.5706","long":"3.9115522","pm25":""},{"location_name":"FR08018","location_id":"2532","lat":"43.695366","long":"3.8008168","pm25":""},{"location_name":"FR08020","location_id":"2533","lat":"43.67575","long":"4.0884213","pm25":""},{"location_name":"FR08022","location_id":"2534","lat":"43.287727","long":"3.504831","pm25":""},{"location_name":"FR08023","location_id":"2535","lat":"43.40682","long":"3.1888037","pm25":""},{"location_name":"FR08030","location_id":"2538","lat":"43.609962","long":"3.8986075","pm25":""},{"location_name":"FR08209","location_id":"2540","lat":"43.942898","long":"4.6796837","pm25":""},{"location_name":"FR08252","location_id":"2541","lat":"44.05353","long":"4.6973624","pm25":""},{"location_name":"FR08614","location_id":"2542","lat":"43.834393","long":"4.3742204","pm25":""},{"location_name":"FR08616","location_id":"2543","lat":"43.829857","long":"4.3619857","pm25":""},{"location_name":"FR08617","location_id":"2544","lat":"43.92537","long":"4.265812","pm25":""},{"location_name":"FR08712","location_id":"2546","lat":"42.719803","long":"2.8398712","pm25":""},{"location_name":"FR08713","location_id":"2547","lat":"42.684025","long":"2.9034538","pm25":""},{"location_name":"FR08714","location_id":"2548","lat":"42.695778","long":"2.899699","pm25":""},{"location_name":"FR09003","location_id":"2549","lat":"46.162556","long":"-1.153603","pm25":""},{"location_name":"FR09008","location_id":"2550","lat":"46.135128","long":"-1.1170461","pm25":""},{"location_name":"FR09015","location_id":"2551","lat":"46.586933","long":"0.3585832","pm25":""},{"location_name":"FR09016","location_id":"2552","lat":"45.608807","long":"0.09972198","pm25":""},{"location_name":"FR09019","location_id":"2554","lat":"46.329563","long":"-0.4588891","pm25":""},{"location_name":"FR09103","location_id":"2555","lat":"45.647438","long":"0.16716659","pm25":""},{"location_name":"FR09106","location_id":"2556","lat":"45.65146","long":"0.1623669","pm25":""},{"location_name":"FR09203","location_id":"2557","lat":"46.16164","long":"-1.2112075","pm25":""},{"location_name":"FR09301","location_id":"2558","lat":"46.82435","long":"-0.13546056","pm25":""},{"location_name":"FR09302","location_id":"2559","lat":"46.143158","long":"-0.39604205","pm25":""},{"location_name":"FR09399","location_id":"2560","lat":"46.321747","long":"-0.4659723","pm25":""},{"location_name":"FR09404","location_id":"2562","lat":"46.583908","long":"0.34555584","pm25":""},{"location_name":"FR10004","location_id":"2563","lat":"51.048573","long":"2.4200435","pm25":""},{"location_name":"FR10012","location_id":"2564","lat":"51.01942","long":"2.2509894","pm25":""},{"location_name":"FR10016","location_id":"2565","lat":"50.947315","long":"1.8430824","pm25":""},{"location_name":"FR10025","location_id":"2566","lat":"50.949863","long":"1.7691691","pm25":""},{"location_name":"FR10026","location_id":"2567","lat":"50.957787","long":"1.8900824","pm25":""},{"location_name":"FR10028","location_id":"2568","lat":"50.981037","long":"2.1431737","pm25":""},{"location_name":"FR10029","location_id":"2569","lat":"50.995907","long":"2.365994","pm25":""},{"location_name":"FR10032","location_id":"2570","lat":"50.69432","long":"1.5765703","pm25":""},{"location_name":"FR10034","location_id":"2571","lat":"51.024452","long":"2.3021486","pm25":""},{"location_name":"FR10041","location_id":"2572","lat":"50.748238","long":"2.259784","pm25":""},{"location_name":"FR10132","location_id":"2573","lat":"50.610485","long":"1.9914482","pm25":""},{"location_name":"FR11007","location_id":"2574","lat":"50.6408","long":"3.0747714","pm25":""},{"location_name":"FR11016","location_id":"2575","lat":"50.670017","long":"3.076559","pm25":""},{"location_name":"FR11025","location_id":"2576","lat":"50.62804","long":"3.0903125","pm25":""},{"location_name":"FR11026","location_id":"2577","lat":"50.775455","long":"3.125679","pm25":""},{"location_name":"FR11034","location_id":"2580","lat":"50.706554","long":"3.180656","pm25":""},{"location_name":"FR11114","location_id":"2581","lat":"50.597713","long":"3.049457","pm25":""},{"location_name":"FR12004","location_id":"2582","lat":"43.575546","long":"1.4186106","pm25":""},{"location_name":"FR12015","location_id":"2583","lat":"43.094456","long":"0.74472225","pm25":""},{"location_name":"FR12016","location_id":"2584","lat":"43.10639","long":"0.71888936","pm25":""},{"location_name":"FR12020","location_id":"2585","lat":"43.630253","long":"0.17972234","pm25":""},{"location_name":"FR12021","location_id":"2586","lat":"43.62362","long":"1.438607","pm25":""},{"location_name":"FR12026","location_id":"2587","lat":"43.928055","long":"2.146111","pm25":""},{"location_name":"FR12029","location_id":"2588","lat":"43.88362","long":"0.84500027","pm25":""},{"location_name":"FR12030","location_id":"2589","lat":"43.587193","long":"1.4438891","pm25":""},{"location_name":"FR12031","location_id":"2590","lat":"43.441395","long":"1.8219451","pm25":""},{"location_name":"FR12039","location_id":"2591","lat":"43.560837","long":"1.3950028","pm25":""},{"location_name":"FR12040","location_id":"2592","lat":"43.55693","long":"1.4063934","pm25":""},{"location_name":"FR12041","location_id":"2593","lat":"43.457504","long":"1.5711085","pm25":""},{"location_name":"FR12042","location_id":"2594","lat":"43.096947","long":"-0.03888897","pm25":""},{"location_name":"FR12044","location_id":"2595","lat":"43.63402","long":"1.3760034","pm25":""},{"location_name":"FR12045","location_id":"2596","lat":"43.09498","long":"-0.051944003","pm25":""},{"location_name":"FR12047","location_id":"2597","lat":"43.803867","long":"1.5958302","pm25":""},{"location_name":"FR12052","location_id":"2598","lat":"43.23029","long":"0.06222199","pm25":""},{"location_name":"FR12053","location_id":"2599","lat":"43.610546","long":"2.2299957","pm25":""},{"location_name":"FR12054","location_id":"2600","lat":"43.64306","long":"1.4676496","pm25":""},{"location_name":"FR14008","location_id":"2604","lat":"49.90778","long":"4.6299977","pm25":""},{"location_name":"FR14010","location_id":"2605","lat":"49.282192","long":"4.0511146","pm25":""},{"location_name":"FR14011","location_id":"2606","lat":"49.250713","long":"4.0230603","pm25":""},{"location_name":"FR14012","location_id":"2607","lat":"49.224144","long":"4.0205536","pm25":""},{"location_name":"FR14022","location_id":"2608","lat":"48.9622","long":"4.36","pm25":""},{"location_name":"FR14028","location_id":"2609","lat":"49.046116","long":"3.955911","pm25":""},{"location_name":"FR14029","location_id":"2610","lat":"48.726612","long":"4.594784","pm25":""},{"location_name":"FR14031","location_id":"2611","lat":"48.301674","long":"4.076941","pm25":""},{"location_name":"FR14032","location_id":"2612","lat":"48.299164","long":"4.1172214","pm25":""},{"location_name":"FR14033","location_id":"2613","lat":"48.29498","long":"4.050279","pm25":""},{"location_name":"FR14042","location_id":"2614","lat":"48.64584","long":"4.9661117","pm25":""},{"location_name":"FR14051","location_id":"2615","lat":"49.745285","long":"4.7191644","pm25":""},{"location_name":"FR15013","location_id":"2617","lat":"45.079525","long":"5.7286553","pm25":""},{"location_name":"FR15018","location_id":"2619","lat":"45.360157","long":"5.5894165","pm25":""},{"location_name":"FR15031","location_id":"2620","lat":"44.997005","long":"6.469397","pm25":""},{"location_name":"FR15038","location_id":"2621","lat":"45.182827","long":"5.7530985","pm25":""},{"location_name":"FR15039","location_id":"2622","lat":"45.158382","long":"5.703763","pm25":""},{"location_name":"FR15043","location_id":"2623","lat":"45.16193","long":"5.7355995","pm25":""},{"location_name":"FR15045","location_id":"2624","lat":"45.057827","long":"5.676697","pm25":""},{"location_name":"FR15046","location_id":"2625","lat":"45.180676","long":"5.7200584","pm25":""},{"location_name":"FR15048","location_id":"2626","lat":"45.279682","long":"5.8822045","pm25":""},{"location_name":"FR16001","location_id":"2627","lat":"48.60879","long":"7.7089195","pm25":""},{"location_name":"FR16017","location_id":"2628","lat":"48.91936","long":"8.158455","pm25":""},{"location_name":"FR16029","location_id":"2629","lat":"48.610332","long":"7.781629","pm25":""},{"location_name":"FR16031","location_id":"2630","lat":"48.857285","long":"7.3141727","pm25":""},{"location_name":"FR16034","location_id":"2631","lat":"48.59043","long":"7.744987","pm25":""},{"location_name":"FR16038","location_id":"2632","lat":"48.570347","long":"7.7663307","pm25":""},{"location_name":"FR16040","location_id":"2633","lat":"48.575993","long":"7.727479","pm25":""},{"location_name":"FR16041","location_id":"2634","lat":"48.51569","long":"7.687818","pm25":""},{"location_name":"FR16052","location_id":"2635","lat":"47.810944","long":"7.105557","pm25":""},{"location_name":"FR16054","location_id":"2636","lat":"48.07463","long":"7.3506713","pm25":""},{"location_name":"FR16057","location_id":"2637","lat":"47.757465","long":"7.347294","pm25":""},{"location_name":"FR16059","location_id":"2638","lat":"47.820232","long":"7.5386796","pm25":""},{"location_name":"FR16060","location_id":"2639","lat":"47.59494","long":"7.5681715","pm25":""},{"location_name":"FR16064","location_id":"2640","lat":"48.065388","long":"7.333136","pm25":""},{"location_name":"FR16065","location_id":"2641","lat":"47.72309","long":"7.3416076","pm25":""},{"location_name":"FR16066","location_id":"2642","lat":"47.73741","long":"7.3090796","pm25":""},{"location_name":"FR16067","location_id":"2643","lat":"47.802197","long":"7.122841","pm25":""},{"location_name":"FR16069","location_id":"2644","lat":"47.74768","long":"7.321368","pm25":""},{"location_name":"FR16302","location_id":"2645","lat":"48.49301","long":"7.1298027","pm25":""},{"location_name":"FR18019","location_id":"2646","lat":"49.27639","long":"2.4821708","pm25":""},{"location_name":"FR18035","location_id":"2647","lat":"49.868885","long":"2.2398055","pm25":""},{"location_name":"FR18039","location_id":"2648","lat":"50.129425","long":"1.610832","pm25":""},{"location_name":"FR18042","location_id":"2649","lat":"49.851337","long":"3.2839983","pm25":""},{"location_name":"FR18043","location_id":"2650","lat":"49.259567","long":"2.4744005","pm25":""},{"location_name":"FR18045","location_id":"2651","lat":"49.696674","long":"2.8011358","pm25":""},{"location_name":"FR18053","location_id":"2652","lat":"49.9025","long":"2.3046","pm25":""},{"location_name":"FR18079","location_id":"2654","lat":"49.87722","long":"2.2825","pm25":""},{"location_name":"FR18080","location_id":"2655","lat":"49.842823","long":"3.2814379","pm25":""},{"location_name":"FR18089","location_id":"2656","lat":"49.435955","long":"2.084289","pm25":""},{"location_name":"FR19002","location_id":"2657","lat":"48.108654","long":"-1.665764","pm25":""},{"location_name":"FR19007","location_id":"2658","lat":"48.107513","long":"-1.6791669","pm25":""},{"location_name":"FR19008","location_id":"2659","lat":"47.831932","long":"-1.8363271","pm25":""},{"location_name":"FR19010","location_id":"2660","lat":"48.110813","long":"-1.6828231","pm25":""},{"location_name":"FR19012","location_id":"2661","lat":"48.3864","long":"-4.4868155","pm25":""},{"location_name":"FR19014","location_id":"2662","lat":"48.39964","long":"-4.467232","pm25":""},{"location_name":"FR19015","location_id":"2663","lat":"48.40906","long":"-4.4751105","pm25":""},{"location_name":"FR19017","location_id":"2664","lat":"48.089695","long":"-1.6590266","pm25":""},{"location_name":"FR19021","location_id":"2665","lat":"47.75221","long":"-3.3756533","pm25":""},{"location_name":"FR19032","location_id":"2666","lat":"47.742485","long":"-3.3948054","pm25":""},{"location_name":"FR19033","location_id":"2667","lat":"47.648888","long":"-2.7638915","pm25":""},{"location_name":"FR19052","location_id":"2668","lat":"47.996124","long":"-4.0997224","pm25":""},{"location_name":"FR19061","location_id":"2669","lat":"48.51349","long":"-2.7495275","pm25":""},{"location_name":"FR20013","location_id":"2671","lat":"45.72005","long":"4.818159","pm25":""},{"location_name":"FR20017","location_id":"2672","lat":"45.735287","long":"4.829792","pm25":""},{"location_name":"FR20019","location_id":"2673","lat":"45.758358","long":"4.886215","pm25":""},{"location_name":"FR20029","location_id":"2674","lat":"45.66389","long":"4.845899","pm25":""},{"location_name":"FR20031","location_id":"2675","lat":"45.70782","long":"4.864404","pm25":""},{"location_name":"FR20037","location_id":"2677","lat":"45.60189","long":"4.802196","pm25":""},{"location_name":"FR20046","location_id":"2679","lat":"45.77891","long":"4.9246993","pm25":""},{"location_name":"FR20047","location_id":"2680","lat":"45.82325","long":"4.953957","pm25":""},{"location_name":"FR20048","location_id":"2681","lat":"45.75328","long":"5.0722027","pm25":""},{"location_name":"FR20049","location_id":"2682","lat":"45.961426","long":"4.465714","pm25":""},{"location_name":"FR20062","location_id":"2685","lat":"45.757732","long":"4.8542175","pm25":""},{"location_name":"FR20069","location_id":"2686","lat":"45.774837","long":"4.8985763","pm25":""},{"location_name":"FR21001","location_id":"2687","lat":"49.19222","long":"-0.39118308","pm25":""},{"location_name":"FR21016","location_id":"2688","lat":"49.17525","long":"-0.35361102","pm25":""},{"location_name":"FR21019","location_id":"2689","lat":"49.151695","long":"-0.3527783","pm25":""},{"location_name":"FR21021","location_id":"2690","lat":"49.14723","long":"0.22722167","pm25":""},{"location_name":"FR21031","location_id":"2691","lat":"48.44554","long":"0.11083324","pm25":""},{"location_name":"FR21035","location_id":"2692","lat":"49.636383","long":"-1.6266693","pm25":""},{"location_name":"FR21040","location_id":"2693","lat":"49.11637","long":"-1.0847247","pm25":""},{"location_name":"FR21050","location_id":"2694","lat":"48.645008","long":"-0.45833305","pm25":""},{"location_name":"FR21060","location_id":"2695","lat":"49.11719","long":"-0.16966571","pm25":""},{"location_name":"FR22009","location_id":"2696","lat":"49.165733","long":"6.716883","pm25":""},{"location_name":"FR22011","location_id":"2697","lat":"49.15839","long":"6.7316604","pm25":""},{"location_name":"FR22014","location_id":"2698","lat":"49.19539","long":"6.9574428","pm25":""},{"location_name":"FR22019","location_id":"2699","lat":"49.22039","long":"6.9258313","pm25":""},{"location_name":"FR22022","location_id":"2700","lat":"49.11837","long":"7.0835395","pm25":""},{"location_name":"FR22054","location_id":"2701","lat":"49.187405","long":"6.9108653","pm25":""},{"location_name":"FR23001","location_id":"2702","lat":"47.32412","long":"-2.0815673","pm25":""},{"location_name":"FR23003","location_id":"2703","lat":"47.32284","long":"-2.0398495","pm25":""},{"location_name":"FR23004","location_id":"2704","lat":"47.3173","long":"-2.0733027","pm25":""},{"location_name":"FR23068","location_id":"2705","lat":"47.24746","long":"-1.936615","pm25":""},{"location_name":"FR23069","location_id":"2706","lat":"47.360764","long":"-1.954752","pm25":""},{"location_name":"FR23070","location_id":"2707","lat":"47.283184","long":"-1.7831649","pm25":""},{"location_name":"FR23075","location_id":"2708","lat":"47.315716","long":"-2.1907663","pm25":""},{"location_name":"FR23078","location_id":"2709","lat":"47.054443","long":"-0.886111","pm25":""},{"location_name":"FR23107","location_id":"2710","lat":"47.252766","long":"-1.5733364","pm25":""},{"location_name":"FR23110","location_id":"2711","lat":"47.264107","long":"-2.2498577","pm25":""},{"location_name":"FR23120","location_id":"2712","lat":"47.46854","long":"-0.5560527","pm25":""},{"location_name":"FR23123","location_id":"2713","lat":"48.06941","long":"-0.76769215","pm25":""},{"location_name":"FR23124","location_id":"2714","lat":"46.656715","long":"-0.7436811","pm25":""},{"location_name":"FR23140","location_id":"2715","lat":"47.20439","long":"-1.5528278","pm25":""},{"location_name":"FR23149","location_id":"2716","lat":"47.28611","long":"-2.0322857","pm25":""},{"location_name":"FR23150","location_id":"2717","lat":"47.447403","long":"-0.5500672","pm25":""},{"location_name":"FR23152","location_id":"2718","lat":"46.66072","long":"-1.4368284","pm25":""},{"location_name":"FR23153","location_id":"2719","lat":"47.331547","long":"-2.1516268","pm25":""},{"location_name":"FR23157","location_id":"2720","lat":"47.146076","long":"-1.6902701","pm25":""},{"location_name":"FR23163","location_id":"2721","lat":"47.92189","long":"0.15182516","pm25":""},{"location_name":"FR23174","location_id":"2722","lat":"47.98891","long":"0.19598275","pm25":""},{"location_name":"FR23175","location_id":"2723","lat":"47.43015","long":"-0.61006385","pm25":""},{"location_name":"FR23177","location_id":"2724","lat":"47.787712","long":"-0.44404444","pm25":""},{"location_name":"FR23178","location_id":"2725","lat":"47.319187","long":"-2.0669515","pm25":""},{"location_name":"FR23181","location_id":"2726","lat":"47.273067","long":"-2.2230518","pm25":""},{"location_name":"FR23182","location_id":"2727","lat":"47.97105","long":"0.22142214","pm25":""},{"location_name":"FR23188","location_id":"2728","lat":"47.222515","long":"-1.5375025","pm25":""},{"location_name":"FR23230","location_id":"2729","lat":"47.25307","long":"-2.3320713","pm25":""},{"location_name":"FR24007","location_id":"2730","lat":"43.59975","long":"7.094723","pm25":""},{"location_name":"FR24009","location_id":"2731","lat":"43.562527","long":"7.0072184","pm25":""},{"location_name":"FR24011","location_id":"2732","lat":"43.686077","long":"7.2119446","pm25":""},{"location_name":"FR24015","location_id":"2734","lat":"43.657814","long":"6.9209533","pm25":""},{"location_name":"FR24018","location_id":"2735","lat":"43.8353","long":"5.7858334","pm25":""},{"location_name":"FR24021","location_id":"2736","lat":"43.786617","long":"7.373282","pm25":""},{"location_name":"FR24023","location_id":"2737","lat":"43.79336","long":"7.3313937","pm25":""},{"location_name":"FR24033","location_id":"2738","lat":"44.55522","long":"6.0730605","pm25":""},{"location_name":"FR24035","location_id":"2739","lat":"43.689262","long":"7.242083","pm25":""},{"location_name":"FR24036","location_id":"2740","lat":"43.702057","long":"7.286262","pm25":""},{"location_name":"FR24038","location_id":"2741","lat":"44.54863","long":"6.067302","pm25":""},{"location_name":"FR24039","location_id":"2742","lat":"43.93352","long":"5.7117043","pm25":""},{"location_name":"FR24040","location_id":"2743","lat":"43.791935","long":"7.0483346","pm25":""},{"location_name":"FR25011","location_id":"2744","lat":"49.383118","long":"1.0257592","pm25":""},{"location_name":"FR25035","location_id":"2745","lat":"49.358196","long":"1.0078559","pm25":""},{"location_name":"FR25036","location_id":"2746","lat":"49.442436","long":"1.0936899","pm25":""},{"location_name":"FR25039","location_id":"2747","lat":"49.02132","long":"1.1483164","pm25":""},{"location_name":"FR25040","location_id":"2748","lat":"49.40621","long":"1.1551526","pm25":""},{"location_name":"FR25043","location_id":"2749","lat":"49.40052","long":"1.098825","pm25":""},{"location_name":"FR25045","location_id":"2750","lat":"49.91634","long":"0.9571819","pm25":""},{"location_name":"FR25048","location_id":"2751","lat":"49.428066","long":"1.0577753","pm25":""},{"location_name":"FR25049","location_id":"2752","lat":"49.304867","long":"1.2143695","pm25":""},{"location_name":"FR25050","location_id":"2753","lat":"49.781204","long":"1.3450834","pm25":""},{"location_name":"FR25051","location_id":"2754","lat":"49.91802","long":"1.0739719","pm25":""},{"location_name":"FR26005","location_id":"2756","lat":"47.30804","long":"5.066112","pm25":""},{"location_name":"FR26010","location_id":"2757","lat":"47.34555","long":"5.002224","pm25":""},{"location_name":"FR26012","location_id":"2758","lat":"47.275017","long":"4.09833","pm25":""},{"location_name":"FR26014","location_id":"2759","lat":"47.340252","long":"5.0583324","pm25":""},{"location_name":"FR26016","location_id":"2760","lat":"48.200584","long":"3.2772248","pm25":""},{"location_name":"FR26017","location_id":"2761","lat":"46.996666","long":"3.1708374","pm25":""},{"location_name":"FR26019","location_id":"2762","lat":"47.800568","long":"3.5763907","pm25":""},{"location_name":"FR26035","location_id":"2763","lat":"47.137215","long":"4.9505796","pm25":""},{"location_name":"FR26043","location_id":"2764","lat":"47.31547","long":"5.037429","pm25":""},{"location_name":"FR27002","location_id":"2765","lat":"45.367794","long":"4.8051515","pm25":""},{"location_name":"FR27003","location_id":"2766","lat":"45.454506","long":"4.766524","pm25":""},{"location_name":"FR27005","location_id":"2767","lat":"45.31962","long":"4.772866","pm25":""},{"location_name":"FR27007","location_id":"2768","lat":"45.60824","long":"5.270874","pm25":""},{"location_name":"FR27008","location_id":"2769","lat":"45.35321","long":"4.804819","pm25":""},{"location_name":"FR27010","location_id":"2770","lat":"45.46087","long":"5.1810784","pm25":""},{"location_name":"FR28010","location_id":"2771","lat":"50.449165","long":"2.9000044","pm25":""},{"location_name":"FR28022","location_id":"2772","lat":"50.308872","long":"2.80737","pm25":""},{"location_name":"FR28028","location_id":"2773","lat":"50.535404","long":"2.635693","pm25":""},{"location_name":"FR28033","location_id":"2774","lat":"50.489704","long":"2.6664243","pm25":""},{"location_name":"FR29423","location_id":"2775","lat":"46.04111","long":"4.0746593","pm25":""},{"location_name":"FR29424","location_id":"2776","lat":"45.42009","long":"4.3954206","pm25":""},{"location_name":"FR29426","location_id":"2777","lat":"45.475296","long":"4.5150046","pm25":""},{"location_name":"FR29429","location_id":"2779","lat":"45.533405","long":"4.6239433","pm25":""},{"location_name":"FR29439","location_id":"2780","lat":"45.481785","long":"4.4296646","pm25":""},{"location_name":"FR30016","location_id":"2781","lat":"48.685825","long":"6.175109","pm25":""},{"location_name":"FR30018","location_id":"2782","lat":"48.02461","long":"6.585837","pm25":""},{"location_name":"FR30019","location_id":"2783","lat":"48.172794","long":"6.452814","pm25":""},{"location_name":"FR30020","location_id":"2784","lat":"48.775833","long":"5.1627884","pm25":""},{"location_name":"FR30021","location_id":"2785","lat":"48.6215","long":"6.194926","pm25":""},{"location_name":"FR30023","location_id":"2786","lat":"48.633316","long":"6.304826","pm25":""},{"location_name":"FR30026","location_id":"2787","lat":"48.584846","long":"6.483896","pm25":""},{"location_name":"FR30027","location_id":"2788","lat":"48.56547","long":"6.1295824","pm25":""},{"location_name":"FR30028","location_id":"2789","lat":"48.051098","long":"7.0111175","pm25":""},{"location_name":"FR30029","location_id":"2790","lat":"48.193638","long":"5.9372263","pm25":""},{"location_name":"FR30030","location_id":"2791","lat":"48.614906","long":"6.1076727","pm25":""},{"location_name":"FR30032","location_id":"2792","lat":"48.69472","long":"6.9652762","pm25":""},{"location_name":"FR30033","location_id":"2793","lat":"49.065838","long":"5.785555","pm25":""},{"location_name":"FR30034","location_id":"2794","lat":"48.688198","long":"6.1904345","pm25":""},{"location_name":"FR30036","location_id":"2795","lat":"48.696323","long":"6.1461205","pm25":""},{"location_name":"FR30037","location_id":"2796","lat":"48.656937","long":"6.1360235","pm25":""},{"location_name":"FR31001","location_id":"2798","lat":"44.861412","long":"-0.5794439","pm25":""},{"location_name":"FR31002","location_id":"2799","lat":"44.80057","long":"-0.588056","pm25":""},{"location_name":"FR31003","location_id":"2800","lat":"44.849693","long":"-0.54388857","pm25":""},{"location_name":"FR31006","location_id":"2802","lat":"44.84139","long":"-0.65","pm25":""},{"location_name":"FR31007","location_id":"2803","lat":"44.900303","long":"-0.5147221","pm25":""},{"location_name":"FR31008","location_id":"2804","lat":"44.86555","long":"-0.93944013","pm25":""},{"location_name":"FR31010","location_id":"2805","lat":"45.01225","long":"-0.52833337","pm25":""},{"location_name":"FR31013","location_id":"2806","lat":"43.310806","long":"-0.3911112","pm25":""},{"location_name":"FR31016","location_id":"2808","lat":"43.479736","long":"-1.4880593","pm25":""},{"location_name":"FR31017","location_id":"2809","lat":"43.49414","long":"-1.5277737","pm25":""},{"location_name":"FR31020","location_id":"2810","lat":"43.410538","long":"-0.6169441","pm25":""},{"location_name":"FR31021","location_id":"2811","lat":"43.37611","long":"-0.536944","pm25":""},{"location_name":"FR31022","location_id":"2812","lat":"43.409687","long":"-0.67166674","pm25":""},{"location_name":"FR31023","location_id":"2813","lat":"43.434155","long":"-0.6919444","pm25":""},{"location_name":"FR31024","location_id":"2814","lat":"43.37692","long":"-0.609444","pm25":""},{"location_name":"FR31026","location_id":"2815","lat":"43.83835","long":"-0.81083286","pm25":""},{"location_name":"FR31033","location_id":"2819","lat":"45.189728","long":"0.72722214","pm25":""},{"location_name":"FR31034","location_id":"2820","lat":"45.012222","long":"-0.529722","pm25":""},{"location_name":"FR31036","location_id":"2821","lat":"43.70472","long":"-1.0386142","pm25":""},{"location_name":"FR31039","location_id":"2822","lat":"43.31107","long":"-0.35211894","pm25":""},{"location_name":"FR31040","location_id":"2823","lat":"44.508667","long":"0.14250335","pm25":""},{"location_name":"FR31041","location_id":"2824","lat":"43.896053","long":"-0.49061668","pm25":""},{"location_name":"FR31043","location_id":"2825","lat":"43.47022","long":"-1.5538429","pm25":""},{"location_name":"FR32001","location_id":"2826","lat":"46.78247","long":"4.8472643","pm25":""},{"location_name":"FR32002","location_id":"2827","lat":"46.82109","long":"4.8350024","pm25":""},{"location_name":"FR32005","location_id":"2828","lat":"46.66664","long":"4.366666","pm25":""},{"location_name":"FR32006","location_id":"2829","lat":"46.3161","long":"4.839997","pm25":""},{"location_name":"FR32007","location_id":"2830","lat":"46.802216","long":"4.4175014","pm25":""},{"location_name":"FR33101","location_id":"2832","lat":"45.564735","long":"5.928333","pm25":""},{"location_name":"FR33102","location_id":"2833","lat":"45.596676","long":"5.918613","pm25":""},{"location_name":"FR33105","location_id":"2834","lat":"45.56945","long":"5.9329863","pm25":""},{"location_name":"FR33111","location_id":"2835","lat":"45.274723","long":"6.349722","pm25":""},{"location_name":"FR33120","location_id":"2837","lat":"45.92251","long":"6.870001","pm25":""},{"location_name":"FR33121","location_id":"2838","lat":"45.675","long":"6.3897257","pm25":""},{"location_name":"FR33122","location_id":"2839","lat":"45.535862","long":"6.4711127","pm25":""},{"location_name":"FR33201","location_id":"2840","lat":"45.895256","long":"6.1183357","pm25":""},{"location_name":"FR33202","location_id":"2841","lat":"45.916946","long":"6.135556","pm25":""},{"location_name":"FR33203","location_id":"2842","lat":"45.9097","long":"6.1182456","pm25":""},{"location_name":"FR33211","location_id":"2843","lat":"46.19583","long":"6.240556","pm25":""},{"location_name":"FR33212","location_id":"2844","lat":"46.193672","long":"6.2148595","pm25":""},{"location_name":"FR33220","location_id":"2845","lat":"45.923634","long":"6.713613","pm25":""},{"location_name":"FR33232","location_id":"2846","lat":"45.907196","long":"6.845836","pm25":""},{"location_name":"FR33302","location_id":"2847","lat":"46.07222","long":"5.8208313","pm25":""},{"location_name":"FR33305","location_id":"2848","lat":"46.211643","long":"5.2263894","pm25":""},{"location_name":"FR34013","location_id":"2849","lat":"47.907078","long":"1.9011406","pm25":""},{"location_name":"FR34014","location_id":"2850","lat":"47.917374","long":"1.9662595","pm25":""},{"location_name":"FR34017","location_id":"2851","lat":"47.95896","long":"2.0092888","pm25":""},{"location_name":"FR34018","location_id":"2852","lat":"47.99793","long":"2.7195148","pm25":""},{"location_name":"FR34024","location_id":"2853","lat":"47.34415","long":"0.6537759","pm25":""},{"location_name":"FR34025","location_id":"2854","lat":"47.419086","long":"0.6829406","pm25":""},{"location_name":"FR34026","location_id":"2855","lat":"47.46945","long":"0.7169436","pm25":""},{"location_name":"FR34028","location_id":"2856","lat":"47.394646","long":"0.70487297","pm25":""},{"location_name":"FR34029","location_id":"2857","lat":"47.837784","long":"1.944655","pm25":""},{"location_name":"FR34030","location_id":"2858","lat":"47.07503","long":"2.4071796","pm25":""},{"location_name":"FR34032","location_id":"2859","lat":"47.0828","long":"2.405329","pm25":""},{"location_name":"FR34038","location_id":"2860","lat":"46.81482","long":"2.610082","pm25":""},{"location_name":"FR34041","location_id":"2861","lat":"48.444412","long":"1.5101489","pm25":""},{"location_name":"FR34043","location_id":"2863","lat":"48.39117","long":"1.9556234","pm25":""},{"location_name":"FR34046","location_id":"2864","lat":"48.73141","long":"1.3638852","pm25":""},{"location_name":"FR34047","location_id":"2865","lat":"48.76091","long":"1.2336473","pm25":""},{"location_name":"FR34051","location_id":"2866","lat":"46.79828","long":"1.6931267","pm25":""},{"location_name":"FR34054","location_id":"2867","lat":"47.170143","long":"1.4096812","pm25":""},{"location_name":"FR34056","location_id":"2868","lat":"46.864532","long":"1.7719538","pm25":""},{"location_name":"FR34057","location_id":"2869","lat":"46.942966","long":"2.003261","pm25":""},{"location_name":"FR34061","location_id":"2870","lat":"47.594517","long":"1.3017397","pm25":""},{"location_name":"FR35002","location_id":"2871","lat":"45.890007","long":"0.9000041","pm25":""},{"location_name":"FR35004","location_id":"2873","lat":"45.15876","long":"1.537224","pm25":""},{"location_name":"FR35005","location_id":"2874","lat":"46.169975","long":"1.869996","pm25":""},{"location_name":"FR35006","location_id":"2875","lat":"45.26002","long":"1.7599972","pm25":""},{"location_name":"FR35007","location_id":"2876","lat":"45.869995","long":"1.3100042","pm25":""},{"location_name":"FR35010","location_id":"2877","lat":"45.83333","long":"1.216804","pm25":""},{"location_name":"FR35012","location_id":"2878","lat":"45.80998","long":"2.0599988","pm25":""},{"location_name":"FR35019","location_id":"2879","lat":"45.87581","long":"0.82388896","pm25":""},{"location_name":"FR36001","location_id":"2881","lat":"44.870262","long":"4.876289","pm25":""},{"location_name":"FR36002","location_id":"2882","lat":"44.93351","long":"4.8934827","pm25":""},{"location_name":"FR36007","location_id":"2884","lat":"44.67595","long":"4.673584","pm25":""},{"location_name":"FR36019","location_id":"2885","lat":"45.04247","long":"5.044301","pm25":""},{"location_name":"FR36021","location_id":"2886","lat":"44.56943","long":"5.278968","pm25":""},{"location_name":"FR37001","location_id":"2887","lat":"16.256104","long":"-61.590294","pm25":""},{"location_name":"FR37007","location_id":"2889","lat":"16.25067","long":"-61.52795","pm25":""},{"location_name":"FR38002","location_id":"2891","lat":"-20.903284","long":"55.468365","pm25":""},{"location_name":"FR38008","location_id":"2892","lat":"-20.884737","long":"55.45381","pm25":""},{"location_name":"FR38009","location_id":"2893","lat":"-20.910585","long":"55.61901","pm25":""},{"location_name":"FR38011","location_id":"2894","lat":"-21.334423","long":"55.459023","pm25":""},{"location_name":"FR38014","location_id":"2895","lat":"-21.312918","long":"55.4742","pm25":""},{"location_name":"FR38016","location_id":"2896","lat":"-21.204836","long":"55.58263","pm25":""},{"location_name":"FR38017","location_id":"2897","lat":"-21.294338","long":"55.627903","pm25":""},{"location_name":"FR38018","location_id":"2898","lat":"-20.949768","long":"55.313854","pm25":""},{"location_name":"FR38020","location_id":"2899","lat":"-21.009739","long":"55.27271","pm25":""},{"location_name":"FR38021","location_id":"2900","lat":"-21.03213","long":"55.232555","pm25":""},{"location_name":"FR38023","location_id":"2901","lat":"-21.331663","long":"55.478962","pm25":""},{"location_name":"FR38098","location_id":"2903","lat":"-21.277094","long":"55.403057","pm25":""},{"location_name":"FR39003","location_id":"2904","lat":"14.603527","long":"-61.04124","pm25":""},{"location_name":"FR39009","location_id":"2906","lat":"14.610743","long":"-61.002613","pm25":""},{"location_name":"FR39014","location_id":"2909","lat":"14.468832","long":"-60.927425","pm25":""},{"location_name":"FR39015","location_id":"2910","lat":"14.6661","long":"-61.1518","pm25":""},{"location_name":"FR39016","location_id":"2911","lat":"14.6781","long":"-60.939102","pm25":""},{"location_name":"FR39017","location_id":"2912","lat":"14.600572","long":"-61.08571","pm25":""},{"location_name":"FR40007","location_id":"2914","lat":"4.848161","long":"-52.32381","pm25":""},{"location_name":"FR40008","location_id":"2915","lat":"4.9378443","long":"-52.32094","pm25":""},{"location_name":"FR41001","location_id":"2916","lat":"41.924656","long":"8.735694","pm25":""},{"location_name":"FR41002","location_id":"2917","lat":"42.69789","long":"9.446414","pm25":""},{"location_name":"FR41003","location_id":"2918","lat":"41.964443","long":"8.820278","pm25":""},{"location_name":"FR41004","location_id":"2919","lat":"42.535797","long":"9.475968","pm25":""},{"location_name":"FR41007","location_id":"2920","lat":"41.94925","long":"8.757586","pm25":""},{"location_name":"FR41017","location_id":"2921","lat":"42.671345","long":"9.434646","pm25":""},{"location_name":"FR41024","location_id":"2924","lat":"42.236088","long":"9.190035","pm25":""},{"location_name":"FR82001","location_id":"2925","lat":"47.235996","long":"6.023608","pm25":""},{"location_name":"FR82005","location_id":"2927","lat":"47.234592","long":"6.076474","pm25":""},{"location_name":"FR82006","location_id":"2928","lat":"47.2474","long":"6.0154157","pm25":""},{"location_name":"FR82010","location_id":"2929","lat":"47.510303","long":"6.7940035","pm25":""},{"location_name":"FR82012","location_id":"2930","lat":"47.538208","long":"6.868357","pm25":""},{"location_name":"FR82020","location_id":"2931","lat":"47.64066","long":"6.859275","pm25":""},{"location_name":"FR82030","location_id":"2933","lat":"47.29464","long":"6.8258576","pm25":""},{"location_name":"FR82040","location_id":"2934","lat":"47.09675","long":"5.496387","pm25":""},{"location_name":"FR82041","location_id":"2935","lat":"47.0426","long":"5.400896","pm25":""},{"location_name":"FR82042","location_id":"2936","lat":"47.06561","long":"5.4150267","pm25":""},{"location_name":"FR82043","location_id":"2937","lat":"47.147236","long":"5.556116","pm25":""},{"location_name":"FR82050","location_id":"2938","lat":"46.671326","long":"5.5568075","pm25":""},{"location_name":"FR82060","location_id":"2939","lat":"47.620014","long":"6.15761","pm25":""},{"location_name":"FR82070","location_id":"2940","lat":"47.35127","long":"6.3597217","pm25":""},{"location_name":"FRANCHINI-ANGELONI","location_id":"2941","lat":"44.1414","long":"12.2447","pm25":""},{"location_name":"FRANCONIA","location_id":"2942","lat":"38.7717","long":"-77.1089","pm25":""},{"location_name":"FRAYSER","location_id":"2945","lat":"35.2175","long":"-90.0194","pm25":""},{"location_name":"FREDERICTON-NEEDHAM","location_id":"2947","lat":"45.95729","long":"-66.64523","pm25":""},{"location_name":"Fair Hill","location_id":"2950","lat":"39.7011","long":"-75.86","pm25":""},{"location_name":"Fairfield","location_id":"2951","lat":"38.227066","long":"-122.07562","pm25":""},{"location_name":"Fairgrounds","location_id":"2952","lat":"32.0475","long":"-110.7739","pm25":""},{"location_name":"Fairhaven2","location_id":"2953","lat":"41.6454","long":"-70.898","pm25":""},{"location_name":"Fairland","location_id":"2954","lat":"39.613365","long":"-85.87067","pm25":""},{"location_name":"Falcon Field Police","location_id":"2956","lat":"33.4522","long":"-111.7331","pm25":""},{"location_name":"Fall River","location_id":"2957","lat":"41.6833","long":"-71.1697","pm25":""},{"location_name":"Fallon","location_id":"2958","lat":"39.47247","long":"-118.78362","pm25":""},{"location_name":"Faro","location_id":"2959","lat":"42.098904","long":"11.817692","pm25":""},{"location_name":"Farrell","location_id":"2961","lat":"41.215","long":"-80.485","pm25":""},{"location_name":"Fayetteville","location_id":"2965","lat":"36.011703","long":"-94.167435","pm25":""},{"location_name":"Felton Cal-Fire","location_id":"2969","lat":"37.0481","long":"-122.0746","pm25":""},{"location_name":"Fengshan","location_id":"2970","lat":"22.627392","long":"120.358086","pm25":""},{"location_name":"Ferentino","location_id":"2971","lat":"41.69","long":"13.250411","pm25":""},{"location_name":"Fermi","location_id":"2972","lat":"41.864193","long":"12.469531","pm25":""},{"location_name":"Fernley","location_id":"2974","lat":"39.602737","long":"-119.247856","pm25":""},{"location_name":"Fijnaart-Zwingelspaansedijk","location_id":"2977","lat":"51.6537","long":"4.51527","pm25":""},{"location_name":"Fire Station 13","location_id":"2979","lat":"41.471783","long":"-81.65679","pm25":""},{"location_name":"Firearms Training","location_id":"2980","lat":"38.23158","long":"-85.82675","pm25":""},{"location_name":"Fisherman's Landing","location_id":"2981","lat":"-23.7937","long":"151.16","pm25":""},{"location_name":"Fiumaretta","location_id":"2983","lat":"42.102158","long":"11.784358","pm25":""},{"location_name":"Fiumicino Porto","location_id":"2984","lat":"41.77485","long":"12.223413","pm25":""},{"location_name":"Fiumicino Villa Guglielmi","location_id":"2985","lat":"41.76819","long":"12.237048","pm25":""},{"location_name":"Fl. Baptist Children","location_id":"2986","lat":"28.0294","long":"-81.9719","pm25":""},{"location_name":"Flagler County","location_id":"2987","lat":"29.489082","long":"-81.27683","pm25":""},{"location_name":"Flagstaff Middle Sch","location_id":"2988","lat":"35.206112","long":"-111.65278","pm25":""},{"location_name":"Flat Valley","location_id":"2989","lat":"54.29464","long":"-109.20921","pm25":""},{"location_name":"Flemington","location_id":"2991","lat":"40.51525","long":"-74.806755","pm25":""},{"location_name":"Flinders View","location_id":"2993","lat":"-27.6528","long":"152.774","pm25":""},{"location_name":"Flora","location_id":"2994","lat":"40.540558","long":"-86.553055","pm25":""},{"location_name":"Florence","location_id":"2995","lat":"40.4447","long":"-80.42","pm25":""},{"location_name":"Florianka RPN","location_id":"2996","lat":"50.551895","long":"22.98286","pm25":""},{"location_name":"Floyd Dryden","location_id":"2998","lat":"58.38889","long":"-134.56555","pm25":""},{"location_name":"Fond du Lac","location_id":"3003","lat":"46.713696","long":"-92.51172","pm25":""},{"location_name":"Fontana - Arrow High","location_id":"3005","lat":"34.100132","long":"-117.49198","pm25":""},{"location_name":"Fontechiari","location_id":"3006","lat":"41.67","long":"13.674472","pm25":""},{"location_name":"Forest Park","location_id":"3007","lat":"38.631058","long":"-90.28114","pm25":""},{"location_name":"Fort Bragg High Scho","location_id":"3010","lat":"39.43734","long":"-123.78766","pm25":""},{"location_name":"Fort Chipewyan","location_id":"3011","lat":"58.7083","long":"-111.1764","pm25":""},{"location_name":"Fort Collins - CSU -","location_id":"3012","lat":"40.5764","long":"-105.0794","pm25":""},{"location_name":"Fort Collins - West","location_id":"3013","lat":"40.59254","long":"-105.1411","pm25":""},{"location_name":"Fort Independence Me","location_id":"3014","lat":"36.8028","long":"-118.1167","pm25":""},{"location_name":"Fort Lee Near Road","location_id":"3016","lat":"40.85355","long":"-73.9661","pm25":""},{"location_name":"Fort McKay","location_id":"3017","lat":"57.1889","long":"-111.6406","pm25":""},{"location_name":"Fort Saskatchewan","location_id":"3019","lat":"53.6989","long":"-113.2233","pm25":""},{"location_name":"Fort Wayne-Beacon St","location_id":"3020","lat":"41.094967","long":"-85.101814","pm25":""},{"location_name":"Fort William","location_id":"3021","lat":"56.82266","long":"-5.101102","pm25":""},{"location_name":"Fountain Hills","location_id":"3025","lat":"33.611","long":"-111.7253","pm25":""},{"location_name":"Francia","location_id":"3026","lat":"41.94745","long":"12.469588","pm25":""},{"location_name":"Fran\u00e7ois","location_id":"3029","lat":"47.0147","long":"-70.8644","pm25":""},{"location_name":"Freedom 7 Elementary","location_id":"3031","lat":"28.3108","long":"-80.6156","pm25":""},{"location_name":"Freemansburg","location_id":"3033","lat":"40.6281","long":"-75.3411","pm25":""},{"location_name":"Frelighsburg","location_id":"3035","lat":"45.0517","long":"-72.8617","pm25":""},{"location_name":"French Settlement","location_id":"3036","lat":"30.315","long":"-90.8114","pm25":""},{"location_name":"French Town - Beckwi","location_id":"3037","lat":"47.012905","long":"-114.22427","pm25":""},{"location_name":"Fresh Kills","location_id":"3038","lat":"40.5802","long":"-74.1994","pm25":""},{"location_name":"Fresno - Drummond St","location_id":"3039","lat":"36.7056","long":"-119.7414","pm25":""},{"location_name":"Fresno - Garland","location_id":"3040","lat":"36.78538","long":"-119.77321","pm25":""},{"location_name":"Frisco C31","location_id":"3042","lat":"33.1325","long":"-96.7861","pm25":""},{"location_name":"Front Street","location_id":"3043","lat":"39.13198","long":"-94.53128","pm25":""},{"location_name":"Frosinone Mazzini","location_id":"3044","lat":"41.639668","long":"13.348913","pm25":""},{"location_name":"Frosinone Scalo","location_id":"3045","lat":"41.62","long":"13.33081","pm25":""},{"location_name":"Ft McD Yuma Frank-AZ","location_id":"3047","lat":"33.6292","long":"-111.6769","pm25":""},{"location_name":"Ft. Collins - CSU Fa","location_id":"3048","lat":"40.57126","long":"-105.079765","pm25":""},{"location_name":"Ft. Gibson","location_id":"3049","lat":"35.775803","long":"-95.28716","pm25":""},{"location_name":"Ft. Worth Northwest","location_id":"3050","lat":"32.805817","long":"-97.35657","pm25":""},{"location_name":"FugueiCape","location_id":"3051","lat":"25.297436","long":"121.53797","pm25":""},{"location_name":"Fulton","location_id":"3053","lat":"43.28428","long":"-76.46318","pm25":""},{"location_name":"Furulund","location_id":"3055","lat":"59.057304","long":"9.695568","pm25":""},{"location_name":"Fuxing","location_id":"3056","lat":"22.608711","long":"120.31202","pm25":""},{"location_name":"G.T.Craig","location_id":"3060","lat":"41.49219","long":"-81.67855","pm25":""},{"location_name":"GANDY","location_id":"3062","lat":"27.8928","long":"-82.5383","pm25":""},{"location_name":"GARDINIER","location_id":"3064","lat":"27.864273","long":"-82.38336","pm25":""},{"location_name":"GARINGER","location_id":"3065","lat":"35.2411","long":"-80.7831","pm25":""},{"location_name":"GAVELLO","location_id":"3066","lat":"44.9288","long":"11.1789","pm25":""},{"location_name":"GC_MAD","location_id":"3079","lat":"38.7045","long":"-90.1397","pm25":""},{"location_name":"GERBIDO","location_id":"3080","lat":"45.0559","long":"9.7479","pm25":""},{"location_name":"GHERARDI","location_id":"3081","lat":"44.8397","long":"11.9613","pm25":""},{"location_name":"GIARDINI","location_id":"3082","lat":"44.637","long":"10.9057","pm25":""},{"location_name":"GIARDINI MARGHERITA","location_id":"3083","lat":"44.4836","long":"11.355","pm25":""},{"location_name":"GIORDANI-FARNESE","location_id":"3085","lat":"45.0488","long":"9.6933","pm25":""},{"location_name":"GIR-IECO - Institucion Educativa Colombia. Girardota","location_id":"3086","lat":"6.378361","long":"-75.443886","pm25":""},{"location_name":"GIR-SOSN - Girardota - S.O.S Aburr\u00e1 Norte","location_id":"3087","lat":"6.378433","long":"-75.45114","pm25":""},{"location_name":"GPORT YC","location_id":"3088","lat":"30.39","long":"-89.0497","pm25":""},{"location_name":"GRAND RAPIDS","location_id":"3090","lat":"42.9847","long":"-85.6711","pm25":""},{"location_name":"GREEN BAY E HIGH","location_id":"3092","lat":"44.5167","long":"-87.9939","pm25":""},{"location_name":"Gaeta","location_id":"3096","lat":"41.223076","long":"13.570481","pm25":""},{"location_name":"Gainesville","location_id":"3097","lat":"34.3003","long":"-83.8139","pm25":""},{"location_name":"Gajew","location_id":"3098","lat":"52.14325","long":"19.233225","pm25":""},{"location_name":"Galleria","location_id":"3099","lat":"41.50466","long":"-81.690186","pm25":""},{"location_name":"Galveston Airport C1","location_id":"3101","lat":"29.2631","long":"-94.8564","pm25":""},{"location_name":"Garden","location_id":"3105","lat":"61.20586","long":"-149.8246","pm25":""},{"location_name":"Garden City","location_id":"3106","lat":"43.64789","long":"-116.26941","pm25":""},{"location_name":"Garden Valley","location_id":"3107","lat":"44.1045","long":"-115.97239","pm25":""},{"location_name":"Gardiner","location_id":"3108","lat":"44.23062","long":"-69.785","pm25":""},{"location_name":"Gartnerl\u00f8kka","location_id":"3109","lat":"58.14703","long":"7.98662","pm25":""},{"location_name":"Gary-IITRI","location_id":"3110","lat":"41.6067","long":"-87.3047","pm25":""},{"location_name":"Garyville","location_id":"3111","lat":"30.0494","long":"-90.6367","pm25":""},{"location_name":"Geleen-Asterstraat","location_id":"3116","lat":"50.9844","long":"5.82223","pm25":""},{"location_name":"Geleen-Vouershof","location_id":"3117","lat":"50.9631","long":"5.8107","pm25":""},{"location_name":"Georgia Station","location_id":"3120","lat":"33.1787","long":"-84.4052","pm25":""},{"location_name":"Geronimo","location_id":"3122","lat":"32.25","long":"-110.9667","pm25":""},{"location_name":"Gilory - 9th Street","location_id":"3124","lat":"36.999573","long":"-121.574684","pm25":""},{"location_name":"Gjilan","location_id":"3126","lat":"42.461143","long":"21.467201","pm25":""},{"location_name":"Glacier NP","location_id":"3127","lat":"48.5103","long":"-113.9956","pm25":""},{"location_name":"Glasgow Great Western Road","location_id":"3128","lat":"55.87204","long":"-4.270936","pm25":""},{"location_name":"Glasgow High Street","location_id":"3129","lat":"55.860935","long":"-4.238214","pm25":""},{"location_name":"Glasgow Kerbside","location_id":"3130","lat":"55.85917","long":"-4.258889","pm25":""},{"location_name":"Glasgow Townhead","location_id":"3131","lat":"55.865784","long":"-4.243631","pm25":""},{"location_name":"Glazebury","location_id":"3132","lat":"53.46008","long":"-2.472056","pm25":""},{"location_name":"Glen Oaks","location_id":"3134","lat":"36.19347","long":"-116.00758","pm25":""},{"location_name":"Glendale Community C","location_id":"3135","lat":"33.5694","long":"-112.1915","pm25":""},{"location_name":"Glendora - Laurel","location_id":"3136","lat":"34.1439","long":"-117.8508","pm25":""},{"location_name":"Glenpool","location_id":"3138","lat":"35.9525","long":"-96.0033","pm25":""},{"location_name":"Gliwice, ul. Mewy 34","location_id":"3141","lat":"50.27933","long":"18.655764","pm25":""},{"location_name":"Globeville","location_id":"3142","lat":"39.78562","long":"-104.98847","pm25":""},{"location_name":"Gocza\u0142kowice Zdr\u00f3j, ul. Parkowa","location_id":"3143","lat":"49.93785","long":"18.975594","pm25":""},{"location_name":"Golden - NREL - 2054","location_id":"3144","lat":"39.7419","long":"-105.1786","pm25":""},{"location_name":"Goleta","location_id":"3148","lat":"34.4453","long":"-119.8278","pm25":""},{"location_name":"Goodland","location_id":"3151","lat":"39.3428","long":"-101.702995","pm25":""},{"location_name":"Goose Bay","location_id":"3152","lat":"53.3047","long":"-60.3644","pm25":""},{"location_name":"Gorz\u00f3w Wlkp. ul. Kosynier\u00f3w Gdy\u0144skich","location_id":"3153","lat":"52.738213","long":"15.228667","pm25":""},{"location_name":"Gothic","location_id":"3154","lat":"38.9564","long":"-106.9858","pm25":""},{"location_name":"Granbury C73","location_id":"3157","lat":"32.4419","long":"-97.8033","pm25":""},{"location_name":"Grand Bend","location_id":"3158","lat":"43.3306","long":"-81.7425","pm25":""},{"location_name":"Grand Canyon NP","location_id":"3159","lat":"36.055","long":"-112.1531","pm25":""},{"location_name":"Grand Falls Windsor","location_id":"3160","lat":"49.0194","long":"-55.8028","pm25":""},{"location_name":"Grand Portage","location_id":"3163","lat":"47.9721","long":"-89.6908","pm25":""},{"location_name":"Grand Teton NP - Sci","location_id":"3164","lat":"43.67083","long":"-110.5994","pm25":""},{"location_name":"Grangemouth","location_id":"3165","lat":"56.01032","long":"-3.704399","pm25":""},{"location_name":"Grangemouth Moray","location_id":"3166","lat":"56.01314","long":"-3.710833","pm25":""},{"location_name":"Granger-Beckley St.","location_id":"3167","lat":"41.75487","long":"-86.11009","pm25":""},{"location_name":"Grangeville","location_id":"3168","lat":"45.9313","long":"-116.1152","pm25":""},{"location_name":"Granica-KPN","location_id":"3169","lat":"52.28586","long":"20.454653","pm25":""},{"location_name":"Grants Pass - Parksi","location_id":"3170","lat":"42.43415","long":"-123.348465","pm25":""},{"location_name":"Grapevine Fairway C7","location_id":"3171","lat":"32.98426","long":"-97.063705","pm25":""},{"location_name":"Grass Valley","location_id":"3172","lat":"39.2344","long":"-121.0556","pm25":""},{"location_name":"Great Basin NP","location_id":"3187","lat":"39.0053","long":"-114.2158","pm25":""},{"location_name":"Great Falls Overlook","location_id":"3189","lat":"47.494316","long":"-111.303314","pm25":""},{"location_name":"Greeley - Weld Co. T","location_id":"3192","lat":"40.3861","long":"-104.7367","pm25":""},{"location_name":"Greeley Hospital","location_id":"3193","lat":"40.4147","long":"-104.7061","pm25":""},{"location_name":"Green Valley","location_id":"3194","lat":"31.8794","long":"-110.9964","pm25":""},{"location_name":"GreenValley","location_id":"3195","lat":"36.048706","long":"-115.05294","pm25":""},{"location_name":"Greenfield","location_id":"3196","lat":"42.605816","long":"-72.59669","pm25":""},{"location_name":"Greenock A8 Roadside","location_id":"3197","lat":"55.94408","long":"-4.734421","pm25":""},{"location_name":"Greensburg","location_id":"3198","lat":"40.3053","long":"-79.5061","pm25":""},{"location_name":"Greenville C1006\/198","location_id":"3199","lat":"33.153076","long":"-96.11556","pm25":""},{"location_name":"Greenville-ESC","location_id":"3200","lat":"34.8439","long":"-82.4146","pm25":""},{"location_name":"Gridley","location_id":"3205","lat":"39.32756","long":"-121.66881","pm25":""},{"location_name":"Grimmerhaugen","location_id":"3206","lat":"62.47217","long":"6.15682","pm25":""},{"location_name":"Groningen-Europaweg","location_id":"3207","lat":"53.2178","long":"6.5789","pm25":""},{"location_name":"Groningen-Nijensteinheerd","location_id":"3208","lat":"53.2465","long":"6.60894","pm25":""},{"location_name":"Groton Fort Griswold","location_id":"3209","lat":"41.3536","long":"-72.0789","pm25":""},{"location_name":"Grudzi\u0105dz Airpointer","location_id":"3211","lat":"53.49355","long":"18.762138","pm25":""},{"location_name":"Guangzhou","location_id":"3218","lat":"23.12","long":"113.32","pm25":""},{"location_name":"Guatemala City","location_id":"3222","lat":"14.989397","long":"-90.52241","pm25":""},{"location_name":"Guidonia","location_id":"3223","lat":"41.995678","long":"12.726371","pm25":""},{"location_name":"Guting","location_id":"3224","lat":"25.020609","long":"121.52956","pm25":""},{"location_name":"Guty Du\u017ce","location_id":"3225","lat":"52.943172","long":"21.288168","pm25":""},{"location_name":"Gwinnett Tech","location_id":"3226","lat":"33.9636","long":"-84.0664","pm25":""},{"location_name":"HAMPTON","location_id":"3237","lat":"37.103683","long":"-76.38695","pm25":""},{"location_name":"HARRINGTON BCH","location_id":"3240","lat":"43.4981","long":"-87.81","pm25":""},{"location_name":"HATTIEAVEN","location_id":"3241","lat":"36.1106","long":"-80.2267","pm25":""},{"location_name":"HAZ2","location_id":"3242","lat":"37.2831","long":"-83.2203","pm25":""},{"location_name":"HERNANDO","location_id":"3244","lat":"34.820557","long":"-89.98778","pm25":""},{"location_name":"HICKORY","location_id":"3245","lat":"35.72889","long":"-81.365555","pm25":""},{"location_name":"Higley","location_id":"3246","lat":"33.3107","long":"-111.7225","pm25":""},{"location_name":"HILAIRE","location_id":"3247","lat":"45.8156","long":"-70.8597","pm25":""},{"location_name":"HOUGHTON LAKE","location_id":"3250","lat":"44.3106","long":"-84.8919","pm25":""},{"location_name":"HOUSTON","location_id":"3251","lat":"38.1761","long":"-89.7883","pm25":""},{"location_name":"HR0002A","location_id":"3252","lat":"45.479057","long":"16.780666","pm25":""},{"location_name":"HR0003A","location_id":"3253","lat":"45.558792","long":"18.698769","pm25":""},{"location_name":"HR0005A","location_id":"3254","lat":"45.320793","long":"14.483511","pm25":""},{"location_name":"HR0006A","location_id":"3255","lat":"45.458126","long":"16.388355","pm25":""},{"location_name":"HR0007A","location_id":"3256","lat":"45.80034","long":"15.974072","pm25":""},{"location_name":"HR0009A","location_id":"3257","lat":"45.764946","long":"16.00647","pm25":""},{"location_name":"HR0010A","location_id":"3258","lat":"45.159473","long":"17.9951","pm25":""},{"location_name":"HR0011A","location_id":"3259","lat":"45.69803","long":"18.834639","pm25":""},{"location_name":"HR0012A","location_id":"3260","lat":"46.169056","long":"15.660639","pm25":""},{"location_name":"HR0013A","location_id":"3261","lat":"44.899334","long":"15.609777","pm25":""},{"location_name":"HR0014A","location_id":"3262","lat":"45.59348","long":"14.630464","pm25":""},{"location_name":"HR0015A","location_id":"3263","lat":"45.291203","long":"13.749778","pm25":""},{"location_name":"HR0018A","location_id":"3264","lat":"43.031334","long":"16.115973","pm25":""},{"location_name":"HR0020A","location_id":"3265","lat":"42.6447","long":"18.122612","pm25":""},{"location_name":"HR0022A","location_id":"3266","lat":"43.510654","long":"16.44934","pm25":""},{"location_name":"HR0023A","location_id":"3267","lat":"43.54812","long":"16.434961","pm25":""},{"location_name":"HR0025A","location_id":"3268","lat":"44.86247","long":"13.816858","pm25":""},{"location_name":"HR0026A","location_id":"3269","lat":"45.714844","long":"16.068254","pm25":""},{"location_name":"HU-Beltsville","location_id":"3271","lat":"39.0553","long":"-76.8783","pm25":""},{"location_name":"HU0022A","location_id":"3273","lat":"47.430836","long":"19.184174","pm25":""},{"location_name":"HU0023A","location_id":"3274","lat":"47.513332","long":"21.624445","pm25":""},{"location_name":"HU0024A","location_id":"3275","lat":"47.68528","long":"17.639444","pm25":""},{"location_name":"HU0025A","location_id":"3276","lat":"47.676113","long":"17.64974","pm25":""},{"location_name":"HU0026A","location_id":"3277","lat":"48.247223","long":"20.616404","pm25":""},{"location_name":"HU0027A","location_id":"3278","lat":"48.106915","long":"20.78998","pm25":""},{"location_name":"HU0028A","location_id":"3279","lat":"47.961113","long":"21.70584","pm25":""},{"location_name":"HU0029A","location_id":"3280","lat":"46.080276","long":"18.211123","pm25":""},{"location_name":"HU0030A","location_id":"3281","lat":"46.07111","long":"18.225286","pm25":""},{"location_name":"HU0031A","location_id":"3282","lat":"47.55722","long":"18.420835","pm25":""},{"location_name":"HU0032A","location_id":"3283","lat":"47.306667","long":"18.920002","pm25":""},{"location_name":"HU0033A","location_id":"3284","lat":"46.976112","long":"18.936113","pm25":""},{"location_name":"HU0034A","location_id":"3285","lat":"47.09111","long":"17.901121","pm25":""},{"location_name":"HU0035A","location_id":"3286","lat":"47.691944","long":"16.575008","pm25":""},{"location_name":"HU0036A","location_id":"3287","lat":"47.561943","long":"18.960009","pm25":""},{"location_name":"HU0037A","location_id":"3288","lat":"47.105278","long":"17.556665","pm25":""},{"location_name":"HU0038A","location_id":"3289","lat":"48.218056","long":"20.703058","pm25":""},{"location_name":"HU0039A","location_id":"3290","lat":"47.790005","long":"18.746134","pm25":""},{"location_name":"HU0040A","location_id":"3291","lat":"47.671947","long":"16.838896","pm25":""},{"location_name":"HU0041A","location_id":"3292","lat":"47.508057","long":"19.028067","pm25":""},{"location_name":"HU0042A","location_id":"3293","lat":"47.541943","long":"19.146122","pm25":""},{"location_name":"HU0044A","location_id":"3294","lat":"48.47389","long":"21.21168","pm25":""},{"location_name":"HU0045A","location_id":"3295","lat":"47.491943","long":"19.087782","pm25":""},{"location_name":"HU0057A","location_id":"3296","lat":"46.266613","long":"20.153053","pm25":""},{"location_name":"HVILLE","location_id":"3299","lat":"36.2975","long":"-86.6525","pm25":""},{"location_name":"Haarlem-Schipholweg","location_id":"3300","lat":"52.3705","long":"4.64232","pm25":""},{"location_name":"Hackney","location_id":"3301","lat":"39.6323","long":"-81.6701","pm25":""},{"location_name":"Hafod-yr-ynys Roadside","location_id":"3303","lat":"51.68058","long":"-3.133508","pm25":""},{"location_name":"Hagerstown","location_id":"3304","lat":"39.5656","long":"-77.7219","pm25":""},{"location_name":"Hamilton Downtown","location_id":"3317","lat":"43.2561","long":"-79.8617","pm25":""},{"location_name":"Hamilton PS 46","location_id":"3318","lat":"46.24362","long":"-114.15889","pm25":""},{"location_name":"Hammond-141st St","location_id":"3319","lat":"41.6394","long":"-87.4936","pm25":""},{"location_name":"Hammond-167th St","location_id":"3320","lat":"41.594425","long":"-87.49504","pm25":""},{"location_name":"Hamshire C64","location_id":"3321","lat":"29.863953","long":"-94.3178","pm25":""},{"location_name":"Hanford - S. Irwin S","location_id":"3322","lat":"36.3144","long":"-119.6436","pm25":""},{"location_name":"Hani i Elezit","location_id":"3323","lat":"42.15396","long":"21.29601","pm25":""},{"location_name":"Hansjordnesbukta","location_id":"3324","lat":"69.65625","long":"18.96372","pm25":""},{"location_name":"Happy Hill","location_id":"3325","lat":"36.513054","long":"-82.55046","pm25":""},{"location_name":"Haringey Roadside","location_id":"3327","lat":"51.5993","long":"-0.068218","pm25":""},{"location_name":"Harriman","location_id":"3330","lat":"35.9386","long":"-84.5439","pm25":""},{"location_name":"Harrisburg","location_id":"3331","lat":"40.24699","long":"-76.846985","pm25":""},{"location_name":"Harrison Township","location_id":"3332","lat":"40.613865","long":"-79.72957","pm25":""},{"location_name":"Harrisville","location_id":"3333","lat":"41.3028","long":"-111.9883","pm25":""},{"location_name":"Hartford-Huntley","location_id":"3336","lat":"41.771442","long":"-72.679924","pm25":""},{"location_name":"Harvard Yards","location_id":"3338","lat":"41.446682","long":"-81.66242","pm25":""},{"location_name":"Hat Yai, Hat Yai","location_id":"3339","lat":"7.0100007","long":"100.29","pm25":""},{"location_name":"Hattiesburg","location_id":"3340","lat":"31.322779","long":"-89.2875","pm25":""},{"location_name":"Haukenes","location_id":"3341","lat":"59.2024","long":"9.48708","pm25":""},{"location_name":"Haverhill","location_id":"3343","lat":"42.7708","long":"-71.1028","pm25":""},{"location_name":"Havre","location_id":"3344","lat":"48.551018","long":"-109.67748","pm25":""},{"location_name":"Hawaii Volcanoes NP","location_id":"3345","lat":"19.4308","long":"-155.2578","pm25":""},{"location_name":"Haws Athletic Center","location_id":"3346","lat":"32.7592","long":"-97.3414","pm25":""},{"location_name":"Hawthorne","location_id":"3347","lat":"40.7335","long":"-111.8717","pm25":""},{"location_name":"Hayden","location_id":"3348","lat":"33.006268","long":"-110.78648","pm25":""},{"location_name":"Hayward","location_id":"3349","lat":"37.6547","long":"-122.0317","pm25":""},{"location_name":"Healdton","location_id":"3350","lat":"34.2569","long":"-97.4742","pm25":""},{"location_name":"Heerlen-Jamboreepad","location_id":"3353","lat":"50.9003","long":"5.98685","pm25":""},{"location_name":"Heerlen-Looierstraat","location_id":"3354","lat":"50.888","long":"5.9705","pm25":""},{"location_name":"Hellendoorn-Luttenbergerweg","location_id":"3357","lat":"52.3883","long":"6.40293","pm25":""},{"location_name":"Helmsburg","location_id":"3358","lat":"39.263912","long":"-86.29226","pm25":""},{"location_name":"Herculaneum, Mott St","location_id":"3359","lat":"38.263393","long":"-90.37967","pm25":""},{"location_name":"Heritage Park","location_id":"3361","lat":"38.8386","long":"-94.7464","pm25":""},{"location_name":"Hershey","location_id":"3365","lat":"40.2722","long":"-76.6814","pm25":""},{"location_name":"Hesperia - Olive Str","location_id":"3366","lat":"34.416508","long":"-117.2856","pm25":""},{"location_name":"Hiawatha","location_id":"3367","lat":"41.15778","long":"-108.619446","pm25":""},{"location_name":"Hidden Valley","location_id":"3368","lat":"32.88476","long":"-112.03705","pm25":""},{"location_name":"High Muffles","location_id":"3371","lat":"54.334946","long":"-0.80855","pm25":""},{"location_name":"High School","location_id":"3372","lat":"33.508","long":"-111.8378","pm25":""},{"location_name":"Highland Reservoir -","location_id":"3373","lat":"39.5689","long":"-104.9572","pm25":""},{"location_name":"Hillcrest","location_id":"3374","lat":"34.7518","long":"-82.2567","pm25":""},{"location_name":"Hillcrest HS","location_id":"3375","lat":"37.25607","long":"-93.29969","pm25":""},{"location_name":"Hillsboro - Hare Fie","location_id":"3376","lat":"45.5285","long":"-122.9724","pm25":""},{"location_name":"Hilo","location_id":"3377","lat":"19.717562","long":"-155.11053","pm25":""},{"location_name":"Hinds CC","location_id":"3381","lat":"32.346905","long":"-90.22593","pm25":""},{"location_name":"Hiran Ruchi, Thon Buri","location_id":"3382","lat":"13.732878","long":"100.486015","pm25":""},{"location_name":"Hjortnes","location_id":"3383","lat":"59.91132","long":"10.70407","pm25":""},{"location_name":"Hobbs Jefferson","location_id":"3385","lat":"32.7267","long":"-103.1233","pm25":""},{"location_name":"Hochelaga","location_id":"3386","lat":"45.53993","long":"-73.54039","pm25":""},{"location_name":"Hoek v. Holland-Berghaven","location_id":"3390","lat":"51.9778","long":"4.12194","pm25":""},{"location_name":"Holbrook","location_id":"3392","lat":"39.82","long":"-80.2897","pm25":""},{"location_name":"Holiday","location_id":"3394","lat":"28.1953","long":"-82.7578","pm25":""},{"location_name":"Holman Rd","location_id":"3396","lat":"32.4247","long":"-106.6742","pm25":""},{"location_name":"Holta","location_id":"3397","lat":"58.25602","long":"8.35935","pm25":""},{"location_name":"Holtsville","location_id":"3398","lat":"40.8278","long":"-73.0575","pm25":""},{"location_name":"Honiton","location_id":"3401","lat":"50.792286","long":"-3.196702","pm25":""},{"location_name":"Honolulu","location_id":"3402","lat":"21.3103","long":"-157.8581","pm25":""},{"location_name":"Hoofddorp-Hoofdweg","location_id":"3404","lat":"52.3275","long":"4.71501","pm25":""},{"location_name":"Hoogvliet-Leemkuil","location_id":"3405","lat":"51.8674","long":"4.35524","pm25":""},{"location_name":"Hookstown","location_id":"3406","lat":"40.5625","long":"-80.5042","pm25":""},{"location_name":"Hope","location_id":"3408","lat":"49.36972","long":"-121.49944","pm25":""},{"location_name":"Hopeland","location_id":"3409","lat":"0","long":"0","pm25":""},{"location_name":"Horicon Wildlife Are","location_id":"3410","lat":"43.46611","long":"-88.62111","pm25":""},{"location_name":"Horley","location_id":"3411","lat":"51.165867","long":"-0.167734","pm25":""},{"location_name":"Horn Point","location_id":"3412","lat":"38.5876","long":"-76.1408","pm25":""},{"location_name":"Horse Rock","location_id":"3414","lat":"39.483616","long":"-79.02638","pm25":""},{"location_name":"Horst a\/d Maas-Hoogheide","location_id":"3415","lat":"51.4541","long":"6.1082","pm25":""},{"location_name":"Horton Station","location_id":"3416","lat":"37.3297","long":"-80.5578","pm25":""},{"location_name":"Horyniec-Zdr\u00f3j-Park","location_id":"3417","lat":"50.1921","long":"23.361425","pm25":""},{"location_name":"Houston","location_id":"3419","lat":"40.269","long":"-80.244","pm25":""},{"location_name":"Houston Aldine C8","location_id":"3420","lat":"29.9011","long":"-95.3261","pm25":""},{"location_name":"Houston Bayland Park","location_id":"3422","lat":"29.6958","long":"-95.4992","pm25":""},{"location_name":"Houston Croquet C409","location_id":"3424","lat":"29.62389","long":"-95.47417","pm25":""},{"location_name":"Houston Deer Park C3","location_id":"3425","lat":"29.670025","long":"-95.12851","pm25":""},{"location_name":"Houston East C1","location_id":"3426","lat":"29.7681","long":"-95.2206","pm25":""},{"location_name":"Houston Monroe C406","location_id":"3429","lat":"29.625557","long":"-95.26722","pm25":""},{"location_name":"Houston North Waysid","location_id":"3431","lat":"29.8281","long":"-95.2842","pm25":""},{"location_name":"Houston Park Place C","location_id":"3433","lat":"29.68639","long":"-95.29472","pm25":""},{"location_name":"Houston Westhollow C","location_id":"3436","lat":"29.7233","long":"-95.6358","pm25":""},{"location_name":"Howard County Near R","location_id":"3439","lat":"39.143196","long":"-76.84619","pm25":""},{"location_name":"Hoxeyville","location_id":"3441","lat":"44.1809","long":"-85.739","pm25":""},{"location_name":"Hsinchu","location_id":"3442","lat":"24.805618","long":"120.97208","pm25":""},{"location_name":"Huai Kon, Chaloem Phra Kiat","location_id":"3443","lat":"19.540054","long":"101.0483","pm25":""},{"location_name":"Huai Pong, Mueang","location_id":"3444","lat":"12.735202","long":"101.13567","pm25":""},{"location_name":"Hualqui","location_id":"3445","lat":"-36.977432","long":"-72.932014","pm25":""},{"location_name":"Huijbergen-Vennekenstraat","location_id":"3448","lat":"51.4344","long":"4.35984","pm25":""},{"location_name":"Hull (Ile)","location_id":"3449","lat":"45.4369","long":"-75.7261","pm25":""},{"location_name":"Hull Freetown","location_id":"3450","lat":"53.74878","long":"-0.341222","pm25":""},{"location_name":"Hull Holderness Road","location_id":"3451","lat":"53.758972","long":"-0.305749","pm25":""},{"location_name":"Humboldt Mountain -","location_id":"3453","lat":"33.9828","long":"-111.7987","pm25":""},{"location_name":"Huntington Wildlife","location_id":"3454","lat":"43.97","long":"-74.22","pm25":""},{"location_name":"Hurdal25","location_id":"3458","lat":"60.37288","long":"11.07407","pm25":""},{"location_name":"Huron","location_id":"3459","lat":"36.1994","long":"-120.0991","pm25":""},{"location_name":"Hurricane","location_id":"3460","lat":"37.179","long":"-113.3052","pm25":""},{"location_name":"Hurst Road","location_id":"3461","lat":"64.76297","long":"-147.3103","pm25":""},{"location_name":"I25 Denver","location_id":"3469","lat":"39.732143","long":"-105.01531","pm25":""},{"location_name":"IE0001R","location_id":"3471","lat":"51.938057","long":"-10.240833","pm25":""},{"location_name":"IE001AP","location_id":"3472","lat":"53.336296","long":"-6.30902","pm25":""},{"location_name":"IE001BP","location_id":"3473","lat":"51.91111","long":"-8.475","pm25":""},{"location_name":"IE001CM","location_id":"3474","lat":"53.036125","long":"-7.288675","pm25":""},{"location_name":"IE001DM","location_id":"3475","lat":"52.4985","long":"-6.57075","pm25":""},{"location_name":"IE0028A","location_id":"3476","lat":"53.35389","long":"-6.278056","pm25":""},{"location_name":"IE002AP","location_id":"3477","lat":"53.372044","long":"-6.175326","pm25":""},{"location_name":"IE0031R","location_id":"3478","lat":"54.326668","long":"-9.904444","pm25":""},{"location_name":"IE0036A","location_id":"3479","lat":"53.333332","long":"-6.366667","pm25":""},{"location_name":"IE003AP","location_id":"3480","lat":"53.39025","long":"-6.305266","pm25":""},{"location_name":"IE0090A","location_id":"3481","lat":"54.066113","long":"-6.883056","pm25":""},{"location_name":"IE0095A","location_id":"3482","lat":"53.35278","long":"-6.366667","pm25":""},{"location_name":"IE0098A","location_id":"3483","lat":"53.341667","long":"-6.288889","pm25":""},{"location_name":"IE0110A","location_id":"3485","lat":"51.881943","long":"-8.456667","pm25":""},{"location_name":"IE0111A","location_id":"3486","lat":"53.106945","long":"-7.196389","pm25":""},{"location_name":"IE0118A","location_id":"3487","lat":"53.851112","long":"-9.299722","pm25":""},{"location_name":"IE0127A","location_id":"3488","lat":"53.31389","long":"-6.249167","pm25":""},{"location_name":"IE0131A","location_id":"3489","lat":"53.385635","long":"-6.369934","pm25":""},{"location_name":"IE0140A","location_id":"3493","lat":"53.27481","long":"-6.222367","pm25":""},{"location_name":"IE0141A","location_id":"3494","lat":"53.18722","long":"-6.121667","pm25":""},{"location_name":"IE0147A","location_id":"3496","lat":"52.638798","long":"-7.268114","pm25":""},{"location_name":"IMGW \u0141eba - R\u0105bka","location_id":"3503","lat":"54.75414","long":"17.534529","pm25":""},{"location_name":"IMGW-Jarczew","location_id":"3504","lat":"51.814365","long":"21.972376","pm25":""},{"location_name":"ISONZO","location_id":"3505","lat":"44.8425","long":"11.6131","pm25":""},{"location_name":"ITA-CJUS - Itag\u00fc\u00ed - Casa de Justicia Itag\u00fc\u00ed","location_id":"3506","lat":"6.1856666","long":"-75.597206","pm25":""},{"location_name":"ITA-CONC - Itag\u00fc\u00ed - I.E. Concejo Municipal de Itag\u00fc\u00ed","location_id":"3507","lat":"6.168497","long":"-75.644356","pm25":""},{"location_name":"ITA-POGO - Itag\u00fc\u00ed - Estaci\u00f3n de Polic\u00eda Los G\u00f3mez","location_id":"3508","lat":"6.189889","long":"-75.61061","pm25":""},{"location_name":"Idaho City","location_id":"3512","lat":"43.823017","long":"-115.838554","pm25":""},{"location_name":"Idaho Falls \/ Penfor","location_id":"3513","lat":"43.4683","long":"-112.0531","pm25":""},{"location_name":"Incline","location_id":"3519","lat":"39.25044","long":"-119.95674","pm25":""},{"location_name":"Independencia","location_id":"3520","lat":"-33.422302","long":"-70.65116","pm25":""},{"location_name":"Indian River Lagoon","location_id":"3521","lat":"27.8492","long":"-80.4554","pm25":""},{"location_name":"Indio - Jackson Stre","location_id":"3523","lat":"33.708565","long":"-116.21539","pm25":""},{"location_name":"Indio-29 Palms","location_id":"3524","lat":"33.71969","long":"-116.1897","pm25":""},{"location_name":"Indpls - I-70 E","location_id":"3526","lat":"39.787933","long":"-86.13088","pm25":""},{"location_name":"Indpls- Illinois St","location_id":"3527","lat":"39.768055","long":"-86.16","pm25":""},{"location_name":"Indpls-Ft. Harrison","location_id":"3529","lat":"39.8589","long":"-86.0214","pm25":""},{"location_name":"Indpls-Harding St","location_id":"3530","lat":"39.7489","long":"-86.1861","pm25":""},{"location_name":"Indpls-W.18th St","location_id":"3531","lat":"39.7889","long":"-86.2147","pm25":""},{"location_name":"Indpls-Washington Pa","location_id":"3532","lat":"39.8108","long":"-86.1147","pm25":""},{"location_name":"Inglefield","location_id":"3533","lat":"38.1139","long":"-87.5369","pm25":""},{"location_name":"Inowroc\u0142aw Airpointer","location_id":"3541","lat":"52.79312","long":"18.241043","pm25":""},{"location_name":"Inpesca","location_id":"3542","lat":"-36.7372","long":"-73.10442","pm25":""},{"location_name":"Intarapitak Rd., Thon Buri","location_id":"3543","lat":"13.727559","long":"100.4866","pm25":""},{"location_name":"Inverness","location_id":"3545","lat":"57.481308","long":"-4.241451","pm25":""},{"location_name":"Iowa City, Hoover Sc","location_id":"3546","lat":"41.658195","long":"-91.50347","pm25":""},{"location_name":"Irmo","location_id":"3547","lat":"34.0511","long":"-81.155","pm25":""},{"location_name":"Ironton - ODOT","location_id":"3550","lat":"38.508114","long":"-82.6593","pm25":""},{"location_name":"Islamabad","location_id":"3552","lat":"33.7235","long":"73.11822","pm25":""},{"location_name":"Italy C1044","location_id":"3555","lat":"32.1772","long":"-96.8711","pm25":""},{"location_name":"Ivanhoe C414","location_id":"3558","lat":"31.7864","long":"-106.3242","pm25":""},{"location_name":"JAMES S. LONG PARK","location_id":"3561","lat":"38.8553","long":"-77.6356","pm25":""},{"location_name":"JAMESVIL","location_id":"3562","lat":"35.8111","long":"-76.9067","pm25":""},{"location_name":"JERSEYVL","location_id":"3564","lat":"39.1097","long":"-90.3286","pm25":""},{"location_name":"JN\u5b50\u7ad9","location_id":"3565","lat":"35.878","long":"120.005","pm25":""},{"location_name":"JOHNSTON","location_id":"3567","lat":"35.59095","long":"-78.4622","pm25":""},{"location_name":"JOHNSTON BUILDING -","location_id":"3568","lat":"44.647","long":"-63.574","pm25":""},{"location_name":"JPRECC","location_id":"3569","lat":"37.0581","long":"-88.5725","pm25":""},{"location_name":"Jackson","location_id":"3575","lat":"33.3422","long":"-81.7886","pm25":""},{"location_name":"Jackson - Clinton","location_id":"3576","lat":"38.342606","long":"-120.76443","pm25":""},{"location_name":"Jackson NCORE","location_id":"3578","lat":"32.32911","long":"-90.182724","pm25":""},{"location_name":"Jackson Road","location_id":"3579","lat":"27.0892","long":"-82.3625","pm25":""},{"location_name":"Jacobs","location_id":"3580","lat":"40.776943","long":"-124.1775","pm25":""},{"location_name":"Jakarta Central","location_id":"3584","lat":"-6.182536","long":"106.834236","pm25":""},{"location_name":"Jard\u00edn Infantil Integra","location_id":"3586","lat":"-23.098799","long":"-70.442764","pm25":""},{"location_name":"Jaros\u0142aw-PWSTE-WIOS","location_id":"3587","lat":"50.01208","long":"22.674772","pm25":""},{"location_name":"Jaslo-Sikorskiego-WIOS","location_id":"3588","lat":"49.744884","long":"21.454617","pm25":""},{"location_name":"Jawor","location_id":"3589","lat":"51.049213","long":"16.202316","pm25":""},{"location_name":"Jean","location_id":"3592","lat":"35.785664","long":"-115.357086","pm25":""},{"location_name":"Jeffersonville - Bat","location_id":"3594","lat":"38.288193","long":"-85.74134","pm25":""},{"location_name":"Jelenia G\u00f3ra - Ogi\u0144skiego","location_id":"3595","lat":"50.913433","long":"15.765608","pm25":""},{"location_name":"Jenkins Avenue","location_id":"3596","lat":"32.88229","long":"-79.97754","pm25":""},{"location_name":"Jerome Mack","location_id":"3598","lat":"36.141876","long":"-115.07874","pm25":""},{"location_name":"Jersey City","location_id":"3599","lat":"40.73169","long":"-74.06657","pm25":""},{"location_name":"Jersey City FH","location_id":"3600","lat":"40.725452","long":"-74.05229","pm25":""},{"location_name":"Joe Neal","location_id":"3602","lat":"36.27059","long":"-115.23828","pm25":""},{"location_name":"John A. Chesnut Sr.","location_id":"3603","lat":"28.0903","long":"-82.7008","pm25":""},{"location_name":"John Day Dayton St","location_id":"3604","lat":"44.418","long":"-118.9513","pm25":""},{"location_name":"Johnson County","location_id":"3605","lat":"43.87483","long":"-106.50974","pm25":""},{"location_name":"Johnstown","location_id":"3606","lat":"40.3097","long":"-78.9158","pm25":""},{"location_name":"Joliet","location_id":"3607","lat":"41.526886","long":"-88.11647","pm25":""},{"location_name":"Joshua Tree NP - Bla","location_id":"3609","lat":"34.0714","long":"-116.3906","pm25":""},{"location_name":"Joshua Tree NP - Cot","location_id":"3610","lat":"33.74127","long":"-115.82041","pm25":""},{"location_name":"Joussard","location_id":"3611","lat":"55.340366","long":"-115.89567","pm25":""},{"location_name":"Juan Jose Latorre","location_id":"3612","lat":"-23.10488","long":"-70.44138","pm25":""},{"location_name":"Juel Spring","location_id":"3620","lat":"42.373","long":"-109.563","pm25":""},{"location_name":"K-Ko\u017ale automat 1","location_id":"3623","lat":"50.34961","long":"18.236574","pm25":""},{"location_name":"KAHULUI","location_id":"3625","lat":"20.869444","long":"-156.49242","pm25":""},{"location_name":"KALAMAZOO","location_id":"3626","lat":"42.2781","long":"-85.5419","pm25":""},{"location_name":"KENTVILLE","location_id":"3627","lat":"45.04","long":"-64.29","pm25":""},{"location_name":"KILLENS","location_id":"3629","lat":"38.9847","long":"-75.5556","pm25":""},{"location_name":"KITIMAT WHITESAIL","location_id":"3631","lat":"54.0403","long":"-128.3825","pm25":""},{"location_name":"KM\u015a Puszcza Borecka","location_id":"3632","lat":"54.12482","long":"22.038055","pm25":""},{"location_name":"KNI-Topeka","location_id":"3633","lat":"39.0242","long":"-95.7114","pm25":""},{"location_name":"KNIGHT_P","location_id":"3634","lat":"38.0889","long":"-88.625","pm25":""},{"location_name":"KS Hawaii","location_id":"3636","lat":"19.611916","long":"-155.05504","pm25":""},{"location_name":"Kabul","location_id":"3638","lat":"34.554382","long":"69.2046","pm25":""},{"location_name":"Kalispell Flathead E","location_id":"3640","lat":"48.2025","long":"-114.30556","pm25":""},{"location_name":"Kalisz-Wyszynskiego","location_id":"3641","lat":"51.749054","long":"18.04839","pm25":""},{"location_name":"Kamiah-ID","location_id":"3642","lat":"46.2094","long":"-116.0275","pm25":""},{"location_name":"Kamloops Federal Bui","location_id":"3643","lat":"50.6747","long":"-120.3339","pm25":""},{"location_name":"Kampala","location_id":"3644","lat":"0.300225","long":"32.591553","pm25":""},{"location_name":"Kane Exp. Forest","location_id":"3648","lat":"41.598","long":"-78.7674","pm25":""},{"location_name":"Kannik","location_id":"3649","lat":"58.96415","long":"5.72785","pm25":""},{"location_name":"Kapolei","location_id":"3652","lat":"21.3236","long":"-158.0886","pm25":""},{"location_name":"Karachi","location_id":"3654","lat":"24.8415","long":"67.0091","pm25":""},{"location_name":"Karl Eriksens plass","location_id":"3660","lat":"62.470623","long":"6.153501","pm25":""},{"location_name":"Karnack C85","location_id":"3661","lat":"32.6706","long":"-94.1681","pm25":""},{"location_name":"Karpdalen","location_id":"3662","lat":"69.65617","long":"30.42147","pm25":""},{"location_name":"Kasz\u00f3w","location_id":"3667","lat":"50.02503","long":"19.726833","pm25":""},{"location_name":"Katowice, ul. Kossutha 6","location_id":"3668","lat":"50.26461","long":"18.975027","pm25":""},{"location_name":"Katowice, ul. Plebiscytowa\/A4","location_id":"3669","lat":"50.246796","long":"19.019468","pm25":""},{"location_name":"Kaufman C71","location_id":"3671","lat":"32.565","long":"-96.3175","pm25":""},{"location_name":"Keeler","location_id":"3675","lat":"36.4878","long":"-117.871","pm25":""},{"location_name":"Keene","location_id":"3676","lat":"42.93052","long":"-72.27233","pm25":""},{"location_name":"Kejimkujik Site B","location_id":"3678","lat":"44.40298","long":"-65.20277","pm25":""},{"location_name":"Keller C17","location_id":"3679","lat":"32.922497","long":"-97.28209","pm25":""},{"location_name":"Kelowna College","location_id":"3680","lat":"49.8611","long":"-119.475","pm25":""},{"location_name":"Kembla Grange","location_id":"3683","lat":"-34.476387","long":"150.8175","pm25":""},{"location_name":"Kennedy Meadows","location_id":"3687","lat":"36.0214","long":"-118.137","pm25":""},{"location_name":"Kenner","location_id":"3688","lat":"30.0411","long":"-90.2728","pm25":""},{"location_name":"Kennewick-Metaline","location_id":"3690","lat":"46.2183","long":"-119.2015","pm25":""},{"location_name":"Kensington Park","location_id":"3693","lat":"49.2794","long":"-122.9711","pm25":""},{"location_name":"Kent-James & Central","location_id":"3694","lat":"47.3861","long":"-122.2302","pm25":""},{"location_name":"Kernville","location_id":"3696","lat":"35.755","long":"-118.4175","pm25":""},{"location_name":"Ketchum","location_id":"3698","lat":"43.682556","long":"-114.37109","pm25":""},{"location_name":"Khlong Chan, Bang kapi","location_id":"3702","lat":"13.78152","long":"100.63655","pm25":""},{"location_name":"Khlong Nueng, Khlong Luang","location_id":"3703","lat":"14.040299","long":"100.60874","pm25":""},{"location_name":"Kielce, ul. Targowa","location_id":"3705","lat":"50.878998","long":"20.633692","pm25":""},{"location_name":"Kihei, Maui","location_id":"3706","lat":"20.7808","long":"-156.4461","pm25":""},{"location_name":"Killeen C1047","location_id":"3707","lat":"31.088001","long":"-97.67973","pm25":""},{"location_name":"King Greenleaf Rec C","location_id":"3709","lat":"38.87516","long":"-77.01282","pm25":""},{"location_name":"Kingery Near-road #1","location_id":"3710","lat":"41.5786","long":"-87.55739","pm25":""},{"location_name":"Kingsport","location_id":"3711","lat":"36.5408","long":"-82.5217","pm25":""},{"location_name":"Kingston","location_id":"3712","lat":"44.219868","long":"-76.521126","pm25":""},{"location_name":"Kirkeveien","location_id":"3715","lat":"59.93233","long":"10.72447","pm25":""},{"location_name":"Kitchener","location_id":"3716","lat":"43.4419","long":"-80.5044","pm25":""},{"location_name":"Kitimat Haisla Villa","location_id":"3717","lat":"53.9733","long":"-128.6503","pm25":""},{"location_name":"Kitimat Riverlodge","location_id":"3718","lat":"54.0558","long":"-128.6739","pm25":""},{"location_name":"Kittanning","location_id":"3719","lat":"40.8142","long":"-79.565","pm25":""},{"location_name":"Klamath Falls - Pete","location_id":"3729","lat":"42.190296","long":"-121.73137","pm25":""},{"location_name":"Klosterhaugen","location_id":"3731","lat":"60.395927","long":"5.312674","pm25":""},{"location_name":"Knarrdalstranda","location_id":"3738","lat":"59.13354","long":"9.6219","pm25":""},{"location_name":"Kokomo - E. Vaile Av","location_id":"3742","lat":"40.48135","long":"-86.10972","pm25":""},{"location_name":"Kollumerwaard-Hooge Zuidwal","location_id":"3744","lat":"53.3304","long":"6.27681","pm25":""},{"location_name":"Kona","location_id":"3746","lat":"19.5097","long":"-155.9133","pm25":""},{"location_name":"Koniczynka","location_id":"3748","lat":"53.080647","long":"18.684258","pm25":""},{"location_name":"Konin-Wyszynskiego","location_id":"3749","lat":"52.22563","long":"18.269035","pm25":""},{"location_name":"Konstancin-Jeziorna-Wierzejewskiego","location_id":"3750","lat":"52.080624","long":"21.111185","pm25":""},{"location_name":"Kooker Park","location_id":"3751","lat":"30.356112","long":"-81.63556","pm25":""},{"location_name":"Koper","location_id":"3752","lat":"45.54297","long":"13.713539","pm25":""},{"location_name":"Koszalin_ArmiiKrajowej","location_id":"3753","lat":"54.193985","long":"16.172544","pm25":""},{"location_name":"Koszalin_Chopina","location_id":"3754","lat":"54.194363","long":"16.211227","pm25":""},{"location_name":"Kozieglowy-os.Lesne","location_id":"3755","lat":"52.44933","long":"16.999683","pm25":""},{"location_name":"Krak\u00f3w, Aleja Krasi\u0144skiego","location_id":"3757","lat":"50.05768","long":"19.92619","pm25":""},{"location_name":"Krak\u00f3w, os. Piast\u00f3w","location_id":"3758","lat":"50.098507","long":"20.018269","pm25":""},{"location_name":"Krak\u00f3w, os. Swoszowice","location_id":"3759","lat":"49.991444","long":"19.936792","pm25":""},{"location_name":"Krak\u00f3w, os. Wad\u00f3w","location_id":"3760","lat":"50.10057","long":"20.12256","pm25":""},{"location_name":"Krak\u00f3w, ul. Bujaka","location_id":"3761","lat":"50.010574","long":"19.949188","pm25":""},{"location_name":"Krak\u00f3w, ul. Bulwarowa","location_id":"3762","lat":"50.06931","long":"20.053492","pm25":""},{"location_name":"Krak\u00f3w, ul. Dietla","location_id":"3763","lat":"50.057446","long":"19.946009","pm25":""},{"location_name":"Krak\u00f3w, ul. Z\u0142oty R\u00f3g","location_id":"3764","lat":"50.081196","long":"19.895357","pm25":""},{"location_name":"Kransen","location_id":"3766","lat":"59.43347","long":"10.661762","pm25":""},{"location_name":"Kremlin","location_id":"3767","lat":"36.512295","long":"-97.84563","pm25":""},{"location_name":"Krempna-MPN-WIOS","location_id":"3768","lat":"49.511295","long":"21.498606","pm25":""},{"location_name":"Krynica, ul. Bulwary Dietla","location_id":"3770","lat":"49.416977","long":"20.956146","pm25":""},{"location_name":"Kutno-1 Maja 7","location_id":"3777","lat":"52.231728","long":"19.353743","pm25":""},{"location_name":"Kutztown","location_id":"3778","lat":"40.51408","long":"-75.7897","pm25":""},{"location_name":"Kuwait City","location_id":"3779","lat":"29.292316","long":"48.04768","pm25":""},{"location_name":"Kwai Chung","location_id":"3780","lat":"22.357222","long":"114.12972","pm25":""},{"location_name":"Kwun Tong","location_id":"3781","lat":"22.313334","long":"114.224724","pm25":""},{"location_name":"K\u00e5rvatn","location_id":"3782","lat":"62.78246","long":"8.87658","pm25":""},{"location_name":"K\u0142odzko - Szkolna","location_id":"3786","lat":"50.433495","long":"16.65366","pm25":""},{"location_name":"LABP","location_id":"3791","lat":"40.0917","long":"-75.0978","pm25":""},{"location_name":"LACROSSE DOT","location_id":"3792","lat":"43.7781","long":"-91.225","pm25":""},{"location_name":"LANSING FILLEY ST","location_id":"3796","lat":"42.76138","long":"-84.56287","pm25":""},{"location_name":"LAX-Hastings","location_id":"3798","lat":"33.95507","long":"-118.43046","pm25":""},{"location_name":"LEEDS","location_id":"3799","lat":"33.5453","long":"-86.5492","pm25":""},{"location_name":"LEGGETT","location_id":"3800","lat":"35.988277","long":"-77.5843","pm25":""},{"location_name":"LEHI","location_id":"3801","lat":"33.4745","long":"-111.8051","pm25":""},{"location_name":"LEMONT","location_id":"3802","lat":"41.6681","long":"-87.9906","pm25":""},{"location_name":"LENOIR","location_id":"3803","lat":"35.9359","long":"-81.5306","pm25":""},{"location_name":"LEWES","location_id":"3805","lat":"38.7833","long":"-75.1667","pm25":""},{"location_name":"LIBERTY","location_id":"3807","lat":"39.303055","long":"-94.37639","pm25":""},{"location_name":"LLCHD BAM","location_id":"3810","lat":"40.812557","long":"-96.675735","pm25":""},{"location_name":"LOCKLAND","location_id":"3812","lat":"36.1767","long":"-86.7386","pm25":""},{"location_name":"LOUDONMS","location_id":"3813","lat":"35.7197","long":"-84.3417","pm25":""},{"location_name":"LSU","location_id":"3814","lat":"30.4197","long":"-91.1819","pm25":""},{"location_name":"LT00001","location_id":"3815","lat":"54.677624","long":"25.285187","pm25":""},{"location_name":"LT00002","location_id":"3816","lat":"54.68611","long":"25.210835","pm25":""},{"location_name":"LT00003","location_id":"3817","lat":"54.71528","long":"25.289444","pm25":""},{"location_name":"LT00004","location_id":"3818","lat":"54.673332","long":"25.248903","pm25":""},{"location_name":"LT00012","location_id":"3819","lat":"55.725","long":"24.36557","pm25":""},{"location_name":"LT00021","location_id":"3820","lat":"56.31944","long":"22.87084","pm25":""},{"location_name":"LT00022","location_id":"3821","lat":"55.937836","long":"23.308027","pm25":""},{"location_name":"LT00023","location_id":"3822","lat":"56.309723","long":"22.33139","pm25":""},{"location_name":"LT00031","location_id":"3823","lat":"55.70778","long":"21.141111","pm25":""},{"location_name":"LT00033","location_id":"3824","lat":"55.69","long":"21.17946","pm25":""},{"location_name":"LT00041","location_id":"3825","lat":"54.895126","long":"23.986221","pm25":""},{"location_name":"LT00042","location_id":"3826","lat":"55.072224","long":"24.283894","pm25":""},{"location_name":"LT00043","location_id":"3827","lat":"55.28","long":"23.95778","pm25":""},{"location_name":"LT00044","location_id":"3828","lat":"54.883614","long":"23.835835","pm25":""},{"location_name":"LT00051","location_id":"3829","lat":"55.463333","long":"26.00417","pm25":""},{"location_name":"LT00052","location_id":"3830","lat":"54.0925","long":"24.289728","pm25":""},{"location_name":"LT00053","location_id":"3831","lat":"56.008335","long":"21.886948","pm25":""},{"location_name":"LU0101A","location_id":"3832","lat":"49.59769","long":"6.13759","pm25":""},{"location_name":"LU0102A","location_id":"3833","lat":"49.50504","long":"5.97694","pm25":""},{"location_name":"LU0103A","location_id":"3834","lat":"49.94396","long":"6.17591","pm25":""},{"location_name":"LU0104A","location_id":"3835","lat":"49.73181","long":"5.84714","pm25":""},{"location_name":"LU0105A","location_id":"3836","lat":"49.72226","long":"6.30533","pm25":""},{"location_name":"LU0109A","location_id":"3838","lat":"49.61157","long":"6.11847","pm25":""},{"location_name":"LUGAGNANO","location_id":"3839","lat":"44.8239","long":"9.8304","pm25":""},{"location_name":"LUMS 2","location_id":"3840","lat":"39.5511","long":"-75.7308","pm25":""},{"location_name":"LV0007A","location_id":"3841","lat":"57.404633","long":"21.59199","pm25":""},{"location_name":"LV0008A","location_id":"3842","lat":"56.510204","long":"27.333368","pm25":""},{"location_name":"LV0012A","location_id":"3843","lat":"56.523174","long":"21.004694","pm25":""},{"location_name":"LV0019A","location_id":"3844","lat":"56.950607","long":"24.115871","pm25":""},{"location_name":"LWATTOWR","location_id":"3845","lat":"35.8145","long":"-80.2627","pm25":""},{"location_name":"LYNN","location_id":"3846","lat":"42.4747","long":"-70.9719","pm25":""},{"location_name":"La Casa NCORE - 4545","location_id":"3847","lat":"39.7794","long":"-105.00523","pm25":""},{"location_name":"La Florida","location_id":"3849","lat":"-33.516632","long":"-70.58813","pm25":""},{"location_name":"La Grande Hall & N S","location_id":"3851","lat":"45.3235","long":"-118.0778","pm25":""},{"location_name":"La Greda","location_id":"3852","lat":"-32.748154","long":"-71.474205","pm25":""},{"location_name":"La Habra","location_id":"3853","lat":"33.92506","long":"-117.95258","pm25":""},{"location_name":"La P\u00eache","location_id":"3859","lat":"45.6222","long":"-76.0178","pm25":""},{"location_name":"La Union","location_id":"3861","lat":"31.9306","long":"-106.6306","pm25":""},{"location_name":"LaPorte-E. Lincolnwa","location_id":"3862","lat":"41.6292","long":"-86.6847","pm25":""},{"location_name":"Lab Annex","location_id":"3864","lat":"25.798332","long":"-80.21028","pm25":""},{"location_name":"Lacey-College St","location_id":"3865","lat":"47.0293","long":"-122.8215","pm25":""},{"location_name":"Lacrosse-Hill St","location_id":"3867","lat":"46.8153","long":"-117.8739","pm25":""},{"location_name":"Ladue","location_id":"3868","lat":"38.650257","long":"-90.350464","pm25":""},{"location_name":"Ladybower","location_id":"3869","lat":"53.40337","long":"-1.752006","pm25":""},{"location_name":"Lafayette","location_id":"3870","lat":"30.2258","long":"-92.0428","pm25":""},{"location_name":"Lahore","location_id":"3873","lat":"31.560078","long":"74.33589","pm25":""},{"location_name":"Laja","location_id":"3874","lat":"-37.267803","long":"-72.71069","pm25":""},{"location_name":"Lake City","location_id":"3877","lat":"30.1783","long":"-82.6192","pm25":""},{"location_name":"Lake Elsinore - W. F","location_id":"3878","lat":"33.676537","long":"-117.331024","pm25":""},{"location_name":"Lake Forest Park-Tow","location_id":"3879","lat":"47.755","long":"-122.2806","pm25":""},{"location_name":"Lake Ilo","location_id":"3880","lat":"47.34259","long":"-102.645996","pm25":""},{"location_name":"Lake Jackson C1016","location_id":"3881","lat":"29.043758","long":"-95.472946","pm25":""},{"location_name":"Lake Major","location_id":"3882","lat":"44.7197","long":"-63.4819","pm25":""},{"location_name":"Lake Sugema","location_id":"3884","lat":"40.6933","long":"-92.0061","pm25":""},{"location_name":"Lakeview - Center &","location_id":"3885","lat":"42.189217","long":"-120.353966","pm25":""},{"location_name":"Lakeville - Near Roa","location_id":"3886","lat":"44.706123","long":"-93.285805","pm25":""},{"location_name":"Lancaster","location_id":"3889","lat":"47.7889","long":"-116.8044","pm25":""},{"location_name":"Lancaster DW","location_id":"3890","lat":"40.0439","long":"-76.1125","pm25":""},{"location_name":"Lancaster-Division","location_id":"3891","lat":"34.66959","long":"-118.13069","pm25":""},{"location_name":"Laney College","location_id":"3892","lat":"37.793625","long":"-122.263374","pm25":""},{"location_name":"Lang C408","location_id":"3893","lat":"29.834167","long":"-95.48917","pm25":""},{"location_name":"Langley","location_id":"3895","lat":"49.09556","long":"-122.56694","pm25":""},{"location_name":"Lantana Preserve","location_id":"3896","lat":"26.593807","long":"-80.058914","pm25":""},{"location_name":"Lapwai","location_id":"3898","lat":"46.3972","long":"-116.8062","pm25":""},{"location_name":"Laramie County Mobil","location_id":"3899","lat":"41.08536","long":"-104.52277","pm25":""},{"location_name":"Laramie Temporary PM","location_id":"3901","lat":"41.32","long":"-105.62","pm25":""},{"location_name":"Laredo C44","location_id":"3903","lat":"27.517403","long":"-99.51524","pm25":""},{"location_name":"Las Condes","location_id":"3906","lat":"-33.376774","long":"-70.52332","pm25":""},{"location_name":"Las Cruces ED","location_id":"3907","lat":"32.310333","long":"-106.75121","pm25":""},{"location_name":"Las Flores Canyon","location_id":"3908","lat":"34.4897","long":"-120.0458","pm25":""},{"location_name":"Las Gaviotas","location_id":"3910","lat":"-32.91546","long":"-71.48148","pm25":""},{"location_name":"Las Vegas Paiute","location_id":"3911","lat":"36.357777","long":"-115.36139","pm25":""},{"location_name":"Lassen Volcanic NP","location_id":"3912","lat":"40.5403","long":"-121.5764","pm25":""},{"location_name":"Lat Phrao Rd., Wang Thonglang","location_id":"3913","lat":"13.792635","long":"100.59608","pm25":""},{"location_name":"Latina-Scalo","location_id":"3914","lat":"41.53143","long":"12.946064","pm25":""},{"location_name":"Laurel Hill","location_id":"3915","lat":"39.9878","long":"-79.2514","pm25":""},{"location_name":"Laurel Oaks Elementa","location_id":"3916","lat":"26.2992","long":"-81.72","pm25":""},{"location_name":"Lawrenceville","location_id":"3919","lat":"40.4656","long":"-79.9611","pm25":""},{"location_name":"Lawton North","location_id":"3920","lat":"34.633","long":"-98.4288","pm25":""},{"location_name":"Leamington Spa","location_id":"3921","lat":"52.28881","long":"-1.533119","pm25":""},{"location_name":"Leamington Spa Rugby Road","location_id":"3922","lat":"52.294884","long":"-1.542911","pm25":""},{"location_name":"Leavenworth-Evans St","location_id":"3923","lat":"47.5988","long":"-120.6647","pm25":""},{"location_name":"Leavenworth-U.S. Pen","location_id":"3924","lat":"39.3275","long":"-94.9513","pm25":""},{"location_name":"Lebanon","location_id":"3926","lat":"40.33733","long":"-76.383446","pm25":""},{"location_name":"Lebec","location_id":"3927","lat":"34.8416","long":"-118.8647","pm25":""},{"location_name":"Lee Vining","location_id":"3929","lat":"37.96207","long":"-119.12028","pm25":""},{"location_name":"Leech Lake Nation: C","location_id":"3930","lat":"47.38443","long":"-94.60166","pm25":""},{"location_name":"Leeds Centre","location_id":"3931","lat":"53.80378","long":"-1.546472","pm25":""},{"location_name":"Leeds Headingley Kerbside","location_id":"3932","lat":"53.819973","long":"-1.576361","pm25":""},{"location_name":"Legionowo-Zegrzy\u0144ska","location_id":"3933","lat":"52.407578","long":"20.955929","pm25":""},{"location_name":"Legnica - Rzeczypospolitej","location_id":"3934","lat":"51.204502","long":"16.180513","pm25":""},{"location_name":"Leicester A594 Roadside","location_id":"3937","lat":"52.638676","long":"-1.124228","pm25":""},{"location_name":"Leicester University","location_id":"3938","lat":"52.619823","long":"-1.127311","pm25":""},{"location_name":"Leiret","location_id":"3940","lat":"60.883644","long":"11.5593","pm25":""},{"location_name":"Lemmon Valley","location_id":"3941","lat":"39.645","long":"-119.842","pm25":""},{"location_name":"Lennon Drive","location_id":"3942","lat":"-19.2589","long":"146.826","pm25":""},{"location_name":"Lensmannsdalen","location_id":"3944","lat":"59.15927","long":"9.63565","pm25":""},{"location_name":"Leo HS","location_id":"3947","lat":"41.221416","long":"-85.01682","pm25":""},{"location_name":"Leominster","location_id":"3953","lat":"52.22174","long":"-2.736665","pm25":""},{"location_name":"Leonessa","location_id":"3954","lat":"42.572594","long":"12.961982","pm25":""},{"location_name":"Leopold","location_id":"3956","lat":"38.1131","long":"-86.6036","pm25":""},{"location_name":"Lerwick","location_id":"3957","lat":"60.13922","long":"-1.185319","pm25":""},{"location_name":"Lethbridge","location_id":"3959","lat":"49.7164","long":"-112.8006","pm25":""},{"location_name":"Lewiston","location_id":"3960","lat":"44.089355","long":"-70.214134","pm25":""},{"location_name":"Lewistown","location_id":"3961","lat":"47.04854","long":"-109.455315","pm25":""},{"location_name":"Libby Courthouse","location_id":"3962","lat":"48.3841","long":"-115.548","pm25":""},{"location_name":"Liberty (SAHS)","location_id":"3963","lat":"40.3239","long":"-79.8683","pm25":""},{"location_name":"Liceo Polivalente","location_id":"3965","lat":"-36.601715","long":"-72.95853","pm25":""},{"location_name":"Lido Park; McKinley","location_id":"3966","lat":"27.3072","long":"-82.5703","pm25":""},{"location_name":"Lillehammer barnehage","location_id":"3975","lat":"61.12087","long":"10.46563","pm25":""},{"location_name":"Lima","location_id":"3977","lat":"-12.099398","long":"-76.96888","pm25":""},{"location_name":"Linares","location_id":"3980","lat":"-35.83694","long":"-71.592865","pm25":""},{"location_name":"Lincoln","location_id":"3981","lat":"38.89","long":"-121.3","pm25":""},{"location_name":"Linda","location_id":"3983","lat":"36.349377","long":"-116.03197","pm25":""},{"location_name":"Lindon","location_id":"3985","lat":"40.3414","long":"-111.7136","pm25":""},{"location_name":"Livermore - Rincon","location_id":"3996","lat":"37.687527","long":"-121.78422","pm25":""},{"location_name":"Liverpool","location_id":"3997","lat":"-33.932777","long":"150.90584","pm25":""},{"location_name":"Liverpool Speke","location_id":"3999","lat":"53.34633","long":"-2.844333","pm25":""},{"location_name":"Ljubljana Be\u017eigrad","location_id":"4000","lat":"46.0655","long":"14.512704","pm25":""},{"location_name":"Loddefjord","location_id":"4002","lat":"60.361134","long":"5.23686","pm25":""},{"location_name":"Lommedalen","location_id":"4004","lat":"59.9524","long":"10.487777","pm25":""},{"location_name":"Lompoc H Street","location_id":"4005","lat":"34.6378","long":"-120.4567","pm25":""},{"location_name":"Lompoc HS&P","location_id":"4006","lat":"34.7256","long":"-120.4278","pm25":""},{"location_name":"Lomza Sikorskiego 48\/94","location_id":"4007","lat":"53.181393","long":"22.05438","pm25":""},{"location_name":"London","location_id":"4008","lat":"42.97446","long":"-81.20086","pm25":""},{"location_name":"London Bexley","location_id":"4009","lat":"51.46603","long":"0.184806","pm25":""},{"location_name":"London Bloomsbury","location_id":"4010","lat":"51.52229","long":"-0.125889","pm25":""},{"location_name":"London Eltham","location_id":"4011","lat":"51.45258","long":"0.070766","pm25":""},{"location_name":"London Haringey Priory Park South","location_id":"4012","lat":"51.58413","long":"-0.125254","pm25":""},{"location_name":"London Harlington","location_id":"4013","lat":"51.48879","long":"-0.441614","pm25":""},{"location_name":"London Hillingdon","location_id":"4015","lat":"51.49633","long":"-0.460861","pm25":""},{"location_name":"London Marylebone Road","location_id":"4016","lat":"51.52253","long":"-0.154611","pm25":""},{"location_name":"London N. Kensington","location_id":"4017","lat":"51.52105","long":"-0.213492","pm25":""},{"location_name":"London Teddington Bushy Park","location_id":"4019","lat":"51.425285","long":"-0.345606","pm25":""},{"location_name":"London Westminster","location_id":"4020","lat":"51.49467","long":"-0.131931","pm25":""},{"location_name":"Londonderry - Moose","location_id":"4021","lat":"42.86253","long":"-71.38014","pm25":""},{"location_name":"Lone Pine","location_id":"4022","lat":"36.609","long":"-118.0578","pm25":""},{"location_name":"Long Beach - Hudson","location_id":"4024","lat":"33.802418","long":"-118.21993","pm25":""},{"location_name":"Long Creek","location_id":"4025","lat":"34.805","long":"-83.2375","pm25":""},{"location_name":"Longmont","location_id":"4027","lat":"40.164585","long":"-105.10086","pm25":""},{"location_name":"Longtan","location_id":"4028","lat":"24.863869","long":"121.21635","pm25":""},{"location_name":"Longview C19\/C127","location_id":"4029","lat":"32.37868","long":"-94.71181","pm25":""},{"location_name":"Longview-30th Ave","location_id":"4030","lat":"46.1394","long":"-122.9619","pm25":""},{"location_name":"Look Rock - GSMNP","location_id":"4032","lat":"35.6322","long":"-83.9422","pm25":""},{"location_name":"Los Andes","location_id":"4034","lat":"-32.844124","long":"-70.59213","pm25":""},{"location_name":"Los Angeles - N. Mai","location_id":"4035","lat":"34.06643","long":"-118.22675","pm25":""},{"location_name":"Los Gatos","location_id":"4037","lat":"37.2267","long":"-121.9786","pm25":""},{"location_name":"Los Maitenes","location_id":"4039","lat":"-32.764137","long":"-71.45449","pm25":""},{"location_name":"Los Volcanes","location_id":"4042","lat":"-27.373178","long":"-70.306175","pm25":""},{"location_name":"Loudonville","location_id":"4045","lat":"42.6769","long":"-73.7556","pm25":""},{"location_name":"Lough Navar","location_id":"4046","lat":"54.43951","long":"-7.900328","pm25":""},{"location_name":"Luba\u0144 - Mieszka II","location_id":"4050","lat":"51.11901","long":"15.275539","pm25":""},{"location_name":"Lublin ul. Obywatelska","location_id":"4052","lat":"51.25943","long":"22.569134","pm25":""},{"location_name":"Lublin-Podmiejska","location_id":"4053","lat":"51.163544","long":"22.598608","pm25":""},{"location_name":"Lubliniec, ul. ks. Szyma\u0142y","location_id":"4054","lat":"50.675694","long":"18.682064","pm25":""},{"location_name":"Lucerne Valley","location_id":"4055","lat":"34.4101","long":"-116.906876","pm25":""},{"location_name":"Lukavac","location_id":"4056","lat":"44.533302","long":"18.534891","pm25":""},{"location_name":"Lullington Heath","location_id":"4057","lat":"50.7937","long":"0.18125","pm25":""},{"location_name":"Luton A505 Roadside","location_id":"4061","lat":"51.892292","long":"-0.46211","pm25":""},{"location_name":"Lynchburg Ferry C101","location_id":"4062","lat":"29.7644","long":"-95.0781","pm25":""},{"location_name":"Lynn Lane","location_id":"4064","lat":"36.1336","long":"-95.7636","pm25":""},{"location_name":"Lynnwood-212th","location_id":"4066","lat":"47.8064","long":"-122.3167","pm25":""},{"location_name":"Lyons","location_id":"4067","lat":"44.778744","long":"-122.61705","pm25":""},{"location_name":"Lytton","location_id":"4068","lat":"-27.4065","long":"153.153","pm25":""},{"location_name":"M.K. Goddard","location_id":"4071","lat":"41.4271","long":"-80.1451","pm25":""},{"location_name":"MA","location_id":"4072","lat":"40.712063","long":"-112.11112","pm25":""},{"location_name":"MADISON EAST","location_id":"4073","lat":"43.1008","long":"-89.3572","pm25":""},{"location_name":"MALCANTONE","location_id":"4075","lat":"44.8909","long":"10.3996","pm25":""},{"location_name":"MARION","location_id":"4079","lat":"35.1967","long":"-90.1911","pm25":""},{"location_name":"MARYVILL","location_id":"4082","lat":"35.7683","long":"-83.9422","pm25":""},{"location_name":"MATH & SCIENCE CTR","location_id":"4083","lat":"37.55652","long":"-77.40027","pm25":""},{"location_name":"MCADORY","location_id":"4085","lat":"33.3311","long":"-87.0036","pm25":""},{"location_name":"MED-ALTA - Medell\u00edn, Altavista - I.E. Pedro Octavio Amado","location_id":"4087","lat":"6.221894","long":"-75.6106","pm25":""},{"location_name":"MED-ARAN - Medell\u00edn, Aranjuez - I.E Ciro Mendia","location_id":"4088","lat":"6.2904806","long":"-75.55552","pm25":""},{"location_name":"MED-BEME - Medellin, Bel\u00e9n - I.E Pedro Justo Berrio","location_id":"4089","lat":"6.237234","long":"-75.610466","pm25":""},{"location_name":"MED-EXSA - Exito San Antonio - Medellin","location_id":"4090","lat":"6.2465863","long":"-75.56747","pm25":""},{"location_name":"MED-ITMR - Institucion Universitaria ITM Robledo","location_id":"4091","lat":"6.2755637","long":"-75.58829","pm25":""},{"location_name":"MED-LAYE - Medell\u00edn, El Poblado - Tanques La Ye EPM","location_id":"4092","lat":"6.182542","long":"-75.55064","pm25":""},{"location_name":"MED-MIRA - Tanque Miraflores","location_id":"4093","lat":"6.2299724","long":"-75.549194","pm25":""},{"location_name":"MED-PJIC - Politecnico Colombiano Jaime Isaza Cadavid - Medellin","location_id":"4094","lat":"6.208975","long":"-75.57777","pm25":""},{"location_name":"MED-SCRI - Medell\u00edn, San Cristobal - Parque Biblioteca Fernando Botero","location_id":"4095","lat":"6.27785","long":"-75.63643","pm25":""},{"location_name":"MED-TESO - Medell\u00edn, El Poblado - I.E INEM sede Santa Catalina","location_id":"4096","lat":"6.19987","long":"-75.56095","pm25":""},{"location_name":"MED-UDEM - Universidad de Medellin","location_id":"4097","lat":"6.230184","long":"-75.60996","pm25":""},{"location_name":"MED-UNNV - Medell\u00edn,  centro occidente - Universidad Nacional, sede El Volador","location_id":"4098","lat":"6.2633696","long":"-75.577","pm25":""},{"location_name":"MED-VILL - Medell\u00edn, Villahermosa - Planta de producci\u00f3n de agua potable EPM","location_id":"4099","lat":"6.258909","long":"-75.54826","pm25":""},{"location_name":"MENDNHAL","location_id":"4100","lat":"36.109005","long":"-79.802315","pm25":""},{"location_name":"MICMAC","location_id":"4103","lat":"46.6964","long":"-68.0331","pm25":""},{"location_name":"MILITARY PARK","location_id":"4106","lat":"42.312077","long":"-83.10347","pm25":""},{"location_name":"MILWAUKEE 16TH ST","location_id":"4107","lat":"43.0178","long":"-87.9333","pm25":""},{"location_name":"MILWAUKEE SER DNR","location_id":"4109","lat":"43.0611","long":"-87.9125","pm25":""},{"location_name":"MK0030A","location_id":"4110","lat":"42.00361","long":"21.46362","pm25":""},{"location_name":"MK0031A","location_id":"4111","lat":"41.97833","long":"21.47","pm25":""},{"location_name":"MK0034A","location_id":"4112","lat":"41.91389","long":"22.41585","pm25":""},{"location_name":"MK0035A","location_id":"4113","lat":"41.51445","long":"20.95862","pm25":""},{"location_name":"MK0036A","location_id":"4114","lat":"42.13556","long":"21.71474","pm25":""},{"location_name":"MK0037A","location_id":"4115","lat":"41.04","long":"21.3564","pm25":""},{"location_name":"MK0038A","location_id":"4116","lat":"41.03028","long":"21.33667","pm25":""},{"location_name":"MK0040A","location_id":"4117","lat":"41.70583","long":"21.76529","pm25":""},{"location_name":"MK0041A","location_id":"4118","lat":"42.00444","long":"20.96807","pm25":""},{"location_name":"MK0042A","location_id":"4119","lat":"41.53583","long":"20.6989","pm25":""},{"location_name":"MK0043A","location_id":"4120","lat":"41.99917","long":"21.44084","pm25":""},{"location_name":"MK0044A","location_id":"4121","lat":"41.44056","long":"22.00723","pm25":""},{"location_name":"MK0045A","location_id":"4122","lat":"41.98744","long":"21.6525","pm25":""},{"location_name":"MK0047A","location_id":"4123","lat":"41.992","long":"21.423","pm25":""},{"location_name":"MK0048A","location_id":"4124","lat":"42.006","long":"21.387","pm25":""},{"location_name":"MLK","location_id":"4125","lat":"39.7394","long":"-75.5581","pm25":""},{"location_name":"MMCA81006","location_id":"4126","lat":"35.758396","long":"-120.69644","pm25":""},{"location_name":"MMCA81010","location_id":"4127","lat":"40.50522","long":"-122.54337","pm25":""},{"location_name":"MMCA81015","location_id":"4129","lat":"38.61088","long":"-122.86884","pm25":""},{"location_name":"MMCA81032","location_id":"4131","lat":"38.21145","long":"-122.13293","pm25":""},{"location_name":"MMCA81033","location_id":"4132","lat":"38.804214","long":"-123.01819","pm25":""},{"location_name":"MMCA81036","location_id":"4133","lat":"38.753124","long":"-122.62214","pm25":""},{"location_name":"MMCA81042","location_id":"4134","lat":"38.510727","long":"-122.80603","pm25":""},{"location_name":"MMCA81046","location_id":"4135","lat":"38.507553","long":"-122.47896","pm25":""},{"location_name":"MON","location_id":"4140","lat":"39.988842","long":"-75.20721","pm25":""},{"location_name":"MONCTON","location_id":"4141","lat":"46.11","long":"-64.79","pm25":""},{"location_name":"MONROE STERLING ST P","location_id":"4142","lat":"41.92357","long":"-83.345856","pm25":""},{"location_name":"MONTEBELLO","location_id":"4144","lat":"44.7866","long":"10.3365","pm25":""},{"location_name":"MONTG","location_id":"4145","lat":"32.4069","long":"-86.2564","pm25":""},{"location_name":"MT00004","location_id":"4151","lat":"35.85229","long":"14.538986","pm25":""},{"location_name":"MT00005","location_id":"4152","lat":"35.895836","long":"14.489986","pm25":""},{"location_name":"MT00007","location_id":"4153","lat":"36.06707","long":"14.197153","pm25":""},{"location_name":"MT00008","location_id":"4154","lat":"35.89002","long":"14.434464","pm25":""},{"location_name":"MTSP","location_id":"4155","lat":"39.4751","long":"-91.78899","pm25":""},{"location_name":"MUNRO STREET","location_id":"4156","lat":"27.955133","long":"-82.46953","pm25":""},{"location_name":"Maassluis-Kwartellaan","location_id":"4159","lat":"51.932","long":"4.22802","pm25":""},{"location_name":"Maastricht-A2 Kasteel Hillenraadweg","location_id":"4160","lat":"50.8598","long":"5.71381","pm25":""},{"location_name":"Maastricht-A2 Nassaulaan","location_id":"4161","lat":"50.8459","long":"5.71475","pm25":""},{"location_name":"Maastricht-Hoge Fronten","location_id":"4162","lat":"50.8521","long":"5.6758","pm25":""},{"location_name":"MacPherson Avenue -","location_id":"4163","lat":"48.95224","long":"-57.92207","pm25":""},{"location_name":"Mace Head","location_id":"4164","lat":"53.326443","long":"-9.903917","pm25":""},{"location_name":"Mackville","location_id":"4165","lat":"37.7046","long":"-85.0485","pm25":""},{"location_name":"Macon Forestry","location_id":"4166","lat":"32.8031","long":"-83.5447","pm25":""},{"location_name":"Madawaska PSB","location_id":"4167","lat":"47.3553","long":"-68.3211","pm25":""},{"location_name":"Made","location_id":"4168","lat":"39.464718","long":"-84.40377","pm25":""},{"location_name":"Madera - Pump Yard","location_id":"4169","lat":"36.8669","long":"-120.01","pm25":""},{"location_name":"Madera-City","location_id":"4170","lat":"36.9533","long":"-120.0341","pm25":""},{"location_name":"Madisonville","location_id":"4172","lat":"30.4293","long":"-90.1997","pm25":""},{"location_name":"Madras - Westside Sc","location_id":"4173","lat":"44.6306","long":"-121.1316","pm25":""},{"location_name":"Mae Mo, Mae Mo","location_id":"4174","lat":"18.27968","long":"99.66315","pm25":""},{"location_name":"Magna Grecia","location_id":"4175","lat":"41.883064","long":"12.508939","pm25":""},{"location_name":"Maha Chai, Mueang","location_id":"4176","lat":"13.550478","long":"100.26425","pm25":""},{"location_name":"Mahon Park","location_id":"4178","lat":"49.32389","long":"-123.08361","pm25":""},{"location_name":"Mailiao","location_id":"4179","lat":"23.753506","long":"120.25182","pm25":""},{"location_name":"Malagrotta","location_id":"4182","lat":"41.874893","long":"12.345598","pm25":""},{"location_name":"Malta","location_id":"4183","lat":"48.31751","long":"-107.86247","pm25":""},{"location_name":"Mammoth Cave NP","location_id":"4184","lat":"37.1314","long":"-86.1481","pm25":""},{"location_name":"Mammoth Lakes","location_id":"4185","lat":"37.645718","long":"-118.966515","pm25":""},{"location_name":"Manama","location_id":"4187","lat":"26.204697","long":"50.57083","pm25":""},{"location_name":"Manchester Piccadilly","location_id":"4188","lat":"53.48152","long":"-2.237881","pm25":""},{"location_name":"Manchester Sharston","location_id":"4189","lat":"53.371307","long":"-2.239218","pm25":""},{"location_name":"Manglerud","location_id":"4193","lat":"59.89869","long":"10.81495","pm25":""},{"location_name":"Manhattan\/IS143","location_id":"4194","lat":"40.8492","long":"-73.9319","pm25":""},{"location_name":"Manitou Springs","location_id":"4195","lat":"38.853096","long":"-104.90128","pm25":""},{"location_name":"Mannford","location_id":"4196","lat":"36.1053","long":"-96.3608","pm25":""},{"location_name":"Manse","location_id":"4199","lat":"36.212788","long":"-115.994804","pm25":""},{"location_name":"Manteca","location_id":"4200","lat":"37.8027","long":"-121.2208","pm25":""},{"location_name":"Manvel Croix Park C8","location_id":"4201","lat":"29.5203","long":"-95.3925","pm25":""},{"location_name":"Map Ta Phut, Mueang","location_id":"4203","lat":"","long":"","pm25":""},{"location_name":"Maple Falls-Azure Wa","location_id":"4204","lat":"48.9477","long":"-122.1471","pm25":""},{"location_name":"Maple Ridge","location_id":"4205","lat":"49.215","long":"-122.58194","pm25":""},{"location_name":"Marcus Hook","location_id":"4207","lat":"39.818714","long":"-75.41397","pm25":""},{"location_name":"Maribor center","location_id":"4210","lat":"46.558838","long":"15.651241","pm25":""},{"location_name":"Maricopa","location_id":"4211","lat":"33.06115","long":"-112.05204","pm25":""},{"location_name":"Maricopa - Stanilaus","location_id":"4212","lat":"35.0544","long":"-119.4039","pm25":""},{"location_name":"Marshall","location_id":"4218","lat":"44.4572","long":"-95.835","pm25":""},{"location_name":"Marystown\/Burin","location_id":"4222","lat":"47.09899","long":"-55.19852","pm25":""},{"location_name":"Marysville-7th Ave","location_id":"4223","lat":"48.055","long":"-122.1758","pm25":""},{"location_name":"Maspeth","location_id":"4227","lat":"40.7269","long":"-73.8933","pm25":""},{"location_name":"Matsu","location_id":"4228","lat":"26.15361","long":"119.9525","pm25":""},{"location_name":"Mayaguez 59","location_id":"4230","lat":"18.214167","long":"-67.144165","pm25":""},{"location_name":"Mayo Clinic","location_id":"4232","lat":"30.2603","long":"-81.4533","pm25":""},{"location_name":"Ma\u0142ogoszcz, ul. S\u0142oneczna","location_id":"4234","lat":"50.809563","long":"20.2661","pm25":""},{"location_name":"McAlester","location_id":"4235","lat":"34.906082","long":"-95.79413","pm25":""},{"location_name":"McCall","location_id":"4236","lat":"44.890198","long":"-116.1065","pm25":""},{"location_name":"McDonough","location_id":"4237","lat":"33.4347","long":"-84.1617","pm25":""},{"location_name":"McMillan NCORE","location_id":"4238","lat":"38.92185","long":"-77.013176","pm25":""},{"location_name":"Medford Welch & Jack","location_id":"4241","lat":"42.33155","long":"-122.880264","pm25":""},{"location_name":"Medicine Hat - Cresc","location_id":"4242","lat":"50.0492","long":"-110.6814","pm25":""},{"location_name":"Meinong","location_id":"4244","lat":"22.883583","long":"120.53054","pm25":""},{"location_name":"Melbourne","location_id":"4245","lat":"28.0542","long":"-80.6283","pm25":""},{"location_name":"Memorial Park","location_id":"4247","lat":"-23.8443","long":"151.252","pm25":""},{"location_name":"Meraux","location_id":"4250","lat":"29.94","long":"-89.92","pm25":""},{"location_name":"Merced - S. Coffee A","location_id":"4252","lat":"37.2817","long":"-120.4336","pm25":""},{"location_name":"Mesa - Brooks Reserv","location_id":"4257","lat":"33.4105","long":"-111.8651","pm25":""},{"location_name":"Mesa 2 \/Nipomo","location_id":"4258","lat":"35.02079","long":"-120.56389","pm25":""},{"location_name":"Mesa Verde NP","location_id":"4259","lat":"37.1983","long":"-108.4903","pm25":""},{"location_name":"Mesa-Pepoit Way (tem","location_id":"4260","lat":"46.5754","long":"-119.0021","pm25":""},{"location_name":"Methodist Hill","location_id":"4263","lat":"39.9611","long":"-77.4756","pm25":""},{"location_name":"Miami","location_id":"4266","lat":"36.922222","long":"-94.83889","pm25":""},{"location_name":"Miami Golf Course","location_id":"4269","lat":"33.419018","long":"-110.829666","pm25":""},{"location_name":"Miami Jones Ranch","location_id":"4270","lat":"33.3855","long":"-110.86726","pm25":""},{"location_name":"Miami Town Site","location_id":"4272","lat":"33.397434","long":"-110.87445","pm25":""},{"location_name":"Miaoli","location_id":"4273","lat":"24.56527","long":"120.8202","pm25":""},{"location_name":"Michigan City-4th St","location_id":"4274","lat":"41.7169","long":"-86.9075","pm25":""},{"location_name":"Middleport","location_id":"4275","lat":"43.2189","long":"-78.4792","pm25":""},{"location_name":"Middlesbrough","location_id":"4276","lat":"54.569298","long":"-1.220874","pm25":""},{"location_name":"Midlothian OFW C52","location_id":"4279","lat":"32.482082","long":"-97.026924","pm25":""},{"location_name":"Mielec-Biernackiego-WIOS","location_id":"4280","lat":"50.29913","long":"21.440943","pm25":""},{"location_name":"Mill Site","location_id":"4284","lat":"36.4581","long":"-117.8519","pm25":""},{"location_name":"Millbrook","location_id":"4285","lat":"41.7856","long":"-73.6947","pm25":""},{"location_name":"Millbrook NCore","location_id":"4286","lat":"35.85611","long":"-78.574165","pm25":""},{"location_name":"Miller State Park","location_id":"4288","lat":"42.86183","long":"-71.878624","pm25":""},{"location_name":"Millington","location_id":"4289","lat":"39.3052","long":"-75.7972","pm25":""},{"location_name":"Millville","location_id":"4290","lat":"39.42227","long":"-75.0252","pm25":""},{"location_name":"Minidoka National Hi","location_id":"4293","lat":"42.68","long":"-114.2525","pm25":""},{"location_name":"Minneapolis - Bottin","location_id":"4294","lat":"45.01361","long":"-93.27205","pm25":""},{"location_name":"Minneapolis-Downtown","location_id":"4295","lat":"44.979","long":"-93.2737","pm25":""},{"location_name":"Minneapolis-Lowry Av","location_id":"4296","lat":"45.0121","long":"-93.276695","pm25":""},{"location_name":"Minneapolis-Near Roa","location_id":"4297","lat":"44.9653","long":"-93.2551","pm25":""},{"location_name":"Minneapolis-Pacific","location_id":"4298","lat":"45.008297","long":"-93.27704","pm25":""},{"location_name":"Minneapolis-Phillips","location_id":"4299","lat":"44.9536","long":"-93.2581","pm25":""},{"location_name":"Minnesundvegen, Gj\u00f8vik","location_id":"4300","lat":"60.79089","long":"10.6967","pm25":""},{"location_name":"Mira Loma - Van Bure","location_id":"4301","lat":"33.996387","long":"-117.4925","pm25":""},{"location_name":"Mission C43","location_id":"4303","lat":"26.226227","long":"-98.29107","pm25":""},{"location_name":"Mission Viejo","location_id":"4304","lat":"33.62999","long":"-117.67587","pm25":""},{"location_name":"Missoula Boyd Park","location_id":"4305","lat":"46.842297","long":"-114.020546","pm25":""},{"location_name":"Mitrovice","location_id":"4308","lat":"42.891792","long":"20.868937","pm25":""},{"location_name":"Mi\u0144sk Mazowiecki-Kazikowskiego","location_id":"4309","lat":"52.178764","long":"21.560968","pm25":""},{"location_name":"Mobile-Pomeroy","location_id":"4310","lat":"46.474438","long":"-117.61476","pm25":""},{"location_name":"Mobile-White Salmon","location_id":"4311","lat":"45.73593","long":"-121.488396","pm25":""},{"location_name":"Modesto - 14th Stree","location_id":"4319","lat":"37.642166","long":"-120.99421","pm25":""},{"location_name":"Mogilno,Ko\u015bciuszki","location_id":"4321","lat":"52.65684","long":"17.949566","pm25":""},{"location_name":"Moheia Vest","location_id":"4323","lat":"66.31219","long":"14.149923","pm25":""},{"location_name":"Mojave - 923 Poole S","location_id":"4325","lat":"35.05045","long":"-118.14778","pm25":""},{"location_name":"Molson","location_id":"4327","lat":"45.542767","long":"-73.57204","pm25":""},{"location_name":"Mong Kok","location_id":"4328","lat":"22.3225","long":"114.168335","pm25":""},{"location_name":"Mono Shore","location_id":"4331","lat":"38.0697","long":"-118.9477","pm25":""},{"location_name":"Monroe","location_id":"4332","lat":"32.5097","long":"-92.0461","pm25":""},{"location_name":"Monrovia","location_id":"4333","lat":"39.5756","long":"-86.4778","pm25":""},{"location_name":"Mont-Saint-Michel","location_id":"4334","lat":"46.7686","long":"-75.4319","pm25":""},{"location_name":"Monte Romano","location_id":"4336","lat":"42.268562","long":"11.910914","pm25":""},{"location_name":"Montevallo","location_id":"4338","lat":"33.0928","long":"-86.8072","pm25":""},{"location_name":"Montoursville","location_id":"4339","lat":"41.2508","long":"-76.9239","pm25":""},{"location_name":"Moore","location_id":"4341","lat":"35.32","long":"-97.4883","pm25":""},{"location_name":"Moran","location_id":"4342","lat":"39.4864","long":"-79.0638","pm25":""},{"location_name":"Moranbah","location_id":"4343","lat":"-21.9995","long":"148.071","pm25":""},{"location_name":"Morro Bay","location_id":"4346","lat":"35.36639","long":"-120.8426","pm25":""},{"location_name":"Moscow","location_id":"4348","lat":"46.7282","long":"-116.9546","pm25":""},{"location_name":"Moses Lake-Balsam St","location_id":"4349","lat":"47.1303","long":"-119.2726","pm25":""},{"location_name":"Moshannon","location_id":"4350","lat":"41.1175","long":"-78.5261","pm25":""},{"location_name":"Mount Pearl","location_id":"4351","lat":"47.505","long":"-52.7947","pm25":""},{"location_name":"Mountain Creek","location_id":"4352","lat":"-26.6917","long":"153.104","pm25":""},{"location_name":"Mountain View","location_id":"4353","lat":"19.5698","long":"-155.0806","pm25":""},{"location_name":"Moxa Arch","location_id":"4354","lat":"41.7506","long":"-109.7897","pm25":""},{"location_name":"Mt Ninham","location_id":"4357","lat":"41.4561","long":"-73.7103","pm25":""},{"location_name":"Mt Rainier- Jackson","location_id":"4358","lat":"46.7841","long":"-121.7403","pm25":""},{"location_name":"Mt Vernon-2nd Ave","location_id":"4359","lat":"48.4102","long":"-122.3376","pm25":""},{"location_name":"Mud Run","location_id":"4361","lat":"39.85567","long":"-83.99773","pm25":""},{"location_name":"Murphy Ridge","location_id":"4364","lat":"41.3694","long":"-111.0419","pm25":""},{"location_name":"Murska Sobota","location_id":"4365","lat":"46.6525","long":"16.1961","pm25":""},{"location_name":"Muscatine, Greenwood","location_id":"4366","lat":"41.4192","long":"-91.0708","pm25":""},{"location_name":"Muscatine, High Scho","location_id":"4367","lat":"41.4014","long":"-91.0684","pm25":""},{"location_name":"Muscatine, Musser Pa","location_id":"4368","lat":"41.4078","long":"-91.0625","pm25":""},{"location_name":"Muswellbrook","location_id":"4372","lat":"-32.271667","long":"150.88583","pm25":""},{"location_name":"Mutdapilly","location_id":"4373","lat":"-27.7528","long":"152.651","pm25":""},{"location_name":"Myton","location_id":"4375","lat":"40.2169","long":"-110.1823","pm25":""},{"location_name":"N.-D.-du-Rosaire","location_id":"4380","lat":"46.8508","long":"-70.4528","pm25":""},{"location_name":"NCORE","location_id":"4383","lat":"46.8505","long":"-111.98717","pm25":""},{"location_name":"NCore","location_id":"4384","lat":"64.8458","long":"-147.72726","pm25":""},{"location_name":"NCore - White Mounta","location_id":"4385","lat":"37.360703","long":"-118.33083","pm25":""},{"location_name":"NEA","location_id":"4386","lat":"40.0767","long":"-75.0108","pm25":""},{"location_name":"NEW","location_id":"4387","lat":"39.99139","long":"-75.08083","pm25":""},{"location_name":"NEWKIRK","location_id":"4390","lat":"36.9567","long":"-97.0344","pm25":""},{"location_name":"NEWTWN","location_id":"4392","lat":"38.065","long":"-84.5","pm25":""},{"location_name":"NKU","location_id":"4396","lat":"39.0217","long":"-84.4744","pm25":""},{"location_name":"NLRAP","location_id":"4397","lat":"34.8306","long":"-92.2594","pm25":""},{"location_name":"NMH48217","location_id":"4400","lat":"42.26167","long":"-83.15789","pm25":""},{"location_name":"NO. BHAM","location_id":"4402","lat":"33.5531","long":"-86.815","pm25":""},{"location_name":"NORFOLK - NOAA","location_id":"4403","lat":"36.85555","long":"-76.30135","pm25":""},{"location_name":"NORMAL","location_id":"4404","lat":"40.5169","long":"-88.9975","pm25":""},{"location_name":"NORTHBRK","location_id":"4405","lat":"42.1406","long":"-87.7994","pm25":""},{"location_name":"NR","location_id":"4407","lat":"40.66284","long":"-111.901794","pm25":""},{"location_name":"NR-285","location_id":"4408","lat":"33.698612","long":"-84.272606","pm25":""},{"location_name":"NR-Georgia Tech","location_id":"4409","lat":"33.778316","long":"-84.39142","pm25":""},{"location_name":"Na An, Mueang","location_id":"4412","lat":"13.763936","long":"100.529076","pm25":""},{"location_name":"Na Chak, Mueang","location_id":"4413","lat":"18.12614","long":"100.1654","pm25":""},{"location_name":"Na Mueang, Mueang","location_id":"4414","lat":"13.532555","long":"99.81487","pm25":""},{"location_name":"Na Phra Lan, Chaloem Phra Kiat","location_id":"4415","lat":"14.683085","long":"100.87514","pm25":""},{"location_name":"Nai Wiang, Mueang","location_id":"4416","lat":"","long":"","pm25":""},{"location_name":"Nampa Fire Station","location_id":"4419","lat":"43.58031","long":"-116.562675","pm25":""},{"location_name":"Nanaimo Labieux Road","location_id":"4420","lat":"49.2008","long":"-123.9939","pm25":""},{"location_name":"Nantou","location_id":"4421","lat":"23.913","long":"120.6853","pm25":""},{"location_name":"Napa - Napa Valley C","location_id":"4423","lat":"38.27885","long":"-122.275024","pm25":""},{"location_name":"Naperville","location_id":"4424","lat":"41.7714","long":"-88.1522","pm25":""},{"location_name":"Narberth","location_id":"4425","lat":"51.781784","long":"-4.691462","pm25":""},{"location_name":"Narragansett","location_id":"4427","lat":"41.4942","long":"-71.4219","pm25":""},{"location_name":"Navajo Lake","location_id":"4430","lat":"36.8097","long":"-107.6517","pm25":""},{"location_name":"Na\u0142\u0119cz\u00f3wMOB","location_id":"4431","lat":"51.28493","long":"22.210241","pm25":""},{"location_name":"Neah Bay 2-Makah Tri","location_id":"4432","lat":"48.36606","long":"-124.61005","pm25":""},{"location_name":"Near Road","location_id":"4433","lat":"26.131256","long":"-80.16785","pm25":""},{"location_name":"Near Road OKC","location_id":"4434","lat":"35.502968","long":"-97.577675","pm25":""},{"location_name":"Nederland C1035","location_id":"4435","lat":"29.9786","long":"-94.0111","pm25":""},{"location_name":"Nedre Langgate","location_id":"4436","lat":"59.263725","long":"10.411165","pm25":""},{"location_name":"New Albany","location_id":"4442","lat":"40.0845","long":"-82.81552","pm25":""},{"location_name":"New Castle","location_id":"4443","lat":"40.9958","long":"-80.3467","pm25":""},{"location_name":"New Delhi","location_id":"4444","lat":"28.63576","long":"77.22445","pm25":""},{"location_name":"New Garden","location_id":"4445","lat":"39.8344","long":"-75.7678","pm25":""},{"location_name":"New Haven - Criscuol","location_id":"4446","lat":"41.30129","long":"-72.90269","pm25":""},{"location_name":"New Milford","location_id":"4447","lat":"41.867336","long":"-75.6866","pm25":""},{"location_name":"New Roads","location_id":"4449","lat":"30.6817","long":"-91.3661","pm25":""},{"location_name":"NewCastle","location_id":"4450","lat":"43.8814","long":"-104.1919","pm25":""},{"location_name":"Newark Firehouse","location_id":"4451","lat":"40.72099","long":"-74.192894","pm25":""},{"location_name":"Newburgh","location_id":"4452","lat":"41.4994","long":"-74.0097","pm25":""},{"location_name":"Newcastle","location_id":"4454","lat":"-32.9325","long":"151.75833","pm25":""},{"location_name":"Newcastle Centre","location_id":"4455","lat":"54.97825","long":"-1.610528","pm25":""},{"location_name":"Newcastle Cradlewell Roadside","location_id":"4456","lat":"54.986404","long":"-1.595362","pm25":""},{"location_name":"Newport","location_id":"4458","lat":"51.601204","long":"-2.977281","pm25":""},{"location_name":"Nez Perce Tribe","location_id":"4460","lat":"46.2756","long":"-116.0216","pm25":""},{"location_name":"Nicks Lake","location_id":"4462","lat":"43.6856","long":"-74.9864","pm25":""},{"location_name":"Nijmegen-Graafseweg","location_id":"4464","lat":"51.8414","long":"5.85778","pm25":""},{"location_name":"Nijmegen-Ruyterstraat","location_id":"4465","lat":"51.8382","long":"5.85694","pm25":""},{"location_name":"Niland - English Roa","location_id":"4466","lat":"33.2136","long":"-115.5444","pm25":""},{"location_name":"Nipomo Mesa CDF","location_id":"4467","lat":"35.04676","long":"-120.58777","pm25":""},{"location_name":"Nipomo RP","location_id":"4468","lat":"35.0315","long":"-120.50101","pm25":""},{"location_name":"Nisko-Szklarniowa-WIOS","location_id":"4471","lat":"50.529892","long":"22.112467","pm25":""},{"location_name":"Noblesville-191st St","location_id":"4472","lat":"40.068333","long":"-85.9925","pm25":""},{"location_name":"Noen Phra, Mueang","location_id":"4473","lat":"12.705355","long":"101.18184","pm25":""},{"location_name":"Nogales Post Office","location_id":"4474","lat":"31.337204","long":"-110.93672","pm25":""},{"location_name":"Norristown","location_id":"4476","lat":"40.1122","long":"-75.3092","pm25":""},{"location_name":"North Bay","location_id":"4478","lat":"46.3175","long":"-79.4453","pm25":""},{"location_name":"North Beach","location_id":"4479","lat":"36.542233","long":"-117.99005","pm25":""},{"location_name":"North Bend-North Ben","location_id":"4480","lat":"47.4902","long":"-121.7727","pm25":""},{"location_name":"North Delta","location_id":"4482","lat":"49.15833","long":"-122.90167","pm25":""},{"location_name":"North Maclean","location_id":"4483","lat":"-27.7708","long":"153.03","pm25":""},{"location_name":"North OKC","location_id":"4484","lat":"35.6128","long":"-97.4722","pm25":""},{"location_name":"North Phoenix","location_id":"4485","lat":"33.5603","long":"-112.0663","pm25":""},{"location_name":"North Valley","location_id":"4488","lat":"35.1878","long":"-106.6039","pm25":""},{"location_name":"North Ward","location_id":"4489","lat":"-19.2509","long":"146.807","pm25":""},{"location_name":"NorthAdams","location_id":"4490","lat":"42.702225","long":"-73.11041","pm25":""},{"location_name":"Northampton","location_id":"4491","lat":"36.511707","long":"-77.65539","pm25":""},{"location_name":"Northwest Harris Co.","location_id":"4493","lat":"30.0394","long":"-95.6739","pm25":""},{"location_name":"Norwich Lakenfields","location_id":"4495","lat":"52.614193","long":"1.301976","pm25":""},{"location_name":"Nottingham Centre","location_id":"4497","lat":"52.95473","long":"-1.146447","pm25":""},{"location_name":"Nottingham Western Boulevard","location_id":"4498","lat":"52.969376","long":"-1.188851","pm25":""},{"location_name":"Nova Gorica","location_id":"4499","lat":"45.955513","long":"13.652398","pm25":""},{"location_name":"Nowa Ruda - Jeziorna","location_id":"4500","lat":"50.581493","long":"16.498245","pm25":""},{"location_name":"Nowa S\u00f3l, ul. T. Ko\u015bciuszki","location_id":"4502","lat":"51.808662","long":"15.708193","pm25":""},{"location_name":"Nowiny, ul. Parkowa","location_id":"4503","lat":"50.82311","long":"20.533506","pm25":""},{"location_name":"Nowy S\u0105cz, ul. Nadbrze\u017cna","location_id":"4504","lat":"49.61928","long":"20.714403","pm25":""},{"location_name":"Nowy Targ, Plac S\u0142owackiego","location_id":"4505","lat":"49.483597","long":"20.028992","pm25":""},{"location_name":"Nueva Libertad","location_id":"4507","lat":"-36.735996","long":"-73.11869","pm25":""},{"location_name":"Nygaardsgata","location_id":"4508","lat":"59.21019","long":"10.940097","pm25":""},{"location_name":"Nysa manualna 3","location_id":"4509","lat":"50.45899","long":"17.331905","pm25":""},{"location_name":"ORGILL","location_id":"4513","lat":"35.3772","long":"-89.8319","pm25":""},{"location_name":"OSTELLATO","location_id":"4515","lat":"44.7409","long":"11.9419","pm25":""},{"location_name":"OWENPRI","location_id":"4517","lat":"37.7808","long":"-87.0756","pm25":""},{"location_name":"Oak Harbor-SW 6th (U","location_id":"4518","lat":"48.2944","long":"-122.66","pm25":""},{"location_name":"Oakdale","location_id":"4519","lat":"-34.053055","long":"150.49722","pm25":""},{"location_name":"Oakland","location_id":"4520","lat":"37.74306","long":"-122.16991","pm25":""},{"location_name":"Oakland West","location_id":"4521","lat":"37.8148","long":"-122.2824","pm25":""},{"location_name":"Oakridge - Willamett","location_id":"4522","lat":"43.74436","long":"-122.48051","pm25":""},{"location_name":"Ocean View","location_id":"4528","lat":"19.117561","long":"-155.77814","pm25":""},{"location_name":"Ogden Dunes","location_id":"4534","lat":"41.6175","long":"-87.1992","pm25":""},{"location_name":"Oildale - 3311 Manor","location_id":"4537","lat":"35.438034","long":"-119.016785","pm25":""},{"location_name":"Ojai - Ojai Ave.","location_id":"4538","lat":"34.4483","long":"-119.2303","pm25":""},{"location_name":"Olancha","location_id":"4540","lat":"36.280598","long":"-118.01166","pm25":""},{"location_name":"Olav V gate","location_id":"4541","lat":"67.2755","long":"14.419057","pm25":""},{"location_name":"Oldbury Birmingham Road","location_id":"4542","lat":"52.502438","long":"-2.003497","pm25":""},{"location_name":"Oldtown","location_id":"4543","lat":"39.2981","long":"-76.6047","pm25":""},{"location_name":"Olesno automat 4","location_id":"4544","lat":"50.876984","long":"18.416878","pm25":""},{"location_name":"Om Noi, Krathum Baen","location_id":"4545","lat":"13.705459","long":"100.315674","pm25":""},{"location_name":"Omak-Colville Tribe","location_id":"4546","lat":"48.39999","long":"-119.51896","pm25":""},{"location_name":"Ontario Near Road","location_id":"4548","lat":"34.068115","long":"-117.525795","pm25":""},{"location_name":"Opole automat 5","location_id":"4549","lat":"50.666737","long":"17.899137","pm25":""},{"location_name":"Opole manualna 4","location_id":"4550","lat":"50.676857","long":"17.950277","pm25":""},{"location_name":"Orange Grove","location_id":"4552","lat":"32.322575","long":"-111.03771","pm25":""},{"location_name":"Osceola Co. Fire Sta","location_id":"4556","lat":"28.3478","long":"-81.6367","pm25":""},{"location_name":"Osceola National For","location_id":"4557","lat":"30.1972","long":"-82.445","pm25":""},{"location_name":"Osiecz\u00f3w","location_id":"4558","lat":"51.31763","long":"15.431719","pm25":""},{"location_name":"Osorno","location_id":"4559","lat":"-40.58448","long":"-73.11872","pm25":""},{"location_name":"Otay Mesa - Donovan","location_id":"4560","lat":"32.57936","long":"-116.92949","pm25":""},{"location_name":"Ottawa","location_id":"4562","lat":"45.4322","long":"-75.6764","pm25":""},{"location_name":"Otwock-Brzozowa","location_id":"4563","lat":"52.115726","long":"21.237297","pm25":""},{"location_name":"Oude Meer-Aalsmeerderdijk","location_id":"4564","lat":"52.28","long":"4.77077","pm25":""},{"location_name":"Ouray","location_id":"4565","lat":"40.054848","long":"-109.68737","pm25":""},{"location_name":"Oxford","location_id":"4566","lat":"39.5327","long":"-84.7286","pm25":""},{"location_name":"Oxford Centre Roadside","location_id":"4567","lat":"51.751743","long":"-1.257463","pm25":""},{"location_name":"Oxford St Ebbes","location_id":"4568","lat":"51.744804","long":"-1.260278","pm25":""},{"location_name":"O\u0142awa - \u017bo\u0142nierzy AK","location_id":"4570","lat":"50.942074","long":"17.291332","pm25":""},{"location_name":"P2","location_id":"4571","lat":"39.5958","long":"-110.77","pm25":""},{"location_name":"PARADIGNA","location_id":"4574","lat":"44.8413","long":"10.3446","pm25":""},{"location_name":"PARCO BERTOZZI","location_id":"4575","lat":"44.2856","long":"11.8734","pm25":""},{"location_name":"PARCO EDILCARANI","location_id":"4576","lat":"44.5404","long":"10.7924","pm25":""},{"location_name":"PARCO FERRARI","location_id":"4577","lat":"44.6516","long":"10.9073","pm25":""},{"location_name":"PARCO MONTECUCCO","location_id":"4578","lat":"45.0385","long":"9.6693","pm25":""},{"location_name":"PARCO RESISTENZA","location_id":"4579","lat":"44.2152","long":"12.0482","pm25":""},{"location_name":"PARR","location_id":"4581","lat":"34.7561","long":"-92.2758","pm25":""},{"location_name":"PASCAGOULA","location_id":"4582","lat":"30.3775","long":"-88.5339","pm25":""},{"location_name":"PC South Girard Scho","location_id":"4583","lat":"32.437027","long":"-84.99966","pm25":""},{"location_name":"PEORIA_H","location_id":"4585","lat":"40.745","long":"-89.5861","pm25":""},{"location_name":"PEORIA_J","location_id":"4586","lat":"40.6978","long":"-89.5889","pm25":""},{"location_name":"Perkinstown","location_id":"4588","lat":"45.2039","long":"-90.6","pm25":""},{"location_name":"PICTOU","location_id":"4591","lat":"45.6819","long":"-62.6953","pm25":""},{"location_name":"PIKE2001","location_id":"4593","lat":"37.4828","long":"-82.5353","pm25":""},{"location_name":"PITTAGCT","location_id":"4594","lat":"35.641277","long":"-77.36012","pm25":""},{"location_name":"POMPANO_BEACH","location_id":"4596","lat":"26.2906","long":"-80.0969","pm25":""},{"location_name":"PORT HAWKESBURY","location_id":"4597","lat":"45.61394","long":"-61.36235","pm25":""},{"location_name":"PORT HURON","location_id":"4598","lat":"42.9533","long":"-82.4564","pm25":""},{"location_name":"PORTA SAN FELICE","location_id":"4599","lat":"44.5","long":"11.3285","pm25":""},{"location_name":"POTAWATOMI","location_id":"4600","lat":"45.5639","long":"-88.81","pm25":""},{"location_name":"PRG Plaza 400","location_id":"4601","lat":"53.9147","long":"-122.7419","pm25":""},{"location_name":"PRINCE ALBERT","location_id":"4602","lat":"53.201694","long":"-105.75203","pm25":""},{"location_name":"Pryor","location_id":"4603","lat":"36.2283","long":"-95.25","pm25":""},{"location_name":"PT01021","location_id":"4605","lat":"41.199722","long":"-8.644722","pm25":""},{"location_name":"PT01023","location_id":"4606","lat":"41.20667","long":"-8.552778","pm25":""},{"location_name":"PT01024","location_id":"4607","lat":"41.235558","long":"-8.618611","pm25":""},{"location_name":"PT01025","location_id":"4608","lat":"41.232224","long":"-8.713056","pm25":""},{"location_name":"PT01028","location_id":"4609","lat":"41.164444","long":"-8.589444","pm25":""},{"location_name":"PT01030","location_id":"4610","lat":"41.18611","long":"-8.663056","pm25":""},{"location_name":"PT01031","location_id":"4611","lat":"41.25222","long":"-8.660556","pm25":""},{"location_name":"PT01034","location_id":"4612","lat":"41.218056","long":"-8.632222","pm25":""},{"location_name":"PT01041","location_id":"4613","lat":"41.54972","long":"-8.405833","pm25":""},{"location_name":"PT01042","location_id":"4614","lat":"41.569443","long":"-8.456944","pm25":""},{"location_name":"PT01043","location_id":"4615","lat":"41.2075","long":"-8.338056","pm25":""},{"location_name":"PT01044","location_id":"4616","lat":"41.274166","long":"-8.376111","pm25":""},{"location_name":"PT01046","location_id":"4617","lat":"41.449722","long":"-8.296389","pm25":""},{"location_name":"PT01047","location_id":"4618","lat":"41.802223","long":"-8.693889","pm25":""},{"location_name":"PT01048","location_id":"4619","lat":"41.371387","long":"-7.790833","pm25":""},{"location_name":"PT01050","location_id":"4620","lat":"41.1475","long":"-8.658889","pm25":""},{"location_name":"PT01051","location_id":"4621","lat":"41.308613","long":"-8.720833","pm25":""},{"location_name":"PT01052","location_id":"4622","lat":"41.18778","long":"-8.672222","pm25":""},{"location_name":"PT01053","location_id":"4623","lat":"41.09667","long":"-8.555833","pm25":""},{"location_name":"PT01054","location_id":"4624","lat":"40.999443","long":"-8.623333","pm25":""},{"location_name":"PT01055","location_id":"4625","lat":"41.18778","long":"-8.671944","pm25":""},{"location_name":"PT02004","location_id":"4626","lat":"40.756668","long":"-8.572778","pm25":""},{"location_name":"PT02006","location_id":"4627","lat":"40.21472","long":"-8.401667","pm25":""},{"location_name":"PT02016","location_id":"4628","lat":"40.206944","long":"-8.410833","pm25":""},{"location_name":"PT02017","location_id":"4629","lat":"40.635555","long":"-8.646667","pm25":""},{"location_name":"PT02018","location_id":"4630","lat":"40.58972","long":"-8.670556","pm25":""},{"location_name":"PT02019","location_id":"4631","lat":"39.92389","long":"-8.891667","pm25":""},{"location_name":"PT02020","location_id":"4632","lat":"40.233055","long":"-7.301944","pm25":""},{"location_name":"PT02021","location_id":"4633","lat":"40.64111","long":"-8.100556","pm25":""},{"location_name":"PT03055","location_id":"4635","lat":"38.666668","long":"-9.047778","pm25":""},{"location_name":"PT03063","location_id":"4636","lat":"38.619446","long":"-9.081111","pm25":""},{"location_name":"PT03070","location_id":"4637","lat":"38.894722","long":"-9.1175","pm25":""},{"location_name":"PT03071","location_id":"4638","lat":"38.76889","long":"-9.108056","pm25":""},{"location_name":"PT03072","location_id":"4639","lat":"38.74861","long":"-9.148889","pm25":""},{"location_name":"PT03075","location_id":"4640","lat":"38.72028","long":"-9.145833","pm25":""},{"location_name":"PT03082","location_id":"4641","lat":"38.738888","long":"-9.2075","pm25":""},{"location_name":"PT03083","location_id":"4642","lat":"38.663612","long":"-9.157778","pm25":""},{"location_name":"PT03084","location_id":"4643","lat":"38.754166","long":"-9.230833","pm25":""},{"location_name":"PT03085","location_id":"4644","lat":"38.829723","long":"-9.164444","pm25":""},{"location_name":"PT03087","location_id":"4645","lat":"38.705","long":"-9.210278","pm25":""},{"location_name":"PT03089","location_id":"4646","lat":"38.785","long":"-9.347222","pm25":""},{"location_name":"PT03091","location_id":"4647","lat":"38.6975","long":"-9.323333","pm25":""},{"location_name":"PT03093","location_id":"4648","lat":"38.529167","long":"-8.894167","pm25":""},{"location_name":"PT03094","location_id":"4649","lat":"38.524166","long":"-8.894167","pm25":""},{"location_name":"PT03095","location_id":"4650","lat":"38.65861","long":"-9.066944","pm25":""},{"location_name":"PT03096","location_id":"4651","lat":"39.3525","long":"-8.466111","pm25":""},{"location_name":"PT03097","location_id":"4652","lat":"38.802223","long":"-9.182222","pm25":""},{"location_name":"PT03099","location_id":"4653","lat":"38.635555","long":"-8.690556","pm25":""},{"location_name":"PT03100","location_id":"4654","lat":"38.748055","long":"-9.2025","pm25":""},{"location_name":"PT03101","location_id":"4655","lat":"38.89611","long":"-9.040278","pm25":""},{"location_name":"PT03102","location_id":"4656","lat":"39.27833","long":"-9.245556","pm25":""},{"location_name":"PT03103","location_id":"4657","lat":"38.65","long":"-9.048611","pm25":""},{"location_name":"PT03104","location_id":"4658","lat":"38.70139","long":"-9.429444","pm25":""},{"location_name":"PT04001","location_id":"4659","lat":"37.954166","long":"-8.838056","pm25":""},{"location_name":"PT04002","location_id":"4660","lat":"38.076942","long":"-8.798611","pm25":""},{"location_name":"PT04003","location_id":"4661","lat":"37.871113","long":"-8.723889","pm25":""},{"location_name":"PT04004","location_id":"4662","lat":"38.02","long":"-8.6975","pm25":""},{"location_name":"PT04006","location_id":"4663","lat":"38.615","long":"-7.3975","pm25":""},{"location_name":"PT05007","location_id":"4664","lat":"37.015","long":"-7.926667","pm25":""},{"location_name":"PT05008","location_id":"4665","lat":"37.091667","long":"-8.249722","pm25":""},{"location_name":"PT05011","location_id":"4666","lat":"37.138332","long":"-8.542222","pm25":""},{"location_name":"PT05012","location_id":"4667","lat":"37.3125","long":"-7.678611","pm25":""},{"location_name":"PT06004","location_id":"4668","lat":"32.648888","long":"-16.883057","pm25":""},{"location_name":"PT06005","location_id":"4669","lat":"32.649723","long":"-16.918333","pm25":""},{"location_name":"PT06008","location_id":"4670","lat":"32.807777","long":"-16.886389","pm25":""},{"location_name":"PT07001","location_id":"4671","lat":"38.605","long":"-28.63139","pm25":""},{"location_name":"PUBLIC HEALTH","location_id":"4672","lat":"41.9767","long":"-91.6878","pm25":""},{"location_name":"Pabianice-Polfa","location_id":"4677","lat":"51.66798","long":"19.368683","pm25":""},{"location_name":"Padonia","location_id":"4680","lat":"39.462","long":"-76.6316","pm25":""},{"location_name":"Pahala","location_id":"4681","lat":"19.2065","long":"-155.4689","pm25":""},{"location_name":"Painesville - JFS","location_id":"4683","lat":"41.72681","long":"-81.24216","pm25":""},{"location_name":"Pak Nam Pho, Mueang","location_id":"4684","lat":"15.707849","long":"100.13193","pm25":""},{"location_name":"Pak Nam, Mueang","location_id":"4685","lat":"","long":"","pm25":""},{"location_name":"Pak Phriao, Mueang","location_id":"4686","lat":"14.523537","long":"100.92917","pm25":""},{"location_name":"Palatka","location_id":"4688","lat":"29.686666","long":"-81.65639","pm25":""},{"location_name":"Palisade Ozone","location_id":"4689","lat":"39.1306","long":"-108.3139","pm25":""},{"location_name":"Palm Springs - Fire","location_id":"4691","lat":"33.852604","long":"-116.54096","pm25":""},{"location_name":"Palo Duro","location_id":"4693","lat":"34.8803","long":"-101.6649","pm25":""},{"location_name":"Palo Verde","location_id":"4694","lat":"36.173416","long":"-115.332726","pm25":""},{"location_name":"Paonia","location_id":"4696","lat":"38.8763","long":"-107.6022","pm25":""},{"location_name":"Paradise - Airport","location_id":"4697","lat":"39.708454","long":"-121.61731","pm25":""},{"location_name":"Paradise Road","location_id":"4698","lat":"34.5414","long":"-119.7906","pm25":""},{"location_name":"Paradise Theater","location_id":"4699","lat":"39.77919","long":"-121.59135","pm25":""},{"location_name":"Parc Cambron","location_id":"4701","lat":"45.4125","long":"-71.8744","pm25":""},{"location_name":"Parc Primavere","location_id":"4702","lat":"46.77417","long":"-71.36972","pm25":""},{"location_name":"Parc Tremblay","location_id":"4703","lat":"48.2344","long":"-78.9833","pm25":""},{"location_name":"Parker County C76","location_id":"4704","lat":"32.8686","long":"-97.9058","pm25":""},{"location_name":"Parkgate (Eagle Rive","location_id":"4705","lat":"61.3267","long":"-149.5697","pm25":""},{"location_name":"Parklane","location_id":"4706","lat":"34.0939","long":"-80.9622","pm25":""},{"location_name":"Parkway East (Near R","location_id":"4707","lat":"40.43743","long":"-79.86357","pm25":""},{"location_name":"Parlier","location_id":"4708","lat":"36.5975","long":"-119.5036","pm25":""},{"location_name":"Parry Sound","location_id":"4710","lat":"45.3378","long":"-80.0378","pm25":""},{"location_name":"Parsons","location_id":"4711","lat":"39.0905","long":"-79.6617","pm25":""},{"location_name":"Parzniewice","location_id":"4712","lat":"51.291176","long":"19.517555","pm25":""},{"location_name":"Pasadena","location_id":"4713","lat":"34.13263","long":"-118.127144","pm25":""},{"location_name":"Paso Robles - Santa","location_id":"4715","lat":"35.61467","long":"-120.65691","pm25":""},{"location_name":"Patricia McInnes","location_id":"4718","lat":"56.7522","long":"-111.4761","pm25":""},{"location_name":"Paul Meyer","location_id":"4722","lat":"36.106388","long":"-115.253334","pm25":""},{"location_name":"Paul Spur Chemical L","location_id":"4724","lat":"31.3658","long":"-109.7309","pm25":""},{"location_name":"Paw Park","location_id":"4726","lat":"27.3503","long":"-82.4797","pm25":""},{"location_name":"Payson Well Site","location_id":"4731","lat":"34.22934","long":"-111.3297","pm25":""},{"location_name":"Pearl City","location_id":"4732","lat":"21.392834","long":"-157.96913","pm25":""},{"location_name":"Peckville","location_id":"4733","lat":"41.4789","long":"-75.5781","pm25":""},{"location_name":"Peebles","location_id":"4736","lat":"55.65747","long":"-3.196527","pm25":""},{"location_name":"Peje","location_id":"4739","lat":"42.65969","long":"20.284597","pm25":""},{"location_name":"Pembroke Exchange St","location_id":"4740","lat":"43.13246","long":"-71.458244","pm25":""},{"location_name":"Pendleton - McKay Cr","location_id":"4741","lat":"45.65223","long":"-118.82304","pm25":""},{"location_name":"Penn State","location_id":"4742","lat":"40.7208","long":"-77.9319","pm25":""},{"location_name":"Pensacola NAS","location_id":"4744","lat":"30.3681","long":"-87.2708","pm25":""},{"location_name":"Pepsi Place","location_id":"4745","lat":"30.262808","long":"-81.606834","pm25":""},{"location_name":"Perch River","location_id":"4746","lat":"44.0878","long":"-75.9744","pm25":""},{"location_name":"Perdue","location_id":"4747","lat":"25.5864","long":"-80.3269","pm25":""},{"location_name":"Perimeter","location_id":"4748","lat":"25.785473","long":"-80.2842","pm25":""},{"location_name":"Perris","location_id":"4750","lat":"33.78933","long":"-117.22764","pm25":""},{"location_name":"Peterborough","location_id":"4753","lat":"44.3","long":"-78.35","pm25":""},{"location_name":"Petrified Forest NP","location_id":"4754","lat":"34.8225","long":"-109.8919","pm25":""},{"location_name":"Pfizer Lab","location_id":"4755","lat":"40.868","long":"-73.8782","pm25":""},{"location_name":"Phaya Thai, Khet Phaya Thai","location_id":"4758","lat":"13.780444","long":"100.537796","pm25":""},{"location_name":"Phelan - Beekley Roa","location_id":"4759","lat":"34.425053","long":"-117.58981","pm25":""},{"location_name":"Philippine-Stelleweg","location_id":"4760","lat":"51.2945","long":"3.74948","pm25":""},{"location_name":"Phoenix JLG Supersit","location_id":"4761","lat":"33.5036","long":"-112.095","pm25":""},{"location_name":"Phra Bat, Mueang","location_id":"4762","lat":"18.286776","long":"99.50632","pm25":""},{"location_name":"Piaski-Krzyzowka","location_id":"4763","lat":"52.50139","long":"17.773464","pm25":""},{"location_name":"Piast\u00f3w-Pu\u0142askiego","location_id":"4764","lat":"52.191727","long":"20.837488","pm25":""},{"location_name":"Pickle Lake","location_id":"4765","lat":"54.4494","long":"-90.2175","pm25":""},{"location_name":"Pico Rivera","location_id":"4766","lat":"34.010284","long":"-118.06848","pm25":""},{"location_name":"Pierre","location_id":"4768","lat":"44.373787","long":"-100.28727","pm25":""},{"location_name":"Pila, ul. Kusocinkiego","location_id":"4770","lat":"53.154408","long":"16.759571","pm25":""},{"location_name":"Pilot Point C1032","location_id":"4772","lat":"33.4107","long":"-96.9437","pm25":""},{"location_name":"Pinal Air Park","location_id":"4773","lat":"32.50831","long":"-111.30806","pm25":""},{"location_name":"Pinal County Housing","location_id":"4774","lat":"32.891056","long":"-111.5705","pm25":""},{"location_name":"Pinedale","location_id":"4775","lat":"42.8698","long":"-109.8708","pm25":""},{"location_name":"Pinedale Gaseous","location_id":"4776","lat":"42.8698","long":"-109.8708","pm25":""},{"location_name":"Pinehouse Lake","location_id":"4777","lat":"55.50333","long":"-106.72167","pm25":""},{"location_name":"Pinehurst","location_id":"4778","lat":"47.536713","long":"-116.23687","pm25":""},{"location_name":"Piney Run","location_id":"4779","lat":"39.7058","long":"-79.0119","pm25":""},{"location_name":"Pingtung","location_id":"4780","lat":"22.67308","long":"120.48803","pm25":""},{"location_name":"Pinnacle Peak Club H","location_id":"4782","lat":"33.7123","long":"-111.8527","pm25":""},{"location_name":"Pinnacle State Park","location_id":"4783","lat":"42.0972","long":"-77.2103","pm25":""},{"location_name":"Pinnacles NM","location_id":"4784","lat":"36.485","long":"-121.1556","pm25":""},{"location_name":"Piotrk\u00f3w Tryb.-Krakowskie Przedmie\u015bcie","location_id":"4785","lat":"51.404408","long":"19.696957","pm25":""},{"location_name":"Piru - Pacific","location_id":"4787","lat":"34.4044","long":"-118.81","pm25":""},{"location_name":"Piseco Lake","location_id":"4788","lat":"43.4556","long":"-74.515","pm25":""},{"location_name":"Pitt Meadows","location_id":"4791","lat":"49.24528","long":"-122.70889","pm25":""},{"location_name":"PittsfieldES","location_id":"4792","lat":"42.453033","long":"-73.23878","pm25":""},{"location_name":"Placerville","location_id":"4793","lat":"38.72528","long":"-120.82192","pm25":""},{"location_name":"Pleasanton - Owens C","location_id":"4795","lat":"37.70122","long":"-121.90302","pm25":""},{"location_name":"Pleszew, Al. Mickiewicza","location_id":"4796","lat":"51.884922","long":"17.791105","pm25":""},{"location_name":"Pluak Daeng, Pluak Daeng","location_id":"4797","lat":"12.97378","long":"101.212845","pm25":""},{"location_name":"Plummer","location_id":"4799","lat":"38.9856","long":"-86.99","pm25":""},{"location_name":"Plummer CDA Tribe","location_id":"4800","lat":"47.3386","long":"-116.8859","pm25":""},{"location_name":"Plymouth Centre","location_id":"4801","lat":"50.37167","long":"-4.142361","pm25":""},{"location_name":"Pocatello Garrett an","location_id":"4806","lat":"42.8767","long":"-112.4603","pm25":""},{"location_name":"Pocatello STP","location_id":"4807","lat":"42.9164","long":"-112.5158","pm25":""},{"location_name":"Polson-MT","location_id":"4810","lat":"47.6925","long":"-114.0122","pm25":""},{"location_name":"Pomona","location_id":"4812","lat":"34.0667","long":"-117.7506","pm25":""},{"location_name":"Ponca City","location_id":"4813","lat":"36.69719","long":"-97.081276","pm25":""},{"location_name":"Port Alberni Element","location_id":"4815","lat":"49.2608","long":"-124.8056","pm25":""},{"location_name":"Port Allen","location_id":"4816","lat":"30.5019","long":"-91.2111","pm25":""},{"location_name":"Port Angeles-E 5th S","location_id":"4817","lat":"48.115","long":"-123.43643","pm25":""},{"location_name":"Port Arthur West C28","location_id":"4818","lat":"29.8942","long":"-93.9875","pm25":""},{"location_name":"Port Manatee","location_id":"4820","lat":"27.63861","long":"-82.547775","pm25":""},{"location_name":"Port Stanley","location_id":"4822","lat":"42.6725","long":"-81.1647","pm25":""},{"location_name":"Port Talbot Margam","location_id":"4823","lat":"51.58395","long":"-3.770822","pm25":""},{"location_name":"Port Townsend-San Ju","location_id":"4824","lat":"48.1291","long":"-122.7789","pm25":""},{"location_name":"Port au Choix","location_id":"4825","lat":"50.71124","long":"-57.36365","pm25":""},{"location_name":"Portage-Hwy 12","location_id":"4827","lat":"41.6167","long":"-87.1458","pm25":""},{"location_name":"Porterville-NFS","location_id":"4828","lat":"36.0319","long":"-119.055","pm25":""},{"location_name":"Portland - Deering O","location_id":"4830","lat":"43.660248","long":"-70.26897","pm25":""},{"location_name":"Portland - SE Lafaye","location_id":"4831","lat":"45.49664","long":"-122.602875","pm25":""},{"location_name":"Portland - Sauvie Is","location_id":"4832","lat":"45.76853","long":"-122.7721","pm25":""},{"location_name":"Portland Near Road","location_id":"4834","lat":"45.39916","long":"-122.7455","pm25":""},{"location_name":"Portola","location_id":"4835","lat":"39.808334","long":"-120.471664","pm25":""},{"location_name":"Portsmouth","location_id":"4836","lat":"43.07537","long":"-70.74802","pm25":""},{"location_name":"Posterholt-Vlodropperweg","location_id":"4838","lat":"51.1192","long":"6.0424","pm25":""},{"location_name":"Potato Creek State P","location_id":"4840","lat":"41.5517","long":"-86.3706","pm25":""},{"location_name":"Potosi","location_id":"4842","lat":"42.69213","long":"-90.69637","pm25":""},{"location_name":"Powell River James T","location_id":"4843","lat":"49.8891","long":"-124.5625","pm25":""},{"location_name":"Poznan-Dabrowskiego","location_id":"4845","lat":"52.42032","long":"16.877289","pm25":""},{"location_name":"Poznan-Polanka","location_id":"4846","lat":"52.398174","long":"16.959518","pm25":""},{"location_name":"Pozna\u0144 - RatajeMOB","location_id":"4847","lat":"52.391727","long":"16.998577","pm25":""},{"location_name":"Po\u0142aniec, ul. Ruszcza\u0144ska","location_id":"4848","lat":"50.429012","long":"21.277367","pm25":""},{"location_name":"Pratu Chai, Phra Nakhon Si Ayutthayal","location_id":"4850","lat":"14.349367","long":"100.568535","pm25":""},{"location_name":"Preble County","location_id":"4851","lat":"39.83562","long":"-84.72049","pm25":""},{"location_name":"Preneste","location_id":"4852","lat":"41.886017","long":"12.541614","pm25":""},{"location_name":"Prescott Pioneer Par","location_id":"4854","lat":"34.61205","long":"-112.46321","pm25":""},{"location_name":"Presque Isle Riversi","location_id":"4856","lat":"46.6823","long":"-68.0162","pm25":""},{"location_name":"Prestebakke","location_id":"4857","lat":"58.99677","long":"11.52769","pm25":""},{"location_name":"Preston","location_id":"4858","lat":"53.76559","long":"-2.680353","pm25":""},{"location_name":"Preston PM25 BAM","location_id":"4859","lat":"42.082222","long":"-111.86417","pm25":""},{"location_name":"Pride","location_id":"4861","lat":"30.7008","long":"-91.0561","pm25":""},{"location_name":"Prince Edward","location_id":"4862","lat":"37.17","long":"-78.31","pm25":""},{"location_name":"Prineville - Davidso","location_id":"4863","lat":"44.299786","long":"-120.84477","pm25":""},{"location_name":"Prishtine - IHMK","location_id":"4864","lat":"42.648872","long":"21.137121","pm25":""},{"location_name":"Prishtine, Rilindje","location_id":"4865","lat":"42.659657","long":"21.157309","pm25":""},{"location_name":"Pristina","location_id":"4866","lat":"42.661995","long":"21.15055","pm25":""},{"location_name":"Prizren","location_id":"4867","lat":"42.21586","long":"20.741556","pm25":""},{"location_name":"Prospect","location_id":"4869","lat":"-33.794724","long":"150.9125","pm25":""},{"location_name":"Prudnik mobilna","location_id":"4872","lat":"50.320858","long":"17.59191","pm25":""},{"location_name":"Przemysl-Grunwaldzka-WIOS","location_id":"4873","lat":"49.78434","long":"22.756239","pm25":""},{"location_name":"Pubpla, Wang Thonglang","location_id":"4874","lat":"13.76963","long":"100.61456","pm25":""},{"location_name":"Puchuncav\u00ed","location_id":"4875","lat":"-32.71859","long":"-71.40728","pm25":""},{"location_name":"Pudahuel","location_id":"4876","lat":"-33.437813","long":"-70.75017","pm25":""},{"location_name":"Puente Alto","location_id":"4877","lat":"-33.591393","long":"-70.59479","pm25":""},{"location_name":"Pullman-Dexter Ave","location_id":"4879","lat":"46.7245","long":"-117.1801","pm25":""},{"location_name":"Punta Arenas","location_id":"4883","lat":"-53.158295","long":"-70.9215","pm25":""},{"location_name":"Puyallup-128th St","location_id":"4888","lat":"47.1405","long":"-122.2992","pm25":""},{"location_name":"Pu\u0142awy ul. Karpi\u0144skiego","location_id":"4890","lat":"51.41905","long":"21.961088","pm25":""},{"location_name":"P\u00c9MONCA","location_id":"4891","lat":"48.8183","long":"-72.7428","pm25":""},{"location_name":"P\u0142ock-Gimnazjum","location_id":"4893","lat":"52.55628","long":"19.687672","pm25":""},{"location_name":"P\u0142ock-Reja","location_id":"4894","lat":"52.550938","long":"19.709791","pm25":""},{"location_name":"Quilicura","location_id":"4896","lat":"-33.34963","long":"-70.72379","pm25":""},{"location_name":"Quaker City","location_id":"4898","lat":"39.9428","long":"-81.3373","pm25":""},{"location_name":"Queen Valley","location_id":"4899","lat":"33.2894","long":"-111.2928","pm25":""},{"location_name":"Queens","location_id":"4900","lat":"40.7375","long":"-73.8244","pm25":""},{"location_name":"Queens Near-road","location_id":"4901","lat":"40.739265","long":"-73.817696","pm25":""},{"location_name":"Quesnel Senior Secon","location_id":"4902","lat":"52.9822","long":"-122.4922","pm25":""},{"location_name":"Quincy 3rd","location_id":"4905","lat":"47.24126","long":"-119.84595","pm25":""},{"location_name":"Quincy BAM","location_id":"4906","lat":"39.9369","long":"-120.9478","pm25":""},{"location_name":"Quintero","location_id":"4907","lat":"-32.77252","long":"-71.5353","pm25":""},{"location_name":"RED DEER RIVERSIDE D","location_id":"4910","lat":"52.2989","long":"-113.7942","pm25":""},{"location_name":"REMESINA","location_id":"4912","lat":"44.8004","long":"10.8843","pm25":""},{"location_name":"RG_SOUTH","location_id":"4913","lat":"38.75961","long":"-94.57983","pm25":""},{"location_name":"RHINELANDER","location_id":"4914","lat":"45.6453","long":"-89.4125","pm25":""},{"location_name":"RIT","location_id":"4916","lat":"39.922516","long":"-75.18678","pm25":""},{"location_name":"RIVER_Terrace","location_id":"4917","lat":"38.895683","long":"-76.95809","pm25":""},{"location_name":"ROCKWELL","location_id":"4918","lat":"35.55187","long":"-80.39504","pm25":""},{"location_name":"ROCK_IS","location_id":"4919","lat":"41.5144","long":"-90.5172","pm25":""},{"location_name":"ROLAND","location_id":"4921","lat":"35.40814","long":"-94.524414","pm25":""},{"location_name":"ROMA","location_id":"4922","lat":"44.216","long":"12.0575","pm25":""},{"location_name":"RS0030A","location_id":"4925","lat":"43.31655","long":"21.913548","pm25":""},{"location_name":"RS0031A","location_id":"4926","lat":"45.238644","long":"19.835705","pm25":""},{"location_name":"RS0032A","location_id":"4927","lat":"44.82112","long":"20.459112","pm25":""},{"location_name":"RS0033A","location_id":"4928","lat":"43.322556","long":"21.919025","pm25":""},{"location_name":"RS0034A","location_id":"4929","lat":"45.821484","long":"20.454008","pm25":""},{"location_name":"RS0036A","location_id":"4930","lat":"44.80318","long":"20.400152","pm25":""},{"location_name":"RT","location_id":"4931","lat":"36.139706","long":"-115.17565","pm25":""},{"location_name":"RUTLAND","location_id":"4933","lat":"43.60853","long":"-72.98246","pm25":""},{"location_name":"Racib\u00f3rz, Wojska Polskiego 8","location_id":"4936","lat":"50.09114","long":"18.21626","pm25":""},{"location_name":"Radom-Tochtermana","location_id":"4939","lat":"51.399082","long":"21.147474","pm25":""},{"location_name":"Radomsko-Rolna2","location_id":"4940","lat":"51.06744","long":"19.448694","pm25":""},{"location_name":"Rahway PM","location_id":"4941","lat":"40.603943","long":"-74.27618","pm25":""},{"location_name":"Rama IV Rd., Pathum Wan","location_id":"4943","lat":"13.72983","long":"100.53649","pm25":""},{"location_name":"Rambergan","location_id":"4945","lat":"69.65428","long":"18.95636","pm25":""},{"location_name":"Ranchos","location_id":"4946","lat":"38.89761","long":"-119.7321","pm25":""},{"location_name":"Randwick","location_id":"4947","lat":"-33.933334","long":"151.24194","pm25":""},{"location_name":"Rangely, CO","location_id":"4948","lat":"40.08694","long":"-108.761","pm25":""},{"location_name":"Rangoon","location_id":"4949","lat":"16.8256","long":"96.1445","pm25":""},{"location_name":"Raymond-4th St","location_id":"4953","lat":"46.688217","long":"-123.731766","pm25":""},{"location_name":"Reading Airport","location_id":"4954","lat":"40.3833","long":"-75.9686","pm25":""},{"location_name":"Reading New Town","location_id":"4956","lat":"51.45309","long":"-0.944067","pm25":""},{"location_name":"Red Bluff - Walnut o","location_id":"4957","lat":"40.170918","long":"-122.25567","pm25":""},{"location_name":"Red Lake Nation","location_id":"4958","lat":"47.87816","long":"-95.029175","pm25":""},{"location_name":"Red Mountain","location_id":"4959","lat":"33.5079","long":"-111.7546","pm25":""},{"location_name":"Redding","location_id":"4960","lat":"40.5497","long":"-122.3792","pm25":""},{"location_name":"Redhills\/Shandon","location_id":"4961","lat":"35.64366","long":"-120.23134","pm25":""},{"location_name":"Redlands - Dearborn","location_id":"4962","lat":"34.059628","long":"-117.14735","pm25":""},{"location_name":"Redwash","location_id":"4963","lat":"40.204433","long":"-109.35321","pm25":""},{"location_name":"Redwood City","location_id":"4964","lat":"37.4828","long":"-122.2022","pm25":""},{"location_name":"Regina","location_id":"4965","lat":"50.45","long":"-104.6169","pm25":""},{"location_name":"Remount","location_id":"4967","lat":"35.21317","long":"-80.874084","pm25":""},{"location_name":"Rengo","location_id":"4968","lat":"-34.394543","long":"-70.85298","pm25":""},{"location_name":"Reno3","location_id":"4971","lat":"39.52507","long":"-119.80775","pm25":""},{"location_name":"Research Farm","location_id":"4972","lat":"44.348602","long":"-96.8073","pm25":""},{"location_name":"Reseda","location_id":"4973","lat":"34.1992","long":"-118.5331","pm25":""},{"location_name":"Residence for Dept. of Primary Industries and Mines","location_id":"4974","lat":"13.652157","long":"100.53184","pm25":""},{"location_name":"Richmond","location_id":"4978","lat":"-33.618332","long":"150.74583","pm25":""},{"location_name":"Richmond - 7th St","location_id":"4979","lat":"37.9478","long":"-122.3636","pm25":""},{"location_name":"Richmond South","location_id":"4980","lat":"49.14139","long":"-123.10833","pm25":""},{"location_name":"Ridderkerk-Hogeweg","location_id":"4981","lat":"51.8694","long":"4.58006","pm25":""},{"location_name":"Rider Trail I-70","location_id":"4982","lat":"38.75264","long":"-90.44884","pm25":""},{"location_name":"Rider University","location_id":"4983","lat":"40.283092","long":"-74.742645","pm25":""},{"location_name":"Rieti 1","location_id":"4984","lat":"42.404095","long":"12.858224","pm25":""},{"location_name":"Rifle Ozone","location_id":"4985","lat":"39.5418","long":"-107.7841","pm25":""},{"location_name":"Rifle Particulate","location_id":"4986","lat":"39.5318","long":"-107.7823","pm25":""},{"location_name":"Rillito","location_id":"4987","lat":"32.41434","long":"-111.15454","pm25":""},{"location_name":"Ringsakervegen","location_id":"4989","lat":"60.88593","long":"10.93785","pm25":""},{"location_name":"Rio Vista","location_id":"4993","lat":"38.2183","long":"-121.77","pm25":""},{"location_name":"Ritzville-Alder St","location_id":"4995","lat":"47.128","long":"-118.3819","pm25":""},{"location_name":"Riverside","location_id":"4997","lat":"35.0508","long":"-85.2931","pm25":""},{"location_name":"Riverside - Rubidoux","location_id":"4998","lat":"33.99945","long":"-117.41583","pm25":""},{"location_name":"Riviera Beach","location_id":"4999","lat":"39.158882","long":"-76.51137","pm25":""},{"location_name":"Rivi\u00e8re-des-Prairies","location_id":"5000","lat":"45.651722","long":"-73.5739","pm25":""},{"location_name":"Roanoke Elem. School","location_id":"5002","lat":"40.9606","long":"-85.3803","pm25":""},{"location_name":"Rochester","location_id":"5003","lat":"43.9947","long":"-92.4497","pm25":""},{"location_name":"Rochester Stoke","location_id":"5004","lat":"51.45617","long":"0.634889","pm25":""},{"location_name":"Rockford","location_id":"5005","lat":"42.267002","long":"-89.08917","pm25":""},{"location_name":"Rockingham","location_id":"5006","lat":"38.4772","long":"-78.8167","pm25":""},{"location_name":"Rockland Cty","location_id":"5007","lat":"41.18208","long":"-74.02819","pm25":""},{"location_name":"Rocklea","location_id":"5008","lat":"-27.5358","long":"152.993","pm25":""},{"location_name":"Rockville","location_id":"5009","lat":"39.1144","long":"-77.1069","pm25":""},{"location_name":"Rockwall Heath C69","location_id":"5010","lat":"32.9361","long":"-96.4592","pm25":""},{"location_name":"Rocky Flats - N - 16","location_id":"5012","lat":"39.9128","long":"-105.1883","pm25":""},{"location_name":"Rocky Mountain NP","location_id":"5013","lat":"40.2778","long":"-105.5453","pm25":""},{"location_name":"Rocky Point Park","location_id":"5014","lat":"49.28083","long":"-122.84917","pm25":""},{"location_name":"Rolland, \u00c5sane","location_id":"5016","lat":"60.462666","long":"5.332447","pm25":""},{"location_name":"Rome","location_id":"5017","lat":"34.26054","long":"-85.32333","pm25":""},{"location_name":"Rome-Kraftsman","location_id":"5018","lat":"34.243645","long":"-85.32595","pm25":""},{"location_name":"Romeral","location_id":"5019","lat":"-32.823956","long":"-71.00644","pm25":""},{"location_name":"Roosvelt","location_id":"5022","lat":"40.2943","long":"-110.009","pm25":""},{"location_name":"Rosalia-Josephine St","location_id":"5023","lat":"47.2313","long":"-117.3685","pm25":""},{"location_name":"Rose Elementary","location_id":"5024","lat":"32.1731","long":"-110.9797","pm25":""},{"location_name":"Rose Park","location_id":"5025","lat":"40.7955","long":"-111.9309","pm25":""},{"location_name":"Roseburg - Garden Va","location_id":"5026","lat":"43.2266","long":"-123.36479","pm25":""},{"location_name":"Rosenstiel","location_id":"5027","lat":"25.7325","long":"-80.1622","pm25":""},{"location_name":"Roseville - N.Sunris","location_id":"5028","lat":"38.74643","long":"-121.26498","pm25":""},{"location_name":"Rossiter Pump House","location_id":"5030","lat":"46.6588","long":"-112.0131","pm25":""},{"location_name":"Rossville","location_id":"5031","lat":"34.9789","long":"-85.3009","pm25":""},{"location_name":"Rotterdam Noord -Statenweg","location_id":"5032","lat":"51.9271","long":"4.46134","pm25":""},{"location_name":"Rotterdam Zuid-Pleinweg","location_id":"5033","lat":"51.8911","long":"4.48069","pm25":""},{"location_name":"Rotterdam Zuid-Zwartewaalstraat","location_id":"5034","lat":"51.8936","long":"4.48753","pm25":""},{"location_name":"Rotterdam-Oost Sidelinge A13","location_id":"5035","lat":"51.9385","long":"4.43069","pm25":""},{"location_name":"Rotterdam-Schiedamsevest","location_id":"5036","lat":"51.9142","long":"4.47992","pm25":""},{"location_name":"Rozelle","location_id":"5040","lat":"-33.865833","long":"151.1625","pm25":""},{"location_name":"Rte 9 Del. City","location_id":"5041","lat":"39.595","long":"-75.611","pm25":""},{"location_name":"Rutgers University","location_id":"5043","lat":"40.46218","long":"-74.429436","pm25":""},{"location_name":"Rv 4, Aker sykehus","location_id":"5044","lat":"59.94103","long":"10.79803","pm25":""},{"location_name":"Rybnik, ul. Borki 37 d","location_id":"5045","lat":"50.11118","long":"18.516138","pm25":""},{"location_name":"Ryman\u00f3w-Zdr\u00f3j-Samorz\u0105d","location_id":"5046","lat":"49.54654","long":"21.851006","pm25":""},{"location_name":"Rzesz\u00f3w-Nowe Miasto","location_id":"5047","lat":"50.024242","long":"22.010574","pm25":""},{"location_name":"Rzesz\u00f3w-Pi\u0142sudskiego","location_id":"5048","lat":"50.040676","long":"22.004656","pm25":""},{"location_name":"R\u00e5dal","location_id":"5049","lat":"60.29427","long":"5.324619","pm25":""},{"location_name":"S. LAZZARO","location_id":"5051","lat":"44.689","long":"10.6636","pm25":""},{"location_name":"S. ROCCO","location_id":"5052","lat":"44.8737","long":"10.6648","pm25":""},{"location_name":"S.Agostino","location_id":"5053","lat":"42.159946","long":"11.742631","pm25":""},{"location_name":"S.Gordiano","location_id":"5058","lat":"42.07361","long":"11.815916","pm25":""},{"location_name":"SAB-RAME - Sabaneta - I.E. Rafael J. Mej\u00eda","location_id":"5061","lat":"6.1433334","long":"-75.62028","pm25":""},{"location_name":"SAINT JOHN WEST","location_id":"5063","lat":"45.2536","long":"-66.0803","pm25":""},{"location_name":"SAN CLEMENTE","location_id":"5066","lat":"43.9318","long":"12.6273","pm25":""},{"location_name":"SAN FRANCESCO","location_id":"5067","lat":"44.5422","long":"10.8199","pm25":""},{"location_name":"SAN LAZZARO","location_id":"5069","lat":"44.4672","long":"11.4166","pm25":""},{"location_name":"SAN LEO","location_id":"5070","lat":"43.9072","long":"12.4012","pm25":""},{"location_name":"SAN PIETRO CAPOFIUME","location_id":"5072","lat":"44.6542","long":"11.6248","pm25":""},{"location_name":"SAND ISLAND 2 - ANUE","location_id":"5073","lat":"21.3039","long":"-157.8711","pm25":""},{"location_name":"SARAGAT","location_id":"5075","lat":"44.926","long":"10.3719","pm25":""},{"location_name":"SAVIGNANO","location_id":"5078","lat":"44.0969","long":"12.4033","pm25":""},{"location_name":"SAVIGNANO DI RIGO","location_id":"5079","lat":"43.9274","long":"12.2248","pm25":""},{"location_name":"SEAFORD","location_id":"5082","lat":"38.6444","long":"-75.6131","pm25":""},{"location_name":"SENEY","location_id":"5083","lat":"46.2889","long":"-85.9503","pm25":""},{"location_name":"SETRPC 40 Sabine Pas","location_id":"5084","lat":"29.7181","long":"-93.8969","pm25":""},{"location_name":"SETRPC 43 Jefferson","location_id":"5085","lat":"29.9425","long":"-94.0006","pm25":""},{"location_name":"SHELBY FARMS","location_id":"5089","lat":"35.15159","long":"-89.85022","pm25":""},{"location_name":"SHELDAHL","location_id":"5090","lat":"41.849434","long":"-93.69762","pm25":""},{"location_name":"SHIRLEY PLANTATION","location_id":"5092","lat":"37.3419","long":"-77.2608","pm25":""},{"location_name":"SIMMONS PARK","location_id":"5094","lat":"27.7403","long":"-82.4656","pm25":""},{"location_name":"SK0001A","location_id":"5096","lat":"48.12502","long":"17.12561","pm25":""},{"location_name":"SK0002A","location_id":"5097","lat":"48.15843","long":"17.128677","pm25":""},{"location_name":"SK0002R","location_id":"5098","lat":"48.942223","long":"19.592232","pm25":""},{"location_name":"SK0004A","location_id":"5099","lat":"48.144733","long":"17.113619","pm25":""},{"location_name":"SK0004R","location_id":"5100","lat":"49.15278","long":"20.291117","pm25":""},{"location_name":"SK0006R","location_id":"5101","lat":"49.04222","long":"22.259731","pm25":""},{"location_name":"SK0007R","location_id":"5102","lat":"47.96","long":"17.860563","pm25":""},{"location_name":"SK0008A","location_id":"5103","lat":"49.079166","long":"19.302525","pm25":""},{"location_name":"SK0013A","location_id":"5104","lat":"48.666946","long":"18.530848","pm25":""},{"location_name":"SK0016A","location_id":"5105","lat":"48.755","long":"21.246122","pm25":""},{"location_name":"SK0018A","location_id":"5106","lat":"48.59222","long":"21.175285","pm25":""},{"location_name":"SK0020A","location_id":"5107","lat":"49.211945","long":"18.771114","pm25":""},{"location_name":"SK0021A","location_id":"5108","lat":"48.680557","long":"17.363344","pm25":""},{"location_name":"SK0022A","location_id":"5109","lat":"48.58361","long":"19.951685","pm25":""},{"location_name":"SK0025A","location_id":"5110","lat":"48.63111","long":"20.240284","pm25":""},{"location_name":"SK0027A","location_id":"5111","lat":"48.733055","long":"18.756395","pm25":""},{"location_name":"SK0030A","location_id":"5112","lat":"48.874165","long":"21.837503","pm25":""},{"location_name":"SK0031A","location_id":"5113","lat":"48.88639","long":"21.687502","pm25":""},{"location_name":"SK0037A","location_id":"5114","lat":"48.930836","long":"21.913622","pm25":""},{"location_name":"SK0039A","location_id":"5115","lat":"49.066944","long":"18.921947","pm25":""},{"location_name":"SK0041A","location_id":"5116","lat":"49.066666","long":"20.25","pm25":""},{"location_name":"SK0042A","location_id":"5117","lat":"48.783333","long":"20.992231","pm25":""},{"location_name":"SK0045A","location_id":"5118","lat":"48.37111","long":"17.585018","pm25":""},{"location_name":"SK0047A","location_id":"5119","lat":"48.89639","long":"18.041393","pm25":""},{"location_name":"SK0048A","location_id":"5120","lat":"48.166668","long":"17.116667","pm25":""},{"location_name":"SK0050A","location_id":"5121","lat":"48.782654","long":"18.62808","pm25":""},{"location_name":"SK0134A","location_id":"5122","lat":"48.28305","long":"18.14112","pm25":""},{"location_name":"SK0214A","location_id":"5123","lat":"48.735","long":"19.154999","pm25":""},{"location_name":"SK0262A","location_id":"5124","lat":"48.558056","long":"19.156668","pm25":""},{"location_name":"SK0263A","location_id":"5125","lat":"48.733334","long":"19.115278","pm25":""},{"location_name":"SK0264A","location_id":"5126","lat":"48.691113","long":"21.286388","pm25":""},{"location_name":"SK0265A","location_id":"5127","lat":"48.915558","long":"20.42389","pm25":""},{"location_name":"SK0266A","location_id":"5128","lat":"48.993332","long":"21.2675","pm25":""},{"location_name":"SK0267A","location_id":"5129","lat":"48.72627","long":"21.258837","pm25":""},{"location_name":"SK0268A","location_id":"5130","lat":"48.59956","long":"18.84246","pm25":""},{"location_name":"SK0269A","location_id":"5131","lat":"48.309456","long":"18.076832","pm25":""},{"location_name":"SK0406A","location_id":"5132","lat":"48.935","long":"22.27361","pm25":""},{"location_name":"SK0407A","location_id":"5133","lat":"48.43667","long":"17.019722","pm25":""},{"location_name":"SM2","location_id":"5137","lat":"-28.461866","long":"-71.18139","pm25":""},{"location_name":"SM3 ","location_id":"5138","lat":"-28.471973","long":"-71.17831","pm25":""},{"location_name":"SM4 ","location_id":"5139","lat":"-28.4813","long":"-71.1672","pm25":""},{"location_name":"SM5 ","location_id":"5140","lat":"-28.484486","long":"-71.14612","pm25":""},{"location_name":"SM6 ","location_id":"5141","lat":"-28.50365","long":"-71.12653","pm25":""},{"location_name":"SM7 ","location_id":"5142","lat":"-28.497965","long":"-71.096085","pm25":""},{"location_name":"SMITHLD","location_id":"5143","lat":"37.1556","long":"-88.3931","pm25":""},{"location_name":"South Fayette","location_id":"5146","lat":"40.3819","long":"-80.1856","pm25":""},{"location_name":"SOUTHAMPTON","location_id":"5147","lat":"46.3864","long":"-62.5828","pm25":""},{"location_name":"SPABC14 COBACH","location_id":"5148","lat":"32.6336","long":"-115.5042","pm25":""},{"location_name":"SPEEDY CREEK","location_id":"5161","lat":"50.28583","long":"-107.81689","pm25":""},{"location_name":"SPRINGFIELDSP","location_id":"5164","lat":"42.120247","long":"-72.58499","pm25":""},{"location_name":"SPRNGDLE","location_id":"5166","lat":"36.1797","long":"-94.1167","pm25":""},{"location_name":"SQUAMISH ELEMENTARY","location_id":"5167","lat":"49.70516","long":"-123.15133","pm25":""},{"location_name":"ST ANDREWS","location_id":"5168","lat":"45.0892","long":"-67.0786","pm25":""},{"location_name":"STILWELL CASTNET & N","location_id":"5172","lat":"35.7506","long":"-94.6697","pm25":""},{"location_name":"SUR-TRAF - Estaci\u00f3n Tr\u00e1fico Sur","location_id":"5175","lat":"6.1523128","long":"-75.62749","pm25":""},{"location_name":"SYDNEY","location_id":"5176","lat":"27.9659","long":"-82.23061","pm25":""},{"location_name":"Sacaton","location_id":"5177","lat":"33.08","long":"-111.739296","pm25":""},{"location_name":"Saguaro Monument","location_id":"5179","lat":"32.1764","long":"-110.7378","pm25":""},{"location_name":"Saint-Faustin","location_id":"5181","lat":"46.035","long":"-74.4819","pm25":""},{"location_name":"Saint-Jean-Baptiste","location_id":"5182","lat":"45.641026","long":"-73.49968","pm25":""},{"location_name":"Sainte-Anne-de-Belle","location_id":"5183","lat":"45.42651","long":"-73.92895","pm25":""},{"location_name":"Salamonie Reservoir","location_id":"5184","lat":"40.816","long":"-85.6611","pm25":""},{"location_name":"Salem - State Hospit","location_id":"5185","lat":"44.943115","long":"-123.005936","pm25":""},{"location_name":"Salford Eccles","location_id":"5186","lat":"53.48481","long":"-2.334139","pm25":""},{"location_name":"Salladasburg","location_id":"5188","lat":"41.266193","long":"-77.230934","pm25":""},{"location_name":"Salmon PM2.5","location_id":"5189","lat":"45.1787","long":"-113.893","pm25":""},{"location_name":"Saltash Callington Road","location_id":"5190","lat":"50.411465","long":"-4.227678","pm25":""},{"location_name":"Samae Dam, Bang Khun Thian","location_id":"5195","lat":"13.668461","long":"100.50581","pm25":""},{"location_name":"San Andreas","location_id":"5197","lat":"38.20185","long":"-120.680275","pm25":""},{"location_name":"San Antonio","location_id":"5198","lat":"28.3322","long":"-82.3056","pm25":""},{"location_name":"San Antonio Northwes","location_id":"5199","lat":"29.515","long":"-98.62","pm25":""},{"location_name":"San Antonio Old Hwy9","location_id":"5200","lat":"29.423933","long":"-98.580505","pm25":""},{"location_name":"San Antonio Palo Alt","location_id":"5201","lat":"29.332804","long":"-98.5514","pm25":""},{"location_name":"San Bernadino - 4th","location_id":"5203","lat":"34.106678","long":"-117.27406","pm25":""},{"location_name":"San Diego - Kearny V","location_id":"5205","lat":"32.845467","long":"-117.12389","pm25":""},{"location_name":"San Diego - Sherman","location_id":"5206","lat":"32.71018","long":"-117.14266","pm25":""},{"location_name":"San Fernando","location_id":"5207","lat":"-34.57976","long":"-70.989685","pm25":""},{"location_name":"San Francisco","location_id":"5208","lat":"37.7658","long":"-122.3978","pm25":""},{"location_name":"San Jose","location_id":"5210","lat":"9.949488","long":"-84.142876","pm25":""},{"location_name":"San Jose - Jackson S","location_id":"5211","lat":"37.3483","long":"-121.8947","pm25":""},{"location_name":"San Jose - Knox Ave","location_id":"5212","lat":"37.338203","long":"-121.84989","pm25":""},{"location_name":"San Luis Obispo - Hi","location_id":"5213","lat":"35.25651","long":"-120.6693","pm25":""},{"location_name":"San Luis Rio Colorad","location_id":"5214","lat":"32.4667","long":"-114.76876","pm25":""},{"location_name":"San Martin","location_id":"5215","lat":"37.0792","long":"-121.5994","pm25":""},{"location_name":"San Pablo - Rumrill","location_id":"5218","lat":"37.9604","long":"-122.3571","pm25":""},{"location_name":"San Rafael","location_id":"5219","lat":"37.9722","long":"-122.5189","pm25":""},{"location_name":"San Ramon","location_id":"5220","lat":"37.74365","long":"-121.93419","pm25":""},{"location_name":"Sanchong","location_id":"5223","lat":"25.07261","long":"121.493805","pm25":""},{"location_name":"Sandcut","location_id":"5224","lat":"39.5642","long":"-87.3253","pm25":""},{"location_name":"Sandhill","location_id":"5225","lat":"34.1311","long":"-80.8683","pm25":""},{"location_name":"Sandpoint U of I","location_id":"5226","lat":"48.29182","long":"-116.55656","pm25":""},{"location_name":"Sandve","location_id":"5227","lat":"59.19722","long":"5.20148","pm25":""},{"location_name":"Sandy Roadside","location_id":"5228","lat":"52.132416","long":"-0.300306","pm25":""},{"location_name":"Santa Barbara","location_id":"5232","lat":"34.4278","long":"-119.6903","pm25":""},{"location_name":"Santa Clarita","location_id":"5235","lat":"34.3833","long":"-118.5283","pm25":""},{"location_name":"Santa Fe Airport","location_id":"5238","lat":"35.6198","long":"-106.0797","pm25":""},{"location_name":"Santa Maria - Broadw","location_id":"5240","lat":"34.94287","long":"-120.43561","pm25":""},{"location_name":"Santa Teresa","location_id":"5242","lat":"31.7878","long":"-106.6828","pm25":""},{"location_name":"Santa Ynez","location_id":"5243","lat":"34.60582","long":"-120.07506","pm25":""},{"location_name":"Santee Sioux","location_id":"5245","lat":"42.8292","long":"-97.8541","pm25":""},{"location_name":"Sarajevo","location_id":"5250","lat":"43.856667","long":"18.398205","pm25":""},{"location_name":"Saratoga BAM","location_id":"5251","lat":"41.452133","long":"-106.81393","pm25":""},{"location_name":"Sarnia","location_id":"5252","lat":"42.990265","long":"-82.39534","pm25":""},{"location_name":"Saskatoon","location_id":"5254","lat":"52.1361","long":"-106.6631","pm25":""},{"location_name":"Sateng, Mueang","location_id":"5255","lat":"6.549994","long":"101.28","pm25":""},{"location_name":"Saturna","location_id":"5256","lat":"48.7833","long":"-123.1333","pm25":""},{"location_name":"Saul Martinez","location_id":"5257","lat":"33.572018","long":"-116.06382","pm25":""},{"location_name":"Sault Ste Marie","location_id":"5258","lat":"46.5331","long":"-84.3094","pm25":""},{"location_name":"Savannah East Presid","location_id":"5259","lat":"32.0683","long":"-81.0489","pm25":""},{"location_name":"Savannah L&A","location_id":"5260","lat":"32.0903","long":"-81.1306","pm25":""},{"location_name":"Savannahs","location_id":"5261","lat":"27.38908","long":"-80.311035","pm25":""},{"location_name":"Sawgrass Lake Park","location_id":"5262","lat":"27.83441","long":"-82.66525","pm25":""},{"location_name":"Schancheholen","location_id":"5264","lat":"58.951878","long":"5.721875","pm25":""},{"location_name":"Schiedam-Alphons Arienstraat","location_id":"5265","lat":"51.9214","long":"4.40139","pm25":""},{"location_name":"Scranton","location_id":"5271","lat":"41.4428","long":"-75.6231","pm25":""},{"location_name":"Scunthorpe Town","location_id":"5272","lat":"53.58634","long":"-0.636811","pm25":""},{"location_name":"Seabrook Friendship","location_id":"5273","lat":"29.5831","long":"-95.0156","pm25":""},{"location_name":"Seattle-10th & Welle","location_id":"5275","lat":"47.59722","long":"-122.319725","pm25":""},{"location_name":"Seattle-Beacon Hill","location_id":"5276","lat":"47.568237","long":"-122.308624","pm25":""},{"location_name":"Seattle-Duwamish","location_id":"5277","lat":"47.562","long":"-122.3405","pm25":""},{"location_name":"Seattle-South Park","location_id":"5278","lat":"47.5309","long":"-122.3208","pm25":""},{"location_name":"Sebastopol","location_id":"5279","lat":"38.403767","long":"-122.81829","pm25":""},{"location_name":"Sedgwick","location_id":"5292","lat":"37.8975","long":"-97.49207","pm25":""},{"location_name":"Seeley Elementary Sc","location_id":"5293","lat":"47.17563","long":"-113.47618","pm25":""},{"location_name":"Seiling","location_id":"5294","lat":"36.1589","long":"-98.9353","pm25":""},{"location_name":"Seljestad Rv83","location_id":"5296","lat":"68.79223","long":"16.537424","pm25":""},{"location_name":"Seminole Community C","location_id":"5300","lat":"28.7456","long":"-81.31","pm25":""},{"location_name":"Semora DRR","location_id":"5301","lat":"36.489944","long":"-79.058525","pm25":""},{"location_name":"Senior Center","location_id":"5302","lat":"33.4883","long":"-111.855","pm25":""},{"location_name":"Sentrum","location_id":"5303","lat":"68.435394","long":"17.42489","pm25":""},{"location_name":"Sequoia and Kings Ca","location_id":"5304","lat":"36.4894","long":"-118.8269","pm25":""},{"location_name":"Sha Tin","location_id":"5305","lat":"22.376389","long":"114.18445","pm25":""},{"location_name":"Shady Cove - Shady C","location_id":"5307","lat":"42.623226","long":"-122.81016","pm25":""},{"location_name":"Shadyside PSD","location_id":"5308","lat":"39.9679","long":"-80.7464","pm25":""},{"location_name":"Shafter - Walker Str","location_id":"5309","lat":"35.50349","long":"-119.27264","pm25":""},{"location_name":"Shakopee","location_id":"5310","lat":"44.7894","long":"-93.5125","pm25":""},{"location_name":"Sham Shui Po","location_id":"5311","lat":"22.330278","long":"114.159164","pm25":""},{"location_name":"Shanghai","location_id":"5312","lat":"31.21","long":"121.44","pm25":""},{"location_name":"Shasta Lake City","location_id":"5314","lat":"40.6894","long":"-122.4024","pm25":""},{"location_name":"Shaw Crompton Way","location_id":"5317","lat":"53.579285","long":"-2.093786","pm25":""},{"location_name":"Sheffield Barnsley Road","location_id":"5320","lat":"53.40495","long":"-1.455815","pm25":""},{"location_name":"Sheffield Devonshire Green","location_id":"5321","lat":"53.37862","long":"-1.478096","pm25":""},{"location_name":"Sheffield Elementary","location_id":"5322","lat":"30.4758","long":"-81.5869","pm25":""},{"location_name":"Sheffield Tinsley","location_id":"5323","lat":"53.41058","long":"-1.396139","pm25":""},{"location_name":"Sheldon Station","location_id":"5325","lat":"40.55476","long":"-96.78035","pm25":""},{"location_name":"Shell Cut","location_id":"5326","lat":"36.3663","long":"-117.8976","pm25":""},{"location_name":"Shelton-W Franklin","location_id":"5327","lat":"47.21355","long":"-123.10081","pm25":""},{"location_name":"Shenandoah NP","location_id":"5328","lat":"38.5231","long":"-78.4347","pm25":""},{"location_name":"Shenyang","location_id":"5329","lat":"41.78","long":"123.42","pm25":""},{"location_name":"Sheridan","location_id":"5330","lat":"44.934","long":"-106.8472","pm25":""},{"location_name":"Sheridan PD","location_id":"5332","lat":"44.815144","long":"-106.95593","pm25":""},{"location_name":"Shilin","location_id":"5334","lat":"25.105917","long":"121.5145","pm25":""},{"location_name":"Shoshone Bannock Tri","location_id":"5335","lat":"42.589832","long":"-112.458885","pm25":""},{"location_name":"Shreveport Airport","location_id":"5336","lat":"32.5364","long":"-93.7492","pm25":""},{"location_name":"Shuttlesworth","location_id":"5337","lat":"33.565277","long":"-86.79639","pm25":""},{"location_name":"Si Phum, Mueang","location_id":"5339","lat":"18.791092","long":"98.98866","pm25":""},{"location_name":"Si Racha, Si Racha","location_id":"5340","lat":"13.173601","long":"100.9277","pm25":""},{"location_name":"Sibton","location_id":"5341","lat":"52.2944","long":"1.463497","pm25":""},{"location_name":"Sidney 201","location_id":"5343","lat":"47.8679","long":"-104.676865","pm25":""},{"location_name":"Siedlce-Konarskiego","location_id":"5345","lat":"52.172146","long":"22.282001","pm25":""},{"location_name":"Sikes Elementary Sch","location_id":"5347","lat":"27.94","long":"-82.0003","pm25":""},{"location_name":"Simi Valley - Cochra","location_id":"5350","lat":"34.2775","long":"-118.6847","pm25":""},{"location_name":"Sinclair In-Town","location_id":"5352","lat":"41.78237","long":"-107.12083","pm25":""},{"location_name":"Singleton","location_id":"5353","lat":"-32.52972","long":"151.14972","pm25":""},{"location_name":"Sioux Falls","location_id":"5356","lat":"43.54792","long":"-96.70077","pm25":""},{"location_name":"Sipayik-ME","location_id":"5357","lat":"44.9636","long":"-67.0608","pm25":""},{"location_name":"Sisters Forest Servi","location_id":"5359","lat":"44.2921","long":"-121.5555","pm25":""},{"location_name":"Skar\u017cysko-Kamienna, MOBILNA","location_id":"5361","lat":"51.1211","long":"20.88063","pm25":""},{"location_name":"Skawina, os. Ogrody","location_id":"5362","lat":"49.971046","long":"19.830421","pm25":""},{"location_name":"Skiatook","location_id":"5363","lat":"36.35586","long":"-96.01243","pm25":""},{"location_name":"Skver","location_id":"5364","lat":"44.540833","long":"18.673334","pm25":""},{"location_name":"Skyland DRR","location_id":"5365","lat":"35.48186","long":"-82.509865","pm25":""},{"location_name":"Skyland Drive","location_id":"5366","lat":"36.52102","long":"-82.516304","pm25":""},{"location_name":"Skyline Park C72","location_id":"5367","lat":"31.893888","long":"-106.42555","pm25":""},{"location_name":"Sk\u00f8yen","location_id":"5368","lat":"59.91975","long":"10.68973","pm25":""},{"location_name":"Sloughhouse","location_id":"5369","lat":"38.494476","long":"-121.21113","pm25":""},{"location_name":"Smestad","location_id":"5370","lat":"59.93255","long":"10.66984","pm25":""},{"location_name":"Smithers St Josephs","location_id":"5371","lat":"54.7831","long":"-127.1775","pm25":""},{"location_name":"Smithfield","location_id":"5372","lat":"41.842777","long":"-111.85194","pm25":""},{"location_name":"Smolary Bytnickie","location_id":"5374","lat":"52.172222","long":"15.206667","pm25":""},{"location_name":"Snare Rapids","location_id":"5375","lat":"63.5086","long":"-116.0078","pm25":""},{"location_name":"Socorro Hueco C49","location_id":"5376","lat":"31.66752","long":"-106.28774","pm25":""},{"location_name":"Soda Springs Monsant","location_id":"5377","lat":"42.6953","long":"-111.5939","pm25":""},{"location_name":"Soda Springs PM25","location_id":"5378","lat":"42.65167","long":"-111.61472","pm25":""},{"location_name":"Sofienbergparken","location_id":"5380","lat":"59.92295","long":"10.76573","pm25":""},{"location_name":"Solano Drive","location_id":"5381","lat":"32.3169","long":"-106.7669","pm25":""},{"location_name":"Solheim","location_id":"5384","lat":"59.92861","long":"10.953203","pm25":""},{"location_name":"Song Khanong, Phra Pradaeng","location_id":"5386","lat":"13.664026","long":"100.5434","pm25":""},{"location_name":"Sonora - Barretta St","location_id":"5390","lat":"37.98178","long":"-120.37855","pm25":""},{"location_name":"Sop Pat, Mae Mo","location_id":"5391","lat":"18.247768","long":"99.76689","pm25":""},{"location_name":"Sosnowiec, ul. Lubelska 51","location_id":"5394","lat":"50.285957","long":"19.184399","pm25":""},{"location_name":"South Bend-Shields D","location_id":"5396","lat":"41.6967","long":"-86.2147","pm25":""},{"location_name":"South Brisbane","location_id":"5397","lat":"-27.4848","long":"153.032","pm25":""},{"location_name":"South DeKalb","location_id":"5399","lat":"33.6906","long":"-84.2731","pm25":""},{"location_name":"South Gladstone","location_id":"5400","lat":"-23.8626","long":"151.27","pm25":""},{"location_name":"South Lake Tahoe - S","location_id":"5401","lat":"38.94498","long":"-119.97061","pm25":""},{"location_name":"South Long Beach","location_id":"5403","lat":"33.79222","long":"-118.17528","pm25":""},{"location_name":"South Pass","location_id":"5404","lat":"42.5275","long":"-108.7203","pm25":""},{"location_name":"South Phoenix","location_id":"5405","lat":"33.4033","long":"-112.0731","pm25":""},{"location_name":"South Reno","location_id":"5406","lat":"39.469227","long":"-119.77539","pm25":""},{"location_name":"South Scottsdale","location_id":"5407","lat":"33.4797","long":"-111.9172","pm25":""},{"location_name":"South Tucson","location_id":"5408","lat":"32.20215","long":"-110.96792","pm25":""},{"location_name":"South Valley","location_id":"5409","lat":"35.0186","long":"-106.6519","pm25":""},{"location_name":"Southampton A33","location_id":"5410","lat":"50.920265","long":"-1.463484","pm25":""},{"location_name":"Southampton Centre","location_id":"5411","lat":"50.90814","long":"-1.395778","pm25":""},{"location_name":"Southend-on-Sea","location_id":"5412","lat":"51.544205","long":"0.678408","pm25":""},{"location_name":"Southport","location_id":"5414","lat":"-27.9612","long":"153.402","pm25":""},{"location_name":"Southport DRR","location_id":"5415","lat":"33.942223","long":"-78.019165","pm25":""},{"location_name":"Southwark A2 Old Kent Road","location_id":"5417","lat":"51.4805","long":"-0.05955","pm25":""},{"location_name":"Spanish Fork","location_id":"5419","lat":"40.1364","long":"-111.6602","pm25":""},{"location_name":"Spanish Springs","location_id":"5420","lat":"39.621464","long":"-119.718735","pm25":""},{"location_name":"Sparks","location_id":"5421","lat":"39.54092","long":"-119.746765","pm25":""},{"location_name":"Speedwell","location_id":"5422","lat":"36.47","long":"-83.83","pm25":""},{"location_name":"Spokane-Augusta Ave","location_id":"5426","lat":"47.6725","long":"-117.3649","pm25":""},{"location_name":"Spokane-E Broadway A","location_id":"5427","lat":"47.663963","long":"-117.25765","pm25":""},{"location_name":"Spokane-Monroe St.","location_id":"5429","lat":"47.6997","long":"-117.4263","pm25":""},{"location_name":"Springfield Ag","location_id":"5431","lat":"39.83192","long":"-89.644165","pm25":""},{"location_name":"Springfield City Hal","location_id":"5432","lat":"44.046684","long":"-123.01774","pm25":""},{"location_name":"Springfield PM","location_id":"5433","lat":"39.92882","long":"-83.80949","pm25":""},{"location_name":"Springville","location_id":"5434","lat":"36.1358","long":"-118.8108","pm25":""},{"location_name":"Springwood","location_id":"5435","lat":"-27.6125","long":"153.136","pm25":""},{"location_name":"Spruce Pine","location_id":"5436","lat":"35.912487","long":"-82.06208","pm25":""},{"location_name":"St Helens Linkway","location_id":"5440","lat":"53.451824","long":"-2.742134","pm25":""},{"location_name":"St Marys","location_id":"5442","lat":"-33.797222","long":"150.76584","pm25":""},{"location_name":"St Osyth","location_id":"5443","lat":"51.77798","long":"1.049031","pm25":""},{"location_name":"St Regis Mohawk-NY","location_id":"5445","lat":"44.9806","long":"-74.6953","pm25":""},{"location_name":"St Theodosius","location_id":"5446","lat":"41.477013","long":"-81.68238","pm25":""},{"location_name":"St-Dominique","location_id":"5447","lat":"45.512188","long":"-73.56687","pm25":""},{"location_name":"St. Andrews Park","location_id":"5448","lat":"30.1289","long":"-85.7381","pm25":""},{"location_name":"St. Catharines","location_id":"5452","lat":"43.1583","long":"-79.235","pm25":""},{"location_name":"St. Cloud","location_id":"5453","lat":"45.55","long":"-94.1333","pm25":""},{"location_name":"St. John's","location_id":"5457","lat":"47.6528","long":"-52.8167","pm25":""},{"location_name":"St. Joseph","location_id":"5458","lat":"39.74167","long":"-94.85833","pm25":""},{"location_name":"St. Lukes Meridian","location_id":"5461","lat":"43.6007","long":"-116.347855","pm25":""},{"location_name":"St. Maries","location_id":"5462","lat":"47.3167","long":"-116.5703","pm25":""},{"location_name":"St. Marks Wildlife R","location_id":"5463","lat":"30.0842","long":"-84.1617","pm25":""},{"location_name":"St. Martinville","location_id":"5464","lat":"30.008886","long":"-91.8696","pm25":""},{"location_name":"St. Michael","location_id":"5465","lat":"45.2108","long":"-93.6686","pm25":""},{"location_name":"St. Paul - Downtown","location_id":"5466","lat":"44.9507","long":"-93.0985","pm25":""},{"location_name":"St. Paul-Harding H.S","location_id":"5467","lat":"44.9594","long":"-93.0356","pm25":""},{"location_name":"St. Petersburg Colle","location_id":"5469","lat":"27.9711","long":"-82.7361","pm25":""},{"location_name":"St. Philips","location_id":"5470","lat":"38.0053","long":"-87.7183","pm25":""},{"location_name":"St.Croix","location_id":"5479","lat":"59.2103","long":"10.9454","pm25":""},{"location_name":"StJohns","location_id":"5480","lat":"33.29015","long":"-112.159874","pm25":""},{"location_name":"Stanfield","location_id":"5484","lat":"32.881195","long":"-111.962","pm25":""},{"location_name":"Stanford-le-Hope Roadside","location_id":"5485","lat":"51.518166","long":"0.439548","pm25":""},{"location_name":"Starachowice, ul. Z\u0142ota","location_id":"5487","lat":"51.05061","long":"21.084175","pm25":""},{"location_name":"State College","location_id":"5488","lat":"40.8114","long":"-77.8769","pm25":""},{"location_name":"Steeper","location_id":"5492","lat":"53.1325","long":"-117.09111","pm25":""},{"location_name":"Stener Heyerdahl","location_id":"5493","lat":"58.14888","long":"7.99183","pm25":""},{"location_name":"Steubenville","location_id":"5495","lat":"40.36645","long":"-80.61569","pm25":""},{"location_name":"Stillwater","location_id":"5500","lat":"43.0122","long":"-73.6492","pm25":""},{"location_name":"Stockton","location_id":"5504","lat":"42.2869","long":"-89.9997","pm25":""},{"location_name":"Stockton - Hazelton","location_id":"5505","lat":"37.95075","long":"-121.26897","pm25":""},{"location_name":"Stockton-on-Tees A1305 Roadside","location_id":"5506","lat":"54.56582","long":"-1.3159","pm25":""},{"location_name":"Stockton-on-Tees Eaglescliffe","location_id":"5507","lat":"54.516666","long":"-1.358547","pm25":""},{"location_name":"Stoke-on-Trent A50 Roadside","location_id":"5508","lat":"52.980434","long":"-2.111898","pm25":""},{"location_name":"Stoke-on-Trent Centre","location_id":"5509","lat":"53.02821","long":"-2.175133","pm25":""},{"location_name":"Storrington Roadside","location_id":"5510","lat":"50.91693","long":"-0.449548","pm25":""},{"location_name":"Strathvaich","location_id":"5512","lat":"57.734455","long":"-4.776583","pm25":""},{"location_name":"Strongstown","location_id":"5516","lat":"40.5633","long":"-78.92","pm25":""},{"location_name":"Stuart","location_id":"5517","lat":"-19.3463","long":"146.834","pm25":""},{"location_name":"Substation","location_id":"5519","lat":"36.7969","long":"-108.4725","pm25":""},{"location_name":"Sucha Beskidzka, ul. Nieszczy\u0144skiej","location_id":"5520","lat":"49.74313","long":"19.60034","pm25":""},{"location_name":"Sudbury","location_id":"5521","lat":"46.49194","long":"-81.003105","pm25":""},{"location_name":"Sul\u0119cin ul. Dudka","location_id":"5528","lat":"52.43772","long":"15.122444","pm25":""},{"location_name":"Sumatra","location_id":"5529","lat":"30.1103","long":"-84.9903","pm25":""},{"location_name":"Sunderland Silksworth","location_id":"5531","lat":"54.88361","long":"-1.406878","pm25":""},{"location_name":"Sunderland Wessington Way","location_id":"5532","lat":"54.91839","long":"-1.408391","pm25":""},{"location_name":"Sunnyside-S 16th","location_id":"5533","lat":"46.32033","long":"-119.9981","pm25":""},{"location_name":"Sunrise Acres","location_id":"5534","lat":"36.163963","long":"-115.11393","pm25":""},{"location_name":"Surrey East","location_id":"5535","lat":"49.13278","long":"-122.69417","pm25":""},{"location_name":"Suwa\u0142ki, ul. Pu\u0142askiego 26","location_id":"5538","lat":"54.116055","long":"22.93875","pm25":""},{"location_name":"Svanvik","location_id":"5539","lat":"69.45505","long":"30.04075","pm25":""},{"location_name":"Swansea Roadside","location_id":"5542","lat":"51.632694","long":"-3.947374","pm25":""},{"location_name":"Sweet Home - Fire De","location_id":"5543","lat":"44.3958","long":"-122.7305","pm25":""},{"location_name":"Swiftwater","location_id":"5544","lat":"41.0831","long":"-75.3283","pm25":""},{"location_name":"Sycamore","location_id":"5545","lat":"39.2787","long":"-84.36612","pm25":""},{"location_name":"Szar\u00f3w, ul. Spokojna","location_id":"5548","lat":"50.0075","long":"20.259167","pm25":""},{"location_name":"Szczecin_Andrzejewskiego","location_id":"5549","lat":"53.380974","long":"14.663347","pm25":""},{"location_name":"Szczecin_Budzysza Wosia","location_id":"5550","lat":"53.447","long":"14.508","pm25":""},{"location_name":"Szczecin_Pi\u0142sudskiego","location_id":"5551","lat":"53.43217","long":"14.5539","pm25":""},{"location_name":"Szczecinek_Przemys\u0142owa","location_id":"5553","lat":"53.6989","long":"16.704573","pm25":""},{"location_name":"Szymbark","location_id":"5554","lat":"49.633713","long":"21.116833","pm25":""},{"location_name":"TAIT CUMMINS","location_id":"5561","lat":"41.94867","long":"-91.63954","pm25":""},{"location_name":"TECUMSEH","location_id":"5563","lat":"41.9956","long":"-83.9467","pm25":""},{"location_name":"TERRACE SKEENA MIDDL","location_id":"5564","lat":"54.5217","long":"-128.6075","pm25":""},{"location_name":"TIMAVO","location_id":"5567","lat":"44.6996","long":"10.6228","pm25":""},{"location_name":"TK Gregg","location_id":"5568","lat":"34.9556","long":"-81.9248","pm25":""},{"location_name":"TOR","location_id":"5569","lat":"40.054173","long":"-74.98517","pm25":""},{"location_name":"TRINITY ST MARKS","location_id":"5571","lat":"42.295822","long":"-83.12943","pm25":""},{"location_name":"TROUT LAKE","location_id":"5572","lat":"46.0481","long":"-89.6536","pm25":""},{"location_name":"TRURO","location_id":"5573","lat":"41.9756","long":"-70.0239","pm25":""},{"location_name":"Tacoma-Alexander Ave","location_id":"5578","lat":"47.2656","long":"-122.3858","pm25":""},{"location_name":"Tacoma-L St","location_id":"5579","lat":"47.1864","long":"-122.4517","pm25":""},{"location_name":"Tacoma-S 36th St","location_id":"5580","lat":"47.22634","long":"-122.46256","pm25":""},{"location_name":"Taft","location_id":"5581","lat":"39.12886","long":"-84.50404","pm25":""},{"location_name":"Tahoe City","location_id":"5582","lat":"39.166","long":"-120.1488","pm25":""},{"location_name":"Taholah-Quinault Tri","location_id":"5583","lat":"47.3398","long":"-124.2918","pm25":""},{"location_name":"Tai Po","location_id":"5584","lat":"22.450834","long":"114.164444","pm25":""},{"location_name":"Tainan","location_id":"5585","lat":"22.984581","long":"120.202614","pm25":""},{"location_name":"TakomaRec","location_id":"5586","lat":"38.9701","long":"-77.016716","pm25":""},{"location_name":"Talagante","location_id":"5587","lat":"-33.67375","long":"-70.953064","pm25":""},{"location_name":"Talat Yai, Mueang","location_id":"5588","lat":"7.881636","long":"98.39429","pm25":""},{"location_name":"Tallahassee Communit","location_id":"5591","lat":"30.4397","long":"-84.3483","pm25":""},{"location_name":"Tamworth","location_id":"5594","lat":"-31.110556","long":"150.91417","pm25":""},{"location_name":"Tangerine & Camino d","location_id":"5595","lat":"32.4253","long":"-111.0669","pm25":""},{"location_name":"Taos Fire Station","location_id":"5596","lat":"36.3833","long":"-105.5833","pm25":""},{"location_name":"Taoyuan","location_id":"5597","lat":"24.995667","long":"121.30442","pm25":""},{"location_name":"Tap Mun","location_id":"5598","lat":"22.47139","long":"114.36083","pm25":""},{"location_name":"Targinie","location_id":"5600","lat":"-23.7744","long":"151.105","pm25":""},{"location_name":"Tarn\u00f3w, ul. Bitwy pod Studziankami","location_id":"5602","lat":"50.02017","long":"21.004168","pm25":""},{"location_name":"Tarn\u00f3w, ul. Ks. Romana Sitko","location_id":"5603","lat":"50.018253","long":"20.992579","pm25":""},{"location_name":"Taylorsville Liledou","location_id":"5608","lat":"35.9138","long":"-81.191","pm25":""},{"location_name":"Temecula (Lake Skinn","location_id":"5611","lat":"33.5831","long":"-117.0722","pm25":""},{"location_name":"Tempe","location_id":"5612","lat":"33.4124","long":"-111.9347","pm25":""},{"location_name":"Temple Georgia C1045","location_id":"5613","lat":"31.122526","long":"-97.43116","pm25":""},{"location_name":"Terre Haute-Lafayett","location_id":"5614","lat":"39.4861","long":"-87.4014","pm25":""},{"location_name":"Tha Pradu, Mueng","location_id":"5619","lat":"12.680919","long":"101.273575","pm25":""},{"location_name":"The Dalles - Cherry","location_id":"5620","lat":"45.60242","long":"-121.203384","pm25":""},{"location_name":"The Gap","location_id":"5622","lat":"-20.7264","long":"139.498","pm25":""},{"location_name":"Theodore Roosevelt N","location_id":"5623","lat":"46.9497","long":"-103.5144","pm25":""},{"location_name":"Thibodaux","location_id":"5624","lat":"29.7639","long":"-90.7653","pm25":""},{"location_name":"Thirty Third","location_id":"5625","lat":"33.461807","long":"-112.128044","pm25":""},{"location_name":"Thompson Falls HS","location_id":"5627","lat":"47.594395","long":"-115.323746","pm25":""},{"location_name":"Thousand Oaks - Moor","location_id":"5628","lat":"34.21","long":"-118.8694","pm25":""},{"location_name":"Thunder Basin","location_id":"5629","lat":"44.6633","long":"-105.2875","pm25":""},{"location_name":"Thung Sukhla, Si Racha","location_id":"5630","lat":"13.119234","long":"100.9185","pm25":""},{"location_name":"Thurrock","location_id":"5631","lat":"51.47707","long":"0.317969","pm25":""},{"location_name":"Tiburtina","location_id":"5633","lat":"41.910255","long":"12.54887","pm25":""},{"location_name":"Tierra Amarilla","location_id":"5634","lat":"-27.47551","long":"-70.26589","pm25":""},{"location_name":"Timpanogos Cave","location_id":"5635","lat":"40.44194","long":"-111.71341","pm25":""},{"location_name":"Tingwick","location_id":"5636","lat":"45.9075","long":"-71.9492","pm25":""},{"location_name":"Tioga County","location_id":"5637","lat":"41.6447","long":"-76.9392","pm25":""},{"location_name":"Tishomingo","location_id":"5639","lat":"34.198875","long":"-96.67308","pm25":""},{"location_name":"Tiverton","location_id":"5640","lat":"44.2994","long":"-81.5753","pm25":""},{"location_name":"Tolfa","location_id":"5644","lat":"42.152225","long":"11.93583","pm25":""},{"location_name":"Toll","location_id":"5646","lat":"39.399837","long":"-119.73961","pm25":""},{"location_name":"Tomahawk","location_id":"5648","lat":"53.37","long":"-115.1906","pm25":""},{"location_name":"Tonawanda II","location_id":"5649","lat":"42.9981","long":"-78.8993","pm25":""},{"location_name":"Tonto National Monum","location_id":"5650","lat":"33.654724","long":"-111.10741","pm25":""},{"location_name":"Toppenish-Yakama Tri","location_id":"5652","lat":"46.3802","long":"-120.3326","pm25":""},{"location_name":"Toronto Downtown","location_id":"5654","lat":"43.6619","long":"-79.3853","pm25":""},{"location_name":"Toru\u0144 Airpointer","location_id":"5656","lat":"53.01226","long":"18.606203","pm25":""},{"location_name":"Toru\u0144 POLICJA","location_id":"5657","lat":"53.02865","long":"18.666103","pm25":""},{"location_name":"Toru\u0144, KASZOWNIK","location_id":"5658","lat":"53.017628","long":"18.612808","pm25":""},{"location_name":"Torvet","location_id":"5660","lat":"63.43038","long":"10.39355","pm25":""},{"location_name":"Toufen","location_id":"5661","lat":"24.696968","long":"120.898575","pm25":""},{"location_name":"Towanda","location_id":"5662","lat":"41.705227","long":"-76.512726","pm25":""},{"location_name":"Tower Hamlets Roadside","location_id":"5663","lat":"51.52253","long":"-0.042155","pm25":""},{"location_name":"TracyAP","location_id":"5664","lat":"37.6825","long":"-121.4406","pm25":""},{"location_name":"Tramway","location_id":"5668","lat":"35.185","long":"-106.5077","pm25":""},{"location_name":"Tranquillity","location_id":"5669","lat":"36.6324","long":"-120.3822","pm25":""},{"location_name":"Trbovlje","location_id":"5672","lat":"46.138744","long":"15.035197","pm25":""},{"location_name":"Trenton","location_id":"5673","lat":"33.7397","long":"-81.8536","pm25":""},{"location_name":"Triple Oak - Near Ro","location_id":"5676","lat":"35.8652","long":"-78.8197","pm25":""},{"location_name":"Trollhaugen","location_id":"5677","lat":"-72.0117","long":"2.5351","pm25":""},{"location_name":"Trona - Athol and Te","location_id":"5678","lat":"35.774456","long":"-117.37211","pm25":""},{"location_name":"Troost","location_id":"5679","lat":"39.10465","long":"-94.57055","pm25":""},{"location_name":"Truckee BAM","location_id":"5680","lat":"39.3386","long":"-120.1703","pm25":""},{"location_name":"Trzebinia, os. Zwi\u0105zku Walki M\u0142odych","location_id":"5682","lat":"50.159405","long":"19.477465","pm25":""},{"location_name":"Tsawwassen","location_id":"5683","lat":"49.00987","long":"-123.082016","pm25":""},{"location_name":"Tseung Kwan O","location_id":"5684","lat":"22.317778","long":"114.259445","pm25":""},{"location_name":"Tsuen Wan","location_id":"5685","lat":"22.371666","long":"114.11444","pm25":""},{"location_name":"Tuen Mun","location_id":"5686","lat":"22.391111","long":"113.97667","pm25":""},{"location_name":"Tukwila_Allentown","location_id":"5687","lat":"47.498535","long":"-122.27838","pm25":""},{"location_name":"Tulalip-Totem Beach","location_id":"5688","lat":"48.06534","long":"-122.285194","pm25":""},{"location_name":"Tulsa","location_id":"5690","lat":"36.2067","long":"-95.9764","pm25":""},{"location_name":"Tulsa 0175","location_id":"5691","lat":"36.149876","long":"-96.011665","pm25":""},{"location_name":"Tulsa 0179","location_id":"5692","lat":"36.15483","long":"-96.01585","pm25":""},{"location_name":"Tulsa 0235","location_id":"5693","lat":"36.126945","long":"-95.99894","pm25":""},{"location_name":"Tung Chung","location_id":"5695","lat":"22.288889","long":"113.94361","pm25":""},{"location_name":"Turlock - S. Minaret","location_id":"5697","lat":"37.4883","long":"-120.8358","pm25":""},{"location_name":"Tustervatn","location_id":"5700","lat":"65.83089","long":"13.90655","pm25":""},{"location_name":"Twin Falls PM25","location_id":"5702","lat":"42.56509","long":"-114.49472","pm25":""},{"location_name":"Twisp-Glover St","location_id":"5703","lat":"48.3645","long":"-120.1211","pm25":""},{"location_name":"Tychy, ul. To\u0142stoja 1","location_id":"5704","lat":"50.099903","long":"18.990236","pm25":""},{"location_name":"Tyler Airport Reloca","location_id":"5705","lat":"32.34401","long":"-95.41575","pm25":""},{"location_name":"UC1","location_id":"5709","lat":"42.75152","long":"-96.70721","pm25":""},{"location_name":"US Diplomatic Post: Abu Dhabi","location_id":"5715","lat":"24.424398","long":"54.433746","pm25":""},{"location_name":"US Diplomatic Post: Addis Ababa Central","location_id":"5716","lat":"9.058498","long":"38.761642","pm25":""},{"location_name":"US Diplomatic Post: Addis Ababa School","location_id":"5717","lat":"8.996519","long":"38.725433","pm25":""},{"location_name":"US Diplomatic Post: Algiers","location_id":"5718","lat":"36.7558","long":"3.039114","pm25":""},{"location_name":"US Diplomatic Post: Amman","location_id":"5719","lat":"31.945389","long":"35.880554","pm25":""},{"location_name":"US Diplomatic Post: Ashgabat","location_id":"5720","lat":"37.941856","long":"58.387943","pm25":""},{"location_name":"US Diplomatic Post: Baghdad","location_id":"5722","lat":"33.29872","long":"44.395916","pm25":""},{"location_name":"US Diplomatic Post: Bishkek","location_id":"5723","lat":"42.8273","long":"74.5833","pm25":""},{"location_name":"US Diplomatic Post: Bogota","location_id":"5724","lat":"4.637735","long":"-74.09486","pm25":""},{"location_name":"US Diplomatic Post: Chennai","location_id":"5725","lat":"13.08784","long":"80.27847","pm25":""},{"location_name":"US Diplomatic Post: Colombo","location_id":"5726","lat":"6.913253","long":"79.84869","pm25":""},{"location_name":"US Diplomatic Post: Curacao","location_id":"5727","lat":"12.1696","long":"-68.99","pm25":""},{"location_name":"US Diplomatic Post: Dhaka","location_id":"5728","lat":"23.796373","long":"90.424614","pm25":""},{"location_name":"US Diplomatic Post: Dubai","location_id":"5730","lat":"25.25848","long":"55.309166","pm25":""},{"location_name":"US Diplomatic Post: Embassy Kathmandu","location_id":"5732","lat":"27.738703","long":"85.336205","pm25":""},{"location_name":"US Diplomatic Post: Guatemala City","location_id":"5733","lat":"14.607198","long":"-90.51425","pm25":""},{"location_name":"US Diplomatic Post: Hanoi","location_id":"5734","lat":"21.021938","long":"105.81881","pm25":""},{"location_name":"US Diplomatic Post: Ho Chi Minh City","location_id":"5735","lat":"10.782773","long":"106.700035","pm25":""},{"location_name":"US Diplomatic Post: Hyderabad","location_id":"5736","lat":"17.38405","long":"78.45636","pm25":""},{"location_name":"US Diplomatic Post: Jakarta Central","location_id":"5737","lat":"-6.182536","long":"106.834236","pm25":""},{"location_name":"US Diplomatic Post: Jakarta South","location_id":"5738","lat":"-6.236704","long":"106.79324","pm25":""},{"location_name":"US Diplomatic Post: Kabul","location_id":"5739","lat":"34.535812","long":"69.19051","pm25":""},{"location_name":"US Diplomatic Post: Kolkata","location_id":"5740","lat":"22.56263","long":"88.36304","pm25":""},{"location_name":"US Diplomatic Post: Kuwait City","location_id":"5741","lat":"29.292316","long":"48.04768","pm25":""},{"location_name":"US Diplomatic Post: Lima","location_id":"5742","lat":"-12.099398","long":"-76.96888","pm25":""},{"location_name":"US Diplomatic Post: Manama","location_id":"5743","lat":"26.204697","long":"50.57083","pm25":""},{"location_name":"US Diplomatic Post: Mumbai","location_id":"5744","lat":"19.07283","long":"72.88261","pm25":""},{"location_name":"US Diplomatic Post: New Delhi","location_id":"5745","lat":"28.63576","long":"77.22445","pm25":""},{"location_name":"US Diplomatic Post: Phora Durbar Kathmandu","location_id":"5746","lat":"27.712463","long":"85.315704","pm25":""},{"location_name":"US Diplomatic Post: Pristina","location_id":"5747","lat":"42.661995","long":"21.15055","pm25":""},{"location_name":"US Diplomatic Post: Rangoon","location_id":"5748","lat":"16.8256","long":"96.1445","pm25":""},{"location_name":"US Diplomatic Post: Sarajevo","location_id":"5749","lat":"43.856667","long":"18.398205","pm25":""},{"location_name":"US Diplomatic Post: Tashkent","location_id":"5750","lat":"41.3672","long":"69.2725","pm25":""},{"location_name":"US Diplomatic Post: Ulaanbaatar","location_id":"5751","lat":"47.928387","long":"106.92947","pm25":""},{"location_name":"Utica","location_id":"5752","lat":"43.0994","long":"-75.225","pm25":""},{"location_name":"Ukiah District Offic","location_id":"5753","lat":"39.145733","long":"-123.202995","pm25":""},{"location_name":"Ukiah Library","location_id":"5754","lat":"39.15048","long":"-123.20653","pm25":""},{"location_name":"Ulaanbaatar","location_id":"5755","lat":"47.928387","long":"106.92947","pm25":""},{"location_name":"Underhill","location_id":"5758","lat":"44.52839","long":"-72.86897","pm25":""},{"location_name":"Union","location_id":"5759","lat":"36.918243","long":"-95.632126","pm25":""},{"location_name":"Uniontown","location_id":"5760","lat":"39.917664","long":"-79.8055","pm25":""},{"location_name":"Unionville","location_id":"5761","lat":"43.61","long":"-83.36","pm25":""},{"location_name":"Unit0269","location_id":"5763","lat":"38.979294","long":"-105.35305","pm25":""},{"location_name":"United Ave","location_id":"5769","lat":"33.7206","long":"-84.3578","pm25":""},{"location_name":"Upland","location_id":"5772","lat":"34.10366","long":"-117.6291","pm25":""},{"location_name":"Upper Humbug","location_id":"5773","lat":"-27.0908","long":"150.4","pm25":""},{"location_name":"Ustro\u0144, ul. Sanatoryjna 7","location_id":"5778","lat":"49.71973","long":"18.826721","pm25":""},{"location_name":"Ute 1","location_id":"5779","lat":"37.13678","long":"-107.62863","pm25":""},{"location_name":"Ute 3","location_id":"5780","lat":"37.10258","long":"-107.87022","pm25":""},{"location_name":"Utrecht-Erzeijstraat","location_id":"5781","lat":"52.0677","long":"5.12051","pm25":""},{"location_name":"Utrecht-Griftpark","location_id":"5782","lat":"52.1013","long":"5.12818","pm25":""},{"location_name":"Utrecht-de Jongweg","location_id":"5783","lat":"52.105","long":"5.12446","pm25":""},{"location_name":"Uxbridge","location_id":"5784","lat":"42.0997","long":"-71.62","pm25":""},{"location_name":"VERUCCHIO","location_id":"5789","lat":"44.0139","long":"12.421","pm25":""},{"location_name":"VIA CHIARINI","location_id":"5790","lat":"44.5001","long":"11.2861","pm25":""},{"location_name":"VILLA FULVIA","location_id":"5792","lat":"44.8243","long":"11.6496","pm25":""},{"location_name":"V_VIEW","location_id":"5796","lat":"26.0732","long":"-80.3386","pm25":""},{"location_name":"Vacaville","location_id":"5797","lat":"38.3525","long":"-121.9617","pm25":""},{"location_name":"Valdivia","location_id":"5798","lat":"-39.831318","long":"-73.228516","pm25":""},{"location_name":"Valdosta","location_id":"5799","lat":"30.8486","long":"-83.2933","pm25":""},{"location_name":"Vallejo","location_id":"5802","lat":"38.10251","long":"-122.237976","pm25":""},{"location_name":"Valley Central","location_id":"5803","lat":"41.5231","long":"-74.215","pm25":""},{"location_name":"Valparaiso","location_id":"5804","lat":"-33.049744","long":"-71.61417","pm25":""},{"location_name":"Valthermond-Noorderdiep","location_id":"5805","lat":"52.8757","long":"6.93243","pm25":""},{"location_name":"Vancouver Airport","location_id":"5806","lat":"49.18639","long":"-123.15222","pm25":""},{"location_name":"Vancouver-NE 84th Av","location_id":"5808","lat":"45.64336","long":"-122.58737","pm25":""},{"location_name":"Vanderhoof BAM","location_id":"5809","lat":"54.0163","long":"-124.0061","pm25":""},{"location_name":"Vangsveien, Hamar","location_id":"5810","lat":"60.79646","long":"11.09777","pm25":""},{"location_name":"Veldhoven-Europalaan","location_id":"5816","lat":"51.4074","long":"5.39333","pm25":""},{"location_name":"Velsen-Reijndersweg","location_id":"5817","lat":"52.4789","long":"4.57934","pm25":""},{"location_name":"Velsen-Staalstraat","location_id":"5818","lat":"52.4744","long":"4.6288","pm25":""},{"location_name":"Ventanas","location_id":"5819","lat":"-32.741817","long":"-71.48088","pm25":""},{"location_name":"Vernal #4","location_id":"5820","lat":"40.46472","long":"-109.56083","pm25":""},{"location_name":"Vernon Science Centr","location_id":"5821","lat":"50.2333","long":"-119.2833","pm25":""},{"location_name":"Via Tasso","location_id":"5822","lat":"41.464024","long":"12.913039","pm25":""},{"location_name":"Viale De Chirico","location_id":"5823","lat":"41.45113","long":"12.891731","pm25":""},{"location_name":"Vialidad","location_id":"5824","lat":"-45.4068","long":"-72.69626","pm25":""},{"location_name":"Victoria C87","location_id":"5826","lat":"28.8358","long":"-97.0056","pm25":""},{"location_name":"Victoria Topaz","location_id":"5827","lat":"48.4292","long":"-123.3583","pm25":""},{"location_name":"Victorville - Park A","location_id":"5829","lat":"34.51","long":"-117.3306","pm25":""},{"location_name":"Vientiane","location_id":"5831","lat":"17.896122","long":"102.64","pm25":""},{"location_name":"Vigernes","location_id":"5832","lat":"59.95548","long":"11.073983","pm25":""},{"location_name":"Viking Lake State Pa","location_id":"5836","lat":"40.97","long":"-95.045","pm25":""},{"location_name":"Villa Ada","location_id":"5837","lat":"41.932873","long":"12.506971","pm25":""},{"location_name":"Vincennes","location_id":"5843","lat":"38.7408","long":"-87.4853","pm25":""},{"location_name":"Vinton","location_id":"5845","lat":"30.2278","long":"-93.5797","pm25":""},{"location_name":"Violet Grove","location_id":"5846","lat":"53.1422","long":"-115.1381","pm25":""},{"location_name":"Virginia","location_id":"5847","lat":"47.5212","long":"-92.5393","pm25":""},{"location_name":"Visalia - N. Church","location_id":"5848","lat":"36.33252","long":"-119.29095","pm25":""},{"location_name":"Viterbo","location_id":"5849","lat":"42.42206","long":"12.109125","pm25":""},{"location_name":"Vi\u00f1a del Mar","location_id":"5850","lat":"-33.02042","long":"-71.550095","pm25":""},{"location_name":"Vollgata","location_id":"5855","lat":"59.27897","long":"11.12228","pm25":""},{"location_name":"Voyageurs NP","location_id":"5861","lat":"48.4128","long":"-92.8292","pm25":""},{"location_name":"Vredepeel-Vredeweg","location_id":"5862","lat":"51.5405","long":"5.85307","pm25":""},{"location_name":"V\u00e5land","location_id":"5863","lat":"58.96173","long":"5.73147","pm25":""},{"location_name":"W Greenwich","location_id":"5868","lat":"41.615","long":"-71.7197","pm25":""},{"location_name":"W OWEN SCH","location_id":"5869","lat":"35.041416","long":"-78.95311","pm25":""},{"location_name":"WARE","location_id":"5871","lat":"42.2983","long":"-72.3344","pm25":""},{"location_name":"WATSON","location_id":"5874","lat":"38.0608","long":"-85.8961","pm25":""},{"location_name":"WAUKESHA - CLEVELAND","location_id":"5875","lat":"43.0203","long":"-88.215","pm25":""},{"location_name":"WAVELAND","location_id":"5876","lat":"30.3008","long":"-89.3958","pm25":""},{"location_name":"WELLINGTON","location_id":"5878","lat":"46.4783","long":"-63.9869","pm25":""},{"location_name":"WEST OLIVE","location_id":"5880","lat":"42.923603","long":"-86.19652","pm25":""},{"location_name":"WESTSIDE - 9 Mile","location_id":"5881","lat":"35.0641","long":"-106.76129","pm25":""},{"location_name":"WHlthDpt","location_id":"5883","lat":"37.7011","long":"-97.3139","pm25":""},{"location_name":"WIND CAVE","location_id":"5885","lat":"43.557613","long":"-103.48366","pm25":""},{"location_name":"WIO\u015a Elbl\u0105g ul. Ba\u017cy\u0144skiego","location_id":"5886","lat":"54.167847","long":"19.410942","pm25":""},{"location_name":"WIO\u015a E\u0142k","location_id":"5887","lat":"53.828457","long":"22.34845","pm25":""},{"location_name":"WIO\u015a Go\u0142dap ul. Ja\u0107wieska","location_id":"5888","lat":"54.30591","long":"22.30768","pm25":""},{"location_name":"WIO\u015a Go\u0142dap-Uzdrowisko","location_id":"5889","lat":"54.328175","long":"22.332172","pm25":""},{"location_name":"WIO\u015a Olsztyn ul. Puszkina","location_id":"5890","lat":"53.789234","long":"20.486074","pm25":""},{"location_name":"WIO\u015a Ostr\u00f3da Pi\u0142sudskiego","location_id":"5891","lat":"53.69463","long":"19.968891","pm25":""},{"location_name":"Willits Justice Cent","location_id":"5892","lat":"39.411743","long":"-123.35266","pm25":""},{"location_name":"WY\/KC","location_id":"5896","lat":"39.1175","long":"-94.6356","pm25":""},{"location_name":"WYLAM","location_id":"5897","lat":"33.4997","long":"-86.9242","pm25":""},{"location_name":"Waco C1037","location_id":"5898","lat":"31.6531","long":"-97.0706","pm25":""},{"location_name":"Wadsworth-NV","location_id":"5899","lat":"39.6367","long":"-119.2889","pm25":""},{"location_name":"Wagga Wagga Nth","location_id":"5900","lat":"-35.104443","long":"147.36028","pm25":""},{"location_name":"Wagner2","location_id":"5901","lat":"53.49389","long":"-114.44972","pm25":""},{"location_name":"Walla Walla-12th St","location_id":"5904","lat":"46.0588","long":"-118.3514","pm25":""},{"location_name":"Wallsend","location_id":"5906","lat":"-32.89611","long":"151.66917","pm25":""},{"location_name":"Walsall Woodlands","location_id":"5907","lat":"52.60562","long":"-2.030523","pm25":""},{"location_name":"Walter Johnson","location_id":"5908","lat":"36.169758","long":"-115.26304","pm25":""},{"location_name":"Wampanoag Laboratory","location_id":"5910","lat":"41.3306","long":"-70.7859","pm25":""},{"location_name":"Wamsutter","location_id":"5911","lat":"41.6778","long":"-108.0242","pm25":""},{"location_name":"Wang Yen, Plaeng Yao","location_id":"5912","lat":"13.588554","long":"101.28636","pm25":""},{"location_name":"Ward","location_id":"5913","lat":"32.36253","long":"-88.27792","pm25":""},{"location_name":"Warner Robins","location_id":"5915","lat":"32.6056","long":"-83.5979","pm25":""},{"location_name":"Warrington","location_id":"5916","lat":"53.38928","long":"-2.615358","pm25":""},{"location_name":"Warszawa-Bajkowa","location_id":"5917","lat":"52.188473","long":"21.176233","pm25":""},{"location_name":"Warszawa-Chro\u015bcickiego","location_id":"5918","lat":"52.20774","long":"20.906073","pm25":""},{"location_name":"Warszawa-Komunikacyjna","location_id":"5919","lat":"52.2193","long":"21.004725","pm25":""},{"location_name":"Warszawa-Podle\u015bna","location_id":"5920","lat":"52.280937","long":"20.962156","pm25":""},{"location_name":"Warszawa-Targ\u00f3wek","location_id":"5921","lat":"52.290863","long":"21.042458","pm25":""},{"location_name":"Warszawa-To\u0142stoja","location_id":"5922","lat":"52.285072","long":"20.933018","pm25":""},{"location_name":"Warszawa-Ursyn\u00f3w","location_id":"5923","lat":"52.16077","long":"21.03382","pm25":""},{"location_name":"Wash. Crossing","location_id":"5924","lat":"40.3125","long":"-74.8729","pm25":""},{"location_name":"Waterbury","location_id":"5925","lat":"41.5503","long":"-73.0442","pm25":""},{"location_name":"Waterloo, Water Towe","location_id":"5926","lat":"42.5014","long":"-92.3158","pm25":""},{"location_name":"Watertown","location_id":"5927","lat":"44.89965","long":"-97.1288","pm25":""},{"location_name":"Wa\u0142brzych - Wysockiego","location_id":"5933","lat":"50.76873","long":"16.269676","pm25":""},{"location_name":"Weaverville","location_id":"5935","lat":"40.734722","long":"-122.94111","pm25":""},{"location_name":"Wekerom-Riemterdijk","location_id":"5941","lat":"52.1116","long":"5.70842","pm25":""},{"location_name":"Welby - 78th Ave. &","location_id":"5942","lat":"39.8392","long":"-104.9489","pm25":""},{"location_name":"Welch - 12400 W. Hwy","location_id":"5943","lat":"39.6389","long":"-105.1389","pm25":""},{"location_name":"Wellpinit-Spokane Tr","location_id":"5944","lat":"47.8852","long":"-117.9886","pm25":""},{"location_name":"Wenatchee-Fifth St","location_id":"5947","lat":"47.43061","long":"-120.34195","pm25":""},{"location_name":"West 43rd","location_id":"5948","lat":"33.4064","long":"-112.1443","pm25":""},{"location_name":"West Chandler Fire S","location_id":"5950","lat":"33.299","long":"-111.8843","pm25":""},{"location_name":"West Duluth","location_id":"5951","lat":"46.74389","long":"-92.16695","pm25":""},{"location_name":"West Los Angeles - V","location_id":"5953","lat":"34.051098","long":"-118.45638","pm25":""},{"location_name":"West Mackay","location_id":"5954","lat":"-21.1595","long":"149.155","pm25":""},{"location_name":"West Mesa","location_id":"5955","lat":"32.11","long":"-106.51","pm25":""},{"location_name":"West Orange C9\/C141","location_id":"5956","lat":"30.0844","long":"-93.7617","pm25":""},{"location_name":"West Phoenix","location_id":"5957","lat":"33.4838","long":"-112.1426","pm25":""},{"location_name":"West Union","location_id":"5959","lat":"39.210884","long":"-87.66842","pm25":""},{"location_name":"West Yellowstone Par","location_id":"5960","lat":"44.657013","long":"-111.089615","pm25":""},{"location_name":"Westlake","location_id":"5962","lat":"30.2625","long":"-93.285","pm25":""},{"location_name":"Westmaas-Groeneweg","location_id":"5963","lat":"51.7866","long":"4.45053","pm25":""},{"location_name":"Westmorland - 570 Co","location_id":"5964","lat":"33.0325","long":"-115.6225","pm25":""},{"location_name":"Westport","location_id":"5965","lat":"41.1189","long":"-73.3369","pm25":""},{"location_name":"Weybourne","location_id":"5968","lat":"52.95049","long":"1.122017","pm25":""},{"location_name":"Whistler Meadow Park","location_id":"5969","lat":"50.1439","long":"-122.9611","pm25":""},{"location_name":"White Fish Dead End","location_id":"5970","lat":"48.400524","long":"-114.335976","pm25":""},{"location_name":"White Plains","location_id":"5972","lat":"41.0522","long":"-73.7642","pm25":""},{"location_name":"White Springs","location_id":"5973","lat":"30.4264","long":"-82.7947","pm25":""},{"location_name":"White Swan-Yakama Tr","location_id":"5975","lat":"46.37543","long":"-120.72932","pm25":""},{"location_name":"Whiteface Mtn","location_id":"5976","lat":"44.3647","long":"-73.9017","pm25":""},{"location_name":"Whiterocks","location_id":"5977","lat":"40.4838","long":"-109.9062","pm25":""},{"location_name":"Whitestown","location_id":"5978","lat":"39.9975","long":"-86.39528","pm25":""},{"location_name":"Wiang Phang Kham, Mae Sai","location_id":"5979","lat":"19.909996","long":"99.83","pm25":""},{"location_name":"Wiang Yong, Mueang","location_id":"5980","lat":"18.564722","long":"99.01115","pm25":""},{"location_name":"Wiang, Mueang","location_id":"5981","lat":"19.909243","long":"99.82336","pm25":""},{"location_name":"Wicken Fen","location_id":"5982","lat":"52.2985","long":"0.290917","pm25":""},{"location_name":"Widnes Milton Road","location_id":"5983","lat":"53.36539","long":"-2.73168","pm25":""},{"location_name":"Widuchowa","location_id":"5984","lat":"53.122326","long":"14.382222","pm25":""},{"location_name":"Wieringerwerf-Medemblikkerweg","location_id":"6006","lat":"52.8037","long":"5.05051","pm25":""},{"location_name":"Wigan Centre","location_id":"6008","lat":"53.54914","long":"-2.638139","pm25":""},{"location_name":"Wijk aan Zee-Burgemeester Rothestraat","location_id":"6009","lat":"52.494","long":"4.60199","pm25":""},{"location_name":"Wijnandsrade-Opfergeltstraat","location_id":"6010","lat":"50.9023","long":"5.88175","pm25":""},{"location_name":"Wilkes-Barre","location_id":"6012","lat":"41.2658","long":"-75.8464","pm25":""},{"location_name":"Williams Lake Column","location_id":"6013","lat":"52.1342","long":"-122.1528","pm25":""},{"location_name":"Williams Middle Scho","location_id":"6014","lat":"34.2143","long":"-79.7673","pm25":""},{"location_name":"Williamson","location_id":"6015","lat":"43.2303","long":"-77.1728","pm25":""},{"location_name":"Willows-Colusa","location_id":"6016","lat":"39.53387","long":"-122.190834","pm25":""},{"location_name":"Windsor Downtown","location_id":"6018","lat":"42.3144","long":"-83.0433","pm25":""},{"location_name":"Winegard Elementary","location_id":"6019","lat":"28.4544","long":"-81.3814","pm25":""},{"location_name":"Winkler Pump Station","location_id":"6020","lat":"26.6028","long":"-81.8789","pm25":""},{"location_name":"Winter Park","location_id":"6023","lat":"28.5997","long":"-81.3628","pm25":""},{"location_name":"Winthrop-Chewuch Rd","location_id":"6025","lat":"48.4772","long":"-120.1906","pm25":""},{"location_name":"Wirral Tranmere","location_id":"6026","lat":"53.37287","long":"-3.022722","pm25":""},{"location_name":"Wodzis\u0142aw \u015al\u0105ski, ul. Ga\u0142czy\u0144skiego 1","location_id":"6027","lat":"50.00763","long":"18.455547","pm25":""},{"location_name":"Wollongong","location_id":"6031","lat":"-34.41861","long":"150.88638","pm25":""},{"location_name":"Wood Buffalo Park","location_id":"6032","lat":"60.1465","long":"-113.63769","pm25":""},{"location_name":"Woodland","location_id":"6033","lat":"38.6619","long":"-121.7278","pm25":""},{"location_name":"Woodstock","location_id":"6035","lat":"43.945","long":"-71.7008","pm25":""},{"location_name":"Woolloongabba","location_id":"6036","lat":"-27.4975","long":"153.035","pm25":""},{"location_name":"Worcester","location_id":"6037","lat":"42.2639","long":"-71.7947","pm25":""},{"location_name":"Worthing A27 Roadside","location_id":"6038","lat":"50.832947","long":"-0.379916","pm25":""},{"location_name":"Wrexham","location_id":"6039","lat":"53.04222","long":"-3.002778","pm25":""},{"location_name":"Wroc\u0142aw - Bartnicza","location_id":"6040","lat":"51.115932","long":"17.141125","pm25":""},{"location_name":"Wroc\u0142aw - Korzeniowskiego","location_id":"6041","lat":"51.12938","long":"17.02925","pm25":""},{"location_name":"Wroc\u0142aw - Wi\u015bniowa","location_id":"6042","lat":"51.086224","long":"17.01269","pm25":""},{"location_name":"Wschowa ul. Kazimierza Wielkiego","location_id":"6043","lat":"51.79972","long":"16.3175","pm25":""},{"location_name":"Wynnum","location_id":"6044","lat":"-27.4296","long":"153.158","pm25":""},{"location_name":"Wynnum West","location_id":"6045","lat":"-27.4379","long":"153.15","pm25":""},{"location_name":"Wyong","location_id":"6047","lat":"-32.195","long":"150.67361","pm25":""},{"location_name":"W\u0142oc\u0142awek OKRZEI","location_id":"6049","lat":"52.658466","long":"19.059315","pm25":""},{"location_name":"W\u0142oc\u0142awek, ul. Kaliska","location_id":"6050","lat":"52.637394","long":"19.044485","pm25":""},{"location_name":"Xianxi","location_id":"6054","lat":"24.131672","long":"120.46906","pm25":""},{"location_name":"Xinzhuang","location_id":"6055","lat":"25.037971","long":"121.4325","pm25":""},{"location_name":"YMCA - Marion County","location_id":"6056","lat":"29.1708","long":"-82.1008","pm25":""},{"location_name":"York","location_id":"6057","lat":"39.9653","long":"-76.6994","pm25":""},{"location_name":"YPSILANTI","location_id":"6058","lat":"42.24","long":"-83.5997","pm25":""},{"location_name":"YPT Campbell Ranch","location_id":"6059","lat":"39.063034","long":"-119.2044","pm25":""},{"location_name":"Yacolt-Yacolt Rd","location_id":"6060","lat":"45.8639","long":"-122.41089","pm25":""},{"location_name":"Yakima-4th Ave","location_id":"6061","lat":"46.59495","long":"-120.51228","pm25":""},{"location_name":"Yangming","location_id":"6062","lat":"25.182722","long":"121.52959","pm25":""},{"location_name":"Yankee Road","location_id":"6063","lat":"39.472435","long":"-84.39495","pm25":""},{"location_name":"Yarner Wood","location_id":"6064","lat":"50.5976","long":"-3.71651","pm25":""},{"location_name":"Yellowstone NP","location_id":"6067","lat":"44.5597","long":"-110.4006","pm25":""},{"location_name":"Yellowstone- Old Fai","location_id":"6068","lat":"44.373055","long":"-110.83083","pm25":""},{"location_name":"York Bootham","location_id":"6072","lat":"53.967514","long":"-1.086514","pm25":""},{"location_name":"York DW","location_id":"6073","lat":"39.8608","long":"-76.4619","pm25":""},{"location_name":"York Fishergate","location_id":"6074","lat":"53.95189","long":"-1.075861","pm25":""},{"location_name":"York Landfill","location_id":"6075","lat":"34.977","long":"-81.207","pm25":""},{"location_name":"Yosemite NP Turtleba","location_id":"6077","lat":"37.7133","long":"-119.7061","pm25":""},{"location_name":"Yosemite Village - V","location_id":"6078","lat":"37.748707","long":"-119.5871","pm25":""},{"location_name":"Youngstown - Head St","location_id":"6079","lat":"41.09594","long":"-80.65847","pm25":""},{"location_name":"Youngstown - Laird A","location_id":"6080","lat":"41.23172","long":"-80.80116","pm25":""},{"location_name":"Youngstown - Oakhill","location_id":"6081","lat":"41.096157","long":"-80.658905","pm25":""},{"location_name":"Yreka","location_id":"6082","lat":"41.72679","long":"-122.63359","pm25":""},{"location_name":"Yuba City","location_id":"6083","lat":"39.13868","long":"-121.61884","pm25":""},{"location_name":"Yuen Long","location_id":"6084","lat":"22.445278","long":"114.02278","pm25":""},{"location_name":"Yukon","location_id":"6085","lat":"35.4794","long":"-97.7508","pm25":""},{"location_name":"Yulee","location_id":"6086","lat":"30.62673","long":"-81.53597","pm25":""},{"location_name":"Yuma Supersite","location_id":"6087","lat":"32.690277","long":"-114.61444","pm25":""},{"location_name":"ZALAMELLA","location_id":"6089","lat":"44.4278","long":"12.1865","pm25":""},{"location_name":"Zaandam-Wagenschotpad","location_id":"6091","lat":"52.448","long":"4.81671","pm25":""},{"location_name":"Zaanstad-Hemkade","location_id":"6092","lat":"52.4202","long":"4.83206","pm25":""},{"location_name":"Zabierz\u00f3w, ul. Wapienna","location_id":"6093","lat":"50.116028","long":"19.800638","pm25":""},{"location_name":"Zabrze, ul. M. Curie-Sk\u0142odowskiej 34","location_id":"6094","lat":"50.3165","long":"18.772375","pm25":""},{"location_name":"Zagorje","location_id":"6095","lat":"46.131073","long":"14.996085","pm25":""},{"location_name":"Zakopane, ul. Sienkiewicza","location_id":"6096","lat":"49.293564","long":"19.960083","pm25":""},{"location_name":"Zamo\u015b\u0107 ul. Hrubieszowska 69A","location_id":"6097","lat":"50.71663","long":"23.290247","pm25":""},{"location_name":"Zawiercie, ul. K.I.Ga\u0142czy\u0144skiego 3","location_id":"6098","lat":"50.493046","long":"19.439013","pm25":""},{"location_name":"Zayante Fire Station","location_id":"6099","lat":"37.067","long":"-122.057205","pm25":""},{"location_name":"Zdzieszowice automat 2","location_id":"6100","lat":"50.423534","long":"18.120739","pm25":""},{"location_name":"Zegveld-Oude Meije","location_id":"6103","lat":"52.138","long":"4.83819","pm25":""},{"location_name":"Zeppelinfjellet","location_id":"6108","lat":"78.90669","long":"11.88899","pm25":""},{"location_name":"Zgierz-\u015ar\u00f3dmie\u015bcie","location_id":"6109","lat":"51.856693","long":"19.42123","pm25":""},{"location_name":"Zgorzelec - Bohater\u00f3w Getta","location_id":"6110","lat":"51.15039","long":"15.008175","pm25":""},{"location_name":"Zhongming","location_id":"6111","lat":"24.151958","long":"120.64109","pm25":""},{"location_name":"Zhongshan","location_id":"6112","lat":"25.06236","long":"121.52653","pm25":""},{"location_name":"Zhushan","location_id":"6113","lat":"23.75639","long":"120.67731","pm25":""},{"location_name":"Zielona G\u00f3ra ul. Kr\u00f3tka","location_id":"6114","lat":"51.93978","long":"15.518861","pm25":""},{"location_name":"Zierikzee-Lange Slikweg","location_id":"6115","lat":"51.6347","long":"3.91662","pm25":""},{"location_name":"Zion NP","location_id":"6117","lat":"37.1983","long":"-113.1506","pm25":""},{"location_name":"Zuni Hills","location_id":"6119","lat":"33.68674","long":"-112.29417","pm25":""},{"location_name":"Z\u00e9phirin","location_id":"6122","lat":"46.0419","long":"-72.66","pm25":""},{"location_name":"Z\u0105bkowice \u015al\u0105skie","location_id":"6124","lat":"50.592323","long":"16.819786","pm25":""},{"location_name":"Z\u0142oty Potok, Le\u015bnicz\u00f3wka","location_id":"6125","lat":"50.710888","long":"19.458797","pm25":""},{"location_name":"\u00c9douard","location_id":"6131","lat":"47.6472","long":"-72.2914","pm25":""},{"location_name":"\u00d1ielol","location_id":"6132","lat":"-38.727005","long":"-72.58","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Gda\u0144ska 16","location_id":"6146","lat":"51.77541","long":"19.4509","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Jana Paw\u0142a II 15","location_id":"6147","lat":"51.754612","long":"19.434925","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Widzew","location_id":"6148","lat":"51.75805","long":"19.529785","pm25":""},{"location_name":"\u015anie\u017cka","location_id":"6149","lat":"50.73639","long":"15.739722","pm25":""},{"location_name":"\u017bary, ul. Szymanowskiego 8","location_id":"6153","lat":"51.642654","long":"15.127808","pm25":""},{"location_name":"\u017bory, Os. Gen. W\u0142adys\u0142awa Sikorskiego 52_(2)","location_id":"6154","lat":"50.029415","long":"18.689528","pm25":""},{"location_name":"\u017byrard\u00f3w-Roosevelta","location_id":"6155","lat":"52.05381","long":"20.429892","pm25":""},{"location_name":"\u017bywiec, ul. Kopernika  83 a","location_id":"6156","lat":"49.6716","long":"19.234446","pm25":""},{"location_name":"\u017divinice","location_id":"6157","lat":"44.453888","long":"18.648333","pm25":""},{"location_name":"\u0410\u043b\u0442\u0430\u0439","location_id":"6159","lat":"46.376526","long":"96.26234","pm25":""},{"location_name":"\u0410\u0440\u0432\u0430\u0439\u0445\u044d\u044d\u0440","location_id":"6160","lat":"46.258915","long":"102.78922","pm25":""},{"location_name":"\u0411\u0430\u0440\u0443\u0443\u043d-\u0423\u0440\u0442","location_id":"6161","lat":"46.680305","long":"113.28025","pm25":""},{"location_name":"\u0411\u0430\u044f\u043d\u0445\u043e\u043d\u0433\u043e\u0440","location_id":"6162","lat":"46.19711","long":"100.720085","pm25":""},{"location_name":"\u0411\u0443\u043b\u0433\u0430\u043d","location_id":"6164","lat":"48.818222","long":"103.51867","pm25":""},{"location_name":"\u0414\u0430\u043b\u0430\u043d\u0437\u0430\u0434\u0433\u0430\u0434","location_id":"6171","lat":"43.56761","long":"104.42267","pm25":""},{"location_name":"\u0414\u0430\u0440\u0445\u0430\u043d","location_id":"6172","lat":"49.49039","long":"105.9065","pm25":""},{"location_name":"\u0417\u0443\u0443\u043d\u043c\u043e\u0434","location_id":"6178","lat":"47.71039","long":"106.95365","pm25":""},{"location_name":"\u0417\u04af\u04af\u043d\u0445\u0430\u0440\u0430\u0430","location_id":"6179","lat":"48.866665","long":"106.85","pm25":""},{"location_name":"\u041c\u0430\u043d\u0434\u0430\u043b\u0433\u043e\u0432\u044c","location_id":"6189","lat":"45.767113","long":"106.27489","pm25":""},{"location_name":"\u041c\u04e9\u0440\u04e9\u043d","location_id":"6192","lat":"49.638863","long":"100.16653","pm25":""},{"location_name":"\u0421\u0430\u0439\u043d\u0448\u0430\u043d\u0434","location_id":"6201","lat":"45.06664","long":"110.146385","pm25":""},{"location_name":"\u0421\u04af\u0445\u0431\u0430\u0430\u0442\u0430\u0440","location_id":"6208","lat":"50.239693","long":"106.19278","pm25":""},{"location_name":"\u0423\u0411-11","location_id":"6212","lat":"47.95143","long":"106.904076","pm25":""},{"location_name":"\u0423\u0411-6","location_id":"6214","lat":"47.91345","long":"106.97203","pm25":""},{"location_name":"\u0423\u0411-9","location_id":"6215","lat":"47.981915","long":"106.94051","pm25":""},{"location_name":"\u0423\u043b\u0430\u0430\u043d\u0433\u043e\u043c","location_id":"6216","lat":"49.971943","long":"92.07736","pm25":""},{"location_name":"\u0423\u043b\u0438\u0430\u0441\u0442\u0430\u0439","location_id":"6217","lat":"47.72689","long":"96.84739","pm25":""},{"location_name":"\u0425\u043e\u0432\u0434","location_id":"6219","lat":"47.996","long":"91.63392","pm25":""},{"location_name":"\u0426\u044d\u0446\u044d\u0440\u043b\u044d\u0433","location_id":"6220","lat":"47.472195","long":"101.46245","pm25":""},{"location_name":"\u0427\u043e\u0439\u0431\u0430\u043b\u0441\u0430\u043d","location_id":"6223","lat":"48.080555","long":"114.53758","pm25":""},{"location_name":"\u0427\u043e\u0439\u0440","location_id":"6224","lat":"46.357777","long":"108.24611","pm25":""},{"location_name":"\u0428\u0430\u0440\u044b\u043d \u0433\u043e\u043b","location_id":"6226","lat":"49.261444","long":"106.41189","pm25":""},{"location_name":"\u04e8\u043b\u0433\u0438\u0439","location_id":"6230","lat":"48.969196","long":"89.96494","pm25":""},{"location_name":"\u04e8\u043d\u0434\u04e9\u0440\u0445\u0430\u0430\u043d","location_id":"6231","lat":"47.32397","long":"110.64867","pm25":""},{"location_name":"\u4e00\u4e2d","location_id":"6238","lat":"33.6284","long":"116.9677","pm25":""},{"location_name":"\u4e00\u5546\u573a","location_id":"6239","lat":"43.1594","long":"124.3711","pm25":""},{"location_name":"\u4e01\u5b57\u53e3","location_id":"6240","lat":"27.6869","long":"106.9222","pm25":""},{"location_name":"\u4e03\u661f\u5ca9\u5b50\u7ad9","location_id":"6241","lat":"23.0786","long":"112.4722","pm25":""},{"location_name":"\u4e03\u8d24\u5cad","location_id":"6242","lat":"38.85611","long":"121.51806","pm25":""},{"location_name":"\u4e07\u5b89","location_id":"6243","lat":"24.9424","long":"118.6663","pm25":""},{"location_name":"\u4e07\u5bff\u897f\u5bab","location_id":"6244","lat":"39.8673","long":"116.366","pm25":""},{"location_name":"\u4e07\u91cc\u56fd\u9645\u5b66\u6821","location_id":"6245","lat":"29.901667","long":"121.61472","pm25":""},{"location_name":"\u4e07\u91cc\u5b66\u9662","location_id":"6246","lat":"29.8208","long":"121.56","pm25":""},{"location_name":"\u4e09\u4e94\u4e00\u4e94\u5de5\u5382","location_id":"6247","lat":"33.567","long":"114.056","pm25":""},{"location_name":"\u4e09\u5143\u533a\u653f\u5e9c","location_id":"6248","lat":"26.2378","long":"117.6028","pm25":""},{"location_name":"\u4e09\u5341\u4e00\u4e2d\u5b66","location_id":"6249","lat":"43.831","long":"87.6432","pm25":""},{"location_name":"\u4e09\u56fd\u63fd\u80dc\u5bab","location_id":"6250","lat":"33.8561","long":"115.7831","pm25":""},{"location_name":"\u4e09\u5ddd\u6c34\u8868","location_id":"6251","lat":"28.2169","long":"116.9983","pm25":""},{"location_name":"\u4e09\u660e\u4e8c\u4e2d","location_id":"6252","lat":"26.2708","long":"117.6353","pm25":""},{"location_name":"\u4e09\u6c34\u4e91\u4e1c\u6d77","location_id":"6253","lat":"23.1886","long":"112.863","pm25":""},{"location_name":"\u4e09\u6c34\u5382","location_id":"6254","lat":"31.5072","long":"104.7283","pm25":""},{"location_name":"\u4e09\u6c34\u76d1\u6d4b\u7ad9","location_id":"6255","lat":"23.1572","long":"112.885","pm25":""},{"location_name":"\u4e09\u6c5f\u4e2d\u5b66","location_id":"6256","lat":"29.8906","long":"121.554","pm25":""},{"location_name":"\u4e09\u74e6\u7a91","location_id":"6257","lat":"30.5706","long":"104.079","pm25":""},{"location_name":"\u4e09\u8fea\u5c0f\u5b66","location_id":"6258","lat":"34.3622","long":"107.2386","pm25":""},{"location_name":"\u4e09\u91cc\u8857","location_id":"6259","lat":"31.8766","long":"117.307","pm25":""},{"location_name":"\u4e09\u91d1\u96c6\u56e2","location_id":"6260","lat":"36.8041","long":"117.8512","pm25":""},{"location_name":"\u4e09\u94a2","location_id":"6261","lat":"26.2625","long":"117.6211","pm25":""},{"location_name":"\u4e09\u9646\u533b\u9662","location_id":"6262","lat":"34.3672","long":"107.1906","pm25":""},{"location_name":"\u4e0a\u5170(\u5bf9\u7167\u70b9)","location_id":"6263","lat":"38.0108","long":"112.434","pm25":""},{"location_name":"\u4e0a\u65b9\u5c71","location_id":"6264","lat":"31.2472","long":"120.561","pm25":""},{"location_name":"\u4e0a\u6d77\u4e1c\u8def","location_id":"6265","lat":"38.4841","long":"106.2739","pm25":""},{"location_name":"\u4e0a\u6e05\u5bfa(\u542f\u7528170928)","location_id":"6266","lat":"29.565","long":"106.5469","pm25":""},{"location_name":"\u4e0b\u57d4\u6a2a\u6c5f\u4e09\u8def\u5b50\u7ad9","location_id":"6267","lat":"23.08","long":"114.4053","pm25":""},{"location_name":"\u4e0b\u6c99","location_id":"6268","lat":"30.3058","long":"120.348","pm25":""},{"location_name":"\u4e16\u7eaa\u516c\u56ed","location_id":"6269","lat":"38.017776","long":"114.53306","pm25":""},{"location_name":"\u4e16\u7eaa\u5b66\u6821","location_id":"6270","lat":"36.864","long":"118.78","pm25":""},{"location_name":"\u4e16\u7eaa\u661f\u5e7c\u513f\u56ed","location_id":"6272","lat":"34.7967","long":"114.2886","pm25":""},{"location_name":"\u4e16\u7eaa\u8c6a\u56ed","location_id":"6273","lat":"40.7688","long":"114.9032","pm25":""},{"location_name":"\u4e1b\u53f0\u516c\u56ed","location_id":"6274","lat":"36.61981","long":"114.4965","pm25":""},{"location_name":"\u4e1c\u4ead","location_id":"6275","lat":"31.5848","long":"120.354","pm25":""},{"location_name":"\u4e1c\u4ec1\u4e50\u56ed","location_id":"6276","lat":"24.7121","long":"108.2134","pm25":""},{"location_name":"\u4e1c\u5173\u62db\u5546\u573a(190211\u542f\u7528)","location_id":"6277","lat":"37.9325","long":"102.6486","pm25":""},{"location_name":"\u4e1c\u5174","location_id":"6278","lat":"23.5739","long":"116.3594","pm25":""},{"location_name":"\u4e1c\u5174\u533a\u653f\u5e9c","location_id":"6279","lat":"29.5947","long":"105.0717","pm25":""},{"location_name":"\u4e1c\u56db","location_id":"6280","lat":"39.9522","long":"116.434","pm25":""},{"location_name":"\u4e1c\u5733\u6c34\u5e93","location_id":"6281","lat":"25.4792","long":"118.981","pm25":""},{"location_name":"\u4e1c\u57ce\u4e3b\u5c71","location_id":"6282","lat":"23.053612","long":"113.781944","pm25":""},{"location_name":"\u4e1c\u57ce\u533a","location_id":"6283","lat":"40.7736","long":"120.8631","pm25":""},{"location_name":"\u4e1c\u57ce\u77f3\u4e95","location_id":"6284","lat":"23.012777","long":"113.79444","pm25":""},{"location_name":"\u4e1c\u57d4","location_id":"6285","lat":"23.7586","long":"114.6944","pm25":""},{"location_name":"\u4e1c\u5be8\u6e2f","location_id":"6286","lat":"19.9507","long":"110.576","pm25":""},{"location_name":"\u4e1c\u5c40\u5b50","location_id":"6287","lat":"43.8358","long":"126.5844","pm25":""},{"location_name":"\u4e1c\u5c71\u516c\u56ed","location_id":"6288","lat":"31.1208","long":"104.4219","pm25":""},{"location_name":"\u4e1c\u5c71\u7eb8\u677f\u5382","location_id":"6289","lat":"47.3489","long":"130.3172","pm25":""},{"location_name":"\u4e1c\u660e","location_id":"6290","lat":"41.2864","long":"123.7669","pm25":""},{"location_name":"\u4e1c\u6c61\u6c34\u5904\u7406\u5382","location_id":"6291","lat":"36.6164","long":"114.5426","pm25":""},{"location_name":"\u4e1c\u6cb3\u57ce\u73af\u5c40","location_id":"6292","lat":"40.5905","long":"110.0067","pm25":""},{"location_name":"\u4e1c\u6cb3\u9e3f\u9f99\u6e7e","location_id":"6293","lat":"40.5546","long":"110.0377","pm25":""},{"location_name":"\u4e1c\u6d32\u533a","location_id":"6294","lat":"41.8625","long":"124.0383","pm25":""},{"location_name":"\u4e1c\u6e56(\u5bf9\u7167\u70b9)","location_id":"6295","lat":"22.5931","long":"113.0819","pm25":""},{"location_name":"\u4e1c\u6e56\u68a8\u56ed","location_id":"6296","lat":"30.5719","long":"114.3672","pm25":""},{"location_name":"\u4e1c\u82d1","location_id":"6297","lat":"42.0228","long":"121.6722","pm25":""},{"location_name":"\u4e1c\u95e8\u5916\u5c0f\u6e38\u56ed","location_id":"6298","lat":"46.7432","long":"82.9994","pm25":""},{"location_name":"\u4e1c\u9675\u8def","location_id":"6299","lat":"41.8336","long":"123.542","pm25":""},{"location_name":"\u4e1c\u98ce\u4e1c\u8def","location_id":"6300","lat":"25.0405","long":"102.722","pm25":""},{"location_name":"\u4e1c\u98ce\u5316\u5de5\u5382","location_id":"6301","lat":"36.838","long":"118.0448","pm25":""},{"location_name":"\u4e1c\u98ce\u6c34\u5e93","location_id":"6302","lat":"24.3694","long":"102.5778","pm25":""},{"location_name":"\u4e24\u5bfa\u6e21","location_id":"6303","lat":"34.2969","long":"108.6594","pm25":""},{"location_name":"\u4e24\u8def","location_id":"6304","lat":"29.7228","long":"106.626","pm25":""},{"location_name":"\u4e2d\u4fe1\u4e8c\u5c0f","location_id":"6305","lat":"34.6692","long":"112.3628","pm25":""},{"location_name":"\u4e2d\u533b\u9662","location_id":"6306","lat":"27.6428","long":"113.8381","pm25":""},{"location_name":"\u4e2d\u534e\u5c0f\u533a","location_id":"6307","lat":"34.3181","long":"108.6761","pm25":""},{"location_name":"\u4e2d\u534e\u95e8","location_id":"6308","lat":"32.0144","long":"118.777","pm25":""},{"location_name":"\u4e2d\u56fd\u94f6\u884c","location_id":"6309","lat":"40.9843","long":"117.9525","pm25":""},{"location_name":"\u4e2d\u5c71\u5317\u8def(\u542f\u7528161122)","location_id":"6310","lat":"39.16969","long":"117.2099","pm25":""},{"location_name":"\u4e2d\u5fc3\u533b\u9662","location_id":"6311","lat":"47.7222","long":"128.8736","pm25":""},{"location_name":"\u4e2d\u5fc3\u5e7f\u573a","location_id":"6312","lat":"47.3386","long":"123.9305","pm25":""},{"location_name":"\u4e2d\u6d77\u52c3\u6e7e\u5b66\u6821","location_id":"6313","lat":"39.6572","long":"106.7931","pm25":""},{"location_name":"\u4e2d\u9662\u6751","location_id":"6314","lat":"26.5155","long":"106.6948","pm25":""},{"location_name":"\u4e30\u6ee1","location_id":"6315","lat":"43.7256","long":"126.6772","pm25":""},{"location_name":"\u4e34\u57ce\u65b0\u533a","location_id":"6316","lat":"29.9944","long":"122.19","pm25":""},{"location_name":"\u4e34\u5e73\u9547","location_id":"6317","lat":"30.4183","long":"120.301","pm25":""},{"location_name":"\u4e34\u6c5f\u540e\u8857","location_id":"6318","lat":"40.1503","long":"124.4256","pm25":""},{"location_name":"\u4e34\u6f7c\u533a","location_id":"6319","lat":"34.3731","long":"109.2186","pm25":""},{"location_name":"\u4e34\u94a2\u533b\u9662","location_id":"6320","lat":"36.0783","long":"111.5531","pm25":""},{"location_name":"\u4e39\u5f92\u533a\u76d1\u6d4b\u7ad9","location_id":"6321","lat":"32.1319","long":"119.43","pm25":""},{"location_name":"\u4e3d\u6c5f\u53e4\u57ce","location_id":"6322","lat":"26.8802","long":"100.2497","pm25":""},{"location_name":"\u4e3d\u9633\u82b1\u56ed","location_id":"6323","lat":"31.8542","long":"106.7658","pm25":""},{"location_name":"\u4e4c\u5c14\u79be\u533a\u5546\u8d38\u697c","location_id":"6324","lat":"46.0872","long":"85.6931","pm25":""},{"location_name":"\u4e5d\u6e56(\u5bf9\u7167\u70b9)","location_id":"6325","lat":"24.4674","long":"117.6336","pm25":""},{"location_name":"\u4e5d\u72ee\u5c71","location_id":"6326","lat":"28.9583","long":"105.4306","pm25":""},{"location_name":"\u4e5d\u7ad9","location_id":"6327","lat":"43.953056","long":"126.47389","pm25":""},{"location_name":"\u4e5d\u8862\u6cc9\u7eaf\u51c0\u6c34\u5382","location_id":"6328","lat":"37.4372","long":"116.2714","pm25":""},{"location_name":"\u4e5d\u9f99","location_id":"6329","lat":"26.0931","long":"119.58","pm25":""},{"location_name":"\u4e5d\u9f99\u9547\u9547\u9f99","location_id":"6330","lat":"23.2783","long":"113.568","pm25":""},{"location_name":"\u4e73\u5c71\u5e02\u6c14\u8c61\u5c40","location_id":"6331","lat":"36.907","long":"121.544","pm25":""},{"location_name":"\u4e73\u5c71\u5e02\u73af\u4fdd\u5c40","location_id":"6332","lat":"36.913","long":"121.531","pm25":""},{"location_name":"\u4e8c\u5341\u4e5d\u4e2d","location_id":"6333","lat":"40.8062","long":"111.7277","pm25":""},{"location_name":"\u4e8c\u6c34\u5382","location_id":"6334","lat":"32.935","long":"117.3086","pm25":""},{"location_name":"\u4e91\u5188\u5bbe\u9986","location_id":"6335","lat":"40.0758","long":"113.2994","pm25":""},{"location_name":"\u4e91\u6816","location_id":"6336","lat":"30.1808","long":"120.088","pm25":""},{"location_name":"\u4e91\u6eaa\u533a","location_id":"6337","lat":"29.4758","long":"113.2621","pm25":""},{"location_name":"\u4e91\u7530\u4e2d\u5b66","location_id":"6338","lat":"27.9958","long":"113.1817","pm25":""},{"location_name":"\u4e91\u76d6\u5c0f\u5b66","location_id":"6339","lat":"23.475","long":"111.3178","pm25":""},{"location_name":"\u4e94\u4e03\u4e8c\u4e03\u5382","location_id":"6340","lat":"29.6535","long":"116.0174","pm25":""},{"location_name":"\u4e94\u53f0\u5c71\u533b\u9662(\u542f\u7528161107)","location_id":"6341","lat":"32.41361","long":"119.458","pm25":""},{"location_name":"\u4e94\u53f7\u6c34\u5e93","location_id":"6342","lat":"47.3382","long":"130.1097","pm25":""},{"location_name":"\u4e94\u56db\u5317\u8def","location_id":"6343","lat":"26.1092","long":"119.299","pm25":""},{"location_name":"\u4e94\u661f\u516c\u56ed","location_id":"6344","lat":"31.909","long":"120.237","pm25":""},{"location_name":"\u4e94\u91d1\u5e93","location_id":"6345","lat":"40.8115","long":"114.8814","pm25":""},{"location_name":"\u4ea4\u901a\u5c40\u3000","location_id":"6346","lat":"50.2486","long":"127.4961","pm25":""},{"location_name":"\u4eac\u4e1c\u9547\u653f\u5e9c","location_id":"6347","lat":"28.6969","long":"115.973","pm25":""},{"location_name":"\u4eac\u6c88\u8857","location_id":"6348","lat":"41.9228","long":"123.3783","pm25":""},{"location_name":"\u4eba\u53e3\u5b66\u6821","location_id":"6349","lat":"36.1942","long":"117.0881","pm25":""},{"location_name":"\u4eba\u548c\u4e1c\u8857","location_id":"6350","lat":"46.6384","long":"126.9934","pm25":""},{"location_name":"\u4eba\u5927\u5bbe\u9986","location_id":"6351","lat":"32.2786","long":"118.3244","pm25":""},{"location_name":"\u4eba\u6c11\u4f1a\u5802","location_id":"6352","lat":"38.0524","long":"114.5214","pm25":""},{"location_name":"\u4eba\u6c11\u516c\u56ed","location_id":"6353","lat":"40.8367","long":"114.8985","pm25":""},{"location_name":"\u4eba\u6c11\u5e7f\u573a\u5b50\u7ad9","location_id":"6354","lat":"36.885","long":"120.515","pm25":""},{"location_name":"\u4ec1\u548c","location_id":"6355","lat":"26.5017","long":"101.7453","pm25":""},{"location_name":"\u4ec1\u7687\u5c71\u65b0\u533a","location_id":"6356","lat":"30.89556","long":"120.0875","pm25":""},{"location_name":"\u4ed3\u95e8\u8857\u5b50\u7ad9","location_id":"6357","lat":"39.746","long":"98.509","pm25":""},{"location_name":"\u4ed9\u4eba\u5d16","location_id":"6358","lat":"34.3469","long":"106.005","pm25":""},{"location_name":"\u4ed9\u6797\u5927\u5b66\u57ce","location_id":"6359","lat":"32.105","long":"118.907","pm25":""},{"location_name":"\u4ed9\u846b","location_id":"6360","lat":"22.7906","long":"108.439","pm25":""},{"location_name":"\u4ef0\u53e3","location_id":"6361","lat":"36.2403","long":"120.6659","pm25":""},{"location_name":"\u4ef2\u88c1\u59d4","location_id":"6362","lat":"36.7019","long":"119.12","pm25":""},{"location_name":"\u4f0d\u5bb6\u5173(\u5bf9\u7167\u70b9)","location_id":"6363","lat":"26.2611","long":"105.9606","pm25":""},{"location_name":"\u4f0d\u5bb6\u5c97","location_id":"6364","lat":"30.6463","long":"111.3549","pm25":""},{"location_name":"\u4f0d\u5bb6\u5cad","location_id":"6365","lat":"28.2597","long":"112.9792","pm25":""},{"location_name":"\u4f1a\u5c55\u4e2d\u5fc3","location_id":"6366","lat":"38.4928","long":"112.7003","pm25":""},{"location_name":"\u4f53\u80b2\u573a","location_id":"6367","lat":"38.8343","long":"105.6775","pm25":""},{"location_name":"\u4f53\u80b2\u897f","location_id":"6368","lat":"23.1323","long":"113.3208","pm25":""},{"location_name":"\u4f53\u80b2\u9986","location_id":"6369","lat":"34.493","long":"109.4636","pm25":""},{"location_name":"\u4f59\u5e84\u524d","location_id":"6370","lat":"28.4231","long":"119.879","pm25":""},{"location_name":"\u4f73\u7eba","location_id":"6371","lat":"46.8025","long":"130.2719","pm25":""},{"location_name":"\u4f9b\u6392\u6c34\u516c\u53f8","location_id":"6372","lat":"40.1114","long":"113.2803","pm25":""},{"location_name":"\u4f9b\u6c34\u516c\u53f8","location_id":"6373","lat":"34.802","long":"113.564","pm25":""},{"location_name":"\u4f9b\u9500\u793e","location_id":"6374","lat":"39.6308","long":"118.1662","pm25":""},{"location_name":"\u4fe1\u8bbf\u5c40","location_id":"6375","lat":"36.0878","long":"114.3922","pm25":""},{"location_name":"\u5065\u5eb7\u8def","location_id":"6376","lat":"21.6669","long":"110.9067","pm25":""},{"location_name":"\u5085\u5bb6\u5e84","location_id":"6377","lat":"38.863888","long":"121.625","pm25":""},{"location_name":"\u513f\u7ae5\u4e50\u56ed","location_id":"6378","lat":"37.4664","long":"116.3061","pm25":""},{"location_name":"\u5143\u5b9d\u5c71","location_id":"6379","lat":"40.1461","long":"124.3933","pm25":""},{"location_name":"\u5149\u660e","location_id":"6380","lat":"41.7156","long":"125.9361","pm25":""},{"location_name":"\u5149\u660e\u8857\u5c0f\u5b66","location_id":"6381","lat":"41.0385","long":"113.1076","pm25":""},{"location_name":"\u515a\u653f\u529e\u516c\u4e2d\u5fc3","location_id":"6382","lat":"46.6527","long":"126.9636","pm25":""},{"location_name":"\u515a\u6821","location_id":"6383","lat":"35.0994","long":"109.0656","pm25":""},{"location_name":"\u516b\u4e2d","location_id":"6384","lat":"27.3125","long":"105.2864","pm25":""},{"location_name":"\u516b\u516c\u5c71\u533a\u653f\u5e9c","location_id":"6385","lat":"32.6319","long":"116.8306","pm25":""},{"location_name":"\u516b\u5ed3\u8857","location_id":"6386","lat":"29.6514","long":"91.1319","pm25":""},{"location_name":"\u516b\u91cc\u5821","location_id":"6387","lat":"41.5647","long":"120.4247","pm25":""},{"location_name":"\u516c\u53f8\u4e8c\u62db","location_id":"6388","lat":"38.5061","long":"102.1708","pm25":""},{"location_name":"\u516c\u56ed\u8def","location_id":"6389","lat":"32.4867","long":"119.9","pm25":""},{"location_name":"\u516c\u5b89\u5c40","location_id":"6390","lat":"50.4217","long":"124.1303","pm25":""},{"location_name":"\u5170\u70bc\u5bbe\u9986","location_id":"6391","lat":"36.1031","long":"103.631","pm25":""},{"location_name":"\u5170\u7530\u5baa\u6865","location_id":"6392","lat":"28.8558","long":"105.4322","pm25":""},{"location_name":"\u5171\u548c\u53bf\u6070\u535c\u6070\u9547","location_id":"6393","lat":"36.2866","long":"100.6188","pm25":""},{"location_name":"\u5174\u5e86\u5c0f\u533a","location_id":"6394","lat":"34.2629","long":"108.993","pm25":""},{"location_name":"\u5174\u677e\u5c0f\u533a","location_id":"6395","lat":"40.8452","long":"111.659","pm25":""},{"location_name":"\u5174\u798f\u5b50\u7ad9","location_id":"6396","lat":"31.671","long":"120.721","pm25":""},{"location_name":"\u5174\u9686\u53f0","location_id":"6397","lat":"41.0903","long":"122.0539","pm25":""},{"location_name":"\u5174\u9686\u6b65\u884c\u8857","location_id":"6398","lat":"25.8179","long":"113.0119","pm25":""},{"location_name":"\u517d\u533b\u7ad9","location_id":"6399","lat":"29.2786","long":"117.1983","pm25":""},{"location_name":"\u5185\u6c5f\u4e8c\u4e2d","location_id":"6400","lat":"29.5817","long":"105.0653","pm25":""},{"location_name":"\u5185\u6c5f\u65e5\u62a5\u793e","location_id":"6401","lat":"29.5822","long":"105.0406","pm25":""},{"location_name":"\u519c\u4e1a\u56ed\u533a","location_id":"6402","lat":"42.0503","long":"121.6972","pm25":""},{"location_name":"\u519c\u5c55\u9986","location_id":"6403","lat":"39.9716","long":"116.473","pm25":""},{"location_name":"\u519c\u6c34\u5927\u53a6","location_id":"6404","lat":"44.1756","long":"87.5475","pm25":""},{"location_name":"\u519c\u7267\u8f66\u8f86\u5382","location_id":"6405","lat":"47.3227","long":"123.9483","pm25":""},{"location_name":"\u519c\u79d1\u6240","location_id":"6406","lat":"36.67","long":"116.93","pm25":""},{"location_name":"\u519c\u79d1\u9662","location_id":"6407","lat":"34.2778","long":"117.2933","pm25":""},{"location_name":"\u51b7\u6c34\u6ee9\u533a\u73af\u4fdd\u5c40","location_id":"6408","lat":"26.4519","long":"111.5989","pm25":""},{"location_name":"\u51c0\u6708\u6f6d","location_id":"6409","lat":"43.7878","long":"125.454","pm25":""},{"location_name":"\u51c9\u5c71\u5dde\u653f\u5e9c","location_id":"6410","lat":"27.8847","long":"102.2689","pm25":""},{"location_name":"\u51e1\u53e3\u5f00\u53d1\u533a","location_id":"6411","lat":"30.4133","long":"114.8131","pm25":""},{"location_name":"\u51e4\u51f0\u5149\u5b66","location_id":"6412","lat":"28.4622","long":"117.9511","pm25":""},{"location_name":"\u51e4\u51f0\u5c0f\u533a","location_id":"6413","lat":"31.2108","long":"107.4967","pm25":""},{"location_name":"\u51e4\u51f0\u5c71","location_id":"6414","lat":"27.7019","long":"106.9242","pm25":""},{"location_name":"\u51e4\u57ce\u8857\u529e","location_id":"6415","lat":"23.7106","long":"113.0208","pm25":""},{"location_name":"\u51ef\u65cb\u8def\u5c0f\u5b66","location_id":"6416","lat":"34.6686","long":"112.4433","pm25":""},{"location_name":"\u51ef\u91cc\u5b66\u9662","location_id":"6417","lat":"26.53111","long":"107.89083","pm25":""},{"location_name":"\u5218\u5bb6\u6c9f","location_id":"6418","lat":"32.6389","long":"110.7258","pm25":""},{"location_name":"\u524d\u5c71","location_id":"6419","lat":"22.2294","long":"113.495","pm25":""},{"location_name":"\u524d\u8fdb\u9053","location_id":"6420","lat":"39.0927","long":"117.202","pm25":""},{"location_name":"\u52a8\u529b\u516c\u53f8","location_id":"6421","lat":"36.5481","long":"104.1731","pm25":""},{"location_name":"\u52a8\u529b\u548c\u5e73\u8def","location_id":"6422","lat":"45.7258","long":"126.646","pm25":""},{"location_name":"\u52b3\u52a8\u516c\u56ed","location_id":"6423","lat":"43.8748","long":"125.3649","pm25":""},{"location_name":"\u52e4\u4fed\u9053","location_id":"6424","lat":"39.1654","long":"117.145","pm25":""},{"location_name":"\u5305\u6cb3\u533a","location_id":"6425","lat":"31.7956","long":"117.302","pm25":""},{"location_name":"\u5305\u767e\u5927\u697c","location_id":"6426","lat":"40.6575","long":"109.8104","pm25":""},{"location_name":"\u5316\u5de5\u8857","location_id":"6427","lat":"40.7514","long":"120.8392","pm25":""},{"location_name":"\u5316\u80a5\u5382\u751f\u6d3b\u533a","location_id":"6428","lat":"40.7612","long":"111.717","pm25":""},{"location_name":"\u5317\u4e2d\u65b0\u6821","location_id":"6429","lat":"37.393","long":"117.9776","pm25":""},{"location_name":"\u5317\u4eac\u5357\u8def","location_id":"6430","lat":"33.575","long":"119.007","pm25":""},{"location_name":"\u5317\u534e\u822a\u5929\u5b66\u9662","location_id":"6431","lat":"39.5343","long":"116.7464","pm25":""},{"location_name":"\u5317\u5c97(\u5bf9\u7167\u70b9)","location_id":"6432","lat":"27.7758","long":"115.0586","pm25":""},{"location_name":"\u5317\u6234\u6cb3\u73af\u4fdd\u5c40","location_id":"6433","lat":"39.8283","long":"119.5259","pm25":""},{"location_name":"\u5317\u6cf5\u623f","location_id":"6434","lat":"40.8725","long":"114.904","pm25":""},{"location_name":"\u5317\u6d77\u5de5\u4e1a\u56ed","location_id":"6435","lat":"21.5233","long":"109.1778","pm25":""},{"location_name":"\u5317\u6e56","location_id":"6436","lat":"22.8561","long":"108.316","pm25":""},{"location_name":"\u5317\u6e56\u516c\u56ed","location_id":"6437","lat":"41.1386","long":"121.1303","pm25":""},{"location_name":"\u5317\u6ee8\u6cb3","location_id":"6438","lat":"46.0707","long":"122.0931","pm25":""},{"location_name":"\u5317\u82d1","location_id":"6439","lat":"29.334","long":"120.04","pm25":""},{"location_name":"\u5317\u8857","location_id":"6440","lat":"22.6069","long":"113.104","pm25":""},{"location_name":"\u5317\u8fb0\u5c0f\u5b66","location_id":"6441","lat":"30.4865","long":"106.6351","pm25":""},{"location_name":"\u533a\u4eba\u793e\u5c40","location_id":"6442","lat":"30.0561","long":"103.8286","pm25":""},{"location_name":"\u533a\u519c\u804c\u9662","location_id":"6443","lat":"22.8464","long":"108.239","pm25":""},{"location_name":"\u533a\u653f\u5e9c","location_id":"6444","lat":"36.4372","long":"115.9848","pm25":""},{"location_name":"\u533a\u6cd5\u9662","location_id":"6445","lat":"30.1259","long":"104.6294","pm25":""},{"location_name":"\u533a\u73af\u4fdd\u5927\u697c","location_id":"6446","lat":"29.9108","long":"121.836","pm25":""},{"location_name":"\u533a\u73af\u4fdd\u5c40","location_id":"6447","lat":"49.2261","long":"119.7594","pm25":""},{"location_name":"\u533a\u76d1\u6d4b\u7ad9","location_id":"6448","lat":"29.6475","long":"91.0874","pm25":""},{"location_name":"\u533a\u8f90\u5c04\u7ad9","location_id":"6449","lat":"29.6588","long":"90.9798","pm25":""},{"location_name":"\u533b\u5b66\u5206\u9662","location_id":"6450","lat":"27.9647","long":"116.385","pm25":""},{"location_name":"\u5341\u4e00\u4e2d","location_id":"6451","lat":"46.8032","long":"130.3648","pm25":""},{"location_name":"\u5341\u4e8c\u4e2d","location_id":"6452","lat":"39.65782","long":"118.1838","pm25":""},{"location_name":"\u5341\u4e94\u4e2d","location_id":"6453","lat":"29.077","long":"119.647","pm25":""},{"location_name":"\u5341\u4e94\u5382","location_id":"6454","lat":"31.2036","long":"121.478","pm25":""},{"location_name":"\u5341\u91cc","location_id":"6455","lat":"29.6816","long":"115.9872","pm25":""},{"location_name":"\u5341\u91cc\u5e97","location_id":"6456","lat":"30.6872","long":"104.176","pm25":""},{"location_name":"\u5343\u5c71","location_id":"6457","lat":"41.0228","long":"123.1289","pm25":""},{"location_name":"\u5343\u5c9b\u6e56","location_id":"6458","lat":"29.635","long":"119.026","pm25":""},{"location_name":"\u534e\u4fa8\u57ce","location_id":"6459","lat":"22.5417","long":"113.987","pm25":""},{"location_name":"\u534e\u575a\u978b\u57ce","location_id":"6460","lat":"25.8471","long":"114.8905","pm25":""},{"location_name":"\u534e\u590f\u6280\u6821","location_id":"6461","lat":"37.4294","long":"122.1206","pm25":""},{"location_name":"\u534e\u6750\u804c\u4e2d","location_id":"6462","lat":"23.0395","long":"113.105","pm25":""},{"location_name":"\u534e\u67cf\u56ed","location_id":"6463","lat":"22.5211","long":"113.3769","pm25":""},{"location_name":"\u534e\u6cf0\u6c7d\u8f66\u57ce","location_id":"6464","lat":"39.5989","long":"109.8119","pm25":""},{"location_name":"\u534e\u7535\u4e8c\u533a","location_id":"6465","lat":"38.8957","long":"115.5223","pm25":""},{"location_name":"\u5357\u5145\u5e02\u59d4","location_id":"6466","lat":"30.8023","long":"106.0789","pm25":""},{"location_name":"\u5357\u5145\u70bc\u6cb9\u5382","location_id":"6467","lat":"30.8217","long":"106.1031","pm25":""},{"location_name":"\u5357\u575d","location_id":"6468","lat":"32.4246","long":"105.8153","pm25":""},{"location_name":"\u5357\u576a","location_id":"6469","lat":"29.5186","long":"106.54","pm25":""},{"location_name":"\u5357\u57ce\u5143\u5cad","location_id":"6470","lat":"23.027779","long":"113.74611","pm25":""},{"location_name":"\u5357\u57ce\u897f\u5e73","location_id":"6471","lat":"22.965834","long":"113.738335","pm25":""},{"location_name":"\u5357\u5be8","location_id":"6472","lat":"37.9854","long":"112.549","pm25":""},{"location_name":"\u5357\u5c0f\u5e02","location_id":"6473","lat":"46.619","long":"131.1651","pm25":""},{"location_name":"\u5357\u5c71","location_id":"6474","lat":"41.0781","long":"121.0986","pm25":""},{"location_name":"\u5357\u5c97\u5b66\u5e9c\u8def","location_id":"6475","lat":"45.7222","long":"126.599","pm25":""},{"location_name":"\u5357\u5cf0\u62db\u5f85\u6240\uff08\u539f\u8d77\u91cd\u673a\u5382\uff09","location_id":"6476","lat":"35.5975","long":"104.6169","pm25":""},{"location_name":"\u5357\u5e73\u4e03\u4e2d","location_id":"6477","lat":"26.6272","long":"118.1756","pm25":""},{"location_name":"\u5357\u5e73\u5e02\u76d1\u6d4b\u7ad9","location_id":"6478","lat":"26.6383","long":"118.1694","pm25":""},{"location_name":"\u5357\u5e73\u94dd\u4e1a\u6709\u9650\u516c\u53f8","location_id":"6479","lat":"26.6514","long":"118.1819","pm25":""},{"location_name":"\u5357\u5e84","location_id":"6480","lat":"37.8561","long":"113.5922","pm25":""},{"location_name":"\u5357\u6069\u8def","location_id":"6481","lat":"21.8536","long":"111.9508","pm25":""},{"location_name":"\u5357\u6797\u5c0f\u533a","location_id":"6482","lat":"45.5828","long":"84.8897","pm25":""},{"location_name":"\u5357\u6c5f\u4e00\u4e2d","location_id":"6483","lat":"22.6164","long":"110.1433","pm25":""},{"location_name":"\u5357\u6d66","location_id":"6484","lat":"27.9939","long":"120.677","pm25":""},{"location_name":"\u5357\u6d77\u5b50\u7ad9","location_id":"6485","lat":"22.5171","long":"113.9181","pm25":""},{"location_name":"\u5357\u6d77\u6c14\u8c61\u5c40","location_id":"6486","lat":"23.0467","long":"113.144","pm25":""},{"location_name":"\u5357\u6e56\u533a\u6b8b\u8054","location_id":"6487","lat":"30.7525","long":"120.78445","pm25":""},{"location_name":"\u5357\u6e56\u98ce\u666f\u533a","location_id":"6488","lat":"29.3578","long":"113.1094","pm25":""},{"location_name":"\u5357\u6e7e\u6c34\u5382","location_id":"6489","lat":"32.1403","long":"114.0122","pm25":""},{"location_name":"\u5357\u6fb3","location_id":"6490","lat":"22.5422","long":"114.494","pm25":""},{"location_name":"\u5357\u90ca","location_id":"6491","lat":"31.96","long":"120.913","pm25":""},{"location_name":"\u5357\u90d1\u5927\u6cb3\u574e\u6c34\u5382","location_id":"6492","lat":"33.0323","long":"107.007","pm25":""},{"location_name":"\u5357\u90fd\u5c0f\u533a","location_id":"6493","lat":"37.7111","long":"112.7306","pm25":""},{"location_name":"\u5357\u95e8","location_id":"6494","lat":"31.2864","long":"120.628","pm25":""},{"location_name":"\u535a\u4e50\u5e02\u897f\u90ca\u533a","location_id":"6495","lat":"44.9079","long":"82.0485","pm25":""},{"location_name":"\u535a\u7269\u9986","location_id":"6496","lat":"35.5294","long":"106.7039","pm25":""},{"location_name":"\u5367\u9f99\u6865","location_id":"6497","lat":"30.2456","long":"120.127","pm25":""},{"location_name":"\u539f169\u533b\u9662","location_id":"6498","lat":"26.9089","long":"112.5328","pm25":""},{"location_name":"\u53cb\u8c0a\u4e2d\u5b66","location_id":"6499","lat":"30.4663","long":"106.6271","pm25":""},{"location_name":"\u53ccD\u6e2f","location_id":"6500","lat":"39.0631","long":"121.9769","pm25":""},{"location_name":"\u53cc\u5408\u6751","location_id":"6501","lat":"46.6572","long":"131.1638","pm25":""},{"location_name":"\u53cc\u5c71","location_id":"6502","lat":"36.497","long":"117.8477","pm25":""},{"location_name":"\u53cc\u6c34","location_id":"6503","lat":"26.5506","long":"104.9544","pm25":""},{"location_name":"\u53d1\u7535\u5382","location_id":"6504","lat":"46.8267","long":"130.3961","pm25":""},{"location_name":"\u53e4\u4ead\u5c71","location_id":"6505","lat":"24.3158","long":"109.4839","pm25":""},{"location_name":"\u53e4\u57ce","location_id":"6506","lat":"39.9279","long":"116.225","pm25":""},{"location_name":"\u53e4\u6c5f\u5df4\u683c\u4e61\u9662\u5185","location_id":"6507","lat":"37.1013","long":"79.9117","pm25":""},{"location_name":"\u53f0\u513f\u5e84\u533a\u73af\u4fdd\u5c40","location_id":"6508","lat":"34.5667","long":"117.732","pm25":""},{"location_name":"\u53f0\u5dde\u73af\u4fdd\u5927\u697c","location_id":"6509","lat":"28.6542","long":"121.419","pm25":""},{"location_name":"\u53f0\u8fbe\u9676\u74f7","location_id":"6510","lat":"29.2647","long":"117.1558","pm25":""},{"location_name":"\u5409\u5927","location_id":"6511","lat":"22.2611","long":"113.574","pm25":""},{"location_name":"\u5409\u9996\u5e02\u8ba1\u751f\u5c40","location_id":"6512","lat":"28.2675","long":"109.6958","pm25":""},{"location_name":"\u540c\u4ec1\u53bf\u9686\u52a1\u9547","location_id":"6513","lat":"35.5102","long":"102.0199","pm25":""},{"location_name":"\u541b\u5c71\u533a","location_id":"6514","lat":"29.4402","long":"112.9943","pm25":""},{"location_name":"\u541b\u5e73\u8857","location_id":"6515","lat":"30.6578","long":"104.054","pm25":""},{"location_name":"\u5434\u4e2d\u533a","location_id":"6516","lat":"31.2703","long":"120.613","pm25":""},{"location_name":"\u5434\u5174\u533a\u7ad9","location_id":"6517","lat":"30.8596","long":"120.1844","pm25":""},{"location_name":"\u5434\u5bb6\u5c71","location_id":"6518","lat":"30.6414","long":"114.2131","pm25":""},{"location_name":"\u5434\u6c5f\u5e02\u73af\u4fdd\u5c40","location_id":"6519","lat":"31.155","long":"120.636","pm25":""},{"location_name":"\u5434\u6c5f\u5f00\u53d1\u533a","location_id":"6520","lat":"31.172","long":"120.658","pm25":""},{"location_name":"\u543e\u529e","location_id":"6521","lat":"39.4699","long":"75.9771","pm25":""},{"location_name":"\u5448\u8d21\u65b0\u533a","location_id":"6522","lat":"24.8885","long":"102.821","pm25":""},{"location_name":"\u5468\u53e3\u5e08\u8303","location_id":"6523","lat":"33.6347","long":"114.6758","pm25":""},{"location_name":"\u5468\u6c34\u5b50","location_id":"6524","lat":"38.95111","long":"121.565","pm25":""},{"location_name":"\u547c\u5170\u5e08\u4e13","location_id":"6525","lat":"45.9819","long":"126.6106","pm25":""},{"location_name":"\u547c\u5e02\u4e00\u76d1","location_id":"6526","lat":"40.7579","long":"111.651","pm25":""},{"location_name":"\u548c\u7766\u5c0f\u5b66","location_id":"6527","lat":"30.3119","long":"120.12","pm25":""},{"location_name":"\u54b8\u5b89\u533a\u653f\u5e9c","location_id":"6528","lat":"29.8539","long":"114.2894","pm25":""},{"location_name":"\u54c8\u5564\u5206\u516c\u53f8","location_id":"6529","lat":"47.3349","long":"130.2659","pm25":""},{"location_name":"\u54c8\u5bc6\u5e08\u8303\u5b66\u6821","location_id":"6530","lat":"42.8328","long":"93.4961","pm25":""},{"location_name":"\u54c8\u8fbe\u6e7e","location_id":"6531","lat":"43.8875","long":"126.555","pm25":""},{"location_name":"\u54c8\u8fbe\u8857","location_id":"6532","lat":"42.2725","long":"118.9572","pm25":""},{"location_name":"\u5510\u5bb6","location_id":"6533","lat":"22.4251","long":"113.628","pm25":""},{"location_name":"\u5510\u5bb6\u6cb1","location_id":"6534","lat":"29.6219","long":"106.65","pm25":""},{"location_name":"\u5510\u5c27\u5927\u9152\u5e97(\u542f\u7528161122)","location_id":"6535","lat":"36.10139","long":"111.505","pm25":""},{"location_name":"\u5546\u5dde\u533a\u4e2d\u5b66","location_id":"6536","lat":"33.8471","long":"109.9643","pm25":""},{"location_name":"\u559c\u4e30","location_id":"6537","lat":"41.9206","long":"126.4047","pm25":""},{"location_name":"\u5609\u5174\u5b66\u9662","location_id":"6538","lat":"30.7478","long":"120.726","pm25":""},{"location_name":"\u5609\u5e94\u5927\u5b66","location_id":"6539","lat":"24.3289","long":"116.1278","pm25":""},{"location_name":"\u5609\u9675\u533a\u73af\u4fdd\u5c40","location_id":"6540","lat":"30.7636","long":"106.0642","pm25":""},{"location_name":"\u56db\u4e09\u4e00\u5382","location_id":"6541","lat":"30.1377","long":"104.6289","pm25":""},{"location_name":"\u56db\u4e2d","location_id":"6542","lat":"30.2311","long":"119.6942","pm25":""},{"location_name":"\u56db\u4e30","location_id":"6543","lat":"46.7588","long":"130.3794","pm25":""},{"location_name":"\u56db\u5341\u4e03\u4e2d","location_id":"6544","lat":"34.719","long":"113.734","pm25":""},{"location_name":"\u56db\u5341\u4e2d\u5c0f","location_id":"6545","lat":"26.567","long":"101.7227","pm25":""},{"location_name":"\u56db\u65b9\u533a\u5b50\u7ad9","location_id":"6546","lat":"36.1032","long":"120.3664","pm25":""},{"location_name":"\u56db\u6c34\u5382","location_id":"6547","lat":"31.3139","long":"118.3667","pm25":""},{"location_name":"\u56db\u9646\u533b\u9662","location_id":"6548","lat":"36.5819","long":"101.834","pm25":""},{"location_name":"\u56db\u96f6\u4e09","location_id":"6549","lat":"30.7157","long":"111.3009","pm25":""},{"location_name":"\u56e2\u57ce\u5c71","location_id":"6550","lat":"30.2099","long":"115.0264","pm25":""},{"location_name":"\u56e2\u6cca\u6d3c(\u5bf9\u7167\u70b9)","location_id":"6551","lat":"38.9194","long":"117.157","pm25":""},{"location_name":"\u56ed\u6797\u5904","location_id":"6552","lat":"43.8694","long":"125.325","pm25":""},{"location_name":"\u56fd\u534e\u7535\u529b\u4e1c","location_id":"6553","lat":"49.1577","long":"119.7512","pm25":""},{"location_name":"\u56fe\u4e66\u9986","location_id":"6554","lat":"29.719","long":"120.251","pm25":""},{"location_name":"\u5723\u6cc9\u6c34\u52a1\u516c\u53f8","location_id":"6555","lat":"31.8653","long":"106.7417","pm25":""},{"location_name":"\u572d\u5cf0\u897f","location_id":"6556","lat":"22.5311","long":"113.0219","pm25":""},{"location_name":"\u5730\u533a\u6280\u6821","location_id":"6557","lat":"35.0308","long":"110.9678","pm25":""},{"location_name":"\u5730\u533a\u73af\u4fdd\u5c40","location_id":"6558","lat":"42.9559","long":"89.1673","pm25":""},{"location_name":"\u5730\u533a\u76d1\u6d4b\u7ad9","location_id":"6559","lat":"42.8172","long":"93.5128","pm25":""},{"location_name":"\u5730\u533a\u7ad9","location_id":"6560","lat":"37.1152","long":"79.9485","pm25":""},{"location_name":"\u5730\u59d4","location_id":"6561","lat":"25.8664","long":"114.9367","pm25":""},{"location_name":"\u5730\u8868\u6c34\u5382","location_id":"6562","lat":"38.8416","long":"115.4612","pm25":""},{"location_name":"\u5730\u9707\u5c40\u3000","location_id":"6563","lat":"50.2538","long":"127.4143","pm25":""},{"location_name":"\u573a\u575d\u8857","location_id":"6564","lat":"25.0925","long":"104.9022","pm25":""},{"location_name":"\u574a\u5b50\u90ae\u653f","location_id":"6565","lat":"36.6525","long":"119.1638","pm25":""},{"location_name":"\u5751\u53e3\u5b50\u7ad9","location_id":"6566","lat":"23.1617","long":"112.565","pm25":""},{"location_name":"\u575e\u57ce","location_id":"6567","lat":"37.8195","long":"112.57","pm25":""},{"location_name":"\u5761\u5934\u533a\u73af\u4fdd\u5c40","location_id":"6568","lat":"21.2567","long":"110.4558","pm25":""},{"location_name":"\u576a\u4e1c\u5927\u9053","location_id":"6569","lat":"25.0992","long":"104.8811","pm25":""},{"location_name":"\u57ce\u4e1c\u5f00\u53d1\u59d4","location_id":"6570","lat":"29.9919","long":"120.605","pm25":""},{"location_name":"\u57ce\u4e2d","location_id":"6571","lat":"32.02","long":"120.87","pm25":""},{"location_name":"\u57ce\u4e2d\u5b50\u7ad9","location_id":"6572","lat":"23.0528","long":"112.471","pm25":""},{"location_name":"\u57ce\u5317\u533a\u653f\u5e9c","location_id":"6573","lat":"36.6428","long":"101.7775","pm25":""},{"location_name":"\u57ce\u5317\u5c0f\u5b66","location_id":"6574","lat":"31.882","long":"120.55","pm25":""},{"location_name":"\u57ce\u5357\u65b0\u533a","location_id":"6575","lat":"22.3708","long":"107.3701","pm25":""},{"location_name":"\u57ce\u53a2\u9547","location_id":"6576","lat":"30.1819","long":"120.27","pm25":""},{"location_name":"\u57ce\u897f\u6c34\u5382","location_id":"6577","lat":"30.8244","long":"120.07","pm25":""},{"location_name":"\u57ce\u9633\u533a\u5b50\u7ad9","location_id":"6578","lat":"36.2403","long":"120.4001","pm25":""},{"location_name":"\u57ce\u9675\u77f6","location_id":"6579","lat":"29.4251","long":"113.1493","pm25":""},{"location_name":"\u57f9\u8bad\u57fa\u5730","location_id":"6580","lat":"43.4569","long":"87.4651","pm25":""},{"location_name":"\u5830\u6865","location_id":"6581","lat":"31.6842","long":"120.288","pm25":""},{"location_name":"\u5883\u56ed","location_id":"6582","lat":"43.1847","long":"124.3897","pm25":""},{"location_name":"\u5916\u56fd\u8bed\u5b66\u6821\uff0820181128\u542f\u7528\uff09","location_id":"6583","lat":"29.6995","long":"116.0257","pm25":""},{"location_name":"\u5916\u6ee9\u9996\u5e9c","location_id":"6584","lat":"35.043888","long":"111.05222","pm25":""},{"location_name":"\u5927\u4e9a\u6e7e\u7ba1\u59d4\u4f1a\u5b50\u7ad9","location_id":"6585","lat":"22.7422","long":"114.5317","pm25":""},{"location_name":"\u5927\u4eac\u98ce\u666f\u533a","location_id":"6586","lat":"27.8336","long":"113.251","pm25":""},{"location_name":"\u5927\u4f19\u623f\u6c34\u5e93","location_id":"6587","lat":"41.8864","long":"124.0878","pm25":""},{"location_name":"\u5927\u5174526\u53f0","location_id":"6588","lat":"30.0125","long":"103.009","pm25":""},{"location_name":"\u5927\u540c\u533a","location_id":"6589","lat":"46.0347","long":"124.8354","pm25":""},{"location_name":"\u5927\u540c\u5927\u5b66","location_id":"6590","lat":"40.0917","long":"113.3444","pm25":""},{"location_name":"\u5927\u5858\u5c71","location_id":"6591","lat":"29.3628","long":"104.7547","pm25":""},{"location_name":"\u5927\u5cea","location_id":"6592","lat":"41.3283","long":"123.8436","pm25":""},{"location_name":"\u5927\u5e86\u8def","location_id":"6593","lat":"40.7094","long":"122.2703","pm25":""},{"location_name":"\u5927\u6b66\u53e3\u9ec4\u6cb3\u4e1c\u8857","location_id":"6594","lat":"39.0153","long":"106.3717","pm25":""},{"location_name":"\u5927\u6d77\u82b1\u56ed","location_id":"6595","lat":"21.6414","long":"108.3506","pm25":""},{"location_name":"\u5927\u7406\u53e4\u57ce","location_id":"6596","lat":"25.5811","long":"100.2171","pm25":""},{"location_name":"\u5927\u7406\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"6597","lat":"25.7054","long":"100.1542","pm25":""},{"location_name":"\u5927\u7406\u9053(\u542f\u7528160601)","location_id":"6598","lat":"39.1067","long":"117.1941","pm25":""},{"location_name":"\u5927\u76f4\u6cbd\u516b\u53f7\u8def","location_id":"6599","lat":"39.1082","long":"117.237","pm25":""},{"location_name":"\u5927\u77f3\u897f\u8def","location_id":"6600","lat":"30.65639","long":"104.02389","pm25":""},{"location_name":"\u5927\u81ea\u7136\u82b1\u56ed","location_id":"6601","lat":"22.805","long":"108.383","pm25":""},{"location_name":"\u5927\u9633\u6cc9","location_id":"6602","lat":"37.85","long":"113.5158","pm25":""},{"location_name":"\u5929\u4e49\u8def","location_id":"6603","lat":"42.2556","long":"118.8789","pm25":""},{"location_name":"\u5929\u53f0\u5c71\u5e84","location_id":"6604","lat":"27.8244","long":"113.135","pm25":""},{"location_name":"\u5929\u575b","location_id":"6605","lat":"39.8745","long":"116.434","pm25":""},{"location_name":"\u5929\u5b89\u8857\u9053","location_id":"6606","lat":"41.1222","long":"121.1178","pm25":""},{"location_name":"\u5929\u5c71\u5929\u6c60","location_id":"6607","lat":"44.1564","long":"87.9897","pm25":""},{"location_name":"\u5929\u5e73\u670d\u88c5","location_id":"6608","lat":"31.6411","long":"118.4828","pm25":""},{"location_name":"\u5929\u5fc3\u533a\u73af\u4fdd\u5c40","location_id":"6609","lat":"28.1178","long":"112.9844","pm25":""},{"location_name":"\u5929\u65b9\u4e8c\u5206\u5382\u3000","location_id":"6610","lat":"32.996","long":"113.996","pm25":""},{"location_name":"\u5929\u751f","location_id":"6611","lat":"29.8264","long":"106.424","pm25":""},{"location_name":"\u592a\u4ed3\u5e02\u76d1\u6d4b\u7ad9","location_id":"6612","lat":"31.453","long":"121.115","pm25":""},{"location_name":"\u592a\u539f\u8857","location_id":"6613","lat":"41.7972","long":"123.3997","pm25":""},{"location_name":"\u592a\u53e4\u5c0f\u5b66","location_id":"6614","lat":"29.8633","long":"121.586","pm25":""},{"location_name":"\u592a\u5e73","location_id":"6615","lat":"41.1442","long":"123.0485","pm25":""},{"location_name":"\u592a\u5e73\u5b8f\u4f1f\u516c\u56ed","location_id":"6616","lat":"45.7733","long":"126.689","pm25":""},{"location_name":"\u592a\u6148\u6865","location_id":"6617","lat":"26.5495","long":"106.6867","pm25":""},{"location_name":"\u592a\u6781\u4f53\u80b2\u4e2d\u5fc3","location_id":"6618","lat":"35.2067","long":"113.2725","pm25":""},{"location_name":"\u592a\u9633\u57ce","location_id":"6619","lat":"41.0931","long":"123.011","pm25":""},{"location_name":"\u5937\u9675\u533a","location_id":"6620","lat":"30.7819","long":"111.3296","pm25":""},{"location_name":"\u5965\u4f53\u4e2d\u5fc3","location_id":"6621","lat":"32.0092","long":"118.737","pm25":""},{"location_name":"\u5965\u6797\u82b1\u56ed","location_id":"6622","lat":"39.7884","long":"109.9734","pm25":""},{"location_name":"\u5982\u610f\u6c34\u5904\u7406\u5382","location_id":"6623","lat":"40.8369","long":"111.751","pm25":""},{"location_name":"\u5987\u5e7c\u533b\u9662","location_id":"6625","lat":"42.8939","long":"129.4892","pm25":""},{"location_name":"\u5a01\u5b81","location_id":"6626","lat":"41.3472","long":"123.8142","pm25":""},{"location_name":"\u5a04\u5bb6\u5761","location_id":"6627","lat":"26.2481","long":"105.8983","pm25":""},{"location_name":"\u5b54\u96c0\u516c\u56ed","location_id":"6628","lat":"41.7511","long":"86.1461","pm25":""},{"location_name":"\u5b66\u5e9c\u5357\u8def","location_id":"6629","lat":"40.6592","long":"122.2414","pm25":""},{"location_name":"\u5b66\u9662\u8def","location_id":"6630","lat":"38.5036","long":"106.1358","pm25":""},{"location_name":"\u5b81\u5fb7\u4e00\u4e2d(20190319\u542f\u7528)","location_id":"6631","lat":"26.6564","long":"119.5228","pm25":""},{"location_name":"\u5b81\u5fb7\u5e02\u76d1\u6d4b\u7ad9","location_id":"6632","lat":"26.6611","long":"119.5392","pm25":""},{"location_name":"\u5b89\u5bb6","location_id":"6633","lat":"31.9017","long":"119.9167","pm25":""},{"location_name":"\u5b89\u5bb6\u5c0f\u6751","location_id":"6634","lat":"40.1269","long":"113.2661","pm25":""},{"location_name":"\u5b89\u5c45\u5c0f\u533a","location_id":"6635","lat":"47.3636","long":"123.9305","pm25":""},{"location_name":"\u5b89\u5e86\u5927\u5b66(\u5bf9\u7167\u70b9)","location_id":"6636","lat":"30.6145","long":"116.9894","pm25":""},{"location_name":"\u5b89\u5eb7\u5e02\u76d1\u6d4b\u7ad9","location_id":"6637","lat":"32.6939","long":"109.0281","pm25":""},{"location_name":"\u5b89\u6e90\u533a\u653f\u5e9c","location_id":"6638","lat":"27.6178","long":"113.865","pm25":""},{"location_name":"\u5b8f\u4f1f\u533a","location_id":"6639","lat":"41.1953","long":"123.2","pm25":""},{"location_name":"\u5b98\u56ed","location_id":"6640","lat":"39.9425","long":"116.361","pm25":""},{"location_name":"\u5b98\u6865\u7ad9","location_id":"6641","lat":"37.0172","long":"105.18","pm25":""},{"location_name":"\u5b98\u6e21\u533a\u535a\u7269\u9986\uff08180930\u542f\u7528\uff09","location_id":"6642","lat":"25.0119","long":"102.749","pm25":""},{"location_name":"\u5b9a\u6d77\u6a80\u67ab","location_id":"6643","lat":"30.0203","long":"122.122","pm25":""},{"location_name":"\u5b9a\u9675","location_id":"6644","lat":"40.2865","long":"116.17","pm25":""},{"location_name":"\u5b9c\u5174\u5e02\u73af\u4fdd\u5c40","location_id":"6645","lat":"31.354","long":"119.818","pm25":""},{"location_name":"\u5b9c\u56ed","location_id":"6646","lat":"31.371","long":"119.794","pm25":""},{"location_name":"\u5b9c\u5bbe\u56db\u4e2d","location_id":"6647","lat":"28.7867","long":"104.6061","pm25":""},{"location_name":"\u5b9c\u6625\u5b66\u9662\u5317\u6821\u533a\uff08181229\u542f\u7528\uff09","location_id":"6648","lat":"27.8097","long":"114.375","pm25":""},{"location_name":"\u5b9d\u9f99\u5e7f\u573a","location_id":"6649","lat":"33.3681","long":"120.1631","pm25":""},{"location_name":"\u5b9e\u9a8c\u4e2d\u5b66","location_id":"6650","lat":"38.2839","long":"109.7289","pm25":""},{"location_name":"\u5b9e\u9a8c\u5b66\u6821","location_id":"6651","lat":"28.9664","long":"118.871","pm25":""},{"location_name":"\u5ba1\u8ba1\u5c40","location_id":"6652","lat":"36.2126","long":"113.0886","pm25":""},{"location_name":"\u5ba2\u8f66\u5382","location_id":"6653","lat":"43.91","long":"125.287","pm25":""},{"location_name":"\u5bb9\u6842\u8857\u9053\u529e","location_id":"6654","lat":"22.7629","long":"113.257","pm25":""},{"location_name":"\u5bbe\u6c34\u897f\u9053(\u542f\u7528150702)","location_id":"6655","lat":"39.0845","long":"117.1589","pm25":""},{"location_name":"\u5bbf\u8c6b\u533a\u653f\u5e9c(181206\u542f\u7528)","location_id":"6656","lat":"33.9447","long":"118.3225","pm25":""},{"location_name":"\u5bbf\u8fc1\u4e2d\u5b66","location_id":"6658","lat":"33.9592","long":"118.2442","pm25":""},{"location_name":"\u5bbf\u8fc1\u5b66\u9662","location_id":"6659","lat":"33.9528","long":"118.293","pm25":""},{"location_name":"\u5bcc\u4e50\u5c71","location_id":"6660","lat":"31.4747","long":"104.7778","pm25":""},{"location_name":"\u5bcc\u533a\u73af\u4fdd\u5c40","location_id":"6661","lat":"47.203","long":"123.6261","pm25":""},{"location_name":"\u5bcc\u5eb7\u5bb6\u4e16\u754c\u5b50\u7ad9","location_id":"6662","lat":"39.7294","long":"98.5023","pm25":""},{"location_name":"\u5bcc\u6625\u4e8c\u5c0f","location_id":"6663","lat":"30.049","long":"119.946","pm25":""},{"location_name":"\u5bcc\u6797\u5370\u52a1","location_id":"6664","lat":"29.732","long":"120.209","pm25":""},{"location_name":"\u5bd2\u4ead\u76d1\u6d4b\u7ad9","location_id":"6665","lat":"36.7731","long":"119.1939","pm25":""},{"location_name":"\u5bd2\u5c71\u6c34\u5e93","location_id":"6666","lat":"22.7019","long":"110.1106","pm25":""},{"location_name":"\u5c01\u9f99\u5c71","location_id":"6667","lat":"37.9097","long":"114.3541","pm25":""},{"location_name":"\u5c0f\u4e1c\u6c9f","location_id":"6668","lat":"47.9047","long":"88.1214","pm25":""},{"location_name":"\u5c0f\u53ec","location_id":"6669","lat":"40.8033","long":"111.658","pm25":""},{"location_name":"\u5c0f\u56f4\u5be8","location_id":"6670","lat":"26.2403","long":"107.5228","pm25":""},{"location_name":"\u5c0f\u5be8","location_id":"6671","lat":"34.2324","long":"108.94","pm25":""},{"location_name":"\u5c0f\u5c71","location_id":"6672","lat":"39.6295","long":"118.1997","pm25":""},{"location_name":"\u5c0f\u5e02\u4e0a\u7801\u5934","location_id":"6673","lat":"28.9026","long":"105.4436","pm25":""},{"location_name":"\u5c0f\u5e73\u65e7\u5c45","location_id":"6674","lat":"30.518","long":"106.631","pm25":""},{"location_name":"\u5c0f\u5e97","location_id":"6675","lat":"37.7394","long":"112.5583","pm25":""},{"location_name":"\u5c0f\u6cb3\u6cbf","location_id":"6676","lat":"41.7775","long":"123.478","pm25":""},{"location_name":"\u5c16\u8349\u576a","location_id":"6677","lat":"37.8873","long":"112.522","pm25":""},{"location_name":"\u5c27\u5e99\u9547","location_id":"6678","lat":"36.0417","long":"111.4917","pm25":""},{"location_name":"\u5c55\u89c8\u9986(190815\u542f\u7528)","location_id":"6679","lat":"30.6619","long":"117.4916","pm25":""},{"location_name":"\u5c71\u4e1c\u6210\u5c71\u8f6e\u80ce\u516c\u53f8","location_id":"6680","lat":"37.161","long":"122.41","pm25":""},{"location_name":"\u5c71\u4ead\u533a\u73af\u4fdd\u5c40","location_id":"6681","lat":"35.0992","long":"117.4518","pm25":""},{"location_name":"\u5c71\u5357\u4eba\u6c11\u533b\u9662","location_id":"6682","lat":"29.261","long":"91.7706","pm25":""},{"location_name":"\u5c71\u5357\u76d1\u6d4b\u7ad9","location_id":"6683","lat":"29.2313","long":"91.7608","pm25":""},{"location_name":"\u5c71\u5927\u5206\u6821","location_id":"6684","lat":"37.5325","long":"122.0508","pm25":""},{"location_name":"\u5c71\u897f\u8def","location_id":"6685","lat":"32.0723","long":"118.778","pm25":""},{"location_name":"\u5c97\u674e\u6c34\u5e93(\u5bf9\u7167\u70b9)","location_id":"6686","lat":"34.9162","long":"113.6113","pm25":""},{"location_name":"\u5cad\u5317(\u5bf9\u7167\u70b9)","location_id":"6687","lat":"45.755","long":"126.542","pm25":""},{"location_name":"\u5cb1\u5c71\u516c\u56ed","location_id":"6688","lat":"43.85","long":"125.217","pm25":""},{"location_name":"\u5cb3\u5858","location_id":"6689","lat":"27.8159","long":"112.9227","pm25":""},{"location_name":"\u5cc4\u57ce\u533a\u653f\u5e9c","location_id":"6690","lat":"34.7745","long":"117.5852","pm25":""},{"location_name":"\u5d02\u5c71\u533a\u5b50\u7ad9","location_id":"6691","lat":"36.0851","long":"120.4587","pm25":""},{"location_name":"\u5ddd\u519c\u5927","location_id":"6692","lat":"29.9816","long":"103.0001","pm25":""},{"location_name":"\u5ddd\u6c47\u533a\u73af\u4fdd\u5c40","location_id":"6693","lat":"33.6406","long":"114.6369","pm25":""},{"location_name":"\u5dde\u519c\u79d1\u6240","location_id":"6694","lat":"31.9286","long":"102.1755","pm25":""},{"location_name":"\u5dde\u56fe\u4e66\u9986","location_id":"6695","lat":"23.3682","long":"103.3758","pm25":""},{"location_name":"\u5dde\u59d4\u515a\u6821","location_id":"6696","lat":"35.5997","long":"103.2064","pm25":""},{"location_name":"\u5dde\u653f\u5e9c","location_id":"6697","lat":"28.3169","long":"109.7325","pm25":""},{"location_name":"\u5dde\u6c34\u52a1\u5c40","location_id":"6698","lat":"23.3594","long":"104.2533","pm25":""},{"location_name":"\u5dde\u73af\u4fdd\u5c40","location_id":"6699","lat":"29.9972","long":"101.9533","pm25":""},{"location_name":"\u5dde\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"6700","lat":"25.0441","long":"101.5482","pm25":""},{"location_name":"\u5dde\u7535\u529b\u603b\u516c\u53f8","location_id":"6701","lat":"30.2819","long":"109.4689","pm25":""},{"location_name":"\u5dde\u76d1\u6d4b\u7ad9","location_id":"6702","lat":"25.8567","long":"98.8601","pm25":""},{"location_name":"\u5de1\u8b66\u5927\u961f","location_id":"6703","lat":"39.5371","long":"75.9828","pm25":""},{"location_name":"\u5de5\u4e1a\u56ed\u533a","location_id":"6704","lat":"41.9967","long":"121.6178","pm25":""},{"location_name":"\u5de5\u4eba\u7597\u517b\u9662","location_id":"6705","lat":"32.939","long":"117.3961","pm25":""},{"location_name":"\u5de5\u5546\u5b66\u6821","location_id":"6706","lat":"36.0822","long":"111.5169","pm25":""},{"location_name":"\u5de5\u5927\u91d1\u5ddd\u6821\u533a","location_id":"6707","lat":"40.7866","long":"111.551","pm25":""},{"location_name":"\u5de8\u8f6e","location_id":"6708","lat":"37.8964","long":"112.5628","pm25":""},{"location_name":"\u5df4\u97f3\u5b5f\u514b\u6797\u573a\u529e\u4e8b\u5904","location_id":"6710","lat":"39.8261","long":"109.9486","pm25":""},{"location_name":"\u5e02\u4e00\u4e2d","location_id":"6711","lat":"27.2317","long":"111.4733","pm25":""},{"location_name":"\u5e02\u4e00\u7eb8\u5382\u3000","location_id":"6712","lat":"32.965","long":"114.018","pm25":""},{"location_name":"\u5e02\u4e2d\u533a\u653f\u5e9c","location_id":"6713","lat":"34.864","long":"117.5564","pm25":""},{"location_name":"\u5e02\u4e2d\u5fc3","location_id":"6715","lat":"37.8564","long":"113.5753","pm25":""},{"location_name":"\u5e02\u4e2d\u5fc3\u8840\u7ad9","location_id":"6716","lat":"23.8844","long":"106.6527","pm25":""},{"location_name":"\u5e02\u4e5d\u4e2d","location_id":"6717","lat":"24.3663","long":"109.3957","pm25":""},{"location_name":"\u5e02\u4e8c\u4e2d","location_id":"6718","lat":"39.3673","long":"112.4279","pm25":""},{"location_name":"\u5e02\u4e94\u4e2d","location_id":"6719","lat":"23.105","long":"113.261","pm25":""},{"location_name":"\u5e02\u4ea4\u8b66\u652f\u961f","location_id":"6720","lat":"35.7511","long":"114.2956","pm25":""},{"location_name":"\u5e02\u4eba\u5927","location_id":"6721","lat":"31.4539","long":"104.7536","pm25":""},{"location_name":"\u5e02\u4eba\u6c11\u4f53\u80b2\u573a","location_id":"6722","lat":"34.2713","long":"108.954","pm25":""},{"location_name":"\u5e02\u4eba\u6c11\u653f\u5e9c","location_id":"6723","lat":"39.7153","long":"76.1861","pm25":""},{"location_name":"\u5e02\u4f53\u80b2\u5c40\uff08181219\u542f\u7528\uff09","location_id":"6724","lat":"32.3972","long":"119.3633","pm25":""},{"location_name":"\u5e02\u4f9b\u7535\u5c40(\u542f\u7528161107)","location_id":"6725","lat":"33.965","long":"118.283","pm25":""},{"location_name":"\u5e02\u4fbf\u6c11\u670d\u52a1\u4e2d\u5fc3","location_id":"6726","lat":"23.3892","long":"104.2319","pm25":""},{"location_name":"\u5e02\u516b\u4e2d","location_id":"6727","lat":"24.76952","long":"113.58661","pm25":""},{"location_name":"\u5e02\u516b\u5341\u516d\u4e2d","location_id":"6728","lat":"23.105","long":"113.433","pm25":""},{"location_name":"\u5e02\u516c\u8def\u5c40","location_id":"6729","lat":"30.9222","long":"117.8078","pm25":""},{"location_name":"\u5e02\u519c\u79d1\u9662","location_id":"6730","lat":"21.9508","long":"108.6553","pm25":""},{"location_name":"\u5e02\u5316\u5de5\u5382","location_id":"6731","lat":"27.2582","long":"111.4908","pm25":""},{"location_name":"\u5e02\u5317\u533a\u5b50\u7ad9","location_id":"6732","lat":"36.0699","long":"120.3471","pm25":""},{"location_name":"\u5e02\u5357\u533a\u4e1c\u90e8\u5b50\u7ad9","location_id":"6733","lat":"36.0654","long":"120.4134","pm25":""},{"location_name":"\u5e02\u5357\u533a\u897f\u90e8\u5b50\u7ad9","location_id":"6734","lat":"36.0543","long":"120.2992","pm25":""},{"location_name":"\u5e02\u53d1\u6539\u59d4","location_id":"6735","lat":"29.8211","long":"114.3231","pm25":""},{"location_name":"\u5e02\u56db\u4e2d","location_id":"6736","lat":"24.299","long":"109.4221","pm25":""},{"location_name":"\u5e02\u56db\u533b\u9662","location_id":"6737","lat":"27.5342","long":"109.9792","pm25":""},{"location_name":"\u5e02\u56fe\u4e66\u9986","location_id":"6738","lat":"30.3175","long":"112.2551","pm25":""},{"location_name":"\u5e02\u57ce\u7ba1\u5c40(181124\u542f\u7528)","location_id":"6739","lat":"37.739","long":"115.6689","pm25":""},{"location_name":"\u5e02\u59d4","location_id":"6740","lat":"28.76611","long":"104.6225","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"6741","lat":"30.3515","long":"112.2068","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821(\u542f\u7528180727)","location_id":"6742","lat":"38.5253","long":"102.1864","pm25":""},{"location_name":"\u5e02\u59d4\u65b0\u529e\u516c\u533a","location_id":"6743","lat":"34.6258","long":"112.4275","pm25":""},{"location_name":"\u5e02\u5ba1\u8ba1\u5c40","location_id":"6744","lat":"25.8071","long":"113.0383","pm25":""},{"location_name":"\u5e02\u5e7f\u7535\u5c40","location_id":"6745","lat":"27.8072","long":"114.4011","pm25":""},{"location_name":"\u5e02\u5f69\u5370\u5382\u3000","location_id":"6746","lat":"33.0069","long":"114.0131","pm25":""},{"location_name":"\u5e02\u653f\u4e2d\u5fc3","location_id":"6747","lat":"31.2058","long":"107.4611","pm25":""},{"location_name":"\u5e02\u653f\u534f","location_id":"6748","lat":"35.2375","long":"115.474724","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"6749","lat":"34.7772","long":"111.1928","pm25":""},{"location_name":"\u5e02\u653f\u5e9c(20190313\u542f\u7528)","location_id":"6750","lat":"38.4153","long":"112.7283","pm25":""},{"location_name":"\u5e02\u653f\u5e9c\u539f\u529e\u516c\u697c(20190308\u542f\u7528)","location_id":"6751","lat":"32.3039","long":"118.3117","pm25":""},{"location_name":"\u5e02\u653f\u5e9c\u5e7f\u573a","location_id":"6752","lat":"35.4234","long":"119.5198","pm25":""},{"location_name":"\u5e02\u653f\u5e9c\u8f66\u5e93","location_id":"6753","lat":"27.6231","long":"113.8447","pm25":""},{"location_name":"\u5e02\u6559\u80b2\u57fa\u5730","location_id":"6754","lat":"31.7133","long":"118.6439","pm25":""},{"location_name":"\u5e02\u65b0\u6c11\u6c61\u6c34\u5382","location_id":"6755","lat":"30.9414","long":"117.7806","pm25":""},{"location_name":"\u5e02\u6797\u4e1a\u5c40","location_id":"6756","lat":"31.6908","long":"113.3833","pm25":""},{"location_name":"\u5e02\u68c0\u5bdf\u9662","location_id":"6757","lat":"31.1167","long":"104.4053","pm25":""},{"location_name":"\u5e02\u68ee\u6797\u5de5\u4e1a\u5c40","location_id":"6758","lat":"27.11","long":"114.9739","pm25":""},{"location_name":"\u5e02\u6c14\u8c61\u5c40","location_id":"6759","lat":"35.24889","long":"115.42277","pm25":""},{"location_name":"\u5e02\u6c34\u571f\u6240","location_id":"6760","lat":"27.3033","long":"111.5239","pm25":""},{"location_name":"\u5e02\u7279\u6b8a\u6559\u80b2\u5b66\u6821","location_id":"6761","lat":"28.56","long":"112.3439","pm25":""},{"location_name":"\u5e02\u73af\u4fdd","location_id":"6762","lat":"23.4792","long":"111.2897","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5927\u697c","location_id":"6763","lat":"40.7378","long":"107.3715","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5c40","location_id":"6764","lat":"31.8711","long":"106.7389","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5c40\u6c5f\u5dde\u5206\u5c40","location_id":"6765","lat":"22.4137","long":"107.3476","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5c40\u8302\u6e2f\u5206\u5c40","location_id":"6766","lat":"21.4689","long":"111.0286","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u76d1\u6d4b\u7ad9","location_id":"6767","lat":"43.9317","long":"116.1042","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u7ad9","location_id":"6768","lat":"26.5689","long":"106.6971","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u4e2d\u5fc3","location_id":"6769","lat":"29.8506","long":"121.524","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"6770","lat":"34.5885","long":"119.176","pm25":""},{"location_name":"\u5e02\u73af\u76d1\u7ad9","location_id":"6771","lat":"28.8833","long":"105.4322","pm25":""},{"location_name":"\u5e02\u75be\u63a7\u4e2d\u5fc3","location_id":"6772","lat":"24.6967","long":"108.1009","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"6773","lat":"37.7379","long":"115.6426","pm25":""},{"location_name":"\u5e02\u77f3\u6cb9\u516c\u53f8","location_id":"6774","lat":"27.7842","long":"114.3953","pm25":""},{"location_name":"\u5e02\u7acb\u4ea4\u6865\u6c34\u5382","location_id":"6775","lat":"31.7308","long":"113.3983","pm25":""},{"location_name":"\u5e02\u7ad9","location_id":"6776","lat":"28.0167","long":"120.671","pm25":""},{"location_name":"\u5e02\u7b2c\u4e09\u6c34\u5382","location_id":"6777","lat":"29.6007","long":"103.7506","pm25":""},{"location_name":"\u5e02\u7b2c\u4e5d\u4e2d\u5b66","location_id":"6778","lat":"30.8811","long":"117.7442","pm25":""},{"location_name":"\u5e02\u7b2c\u56db\u4e2d\u5b66","location_id":"6779","lat":"30.9414","long":"117.8178","pm25":""},{"location_name":"\u5e02\u7ecf\u6d4e\u5f00\u53d1\u533a","location_id":"6780","lat":"25.0492","long":"101.538","pm25":""},{"location_name":"\u5e02\u7f50\u5934\u5382","location_id":"6781","lat":"27.2537","long":"111.4503","pm25":""},{"location_name":"\u5e02\u804c\u4e2d","location_id":"6782","lat":"25.8226","long":"113.0116","pm25":""},{"location_name":"\u5e02\u804c\u6559\u57fa\u5730","location_id":"6783","lat":"30.9697","long":"117.8472","pm25":""},{"location_name":"\u5e02\u8fd0\u7ba1\u5904","location_id":"6784","lat":"33.5979","long":"114.6546","pm25":""},{"location_name":"\u5e02\u917f\u9152\u516c\u53f8","location_id":"6785","lat":"32.1342","long":"114.0681","pm25":""},{"location_name":"\u5e08\u4e13","location_id":"6786","lat":"27.2944","long":"105.31","pm25":""},{"location_name":"\u5e08\u5927","location_id":"6787","lat":"26.0392","long":"119.303","pm25":""},{"location_name":"\u5e08\u8303\u5b66\u9662","location_id":"6788","lat":"34.3617","long":"108.7233","pm25":""},{"location_name":"\u5e08\u8303\u6821","location_id":"6789","lat":"30.1142","long":"104.6469","pm25":""},{"location_name":"\u5e3d\u5cf0\u5c71\u68ee\u6797\u516c\u56ed","location_id":"6790","lat":"23.5538","long":"113.589","pm25":""},{"location_name":"\u5e72\u7530\u575d","location_id":"6791","lat":"27.72","long":"106.9178","pm25":""},{"location_name":"\u5e73\u5766","location_id":"6792","lat":"37.8694","long":"113.5689","pm25":""},{"location_name":"\u5e73\u5929\u6e56(\u5bf9\u7167\u70b9)","location_id":"6793","lat":"30.6539","long":"117.4974","pm25":""},{"location_name":"\u5e73\u5b89\u9ad8\u94c1\u65b0\u533a","location_id":"6794","lat":"36.5067","long":"102.0306","pm25":""},{"location_name":"\u5e73\u623f\u4e1c\u8f7b\u5382","location_id":"6795","lat":"45.61","long":"126.615","pm25":""},{"location_name":"\u5e73\u6714","location_id":"6796","lat":"39.3514","long":"112.44","pm25":""},{"location_name":"\u5e73\u6865\u5206\u5c40","location_id":"6797","lat":"32.1078","long":"114.1044","pm25":""},{"location_name":"\u5e73\u9876\u5c71\u5de5\u5b66\u9662","location_id":"6798","lat":"33.737","long":"113.182","pm25":""},{"location_name":"\u5e7f\u4e1c\u5546\u5b66\u9662","location_id":"6799","lat":"23.0916","long":"113.348","pm25":""},{"location_name":"\u5e7f\u7535\u5c40","location_id":"6800","lat":"33.5653","long":"114.0322","pm25":""},{"location_name":"\u5e7f\u7535\u82b1\u56ed","location_id":"6801","lat":"30.4551","long":"106.6388","pm25":""},{"location_name":"\u5e7f\u8fd0\u6f6d","location_id":"6802","lat":"34.3274","long":"109.043","pm25":""},{"location_name":"\u5e7f\u9675\u5efa\u8bbe\u5c40(\u542f\u7528180626)","location_id":"6803","lat":"32.3942","long":"119.4686","pm25":""},{"location_name":"\u5e7f\u96c5\u4e2d\u5b66","location_id":"6804","lat":"23.1422","long":"113.235","pm25":""},{"location_name":"\u5e90\u5c71\u6c14\u8c61\u53f0(\u5bf9\u7167\u70b9)","location_id":"6805","lat":"29.5867","long":"115.9936","pm25":""},{"location_name":"\u5e90\u9633\u533a","location_id":"6806","lat":"31.9438","long":"117.266","pm25":""},{"location_name":"\u5e99\u6c9f\u6751","location_id":"6807","lat":"34.3708","long":"107.1586","pm25":""},{"location_name":"\u5eb7\u6cfd\u82d1","location_id":"6808","lat":"39.5986","long":"109.7736","pm25":""},{"location_name":"\u5ef6\u5927\u533b\u9644\u9662","location_id":"6809","lat":"36.6028","long":"109.4761","pm25":""},{"location_name":"\u5ef6\u5b89\u8def89\u53f7","location_id":"6810","lat":"29.7128","long":"118.3057","pm25":""},{"location_name":"\u5ef6\u8fb9\u533b\u9662","location_id":"6811","lat":"42.9061","long":"129.5042","pm25":""},{"location_name":"\u5efa\u5b89\u5382","location_id":"6812","lat":"29.9899","long":"103.0013","pm25":""},{"location_name":"\u5efa\u5de5\u5b66\u6821","location_id":"6813","lat":"28.6869","long":"115.852","pm25":""},{"location_name":"\u5efa\u8bbe\u5927\u53a6","location_id":"6814","lat":"39.9419","long":"119.5369","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"6815","lat":"37.5639","long":"121.2514","pm25":""},{"location_name":"\u5f00\u53d1\u533a\u5b50\u7ad9","location_id":"6816","lat":"30.9431","long":"118.7175","pm25":""},{"location_name":"\u5f00\u53d1\u533a\u7ba1\u59d4\u4f1a","location_id":"6817","lat":"33.3947","long":"120.225","pm25":""},{"location_name":"\u5f04\u5f04\u576a","location_id":"6818","lat":"26.57098","long":"101.68912","pm25":""},{"location_name":"\u5f20\u5bb6\u6e2f\u5e02\u76d1\u6d4b\u7ad9","location_id":"6819","lat":"31.874","long":"120.526","pm25":""},{"location_name":"\u5f20\u6eaa","location_id":"6820","lat":"22.5497","long":"113.3881","pm25":""},{"location_name":"\u5f69\u5c6f","location_id":"6821","lat":"41.3047","long":"123.7308","pm25":""},{"location_name":"\u5f69\u9999","location_id":"6822","lat":"31.3019","long":"120.591","pm25":""},{"location_name":"\u5f71\u89c6\u57ce(\u5bf9\u7167\u70b9)","location_id":"6823","lat":"35.259","long":"113.1992","pm25":""},{"location_name":"\u5f90\u6c47\u4e0a\u5e08\u5927","location_id":"6824","lat":"31.1654","long":"121.412","pm25":""},{"location_name":"\u5fb7\u4ee4\u54c8\u5e02","location_id":"6825","lat":"37.3753","long":"97.3731","pm25":""},{"location_name":"\u5fb7\u5b8f\u5dde\u76d1\u6d4b\u7ad9","location_id":"6826","lat":"24.428","long":"98.5842","pm25":""},{"location_name":"\u5fb7\u667a\u9ad8\u4e2d","location_id":"6827","lat":"23.1478","long":"109.5681","pm25":""},{"location_name":"\u5fb7\u6e90\u836f\u4e1a(\u76f4\u7ba1\u7ad9)","location_id":"6828","lat":"34.6972","long":"119.3581","pm25":""},{"location_name":"\u5fb7\u76db\u82d1","location_id":"6829","lat":"36.1912","long":"113.1569","pm25":""},{"location_name":"\u5fe0\u5e84","location_id":"6830","lat":"27.6486","long":"106.8906","pm25":""},{"location_name":"\u6000\u67d4\u9547","location_id":"6831","lat":"40.3937","long":"116.644","pm25":""},{"location_name":"\u60e0\u519c\u5357\u5927\u8857","location_id":"6832","lat":"39.2282","long":"106.7704","pm25":""},{"location_name":"\u60e0\u9633\u533a\u627f\u4fee\u8def\u8239\u6e56\u5b50\u7ad9","location_id":"6833","lat":"22.8172","long":"114.3244","pm25":""},{"location_name":"\u60e0\u9f99\u7269\u6d41","location_id":"6834","lat":"40.6288","long":"109.8654","pm25":""},{"location_name":"\u6148\u6e56\u4e8c\u5c0f","location_id":"6835","lat":"31.7506","long":"118.5106","pm25":""},{"location_name":"\u623f\u5bb6\u575d","location_id":"6836","lat":"31.955","long":"119.18","pm25":""},{"location_name":"\u6280\u5de5\u5b66\u6821","location_id":"6837","lat":"36.0714","long":"111.5028","pm25":""},{"location_name":"\u6280\u5e08\u5b66\u9662","location_id":"6838","lat":"23.63444","long":"113.0472","pm25":""},{"location_name":"\u62c9\u8428\u706b\u8f66\u7ad9","location_id":"6840","lat":"29.6292","long":"91.0834","pm25":""},{"location_name":"\u62db\u8fdc\u73af\u4fdd\u5c40","location_id":"6842","lat":"37.374","long":"120.399","pm25":""},{"location_name":"\u632f\u5b81\u82b1\u56ed","location_id":"6843","lat":"22.7875","long":"108.301","pm25":""},{"location_name":"\u6387\u5200","location_id":"6844","lat":"30.9892","long":"112.1969","pm25":""},{"location_name":"\u63a5\u5f85\u4e2d\u5fc3","location_id":"6845","lat":"38.9108","long":"115.4713","pm25":""},{"location_name":"\u6536\u8d39\u6240","location_id":"6846","lat":"43.768","long":"87.6046","pm25":""},{"location_name":"\u653f\u534f\u5927\u697c","location_id":"6847","lat":"24.4072","long":"111.5622","pm25":""},{"location_name":"\u6559\u5e08\u8fdb\u4fee\u5b66\u6821","location_id":"6848","lat":"31.17","long":"120.635","pm25":""},{"location_name":"\u6559\u80b2\u56ed\u533a","location_id":"6849","lat":"37.9648","long":"106.1532","pm25":""},{"location_name":"\u6559\u80b2\u5b66\u9662","location_id":"6850","lat":"40.0844","long":"113.2711","pm25":""},{"location_name":"\u6559\u80b2\u6e2f\uff0820181115\u542f\u7528\uff09","location_id":"6851","lat":"36.1058","long":"103.7583","pm25":""},{"location_name":"\u656c\u4ead\u5c71\u5b50\u7ad9","location_id":"6852","lat":"30.9742","long":"118.7386","pm25":""},{"location_name":"\u6587\u4f53\u4e2d\u5fc3","location_id":"6853","lat":"24.339","long":"102.5381","pm25":""},{"location_name":"\u6587\u5316\u4e2d\u5fc3","location_id":"6854","lat":"40.9733","long":"117.8184","pm25":""},{"location_name":"\u6587\u5316\u5e7f\u573a\u3000","location_id":"6855","lat":"44.5782","long":"129.6115","pm25":""},{"location_name":"\u6587\u5316\u8def","location_id":"6856","lat":"41.765","long":"123.41","pm25":""},{"location_name":"\u6587\u5316\u9986","location_id":"6857","lat":"34.5653","long":"105.8614","pm25":""},{"location_name":"\u6587\u660c\u5317\u8857","location_id":"6858","lat":"38.49494","long":"106.1024","pm25":""},{"location_name":"\u6587\u660e\u91cc(\u542f\u7528171012)","location_id":"6859","lat":"39.938","long":"119.5966","pm25":""},{"location_name":"\u6587\u7406\u5b66\u9662","location_id":"6860","lat":"34.3497","long":"107.2058","pm25":""},{"location_name":"\u6587\u767b\u5e02\u4e1d\u7ef8\u516c\u53f8","location_id":"6861","lat":"37.187","long":"122.019","pm25":""},{"location_name":"\u6587\u767b\u5e02\u73af\u4fdd\u5c40","location_id":"6862","lat":"37.197","long":"122.038","pm25":""},{"location_name":"\u6597\u95e8","location_id":"6863","lat":"22.2281","long":"113.299","pm25":""},{"location_name":"\u65af\u8fbe\u673a\u7535","location_id":"6864","lat":"47.2753","long":"130.261","pm25":""},{"location_name":"\u65b0\u5149\u6bdb\u7eba\u5382","location_id":"6865","lat":"34.9817","long":"118.2764","pm25":""},{"location_name":"\u65b0\u5174","location_id":"6866","lat":"23.5353","long":"116.3697","pm25":""},{"location_name":"\u65b0\u533a","location_id":"6867","lat":"40.715","long":"120.8478","pm25":""},{"location_name":"\u65b0\u533a\u4e8c\u6cf5\u7ad9","location_id":"6868","lat":"37.9723","long":"106.196","pm25":""},{"location_name":"\u65b0\u533a\u5170\u829d\u516c\u53f8","location_id":"6869","lat":"34.8731","long":"108.9589","pm25":""},{"location_name":"\u65b0\u533a\u529e\u4e8b\u5904","location_id":"6870","lat":"32.1883","long":"119.68","pm25":""},{"location_name":"\u65b0\u533a\u653f\u52a1\u4e2d\u5fc3","location_id":"6871","lat":"44.0297","long":"87.2717","pm25":""},{"location_name":"\u65b0\u533a\u7ba1\u59d4\u4f1a","location_id":"6872","lat":"34.9058","long":"108.9344","pm25":""},{"location_name":"\u65b0\u534e\u56ed","location_id":"6873","lat":"41.2553","long":"123.15","pm25":""},{"location_name":"\u65b0\u534e\u65c5\u9986","location_id":"6874","lat":"33.721","long":"113.322","pm25":""},{"location_name":"\u65b0\u534e\u8def","location_id":"6875","lat":"26.5697","long":"106.7164","pm25":""},{"location_name":"\u65b0\u57ce\u4e2d\u5b66","location_id":"6876","lat":"22.7925","long":"115.3622","pm25":""},{"location_name":"\u65b0\u57ce\u533a","location_id":"6877","lat":"34.2153","long":"117.256","pm25":""},{"location_name":"\u65b0\u5c71\u6751","location_id":"6878","lat":"29.4892","long":"106.468","pm25":""},{"location_name":"\u65b0\u5ddd\u82d1","location_id":"6879","lat":"38.5339","long":"102.1725","pm25":""},{"location_name":"\u65b0\u5e02\u5e9c","location_id":"6880","lat":"22.9169","long":"112.0392","pm25":""},{"location_name":"\u65b0\u5e02\u73af\u4fdd\u5c40","location_id":"6881","lat":"21.4661","long":"109.0981","pm25":""},{"location_name":"\u65b0\u5efa\u3000","location_id":"6882","lat":"45.8194","long":"130.8625","pm25":""},{"location_name":"\u65b0\u653f\u5e9c\u7247\u533a","location_id":"6884","lat":"43.895","long":"81.2867","pm25":""},{"location_name":"\u65b0\u751f\u8857\u9053","location_id":"6885","lat":"41.1042","long":"121.835","pm25":""},{"location_name":"\u65b0\u7586\u519c\u79d1\u9662\u519c\u573a","location_id":"6886","lat":"43.9469","long":"87.4754","pm25":""},{"location_name":"\u65b0\u76d1\u6d4b\u7ad9","location_id":"6887","lat":"28.2642","long":"117.0564","pm25":""},{"location_name":"\u65b0\u79c0\u8857","location_id":"6888","lat":"41.7089","long":"123.439","pm25":""},{"location_name":"\u65b0\u7acb\u5c6f","location_id":"6889","lat":"41.2692","long":"123.7989","pm25":""},{"location_name":"\u65b0\u94a2\u6c81\u56ed\u6751(20190301\u542f\u7528)","location_id":"6891","lat":"27.807","long":"114.9149","pm25":""},{"location_name":"\u65c5\u987a","location_id":"6892","lat":"38.808056","long":"121.25889","pm25":""},{"location_name":"\u65e5\u5580\u5219\u76d1\u6d4b\u7ad9","location_id":"6893","lat":"29.2718","long":"88.8876","pm25":""},{"location_name":"\u65e5\u5580\u5219\u9e3f\u8fbe\u516c\u53f8","location_id":"6894","lat":"29.2365","long":"88.8931","pm25":""},{"location_name":"\u65e5\u62a5\u793e","location_id":"6895","lat":"34.5004","long":"109.5049","pm25":""},{"location_name":"\u65fa\u5e84","location_id":"6896","lat":"31.5475","long":"120.354","pm25":""},{"location_name":"\u6606\u5c71\u5b9e\u9a8c\u5c0f\u5b66","location_id":"6897","lat":"31.388","long":"120.953","pm25":""},{"location_name":"\u660c\u5e73\u9547","location_id":"6898","lat":"40.1952","long":"116.23","pm25":""},{"location_name":"\u660c\u90fd\u5730\u533a\u660c\u90fd\u575d","location_id":"6899","lat":"31.1254","long":"97.1809","pm25":""},{"location_name":"\u660c\u90fd\u76d1\u6d4b\u7ad9","location_id":"6900","lat":"31.1278","long":"97.1804","pm25":""},{"location_name":"\u660e\u6c34\u5f00\u53d1\u533a","location_id":"6901","lat":"36.71","long":"117.541","pm25":""},{"location_name":"\u660e\u73e0\u5e7f\u573a","location_id":"6902","lat":"31.7848","long":"117.196","pm25":""},{"location_name":"\u660e\u8fbe\u65b0\u533a","location_id":"6903","lat":"41.0831","long":"123.0156","pm25":""},{"location_name":"\u661f\u6d77\u4e09\u7ad9","location_id":"6904","lat":"38.885","long":"121.56389","pm25":""},{"location_name":"\u661f\u6e56\u82b1\u56ed","location_id":"6905","lat":"31.93","long":"120.94","pm25":""},{"location_name":"\u6625\u534e\u8def","location_id":"6906","lat":"29.3411","long":"104.7692","pm25":""},{"location_name":"\u662d\u5c71","location_id":"6907","lat":"27.9153","long":"113.0048","pm25":""},{"location_name":"\u664b\u6e90","location_id":"6908","lat":"37.7124","long":"112.469","pm25":""},{"location_name":"\u666e\u6d31\u7b2c\u4e8c\u4e2d\u5b66","location_id":"6909","lat":"22.8322","long":"100.9817","pm25":""},{"location_name":"\u666e\u9640","location_id":"6910","lat":"31.238","long":"121.4","pm25":""},{"location_name":"\u666e\u9640\u4e1c\u6e2f","location_id":"6911","lat":"29.9558","long":"122.3094","pm25":""},{"location_name":"\u666f\u6d2a\u5e02\u6c5f\u5317","location_id":"6912","lat":"22.0225","long":"100.8017","pm25":""},{"location_name":"\u666f\u6d2a\u5e02\u6c5f\u5357","location_id":"6913","lat":"22.0019","long":"100.7939","pm25":""},{"location_name":"\u66f2\u6c5f\u6587\u5316\u4ea7\u4e1a\u96c6\u56e2","location_id":"6914","lat":"34.1978","long":"108.985","pm25":""},{"location_name":"\u66f2\u6c5f\u76d1\u6d4b\u7ad9","location_id":"6915","lat":"24.686361","long":"113.597084","pm25":""},{"location_name":"\u66f9\u5f20","location_id":"6916","lat":"31.56","long":"120.294","pm25":""},{"location_name":"\u6714\u552f","location_id":"6917","lat":"39.3606","long":"112.4549","pm25":""},{"location_name":"\u671b\u82b1\u533a","location_id":"6918","lat":"41.8469","long":"123.81","pm25":""},{"location_name":"\u671d\u6656\u4e94\u533a","location_id":"6919","lat":"30.2897","long":"120.157","pm25":""},{"location_name":"\u671d\u9633\u5382","location_id":"6920","lat":"31.7797","long":"116.5068","pm25":""},{"location_name":"\u671d\u9633\u5ddd\u9547\u533b\u9662","location_id":"6921","lat":"42.8775","long":"129.3675","pm25":""},{"location_name":"\u672a\u592e\u8def","location_id":"6922","lat":"29.3547","long":"110.5594","pm25":""},{"location_name":"\u673a\u5e8a\u4e8c\u5382","location_id":"6923","lat":"36.6489","long":"116.943","pm25":""},{"location_name":"\u673a\u7535\u5b66\u6821","location_id":"6925","lat":"28.6064","long":"115.9083","pm25":""},{"location_name":"\u673a\u8f66\u5de5\u5382","location_id":"6926","lat":"44.6104","long":"129.6459","pm25":""},{"location_name":"\u674e\u6ca7\u533a\u5b50\u7ad9","location_id":"6927","lat":"36.1851","long":"120.3905","pm25":""},{"location_name":"\u6765\u51b6\u62db\u5f85\u6240","location_id":"6928","lat":"23.7369","long":"109.2317","pm25":""},{"location_name":"\u6765\u5bbe\u4e8c\u4e2d","location_id":"6929","lat":"23.7208","long":"109.2131","pm25":""},{"location_name":"\u6768\u6865\u897f\u8def","location_id":"6930","lat":"26.0797","long":"119.268","pm25":""},{"location_name":"\u6768\u6d66\u56db\u6f02","location_id":"6931","lat":"31.2659","long":"121.536","pm25":""},{"location_name":"\u677e\u5317\u5546\u5927","location_id":"6932","lat":"45.8167","long":"126.561","pm25":""},{"location_name":"\u677e\u5c71\u4e00\u4e2d","location_id":"6933","lat":"42.2814","long":"118.9233","pm25":""},{"location_name":"\u677f\u5858","location_id":"6934","lat":"27.8614","long":"112.9433","pm25":""},{"location_name":"\u6797\u79d1\u6240","location_id":"6935","lat":"28.7442","long":"115.813","pm25":""},{"location_name":"\u6797\u7ba1\u5c40","location_id":"6936","lat":"47.7317","long":"128.9094","pm25":""},{"location_name":"\u6797\u829d\u4eba\u6c11\u533b\u9662","location_id":"6937","lat":"29.6632","long":"94.3616","pm25":""},{"location_name":"\u6797\u829d\u76d1\u6d4b\u7ad9","location_id":"6938","lat":"29.6376","long":"94.3681","pm25":""},{"location_name":"\u679c\u6811\u573a","location_id":"6939","lat":"40.1097","long":"113.3819","pm25":""},{"location_name":"\u67a3\u56ed","location_id":"6940","lat":"36.6275","long":"109.4131","pm25":""},{"location_name":"\u67f3\u4e1c\u5c0f\u5b66","location_id":"6941","lat":"24.3898","long":"109.4883","pm25":""},{"location_name":"\u6811\u4e0b\u738b\u7ad9","location_id":"6942","lat":"30.0033","long":"120.7789","pm25":""},{"location_name":"\u682a\u51b6\u533b\u9662","location_id":"6943","lat":"27.8867","long":"113.095","pm25":""},{"location_name":"\u6843\u56ed","location_id":"6944","lat":"37.8692","long":"112.5369","pm25":""},{"location_name":"\u6843\u56ed\u8def","location_id":"6945","lat":"34.2911","long":"117.244","pm25":""},{"location_name":"\u6850\u6728\u5cad","location_id":"6946","lat":"26.3003","long":"106.805","pm25":""},{"location_name":"\u6850\u6e90\u515a\u6eaa","location_id":"6947","lat":"28.0797","long":"116.2239","pm25":""},{"location_name":"\u6863\u6848\u5c40","location_id":"6948","lat":"23.6706","long":"116.6447","pm25":""},{"location_name":"\u6881\u56ed\u533a\u6863\u6848\u5c40(20190220\u542f\u7528)","location_id":"6949","lat":"34.445","long":"115.6125","pm25":""},{"location_name":"\u6885\u53bf\u65b0\u57ce","location_id":"6950","lat":"24.2719","long":"116.0797","pm25":""},{"location_name":"\u6885\u6c99","location_id":"6951","lat":"22.5978","long":"114.297","pm25":""},{"location_name":"\u68c9\u7814\u6240","location_id":"6952","lat":"36.061","long":"114.483","pm25":""},{"location_name":"\u68c9\u7eba\u5382","location_id":"6953","lat":"41.7192","long":"86.2022","pm25":""},{"location_name":"\u68ee\u6797\u516c\u56ed","location_id":"6954","lat":"29.8181","long":"114.3036","pm25":""},{"location_name":"\u68ee\u6797\u8def","location_id":"6955","lat":"41.9339","long":"123.6836","pm25":""},{"location_name":"\u695a\u5dde\u533a\u76d1\u6d4b\u7ad9","location_id":"6956","lat":"33.5039","long":"119.135","pm25":""},{"location_name":"\u6986\u4e2d\u5170\u5927\u6821\u533a(\u5bf9\u7167\u70b9)","location_id":"6957","lat":"35.94","long":"104.148","pm25":""},{"location_name":"\u6986\u6b21\u4e09\u4e2d","location_id":"6958","lat":"37.682777","long":"112.719444","pm25":""},{"location_name":"\u6986\u6b21\u533a\u653f\u5e9c","location_id":"6959","lat":"37.7087","long":"112.7105","pm25":""},{"location_name":"\u69df\u6994\u6c34\u4e1a(\u5bf9\u7167\u70b9)","location_id":"6960","lat":"27.8036","long":"114.3442","pm25":""},{"location_name":"\u6a0a\u57ce\u65b0\u534e\u8def","location_id":"6961","lat":"32.0564","long":"112.1392","pm25":""},{"location_name":"\u6a80\u6728\u6797\u4f53\u80b2\u9986","location_id":"6962","lat":"29.36028","long":"104.7778","pm25":""},{"location_name":"\u6b47\u53f0\u5b50(\u542f\u7528161118)","location_id":"6963","lat":"29.53675","long":"106.4959","pm25":""},{"location_name":"\u6b66\u529f\u5c71\u6c14\u8c61\u7ad9","location_id":"6964","lat":"27.4948","long":"114.0944","pm25":""},{"location_name":"\u6b66\u5f53\u5c71","location_id":"6965","lat":"32.395","long":"111.0419","pm25":""},{"location_name":"\u6b66\u660c\u7d2b\u9633","location_id":"6966","lat":"30.5494","long":"114.3006","pm25":""},{"location_name":"\u6b66\u672f\u5b66\u6821","location_id":"6967","lat":"28.7994","long":"115.742","pm25":""},{"location_name":"\u6b66\u8b66\u652f\u961f","location_id":"6968","lat":"29.1128","long":"119.6533","pm25":""},{"location_name":"\u6b66\u8fdb\u76d1\u6d4b\u7ad9","location_id":"6969","lat":"31.7039","long":"119.935","pm25":""},{"location_name":"\u6b66\u9675\u533a\u6c38\u5b89(\u542f\u7528171130)","location_id":"6970","lat":"29.0289","long":"111.7153","pm25":""},{"location_name":"\u6b66\u9675\u533a\u957f\u5e9a","location_id":"6971","lat":"29.0531","long":"111.6625","pm25":""},{"location_name":"\u6c11\u4e2d","location_id":"6972","lat":"26.5894","long":"104.8475","pm25":""},{"location_name":"\u6c11\u4e3b\u6865","location_id":"6973","lat":"40.1194","long":"124.3678","pm25":""},{"location_name":"\u6c11\u65cf\u5927\u9053182\u53f7","location_id":"6974","lat":"30.4908","long":"114.3877","pm25":""},{"location_name":"\u6c14\u8c61\u53f0","location_id":"6975","lat":"25.8481","long":"114.9461","pm25":""},{"location_name":"\u6c14\u8c61\u5c40","location_id":"6976","lat":"39.7711","long":"98.2908","pm25":""},{"location_name":"\u6c14\u8c61\u5c40\u3000","location_id":"6977","lat":"45.2978","long":"130.9298","pm25":""},{"location_name":"\u6c14\u8c61\u7ad9","location_id":"6978","lat":"36.6377","long":"117.9544","pm25":""},{"location_name":"\u6c14\u8c61\u7ad9(\u5bf9\u7167\u70b9)","location_id":"6979","lat":"34.3956","long":"108.7197","pm25":""},{"location_name":"\u6c34\u4e0a\u4e50\u56ed","location_id":"6980","lat":"42.2953","long":"123.8831","pm25":""},{"location_name":"\u6c34\u4e61\u8def(\u76f4\u7ba1\u7ad9)","location_id":"6981","lat":"38.44139","long":"106.2275","pm25":""},{"location_name":"\u6c34\u5229\u5c40","location_id":"6982","lat":"33.581","long":"114.014","pm25":""},{"location_name":"\u6c34\u6865\u5b50","location_id":"6983","lat":"30.0475","long":"101.9603","pm25":""},{"location_name":"\u6c34\u94a2","location_id":"6985","lat":"26.5939","long":"104.89","pm25":""},{"location_name":"\u6c38\u5b9a\u65b0\u533a","location_id":"6986","lat":"29.1389","long":"110.48","pm25":""},{"location_name":"\u6c38\u5dde\u5e02\u73af\u4fdd\u5c40","location_id":"6987","lat":"26.4364","long":"111.5992","pm25":""},{"location_name":"\u6c38\u660e\u8def","location_id":"6988","lat":"38.8394","long":"117.457","pm25":""},{"location_name":"\u6c47\u5de5\u8857\u897f","location_id":"6989","lat":"42.3022","long":"123.8139","pm25":""},{"location_name":"\u6c49\u5317\u8def","location_id":"6990","lat":"39.1587","long":"117.764","pm25":""},{"location_name":"\u6c49\u53e3\u6c5f\u6ee9","location_id":"6991","lat":"30.5947","long":"114.3008","pm25":""},{"location_name":"\u6c49\u53e3\u82b1\u6865","location_id":"6992","lat":"30.6197","long":"114.2836","pm25":""},{"location_name":"\u6c49\u5ddd\u673a\u5e8a\u5382\u5b50\u6821","location_id":"6993","lat":"33.1842","long":"106.9893","pm25":""},{"location_name":"\u6c49\u6ee8\u533a\u68c0\u5bdf\u9662","location_id":"6994","lat":"32.6975","long":"109.0072","pm25":""},{"location_name":"\u6c49\u738b\u9547\u56fa\u6c34\u5b50","location_id":"6995","lat":"33.3261","long":"105.0822","pm25":""},{"location_name":"\u6c49\u753b\u9986","location_id":"6996","lat":"32.9735","long":"112.5003","pm25":""},{"location_name":"\u6c49\u9633\u6708\u6e56","location_id":"6997","lat":"30.5514","long":"114.2511","pm25":""},{"location_name":"\u6c5f\u4e1c","location_id":"6998","lat":"29.305","long":"120.091","pm25":""},{"location_name":"\u6c5f\u5317","location_id":"6999","lat":"45.1642","long":"124.8528","pm25":""},{"location_name":"\u6c5f\u5317\u4e91\u5c71\u897f\u8def\u5b50\u7ad9","location_id":"7000","lat":"23.1142","long":"114.4103","pm25":""},{"location_name":"\u6c5f\u5357","location_id":"7001","lat":"45.0878","long":"124.8292","pm25":""},{"location_name":"\u6c5f\u5357\u516c\u56ed","location_id":"7002","lat":"43.8256","long":"126.55","pm25":""},{"location_name":"\u6c5f\u5357\u5b50\u7ad9\u3000","location_id":"7003","lat":"23.0672","long":"109.6042","pm25":""},{"location_name":"\u6c5f\u6e7e\u4e1c\u8def","location_id":"7004","lat":"40.0625","long":"124.3303","pm25":""},{"location_name":"\u6c5f\u9e93","location_id":"7005","lat":"27.8728","long":"112.8937","pm25":""},{"location_name":"\u6c60\u5dde\u5b66\u9662","location_id":"7006","lat":"30.6617","long":"117.4697","pm25":""},{"location_name":"\u6c61\u6c34\u5904\u7406\u5382","location_id":"7007","lat":"42.8953","long":"125.1567","pm25":""},{"location_name":"\u6c64\u65fa\u6cb3\u56fd\u5bb6\u516c\u56ed","location_id":"7008","lat":"48.4658","long":"129.4942","pm25":""},{"location_name":"\u6c74\u4eac\u516c\u56ed(20190322\u542f\u7528)","location_id":"7009","lat":"34.7964","long":"114.3644","pm25":""},{"location_name":"\u6c82\u6cb3\u5c0f\u533a","location_id":"7010","lat":"35.0573","long":"118.3418","pm25":""},{"location_name":"\u6c88\u5bb6\u8425","location_id":"7011","lat":"30.2352","long":"115.0625","pm25":""},{"location_name":"\u6c88\u629a\u65b0\u57ce","location_id":"7012","lat":"41.8417","long":"123.7117","pm25":""},{"location_name":"\u6c88\u8fbd\u897f\u8def","location_id":"7013","lat":"41.7347","long":"123.2444","pm25":""},{"location_name":"\u6c89\u6e56\u4e03\u58d5","location_id":"7014","lat":"30.2997","long":"113.8531","pm25":""},{"location_name":"\u6c8c\u53e3\u65b0\u533a","location_id":"7015","lat":"30.4753","long":"114.1525","pm25":""},{"location_name":"\u6c99\u4e07","location_id":"7016","lat":"21.6158","long":"108.3411","pm25":""},{"location_name":"\u6c99\u4e95\u9547\u8857\u9053\u529e","location_id":"7017","lat":"22.7833","long":"108.244","pm25":""},{"location_name":"\u6c99\u5761\u5934\u6d88\u9632\u7ad9","location_id":"7018","lat":"37.4514","long":"105.0197","pm25":""},{"location_name":"\u6c99\u576a","location_id":"7019","lat":"28.3586","long":"112.9958","pm25":""},{"location_name":"\u6c99\u6cb3\u94fa","location_id":"7021","lat":"30.63","long":"104.11139","pm25":""},{"location_name":"\u6c99\u6e56\u65c5\u6e38\u533a","location_id":"7022","lat":"38.817","long":"106.3394","pm25":""},{"location_name":"\u6ca7\u53bf\u57ce\u5efa\u5c40","location_id":"7023","lat":"38.2991","long":"116.8854","pm25":""},{"location_name":"\u6cb3\u4e1c\u4fdd\u9669\u516c\u53f8","location_id":"7024","lat":"35.0896","long":"118.4023","pm25":""},{"location_name":"\u6cb3\u4e1c\u5b50\u7ad9","location_id":"7025","lat":"18.2489","long":"109.5078","pm25":""},{"location_name":"\u6cb3\u5317\u5de5\u4e1a\u5927\u5b66","location_id":"7026","lat":"39.5453","long":"116.7022","pm25":""},{"location_name":"\u6cb3\u533b\u5927","location_id":"7027","lat":"34.7538","long":"113.6356","pm25":""},{"location_name":"\u6cb3\u5357\u5cb8\u91d1\u5c71\u6e56\u5b50\u7ad9","location_id":"7028","lat":"23.0528","long":"114.4183","pm25":""},{"location_name":"\u6cb3\u5357\u6797\u6821","location_id":"7029","lat":"34.6869","long":"112.4831","pm25":""},{"location_name":"\u6cb3\u7554\u5c0f\u533a","location_id":"7030","lat":"41.5672","long":"120.4486","pm25":""},{"location_name":"\u6cb3\u897f\u4e00\u7ecf\u8def(\u542f\u7528150702)","location_id":"7031","lat":"39.2474","long":"117.7918","pm25":""},{"location_name":"\u6cb3\u897f\u5730\u7a0e\u5c40","location_id":"7032","lat":"27.5444","long":"109.9453","pm25":""},{"location_name":"\u6cb3\u897f\u5b50\u7ad9","location_id":"7033","lat":"18.2681","long":"109.4964","pm25":""},{"location_name":"\u6cb3\u897f\u6c34\u5382","location_id":"7034","lat":"24.3406","long":"109.3886","pm25":""},{"location_name":"\u6cb3\u95e8\u53e3","location_id":"7035","lat":"26.5928","long":"101.5769","pm25":""},{"location_name":"\u6cb9\u7530\u7269\u63a2\u516c\u53f8","location_id":"7036","lat":"35.767","long":"115.0772","pm25":""},{"location_name":"\u6cb9\u7530\u8fd0\u8f93\u516c\u53f8","location_id":"7037","lat":"35.7672","long":"115.0628","pm25":""},{"location_name":"\u6cf8\u6c34\u4e00\u4e2d","location_id":"7038","lat":"25.8417","long":"98.8546","pm25":""},{"location_name":"\u6cfd\u5dde\u4e00\u4e2d","location_id":"7039","lat":"35.4813","long":"112.8252","pm25":""},{"location_name":"\u6d0b\u6eaa","location_id":"7040","lat":"26.3108","long":"117.7275","pm25":""},{"location_name":"\u6d25\u5934\u57d4","location_id":"7041","lat":"24.8978","long":"118.5972","pm25":""},{"location_name":"\u6d25\u6cbd\u8def(\u542f\u7528150702)","location_id":"7042","lat":"38.9846","long":"117.3747","pm25":""},{"location_name":"\u6d2a\u6587","location_id":"7043","lat":"24.476667","long":"118.15139","pm25":""},{"location_name":"\u6d2a\u6e56","location_id":"7044","lat":"22.5625","long":"114.117","pm25":""},{"location_name":"\u6d2e\u5317\u533a\u73af\u4fdd\u5c40","location_id":"7045","lat":"45.6289","long":"122.8444","pm25":""},{"location_name":"\u6d4e\u5357\u5316\u5de5\u5382","location_id":"7046","lat":"36.6872","long":"116.989","pm25":""},{"location_name":"\u6d4e\u6c11\u533b\u9662(\u5bf9\u7167\u70b9)","location_id":"7047","lat":"31.3839","long":"118.4022","pm25":""},{"location_name":"\u6d51\u5357\u4e1c\u8def","location_id":"7049","lat":"41.7561","long":"123.535","pm25":""},{"location_name":"\u6d59\u6c5f\u519c\u5927","location_id":"7050","lat":"30.2692","long":"120.19","pm25":""},{"location_name":"\u6d66\u4e1c\u5ddd\u6c99","location_id":"7051","lat":"31.1907","long":"121.703","pm25":""},{"location_name":"\u6d66\u4e1c\u5f20\u6c5f","location_id":"7052","lat":"31.2071","long":"121.577","pm25":""},{"location_name":"\u6d66\u4e1c\u65b0\u533a\u76d1\u6d4b\u7ad9","location_id":"7053","lat":"31.2284","long":"121.533","pm25":""},{"location_name":"\u6d66\u53e3","location_id":"7054","lat":"32.0878","long":"118.626","pm25":""},{"location_name":"\u6d77\u5357\u5927\u5b66","location_id":"7055","lat":"20.0574","long":"110.3232","pm25":""},{"location_name":"\u6d77\u5357\u5e08\u8303\u5927\u5b66","location_id":"7056","lat":"19.9969","long":"110.338","pm25":""},{"location_name":"\u6d77\u664f\u53bf\u897f\u6d77\u9547","location_id":"7057","lat":"36.9639","long":"100.9048","pm25":""},{"location_name":"\u6d77\u6dc0\u533a\u4e07\u67f3","location_id":"7058","lat":"39.9934","long":"116.315","pm25":""},{"location_name":"\u6d77\u6ee9\u516c\u56ed","location_id":"7059","lat":"21.4086","long":"109.1436","pm25":""},{"location_name":"\u6d77\u865e\u5b50\u7ad9","location_id":"7060","lat":"31.67","long":"120.758","pm25":""},{"location_name":"\u6d77\u95e8\u5e02\u76d1\u6d4b\u7ad9","location_id":"7061","lat":"31.896","long":"121.173","pm25":""},{"location_name":"\u6d82\u5c71\u8857","location_id":"7062","lat":"24.9117","long":"118.5819","pm25":""},{"location_name":"\u6d88\u9632\u6307\u6325\u4e2d\u5fc3","location_id":"7063","lat":"31.955","long":"119.146","pm25":""},{"location_name":"\u6d9f\u94a2","location_id":"7064","lat":"27.7569","long":"111.9561","pm25":""},{"location_name":"\u6db5\u6c5f\u533a\u516d\u4e2d","location_id":"7065","lat":"25.4556","long":"119.1117","pm25":""},{"location_name":"\u6dee\u4e0a\u533a\u653f\u5e9c","location_id":"7066","lat":"32.9673","long":"117.3536","pm25":""},{"location_name":"\u6dee\u5854","location_id":"7067","lat":"34.2417","long":"117.192","pm25":""},{"location_name":"\u6dee\u6cb3\u9053","location_id":"7068","lat":"39.2133","long":"117.1837","pm25":""},{"location_name":"\u6dee\u9634\u533a\u76d1\u6d4b\u7ad9","location_id":"7069","lat":"33.6297","long":"119.0186","pm25":""},{"location_name":"\u6df1\u6c9f\u5bfa","location_id":"7070","lat":"41.1196","long":"123.044","pm25":""},{"location_name":"\u6e05\u534e\u7ad9","location_id":"7071","lat":"36.1542","long":"113.1097","pm25":""},{"location_name":"\u6e05\u6cb3\u5c0f\u5b66","location_id":"7072","lat":"30.7946","long":"120.744","pm25":""},{"location_name":"\u6e05\u6e90\u5c71","location_id":"7073","lat":"24.9617","long":"118.6108","pm25":""},{"location_name":"\u6e14\u6e56","location_id":"7074","lat":"23.5292","long":"116.4094","pm25":""},{"location_name":"\u6e2f\u52a1\u5c40","location_id":"7075","lat":"35.3962","long":"119.54","pm25":""},{"location_name":"\u6e2f\u533a\u4e00\u5c0f","location_id":"7076","lat":"21.7431","long":"108.5989","pm25":""},{"location_name":"\u6e38\u6cf3\u9986","location_id":"7077","lat":"38.8632","long":"115.493","pm25":""},{"location_name":"\u6e56\u4e1c\u8def\u56db\u5c0f","location_id":"7078","lat":"31.6861","long":"118.5058","pm25":""},{"location_name":"\u6e56\u5317\u6c11\u9662","location_id":"7079","lat":"30.2989","long":"109.5039","pm25":""},{"location_name":"\u6e56\u5357\u4e2d\u533b\u836f\u5927\u5b66","location_id":"7080","lat":"28.1308","long":"112.8908","pm25":""},{"location_name":"\u6e56\u5357\u5e08\u8303\u5927\u5b66","location_id":"7081","lat":"28.19","long":"112.9394","pm25":""},{"location_name":"\u6e56\u91cc\u4e2d\u5b66","location_id":"7082","lat":"24.5058","long":"118.0936","pm25":""},{"location_name":"\u6e5b\u6c5f\u5f71\u5267\u9662","location_id":"7083","lat":"21.2706","long":"110.3539","pm25":""},{"location_name":"\u6e7e\u6881","location_id":"7084","lat":"23.0048","long":"113.134","pm25":""},{"location_name":"\u6e90\u897f","location_id":"7085","lat":"23.7569","long":"114.6778","pm25":""},{"location_name":"\u6ea7\u9633\u5e02\u4e1c\u95e8\u5b50\u7ad9","location_id":"7086","lat":"31.4","long":"119.46","pm25":""},{"location_name":"\u6eaa\u4e1c","location_id":"7087","lat":"24.818056","long":"118.156944","pm25":""},{"location_name":"\u6eaa\u6e56","location_id":"7088","lat":"41.3369","long":"123.7528","pm25":""},{"location_name":"\u6ee8\u6c5f","location_id":"7089","lat":"30.21","long":"120.211","pm25":""},{"location_name":"\u6ee8\u6c5f\u4e2d\u5b66","location_id":"7090","lat":"33.38257","long":"104.93389","pm25":""},{"location_name":"\u6ee8\u6cb3\u65b0\u6751","location_id":"7091","lat":"32.6494","long":"110.78","pm25":""},{"location_name":"\u6ee8\u6cb3\u8def","location_id":"7092","lat":"41.2736","long":"123.1761","pm25":""},{"location_name":"\u6ee8\u6e56\u65b0\u533a","location_id":"7093","lat":"31.7386","long":"117.278","pm25":""},{"location_name":"\u6f06\u5858","location_id":"7094","lat":"31.5031","long":"120.242","pm25":""},{"location_name":"\u6f2f\u6cb3\u5927\u5b66","location_id":"7095","lat":"33.568","long":"114.005","pm25":""},{"location_name":"\u6f33\u5dde\u515a\u6821(20190503\u542f\u7528)","location_id":"7097","lat":"24.5183","long":"114.6622","pm25":""},{"location_name":"\u6f4d\u574a\u4e03\u4e2d","location_id":"7098","lat":"36.7225","long":"119.0586","pm25":""},{"location_name":"\u6f58\u96c6\u533a\u653f\u5e9c","location_id":"7099","lat":"32.7639","long":"116.8028","pm25":""},{"location_name":"\u6f6e\u5357\u5b50\u7ad9","location_id":"7100","lat":"23.2536","long":"116.4019","pm25":""},{"location_name":"\u6f6e\u9633\u5b50\u7ad9","location_id":"7101","lat":"23.2539","long":"116.6092","pm25":""},{"location_name":"\u6f84\u6d77\u5b50\u7ad9","location_id":"7102","lat":"23.4714","long":"116.7519","pm25":""},{"location_name":"\u6fe0\u6c5f\u5b50\u7ad9","location_id":"7103","lat":"23.2775","long":"116.7258","pm25":""},{"location_name":"\u6fee\u6c34\u6cb3\u7ba1\u7406\u5904","location_id":"7104","lat":"35.76806","long":"115.0061","pm25":""},{"location_name":"\u706b\u70ac\u57ce","location_id":"7105","lat":"35.428","long":"116.6305","pm25":""},{"location_name":"\u706b\u8f66\u65b0\u7ad9","location_id":"7106","lat":"28.1944","long":"113.0014","pm25":""},{"location_name":"\u706b\u8f66\u7ad9","location_id":"7107","lat":"27.8381","long":"113.143","pm25":""},{"location_name":"\u7075\u5ca9\u5bfa","location_id":"7108","lat":"31.0283","long":"103.613","pm25":""},{"location_name":"\u70b3\u8349\u5c97","location_id":"7109","lat":"26.585","long":"101.7169","pm25":""},{"location_name":"\u70b9\u519b\u533a","location_id":"7110","lat":"30.696","long":"111.268","pm25":""},{"location_name":"\u70c8\u5c71\u533a\u653f\u5e9c","location_id":"7111","lat":"33.8997","long":"116.8067","pm25":""},{"location_name":"\u70df\u5382","location_id":"7112","lat":"34.7622","long":"113.6844","pm25":""},{"location_name":"\u70df\u5382\u529e\u516c\u533a","location_id":"7113","lat":"25.5364","long":"103.8","pm25":""},{"location_name":"\u7126\u5c97\u6e56\u98ce\u666f\u533a\u7ba1\u7406\u5904","location_id":"7114","lat":"32.625","long":"116.7039","pm25":""},{"location_name":"\u71d5\u5b50\u51b2","location_id":"7115","lat":"26.6343","long":"106.7487","pm25":""},{"location_name":"\u71d5\u5c71\u5b50\u7ad9","location_id":"7116","lat":"31.317","long":"119.438","pm25":""},{"location_name":"\u725b\u5c3e\u5cad\u6c34\u5e93","location_id":"7117","lat":"21.5958","long":"109.2256","pm25":""},{"location_name":"\u725b\u8033\u6865","location_id":"7118","lat":"29.5844","long":"103.7627","pm25":""},{"location_name":"\u725f\u5e73\u68c0\u5bdf\u9662","location_id":"7119","lat":"37.4014","long":"121.5992","pm25":""},{"location_name":"\u7267\u7f8a","location_id":"7120","lat":"22.9539","long":"112.0539","pm25":""},{"location_name":"\u7269\u8d44\u5c40","location_id":"7121","lat":"39.6407","long":"118.1853","pm25":""},{"location_name":"\u72ec\u5c71\u5b50\u533a","location_id":"7122","lat":"44.3336","long":"84.8983","pm25":""},{"location_name":"\u7384\u6b66\u6e56","location_id":"7123","lat":"32.0775","long":"118.795","pm25":""},{"location_name":"\u7389\u6811\u53bf\u7ed3\u53e4\u9547","location_id":"7124","lat":"33.0014","long":"97","pm25":""},{"location_name":"\u7389\u6eaa\u4e00\u4e2d","location_id":"7125","lat":"24.3702","long":"102.5389","pm25":""},{"location_name":"\u7389\u9f99\u65b0\u57ce","location_id":"7126","lat":"42.0486","long":"121.6592","pm25":""},{"location_name":"\u738b\u5c97\u4e2d\u5b66","location_id":"7127","lat":"29.3864","long":"117.3097","pm25":""},{"location_name":"\u738b\u76ca\u533a\u653f\u5e9c","location_id":"7128","lat":"35.0697","long":"109.0697","pm25":""},{"location_name":"\u738b\u8425","location_id":"7129","lat":"32.3292","long":"119.8767","pm25":""},{"location_name":"\u739b\u6c81\u53bf\u5927\u6b66\u9547","location_id":"7130","lat":"34.4714","long":"100.2561","pm25":""},{"location_name":"\u73af\u4fdd\u4e1c\u9662","location_id":"7131","lat":"35.303","long":"113.883","pm25":""},{"location_name":"\u73af\u4fdd\u5927\u697c","location_id":"7132","lat":"28.9404","long":"118.871","pm25":""},{"location_name":"\u73af\u4fdd\u5927\u697c\u3000","location_id":"7133","lat":"44.561","long":"129.61","pm25":""},{"location_name":"\u73af\u4fdd\u5c0f\u533a","location_id":"7134","lat":"24.4175","long":"111.5269","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"7135","lat":"50.4269","long":"124.1186","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"7136","lat":"32.9917","long":"112.5192","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u5b50\u7ad9","location_id":"7137","lat":"36.865","long":"120.537","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u5bbf\u820d","location_id":"7138","lat":"21.1997","long":"110.4019","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u65b0\u697c","location_id":"7139","lat":"38.8516","long":"105.724","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u7ad9","location_id":"7140","lat":"37.5002","long":"105.1971","pm25":""},{"location_name":"\u73af\u4fdd\u76d1\u6d4b\u7ad9","location_id":"7142","lat":"24.3304","long":"109.4108","pm25":""},{"location_name":"\u73af\u4fdd\u897f\u9662","location_id":"7143","lat":"35.31","long":"113.836","pm25":""},{"location_name":"\u73af\u5883\u76d1\u63a7\u4e2d\u5fc3","location_id":"7144","lat":"24.2654","long":"116.1248","pm25":""},{"location_name":"\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"7145","lat":"25.5035","long":"103.7897","pm25":""},{"location_name":"\u73af\u79d1\u9662","location_id":"7147","lat":"30.5103","long":"117.0549","pm25":""},{"location_name":"\u73e0\u6656\u533a\u73af\u4fdd\u5c40","location_id":"7148","lat":"26.8956","long":"112.6211","pm25":""},{"location_name":"\u7406\u5de5\u5b66\u9662","location_id":"7149","lat":"32.9689","long":"112.5481","pm25":""},{"location_name":"\u7425\u73c0\u5c71\u5e84","location_id":"7150","lat":"31.8706","long":"117.259","pm25":""},{"location_name":"\u745e\u91d1\u8def","location_id":"7151","lat":"32.0314","long":"118.803","pm25":""},{"location_name":"\u7476\u6d77\u533a","location_id":"7152","lat":"31.8585","long":"117.336","pm25":""},{"location_name":"\u74e6\u623f\u5e84","location_id":"7153","lat":"33.0122","long":"112.5224","pm25":""},{"location_name":"\u74ef\u6d77","location_id":"7154","lat":"28.0089","long":"120.634","pm25":""},{"location_name":"\u7518\u4e95\u5b50","location_id":"7155","lat":"38.97389","long":"121.611946","pm25":""},{"location_name":"\u7518\u6eaa\u6e2f","location_id":"7156","lat":"28.6428","long":"112.4067","pm25":""},{"location_name":"\u751f\u7269\u5236\u54c1\u6240","location_id":"7157","lat":"36.0725","long":"103.841","pm25":""},{"location_name":"\u7529\u6e7e\u5b50","location_id":"7158","lat":"43.55","long":"125.633","pm25":""},{"location_name":"\u7535\u4e1a\u5c40","location_id":"7159","lat":"29.1242","long":"110.4697","pm25":""},{"location_name":"\u7535\u529b\u5b66\u6821","location_id":"7160","lat":"36.1758","long":"117.1081","pm25":""},{"location_name":"\u7535\u529b\u5b66\u9662","location_id":"7161","lat":"43.8228","long":"126.4978","pm25":""},{"location_name":"\u7535\u5316\u5382","location_id":"7162","lat":"35.4039","long":"116.5546","pm25":""},{"location_name":"\u7535\u5b50\u79d1\u5927\u5c27\u5c71\u6821\u533a","location_id":"7163","lat":"25.3167","long":"110.4144","pm25":""},{"location_name":"\u7535\u673a\u5317\u5382","location_id":"7164","lat":"37.7575","long":"115.6951","pm25":""},{"location_name":"\u7535\u89c6\u53d1\u5c04\u53f0","location_id":"7165","lat":"27.725","long":"111.9975","pm25":""},{"location_name":"\u7535\u89c6\u53f0","location_id":"7166","lat":"41.1636","long":"80.2828","pm25":""},{"location_name":"\u7535\u89c6\u8f6c\u64ad\u7ad9","location_id":"7167","lat":"38.3254","long":"116.8584","pm25":""},{"location_name":"\u7559\u5b66\u751f\u521b\u4e1a\u56ed","location_id":"7168","lat":"32.4639","long":"119.888","pm25":""},{"location_name":"\u756a\u79ba\u4e2d\u5b66","location_id":"7169","lat":"22.9477","long":"113.352","pm25":""},{"location_name":"\u767d\u4e91\u5546\u8d38","location_id":"7170","lat":"35.4934","long":"112.835","pm25":""},{"location_name":"\u767d\u5e02\u9a7f","location_id":"7171","lat":"29.4822","long":"106.364","pm25":""},{"location_name":"\u767d\u78b1\u6ee9\u533a","location_id":"7172","lat":"45.6886","long":"85.1186","pm25":""},{"location_name":"\u767d\u7f8a\u5885","location_id":"7173","lat":"37.8531","long":"113.6292","pm25":""},{"location_name":"\u767d\u9152\u5382\u3000","location_id":"7174","lat":"45.2948","long":"131.0103","pm25":""},{"location_name":"\u767d\u9a6c\u5bfa","location_id":"7175","lat":"35.546","long":"112.8453","pm25":""},{"location_name":"\u767d\u9e64\u5c71","location_id":"7176","lat":"29.1456","long":"111.7158","pm25":""},{"location_name":"\u767d\u9f99\u5c97","location_id":"7177","lat":"30.698","long":"111.2992","pm25":""},{"location_name":"\u767e\u7c73\u5927\u9053","location_id":"7178","lat":"36.6106","long":"109.5056","pm25":""},{"location_name":"\u767e\u80a1\u8857\u9053","location_id":"7179","lat":"41.1219","long":"121.2008","pm25":""},{"location_name":"\u767e\u8349\u56ed","location_id":"7180","lat":"28.4569","long":"118.0058","pm25":""},{"location_name":"\u767e\u8d27\u5927\u697c","location_id":"7181","lat":"32.9444","long":"117.3575","pm25":""},{"location_name":"\u7696\u897f\u5b66\u9662","location_id":"7182","lat":"31.7618","long":"116.478","pm25":""},{"location_name":"\u76ca\u76ca\u4e73\u4e1a\u5de5\u4e1a\u56ed","location_id":"7183","lat":"32.646004","long":"117.04117","pm25":""},{"location_name":"\u76d0\u57ce\u7535\u5382","location_id":"7184","lat":"33.4022","long":"120.118","pm25":""},{"location_name":"\u76d0\u7530","location_id":"7185","lat":"22.5908","long":"114.263","pm25":""},{"location_name":"\u76d1\u63a7\u4e2d\u5fc3(20190222\u542f\u7528)","location_id":"7186","lat":"36.4978","long":"115.9819","pm25":""},{"location_name":"\u76d1\u6d4b\u5927\u697c","location_id":"7187","lat":"31.7371","long":"116.508","pm25":""},{"location_name":"\u76d1\u6d4b\u697c","location_id":"7188","lat":"33.6481","long":"116.9765","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"7189","lat":"32.3061","long":"118.3158","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9\u5927\u697c","location_id":"7190","lat":"28.4514","long":"119.914","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9\uff08\u539f\u7cae\u98df\u5c40\uff09","location_id":"7191","lat":"35.5714","long":"104.6228","pm25":""},{"location_name":"\u76d1\u7406\u7ad9","location_id":"7192","lat":"37.4489","long":"116.3189","pm25":""},{"location_name":"\u76df\u73af\u4fdd\u697c","location_id":"7193","lat":"38.843","long":"105.6975","pm25":""},{"location_name":"\u76f8\u57ce\u533a","location_id":"7194","lat":"31.3708","long":"120.641","pm25":""},{"location_name":"\u7701\u519c\u79d1\u9662","location_id":"7195","lat":"45.6842","long":"126.6206","pm25":""},{"location_name":"\u7701\u5916\u529e","location_id":"7196","lat":"28.6844","long":"115.893","pm25":""},{"location_name":"\u7701\u6797\u4e1a\u516c\u53f8","location_id":"7197","lat":"28.6839","long":"115.8886","pm25":""},{"location_name":"\u7701\u79cd\u5b50\u4ed3\u5e93","location_id":"7198","lat":"36.6868","long":"117.0684","pm25":""},{"location_name":"\u7701\u7ad9","location_id":"7199","lat":"28.6844","long":"115.931","pm25":""},{"location_name":"\u771f\u7a7a\u673a\u7535\u516c\u53f8","location_id":"7200","lat":"26.9056","long":"112.5664","pm25":""},{"location_name":"\u7766\u5c97\u5b50\u7ad9","location_id":"7202","lat":"23.0706","long":"112.427","pm25":""},{"location_name":"\u77f3\u5316\u4e00\u5c0f","location_id":"7203","lat":"31.0386","long":"112.2211","pm25":""},{"location_name":"\u77f3\u5316\u603b\u5382","location_id":"7204","lat":"29.7534","long":"116.0726","pm25":""},{"location_name":"\u77f3\u6eaa\u6d69","location_id":"7205","lat":"30.5797","long":"105.7519","pm25":""},{"location_name":"\u77f3\u9a6c\u4e2d\u5b66","location_id":"7206","lat":"28.8194","long":"104.5969","pm25":""},{"location_name":"\u77ff\u5c71\u8bbe\u8ba1\u9662","location_id":"7207","lat":"34.5911","long":"119.1478","pm25":""},{"location_name":"\u77ff\u9662","location_id":"7208","lat":"36.5776","long":"114.5035","pm25":""},{"location_name":"\u78a7\u4e91\u7a9d","location_id":"7209","lat":"26.4364","long":"106.6554","pm25":""},{"location_name":"\u78a7\u6e56\u5c71\u5e84","location_id":"7210","lat":"24.811195","long":"113.55939","pm25":""},{"location_name":"\u78a7\u9e21\u5e7f\u573a","location_id":"7211","lat":"25.0359","long":"102.638","pm25":""},{"location_name":"\u793c\u5609","location_id":"7212","lat":"29.6453","long":"106.562","pm25":""},{"location_name":"\u793e\u4f1a\u798f\u5229\u9662","location_id":"7213","lat":"31.89708","long":"121.1518","pm25":""},{"location_name":"\u798f\u5c71\u73af\u4fdd\u5c40","location_id":"7214","lat":"37.4967","long":"121.2611","pm25":""},{"location_name":"\u79b9\u90fd\u5f00\u53d1\u533a","location_id":"7215","lat":"35.0611","long":"111.0233","pm25":""},{"location_name":"\u79bb\u5bab","location_id":"7216","lat":"41.0112","long":"117.9384","pm25":""},{"location_name":"\u79c0\u5c7f\u533a\u653f\u5e9c","location_id":"7217","lat":"25.3214","long":"119.1015","pm25":""},{"location_name":"\u79c0\u82f1\u6d77\u5357\u533b\u9662","location_id":"7218","lat":"20.0053","long":"110.283","pm25":""},{"location_name":"\u79cb\u6797\u517b\u6b96\u57fa\u5730","location_id":"7219","lat":"40.916","long":"107.5936","pm25":""},{"location_name":"\u79d1\u521b\u4e2d\u5fc3","location_id":"7220","lat":"31.4189","long":"118.37","pm25":""},{"location_name":"\u79d1\u53f3\u524d\u65d7\u73af\u4fdd\u5c40","location_id":"7221","lat":"46.0756","long":"121.9462","pm25":""},{"location_name":"\u79d1\u5927","location_id":"7222","lat":"27.9119","long":"112.9074","pm25":""},{"location_name":"\u79d1\u59d4","location_id":"7223","lat":"38.9389","long":"100.4497","pm25":""},{"location_name":"\u79d1\u5e72\u6240","location_id":"7224","lat":"36.6114","long":"116.988","pm25":""},{"location_name":"\u79d1\u6559\u65b0\u57ce\u5b9e\u5c0f","location_id":"7225","lat":"31.422","long":"121.14","pm25":""},{"location_name":"\u7a7a\u6e2f","location_id":"7227","lat":"29.7125","long":"106.617","pm25":""},{"location_name":"\u7a7a\u6e2f\u65b0\u533a","location_id":"7228","lat":"35.1147","long":"111.0414","pm25":""},{"location_name":"\u7a91\u4e0a","location_id":"7229","lat":"26.5892","long":"104.8","pm25":""},{"location_name":"\u7af9\u56ed\u5c0f\u5b66","location_id":"7230","lat":"31.0483","long":"112.2014","pm25":""},{"location_name":"\u7af9\u56ed\u6c9f","location_id":"7231","lat":"34.3017","long":"107.0708","pm25":""},{"location_name":"\u7b14\u67b6\u5c71\u5317\u8def","location_id":"7232","lat":"30.1594","long":"115.0158","pm25":""},{"location_name":"\u7b2c\u4e00\u4e2d\u5b66","location_id":"7233","lat":"44.5462","long":"129.6386","pm25":""},{"location_name":"\u7b2c\u4e00\u5173","location_id":"7234","lat":"40.0181","long":"119.7624","pm25":""},{"location_name":"\u7b2c\u4e00\u533b\u9662","location_id":"7235","lat":"44.5952","long":"129.5902","pm25":""},{"location_name":"\u7b2c\u4e00\u5c0f\u5b66","location_id":"7236","lat":"34.7822","long":"111.19","pm25":""},{"location_name":"\u7b2c\u4e8c\u5b9e\u9a8c\u5c0f\u5b66","location_id":"7238","lat":"31.92","long":"120.302","pm25":""},{"location_name":"\u7b2c\u4e8c\u6c34\u5382","location_id":"7239","lat":"37.3617","long":"118.0018","pm25":""},{"location_name":"\u7b2c\u4e94\u6c34\u5382","location_id":"7240","lat":"36.6867","long":"101.524","pm25":""},{"location_name":"\u7b2c\u56db\u5927\u8857","location_id":"7241","lat":"39.0343","long":"117.707","pm25":""},{"location_name":"\u7ba1\u59d4\u4f1a(\u542f\u7528181220)","location_id":"7242","lat":"30.3122","long":"112.2747","pm25":""},{"location_name":"\u7c73\u4e1c\u533a\u73af\u4fdd\u5c40","location_id":"7243","lat":"43.962","long":"87.6444","pm25":""},{"location_name":"\u7cae\u8d38\u603b\u516c\u53f8","location_id":"7244","lat":"35.5236","long":"107.6406","pm25":""},{"location_name":"\u7cd6\u5382","location_id":"7246","lat":"40.8144","long":"111.608","pm25":""},{"location_name":"\u7d2b\u7405\u5b66\u9662","location_id":"7247","lat":"32.0417","long":"120.81","pm25":""},{"location_name":"\u7d2b\u9633","location_id":"7248","lat":"26.0753","long":"119.315","pm25":""},{"location_name":"\u7d2b\u9a6c\u5cad","location_id":"7249","lat":"22.5111","long":"113.4075","pm25":""},{"location_name":"\u7ea2\u536b\u8def","location_id":"7250","lat":"30.4519","long":"114.8858","pm25":""},{"location_name":"\u7ea2\u58f0\u5668\u6750\u5382","location_id":"7251","lat":"27.0658","long":"114.9817","pm25":""},{"location_name":"\u7ea2\u5c97\u533a","location_id":"7252","lat":"46.3991","long":"124.8847","pm25":""},{"location_name":"\u7ea2\u5e99\u8857","location_id":"7253","lat":"36.086","long":"114.32","pm25":""},{"location_name":"\u7ea2\u679c\u5b50\u9547\u60e0\u65b0\u8857","location_id":"7254","lat":"39.1292","long":"106.7096","pm25":""},{"location_name":"\u7ea2\u77f3\u5ce1\u68ee\u6797\u516c\u56ed(\u5bf9\u7167\u70b9)","location_id":"7255","lat":"38.3344","long":"109.7414","pm25":""},{"location_name":"\u7ea2\u8fb9\u95e8","location_id":"7256","lat":"26.6009","long":"106.7105","pm25":""},{"location_name":"\u7eba\u7ec7\u57ce","location_id":"7257","lat":"34.2572","long":"109.06","pm25":""},{"location_name":"\u7ecf\u5f00\u533a","location_id":"7258","lat":"34.3474","long":"108.935","pm25":""},{"location_name":"\u7ecf\u5f00\u533a(\u542f\u7528161026)","location_id":"7259","lat":"31.7694","long":"120.0469","pm25":""},{"location_name":"\u7ecf\u5f00\u533a\u73af\u4fdd\u5c40","location_id":"7260","lat":"28.2325","long":"113.0833","pm25":""},{"location_name":"\u7ecf\u5f00\u533a\u73af\u536b\u5904","location_id":"7261","lat":"43.8667","long":"125.417","pm25":""},{"location_name":"\u7ecf\u5f00\u533a\u7ba1\u59d4","location_id":"7262","lat":"34.7187","long":"113.727","pm25":""},{"location_name":"\u7ecf\u6d4e\u5f00\u53d1\u533a","location_id":"7263","lat":"41.7128","long":"86.2381","pm25":""},{"location_name":"\u7efc\u5408\u5de5\u4e1a\u56ed","location_id":"7264","lat":"29.6039","long":"115.9114","pm25":""},{"location_name":"\u7efc\u5408\u697c","location_id":"7265","lat":"39.8129","long":"110.0023","pm25":""},{"location_name":"\u7f19\u4e91\u5c71\uff08\u5bf9\u7167\u70b9\uff09","location_id":"7266","lat":"29.8272","long":"106.379","pm25":""},{"location_name":"\u7f8e\u5b81\u98df\u54c1\u516c\u53f8","location_id":"7267","lat":"30.475","long":"105.5956","pm25":""},{"location_name":"\u8001\u57ce","location_id":"7268","lat":"23.7233","long":"114.6892","pm25":""},{"location_name":"\u8001\u5e72\u90e8\u6d3b\u52a8\u4e2d\u5fc3","location_id":"7270","lat":"29.2958","long":"117.2111","pm25":""},{"location_name":"\u8001\u5e74\u5927\u5b66","location_id":"7271","lat":"32.3153","long":"118.3094","pm25":""},{"location_name":"\u8010\u706b\u6750\u6599\u5382","location_id":"7272","lat":"31.1108","long":"104.3539","pm25":""},{"location_name":"\u803f\u4e95\u6751","location_id":"7273","lat":"37.4442","long":"118.5857","pm25":""},{"location_name":"\u804a\u5927\u4e1c\u6821","location_id":"7274","lat":"36.4343","long":"116.0072","pm25":""},{"location_name":"\u804c\u4e1a\u4e2d\u5b66","location_id":"7275","lat":"31.858055","long":"106.76195","pm25":""},{"location_name":"\u804c\u4e1a\u6280\u672f\u5b66\u9662","location_id":"7276","lat":"33.9461","long":"116.7844","pm25":""},{"location_name":"\u804c\u5de5\u4e2d\u5fc3","location_id":"7277","lat":"30.4742","long":"114.9028","pm25":""},{"location_name":"\u804c\u5de5\u533b\u9662","location_id":"7278","lat":"36.0756","long":"103.712","pm25":""},{"location_name":"\u804c\u6559\u4e2d\u5fc3","location_id":"7279","lat":"32.215","long":"119.491","pm25":""},{"location_name":"\u805a\u82f1\u5b66\u6821","location_id":"7280","lat":"39.6719","long":"106.8219","pm25":""},{"location_name":"\u80bf\u7624\u533b\u9662","location_id":"7281","lat":"34.7781","long":"114.3389","pm25":""},{"location_name":"\u80dc\u534e\u65b0\u5236\u836f\u5382","location_id":"7282","lat":"46.0703","long":"122.0506","pm25":""},{"location_name":"\u80e1\u6c9f\u7ba1\u7406\u5904","location_id":"7283","lat":"34.7519","long":"119.3608","pm25":""},{"location_name":"\u80f6\u5dde\u4e00\u4e2d","location_id":"7284","lat":"36.253","long":"120.014","pm25":""},{"location_name":"\u80f6\u5efa\u94dd\u4e1a","location_id":"7286","lat":"43.6156","long":"122.3039","pm25":""},{"location_name":"\u80f6\u7247\u5382","location_id":"7287","lat":"38.8756","long":"115.442","pm25":""},{"location_name":"\u81ea\u6765\u6c34\u516c\u53f8","location_id":"7288","lat":"35.5051","long":"112.85","pm25":""},{"location_name":"\u81ea\u6765\u6c34\u516c\u53f8\u3000","location_id":"7289","lat":"45.305","long":"130.9817","pm25":""},{"location_name":"\u821f\u6c34\u6865","location_id":"7290","lat":"27.6506","long":"106.9231","pm25":""},{"location_name":"\u827a\u672f\u4e2d\u5fc3","location_id":"7291","lat":"41.1933","long":"80.2956","pm25":""},{"location_name":"\u827a\u672f\u804c\u4e1a\u5b66\u6821","location_id":"7292","lat":"43.6801","long":"122.2532","pm25":""},{"location_name":"\u827e\u9752\u8bd7\u6b4c\u9986","location_id":"7293","lat":"44.2967","long":"86.0497","pm25":""},{"location_name":"\u8292\u5e02\u5efa\u8bbe\u5c40","location_id":"7294","lat":"24.441","long":"98.578","pm25":""},{"location_name":"\u82b1\u6e56\u6e7e","location_id":"7295","lat":"29.5467","long":"103.7705","pm25":""},{"location_name":"\u82b1\u90fd\u5e08\u8303","location_id":"7296","lat":"23.3917","long":"113.215","pm25":""},{"location_name":"\u82cf\u5c71\u576a","location_id":"7297","lat":"31.87889","long":"106.75139","pm25":""},{"location_name":"\u82cf\u5dde\u5de5\u4e1a\u56ed\u533a","location_id":"7298","lat":"31.3097","long":"120.669","pm25":""},{"location_name":"\u82cf\u5dde\u65b0\u533a","location_id":"7299","lat":"31.2994","long":"120.543","pm25":""},{"location_name":"\u82d7\u5703","location_id":"7300","lat":"46.5888","long":"131.1572","pm25":""},{"location_name":"\u82f1\u534e\u5609\u56ed","location_id":"7301","lat":"22.735","long":"108.328","pm25":""},{"location_name":"\u8302\u77f3\u5316\u4e03\u5c0f","location_id":"7302","lat":"21.6533","long":"110.9294","pm25":""},{"location_name":"\u8305\u5c71\u5934","location_id":"7303","lat":"29.7048","long":"115.9581","pm25":""},{"location_name":"\u832b\u8361\u5c71","location_id":"7304","lat":"26.6761","long":"118.0966","pm25":""},{"location_name":"\u8336\u56ed","location_id":"7305","lat":"29.4892","long":"106.634","pm25":""},{"location_name":"\u8349\u573a\u95e8","location_id":"7306","lat":"32.0572","long":"118.749","pm25":""},{"location_name":"\u8349\u6ee9","location_id":"7307","lat":"34.378","long":"108.869","pm25":""},{"location_name":"\u8354\u57ce\u533a\u4ed3\u540e\u8def","location_id":"7308","lat":"25.442","long":"119.0156","pm25":""},{"location_name":"\u8363\u5df7","location_id":"7309","lat":"31.5631","long":"120.245","pm25":""},{"location_name":"\u8363\u6210\u5e02\u73af\u4fdd\u5c40\u529e\u516c\u697c","location_id":"7310","lat":"37.154","long":"122.471","pm25":""},{"location_name":"\u836f\u6750\u516c\u53f8","location_id":"7311","lat":"39.5178","long":"116.6838","pm25":""},{"location_name":"\u8377\u57ce\u5b50\u7ad9","location_id":"7312","lat":"23.1036","long":"109.5683","pm25":""},{"location_name":"\u8386\u7530\u56ed","location_id":"7313","lat":"36.8198","long":"118.3092","pm25":""},{"location_name":"\u8386\u7530\u5e02\u76d1\u6d4b\u7ad9","location_id":"7314","lat":"25.4552","long":"119.0018","pm25":""},{"location_name":"\u839e\u57ce\u68a8\u5ddd","location_id":"7315","lat":"23.06","long":"113.748055","pm25":""},{"location_name":"\u83b1\u5c71\u73af\u4fdd\u5c40","location_id":"7316","lat":"37.4822","long":"121.4478","pm25":""},{"location_name":"\u83b1\u5dde\u5916\u7ecf\u59d4","location_id":"7317","lat":"37.18","long":"119.959","pm25":""},{"location_name":"\u83b2\u82b1","location_id":"7319","lat":"32.4611","long":"119.9219","pm25":""},{"location_name":"\u83b2\u82b1\u5c71","location_id":"7320","lat":"30.1366","long":"104.6617","pm25":""},{"location_name":"\u83b2\u90fd\u5c0f\u5b66","location_id":"7321","lat":"28.4586","long":"119.93","pm25":""},{"location_name":"\u83cf\u6cfd\u5b66\u9662","location_id":"7322","lat":"35.27","long":"115.455","pm25":""},{"location_name":"\u83f1\u5858\u5b50\u7ad9","location_id":"7323","lat":"31.656","long":"120.734","pm25":""},{"location_name":"\u8428\u5c14\u56fe\u533a","location_id":"7324","lat":"46.5776","long":"125.1386","pm25":""},{"location_name":"\u8463\u94fa\u6c34\u5e93","location_id":"7325","lat":"31.9051","long":"117.16","pm25":""},{"location_name":"\u846b\u5934\u6c9f","location_id":"7326","lat":"45.8309","long":"130.9467","pm25":""},{"location_name":"\u8475\u6d8c","location_id":"7327","lat":"22.6342","long":"114.41","pm25":""},{"location_name":"\u84dd\u7530\u9547(\u542f\u7528160601)","location_id":"7328","lat":"24.506","long":"117.7116","pm25":""},{"location_name":"\u8521\u5bb6","location_id":"7331","lat":"29.709","long":"106.452","pm25":""},{"location_name":"\u859b\u57ce\u73af\u4fdd\u5c40","location_id":"7333","lat":"34.7837","long":"117.2852","pm25":""},{"location_name":"\u864e\u6eaa","location_id":"7334","lat":"29.5983","long":"106.296","pm25":""},{"location_name":"\u8679\u53e3","location_id":"7335","lat":"31.3008","long":"121.467","pm25":""},{"location_name":"\u8679\u6865","location_id":"7336","lat":"32.0005","long":"120.86","pm25":""},{"location_name":"\u8679\u6865\u90ae\u653f","location_id":"7337","lat":"31.92","long":"120.268","pm25":""},{"location_name":"\u868c\u57e0\u5b66\u9662","location_id":"7338","lat":"32.8913","long":"117.4186","pm25":""},{"location_name":"\u87c6\u9890\u89c2","location_id":"7339","lat":"30.0506","long":"103.8986","pm25":""},{"location_name":"\u8840\u9632\u7ad9","location_id":"7340","lat":"27.9639","long":"116.3598","pm25":""},{"location_name":"\u884c\u653f\u4e2d\u5fc3(\u542f\u7528161026)","location_id":"7341","lat":"31.8108","long":"119.9736","pm25":""},{"location_name":"\u8861\u9633\u5316\u5de5\u603b\u5382","location_id":"7342","lat":"26.9258","long":"112.6194","pm25":""},{"location_name":"\u8862\u5dde\u5b66\u9662","location_id":"7343","lat":"28.9745","long":"118.855","pm25":""},{"location_name":"\u8881\u5bb6\u754c","location_id":"7344","lat":"29.315","long":"110.4417","pm25":""},{"location_name":"\u888d\u6c5f\u7ad9","location_id":"7345","lat":"30.0911","long":"120.598","pm25":""},{"location_name":"\u88d5\u519c\u8def","location_id":"7346","lat":"41.9086","long":"123.5953","pm25":""},{"location_name":"\u8944\u57ce\u8fd0\u52a8\u8def","location_id":"7347","lat":"32.0197","long":"112.155","pm25":""},{"location_name":"\u8944\u5dde\u822a\u7a7a\u8def","location_id":"7348","lat":"32.0903","long":"112.2106","pm25":""},{"location_name":"\u897f\u4e61","location_id":"7349","lat":"22.5794","long":"113.891","pm25":""},{"location_name":"\u897f\u5317\u6c34\u6e90","location_id":"7350","lat":"38.1398","long":"114.5019","pm25":""},{"location_name":"\u897f\u533a","location_id":"7351","lat":"22.5811","long":"113.074","pm25":""},{"location_name":"\u897f\u5357\u90ca","location_id":"7352","lat":"26.8576","long":"100.2143","pm25":""},{"location_name":"\u897f\u5357\u9ad8\u6559","location_id":"7353","lat":"38.005833","long":"114.45861","pm25":""},{"location_name":"\u897f\u56db\u9053(\u542f\u7528170426)","location_id":"7354","lat":"39.1495","long":"117.3916","pm25":""},{"location_name":"\u897f\u56ed","location_id":"7355","lat":"29.7292","long":"115.988","pm25":""},{"location_name":"\u897f\u56ed\u8def","location_id":"7356","lat":"23.6714","long":"116.6339","pm25":""},{"location_name":"\u897f\u57ce\u9633\u5149\u73af\u4fdd\u516c\u53f8","location_id":"7357","lat":"37.4658","long":"118.5019","pm25":""},{"location_name":"\u897f\u5c0f\u533a","location_id":"7358","lat":"31.1333","long":"104.3883","pm25":""},{"location_name":"\u897f\u5c71\u6797\u8bed","location_id":"7359","lat":"31.03389","long":"112.1908","pm25":""},{"location_name":"\u897f\u5c71\u68ee\u6797\u516c\u56ed(\u5bf9\u7167\u70b9)","location_id":"7360","lat":"24.9624","long":"102.625","pm25":""},{"location_name":"\u897f\u5c71\u98ce\u666f\u533a","location_id":"7361","lat":"30.8064","long":"106.056","pm25":""},{"location_name":"\u897f\u660c\u5e02\u653f\u5e9c","location_id":"7362","lat":"27.8978","long":"102.2625","pm25":""},{"location_name":"\u897f\u6881","location_id":"7363","lat":"41.5931","long":"120.4439","pm25":""},{"location_name":"\u897f\u6eaa","location_id":"7364","lat":"30.2747","long":"120.063","pm25":""},{"location_name":"\u897f\u70ae\u53f0","location_id":"7365","lat":"40.6789","long":"122.1658","pm25":""},{"location_name":"\u897f\u85cf\u5927\u5b66","location_id":"7366","lat":"29.6541","long":"91.1774","pm25":""},{"location_name":"\u897f\u90ca\u5316\u5de5\u7ad9","location_id":"7367","lat":"37.5436","long":"121.3181","pm25":""},{"location_name":"\u897f\u9a6c","location_id":"7368","lat":"23.5486","long":"116.3242","pm25":""},{"location_name":"\u89c2\u6f9c","location_id":"7369","lat":"22.75","long":"114.085","pm25":""},{"location_name":"\u89c4\u5212\u5c40(20190304\u542f\u7528)","location_id":"7370","lat":"33.7297","long":"113.3025","pm25":""},{"location_name":"\u89c4\u5212\u8bbe\u8ba1\u9662","location_id":"7371","lat":"33.739","long":"113.292","pm25":""},{"location_name":"\u8ba9\u80e1\u8def\u533a","location_id":"7372","lat":"46.6219","long":"124.8648","pm25":""},{"location_name":"\u8c22\u5bb6\u96c6\u533a\u653f\u5e9c","location_id":"7373","lat":"32.6028","long":"116.8556","pm25":""},{"location_name":"\u8c61\u6e56","location_id":"7374","lat":"28.6425","long":"115.892","pm25":""},{"location_name":"\u8c6b\u6e90\u996d\u5e97","location_id":"7375","lat":"36.5458","long":"104.1731","pm25":""},{"location_name":"\u8c6b\u897f\u5bbe\u9986","location_id":"7376","lat":"34.6869","long":"112.4664","pm25":""},{"location_name":"\u8d22\u82d1\u5bbe\u9986","location_id":"7377","lat":"28.2403","long":"117.0281","pm25":""},{"location_name":"\u8d28\u91cf\u6280\u672f\u76d1\u7763\u5c40\uff0820180930\u542f\u7528\uff09","location_id":"7378","lat":"27.8094","long":"99.7136","pm25":""},{"location_name":"\u8d35\u57ce\u5b50\u7ad9","location_id":"7379","lat":"23.0944","long":"109.6014","pm25":""},{"location_name":"\u8d3a\u5170\u5c71\u4e1c\u8def","location_id":"7380","lat":"38.4975","long":"106.2328","pm25":""},{"location_name":"\u8d3a\u5170\u5c71\u9a6c\u83b2\u53e3","location_id":"7381","lat":"38.6016","long":"105.9512","pm25":""},{"location_name":"\u8d44\u9633\u4e2d\u5b66","location_id":"7382","lat":"30.1506","long":"104.6356","pm25":""},{"location_name":"\u8d44\u9633\u533a\u653f\u52a1\u4e2d\u5fc3","location_id":"7383","lat":"28.6047","long":"112.3347","pm25":""},{"location_name":"\u8d5b\u9c7c","location_id":"7384","lat":"37.8792","long":"113.4922","pm25":""},{"location_name":"\u8d6b\u5c71\u73af\u4fdd\u5206\u5c40","location_id":"7385","lat":"28.5819","long":"112.3744","pm25":""},{"location_name":"\u8d75\u5bb6\u575d","location_id":"7386","lat":"30.3714","long":"114.8989","pm25":""},{"location_name":"\u8dc3\u8fdb\u6c34\u5e93","location_id":"7387","lat":"28.2558","long":"109.6414","pm25":""},{"location_name":"\u8dc3\u8fdb\u8def","location_id":"7388","lat":"39.0877","long":"117.307","pm25":""},{"location_name":"\u8def\u6865\u516c\u53f8","location_id":"7389","lat":"37.0964","long":"114.5331","pm25":""},{"location_name":"\u8def\u6865\u7530\u6d0b\u738b","location_id":"7390","lat":"28.5773","long":"121.377","pm25":""},{"location_name":"\u8f66\u7ad9\u65b0\u533a","location_id":"7391","lat":"30.9219","long":"117.8561","pm25":""},{"location_name":"\u8f67\u94a2\u5382","location_id":"7392","lat":"31.3264","long":"120.596","pm25":""},{"location_name":"\u8f74\u627f\u5382","location_id":"7393","lat":"37.5433","long":"121.3719","pm25":""},{"location_name":"\u8fbe\u53bf\u673a\u5173\u5bbe\u9986","location_id":"7394","lat":"31.1956","long":"107.5069","pm25":""},{"location_name":"\u8fbe\u5dde\u804c\u4e1a\u6280\u672f\u5b66\u9662","location_id":"7395","lat":"31.2797","long":"107.5272","pm25":""},{"location_name":"\u8fbe\u6d3b\u6cc9","location_id":"7396","lat":"37.0967","long":"114.4821","pm25":""},{"location_name":"\u8fc8\u768b\u6865","location_id":"7397","lat":"32.1083","long":"118.803","pm25":""},{"location_name":"\u8fce\u5bbe\u9986","location_id":"7398","lat":"35.7306","long":"114.2878","pm25":""},{"location_name":"\u8fd0\u57ce\u4e2d\u5b66","location_id":"7399","lat":"35.0147","long":"110.9956","pm25":""},{"location_name":"\u8fdb\u6b65\u5df7","location_id":"7400","lat":"34.5814","long":"105.7281","pm25":""},{"location_name":"\u8fdc\u822a\u535a\u7269\u9986(181204\u542f\u7528)","location_id":"7401","lat":"33.666","long":"116.951","pm25":""},{"location_name":"\u8fea\u5e86\u5dde\u7ad9","location_id":"7402","lat":"27.8317","long":"99.7056","pm25":""},{"location_name":"\u901a\u5929\u5ca9","location_id":"7403","lat":"25.9118","long":"114.9064","pm25":""},{"location_name":"\u901a\u5fc3\u5cad\u5b50\u7ad9","location_id":"7404","lat":"22.5545","long":"114.1063","pm25":""},{"location_name":"\u901a\u8fbd\u5bbe\u9986","location_id":"7405","lat":"43.6267","long":"122.2603","pm25":""},{"location_name":"\u9053\u5916\u627f\u5fb7\u5e7f\u573a","location_id":"7406","lat":"45.7667","long":"126.635","pm25":""},{"location_name":"\u9053\u91cc\u5efa\u56fd\u8def","location_id":"7407","lat":"45.7478","long":"126.593","pm25":""},{"location_name":"\u9097\u6c5f\u76d1\u6d4b\u7ad9","location_id":"7408","lat":"32.3761","long":"119.389","pm25":""},{"location_name":"\u909b\u6d77\u5bbe\u9986","location_id":"7409","lat":"27.8408","long":"102.2714","pm25":""},{"location_name":"\u90a2\u5e08\u9ad8\u4e13","location_id":"7410","lat":"37.0533","long":"114.5261","pm25":""},{"location_name":"\u90a3\u66f2\u4f1a\u8bae\u4e2d\u5fc3","location_id":"7411","lat":"31.4797","long":"92.0506","pm25":""},{"location_name":"\u90a3\u66f2\u76d1\u6d4b\u7ad9","location_id":"7412","lat":"31.4846","long":"92.0657","pm25":""},{"location_name":"\u90ae\u7535\u5b66\u9662","location_id":"7413","lat":"43.84","long":"125.2786","pm25":""},{"location_name":"\u90d1\u7eba\u673a","location_id":"7414","lat":"34.7745","long":"113.641","pm25":""},{"location_name":"\u9152\u94a2\u5bbe\u9986","location_id":"7415","lat":"39.79778","long":"98.26722","pm25":""},{"location_name":"\u91c7\u8336\u5267\u56e2","location_id":"7416","lat":"28.0005","long":"116.3574","pm25":""},{"location_name":"\u91d1\u51e4\u6c34\u5e93","location_id":"7417","lat":"29.355","long":"113.2117","pm25":""},{"location_name":"\u91d1\u575b\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"7418","lat":"31.751","long":"119.579","pm25":""},{"location_name":"\u91d1\u575b\u5e02\u81ea\u6765\u6c34\u516c\u53f8","location_id":"7419","lat":"31.737","long":"119.579","pm25":""},{"location_name":"\u91d1\u5dde","location_id":"7420","lat":"39.1311","long":"121.7481","pm25":""},{"location_name":"\u91d1\u5e73\u5b50\u7ad9","location_id":"7421","lat":"23.3667","long":"116.6794","pm25":""},{"location_name":"\u91d1\u6c99\u6c5f\u8def\u5317","location_id":"7422","lat":"42.2217","long":"123.7153","pm25":""},{"location_name":"\u91d1\u6cc9\u4e24\u6cb3","location_id":"7423","lat":"30.723583","long":"103.97275","pm25":""},{"location_name":"\u91d1\u6db5\u6c34\u5e93(\u5bf9\u7167\u70b9)","location_id":"7424","lat":"26.6946","long":"119.5001","pm25":""},{"location_name":"\u91d1\u80dc","location_id":"7425","lat":"37.7778","long":"112.4783","pm25":""},{"location_name":"\u91d1\u949f\u5c71","location_id":"7426","lat":"26.2564","long":"105.9439","pm25":""},{"location_name":"\u91d1\u9f0e\u5c71","location_id":"7427","lat":"25.067","long":"102.681","pm25":""},{"location_name":"\u9274\u6e56\u8def","location_id":"7428","lat":"26.6266","long":"106.6243","pm25":""},{"location_name":"\u946b\u6e90\u5f00\u53d1\u533a","location_id":"7429","lat":"33.1138","long":"107.0089","pm25":""},{"location_name":"\u949f\u697c(\u542f\u7528161026)","location_id":"7430","lat":"31.7897","long":"119.8914","pm25":""},{"location_name":"\u94b1\u6e56\u6c34\u5382","location_id":"7431","lat":"29.7736","long":"121.633","pm25":""},{"location_name":"\u94b5\u6c60\u5c71","location_id":"7432","lat":"33.5981","long":"119.036","pm25":""},{"location_name":"\u94c1\u4e8c\u5904","location_id":"7433","lat":"32.5714","long":"110.8839","pm25":""},{"location_name":"\u94c1\u4f5b\u5bfa","location_id":"7434","lat":"36.11","long":"114.286","pm25":""},{"location_name":"\u94c1\u5c71","location_id":"7435","lat":"30.2043","long":"114.8949","pm25":""},{"location_name":"\u94c1\u897f\u4e09\u9053\u8857","location_id":"7436","lat":"41.0971","long":"122.9642","pm25":""},{"location_name":"\u94c1\u897f\u5de5\u4e1a\u56ed","location_id":"7437","lat":"41.2894","long":"123.1417","pm25":""},{"location_name":"\u94c1\u897f\u5de5\u4e1a\u56ed\u533a","location_id":"7438","lat":"41.0833","long":"122.9481","pm25":""},{"location_name":"\u94c1\u8def","location_id":"7439","lat":"40.9161","long":"117.9664","pm25":""},{"location_name":"\u94c1\u8def\u5c40","location_id":"7440","lat":"43.8711","long":"87.5525","pm25":""},{"location_name":"\u94c1\u8def\u8bbe\u8ba1\u9662","location_id":"7441","lat":"36.0464","long":"103.831","pm25":""},{"location_name":"\u94dc\u4ec1\u4e03\u4e2d","location_id":"7442","lat":"27.7231","long":"109.1794","pm25":""},{"location_name":"\u94dc\u4ec1\u536b\u6821","location_id":"7443","lat":"27.7297","long":"109.1916","pm25":""},{"location_name":"\u94dc\u5c71\u533a\u62db\u751f\u529e","location_id":"7444","lat":"34.1781","long":"117.1694","pm25":""},{"location_name":"\u94f6\u5dde\u8def\u4e1c\u6bb5","location_id":"7445","lat":"42.2864","long":"123.8489","pm25":""},{"location_name":"\u94f6\u674f\u5c0f\u533a","location_id":"7446","lat":"36.087","long":"114.358","pm25":""},{"location_name":"\u94f6\u6cb3\u8857","location_id":"7447","lat":"42.0352","long":"119.2654","pm25":""},{"location_name":"\u94f6\u884c\u5b66\u6821","location_id":"7448","lat":"34.8019","long":"113.675","pm25":""},{"location_name":"\u94f6\u9e70\u5236\u836f(20190903\u542f\u7528)","location_id":"7449","lat":"42.9079","long":"125.0829","pm25":""},{"location_name":"\u9526\u7eb6\u5c0f\u533a","location_id":"7450","lat":"37.7019","long":"112.7549","pm25":""},{"location_name":"\u955c\u6e56\u897f\u8def","location_id":"7451","lat":"40.6511","long":"122.215","pm25":""},{"location_name":"\u957f\u5b89","location_id":"7452","lat":"27.8953","long":"102.2311","pm25":""},{"location_name":"\u957f\u5b89\u533a","location_id":"7453","lat":"34.1546","long":"108.906","pm25":""},{"location_name":"\u957f\u5f81\u65b0\u6751","location_id":"7454","lat":"45.6033","long":"84.8861","pm25":""},{"location_name":"\u957f\u6c5f\u4e2d\u8def","location_id":"7455","lat":"31.8572","long":"117.25","pm25":""},{"location_name":"\u957f\u6c5f\u4ea7\u4e1a\u56ed","location_id":"7456","lat":"29.8686","long":"114.3372","pm25":""},{"location_name":"\u957f\u6c5f\u65c5\u6e38\u533a","location_id":"7457","lat":"22.4853","long":"113.4411","pm25":""},{"location_name":"\u957f\u6cbb\u516b\u4e2d","location_id":"7458","lat":"36.1855","long":"113.08444","pm25":""},{"location_name":"\u957f\u6e05\u515a\u6821","location_id":"7459","lat":"36.5336","long":"116.734","pm25":""},{"location_name":"\u957f\u9752\u8857","location_id":"7460","lat":"42.0186","long":"121.6561","pm25":""},{"location_name":"\u95fd\u897f\u804c\u4e1a\u6280\u672f\u5b66\u9662","location_id":"7461","lat":"25.0661","long":"117.0256","pm25":""},{"location_name":"\u960e\u826f\u533a","location_id":"7462","lat":"34.6575","long":"109.2","pm25":""},{"location_name":"\u961c\u9633\u804c\u4e1a\u6280\u672f\u5b66\u9662","location_id":"7463","lat":"32.88922","long":"115.78389","pm25":""},{"location_name":"\u9632\u57ce\u9547\u653f\u5e9c","location_id":"7464","lat":"21.7631","long":"108.3511","pm25":""},{"location_name":"\u9633\u5149\u5b66\u6821","location_id":"7465","lat":"44.3075","long":"86.0697","pm25":""},{"location_name":"\u963f\u57ce\u4f1a\u5b81","location_id":"7466","lat":"45.5422","long":"126.979","pm25":""},{"location_name":"\u963f\u91cc\u76d1\u6d4b\u7ad9","location_id":"7468","lat":"32.5","long":"80.1161","pm25":""},{"location_name":"\u9644\u4e2d","location_id":"7469","lat":"40.7608","long":"107.4211","pm25":""},{"location_name":"\u9648\u4ed3\u73af\u4fdd\u5c40","location_id":"7470","lat":"34.3528","long":"107.3906","pm25":""},{"location_name":"\u9648\u5bb6\u6e7e","location_id":"7471","lat":"30.2028","long":"115.0767","pm25":""},{"location_name":"\u9675\u4e1c\u8857","location_id":"7472","lat":"41.8472","long":"123.428","pm25":""},{"location_name":"\u9676\u74f7\u516c\u53f8","location_id":"7473","lat":"39.6679","long":"118.2185","pm25":""},{"location_name":"\u9676\u7814\u6240","location_id":"7474","lat":"29.2956","long":"117.2461","pm25":""},{"location_name":"\u96c6\u5b81\u65b0\u533a","location_id":"7475","lat":"40.9923","long":"113.1306","pm25":""},{"location_name":"\u96e8\u82b1\u533a\u73af\u4fdd\u5c40","location_id":"7476","lat":"28.1442","long":"112.9956","pm25":""},{"location_name":"\u96ea\u6d6a","location_id":"7477","lat":"31.4867","long":"120.269","pm25":""},{"location_name":"\u96f6\u9675\u533a\u73af\u4fdd\u5c40","location_id":"7478","lat":"26.2331","long":"111.6236","pm25":""},{"location_name":"\u96f6\u9675\u5357\u6d25\u6e21","location_id":"7479","lat":"26.2081","long":"111.6217","pm25":""},{"location_name":"\u96f7\u8fbe\u7ad9","location_id":"7481","lat":"39.643","long":"118.144","pm25":""},{"location_name":"\u9707\u5ddd\u4e2d\u5b66","location_id":"7482","lat":"31.381","long":"120.999","pm25":""},{"location_name":"\u971e\u5c71\u6e38\u6cf3\u573a","location_id":"7483","lat":"21.2028","long":"110.4111","pm25":""},{"location_name":"\u9752\u539f\u533a\u6cd5\u9662","location_id":"7484","lat":"27.0983","long":"115.0075","pm25":""},{"location_name":"\u9752\u5c71\u5bbe\u9986","location_id":"7485","lat":"40.6821","long":"109.8538","pm25":""},{"location_name":"\u9752\u5c71\u94a2\u82b1","location_id":"7486","lat":"30.6103","long":"114.4272","pm25":""},{"location_name":"\u9752\u6760\u6797\u8def","location_id":"7487","lat":"29.33972","long":"104.7228","pm25":""},{"location_name":"\u9752\u6ce5\u6d3c\u6865","location_id":"7488","lat":"38.911945","long":"121.63306","pm25":""},{"location_name":"\u9752\u6d66\u6dc0\u5c71\u6e56","location_id":"7489","lat":"31.0935","long":"120.978","pm25":""},{"location_name":"\u9752\u9f99\u5bfa","location_id":"7490","lat":"27.8094","long":"102.3419","pm25":""},{"location_name":"\u9759\u5b89\u76d1\u6d4b\u7ad9","location_id":"7491","lat":"31.2261","long":"121.425","pm25":""},{"location_name":"\u97f6\u5173\u5b66\u9662","location_id":"7492","lat":"24.779083","long":"113.67347","pm25":""},{"location_name":"\u97f6\u5c71","location_id":"7493","lat":"27.9164","long":"112.4876","pm25":""},{"location_name":"\u987a\u4e49\u65b0\u57ce","location_id":"7494","lat":"40.1438","long":"116.72","pm25":""},{"location_name":"\u987a\u57ce\u533a","location_id":"7495","lat":"41.8828","long":"123.9169","pm25":""},{"location_name":"\u987a\u5fb7\u82cf\u5c97","location_id":"7496","lat":"22.8054","long":"113.292","pm25":""},{"location_name":"\u98ce\u666f\u533a","location_id":"7497","lat":"34.7997","long":"111.1489","pm25":""},{"location_name":"\u98de\u5b87","location_id":"7498","lat":"27.8344","long":"114.9831","pm25":""},{"location_name":"\u98df\u54c1\u5382","location_id":"7499","lat":"43.9167","long":"125.323","pm25":""},{"location_name":"\u9999\u574a\u7ea2\u65d7\u5927\u8857","location_id":"7500","lat":"45.7319","long":"126.685","pm25":""},{"location_name":"\u9999\u6eaa\u6d1e","location_id":"7501","lat":"32.6778","long":"109.0311","pm25":""},{"location_name":"\u9a6c\u5357\u578c","location_id":"7502","lat":"21.865","long":"111.9494","pm25":""},{"location_name":"\u9a6c\u56ed","location_id":"7503","lat":"36.1417","long":"106.2319","pm25":""},{"location_name":"\u9a6c\u5761\u5cad","location_id":"7504","lat":"28.2053","long":"113.0792","pm25":""},{"location_name":"\u9a6c\u5934\u5cad","location_id":"7505","lat":"25.9061","long":"113.0073","pm25":""},{"location_name":"\u9a6c\u5c71\u5bbe\u9986","location_id":"7506","lat":"30.511972","long":"117.03311","pm25":""},{"location_name":"\u9a6c\u5e08\u6821","location_id":"7507","lat":"31.8934","long":"102.2402","pm25":""},{"location_name":"\u9a6c\u8302\u5e84\u5c0f\u5b66","location_id":"7508","lat":"37.51","long":"111.128334","pm25":""},{"location_name":"\u9a6c\u94a2\u52a8\u529b\u5382","location_id":"7509","lat":"31.6928","long":"118.48","pm25":""},{"location_name":"\u9a6c\u978d\u5c71","location_id":"7510","lat":"26.6029","long":"106.6856","pm25":""},{"location_name":"\u9ad8\u538b\u5f00\u5173\u5382","location_id":"7511","lat":"33.7214","long":"113.3064","pm25":""},{"location_name":"\u9ad8\u576a\u533a\u76d1\u6d4b\u7ad9","location_id":"7512","lat":"30.7856","long":"106.1064","pm25":""},{"location_name":"\u9ad8\u5cad","location_id":"7513","lat":"21.6828","long":"110.8592","pm25":""},{"location_name":"\u9ad8\u5f00\u533a\u73af\u4fdd\u5c40","location_id":"7514","lat":"28.2189","long":"112.8872","pm25":""},{"location_name":"\u9ad8\u65b0\u4e00\u5c0f","location_id":"7515","lat":"34.5021","long":"109.4266","pm25":""},{"location_name":"\u9ad8\u65b0\u533a","location_id":"7516","lat":"38.0398","long":"114.6046","pm25":""},{"location_name":"\u9ad8\u65b0\u533a\u653f\u5e9c","location_id":"7517","lat":"35.1764","long":"113.2464","pm25":""},{"location_name":"\u9ad8\u65b0\u533a\u7ba1\u59d4\u4f1a","location_id":"7518","lat":"43.8167","long":"125.25","pm25":""},{"location_name":"\u9ad8\u65b0\u533a\u81ea\u6765\u6c34\u516c\u53f8","location_id":"7519","lat":"31.4656","long":"104.6717","pm25":""},{"location_name":"\u9ad8\u65b0\u7ba1\u59d4\u4f1a","location_id":"7520","lat":"32.1142","long":"112.1825","pm25":""},{"location_name":"\u9ad8\u65b0\u897f\u533a","location_id":"7521","lat":"34.2303","long":"108.883","pm25":""},{"location_name":"\u9ad8\u660e\u5b54\u5802","location_id":"7522","lat":"22.8693","long":"112.844","pm25":""},{"location_name":"\u9ad8\u7ea7\u4e2d\u5b66","location_id":"7523","lat":"37.9844","long":"106.2025","pm25":""},{"location_name":"\u9c7c\u65b0\u8857","location_id":"7524","lat":"29.389","long":"106.513","pm25":""},{"location_name":"\u9c81\u5357\u5236\u836f\u5382","location_id":"7525","lat":"35.0583","long":"118.295","pm25":""},{"location_name":"\u9ccc\u5cf0\u5b50\u7ad9","location_id":"7526","lat":"30.9447","long":"118.7581","pm25":""},{"location_name":"\u9e33\u9e2f\u6e56","location_id":"7527","lat":"21.8586","long":"111.9786","pm25":""},{"location_name":"\u9e93\u6e56","location_id":"7528","lat":"23.1569","long":"113.281","pm25":""},{"location_name":"\u9ebb\u7ae0\u533a\u73af\u4fdd\u5c40","location_id":"7529","lat":"21.2679","long":"110.3316","pm25":""},{"location_name":"\u9ec4\u571f\u5761","location_id":"7530","lat":"26.5917","long":"104.83","pm25":""},{"location_name":"\u9ec4\u5c71\u4e1c\u8def89\u53f7","location_id":"7531","lat":"29.7207","long":"118.3236","pm25":""},{"location_name":"\u9ec4\u5c71\u533a\u653f\u5e9c5\u53f7\u697c","location_id":"7532","lat":"30.2756","long":"118.1371","pm25":""},{"location_name":"\u9ec4\u5c9b\u533a\u5b50\u7ad9","location_id":"7533","lat":"36.3083","long":"120.1964","pm25":""},{"location_name":"\u9ec4\u5ca9\u73af\u4fdd\u5927\u697c","location_id":"7534","lat":"28.6459","long":"121.273","pm25":""},{"location_name":"\u9ec4\u5df7","location_id":"7535","lat":"31.6219","long":"120.275","pm25":""},{"location_name":"\u9ec4\u6cb3\u65b0\u6751","location_id":"7536","lat":"34.2761","long":"117.167","pm25":""},{"location_name":"\u9ec4\u91d1\u5634","location_id":"7537","lat":"28.71583","long":"104.5761","pm25":""},{"location_name":"\u9ed1\u77f3\u5761","location_id":"7538","lat":"32.4535","long":"105.8945","pm25":""},{"location_name":"\u9f0e\u57ce\u533a\u7389\u971e(\u542f\u7528171130)","location_id":"7539","lat":"28.9881","long":"111.6892","pm25":""},{"location_name":"\u9f13\u5c71","location_id":"7540","lat":"26.0542","long":"119.389","pm25":""},{"location_name":"\u9f13\u697c\u533a\u653f\u5e9c","location_id":"7541","lat":"34.29","long":"117.1814","pm25":""},{"location_name":"\u9f13\u6d6a\u5c7f","location_id":"7542","lat":"24.445833","long":"118.063614","pm25":""},{"location_name":"\u9f99\u4e95\u6e7e(\u542f\u7528161118)","location_id":"7543","lat":"29.57278","long":"106.4042","pm25":""},{"location_name":"\u9f99\u4ead\u516c\u56ed(\u542f\u7528180109)","location_id":"7544","lat":"34.8097","long":"114.3442","pm25":""},{"location_name":"\u9f99\u51e4\u533a","location_id":"7545","lat":"46.528","long":"125.112","pm25":""},{"location_name":"\u9f99\u534e\u8def\u73af\u4fdd\u5c40\u5bbf\u820d","location_id":"7546","lat":"20.0356","long":"110.33","pm25":""},{"location_name":"\u9f99\u5729","location_id":"7547","lat":"23.415","long":"111.2353","pm25":""},{"location_name":"\u9f99\u5c97","location_id":"7548","lat":"22.7267","long":"114.24","pm25":""},{"location_name":"\u9f99\u5ca9\u5b66\u9662","location_id":"7549","lat":"25.0311","long":"117.0151","pm25":""},{"location_name":"\u9f99\u5ca9\u5e02\u76d1\u6d4b\u7ad9","location_id":"7550","lat":"25.1035","long":"117.0216","pm25":""},{"location_name":"\u9f99\u5ca9\u5e08\u4e13","location_id":"7551","lat":"25.1174","long":"117.0181","pm25":""},{"location_name":"\u9f99\u65b0","location_id":"7552","lat":"23.4794","long":"111.26","pm25":""},{"location_name":"\u9f99\u6cc9\u9547","location_id":"7553","lat":"25.0836","long":"102.728","pm25":""},{"location_name":"\u9f99\u6cc9\u9a7f\u533a\u533a\u653f\u5e9c","location_id":"7554","lat":"30.5589","long":"104.2725","pm25":""},{"location_name":"\u9f99\u6d32\u6e7e(\u542f\u7528161119)","location_id":"7555","lat":"29.41569","long":"106.5506","pm25":""},{"location_name":"\u9f99\u6e2f\u533a","location_id":"7556","lat":"40.7136","long":"120.9092","pm25":""},{"location_name":"\u9f99\u6e56\u5b50\u7ad9","location_id":"7557","lat":"23.3633","long":"116.7244","pm25":""},{"location_name":"\u9f99\u6e7e","location_id":"7558","lat":"27.9747","long":"120.76","pm25":""},{"location_name":"\u9f99\u864e\u5c71","location_id":"7559","lat":"28.095","long":"116.9622","pm25":""},{"location_name":"\u9f99\u8d5b\u533b\u9662","location_id":"7560","lat":"29.9572","long":"121.713","pm25":""},{"location_name":"\u9f99\u9690\u8def\u5c0f\u5b66","location_id":"7561","lat":"25.2708","long":"110.3089","pm25":""},{"location_name":"Albany","location_id":"7563","lat":"42.6425","long":"-73.7547","pm25":""},{"location_name":"Auburn M St SE","location_id":"7565","lat":"47.2875","long":"-122.2144","pm25":""},{"location_name":"Balneario Curanilahue","location_id":"7567","lat":"-37.48513","long":"-73.33163","pm25":""},{"location_name":"Chester","location_id":"7572","lat":"39.8356","long":"-75.3725","pm25":""},{"location_name":"Columbia","location_id":"7574","lat":"35.65188","long":"-87.0096","pm25":""},{"location_name":"Concord","location_id":"7575","lat":"43.21847","long":"-71.51453","pm25":""},{"location_name":"Coso Junction","location_id":"7576","lat":"36.0494","long":"-117.9439","pm25":""},{"location_name":"FR39014","location_id":"7579","lat":"14.6662","long":"-61.1501","pm25":""},{"location_name":"Guty Du\u017ce","location_id":"7583","lat":"52.943054","long":"21.289167","pm25":""},{"location_name":"Hengchun","location_id":"7589","lat":"21.958069","long":"120.788925","pm25":""},{"location_name":"Hope","location_id":"7591","lat":"39.294323","long":"-85.766846","pm25":""},{"location_name":"Huasco II","location_id":"7593","lat":"-28.4665","long":"-71.23064","pm25":""},{"location_name":"INIA, Chill\u00e1n","location_id":"7594","lat":"-36.59488","long":"-72.08926","pm25":""},{"location_name":"JERSEYVL","location_id":"7597","lat":"39.10144","long":"-90.3445","pm25":""},{"location_name":"Jefferson","location_id":"7598","lat":"35.1441","long":"-106.6044","pm25":""},{"location_name":"Kingston College","location_id":"7599","lat":"-36.784653","long":"-73.05206","pm25":""},{"location_name":"La Florida","location_id":"7602","lat":"-35.435143","long":"-71.67826","pm25":""},{"location_name":"La Serena","location_id":"7603","lat":"-29.933006","long":"-71.26196","pm25":""},{"location_name":"La Union","location_id":"7604","lat":"-40.286858","long":"-73.07671","pm25":""},{"location_name":"Lang C408","location_id":"7605","lat":"29.8342","long":"-95.4892","pm25":""},{"location_name":"Las Encinas Temuco","location_id":"7606","lat":"-38.7487","long":"-72.62079","pm25":""},{"location_name":"Lima","location_id":"7607","lat":"40.771","long":"-84.0539","pm25":""},{"location_name":"London","location_id":"7608","lat":"39.78819","long":"-83.47606","pm25":""},{"location_name":"Mirasol","location_id":"7613","lat":"-41.479507","long":"-72.96876","pm25":""},{"location_name":"Molson","location_id":"7614","lat":"45.54271","long":"-73.57176","pm25":""},{"location_name":"NCORE","location_id":"7615","lat":"41.2474","long":"-95.9731","pm25":""},{"location_name":"Near Road","location_id":"7617","lat":"38.1935","long":"-85.7121","pm25":""},{"location_name":"PECK","location_id":"7618","lat":"37.4769","long":"-97.3664","pm25":""},{"location_name":"Pinehurst","location_id":"7621","lat":"36.6972","long":"-119.0189","pm25":""},{"location_name":"SM8 ","location_id":"7627","lat":"-28.50741","long":"-71.08157","pm25":""},{"location_name":"SYDNEY","location_id":"7628","lat":"46.1425","long":"-60.1728","pm25":""},{"location_name":"Shenyang","location_id":"7632","lat":"41.78351","long":"123.42443","pm25":""},{"location_name":"Stuart","location_id":"7634","lat":"27.172459","long":"-80.24069","pm25":""},{"location_name":"Sur","location_id":"7635","lat":"-32.80144","long":"-71.4841","pm25":""},{"location_name":"The Gap","location_id":"7636","lat":"-20.7264","long":"139.498","pm25":""},{"location_name":"Wampanoag Laboratory","location_id":"7643","lat":"41.3306","long":"-70.788895","pm25":""},{"location_name":"Wanhua","location_id":"7644","lat":"25.046503","long":"121.50797","pm25":""},{"location_name":"West Union","location_id":"7645","lat":"38.79471","long":"-83.53399","pm25":""},{"location_name":"Wiang, Mueang","location_id":"7646","lat":"19.190056","long":"100.17033","pm25":""},{"location_name":"\u042d\u0440\u0434\u044d\u043d\u044d\u04421","location_id":"7648","lat":"49.01939","long":"104.04528","pm25":""},{"location_name":"\u4eba\u6c11\u516c\u56ed","location_id":"7653","lat":"36.8088","long":"118.0482","pm25":""},{"location_name":"\u516b\u4e2d","location_id":"7654","lat":"25.2178","long":"110.2869","pm25":""},{"location_name":"\u519c\u4e1a\u56ed\u533a","location_id":"7655","lat":"41.615","long":"120.3939","pm25":""},{"location_name":"\u533a\u653f\u5e9c","location_id":"7656","lat":"39.3179","long":"112.4254","pm25":""},{"location_name":"\u5965\u4f53\u4e2d\u5fc3","location_id":"7657","lat":"40.0031","long":"116.407","pm25":""},{"location_name":"\u5ba1\u8ba1\u5c40","location_id":"7658","lat":"32.1383","long":"114.0614","pm25":""},{"location_name":"\u5e02\u4e8c\u4e2d","location_id":"7659","lat":"28.9703","long":"111.6975","pm25":""},{"location_name":"\u5e02\u56db\u4e2d","location_id":"7660","lat":"27.8667","long":"113.167","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"7661","lat":"34.6511","long":"112.3939","pm25":""},{"location_name":"\u5e02\u6797\u4e1a\u5c40","location_id":"7663","lat":"39.6969","long":"106.8089","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u7ad9","location_id":"7664","lat":"21.9667","long":"108.6236","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"7665","lat":"36.6428","long":"101.748","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"7666","lat":"32.41","long":"119.404","pm25":""},{"location_name":"\u5e02\u7ad9","location_id":"7667","lat":"27.9883","long":"116.3553","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"7668","lat":"39.5747","long":"116.7729","pm25":""},{"location_name":"\u5f00\u53d1\u533a\u5b50\u7ad9","location_id":"7669","lat":"36.39","long":"120.47","pm25":""},{"location_name":"\u6c5f\u5317","location_id":"7670","lat":"43.8947","long":"126.5786","pm25":""},{"location_name":"21 de mayo","location_id":"7671","lat":"-37.471184","long":"-72.361465","pm25":""},{"location_name":"Albany","location_id":"7672","lat":"40.3","long":"-85.24556","pm25":""},{"location_name":"Baytown Garth C1017","location_id":"7673","lat":"29.823318","long":"-94.98379","pm25":""},{"location_name":"Bristol","location_id":"7675","lat":"41.7178","long":"-85.8247","pm25":""},{"location_name":"Buffalo","location_id":"7676","lat":"41.4672","long":"-90.6883","pm25":""},{"location_name":"Colegio Pedro Vergara Keller","location_id":"7677","lat":"-22.442839","long":"-68.93255","pm25":""},{"location_name":"Copiapo Sivica","location_id":"7678","lat":"-27.370329","long":"-70.323906","pm25":""},{"location_name":"Cornwall","location_id":"7679","lat":"45.0294","long":"-74.7394","pm25":""},{"location_name":"Cuncumen ","location_id":"7680","lat":"-31.889278","long":"-70.62931","pm25":""},{"location_name":"Entre R\u00edos","location_id":"7681","lat":"-37.503605","long":"-72.65967","pm25":""},{"location_name":"Guangzhou","location_id":"7685","lat":"23.116785","long":"113.318085","pm25":""},{"location_name":"Huasco Sivica","location_id":"7689","lat":"-28.469997","long":"-71.21965","pm25":""},{"location_name":"Joshua Tree NP - Cot","location_id":"7690","lat":"33.7472","long":"-115.8201","pm25":""},{"location_name":"Junta de Vecinos","location_id":"7691","lat":"-32.935165","long":"-71.52577","pm25":""},{"location_name":"Lo Campo","location_id":"7693","lat":"-32.797714","long":"-70.89804","pm25":""},{"location_name":"NCORE","location_id":"7700","lat":"26.054047","long":"-80.25761","pm25":""},{"location_name":"NCore - White Mounta","location_id":"7701","lat":"37.360703","long":"-118.33083","pm25":""},{"location_name":"Paipote","location_id":"7702","lat":"-27.4134","long":"-70.27139","pm25":""},{"location_name":"Parque O'Higgins","location_id":"7704","lat":"-33.46414","long":"-70.6608","pm25":""},{"location_name":"Saint-Jean-Baptiste","location_id":"7705","lat":"45.6481","long":"-73.4997","pm25":""},{"location_name":"Sainte-Anne-de-Belle","location_id":"7706","lat":"45.4333","long":"-73.9333","pm25":""},{"location_name":"Taixi","location_id":"7707","lat":"23.717533","long":"120.20284","pm25":""},{"location_name":"U.C. Maule","location_id":"7708","lat":"-35.435726","long":"-71.61955","pm25":""},{"location_name":"Universidad de Talca","location_id":"7710","lat":"-35.40658","long":"-71.6334","pm25":""},{"location_name":"West Mackay","location_id":"7712","lat":"-21.1595","long":"149.155","pm25":""},{"location_name":"Zhongli","location_id":"7713","lat":"24.953278","long":"121.221664","pm25":""},{"location_name":"Zhudong","location_id":"7714","lat":"24.740644","long":"121.088905","pm25":""},{"location_name":"Zuoying","location_id":"7715","lat":"22.674862","long":"120.292915","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"7719","lat":"39.0511","long":"121.7769","pm25":""},{"location_name":"\u6280\u672f\u5b66\u9662","location_id":"7720","lat":"36.2289","long":"117.6789","pm25":""},{"location_name":"\u6cf0\u5174\u516c\u53f8","location_id":"7721","lat":"36.2092","long":"117.7181","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"7722","lat":"36.7008","long":"119.1425","pm25":""},{"location_name":"\u804c\u5de5\u533b\u9662","location_id":"7723","lat":"38.0513","long":"114.4548","pm25":""},{"location_name":"\u9ad8\u538b\u5f00\u5173\u5382","location_id":"7724","lat":"34.2749","long":"108.882","pm25":""},{"location_name":"Calabozo","location_id":"7726","lat":"-36.99643","long":"-73.11581","pm25":""},{"location_name":"Chiayi","location_id":"7728","lat":"23.462778","long":"120.440834","pm25":""},{"location_name":"Conc\u00f3n MMA","location_id":"7729","lat":"-32.926243","long":"-71.51246","pm25":""},{"location_name":"Dali","location_id":"7730","lat":"24.099611","long":"120.67769","pm25":""},{"location_name":"Douliu","location_id":"7731","lat":"23.711853","long":"120.54499","pm25":""},{"location_name":"Erlin","location_id":"7732","lat":"23.925175","long":"120.40965","pm25":""},{"location_name":"Gobernaci\u00f3n","location_id":"7734","lat":"-22.093082","long":"-70.20121","pm25":""},{"location_name":"Guanshan","location_id":"7736","lat":"23.045082","long":"121.161934","pm25":""},{"location_name":"Jerome Mack","location_id":"7742","lat":"36.141876","long":"-115.07874","pm25":""},{"location_name":"Lake Jackson C1016","location_id":"7746","lat":"29.0436","long":"-95.4736","pm25":""},{"location_name":"Lautaro","location_id":"7747","lat":"-37.508938","long":"-72.65609","pm25":""},{"location_name":"Lincoln","location_id":"7749","lat":"46.955997","long":"-112.655396","pm25":""},{"location_name":"Linkou","location_id":"7750","lat":"25.07857","long":"121.3657","pm25":""},{"location_name":"MARYVILL","location_id":"7751","lat":"38.7267","long":"-89.9592","pm25":""},{"location_name":"Near Road","location_id":"7756","lat":"41.829494","long":"-71.41746","pm25":""},{"location_name":"New Albany","location_id":"7757","lat":"38.3081","long":"-85.8342","pm25":""},{"location_name":"Pingzhen","location_id":"7761","lat":"24.954208","long":"121.20498","pm25":""},{"location_name":"Puli","location_id":"7762","lat":"23.968842","long":"120.9679","pm25":""},{"location_name":"San Fernando","location_id":"7765","lat":"-27.393269","long":"-70.298615","pm25":""},{"location_name":"Santa Margarita","location_id":"7766","lat":"-32.776573","long":"-70.93814","pm25":""},{"location_name":"Tucheng","location_id":"7771","lat":"24.982529","long":"121.45186","pm25":""},{"location_name":"Valdivia 2","location_id":"7772","lat":"-39.805428","long":"-73.25873","pm25":""},{"location_name":"Xingang","location_id":"7776","lat":"23.554838","long":"120.34553","pm25":""},{"location_name":"York","location_id":"7777","lat":"34.9356","long":"-81.2283","pm25":""},{"location_name":"\u042d\u0440\u0434\u044d\u043d\u044d\u04422","location_id":"7779","lat":"49.017056","long":"104.02814","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"7784","lat":"36.61763","long":"114.5129","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u3000","location_id":"7785","lat":"45.2924","long":"130.962","pm25":""},{"location_name":"\u76d1\u6d4b\u697c","location_id":"7786","lat":"27.5578","long":"109.9972","pm25":""},{"location_name":"\u519c\u79d1\u6240","location_id":"7787","lat":"34.5101","long":"109.5293","pm25":""},{"location_name":"\u5e02\u59d4","location_id":"7788","lat":"36.0875","long":"111.5025","pm25":""},{"location_name":"Annan","location_id":"7792","lat":"23.048332","long":"120.21833","pm25":""},{"location_name":"Cailiao","location_id":"7795","lat":"25.06895","long":"121.481026","pm25":""},{"location_name":"Cauquenes","location_id":"7796","lat":"-34.24117","long":"-70.55283","pm25":""},{"location_name":"Club Deportivo 23 de Marzo","location_id":"7798","lat":"-22.46027","long":"-68.937706","pm25":""},{"location_name":"Coyhaique II","location_id":"7800","lat":"-45.579044","long":"-72.049965","pm25":""},{"location_name":"Datong","location_id":"7801","lat":"25.0632","long":"121.51331","pm25":""},{"location_name":"Duncan","location_id":"7803","lat":"45.5025","long":"-73.6661","pm25":""},{"location_name":"Keelung","location_id":"7808","lat":"25.129168","long":"121.760056","pm25":""},{"location_name":"Kinmen","location_id":"7809","lat":"24.432133","long":"118.312256","pm25":""},{"location_name":"Loncura","location_id":"7813","lat":"-32.794968","long":"-71.4961","pm25":""},{"location_name":"Lunbei","location_id":"7814","lat":"23.757547","long":"120.34874","pm25":""},{"location_name":"Nai Mueang, Mueang","location_id":"7815","lat":"16.44533","long":"102.83525","pm25":""},{"location_name":"Nanzi","location_id":"7816","lat":"22.733667","long":"120.328285","pm25":""},{"location_name":"Olancha","location_id":"7819","lat":"36.2676","long":"-117.993","pm25":""},{"location_name":"Punteras","location_id":"7822","lat":"-36.92333","long":"-73.03613","pm25":""},{"location_name":"Puren","location_id":"7823","lat":"-36.61617","long":"-72.09304","pm25":""},{"location_name":"Qianjin","location_id":"7824","lat":"22.632566","long":"120.288086","pm25":""},{"location_name":"Qiaotou","location_id":"7825","lat":"22.757505","long":"120.30569","pm25":""},{"location_name":"Sanyi","location_id":"7826","lat":"24.382942","long":"120.758835","pm25":""},{"location_name":"Shanghai","location_id":"7827","lat":"31.210684","long":"121.44823","pm25":""},{"location_name":"Songshan","location_id":"7828","lat":"25.05","long":"121.57861","pm25":""},{"location_name":"Taitung","location_id":"7830","lat":"22.755358","long":"121.15045","pm25":""},{"location_name":"Xindian","location_id":"7832","lat":"24.977222","long":"121.53778","pm25":""},{"location_name":"\u4e1c\u57ce\u533a","location_id":"7838","lat":"30.9075","long":"113.942","pm25":""},{"location_name":"\u4e1c\u5c71\u516c\u56ed","location_id":"7839","lat":"39.617","long":"122.011","pm25":""},{"location_name":"\u4f53\u80b2\u9986","location_id":"7840","lat":"28.2264","long":"117.0222","pm25":""},{"location_name":"\u515a\u6821","location_id":"7841","lat":"36.4796","long":"115.9835","pm25":""},{"location_name":"\u51e4\u51f0\u5c71","location_id":"7842","lat":"26.2431","long":"105.9408","pm25":""},{"location_name":"\u73af\u4fdd\u5c40\u5b50\u7ad9","location_id":"7843","lat":"36.44","long":"120.61","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"7844","lat":"29.1029","long":"119.686","pm25":""},{"location_name":"\u5dde\u76d1\u6d4b\u7ad9","location_id":"7845","lat":"44.0114","long":"87.2997","pm25":""},{"location_name":"\u5e02\u4e00\u4e2d","location_id":"7846","lat":"34.0339","long":"113.8172","pm25":""},{"location_name":"\u5e02\u4e2d\u5fc3","location_id":"7847","lat":"26.8906","long":"100.2203","pm25":""},{"location_name":"\u8001\u57ce","location_id":"7848","lat":"32.4429","long":"105.8242","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"7849","lat":"45.7219","long":"126.6203","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"7850","lat":"22.7898","long":"115.3706","pm25":""},{"location_name":"\u83b1\u829c\u6218\u5f79\u7eaa\u5ff5\u9986","location_id":"7851","lat":"36.2211","long":"117.6983","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5c40","location_id":"7852","lat":"37.739","long":"115.6906","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"7853","lat":"23.1331","long":"113.26","pm25":""},{"location_name":"\u65b0\u533a","location_id":"7854","lat":"36.0211","long":"106.2375","pm25":""},{"location_name":"\u6797\u79d1\u6240","location_id":"7855","lat":"27.5733","long":"109.9333","pm25":""},{"location_name":"Berkeley Aquatic Par","location_id":"7856","lat":"37.864765","long":"-122.30274","pm25":""},{"location_name":"Cookeville","location_id":"7858","lat":"36.1857","long":"-85.4921","pm25":""},{"location_name":"Coronel Norte","location_id":"7859","lat":"-37.00867","long":"-73.14809","pm25":""},{"location_name":"Lancaster","location_id":"7861","lat":"40.0467","long":"-76.2833","pm25":""},{"location_name":"Lewiston","location_id":"7862","lat":"46.4085","long":"-116.9914","pm25":""},{"location_name":"Near Road","location_id":"7864","lat":"43.59393","long":"-116.38125","pm25":""},{"location_name":"Pico Rivera","location_id":"7865","lat":"34.0131","long":"-118.0592","pm25":""},{"location_name":"Portsmouth","location_id":"7866","lat":"50.82881","long":"-1.068583","pm25":""},{"location_name":"Xinying","location_id":"7869","lat":"23.305634","long":"120.31725","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"7877","lat":"33.3942","long":"120.156","pm25":""},{"location_name":"\u884c\u653f\u4e2d\u5fc3","location_id":"7878","lat":"30.6347","long":"105.8161","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"7879","lat":"36.6739","long":"117.114","pm25":""},{"location_name":"\u5f00\u53d1\u533a\u7ba1\u59d4\u4f1a","location_id":"7880","lat":"34.6231","long":"112.3844","pm25":""},{"location_name":"\u9ad8\u65b0\u533a","location_id":"7881","lat":"31.8516","long":"117.124","pm25":""},{"location_name":"Banqiao","location_id":"7882","lat":"25.012972","long":"121.458664","pm25":""},{"location_name":"Greenfield","location_id":"7885","lat":"36.32693","long":"-121.24579","pm25":""},{"location_name":"Hukou","location_id":"7886","lat":"24.900143","long":"121.03865","pm25":""},{"location_name":"Jackson","location_id":"7888","lat":"35.705338","long":"-88.81959","pm25":""},{"location_name":"Lizard Tail","location_id":"7889","lat":"36.5432","long":"-117.9418","pm25":""},{"location_name":"Loretto","location_id":"7890","lat":"35.116867","long":"-87.41972","pm25":""},{"location_name":"Los \u00c1ngeles Oriente","location_id":"7891","lat":"-37.463036","long":"-72.32458","pm25":""},{"location_name":"Moranbah","location_id":"7893","lat":"-21.9995","long":"148.071","pm25":""},{"location_name":"Port Manatee","location_id":"7896","lat":"27.6331","long":"-82.5458","pm25":""},{"location_name":"Qianzhen","location_id":"7897","lat":"22.605387","long":"120.30756","pm25":""},{"location_name":"Rancagua I","location_id":"7898","lat":"-34.162315","long":"-70.71392","pm25":""},{"location_name":"Shanhua","location_id":"7900","lat":"23.115097","long":"120.29714","pm25":""},{"location_name":"\u515a\u6821","location_id":"7907","lat":"50.2391","long":"127.5044","pm25":""},{"location_name":"\u81ea\u6765\u6c34\u516c\u53f8","location_id":"7908","lat":"37.5136","long":"111.1297","pm25":""},{"location_name":"\u5e02\u6c14\u8c61\u5c40","location_id":"7909","lat":"27.7914","long":"114.3703","pm25":""},{"location_name":"\u6c14\u8c61\u7ad9","location_id":"7910","lat":"33.027","long":"112.5573","pm25":""},{"location_name":"Fengyuan","location_id":"7911","lat":"24.256586","long":"120.741714","pm25":""},{"location_name":"Hualien","location_id":"7914","lat":"23.971306","long":"121.59977","pm25":""},{"location_name":"Shalu","location_id":"7916","lat":"24.225628","long":"120.568794","pm25":""},{"location_name":"Valparaiso","location_id":"7918","lat":"41.5114","long":"-87.0353","pm25":""},{"location_name":"Xiaogang","location_id":"7919","lat":"22.565832","long":"120.33774","pm25":""},{"location_name":"\u533a\u73af\u4fdd\u5c40","location_id":"7923","lat":"35.7289","long":"107.6831","pm25":""},{"location_name":"\u56ed\u6797\u5904","location_id":"7924","lat":"24.795927","long":"113.59806","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"7925","lat":"38.8707","long":"115.5214","pm25":""},{"location_name":"CLEVELAND","location_id":"7926","lat":"33.7556","long":"-90.7275","pm25":""},{"location_name":"Padre Las Casas II","location_id":"7928","lat":"-38.764767","long":"-72.59879","pm25":""},{"location_name":"\u6c61\u6c34\u5904\u7406\u5382","location_id":"7930","lat":"33.8399","long":"115.8067","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"7936","lat":"28.76389","long":"104.6417","pm25":""},{"location_name":"Magong","location_id":"7939","lat":"23.56903","long":"119.566154","pm25":""},{"location_name":"\u6c61\u6c34\u5904\u7406\u5382","location_id":"7944","lat":"23.3993","long":"103.3772","pm25":""},{"location_name":"Houston Croquet C409","location_id":"7945","lat":"29.6239","long":"-95.4742","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"7949","lat":"30.8388","long":"106.1087","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"7955","lat":"30.2366","long":"119.7183","pm25":""},{"location_name":"Valle Alegre","location_id":"7956","lat":"-32.80751","long":"-71.43627","pm25":""},{"location_name":"\u6280\u5de5\u5b66\u6821","location_id":"7962","lat":"34.3739","long":"107.1186","pm25":""},{"location_name":"\u6587\u5316\u8def","location_id":"7963","lat":"30.9285","long":"113.9153","pm25":""},{"location_name":"\u94c1\u8def","location_id":"7964","lat":"41.7381","long":"125.9486","pm25":""},{"location_name":"\u5e02\u6c14\u8c61\u5c40","location_id":"7967","lat":"27.8036","long":"114.9314","pm25":""},{"location_name":"\u5e08\u8303\u5b66\u9662","location_id":"7968","lat":"32.645","long":"117.0083","pm25":""},{"location_name":"\u5dde\u76d1\u6d4b\u7ad9","location_id":"7971","lat":"31.9025","long":"102.2218","pm25":""},{"location_name":"Rancagua II","location_id":"7972","lat":"-34.143887","long":"-70.73713","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"7974","lat":"40.9359","long":"117.963","pm25":""},{"location_name":"Lebanon","location_id":"7975","lat":"39.42689","long":"-84.20077","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"7977","lat":"31.7586","long":"119.996","pm25":""},{"location_name":"Dayuan","location_id":"7978","lat":"25.060345","long":"121.20181","pm25":""},{"location_name":"\u5e02\u75be\u63a7\u4e2d\u5fc3","location_id":"7984","lat":"32.18889","long":"119.43694","pm25":""},{"location_name":"Puzi","location_id":"7985","lat":"23.465307","long":"120.24735","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"7988","lat":"41.1556","long":"122.0247","pm25":""},{"location_name":"\u5e02\u6c14\u8c61\u5c40","location_id":"7990","lat":"23.8982","long":"100.0782","pm25":""},{"location_name":"Nai Mueang, Mueang","location_id":"7994","lat":"14.976786","long":"102.102196","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"7999","lat":"39.9567","long":"119.6023","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u5c40","location_id":"8000","lat":"38.3228","long":"116.8709","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"8001","lat":"33.6067","long":"118.989","pm25":""},{"location_name":"\u5e02\u56fe\u4e66\u9986","location_id":"8003","lat":"25.8333","long":"114.9322","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"8008","lat":"46.7975","long":"130.3258","pm25":""},{"location_name":"Herriman #3","location_id":"8012","lat":"40.496407","long":"-112.03631","pm25":""},{"location_name":"Xitun","location_id":"8013","lat":"24.162197","long":"120.61692","pm25":""},{"location_name":"\u5e02\u4eba\u5927","location_id":"8018","lat":"30.5342","long":"117.0594","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"8021","lat":"36.6622","long":"117.049","pm25":""},{"location_name":"\u6c14\u8c61\u5c40","location_id":"8022","lat":"30.0874","long":"103.8416","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"8028","lat":"26.8733","long":"112.6197","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8029","lat":"40.6532","long":"109.8756","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"8032","lat":"43.9311","long":"116.0781","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8034","lat":"21.2228","long":"110.3928","pm25":""},{"location_name":"\u73af\u4fdd\u5927\u697c","location_id":"8035","lat":"23.6936","long":"113.0425","pm25":""},{"location_name":"Dongshan","location_id":"8041","lat":"24.632202","long":"121.79293","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"8042","lat":"36.1942","long":"117.1436","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"8043","lat":"31.7275","long":"113.3583","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"8044","lat":"25.2697","long":"110.2819","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8046","lat":"33.6128","long":"114.6613","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"8047","lat":"32.8603","long":"115.8556","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"8050","lat":"43.8303","long":"87.5801","pm25":""},{"location_name":"Renwu","location_id":"8066","lat":"22.689056","long":"120.332634","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"8069","lat":"35.4144","long":"116.5856","pm25":""},{"location_name":"\u5e02\u59d4","location_id":"8070","lat":"30.4576","long":"106.6303","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"8075","lat":"27.7314","long":"112.0194","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8076","lat":"39.4365","long":"75.9435","pm25":""},{"location_name":"ARNOLD WEST","location_id":"8077","lat":"38.44858","long":"-90.39844","pm25":""},{"location_name":"BAR-PDLA - Parque de las Aguas","location_id":"8078","lat":"6.4067135","long":"-75.41949","pm25":""},{"location_name":"Bocatoma","location_id":"8079","lat":"-36.803036","long":"-73.12053","pm25":""},{"location_name":"Chennai","location_id":"8080","lat":"13.08784","long":"80.27847","pm25":""},{"location_name":"Hanoi","location_id":"8081","lat":"21.021938","long":"105.81881","pm25":""},{"location_name":"Kolkata","location_id":"8082","lat":"22.56263","long":"88.36304","pm25":""},{"location_name":"Laurel","location_id":"8083","lat":"61.181118","long":"-149.834","pm25":""},{"location_name":"MMCA81014","location_id":"8084","lat":"35.407936","long":"-120.54667","pm25":""},{"location_name":"MMCA81024","location_id":"8086","lat":"41.04713","long":"-123.67522","pm25":""},{"location_name":"MMCA81026","location_id":"8087","lat":"41.528053","long":"-122.3645","pm25":""},{"location_name":"MMNPS1017","location_id":"8089","lat":"41.426773","long":"-122.381065","pm25":""},{"location_name":"Miles Airport","location_id":"8090","lat":"0","long":"0","pm25":""},{"location_name":"Mumbai","location_id":"8091","lat":"19.07283","long":"72.88261","pm25":""},{"location_name":"US Diplomatic Post: Kampala","location_id":"8092","lat":"0.300225","long":"32.591553","pm25":""},{"location_name":"Unit1029","location_id":"8093","lat":"41.728477","long":"-122.52157","pm25":""},{"location_name":"York-Roberval","location_id":"8094","lat":"45.512188","long":"-73.56687","pm25":""},{"location_name":"\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8103","lat":"36.71","long":"117.541","pm25":""},{"location_name":"Cuncumen ","location_id":"8104","lat":"-31.889278","long":"-70.62931","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"8105","lat":"38.4519","long":"112.7383","pm25":""},{"location_name":"\u706b\u8f66\u7ad9","location_id":"8113","lat":"33.63064","long":"116.989","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"8124","lat":"37.5211","long":"111.1406","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"8130","lat":"46.6462","long":"131.1516","pm25":""},{"location_name":"\u6280\u672f\u5b66\u9662","location_id":"8131","lat":"35.4894","long":"112.8664","pm25":""},{"location_name":"Chaozhou","location_id":"8132","lat":"22.523108","long":"120.56117","pm25":""},{"location_name":"\u7b2c\u4e8c\u6c34\u5382","location_id":"8135","lat":"27.8328","long":"114.9289","pm25":""},{"location_name":"\u7b2c\u4e8c\u6c34\u5382","location_id":"8137","lat":"43.941","long":"81.3364","pm25":""},{"location_name":"\u5e02\u7ad9","location_id":"8139","lat":"47.8515","long":"88.1267","pm25":""},{"location_name":"\u5f00\u53d1\u533a\u7ba1\u59d4\u4f1a","location_id":"8140","lat":"28.4303","long":"117.9033","pm25":""},{"location_name":"\u5e02\u73af\u4fdd\u7ad9","location_id":"8142","lat":"24.6928","long":"108.054","pm25":""},{"location_name":"\u5e02\u59d4\u515a\u6821","location_id":"8147","lat":"30.0744","long":"103.8578","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"8148","lat":"40.8333","long":"121.045","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"8152","lat":"22.6411","long":"110.1675","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"8155","lat":"41.9419","long":"126.4078","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"8158","lat":"23.65889","long":"116.6183","pm25":""},{"location_name":"\u5e02\u73af\u5883\u76d1\u6d4b\u7ad9","location_id":"8159","lat":"31.215","long":"107.525","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"8160","lat":"28.4459","long":"117.973","pm25":""},{"location_name":"\u5f00\u53d1\u533a","location_id":"8161","lat":"33.9953","long":"113.7906","pm25":""},{"location_name":"\u76d1\u6d4b\u7ad9","location_id":"8165","lat":"33.975","long":"116.8008","pm25":""},{"location_name":"Changhua","location_id":"8166","lat":"24.066","long":"120.54152","pm25":""},{"location_name":"Tamsui","location_id":"8167","lat":"25.1645","long":"121.44924","pm25":""},{"location_name":"Wanli","location_id":"8168","lat":"25.179667","long":"121.68988","pm25":""},{"location_name":"Xizhi","location_id":"8169","lat":"25.065668","long":"121.6408","pm25":""},{"location_name":"\u73af\u4fdd\u5c40","location_id":"8170","lat":"35.6039","long":"103.2139","pm25":""},{"location_name":"CBD","location_id":"8171","lat":"-34.92889","long":"138.60109","pm25":""},{"location_name":"Christies","location_id":"8172","lat":"-35.134945","long":"138.4952","pm25":""},{"location_name":"Civic","location_id":"8173","lat":"-35.28531","long":"149.13158","pm25":""},{"location_name":"Cook And Phillip","location_id":"8174","lat":"-33.8725","long":"151.21333","pm25":""},{"location_name":"Florey","location_id":"8175","lat":"-35.220608","long":"149.04353","pm25":""},{"location_name":"Goulburn","location_id":"8176","lat":"-34.734444","long":"149.72417","pm25":""},{"location_name":"Gunnedah","location_id":"8177","lat":"-30.981667","long":"150.26056","pm25":""},{"location_name":"Kensington","location_id":"8178","lat":"-34.921406","long":"138.6651","pm25":""},{"location_name":"Le Fevre 1","location_id":"8179","lat":"-34.83867","long":"138.49635","pm25":""},{"location_name":"Le Fevre 2","location_id":"8180","lat":"-34.79128","long":"138.49786","pm25":""},{"location_name":"Macquarie Park","location_id":"8181","lat":"-33.765278","long":"151.11781","pm25":""},{"location_name":"Monash","location_id":"8182","lat":"-35.4183","long":"149.09402","pm25":""},{"location_name":"Narrabri","location_id":"8183","lat":"","long":"","pm25":""},{"location_name":"Netley","location_id":"8184","lat":"-34.9438","long":"138.5491","pm25":""},{"location_name":"Northfield","location_id":"8185","lat":"-34.862015","long":"138.62292","pm25":""},{"location_name":"Orange","location_id":"8186","lat":"-33.274445","long":"149.09444","pm25":""},{"location_name":"Parramatta North","location_id":"8187","lat":"-33.799442","long":"150.99777","pm25":""},{"location_name":"Port Augusta","location_id":"8188","lat":"-32.510006","long":"137.78685","pm25":""},{"location_name":"Port Pirie Oliver St","location_id":"8189","lat":"-33.194794","long":"138.0199","pm25":""},{"location_name":"Rouse Hill","location_id":"8190","lat":"-33.682777","long":"150.90361","pm25":""},{"location_name":"US Diplomatic Post: San Jose","location_id":"8191","lat":"9.949488","long":"-84.142876","pm25":""},{"location_name":"Whyalla Schulz Res","location_id":"8192","lat":"-33.023598","long":"137.53322","pm25":""},{"location_name":"Whyalla Walls St","location_id":"8193","lat":"-33.036118","long":"137.5861","pm25":""},{"location_name":"\u5b89\u5e86\u5927\u5b66(191227\u66f4\u4e3a\u8bc4\u4ef7\u70b9)","location_id":"8194","lat":"30.6145","long":"116.9896","pm25":""},{"location_name":"\u5e02\u4eba\u5927(\u542f\u7528180816)","location_id":"8195","lat":"30.5342","long":"117.0594","pm25":""},{"location_name":"\u68ee\u6797\u516c\u56ed(\u5bf9\u7167\u70b9)","location_id":"8196","lat":"29.8175","long":"114.329","pm25":""},{"location_name":"16th and Whitmore","location_id":"8199","lat":"41.32247","long":"-95.93799","pm25":""},{"location_name":"22nd Street & Craycr","location_id":"8200","lat":"32.205","long":"-110.8772","pm25":""},{"location_name":"2912 Coffey","location_id":"8202","lat":"41.133316","long":"-95.95608","pm25":""},{"location_name":"2LL Los Lunas","location_id":"8203","lat":"34.8147","long":"-106.7397","pm25":""},{"location_name":"60 Near Road","location_id":"8206","lat":"34.0309","long":"-117.6174","pm25":""},{"location_name":"710 Near Road","location_id":"8210","lat":"33.85966","long":"-118.20071","pm25":""},{"location_name":"77th and Dodge","location_id":"8212","lat":"41.25948","long":"-96.03471","pm25":""},{"location_name":"7E Deming Airport","location_id":"8213","lat":"32.2558","long":"-107.7228","pm25":""},{"location_name":"A Street","location_id":"8214","lat":"64.84593","long":"-147.69328","pm25":""},{"location_name":"ADEQ-DSR","location_id":"8217","lat":"34.6811","long":"-92.3283","pm25":""},{"location_name":"AIR LAB","location_id":"8219","lat":"35.9803","long":"-83.9306","pm25":""},{"location_name":"AJ Maintenance Yard","location_id":"8220","lat":"33.4206","long":"-111.5033","pm25":""},{"location_name":"ALLEN PARK","location_id":"8222","lat":"42.2283","long":"-83.2092","pm25":""},{"location_name":"ALSIP","location_id":"8223","lat":"41.6708","long":"-87.7325","pm25":""},{"location_name":"AM1 Gda\u0144sk \u015ar\u00f3dmie\u015bcie","location_id":"8225","lat":"54.353336","long":"18.635283","pm25":""},{"location_name":"AM10 Gdynia \u015ar\u00f3dmie\u015bcie","location_id":"8226","lat":"54.525272","long":"18.536383","pm25":""},{"location_name":"AM11 S\u0142upsk Kniaziewicza","location_id":"8227","lat":"54.46361","long":"17.046722","pm25":""},{"location_name":"AM12 Ko\u015bcierzyna Targowa","location_id":"8228","lat":"54.120693","long":"17.97586","pm25":""},{"location_name":"AM15 Malbork Mickiewicza","location_id":"8229","lat":"54.031246","long":"19.0329","pm25":""},{"location_name":"AM16 L\u0119bork Malczewskiego","location_id":"8230","lat":"54.546165","long":"17.746195","pm25":""},{"location_name":"AM17 Liniewko Ko\u015bcierskie","location_id":"8231","lat":"54.10411","long":"18.182972","pm25":""},{"location_name":"AM2 Gda\u0144sk Stogi","location_id":"8232","lat":"54.36778","long":"18.70111","pm25":""},{"location_name":"AM3 Gda\u0144sk Nowy Port","location_id":"8233","lat":"54.400833","long":"18.657497","pm25":""},{"location_name":"AM4 Gdynia Pog\u00f3rze","location_id":"8234","lat":"54.560837","long":"18.493332","pm25":""},{"location_name":"AM5 Gda\u0144sk Szad\u00f3\u0142ki","location_id":"8235","lat":"54.328335","long":"18.557781","pm25":""},{"location_name":"AM6 Sopot","location_id":"8236","lat":"54.431667","long":"18.579721","pm25":""},{"location_name":"AM8 Gda\u0144sk Wrzeszcz","location_id":"8237","lat":"54.38028","long":"18.620274","pm25":""},{"location_name":"AM9 Gdynia D\u0105browa","location_id":"8238","lat":"54.46576","long":"18.46491","pm25":""},{"location_name":"APOLLO BEACH","location_id":"8240","lat":"27.779713","long":"-82.41984","pm25":""},{"location_name":"APPLETON AAL","location_id":"8241","lat":"44.3069","long":"-88.3956","pm25":""},{"location_name":"ARNOLD WEST","location_id":"8244","lat":"38.44858","long":"-90.39844","pm25":""},{"location_name":"ASHBURN","location_id":"8245","lat":"39.0244","long":"-77.49","pm25":""},{"location_name":"ATHENS","location_id":"8247","lat":"35.4511","long":"-84.5992","pm25":""},{"location_name":"AURORA HILLS","location_id":"8248","lat":"38.8594","long":"-77.0589","pm25":""},{"location_name":"Aberdeen","location_id":"8249","lat":"57.15736","long":"-2.094278","pm25":""},{"location_name":"Aberdeen Union Street Roadside","location_id":"8250","lat":"57.144554","long":"-2.106472","pm25":""},{"location_name":"Aberdeen Wellington Road","location_id":"8251","lat":"57.13389","long":"-2.094198","pm25":""},{"location_name":"Aberdeen-Division St","location_id":"8252","lat":"46.9772","long":"-123.8317","pm25":""},{"location_name":"Abington","location_id":"8253","lat":"41.8402","long":"-72.01","pm25":""},{"location_name":"Acadia NP - McFarlan","location_id":"8254","lat":"44.37705","long":"-68.2609","pm25":""},{"location_name":"Acquapendente","location_id":"8256","lat":"42.73665","long":"11.876578","pm25":""},{"location_name":"Adams","location_id":"8257","lat":"39.82839","long":"-104.93846","pm25":""},{"location_name":"Airponter Wieniec Zdr\u00f3j","location_id":"8258","lat":"52.656864","long":"18.987368","pm25":""},{"location_name":"Ajo","location_id":"8260","lat":"32.382034","long":"-112.85745","pm25":""},{"location_name":"Akron NIFH\/STEM","location_id":"8261","lat":"41.07914","long":"-81.51627","pm25":""},{"location_name":"Alabama-Coushatta","location_id":"8264","lat":"30.6681","long":"-94.6739","pm25":""},{"location_name":"Alamo Lake","location_id":"8265","lat":"34.24389","long":"-113.55861","pm25":""},{"location_name":"Alatri","location_id":"8266","lat":"41.73","long":"13.338333","pm25":""},{"location_name":"Albany","location_id":"8267","lat":"40.3","long":"-85.24556","pm25":""},{"location_name":"Albany - Calapooia S","location_id":"8268","lat":"44.61569","long":"-123.09145","pm25":""},{"location_name":"Albemarle HS","location_id":"8269","lat":"38.0766","long":"-78.504","pm25":""},{"location_name":"Alhambra","location_id":"8273","lat":"38.869","long":"-89.6228","pm25":""},{"location_name":"Allentown","location_id":"8276","lat":"40.6119","long":"-75.4325","pm25":""},{"location_name":"Allumiere","location_id":"8279","lat":"42.15774","long":"11.908744","pm25":""},{"location_name":"Allumiere - v.Aldo Moro","location_id":"8280","lat":"42.160973","long":"11.900022","pm25":""},{"location_name":"Alnabru","location_id":"8281","lat":"59.92773","long":"10.84633","pm25":""},{"location_name":"Alpine","location_id":"8282","lat":"32.842297","long":"-116.768326","pm25":""},{"location_name":"Altoona","location_id":"8284","lat":"40.515","long":"-78.3889","pm25":""},{"location_name":"Alvim","location_id":"8286","lat":"59.273777","long":"11.0891905","pm25":""},{"location_name":"Amanda  Elementary","location_id":"8287","lat":"39.478848","long":"-84.40768","pm25":""},{"location_name":"Amherst","location_id":"8290","lat":"42.9925","long":"-78.7764","pm25":""},{"location_name":"Amman","location_id":"8291","lat":"31.94502","long":"35.8805","pm25":""},{"location_name":"Amsterdam-A10 west","location_id":"8292","lat":"52.3395","long":"4.84102","pm25":""},{"location_name":"Amsterdam-Einsteinweg","location_id":"8293","lat":"52.3813","long":"4.84523","pm25":""},{"location_name":"Amsterdam-Haarlemmerweg","location_id":"8294","lat":"52.3854","long":"4.87575","pm25":""},{"location_name":"Amsterdam-Hoogtij","location_id":"8295","lat":"52.428","long":"4.77348","pm25":""},{"location_name":"Amsterdam-Jan van Galenstraat","location_id":"8296","lat":"52.3748","long":"4.86032","pm25":""},{"location_name":"Amsterdam-Kantershof (Zuid Oost)","location_id":"8297","lat":"52.3207","long":"4.9884","pm25":""},{"location_name":"Amsterdam-Nieuwendammerdijk","location_id":"8298","lat":"52.3893","long":"4.94382","pm25":""},{"location_name":"Amsterdam-Oude Schans","location_id":"8299","lat":"52.3721","long":"4.9044","pm25":""},{"location_name":"Amsterdam-Spaarnwoude","location_id":"8300","lat":"52.3984","long":"4.72858","pm25":""},{"location_name":"Amsterdam-Sportpark Ookmeer (Osdorp)","location_id":"8301","lat":"52.3668","long":"4.79334","pm25":""},{"location_name":"Amsterdam-Stadhouderskade","location_id":"8302","lat":"52.358","long":"4.8997","pm25":""},{"location_name":"Amsterdam-Van Diemenstraat","location_id":"8303","lat":"52.39","long":"4.88781","pm25":""},{"location_name":"Amsterdam-Vondelpark","location_id":"8304","lat":"52.3597","long":"4.86621","pm25":""},{"location_name":"Amsterdam-Westerpark","location_id":"8305","lat":"52.394","long":"4.87016","pm25":""},{"location_name":"Anacortes-202 Ave (S","location_id":"8306","lat":"48.52059","long":"-122.61428","pm25":""},{"location_name":"Anacortes-Bartholome","location_id":"8307","lat":"48.4654","long":"-122.56","pm25":""},{"location_name":"Anagni","location_id":"8308","lat":"41.75","long":"13.149685","pm25":""},{"location_name":"Anaheim","location_id":"8309","lat":"33.830585","long":"-117.93851","pm25":""},{"location_name":"Anaheim Near Road","location_id":"8310","lat":"33.819305","long":"-117.91876","pm25":""},{"location_name":"Anderson","location_id":"8312","lat":"40.4531","long":"-122.2978","pm25":""},{"location_name":"Anderson-Eastside El","location_id":"8313","lat":"40.125557","long":"-85.65222","pm25":""},{"location_name":"Andrew Johnson Elem.","location_id":"8314","lat":"36.526417","long":"-82.52868","pm25":""},{"location_name":"Ann Arbor","location_id":"8315","lat":"42.4164","long":"-83.9019","pm25":""},{"location_name":"Antelope - North Hig","location_id":"8317","lat":"38.71209","long":"-121.38109","pm25":""},{"location_name":"Anthony","location_id":"8318","lat":"32.0036","long":"-106.5992","pm25":""},{"location_name":"Apache Junction","location_id":"8319","lat":"33.42","long":"-111.5042","pm25":""},{"location_name":"Apple Valley","location_id":"8321","lat":"44.7383","long":"-93.2372","pm25":""},{"location_name":"Aprilia 2","location_id":"8322","lat":"41.595345","long":"12.653581","pm25":""},{"location_name":"Aranyaprathet, Aranyaprathet","location_id":"8324","lat":"13.689029","long":"102.50621","pm25":""},{"location_name":"Archbold Biomedical","location_id":"8326","lat":"27.1889","long":"-81.3403","pm25":""},{"location_name":"Arden Arcade - Del P","location_id":"8327","lat":"38.613804","long":"-121.368004","pm25":""},{"location_name":"Arendtsville","location_id":"8329","lat":"39.9233","long":"-77.3081","pm25":""},{"location_name":"Arenula","location_id":"8330","lat":"41.89402","long":"12.475368","pm25":""},{"location_name":"Arlington Municipal","location_id":"8331","lat":"32.6558","long":"-97.0886","pm25":""},{"location_name":"Armagh Roadside","location_id":"8332","lat":"54.35373","long":"-6.654558","pm25":""},{"location_name":"Arvin - Di Giorgio S","location_id":"8335","lat":"35.23918","long":"-118.78863","pm25":""},{"location_name":"Ascarate Park Southe","location_id":"8336","lat":"31.7467","long":"-106.4028","pm25":""},{"location_name":"Ashgabat","location_id":"8337","lat":"37.9415","long":"58.3879","pm25":""},{"location_name":"Ashland","location_id":"8338","lat":"46.604","long":"-68.4135","pm25":""},{"location_name":"Ashland Fire Dept","location_id":"8339","lat":"42.1941","long":"-122.7086","pm25":""},{"location_name":"Aston Hill","location_id":"8343","lat":"52.50385","long":"-3.034178","pm25":""},{"location_name":"Atascadero2","location_id":"8345","lat":"35.494556","long":"-120.66621","pm25":""},{"location_name":"Athens","location_id":"8347","lat":"33.925","long":"-83.3575","pm25":""},{"location_name":"Auburn","location_id":"8350","lat":"38.9378","long":"-121.1039","pm25":""},{"location_name":"Auchencorth Moss","location_id":"8351","lat":"55.79216","long":"-3.2429","pm25":""},{"location_name":"Audubon C38","location_id":"8352","lat":"30.483168","long":"-97.8723","pm25":""},{"location_name":"Augusta","location_id":"8353","lat":"33.4333","long":"-82.0219","pm25":""},{"location_name":"August\u00f3w - mobilne ","location_id":"8354","lat":"53.859528","long":"23.00075","pm25":""},{"location_name":"Aurelia","location_id":"8355","lat":"42.137344","long":"11.793163","pm25":""},{"location_name":"Aurora East","location_id":"8356","lat":"39.638542","long":"-104.56906","pm25":""},{"location_name":"Austin Northwest C3","location_id":"8357","lat":"30.3542","long":"-97.76","pm25":""},{"location_name":"Avon","location_id":"8363","lat":"39.7589","long":"-86.3972","pm25":""},{"location_name":"Azalea","location_id":"8364","lat":"27.7858","long":"-82.74","pm25":""},{"location_name":"Azusa","location_id":"8366","lat":"34.136475","long":"-117.923965","pm25":""},{"location_name":"Bad River Tribal Sch","location_id":"8367","lat":"46.6144","long":"-90.6986","pm25":""},{"location_name":"BADIA","location_id":"8368","lat":"44.6582","long":"10.2894","pm25":""},{"location_name":"BALLIRANA","location_id":"8369","lat":"44.5274","long":"11.9824","pm25":""},{"location_name":"BAY CITY","location_id":"8372","lat":"43.5714","long":"-83.8908","pm25":""},{"location_name":"BAYROAD","location_id":"8373","lat":"30.4744","long":"-88.1411","pm25":""},{"location_name":"BAYVIEW","location_id":"8375","lat":"35.428","long":"-76.74","pm25":""},{"location_name":"BCSP","location_id":"8376","lat":"39.8172","long":"-75.5639","pm25":""},{"location_name":"BDED","location_id":"8377","lat":"35.6062","long":"-82.5844","pm25":""},{"location_name":"BELLFNT2","location_id":"8379","lat":"39.7739","long":"-75.4964","pm25":""},{"location_name":"BESENZONE","location_id":"8380","lat":"44.9895","long":"10.0192","pm25":""},{"location_name":"BLAIR STREET","location_id":"8382","lat":"38.65645","long":"-90.19855","pm25":""},{"location_name":"BOGOLESE","location_id":"8384","lat":"44.8291","long":"10.3915","pm25":""},{"location_name":"BONDVILLE","location_id":"8385","lat":"40.052242","long":"-88.37255","pm25":""},{"location_name":"BOSTON-KENMORE","location_id":"8388","lat":"42.3489","long":"-71.0977","pm25":""},{"location_name":"BRAIDWD","location_id":"8389","lat":"41.2222","long":"-88.1906","pm25":""},{"location_name":"BROADWAY (South)","location_id":"8390","lat":"38.5425","long":"-90.26361","pm25":""},{"location_name":"BRYSON","location_id":"8391","lat":"35.43477","long":"-83.44213","pm25":""},{"location_name":"BUTLER MANUF. CO NEA","location_id":"8394","lat":"39.2828","long":"-78.0814","pm25":""},{"location_name":"Babylon","location_id":"8397","lat":"40.7356","long":"-73.4061","pm25":""},{"location_name":"Badhoevedorp-Sloterweg","location_id":"8398","lat":"52.334","long":"4.77401","pm25":""},{"location_name":"Badlands","location_id":"8399","lat":"43.746944","long":"-101.94111","pm25":""},{"location_name":"Baghdad","location_id":"8401","lat":"33.3128","long":"44.3615","pm25":""},{"location_name":"Baker City - Forest","location_id":"8405","lat":"44.78822","long":"-117.8446","pm25":""},{"location_name":"Bakersfield - Califo","location_id":"8406","lat":"35.356613","long":"-119.062614","pm25":""},{"location_name":"Bakersfield-Muni","location_id":"8407","lat":"35.3313","long":"-119","pm25":""},{"location_name":"Bakke kirke","location_id":"8408","lat":"63.43293","long":"10.41067","pm25":""},{"location_name":"Balk-Trophornsterweg","location_id":"8409","lat":"52.9169","long":"5.57349","pm25":""},{"location_name":"Ballymena Ballykeel","location_id":"8410","lat":"54.861595","long":"-6.250873","pm25":""},{"location_name":"Baltimore County Nea","location_id":"8411","lat":"39.371677","long":"-76.74681","pm25":""},{"location_name":"Ban Dong, Mae Mo","location_id":"8412","lat":"18.419424","long":"99.72704","pm25":""},{"location_name":"Ban Suan, Mueang","location_id":"8413","lat":"13.360626","long":"100.98454","pm25":""},{"location_name":"Bang Kruai, Bang Kruai","location_id":"8416","lat":"13.807158","long":"100.50632","pm25":""},{"location_name":"Bang Nak, Mueang","location_id":"8417","lat":"6.427698","long":"101.82357","pm25":""},{"location_name":"Bang Phut, Pak Kret","location_id":"8418","lat":"13.907827","long":"100.53565","pm25":""},{"location_name":"Bang Sao Thong, Bang Sao Thong","location_id":"8419","lat":"13.567697","long":"100.789406","pm25":""},{"location_name":"Bangel\u00f8kka","location_id":"8420","lat":"59.73325","long":"10.21187","pm25":""},{"location_name":"Bangna, Bangna","location_id":"8421","lat":"13.666116","long":"100.60574","pm25":""},{"location_name":"Bangor MSS","location_id":"8423","lat":"44.817398","long":"-68.77276","pm25":""},{"location_name":"Bankplassen","location_id":"8424","lat":"61.11288","long":"10.46497","pm25":""},{"location_name":"Banning - South Hath","location_id":"8425","lat":"33.920757","long":"-116.85842","pm25":""},{"location_name":"Barnsley Gawber","location_id":"8427","lat":"53.56292","long":"-1.510436","pm25":""},{"location_name":"Barnstaple A39","location_id":"8428","lat":"51.074795","long":"-4.041924","pm25":""},{"location_name":"Barsbeek-De Veenen","location_id":"8430","lat":"52.6541","long":"6.01757","pm25":""},{"location_name":"Barstow","location_id":"8431","lat":"34.894054","long":"-117.02476","pm25":""},{"location_name":"Basin","location_id":"8433","lat":"44.28","long":"-108.04111","pm25":""},{"location_name":"Batavia","location_id":"8434","lat":"39.0828","long":"-84.1441","pm25":""},{"location_name":"Bay Oaks Park","location_id":"8437","lat":"26.4489","long":"-81.9394","pm25":""},{"location_name":"Bayonne","location_id":"8440","lat":"40.67025","long":"-74.12608","pm25":""},{"location_name":"Bayou Plaquemine","location_id":"8441","lat":"30.2211","long":"-91.3153","pm25":""},{"location_name":"Bean","location_id":"8448","lat":"39.4452","long":"-79.0691","pm25":""},{"location_name":"Beaufort","location_id":"8449","lat":"34.8848","long":"-76.6203","pm25":""},{"location_name":"Beaumont C2\/C112","location_id":"8450","lat":"30.0394","long":"-94.0747","pm25":""},{"location_name":"Beaver Falls","location_id":"8451","lat":"40.7478","long":"-80.3167","pm25":""},{"location_name":"Beaverton - Highland","location_id":"8452","lat":"45.4702","long":"-122.8159","pm25":""},{"location_name":"Bee Ridge","location_id":"8453","lat":"27.2906","long":"-82.5072","pm25":""},{"location_name":"Bekkestua","location_id":"8454","lat":"59.9181","long":"10.5839","pm25":""},{"location_name":"Belfast Centre","location_id":"8455","lat":"54.59965","long":"-5.928833","pm25":""},{"location_name":"Belfast Stockman's Lane","location_id":"8456","lat":"54.572586","long":"-5.974944","pm25":""},{"location_name":"Belle Glade","location_id":"8457","lat":"26.724167","long":"-80.663055","pm25":""},{"location_name":"Bellevue-SE 12th","location_id":"8459","lat":"47.600864","long":"-122.1484","pm25":""},{"location_name":"Bellingham Pacifc","location_id":"8460","lat":"48.760036","long":"-122.45647","pm25":""},{"location_name":"Belsk-IGFPAN","location_id":"8463","lat":"51.83512","long":"20.791555","pm25":""},{"location_name":"Beltsville","location_id":"8464","lat":"39.0284","long":"-76.8172","pm25":""},{"location_name":"Bend - Pump Station","location_id":"8466","lat":"44.063915","long":"-121.31255","pm25":""},{"location_name":"Bennington","location_id":"8467","lat":"42.8875","long":"-73.2497","pm25":""},{"location_name":"Bercut Dr","location_id":"8468","lat":"38.593327","long":"-121.50373","pm25":""},{"location_name":"Berkeley Aquatic Par","location_id":"8470","lat":"37.864765","long":"-122.30274","pm25":""},{"location_name":"Bernalillo","location_id":"8471","lat":"35.2994","long":"-106.5483","pm25":""},{"location_name":"Bethel Island","location_id":"8473","lat":"38.00631","long":"-121.641914","pm25":""},{"location_name":"Beverwijk West-Creutzberglaan","location_id":"8475","lat":"52.4893","long":"4.64053","pm25":""},{"location_name":"Bia\u0142aP-Orzechowa","location_id":"8478","lat":"52.029194","long":"23.14939","pm25":""},{"location_name":"Bia\u0142ystok-Miejska","location_id":"8479","lat":"53.12669","long":"23.155869","pm25":""},{"location_name":"Bia\u0142ystok-Warszawska","location_id":"8480","lat":"53.129307","long":"23.181744","pm25":""},{"location_name":"Biddinghuizen-Kuilweg","location_id":"8482","lat":"52.4232","long":"5.59338","pm25":""},{"location_name":"Bielsko-Bia\u0142a, ul. Kossak-Szczuckiej 19","location_id":"8483","lat":"49.813465","long":"19.027317","pm25":""},{"location_name":"Bielsko-Bia\u0142a, ul.Partyzant\u00f3w","location_id":"8484","lat":"49.802074","long":"19.04861","pm25":""},{"location_name":"Biest Houtakker-Biestsestraat","location_id":"8485","lat":"51.5184","long":"5.14845","pm25":""},{"location_name":"Big Bend  NP","location_id":"8486","lat":"29.3025","long":"-103.1781","pm25":""},{"location_name":"Big Piney","location_id":"8488","lat":"42.486668","long":"-110.09917","pm25":""},{"location_name":"Billingham","location_id":"8491","lat":"54.60537","long":"-1.275039","pm25":""},{"location_name":"Billings Coburn Rd","location_id":"8492","lat":"45.78658","long":"-108.45878","pm25":""},{"location_name":"Billlings Lockwood","location_id":"8494","lat":"45.80636","long":"-108.42655","pm25":""},{"location_name":"Birkenesobservatoriet","location_id":"8495","lat":"58.38846","long":"8.2519","pm25":""},{"location_name":"Birkenhead Borough Road","location_id":"8496","lat":"53.38851","long":"-3.025014","pm25":""},{"location_name":"Birmingham A4540 Roadside","location_id":"8497","lat":"52.47609","long":"-1.875024","pm25":""},{"location_name":"Birmingham Acocks Green","location_id":"8498","lat":"52.437164","long":"-1.829999","pm25":""},{"location_name":"Birney","location_id":"8501","lat":"45.36615","long":"-106.48982","pm25":""},{"location_name":"Bishkek","location_id":"8502","lat":"42.827625","long":"74.58384","pm25":""},{"location_name":"Bklyn - PS 314","location_id":"8504","lat":"40.64182","long":"-74.01871","pm25":""},{"location_name":"Bklyn - PS274","location_id":"8505","lat":"40.6944","long":"-73.9286","pm25":""},{"location_name":"Black Hawk","location_id":"8506","lat":"44.155636","long":"-103.315765","pm25":""},{"location_name":"Blackburn Accrington Road","location_id":"8507","lat":"53.74775","long":"-2.452724","pm25":""},{"location_name":"Blackpool Marton","location_id":"8508","lat":"53.80489","long":"-3.007175","pm25":""},{"location_name":"Blackwater NWR","location_id":"8510","lat":"38.445","long":"-76.1114","pm25":""},{"location_name":"Blaine","location_id":"8511","lat":"45.1425","long":"-93.2139","pm25":""},{"location_name":"Blind Services; 1185","location_id":"8512","lat":"29.2069","long":"-81.0531","pm25":""},{"location_name":"Bloomfield","location_id":"8513","lat":"36.7422","long":"-107.9769","pm25":""},{"location_name":"Blue Point Sheriff S","location_id":"8515","lat":"33.5455","long":"-111.6093","pm25":""},{"location_name":"Blue Ridge I-70","location_id":"8516","lat":"39.047913","long":"-94.450516","pm25":""},{"location_name":"Blythe","location_id":"8517","lat":"33.61235","long":"-114.60209","pm25":""},{"location_name":"Boise Eastman","location_id":"8518","lat":"43.61638","long":"-116.20382","pm25":""},{"location_name":"Boise Fire Station","location_id":"8519","lat":"43.61889","long":"-116.21361","pm25":""},{"location_name":"Bondville","location_id":"8520","lat":"40.0519","long":"-88.3724","pm25":""},{"location_name":"Bonifay","location_id":"8521","lat":"30.8475","long":"-85.6044","pm25":""},{"location_name":"Boonville","location_id":"8522","lat":"38.0519","long":"-87.2783","pm25":""},{"location_name":"Borowiec-Drapalka","location_id":"8524","lat":"52.276794","long":"17.074114","pm25":""},{"location_name":"Borsukowizna-Wiejska","location_id":"8525","lat":"53.215492","long":"23.642153","pm25":""},{"location_name":"Bory Tucholskie","location_id":"8526","lat":"53.662117","long":"17.934017","pm25":""},{"location_name":"Boston - Roxbury","location_id":"8528","lat":"42.3294","long":"-71.0825","pm25":""},{"location_name":"Boston-Von Hillern","location_id":"8529","lat":"42.325195","long":"-71.05605","pm25":""},{"location_name":"Boulder","location_id":"8532","lat":"42.7186","long":"-109.7531","pm25":""},{"location_name":"Boulder - CU - 2102","location_id":"8533","lat":"40.0128","long":"-105.2667","pm25":""},{"location_name":"Boulder City","location_id":"8534","lat":"35.97815","long":"-114.84631","pm25":""},{"location_name":"Boulder Creek","location_id":"8535","lat":"37.125862","long":"-122.12212","pm25":""},{"location_name":"Boulder Reservoir","location_id":"8536","lat":"40.070007","long":"-105.22023","pm25":""},{"location_name":"Bournemouth","location_id":"8539","lat":"50.73957","long":"-1.826744","pm25":""},{"location_name":"Bozeman High School","location_id":"8542","lat":"45.683765","long":"-111.05628","pm25":""},{"location_name":"Bradford Mayo Avenue","location_id":"8545","lat":"53.771244","long":"-1.759774","pm25":""},{"location_name":"Brainerd","location_id":"8547","lat":"46.3944","long":"-94.1433","pm25":""},{"location_name":"Branch Street","location_id":"8548","lat":"38.65643","long":"-90.18977","pm25":""},{"location_name":"Brawley - 220 Main S","location_id":"8550","lat":"32.9783","long":"-115.5383","pm25":""},{"location_name":"Breda-Bastenakenstraat","location_id":"8551","lat":"51.6031","long":"4.78102","pm25":""},{"location_name":"Breda-Tilburgseweg","location_id":"8552","lat":"51.5935","long":"4.82494","pm25":""},{"location_name":"Bremerton-Spruce Ave","location_id":"8554","lat":"47.592674","long":"-122.627396","pm25":""},{"location_name":"Breukelen-Snelweg","location_id":"8555","lat":"52.2015","long":"4.98744","pm25":""},{"location_name":"Bridgeport","location_id":"8558","lat":"41.1714","long":"-73.1953","pm25":""},{"location_name":"Brigantine","location_id":"8560","lat":"39.46487","long":"-74.44874","pm25":""},{"location_name":"Brighton Preston Park","location_id":"8562","lat":"50.840836","long":"-0.147572","pm25":""},{"location_name":"Brighton Township","location_id":"8563","lat":"40.6847","long":"-80.3597","pm25":""},{"location_name":"Bristol","location_id":"8564","lat":"41.7178","long":"-85.8247","pm25":""},{"location_name":"Bristol St Paul's","location_id":"8565","lat":"51.462837","long":"-2.584482","pm25":""},{"location_name":"Broadus","location_id":"8566","lat":"45.440296","long":"-105.37028","pm25":""},{"location_name":"Brockton","location_id":"8567","lat":"42.06512","long":"-71.01269","pm25":""},{"location_name":"Bronx - IS52","location_id":"8568","lat":"40.8161","long":"-73.9022","pm25":""},{"location_name":"Bronx - IS74","location_id":"8569","lat":"40.8147","long":"-73.8867","pm25":""},{"location_name":"Brownstown","location_id":"8571","lat":"38.920834","long":"-86.08052","pm25":""},{"location_name":"Bryn skole","location_id":"8574","lat":"59.914104","long":"10.82263","pm25":""},{"location_name":"Buckeye","location_id":"8576","lat":"33.37","long":"-112.6207","pm25":""},{"location_name":"Bufalotta","location_id":"8577","lat":"41.947647","long":"12.533682","pm25":""},{"location_name":"Buffalo","location_id":"8578","lat":"41.4672","long":"-90.6883","pm25":""},{"location_name":"Buffalo Near-road","location_id":"8579","lat":"42.92111","long":"-78.76611","pm25":""},{"location_name":"Buick NE","location_id":"8580","lat":"37.65214","long":"-91.11653","pm25":""},{"location_name":"Bullhead City","location_id":"8582","lat":"35.16611","long":"-114.56611","pm25":""},{"location_name":"Burbank-Maple Street","location_id":"8584","lat":"46.2001","long":"-119.0084","pm25":""},{"location_name":"Burdens Creek","location_id":"8585","lat":"35.8894","long":"-78.8747","pm25":""},{"location_name":"Burlington","location_id":"8586","lat":"44.4761","long":"-73.2103","pm25":""},{"location_name":"Burns - Washington S","location_id":"8588","lat":"43.58925","long":"-119.0483","pm25":""},{"location_name":"Bury Whitefield Roadside","location_id":"8589","lat":"53.55903","long":"-2.293772","pm25":""},{"location_name":"Bush Estate","location_id":"8590","lat":"55.86228","long":"-3.205782","pm25":""},{"location_name":"Butte (Harrison Cour","location_id":"8592","lat":"61.534164","long":"-149.03166","pm25":""},{"location_name":"Butte Greely School","location_id":"8593","lat":"46.0024","long":"-112.50089","pm25":""},{"location_name":"Bydgoszcz Plac Pozna\u0144ski","location_id":"8594","lat":"53.121765","long":"17.987906","pm25":""},{"location_name":"Bydgoszcz Warszawska","location_id":"8595","lat":"53.134083","long":"17.995708","pm25":""},{"location_name":"Bygd\u00f8y Alle","location_id":"8596","lat":"59.91898","long":"10.69707","pm25":""},{"location_name":"C GRANDE","location_id":"8598","lat":"32.9544","long":"-111.7622","pm25":""},{"location_name":"CAORLE","location_id":"8601","lat":"44.4193","long":"12.2254","pm25":""},{"location_name":"CARPENTER","location_id":"8603","lat":"41.6031","long":"-93.6433","pm25":""},{"location_name":"CARTHAGE","location_id":"8604","lat":"37.19822","long":"-94.31702","pm25":""},{"location_name":"CARY","location_id":"8605","lat":"42.2211","long":"-88.2411","pm25":""},{"location_name":"CASTELLARANO","location_id":"8607","lat":"44.5162","long":"10.7339","pm25":""},{"location_name":"CASTELLUCCIO","location_id":"8608","lat":"44.1404","long":"10.9172","pm25":""},{"location_name":"CASTLE H","location_id":"8609","lat":"34.364166","long":"-77.83861","pm25":""},{"location_name":"CCNY","location_id":"8610","lat":"40.8197","long":"-73.9481","pm25":""},{"location_name":"CC_Armory","location_id":"8611","lat":"39.144802","long":"-119.76641","pm25":""},{"location_name":"CENO","location_id":"8613","lat":"45.0544","long":"9.7269","pm25":""},{"location_name":"CENTO","location_id":"8614","lat":"44.733","long":"11.2997","pm25":""},{"location_name":"CHARLESTON","location_id":"8615","lat":"38.346256","long":"-81.62116","pm25":""},{"location_name":"CHERRYGR","location_id":"8617","lat":"36.307034","long":"-79.467415","pm25":""},{"location_name":"CHICK.","location_id":"8618","lat":"30.7697","long":"-88.0875","pm25":""},{"location_name":"CHICOPEE","location_id":"8619","lat":"42.1944","long":"-72.5556","pm25":""},{"location_name":"CHIWAUKEE","location_id":"8620","lat":"42.5047","long":"-87.8111","pm25":""},{"location_name":"CHI_COM","location_id":"8621","lat":"41.7547","long":"-87.7136","pm25":""},{"location_name":"CHI_SWFP","location_id":"8623","lat":"41.7558","long":"-87.5453","pm25":""},{"location_name":"CHI_TAFT","location_id":"8624","lat":"41.9844","long":"-87.7919","pm25":""},{"location_name":"CICERO","location_id":"8625","lat":"41.8553","long":"-87.7525","pm25":""},{"location_name":"CITTADELLA","location_id":"8626","lat":"44.7924","long":"10.331","pm25":""},{"location_name":"CLEVELAND","location_id":"8627","lat":"33.75083","long":"-90.73417","pm25":""},{"location_name":"COMBS","location_id":"8633","lat":"33.2192","long":"-111.5608","pm25":""},{"location_name":"CORNER","location_id":"8635","lat":"33.8017","long":"-86.9425","pm25":""},{"location_name":"CORTE BRUGNATELLA","location_id":"8636","lat":"44.7347","long":"9.3669","pm25":""},{"location_name":"CTCLUSI Radar Hill-O","location_id":"8638","lat":"43.381943","long":"-124.263885","pm25":""},{"location_name":"CZ0ABRE","location_id":"8639","lat":"50.084385","long":"14.380116","pm25":""},{"location_name":"CZ0AKAL","location_id":"8640","lat":"50.09424","long":"14.442049","pm25":""},{"location_name":"CZ0AKOB","location_id":"8641","lat":"50.12219","long":"14.467578","pm25":""},{"location_name":"CZ0ALEG","location_id":"8642","lat":"50.072388","long":"14.430673","pm25":""},{"location_name":"CZ0ALIB","location_id":"8643","lat":"50.007305","long":"14.445933","pm25":""},{"location_name":"CZ0APRU","location_id":"8644","lat":"50.062298","long":"14.53782","pm25":""},{"location_name":"CZ0AREP","location_id":"8645","lat":"50.088066","long":"14.42922","pm25":""},{"location_name":"CZ0ARIE","location_id":"8646","lat":"50.081482","long":"14.442692","pm25":""},{"location_name":"CZ0ASTO","location_id":"8648","lat":"50.04613","long":"14.331413","pm25":""},{"location_name":"CZ0ASUC","location_id":"8649","lat":"50.12653","long":"14.384639","pm25":""},{"location_name":"CZ0AVRS","location_id":"8650","lat":"50.06643","long":"14.446152","pm25":""},{"location_name":"CZ0AVYN","location_id":"8651","lat":"50.11108","long":"14.503096","pm25":""},{"location_name":"CZ0BBDN","location_id":"8652","lat":"49.202724","long":"16.616287","pm25":""},{"location_name":"CZ0BBNI","location_id":"8653","lat":"49.21321","long":"16.678024","pm25":""},{"location_name":"CZ0BBNV","location_id":"8654","lat":"49.19809","long":"16.593643","pm25":""},{"location_name":"CZ0BBNY","location_id":"8655","lat":"49.14897","long":"16.696217","pm25":""},{"location_name":"CZ0BKUC","location_id":"8656","lat":"48.881355","long":"16.085817","pm25":""},{"location_name":"CZ0BMIS","location_id":"8657","lat":"48.791767","long":"16.724497","pm25":""},{"location_name":"CZ0BZNO","location_id":"8658","lat":"48.842957","long":"16.060127","pm25":""},{"location_name":"CZ0CCBD","location_id":"8659","lat":"48.984386","long":"14.465684","pm25":""},{"location_name":"CZ0CCHU","location_id":"8660","lat":"49.068436","long":"13.614801","pm25":""},{"location_name":"CZ0CHVO","location_id":"8661","lat":"48.724197","long":"14.723382","pm25":""},{"location_name":"CZ0CKOC","location_id":"8662","lat":"49.467243","long":"13.838234","pm25":""},{"location_name":"CZ0CPRA","location_id":"8663","lat":"49.016087","long":"14.000444","pm25":""},{"location_name":"CZ0CTAB","location_id":"8664","lat":"49.411232","long":"14.676389","pm25":""},{"location_name":"CZ0EMTP","location_id":"8665","lat":"49.758995","long":"16.666721","pm25":""},{"location_name":"CZ0EPAO","location_id":"8666","lat":"50.0422","long":"15.739414","pm25":""},{"location_name":"CZ0EPAU","location_id":"8667","lat":"50.024036","long":"15.763549","pm25":""},{"location_name":"CZ0ESVR","location_id":"8668","lat":"49.735085","long":"16.034197","pm25":""},{"location_name":"CZ0HHKB","location_id":"8669","lat":"50.195362","long":"15.846376","pm25":""},{"location_name":"CZ0HHKO","location_id":"8670","lat":"50.17763","long":"15.83839","pm25":""},{"location_name":"CZ0HPLO","location_id":"8672","lat":"50.350277","long":"16.3225","pm25":""},{"location_name":"CZ0HTRT","location_id":"8673","lat":"50.56588","long":"15.903927","pm25":""},{"location_name":"CZ0JJIH","location_id":"8674","lat":"49.401596","long":"15.610246","pm25":""},{"location_name":"CZ0JKMY","location_id":"8675","lat":"49.159153","long":"15.439048","pm25":""},{"location_name":"CZ0JKOS","location_id":"8676","lat":"49.573395","long":"15.080278","pm25":""},{"location_name":"CZ0JTRE","location_id":"8677","lat":"49.22344","long":"15.865778","pm25":""},{"location_name":"CZ0KCHM","location_id":"8678","lat":"50.06586","long":"12.363442","pm25":""},{"location_name":"CZ0KPRB","location_id":"8679","lat":"50.37248","long":"12.61538","pm25":""},{"location_name":"CZ0KSOM","location_id":"8680","lat":"50.172825","long":"12.672818","pm25":""},{"location_name":"CZ0LCLM","location_id":"8681","lat":"50.698044","long":"14.537345","pm25":""},{"location_name":"CZ0LFRT","location_id":"8682","lat":"50.94065","long":"15.069817","pm25":""},{"location_name":"CZ0LLIL","location_id":"8683","lat":"50.7551","long":"15.069967","pm25":""},{"location_name":"CZ0LSOU","location_id":"8684","lat":"50.789646","long":"15.319683","pm25":""},{"location_name":"CZ0MJES","location_id":"8685","lat":"50.24224","long":"17.19018","pm25":""},{"location_name":"CZ0MOLJ","location_id":"8686","lat":"49.601463","long":"17.238073","pm25":""},{"location_name":"CZ0MPRR","location_id":"8687","lat":"49.451656","long":"17.454159","pm25":""},{"location_name":"CZ0MPST","location_id":"8688","lat":"49.467857","long":"17.114725","pm25":""},{"location_name":"CZ0PKUJ","location_id":"8689","lat":"49.722","long":"13.618538","pm25":""},{"location_name":"CZ0PPLA","location_id":"8690","lat":"49.73245","long":"13.402281","pm25":""},{"location_name":"CZ0PPLE","location_id":"8691","lat":"49.74733","long":"13.381039","pm25":""},{"location_name":"CZ0PPLL","location_id":"8692","lat":"49.770126","long":"13.368221","pm25":""},{"location_name":"CZ0PPLV","location_id":"8693","lat":"49.768616","long":"13.423381","pm25":""},{"location_name":"CZ0PPRM","location_id":"8694","lat":"49.669582","long":"12.677884","pm25":""},{"location_name":"CZ0SBER","location_id":"8695","lat":"49.957928","long":"14.0583","pm25":""},{"location_name":"CZ0SKLM","location_id":"8696","lat":"50.14386","long":"14.101784","pm25":""},{"location_name":"CZ0SKLS","location_id":"8697","lat":"50.16741","long":"14.106048","pm25":""},{"location_name":"CZ0SMBO","location_id":"8698","lat":"50.428646","long":"14.913859","pm25":""},{"location_name":"CZ0SONR","location_id":"8699","lat":"49.913513","long":"14.782625","pm25":""},{"location_name":"CZ0SROR","location_id":"8700","lat":"50.301983","long":"15.178303","pm25":""},{"location_name":"CZ0TBKR","location_id":"8701","lat":"49.50261","long":"18.53856","pm25":""},{"location_name":"CZ0TCER","location_id":"8702","lat":"49.77714","long":"17.541946","pm25":""},{"location_name":"CZ0TCTN","location_id":"8703","lat":"49.74896","long":"18.609726","pm25":""},{"location_name":"CZ0TFMI","location_id":"8704","lat":"49.67179","long":"18.35107","pm25":""},{"location_name":"CZ0THAR","location_id":"8705","lat":"49.790977","long":"18.406836","pm25":""},{"location_name":"CZ0TKAR","location_id":"8706","lat":"49.863796","long":"18.551453","pm25":""},{"location_name":"CZ0TOCB","location_id":"8707","lat":"49.839848","long":"18.289976","pm25":""},{"location_name":"CZ0TOFF","location_id":"8708","lat":"49.839188","long":"18.263689","pm25":""},{"location_name":"CZ0TOPO","location_id":"8709","lat":"49.825294","long":"18.159275","pm25":""},{"location_name":"CZ0TOPR","location_id":"8710","lat":"49.856262","long":"18.269756","pm25":""},{"location_name":"CZ0TOVK","location_id":"8711","lat":"49.94499","long":"17.90953","pm25":""},{"location_name":"CZ0TOZR","location_id":"8712","lat":"49.79604","long":"18.24718","pm25":""},{"location_name":"CZ0TSTD","location_id":"8713","lat":"49.720936","long":"18.089306","pm25":""},{"location_name":"CZ0TTRK","location_id":"8714","lat":"49.67238","long":"18.643038","pm25":""},{"location_name":"CZ0TTRO","location_id":"8715","lat":"49.668114","long":"18.6778","pm25":""},{"location_name":"CZ0TVER","location_id":"8716","lat":"49.92468","long":"18.422873","pm25":""},{"location_name":"CZ0UCHM","location_id":"8717","lat":"50.46753","long":"13.412696","pm25":""},{"location_name":"CZ0UDCM","location_id":"8718","lat":"50.77415","long":"14.218794","pm25":""},{"location_name":"CZ0UDOK","location_id":"8719","lat":"50.458855","long":"14.170162","pm25":""},{"location_name":"CZ0UKRU","location_id":"8720","lat":"50.69667","long":"13.847692","pm25":""},{"location_name":"CZ0ULOM","location_id":"8721","lat":"50.585766","long":"13.673418","pm25":""},{"location_name":"CZ0ULTT","location_id":"8722","lat":"50.540897","long":"14.119409","pm25":""},{"location_name":"CZ0UMED","location_id":"8723","lat":"50.42759","long":"13.130143","pm25":""},{"location_name":"CZ0UMOM","location_id":"8724","lat":"50.510365","long":"13.645272","pm25":""},{"location_name":"CZ0URVH","location_id":"8725","lat":"50.579834","long":"13.419506","pm25":""},{"location_name":"CZ0USNZ","location_id":"8726","lat":"50.789444","long":"14.086799","pm25":""},{"location_name":"CZ0UTPM","location_id":"8727","lat":"50.64528","long":"13.85125","pm25":""},{"location_name":"CZ0UTUS","location_id":"8728","lat":"50.376587","long":"13.327622","pm25":""},{"location_name":"CZ0UULD","location_id":"8729","lat":"50.683125","long":"13.997873","pm25":""},{"location_name":"CZ0UULK","location_id":"8730","lat":"50.683525","long":"14.041195","pm25":""},{"location_name":"CZ0UULM","location_id":"8731","lat":"50.661095","long":"14.043063","pm25":""},{"location_name":"CZ0ZSNV","location_id":"8732","lat":"49.047817","long":"18.007828","pm25":""},{"location_name":"CZ0ZTNV","location_id":"8733","lat":"49.25939","long":"17.41056","pm25":""},{"location_name":"CZ0ZUHR","location_id":"8734","lat":"49.06795","long":"17.466848","pm25":""},{"location_name":"CZ0ZVMZ","location_id":"8735","lat":"49.472057","long":"17.966976","pm25":""},{"location_name":"CZ0ZZLN","location_id":"8736","lat":"49.232906","long":"17.667175","pm25":""},{"location_name":"Cabauw-Wielsekade","location_id":"8737","lat":"51.9745","long":"4.9233","pm25":""},{"location_name":"Caddo Valley","location_id":"8738","lat":"34.1795","long":"-93.0988","pm25":""},{"location_name":"Calaveras Lake C59","location_id":"8740","lat":"29.2753","long":"-98.3117","pm25":""},{"location_name":"Calexico - Ethel Str","location_id":"8741","lat":"32.67618","long":"-115.48307","pm25":""},{"location_name":"Cambridge Roadside","location_id":"8744","lat":"52.20237","long":"0.124456","pm25":""},{"location_name":"Camden Kerbside","location_id":"8745","lat":"51.54421","long":"-0.175269","pm25":""},{"location_name":"Camden Spruce St","location_id":"8746","lat":"39.934444","long":"-75.12529","pm25":""},{"location_name":"Camp Bullis C58","location_id":"8747","lat":"29.6322","long":"-98.565","pm25":""},{"location_name":"Camp Pendleton","location_id":"8748","lat":"33.217026","long":"-117.39616","pm25":""},{"location_name":"Campo dell'Oro","location_id":"8752","lat":"42.081825","long":"11.809336","pm25":""},{"location_name":"Candor","location_id":"8754","lat":"35.26","long":"-79.84","pm25":""},{"location_name":"Candor FRO","location_id":"8755","lat":"35.263165","long":"-79.83664","pm25":""},{"location_name":"Cannock A5190 Roadside","location_id":"8757","lat":"52.687298","long":"-1.980821","pm25":""},{"location_name":"Cannons Lane","location_id":"8758","lat":"38.2286","long":"-85.6544","pm25":""},{"location_name":"Canterbury","location_id":"8759","lat":"51.27399","long":"1.098061","pm25":""},{"location_name":"Canton","location_id":"8760","lat":"40.800716","long":"-81.373","pm25":""},{"location_name":"Canton DRR","location_id":"8762","lat":"35.534","long":"-82.853","pm25":""},{"location_name":"Canyonlands NP","location_id":"8763","lat":"38.4583","long":"-109.8211","pm25":""},{"location_name":"Cape Coral Fire Stat","location_id":"8764","lat":"26.5475","long":"-81.9797","pm25":""},{"location_name":"Cape Elizabeth","location_id":"8765","lat":"43.561043","long":"-70.20732","pm25":""},{"location_name":"Cape Romain","location_id":"8766","lat":"32.941","long":"-79.657","pm25":""},{"location_name":"Capitol","location_id":"8767","lat":"30.4622","long":"-91.1769","pm25":""},{"location_name":"Cardiff Centre","location_id":"8768","lat":"51.48178","long":"-3.17625","pm25":""},{"location_name":"Carlisle","location_id":"8769","lat":"40.2464","long":"-77.1867","pm25":""},{"location_name":"Carlisle Roadside","location_id":"8770","lat":"54.894833","long":"-2.945307","pm25":""},{"location_name":"Carlsbad","location_id":"8771","lat":"32.38","long":"-104.2622","pm25":""},{"location_name":"Carlyss","location_id":"8772","lat":"30.1433","long":"-93.3719","pm25":""},{"location_name":"Carpinteria","location_id":"8775","lat":"34.4028","long":"-119.4575","pm25":""},{"location_name":"Carrithers Middle Sc","location_id":"8777","lat":"38.1825","long":"-85.5744","pm25":""},{"location_name":"Carrizo","location_id":"8778","lat":"35.35474","long":"-120.04013","pm25":""},{"location_name":"Carville","location_id":"8780","lat":"30.1975","long":"-91.1283","pm25":""},{"location_name":"Casa Grande Downtown","location_id":"8781","lat":"32.877583","long":"-111.85222","pm25":""},{"location_name":"CasaBlanca","location_id":"8782","lat":"33.11753","long":"-111.88491","pm25":""},{"location_name":"Casino Center","location_id":"8783","lat":"36.174366","long":"-115.13977","pm25":""},{"location_name":"Casper Gaseous","location_id":"8784","lat":"42.82231","long":"-106.36501","pm25":""},{"location_name":"Cassino","location_id":"8786","lat":"41.49","long":"13.83069","pm25":""},{"location_name":"Castel di Guido","location_id":"8787","lat":"41.88944","long":"12.2663","pm25":""},{"location_name":"Catawba Indian Natio","location_id":"8788","lat":"34.91263","long":"-80.87428","pm25":""},{"location_name":"Cata\u00f1o 40","location_id":"8790","lat":"18.428389","long":"-66.141655","pm25":""},{"location_name":"Causeway Bay","location_id":"8791","lat":"22.28","long":"114.185","pm25":""},{"location_name":"Cavaliere","location_id":"8792","lat":"41.929382","long":"12.658363","pm25":""},{"location_name":"Cave Creek","location_id":"8793","lat":"33.8217","long":"-112.0174","pm25":""},{"location_name":"Cave Junction Forest","location_id":"8794","lat":"42.1617","long":"-123.64835","pm25":""},{"location_name":"Cayce City Hall","location_id":"8795","lat":"33.969147","long":"-81.06629","pm25":""},{"location_name":"Ceccano","location_id":"8797","lat":"41.57","long":"13.33719","pm25":""},{"location_name":"Cedar Bay","location_id":"8798","lat":"30.43111","long":"-81.63194","pm25":""},{"location_name":"Cedar Bluff","location_id":"8799","lat":"38.7703","long":"-99.7636","pm25":""},{"location_name":"Cedar Creek","location_id":"8800","lat":"38.8795","long":"-80.8477","pm25":""},{"location_name":"Celje","location_id":"8801","lat":"46.234474","long":"15.262438","pm25":""},{"location_name":"Centennial","location_id":"8802","lat":"41.3642","long":"-106.2399","pm25":""},{"location_name":"Central","location_id":"8804","lat":"22.281944","long":"114.15806","pm25":""},{"location_name":"Central Phoenix","location_id":"8805","lat":"33.4579","long":"-112.046","pm25":""},{"location_name":"Central\/Western","location_id":"8806","lat":"22.285","long":"114.14445","pm25":""},{"location_name":"Chaco Culture Nation","location_id":"8807","lat":"36.035","long":"-107.90417","pm25":""},{"location_name":"Chalmette Vista","location_id":"8809","lat":"29.9431","long":"-89.9761","pm25":""},{"location_name":"Chamizal C41","location_id":"8810","lat":"31.7656","long":"-106.455","pm25":""},{"location_name":"Chang Phueak, Mueang","location_id":"8811","lat":"","long":"","pm25":""},{"location_name":"Channelview C15","location_id":"8812","lat":"29.8025","long":"-95.1256","pm25":""},{"location_name":"Chanute","location_id":"8814","lat":"37.67696","long":"-95.47594","pm25":""},{"location_name":"Chaparral","location_id":"8815","lat":"32.0411","long":"-106.4092","pm25":""},{"location_name":"Charleroi","location_id":"8816","lat":"40.1469","long":"-79.9033","pm25":""},{"location_name":"Charlestown State Pa","location_id":"8818","lat":"38.393833","long":"-85.66417","pm25":""},{"location_name":"Charlton Mackrell","location_id":"8819","lat":"51.05625","long":"-2.68345","pm25":""},{"location_name":"Chatfield Park - 115","location_id":"8820","lat":"39.5339","long":"-105.07","pm25":""},{"location_name":"Chatham Roadside","location_id":"8821","lat":"51.374264","long":"0.54797","pm25":""},{"location_name":"Cheeka Peak","location_id":"8823","lat":"48.2867","long":"-124.6203","pm25":""},{"location_name":"Chehalis-Market Blvd","location_id":"8824","lat":"46.66409","long":"-122.96732","pm25":""},{"location_name":"Chelan-Woodin Ave","location_id":"8825","lat":"47.83861","long":"-120.02306","pm25":""},{"location_name":"Chelmsford","location_id":"8826","lat":"42.6267","long":"-71.3622","pm25":""},{"location_name":"ChelmsfordNR","location_id":"8827","lat":"42.612114","long":"-71.30752","pm25":""},{"location_name":"Cheney-Turnbull (SO)","location_id":"8829","lat":"47.4164","long":"-117.5298","pm25":""},{"location_name":"Chepstow A48","location_id":"8830","lat":"51.638096","long":"-2.678731","pm25":""},{"location_name":"Cheshire","location_id":"8831","lat":"38.949978","long":"-82.1101","pm25":""},{"location_name":"Chester","location_id":"8832","lat":"39.8356","long":"-75.3725","pm25":""},{"location_name":"Chester BAM","location_id":"8833","lat":"40.3019","long":"-121.235","pm25":""},{"location_name":"Chesterfield","location_id":"8834","lat":"34.6153","long":"-80.1989","pm25":""},{"location_name":"Chesterfield Loundsley Green","location_id":"8835","lat":"53.24413","long":"-1.454946","pm25":""},{"location_name":"Chesterfield Roadside","location_id":"8836","lat":"53.231724","long":"-1.456944","pm25":""},{"location_name":"Cheyenne NCore","location_id":"8838","lat":"41.18222","long":"-104.778336","pm25":""},{"location_name":"Che\u0142m ul.Po\u0142aniecka","location_id":"8839","lat":"51.12219","long":"23.47287","pm25":""},{"location_name":"Chico -  East","location_id":"8840","lat":"39.76168","long":"-121.84047","pm25":""},{"location_name":"Chilbolton Observatory","location_id":"8841","lat":"51.149616","long":"-1.438228","pm25":""},{"location_name":"Children's Park Site","location_id":"8842","lat":"32.2953","long":"-110.9822","pm25":""},{"location_name":"Chiloquin","location_id":"8843","lat":"42.541077","long":"-121.92164","pm25":""},{"location_name":"Chippewa Lake","location_id":"8845","lat":"41.0604","long":"-81.9239","pm25":""},{"location_name":"Chiricahua NM","location_id":"8846","lat":"32.0092","long":"-109.3892","pm25":""},{"location_name":"Choctaw","location_id":"8847","lat":"35.4778","long":"-97.3022","pm25":""},{"location_name":"Chong Kham, Mueang","location_id":"8848","lat":"19.3045","long":"97.97153","pm25":""},{"location_name":"Chong Nonsi, Yannawa","location_id":"8849","lat":"13.708041","long":"100.54735","pm25":""},{"location_name":"Christchurch Barrack Road","location_id":"8850","lat":"50.735455","long":"-1.780888","pm25":""},{"location_name":"Chula Vista","location_id":"8851","lat":"32.63123","long":"-117.059074","pm25":""},{"location_name":"Church","location_id":"8852","lat":"36.159637","long":"-115.99626","pm25":""},{"location_name":"Ciampino","location_id":"8853","lat":"41.79788","long":"12.607033","pm25":""},{"location_name":"Cicero2","location_id":"8854","lat":"41.86433","long":"-87.748825","pm25":""},{"location_name":"Ciechocinek","location_id":"8855","lat":"52.88842","long":"18.780909","pm25":""},{"location_name":"Cieszyn, ul. Mickiewicza 13","location_id":"8856","lat":"49.738136","long":"18.639069","pm25":""},{"location_name":"Cincinnati Near Road","location_id":"8857","lat":"39.146027","long":"-84.538376","pm25":""},{"location_name":"Cinecitta","location_id":"8858","lat":"41.85772","long":"12.568665","pm25":""},{"location_name":"Cipro","location_id":"8859","lat":"41.906357","long":"12.447596","pm25":""},{"location_name":"Cisco Drive","location_id":"8860","lat":"30.378166","long":"-81.84079","pm25":""},{"location_name":"City Park","location_id":"8861","lat":"29.9933","long":"-90.1014","pm25":""},{"location_name":"Civ. Porto","location_id":"8862","lat":"42.097054","long":"11.788354","pm25":""},{"location_name":"Civ. Via Morandi","location_id":"8863","lat":"42.086803","long":"11.806498","pm25":""},{"location_name":"Civ. Via Roma","location_id":"8864","lat":"42.094147","long":"11.795509","pm25":""},{"location_name":"Civ. Villa Albani","location_id":"8865","lat":"42.09936","long":"11.798061","pm25":""},{"location_name":"Civita Castellana","location_id":"8866","lat":"42.3018","long":"12.4132","pm25":""},{"location_name":"Civitavecchia","location_id":"8867","lat":"42.09163","long":"11.802466","pm25":""},{"location_name":"Clarkston-13th St","location_id":"8869","lat":"46.4256","long":"-117.0598","pm25":""},{"location_name":"Clarksville","location_id":"8870","lat":"36.611412","long":"-87.38467","pm25":""},{"location_name":"Cleburne Airport C77","location_id":"8873","lat":"32.353592","long":"-97.436745","pm25":""},{"location_name":"Clemmons Middle","location_id":"8874","lat":"36.0261","long":"-80.3419","pm25":""},{"location_name":"Clermont","location_id":"8876","lat":"28.525","long":"-81.7231","pm25":""},{"location_name":"Clinton C403","location_id":"8879","lat":"29.7339","long":"-95.2575","pm25":""},{"location_name":"Clinton, Chancy Park","location_id":"8881","lat":"41.8231","long":"-90.2119","pm25":""},{"location_name":"Clovis - N. Villa Av","location_id":"8883","lat":"36.8192","long":"-119.7164","pm25":""},{"location_name":"Coachline","location_id":"8884","lat":"32.3806","long":"-111.1272","pm25":""},{"location_name":"Coastal Carolina","location_id":"8885","lat":"33.8005","long":"-78.9941","pm25":""},{"location_name":"Coffeeville","location_id":"8887","lat":"34.0026","long":"-89.799","pm25":""},{"location_name":"Colbert-Greenbluff","location_id":"8888","lat":"47.808228","long":"-117.34327","pm25":""},{"location_name":"Colerain","location_id":"8889","lat":"39.21494","long":"-84.69086","pm25":""},{"location_name":"Colfax","location_id":"8890","lat":"39.1003","long":"-120.9528","pm25":""},{"location_name":"Colleferro-Europa","location_id":"8891","lat":"41.72501","long":"13.009575","pm25":""},{"location_name":"Colleferro-Oberdan","location_id":"8892","lat":"41.73084","long":"13.00435","pm25":""},{"location_name":"Collins Park","location_id":"8894","lat":"41.663406","long":"-83.47596","pm25":""},{"location_name":"Colorado College","location_id":"8895","lat":"38.848","long":"-104.8286","pm25":""},{"location_name":"Colorado Springs - H","location_id":"8896","lat":"38.830894","long":"-104.83924","pm25":""},{"location_name":"Colorado Springs - U","location_id":"8897","lat":"38.9583","long":"-104.8167","pm25":""},{"location_name":"Columbia","location_id":"8898","lat":"40.924606","long":"-75.067825","pm25":""},{"location_name":"Columbia Falls","location_id":"8899","lat":"48.363693","long":"-114.18927","pm25":""},{"location_name":"Columbus - Fairgroun","location_id":"8900","lat":"40.002735","long":"-82.99441","pm25":""},{"location_name":"Columbus Airport","location_id":"8904","lat":"32.5214","long":"-84.9436","pm25":""},{"location_name":"Columbus NR - Smoky","location_id":"8905","lat":"40.11109","long":"-83.06538","pm25":""},{"location_name":"Colusa - Sunrise Blv","location_id":"8906","lat":"39.18919","long":"-121.99887","pm25":""},{"location_name":"Colville-E 1st St","location_id":"8907","lat":"48.54469","long":"-117.90322","pm25":""},{"location_name":"Compton","location_id":"8908","lat":"33.9014","long":"-118.205","pm25":""},{"location_name":"Concord","location_id":"8909","lat":"37.9383","long":"-122.025","pm25":""},{"location_name":"Congaree Bluff","location_id":"8910","lat":"33.8147","long":"-80.7811","pm25":""},{"location_name":"Conneaut","location_id":"8911","lat":"41.959694","long":"-80.57281","pm25":""},{"location_name":"Connecticut Hill","location_id":"8912","lat":"42.4006","long":"-76.6538","pm25":""},{"location_name":"Conroe Relocated C78","location_id":"8913","lat":"30.3503","long":"-95.425","pm25":""},{"location_name":"Convent","location_id":"8915","lat":"29.995","long":"-90.8172","pm25":""},{"location_name":"Converse County Long","location_id":"8916","lat":"43.1","long":"-105.5","pm25":""},{"location_name":"Cookeville","location_id":"8918","lat":"36.1857","long":"-85.4921","pm25":""},{"location_name":"Copper View","location_id":"8923","lat":"40.598057","long":"-111.894165","pm25":""},{"location_name":"Cornwall","location_id":"8924","lat":"41.8331","long":"-73.3033","pm25":""},{"location_name":"Corpus Christi Dona","location_id":"8926","lat":"27.811813","long":"-97.4657","pm25":""},{"location_name":"Corpus Christi Tulos","location_id":"8927","lat":"27.8333","long":"-97.5558","pm25":""},{"location_name":"Corpus Christi West","location_id":"8928","lat":"27.765335","long":"-97.43425","pm25":""},{"location_name":"Corsicana C1051","location_id":"8929","lat":"32.0319","long":"-96.3992","pm25":""},{"location_name":"Cortez Ozone","location_id":"8930","lat":"37.34997","long":"-108.58737","pm25":""},{"location_name":"Corvallis - Circle B","location_id":"8932","lat":"44.5884","long":"-123.2673","pm25":""},{"location_name":"Coso Junction","location_id":"8933","lat":"36.0494","long":"-117.9439","pm25":""},{"location_name":"Cottage Grove City S","location_id":"8935","lat":"43.7995","long":"-123.0535","pm25":""},{"location_name":"County Sheriff Impou","location_id":"8938","lat":"29.1928","long":"-82.1733","pm25":""},{"location_name":"Cove Mountain - GSMN","location_id":"8940","lat":"35.6967","long":"-83.6089","pm25":""},{"location_name":"Coventry Allesley","location_id":"8941","lat":"52.411564","long":"-1.560228","pm25":""},{"location_name":"Coweeta","location_id":"8942","lat":"35.0608","long":"-83.4306","pm25":""},{"location_name":"Cranberry","location_id":"8944","lat":"36.1058","long":"-82.0454","pm25":""},{"location_name":"Craters of the Moon","location_id":"8946","lat":"43.4606","long":"-113.5622","pm25":""},{"location_name":"Credit Union","location_id":"8947","lat":"44.0874","long":"-103.27377","pm25":""},{"location_name":"Crestline - Lake Gre","location_id":"8948","lat":"34.243134","long":"-117.27228","pm25":""},{"location_name":"Crockett","location_id":"8949","lat":"37.9214","long":"-83.0662","pm25":""},{"location_name":"Crystal River Preser","location_id":"8951","lat":"28.958372","long":"-82.6431","pm25":""},{"location_name":"Custer-Loomis (SO-AQ","location_id":"8954","lat":"48.9507","long":"-122.5544","pm25":""},{"location_name":"Cut Bank","location_id":"8955","lat":"48.607407","long":"-112.36384","pm25":""},{"location_name":"Cwmbran","location_id":"8956","lat":"51.6538","long":"-3.006953","pm25":""},{"location_name":"Czerwionka-Leszczyny, ul. Kopalniana","location_id":"8958","lat":"50.16385","long":"18.659977","pm25":""},{"location_name":"Cz\u0119stochowa, ul. AK\/Jana Paw\u0142a II","location_id":"8959","lat":"50.817677","long":"19.117426","pm25":""},{"location_name":"Cz\u0119stochowa, ul. Baczy\u0144skiego 2","location_id":"8960","lat":"50.836388","long":"19.130112","pm25":""},{"location_name":"DANIA_BEACH","location_id":"8961","lat":"26.0864","long":"-80.1114","pm25":""},{"location_name":"DAVIS ISLAND","location_id":"8962","lat":"27.9283","long":"-82.4547","pm25":""},{"location_name":"DCNearRoad","location_id":"8964","lat":"38.89475","long":"-76.95343","pm25":""},{"location_name":"DE AMICIS","location_id":"8965","lat":"44.3554","long":"11.7207","pm25":""},{"location_name":"DEARBORN","location_id":"8966","lat":"42.3075","long":"-83.15","pm25":""},{"location_name":"DEBB007","location_id":"8967","lat":"51.462734","long":"13.526796","pm25":""},{"location_name":"DEBB021","location_id":"8968","lat":"52.401352","long":"13.059945","pm25":""},{"location_name":"DEBB029","location_id":"8969","lat":"53.064262","long":"14.285139","pm25":""},{"location_name":"DEBB032","location_id":"8970","lat":"52.146263","long":"14.638166","pm25":""},{"location_name":"DEBB044","location_id":"8971","lat":"51.756477","long":"14.327998","pm25":""},{"location_name":"DEBB045","location_id":"8972","lat":"52.337337","long":"14.538595","pm25":""},{"location_name":"DEBB048","location_id":"8973","lat":"52.93189","long":"12.809481","pm25":""},{"location_name":"DEBB049","location_id":"8974","lat":"52.40931","long":"12.548376","pm25":""},{"location_name":"DEBB053","location_id":"8975","lat":"52.563835","long":"14.015252","pm25":""},{"location_name":"DEBB054","location_id":"8976","lat":"52.393932","long":"13.037474","pm25":""},{"location_name":"DEBB055","location_id":"8977","lat":"52.42044","long":"12.552303","pm25":""},{"location_name":"DEBB060","location_id":"8978","lat":"52.832466","long":"13.822211","pm25":""},{"location_name":"DEBB063","location_id":"8979","lat":"52.99875","long":"11.73846","pm25":""},{"location_name":"DEBB064","location_id":"8980","lat":"51.746346","long":"14.33455","pm25":""},{"location_name":"DEBB065","location_id":"8981","lat":"52.194225","long":"12.561389","pm25":""},{"location_name":"DEBB066","location_id":"8982","lat":"51.8976","long":"14.057064","pm25":""},{"location_name":"DEBB067","location_id":"8983","lat":"52.60861","long":"12.885194","pm25":""},{"location_name":"DEBB068","location_id":"8984","lat":"52.67765","long":"13.582269","pm25":""},{"location_name":"DEBB073","location_id":"8985","lat":"52.38887","long":"13.094618","pm25":""},{"location_name":"DEBB075","location_id":"8986","lat":"52.48417","long":"13.123698","pm25":""},{"location_name":"DEBB083","location_id":"8987","lat":"51.5645","long":"14.3764","pm25":""},{"location_name":"DEBB086","location_id":"8988","lat":"52.349705","long":"13.424304","pm25":""},{"location_name":"DEBB092","location_id":"8989","lat":"52.33468","long":"14.52596","pm25":""},{"location_name":"DEBE010","location_id":"8991","lat":"52.54304","long":"13.349326","pm25":""},{"location_name":"DEBE018","location_id":"8992","lat":"52.485813","long":"13.348775","pm25":""},{"location_name":"DEBE027","location_id":"8993","lat":"52.398407","long":"13.368103","pm25":""},{"location_name":"DEBE032","location_id":"8994","lat":"52.47319","long":"13.225144","pm25":""},{"location_name":"DEBE034","location_id":"8995","lat":"52.489452","long":"13.430844","pm25":""},{"location_name":"DEBE051","location_id":"8996","lat":"52.643524","long":"13.489531","pm25":""},{"location_name":"DEBE056","location_id":"8997","lat":"52.447697","long":"13.64705","pm25":""},{"location_name":"DEBE061","location_id":"8998","lat":"52.46361","long":"13.31825","pm25":""},{"location_name":"DEBE062","location_id":"8999","lat":"52.65327","long":"13.296081","pm25":""},{"location_name":"DEBE063","location_id":"9000","lat":"52.467533","long":"13.441654","pm25":""},{"location_name":"DEBE064","location_id":"9001","lat":"52.48171","long":"13.433967","pm25":""},{"location_name":"DEBE065","location_id":"9002","lat":"52.514072","long":"13.469931","pm25":""},{"location_name":"DEBE066","location_id":"9003","lat":"52.485294","long":"13.529504","pm25":""},{"location_name":"DEBE067","location_id":"9004","lat":"52.5066","long":"13.332972","pm25":""},{"location_name":"DEBE068","location_id":"9005","lat":"52.513607","long":"13.418833","pm25":""},{"location_name":"DEBE069","location_id":"9006","lat":"52.438114","long":"13.38772","pm25":""},{"location_name":"DEBW004","location_id":"9007","lat":"49.07655","long":"8.40666","pm25":""},{"location_name":"DEBW005","location_id":"9008","lat":"49.54408","long":"8.465281","pm25":""},{"location_name":"DEBW009","location_id":"9009","lat":"49.41953","long":"8.6767","pm25":""},{"location_name":"DEBW010","location_id":"9010","lat":"49.30073","long":"8.700103","pm25":""},{"location_name":"DEBW013","location_id":"9011","lat":"48.8088","long":"9.229745","pm25":""},{"location_name":"DEBW015","location_id":"9012","lat":"49.16551","long":"9.224786","pm25":""},{"location_name":"DEBW019","location_id":"9013","lat":"48.396835","long":"9.979031","pm25":""},{"location_name":"DEBW022","location_id":"9014","lat":"48.57818","long":"7.802317","pm25":""},{"location_name":"DEBW023","location_id":"9015","lat":"47.588154","long":"7.633271","pm25":""},{"location_name":"DEBW024","location_id":"9016","lat":"48.899235","long":"9.172792","pm25":""},{"location_name":"DEBW027","location_id":"9017","lat":"48.488888","long":"9.20732","pm25":""},{"location_name":"DEBW029","location_id":"9018","lat":"48.847916","long":"10.096292","pm25":""},{"location_name":"DEBW031","location_id":"9019","lat":"47.80989","long":"7.764528","pm25":""},{"location_name":"DEBW033","location_id":"9020","lat":"48.889038","long":"8.665536","pm25":""},{"location_name":"DEBW038","location_id":"9021","lat":"47.660057","long":"9.485675","pm25":""},{"location_name":"DEBW039","location_id":"9022","lat":"48.048656","long":"8.463597","pm25":""},{"location_name":"DEBW042","location_id":"9023","lat":"48.67807","long":"9.227769","pm25":""},{"location_name":"DEBW046","location_id":"9024","lat":"48.089886","long":"9.800325","pm25":""},{"location_name":"DEBW052","location_id":"9025","lat":"47.66436","long":"9.169289","pm25":""},{"location_name":"DEBW059","location_id":"9027","lat":"49.634842","long":"9.657919","pm25":""},{"location_name":"DEBW073","location_id":"9028","lat":"47.81902","long":"7.567969","pm25":""},{"location_name":"DEBW076","location_id":"9029","lat":"48.77307","long":"8.220214","pm25":""},{"location_name":"DEBW080","location_id":"9030","lat":"49.00796","long":"8.38719","pm25":""},{"location_name":"DEBW081","location_id":"9031","lat":"49.028595","long":"8.355628","pm25":""},{"location_name":"DEBW084","location_id":"9032","lat":"48.00151","long":"7.832122","pm25":""},{"location_name":"DEBW087","location_id":"9033","lat":"48.34578","long":"9.207639","pm25":""},{"location_name":"DEBW098","location_id":"9034","lat":"49.49256","long":"8.47204","pm25":""},{"location_name":"DEBW099","location_id":"9035","lat":"48.78313","long":"9.18072","pm25":""},{"location_name":"DEBW107","location_id":"9036","lat":"48.5077","long":"9.051178","pm25":""},{"location_name":"DEBW112","location_id":"9037","lat":"48.645607","long":"8.904442","pm25":""},{"location_name":"DEBW116","location_id":"9038","lat":"48.76871","long":"9.18449","pm25":""},{"location_name":"DEBW117","location_id":"9039","lat":"48.8892","long":"9.19003","pm25":""},{"location_name":"DEBW118","location_id":"9040","lat":"48.7881","long":"9.19101","pm25":""},{"location_name":"DEBW120","location_id":"9041","lat":"48.80102","long":"9.01652","pm25":""},{"location_name":"DEBW122","location_id":"9042","lat":"47.9882","long":"7.85992","pm25":""},{"location_name":"DEBW125","location_id":"9043","lat":"49.00371","long":"8.52628","pm25":""},{"location_name":"DEBW136","location_id":"9044","lat":"48.52023","long":"9.05802","pm25":""},{"location_name":"DEBW147","location_id":"9045","lat":"48.48933","long":"9.21079","pm25":""},{"location_name":"DEBW152","location_id":"9046","lat":"49.146","long":"9.22589","pm25":""},{"location_name":"DEBW156","location_id":"9047","lat":"48.22915","long":"8.39062","pm25":""},{"location_name":"DEBY001","location_id":"9048","lat":"49.30489","long":"10.572297","pm25":""},{"location_name":"DEBY002","location_id":"9049","lat":"50.058193","long":"12.18865","pm25":""},{"location_name":"DEBY004","location_id":"9050","lat":"49.869423","long":"9.171544","pm25":""},{"location_name":"DEBY005","location_id":"9051","lat":"49.991516","long":"9.117973","pm25":""},{"location_name":"DEBY006","location_id":"9052","lat":"48.36459","long":"10.895029","pm25":""},{"location_name":"DEBY007","location_id":"9053","lat":"48.376575","long":"10.88837","pm25":""},{"location_name":"DEBY009","location_id":"9054","lat":"49.89833","long":"10.887686","pm25":""},{"location_name":"DEBY012","location_id":"9055","lat":"48.177174","long":"12.829314","pm25":""},{"location_name":"DEBY013","location_id":"9056","lat":"48.182835","long":"12.781387","pm25":""},{"location_name":"DEBY014","location_id":"9057","lat":"50.26058","long":"10.959312","pm25":""},{"location_name":"DEBY020","location_id":"9058","lat":"50.32061","long":"11.897492","pm25":""},{"location_name":"DEBY021","location_id":"9059","lat":"48.769444","long":"11.428766","pm25":""},{"location_name":"DEBY026","location_id":"9060","lat":"48.76711","long":"11.63833","pm25":""},{"location_name":"DEBY028","location_id":"9061","lat":"48.90952","long":"11.879245","pm25":""},{"location_name":"DEBY030","location_id":"9062","lat":"48.90423","long":"11.948795","pm25":""},{"location_name":"DEBY031","location_id":"9063","lat":"47.72514","long":"10.306561","pm25":""},{"location_name":"DEBY032","location_id":"9064","lat":"50.103134","long":"11.442591","pm25":""},{"location_name":"DEBY033","location_id":"9065","lat":"48.539803","long":"12.157051","pm25":""},{"location_name":"DEBY035","location_id":"9066","lat":"47.557472","long":"9.688869","pm25":""},{"location_name":"DEBY037","location_id":"9067","lat":"48.137253","long":"11.564924","pm25":""},{"location_name":"DEBY039","location_id":"9068","lat":"48.154533","long":"11.554669","pm25":""},{"location_name":"DEBY047","location_id":"9069","lat":"50.323246","long":"11.721605","pm25":""},{"location_name":"DEBY049","location_id":"9070","lat":"48.85321","long":"11.777818","pm25":""},{"location_name":"DEBY052","location_id":"9071","lat":"48.39708","long":"10.008293","pm25":""},{"location_name":"DEBY053","location_id":"9072","lat":"49.44591","long":"11.088444","pm25":""},{"location_name":"DEBY056","location_id":"9073","lat":"49.47221","long":"10.984705","pm25":""},{"location_name":"DEBY058","location_id":"9074","lat":"49.46223","long":"11.0248","pm25":""},{"location_name":"DEBY062","location_id":"9075","lat":"48.9724","long":"13.128932","pm25":""},{"location_name":"DEBY063","location_id":"9076","lat":"49.015244","long":"12.101557","pm25":""},{"location_name":"DEBY067","location_id":"9077","lat":"49.321957","long":"12.128139","pm25":""},{"location_name":"DEBY068","location_id":"9078","lat":"50.048397","long":"10.232076","pm25":""},{"location_name":"DEBY072","location_id":"9079","lat":"49.438465","long":"12.548869","pm25":""},{"location_name":"DEBY075","location_id":"9080","lat":"49.67895","long":"12.159361","pm25":""},{"location_name":"DEBY077","location_id":"9081","lat":"49.804695","long":"9.95642","pm25":""},{"location_name":"DEBY079","location_id":"9082","lat":"47.723186","long":"12.858856","pm25":""},{"location_name":"DEBY088","location_id":"9083","lat":"48.021656","long":"12.538174","pm25":""},{"location_name":"DEBY089","location_id":"9084","lat":"48.173195","long":"11.648036","pm25":""},{"location_name":"DEBY093","location_id":"9085","lat":"49.487984","long":"11.786341","pm25":""},{"location_name":"DEBY099","location_id":"9086","lat":"48.32601","long":"10.903051","pm25":""},{"location_name":"DEBY109","location_id":"9087","lat":"47.968754","long":"11.220172","pm25":""},{"location_name":"DEBY110","location_id":"9088","lat":"48.370235","long":"10.896221","pm25":""},{"location_name":"DEBY111","location_id":"9089","lat":"49.943638","long":"11.570088","pm25":""},{"location_name":"DEBY113","location_id":"9090","lat":"49.605915","long":"10.963528","pm25":""},{"location_name":"DEBY115","location_id":"9091","lat":"48.149605","long":"11.536513","pm25":""},{"location_name":"DEBY118","location_id":"9092","lat":"48.573627","long":"13.422039","pm25":""},{"location_name":"DEBY119","location_id":"9093","lat":"49.790527","long":"9.947654","pm25":""},{"location_name":"DEBY120","location_id":"9094","lat":"49.44048","long":"11.036096","pm25":""},{"location_name":"DEBY121","location_id":"9095","lat":"47.64846","long":"12.188324","pm25":""},{"location_name":"DEBY122","location_id":"9096","lat":"47.518013","long":"10.404232","pm25":""},{"location_name":"DEBY124","location_id":"9097","lat":"49.44406","long":"10.325","pm25":""},{"location_name":"DEBY187","location_id":"9098","lat":"48.95218","long":"10.59772","pm25":""},{"location_name":"DEBY188","location_id":"9099","lat":"49.32273","long":"11.02792","pm25":""},{"location_name":"DEBY189","location_id":"9100","lat":"48.18169","long":"11.46445","pm25":""},{"location_name":"DEBY196","location_id":"9101","lat":"47.47706","long":"11.05722","pm25":""},{"location_name":"DECATUR","location_id":"9102","lat":"34.5286","long":"-86.9706","pm25":""},{"location_name":"DEER","location_id":"9103","lat":"35.8325","long":"-93.2192","pm25":""},{"location_name":"DEHB001","location_id":"9104","lat":"53.077152","long":"8.81578","pm25":""},{"location_name":"DEHB002","location_id":"9105","lat":"53.060043","long":"8.916966","pm25":""},{"location_name":"DEHB004","location_id":"9106","lat":"53.180946","long":"8.625456","pm25":""},{"location_name":"DEHB005","location_id":"9107","lat":"53.562454","long":"8.569405","pm25":""},{"location_name":"DEHB006","location_id":"9108","lat":"53.078663","long":"8.825173","pm25":""},{"location_name":"DEHB011","location_id":"9109","lat":"53.585262","long":"8.59876","pm25":""},{"location_name":"DEHB012","location_id":"9110","lat":"53.12456","long":"8.735047","pm25":""},{"location_name":"DEHB013","location_id":"9111","lat":"53.1177","long":"8.69506","pm25":""},{"location_name":"DEHE001","location_id":"9112","lat":"49.872303","long":"8.664619","pm25":""},{"location_name":"DEHE005","location_id":"9113","lat":"50.10175","long":"8.542517","pm25":""},{"location_name":"DEHE008","location_id":"9114","lat":"50.12533","long":"8.746343","pm25":""},{"location_name":"DEHE011","location_id":"9115","lat":"50.13577","long":"8.92157","pm25":""},{"location_name":"DEHE013","location_id":"9116","lat":"51.314247","long":"9.483397","pm25":""},{"location_name":"DEHE018","location_id":"9117","lat":"50.010326","long":"8.451527","pm25":""},{"location_name":"DEHE020","location_id":"9118","lat":"50.567184","long":"8.500619","pm25":""},{"location_name":"DEHE022","location_id":"9119","lat":"50.050343","long":"8.244949","pm25":""},{"location_name":"DEHE024","location_id":"9120","lat":"51.291756","long":"9.774588","pm25":""},{"location_name":"DEHE026","location_id":"9121","lat":"50.16443","long":"9.399441","pm25":""},{"location_name":"DEHE028","location_id":"9122","lat":"49.653465","long":"8.817251","pm25":""},{"location_name":"DEHE030","location_id":"9123","lat":"50.804256","long":"8.769324","pm25":""},{"location_name":"DEHE032","location_id":"9124","lat":"50.970024","long":"9.80026","pm25":""},{"location_name":"DEHE037","location_id":"9125","lat":"50.07719","long":"8.230316","pm25":""},{"location_name":"DEHE039","location_id":"9126","lat":"50.770382","long":"9.459402","pm25":""},{"location_name":"DEHE040","location_id":"9127","lat":"49.869457","long":"8.653745","pm25":""},{"location_name":"DEHE041","location_id":"9128","lat":"50.124588","long":"8.691911","pm25":""},{"location_name":"DEHE042","location_id":"9129","lat":"50.532967","long":"8.684397","pm25":""},{"location_name":"DEHE043","location_id":"9130","lat":"49.825165","long":"8.516798","pm25":""},{"location_name":"DEHE044","location_id":"9131","lat":"50.383217","long":"8.060998","pm25":""},{"location_name":"DEHE045","location_id":"9132","lat":"49.67251","long":"9.001981","pm25":""},{"location_name":"DEHE046","location_id":"9133","lat":"51.430897","long":"8.928171","pm25":""},{"location_name":"DEHE049","location_id":"9134","lat":"51.312077","long":"9.49112","pm25":""},{"location_name":"DEHE050","location_id":"9135","lat":"51.360756","long":"9.271233","pm25":""},{"location_name":"DEHE051","location_id":"9136","lat":"50.49771","long":"9.935862","pm25":""},{"location_name":"DEHE052","location_id":"9137","lat":"50.221943","long":"8.446079","pm25":""},{"location_name":"DEHE059","location_id":"9138","lat":"50.55003","long":"9.684854","pm25":""},{"location_name":"DEHE060","location_id":"9139","lat":"51.154842","long":"9.031754","pm25":""},{"location_name":"DEHE061","location_id":"9140","lat":"50.584106","long":"8.668579","pm25":""},{"location_name":"DEHE062","location_id":"9141","lat":"50.80702","long":"8.769396","pm25":""},{"location_name":"DEHE063","location_id":"9142","lat":"49.643238","long":"8.642","pm25":""},{"location_name":"DEHE112","location_id":"9143","lat":"50.07212","long":"8.228865","pm25":""},{"location_name":"DEHE116","location_id":"9144","lat":"50.101494","long":"8.784892","pm25":""},{"location_name":"DEHE131","location_id":"9145","lat":"50.386425","long":"8.059909","pm25":""},{"location_name":"DEHE134","location_id":"9146","lat":"50.546383","long":"9.680167","pm25":""},{"location_name":"DEHH008","location_id":"9147","lat":"53.56414","long":"9.967882","pm25":""},{"location_name":"DEHH015","location_id":"9148","lat":"53.523262","long":"10.021227","pm25":""},{"location_name":"DEHH016","location_id":"9149","lat":"53.52902","long":"10.081685","pm25":""},{"location_name":"DEHH026","location_id":"9150","lat":"53.56063","long":"9.957236","pm25":""},{"location_name":"DEHH033","location_id":"9151","lat":"53.63829","long":"9.998009","pm25":""},{"location_name":"DEHH047","location_id":"9152","lat":"53.63074","long":"10.110595","pm25":""},{"location_name":"DEHH050","location_id":"9153","lat":"53.480927","long":"9.857223","pm25":""},{"location_name":"DEHH059","location_id":"9154","lat":"53.50793","long":"9.990569","pm25":""},{"location_name":"DEHH064","location_id":"9155","lat":"53.5644","long":"9.94458","pm25":""},{"location_name":"DEHH068","location_id":"9156","lat":"53.5923","long":"10.053859","pm25":""},{"location_name":"DEHH070","location_id":"9157","lat":"53.555668","long":"9.943012","pm25":""},{"location_name":"DEHH072","location_id":"9158","lat":"53.535957","long":"9.84408","pm25":""},{"location_name":"DEHH073","location_id":"9159","lat":"53.532074","long":"9.832702","pm25":""},{"location_name":"DEHH079","location_id":"9160","lat":"53.54527","long":"9.944815","pm25":""},{"location_name":"DEHH081","location_id":"9161","lat":"53.52916","long":"9.981599","pm25":""},{"location_name":"DELTA CERVIA","location_id":"9162","lat":"44.2839","long":"12.3322","pm25":""},{"location_name":"DEMV003","location_id":"9163","lat":"53.559784","long":"13.26644","pm25":""},{"location_name":"DEMV004","location_id":"9164","lat":"53.817776","long":"12.064708","pm25":""},{"location_name":"DEMV007","location_id":"9165","lat":"54.161556","long":"12.174105","pm25":""},{"location_name":"DEMV012","location_id":"9166","lat":"53.520454","long":"14.257407","pm25":""},{"location_name":"DEMV017","location_id":"9167","lat":"53.302353","long":"11.362965","pm25":""},{"location_name":"DEMV019","location_id":"9168","lat":"53.78175","long":"12.175512","pm25":""},{"location_name":"DEMV020","location_id":"9169","lat":"54.092278","long":"12.141994","pm25":""},{"location_name":"DEMV021","location_id":"9170","lat":"54.17133","long":"12.080003","pm25":""},{"location_name":"DEMV022","location_id":"9171","lat":"54.09262","long":"12.099553","pm25":""},{"location_name":"DEMV023","location_id":"9172","lat":"53.631805","long":"11.398332","pm25":""},{"location_name":"DEMV024","location_id":"9173","lat":"53.396347","long":"12.463929","pm25":""},{"location_name":"DEMV025","location_id":"9174","lat":"54.31923","long":"13.08101","pm25":""},{"location_name":"DEMV026","location_id":"9175","lat":"54.323513","long":"13.342138","pm25":""},{"location_name":"DEMV028","location_id":"9176","lat":"53.90077","long":"11.4769","pm25":""},{"location_name":"DEMV031","location_id":"9177","lat":"54.17729","long":"12.09792","pm25":""},{"location_name":"DENI011","location_id":"9178","lat":"52.22694","long":"10.47364","pm25":""},{"location_name":"DENI016","location_id":"9179","lat":"51.90158","long":"10.48132","pm25":""},{"location_name":"DENI020","location_id":"9180","lat":"52.44081","long":"10.81638","pm25":""},{"location_name":"DENI028","location_id":"9181","lat":"51.50758","long":"10.23854","pm25":""},{"location_name":"DENI029","location_id":"9182","lat":"53.36235","long":"7.20726","pm25":""},{"location_name":"DENI031","location_id":"9183","lat":"53.59617","long":"8.09059","pm25":""},{"location_name":"DENI038","location_id":"9184","lat":"52.25534","long":"8.05286","pm25":""},{"location_name":"DENI041","location_id":"9185","lat":"52.17017","long":"9.06255","pm25":""},{"location_name":"DENI042","location_id":"9186","lat":"51.55107","long":"9.94976","pm25":""},{"location_name":"DENI043","location_id":"9187","lat":"52.49855","long":"7.31747","pm25":""},{"location_name":"DENI048","location_id":"9188","lat":"52.359478","long":"9.7155","pm25":""},{"location_name":"DENI051","location_id":"9189","lat":"51.75816","long":"10.61248","pm25":""},{"location_name":"DENI052","location_id":"9190","lat":"52.82943","long":"9.62295","pm25":""},{"location_name":"DENI053","location_id":"9191","lat":"52.99796","long":"7.94257","pm25":""},{"location_name":"DENI054","location_id":"9192","lat":"52.36292","long":"9.70612","pm25":""},{"location_name":"DENI058","location_id":"9193","lat":"53.7153","long":"7.21398","pm25":""},{"location_name":"DENI059","location_id":"9194","lat":"53.83017","long":"8.80122","pm25":""},{"location_name":"DENI060","location_id":"9195","lat":"52.95702","long":"11.16705","pm25":""},{"location_name":"DENI062","location_id":"9196","lat":"53.24696","long":"10.4565","pm25":""},{"location_name":"DENI063","location_id":"9197","lat":"53.52418","long":"9.68503","pm25":""},{"location_name":"DENI066","location_id":"9198","lat":"52.150776","long":"9.950223","pm25":""},{"location_name":"DENI067","location_id":"9199","lat":"52.2703","long":"8.04147","pm25":""},{"location_name":"DENI068","location_id":"9200","lat":"51.5302","long":"9.92833","pm25":""},{"location_name":"DENI070","location_id":"9201","lat":"52.15369","long":"10.45591","pm25":""},{"location_name":"DENI075","location_id":"9203","lat":"52.26673","long":"10.54055","pm25":""},{"location_name":"DENI077","location_id":"9204","lat":"51.70884","long":"9.55462","pm25":""},{"location_name":"DENI143","location_id":"9205","lat":"53.142838","long":"8.212084","pm25":""},{"location_name":"DENI157","location_id":"9206","lat":"52.427887","long":"10.793683","pm25":""},{"location_name":"DENW002","location_id":"9207","lat":"51.641384","long":"7.331405","pm25":""},{"location_name":"DENW006","location_id":"9208","lat":"51.592205","long":"7.569838","pm25":""},{"location_name":"DENW008","location_id":"9209","lat":"51.53691","long":"7.457463","pm25":""},{"location_name":"DENW010","location_id":"9210","lat":"51.547497","long":"7.693835","pm25":""},{"location_name":"DENW015","location_id":"9211","lat":"51.69896","long":"7.122713","pm25":""},{"location_name":"DENW021","location_id":"9212","lat":"51.525963","long":"6.976908","pm25":""},{"location_name":"DENW022","location_id":"9213","lat":"51.533646","long":"7.101786","pm25":""},{"location_name":"DENW024","location_id":"9214","lat":"51.49653","long":"6.981045","pm25":""},{"location_name":"DENW029","location_id":"9215","lat":"51.403004","long":"7.208572","pm25":""},{"location_name":"DENW030","location_id":"9216","lat":"51.67281","long":"6.629576","pm25":""},{"location_name":"DENW034","location_id":"9217","lat":"51.52402","long":"6.748402","pm25":""},{"location_name":"DENW038","location_id":"9218","lat":"51.45346","long":"6.865107","pm25":""},{"location_name":"DENW040","location_id":"9219","lat":"51.385254","long":"6.763001","pm25":""},{"location_name":"DENW042","location_id":"9220","lat":"51.33767","long":"6.640242","pm25":""},{"location_name":"DENW043","location_id":"9221","lat":"51.451176","long":"7.030603","pm25":""},{"location_name":"DENW053","location_id":"9222","lat":"51.019344","long":"6.884636","pm25":""},{"location_name":"DENW058","location_id":"9223","lat":"50.87612","long":"6.873789","pm25":""},{"location_name":"DENW059","location_id":"9224","lat":"50.889812","long":"6.985164","pm25":""},{"location_name":"DENW062","location_id":"9225","lat":"50.75364","long":"7.082676","pm25":""},{"location_name":"DENW064","location_id":"9226","lat":"50.653236","long":"6.281069","pm25":""},{"location_name":"DENW065","location_id":"9227","lat":"50.93033","long":"8.191932","pm25":""},{"location_name":"DENW066","location_id":"9228","lat":"51.326942","long":"6.195868","pm25":""},{"location_name":"DENW067","location_id":"9229","lat":"52.02317","long":"8.548389","pm25":""},{"location_name":"DENW068","location_id":"9230","lat":"51.570663","long":"8.148061","pm25":""},{"location_name":"DENW071","location_id":"9231","lat":"51.24921","long":"6.732383","pm25":""},{"location_name":"DENW074","location_id":"9232","lat":"50.883476","long":"6.469363","pm25":""},{"location_name":"DENW078","location_id":"9233","lat":"51.30392","long":"6.819967","pm25":""},{"location_name":"DENW079","location_id":"9234","lat":"51.028877","long":"7.005063","pm25":""},{"location_name":"DENW080","location_id":"9235","lat":"51.183773","long":"7.052634","pm25":""},{"location_name":"DENW081","location_id":"9236","lat":"51.862","long":"6.874554","pm25":""},{"location_name":"DENW082","location_id":"9237","lat":"51.21311","long":"6.782565","pm25":""},{"location_name":"DENW094","location_id":"9238","lat":"50.754704","long":"6.093923","pm25":""},{"location_name":"DENW095","location_id":"9239","lat":"51.936546","long":"7.611581","pm25":""},{"location_name":"DENW096","location_id":"9240","lat":"51.154613","long":"6.42571","pm25":""},{"location_name":"DENW101","location_id":"9242","lat":"51.519638","long":"7.464347","pm25":""},{"location_name":"DENW112","location_id":"9243","lat":"51.43771","long":"6.771801","pm25":""},{"location_name":"DENW114","location_id":"9244","lat":"51.277645","long":"7.231895","pm25":""},{"location_name":"DENW116","location_id":"9245","lat":"51.34256","long":"6.670195","pm25":""},{"location_name":"DENW133","location_id":"9246","lat":"51.362827","long":"7.46353","pm25":""},{"location_name":"DENW134","location_id":"9247","lat":"51.477932","long":"7.005278","pm25":""},{"location_name":"DENW136","location_id":"9248","lat":"51.523567","long":"7.483597","pm25":""},{"location_name":"DENW179","location_id":"9249","lat":"51.44876","long":"7.582295","pm25":""},{"location_name":"DENW181","location_id":"9250","lat":"51.443012","long":"8.360714","pm25":""},{"location_name":"DENW182","location_id":"9251","lat":"50.92711","long":"6.582205","pm25":""},{"location_name":"DENW188","location_id":"9252","lat":"51.47497","long":"6.863657","pm25":""},{"location_name":"DENW189","location_id":"9253","lat":"51.26068","long":"7.147401","pm25":""},{"location_name":"DENW200","location_id":"9254","lat":"52.005623","long":"8.552804","pm25":""},{"location_name":"DENW206","location_id":"9255","lat":"51.17615","long":"7.084069","pm25":""},{"location_name":"DENW207","location_id":"9256","lat":"50.773132","long":"6.095775","pm25":""},{"location_name":"DENW208","location_id":"9257","lat":"51.52788","long":"7.084597","pm25":""},{"location_name":"DENW211","location_id":"9258","lat":"50.962856","long":"7.00459","pm25":""},{"location_name":"DENW212","location_id":"9259","lat":"50.94737","long":"6.957701","pm25":""},{"location_name":"DENW247","location_id":"9260","lat":"51.406967","long":"6.965643","pm25":""},{"location_name":"DENW259","location_id":"9261","lat":"51.169437","long":"6.439975","pm25":""},{"location_name":"DENW260","location_id":"9262","lat":"51.953266","long":"7.619387","pm25":""},{"location_name":"DENW329","location_id":"9263","lat":"51.033833","long":"6.451483","pm25":""},{"location_name":"DENW337","location_id":"9264","lat":"51.097637","long":"6.469463","pm25":""},{"location_name":"DENW338","location_id":"9265","lat":"51.485493","long":"6.735431","pm25":""},{"location_name":"DENW355","location_id":"9266","lat":"51.03147","long":"7.010934","pm25":""},{"location_name":"DENW367","location_id":"9267","lat":"51.568054","long":"6.990945","pm25":""},{"location_name":"DERP001","location_id":"9269","lat":"49.515053","long":"8.402374","pm25":""},{"location_name":"DERP003","location_id":"9270","lat":"49.45538","long":"8.425833","pm25":""},{"location_name":"DERP007","location_id":"9271","lat":"50.01708","long":"8.216498","pm25":""},{"location_name":"DERP009","location_id":"9272","lat":"49.994976","long":"8.273965","pm25":""},{"location_name":"DERP010","location_id":"9273","lat":"50.000973","long":"8.261277","pm25":""},{"location_name":"DERP011","location_id":"9274","lat":"50.009953","long":"8.265563","pm25":""},{"location_name":"DERP013","location_id":"9276","lat":"49.423138","long":"7.293522","pm25":""},{"location_name":"DERP014","location_id":"9277","lat":"49.741035","long":"7.193486","pm25":""},{"location_name":"DERP015","location_id":"9278","lat":"50.2665","long":"6.3781","pm25":""},{"location_name":"DERP016","location_id":"9279","lat":"50.76675","long":"7.9735","pm25":""},{"location_name":"DERP017","location_id":"9280","lat":"49.270264","long":"7.826521","pm25":""},{"location_name":"DERP019","location_id":"9281","lat":"49.446","long":"7.7673","pm25":""},{"location_name":"DERP020","location_id":"9282","lat":"49.754192","long":"6.646762","pm25":""},{"location_name":"DERP021","location_id":"9283","lat":"50.424675","long":"7.481394","pm25":""},{"location_name":"DERP022","location_id":"9284","lat":"49.842136","long":"7.866208","pm25":""},{"location_name":"DERP023","location_id":"9285","lat":"49.6287","long":"8.3649","pm25":""},{"location_name":"DERP024","location_id":"9286","lat":"50.3544","long":"7.596583","pm25":""},{"location_name":"DERP025","location_id":"9287","lat":"49.052322","long":"8.253547","pm25":""},{"location_name":"DERP026","location_id":"9288","lat":"49.5333","long":"8.3553","pm25":""},{"location_name":"DERP028","location_id":"9289","lat":"50.4243","long":"7.7299","pm25":""},{"location_name":"DERP041","location_id":"9290","lat":"49.47869","long":"8.443654","pm25":""},{"location_name":"DERP045","location_id":"9291","lat":"50.359604","long":"7.592515","pm25":""},{"location_name":"DERP046","location_id":"9292","lat":"50.431396","long":"7.460812","pm25":""},{"location_name":"DERP047","location_id":"9293","lat":"49.783943","long":"6.690488","pm25":""},{"location_name":"DERP053","location_id":"9294","lat":"49.351143","long":"8.423005","pm25":""},{"location_name":"DERP060","location_id":"9295","lat":"49.191998","long":"7.614573","pm25":""},{"location_name":"DESH001","location_id":"9296","lat":"53.67055","long":"9.585874","pm25":""},{"location_name":"DESH008","location_id":"9297","lat":"54.09323","long":"10.240596","pm25":""},{"location_name":"DESH013","location_id":"9298","lat":"54.412987","long":"11.215994","pm25":""},{"location_name":"DESH014","location_id":"9299","lat":"54.32781","long":"8.603474","pm25":""},{"location_name":"DESH015","location_id":"9300","lat":"53.924713","long":"9.532635","pm25":""},{"location_name":"DESH016","location_id":"9301","lat":"53.570583","long":"10.214871","pm25":""},{"location_name":"DESH022","location_id":"9302","lat":"54.78143","long":"9.43809","pm25":""},{"location_name":"DESH023","location_id":"9303","lat":"53.83549","long":"10.695936","pm25":""},{"location_name":"DESH025","location_id":"9304","lat":"53.92803","long":"9.511769","pm25":""},{"location_name":"DESH027","location_id":"9305","lat":"54.304676","long":"10.135158","pm25":""},{"location_name":"DESH030","location_id":"9306","lat":"53.68199","long":"9.997256","pm25":""},{"location_name":"DESH035","location_id":"9307","lat":"53.89612","long":"9.156908","pm25":""},{"location_name":"DESH052","location_id":"9308","lat":"54.30424","long":"10.122364","pm25":""},{"location_name":"DESH053","location_id":"9309","lat":"53.862236","long":"10.67332","pm25":""},{"location_name":"DESH055","location_id":"9310","lat":"53.87453","long":"10.664881","pm25":""},{"location_name":"DESL001","location_id":"9311","lat":"49.263905","long":"6.687126","pm25":""},{"location_name":"DESL002","location_id":"9312","lat":"49.36205","long":"7.263234","pm25":""},{"location_name":"DESL003","location_id":"9313","lat":"49.35786","long":"6.73354","pm25":""},{"location_name":"DESL006","location_id":"9314","lat":"49.18361","long":"6.744856","pm25":""},{"location_name":"DESL010","location_id":"9315","lat":"49.244247","long":"6.948776","pm25":""},{"location_name":"DESL011","location_id":"9316","lat":"49.23723","long":"7.036322","pm25":""},{"location_name":"DESL012","location_id":"9317","lat":"49.233463","long":"6.987601","pm25":""},{"location_name":"DESL013","location_id":"9318","lat":"49.322647","long":"6.753639","pm25":""},{"location_name":"DESL017","location_id":"9319","lat":"49.254345","long":"6.867744","pm25":""},{"location_name":"DESL019","location_id":"9320","lat":"49.416885","long":"6.552037","pm25":""},{"location_name":"DESL020","location_id":"9321","lat":"49.23074","long":"7.003174","pm25":""},{"location_name":"DESN001","location_id":"9322","lat":"50.570873","long":"12.997278","pm25":""},{"location_name":"DESN004","location_id":"9323","lat":"51.17567","long":"14.443771","pm25":""},{"location_name":"DESN006","location_id":"9324","lat":"51.125","long":"12.493056","pm25":""},{"location_name":"DESN017","location_id":"9325","lat":"50.9163","long":"13.346826","pm25":""},{"location_name":"DESN019","location_id":"9326","lat":"50.826","long":"12.542056","pm25":""},{"location_name":"DESN020","location_id":"9327","lat":"51.1558","long":"14.973958","pm25":""},{"location_name":"DESN024","location_id":"9328","lat":"50.354782","long":"12.468739","pm25":""},{"location_name":"DESN025","location_id":"9329","lat":"51.344166","long":"12.377163","pm25":""},{"location_name":"DESN045","location_id":"9330","lat":"50.892376","long":"14.822846","pm25":""},{"location_name":"DESN049","location_id":"9331","lat":"50.43132","long":"12.611125","pm25":""},{"location_name":"DESN051","location_id":"9332","lat":"51.119514","long":"13.675005","pm25":""},{"location_name":"DESN052","location_id":"9333","lat":"50.73148","long":"13.75145","pm25":""},{"location_name":"DESN053","location_id":"9334","lat":"50.42849","long":"12.953459","pm25":""},{"location_name":"DESN059","location_id":"9335","lat":"51.317905","long":"12.297411","pm25":""},{"location_name":"DESN061","location_id":"9336","lat":"51.06493","long":"13.741397","pm25":""},{"location_name":"DESN074","location_id":"9337","lat":"50.659096","long":"13.465078","pm25":""},{"location_name":"DESN075","location_id":"9338","lat":"50.486137","long":"12.138054","pm25":""},{"location_name":"DESN076","location_id":"9339","lat":"51.303772","long":"13.009406","pm25":""},{"location_name":"DESN077","location_id":"9340","lat":"51.335873","long":"12.334686","pm25":""},{"location_name":"DESN079","location_id":"9341","lat":"51.285355","long":"14.749731","pm25":""},{"location_name":"DESN080","location_id":"9342","lat":"51.396095","long":"12.234054","pm25":""},{"location_name":"DESN081","location_id":"9343","lat":"50.48175","long":"12.130376","pm25":""},{"location_name":"DESN082","location_id":"9344","lat":"51.375988","long":"12.425748","pm25":""},{"location_name":"DESN083","location_id":"9345","lat":"50.84574","long":"12.903367","pm25":""},{"location_name":"DESN084","location_id":"9346","lat":"51.026295","long":"13.731608","pm25":""},{"location_name":"DESN091","location_id":"9347","lat":"50.720406","long":"12.486621","pm25":""},{"location_name":"DESN092","location_id":"9348","lat":"51.036106","long":"13.730205","pm25":""},{"location_name":"DESN093","location_id":"9349","lat":"50.608135","long":"12.211112","pm25":""},{"location_name":"DESPLNS","location_id":"9350","lat":"42.0603","long":"-87.8631","pm25":""},{"location_name":"DEST002","location_id":"9351","lat":"52.268353","long":"11.864763","pm25":""},{"location_name":"DEST011","location_id":"9352","lat":"51.839382","long":"10.790143","pm25":""},{"location_name":"DEST015","location_id":"9353","lat":"51.651165","long":"12.302866","pm25":""},{"location_name":"DEST028","location_id":"9354","lat":"51.054558","long":"12.141322","pm25":""},{"location_name":"DEST029","location_id":"9355","lat":"51.803535","long":"11.738962","pm25":""},{"location_name":"DEST039","location_id":"9356","lat":"51.79863","long":"10.618275","pm25":""},{"location_name":"DEST044","location_id":"9357","lat":"51.89698","long":"11.057442","pm25":""},{"location_name":"DEST050","location_id":"9358","lat":"51.496166","long":"11.979064","pm25":""},{"location_name":"DEST066","location_id":"9359","lat":"51.870853","long":"12.663663","pm25":""},{"location_name":"DEST077","location_id":"9361","lat":"52.1279","long":"11.611464","pm25":""},{"location_name":"DEST089","location_id":"9362","lat":"52.593136","long":"11.172327","pm25":""},{"location_name":"DEST090","location_id":"9363","lat":"51.321365","long":"12.032141","pm25":""},{"location_name":"DEST091","location_id":"9364","lat":"51.840576","long":"12.244764","pm25":""},{"location_name":"DEST092","location_id":"9365","lat":"51.86747","long":"12.59827","pm25":""},{"location_name":"DEST095","location_id":"9366","lat":"51.759556","long":"11.449438","pm25":""},{"location_name":"DEST098","location_id":"9367","lat":"51.662434","long":"11.043386","pm25":""},{"location_name":"DEST102","location_id":"9368","lat":"51.494755","long":"11.981314","pm25":""},{"location_name":"DEST103","location_id":"9369","lat":"52.12076","long":"11.632669","pm25":""},{"location_name":"DEST104","location_id":"9370","lat":"51.837307","long":"11.891412","pm25":""},{"location_name":"DEST105","location_id":"9371","lat":"52.602055","long":"11.850274","pm25":""},{"location_name":"DEST106","location_id":"9372","lat":"51.45607","long":"11.091078","pm25":""},{"location_name":"DEST108","location_id":"9373","lat":"51.19725","long":"11.96096","pm25":""},{"location_name":"DEST112","location_id":"9374","lat":"52.13174","long":"11.631919","pm25":""},{"location_name":"DET POLICE 4TH","location_id":"9375","lat":"42.312157","long":"-83.09194","pm25":""},{"location_name":"DETH005","location_id":"9376","lat":"50.65118","long":"11.368875","pm25":""},{"location_name":"DETH009","location_id":"9377","lat":"50.877316","long":"12.07471","pm25":""},{"location_name":"DETH011","location_id":"9378","lat":"50.98776","long":"12.437621","pm25":""},{"location_name":"DETH013","location_id":"9379","lat":"50.97829","long":"10.317236","pm25":""},{"location_name":"DETH018","location_id":"9380","lat":"51.497196","long":"10.791404","pm25":""},{"location_name":"DETH020","location_id":"9381","lat":"50.979454","long":"11.037924","pm25":""},{"location_name":"DETH026","location_id":"9382","lat":"50.561752","long":"10.375299","pm25":""},{"location_name":"DETH027","location_id":"9383","lat":"50.499954","long":"11.134593","pm25":""},{"location_name":"DETH036","location_id":"9384","lat":"50.65586","long":"12.205199","pm25":""},{"location_name":"DETH041","location_id":"9385","lat":"50.933514","long":"11.597062","pm25":""},{"location_name":"DETH042","location_id":"9386","lat":"51.333332","long":"10.867188","pm25":""},{"location_name":"DETH043","location_id":"9387","lat":"50.984875","long":"11.019353","pm25":""},{"location_name":"DETH061","location_id":"9389","lat":"50.791615","long":"11.661233","pm25":""},{"location_name":"DETH072","location_id":"9390","lat":"50.61153","long":"10.693092","pm25":""},{"location_name":"DETH081","location_id":"9391","lat":"50.972332","long":"11.010446","pm25":""},{"location_name":"DETH083","location_id":"9392","lat":"50.977463","long":"11.32607","pm25":""},{"location_name":"DETH091","location_id":"9393","lat":"51.205467","long":"10.448476","pm25":""},{"location_name":"DETH093","location_id":"9394","lat":"50.982544","long":"11.3204","pm25":""},{"location_name":"DETH095","location_id":"9395","lat":"51.207943","long":"10.450997","pm25":""},{"location_name":"DETH117","location_id":"9396","lat":"50.993126","long":"11.056578","pm25":""},{"location_name":"DETROIT - E 7 MILE","location_id":"9397","lat":"42.4308","long":"-83.0008","pm25":""},{"location_name":"DETROIT - SOUTHWEST","location_id":"9398","lat":"42.3042","long":"-83.1072","pm25":""},{"location_name":"DEUB001","location_id":"9400","lat":"54.92497","long":"8.308208","pm25":""},{"location_name":"DEUB004","location_id":"9401","lat":"47.913258","long":"7.908035","pm25":""},{"location_name":"DEUB005","location_id":"9402","lat":"52.800774","long":"10.756733","pm25":""},{"location_name":"DEUB028","location_id":"9403","lat":"54.436985","long":"12.721938","pm25":""},{"location_name":"DEUB029","location_id":"9404","lat":"50.654064","long":"10.769534","pm25":""},{"location_name":"DEUB030","location_id":"9405","lat":"53.141304","long":"13.031662","pm25":""},{"location_name":"DEUB046","location_id":"9406","lat":"48.947613","long":"13.420573","pm25":""},{"location_name":"DK0012R","location_id":"9407","lat":"55.694103","long":"12.088629","pm25":""},{"location_name":"DK0030A","location_id":"9408","lat":"55.698357","long":"12.553328","pm25":""},{"location_name":"DK0031A","location_id":"9409","lat":"55.394447","long":"10.393777","pm25":""},{"location_name":"DK0031R","location_id":"9410","lat":"56.29038","long":"8.427402","pm25":""},{"location_name":"DK0034A","location_id":"9411","lat":"55.674305","long":"12.571114","pm25":""},{"location_name":"DK0045A","location_id":"9412","lat":"55.70028","long":"12.561412","pm25":""},{"location_name":"DK0046A","location_id":"9413","lat":"55.39639","long":"10.389196","pm25":""},{"location_name":"DK0051A","location_id":"9414","lat":"56.15056","long":"10.200842","pm25":""},{"location_name":"DK0053A","location_id":"9415","lat":"57.046654","long":"9.930876","pm25":""},{"location_name":"DK0054A","location_id":"9416","lat":"54.746387","long":"10.736395","pm25":""},{"location_name":"DK0056A","location_id":"9417","lat":"56.159782","long":"10.193633","pm25":""},{"location_name":"DK0057A","location_id":"9418","lat":"55.631985","long":"12.463316","pm25":""},{"location_name":"DYERTEOM","location_id":"9421","lat":"36.0528","long":"-89.3819","pm25":""},{"location_name":"Dallas Hinton St. C4","location_id":"9422","lat":"32.82","long":"-96.86","pm25":""},{"location_name":"Dallas North C63","location_id":"9423","lat":"32.919205","long":"-96.808495","pm25":""},{"location_name":"Dallas Redbird Airpo","location_id":"9424","lat":"32.6767","long":"-96.8717","pm25":""},{"location_name":"Danbury","location_id":"9426","lat":"41.4014","long":"-73.4447","pm25":""},{"location_name":"Daniel South","location_id":"9428","lat":"42.7914","long":"-110.0547","pm25":""},{"location_name":"Danmarks plass","location_id":"9429","lat":"60.37408","long":"5.34042","pm25":""},{"location_name":"Darrington-Fir St","location_id":"9430","lat":"48.2468","long":"-121.6031","pm25":""},{"location_name":"Davenport, 10th & Vi","location_id":"9431","lat":"41.53","long":"-90.5875","pm25":""},{"location_name":"Davis - UCD Campus","location_id":"9435","lat":"38.53455","long":"-121.7734","pm25":""},{"location_name":"Dayton-W Main","location_id":"9438","lat":"46.318","long":"-117.985","pm25":""},{"location_name":"Dayville","location_id":"9439","lat":"37.9536","long":"-87.29","pm25":""},{"location_name":"De Rijp-Oostdijkje","location_id":"9440","lat":"52.5636","long":"4.8617","pm25":""},{"location_name":"De Zilk-Vogelaarsdreef","location_id":"9443","lat":"52.2966","long":"4.51082","pm25":""},{"location_name":"Death Valley NP","location_id":"9444","lat":"36.5092","long":"-116.8481","pm25":""},{"location_name":"Deer Creek","location_id":"9445","lat":"39.6359","long":"-83.2605","pm25":""},{"location_name":"Del Norte","location_id":"9447","lat":"35.1353","long":"-106.5847","pm25":""},{"location_name":"Den Haag-Bleriotlaan","location_id":"9451","lat":"52.039","long":"4.35938","pm25":""},{"location_name":"Den Haag-Rebecquestraat","location_id":"9452","lat":"52.0771","long":"4.28919","pm25":""},{"location_name":"Den Haag-Veerkade","location_id":"9453","lat":"52.0751","long":"4.31587","pm25":""},{"location_name":"Denali NPP","location_id":"9454","lat":"63.7233","long":"-148.9675","pm25":""},{"location_name":"Denton Airport South","location_id":"9455","lat":"33.1944","long":"-97.1933","pm25":""},{"location_name":"Denver - CAMP - 2105","location_id":"9456","lat":"39.7511","long":"-104.9872","pm25":""},{"location_name":"Denver - NJH - 14th","location_id":"9457","lat":"39.7386","long":"-104.9394","pm25":""},{"location_name":"Derby St Alkmund's Way","location_id":"9458","lat":"52.92298","long":"-1.469507","pm25":""},{"location_name":"Derry Rosemount","location_id":"9460","lat":"55.00282","long":"-7.331179","pm25":""},{"location_name":"Desert View","location_id":"9461","lat":"31.7961","long":"-106.5839","pm25":""},{"location_name":"Detroit Lakes","location_id":"9463","lat":"46.8511","long":"-95.8467","pm25":""},{"location_name":"Devils Lake","location_id":"9464","lat":"43.4356","long":"-89.6803","pm25":""},{"location_name":"Dhahran","location_id":"9465","lat":"26.276861","long":"50.147232","pm25":""},{"location_name":"Diablo","location_id":"9466","lat":"33.3961","long":"-111.968","pm25":""},{"location_name":"Din Daeng Rd., Din Daeng","location_id":"9472","lat":"13.762406","long":"100.5506","pm25":""},{"location_name":"Din Daeng, Din Daeng","location_id":"9473","lat":"13.775373","long":"100.56893","pm25":""},{"location_name":"Dinosaur National Mo","location_id":"9474","lat":"40.4372","long":"-109.3047","pm25":""},{"location_name":"Dirty Socks","location_id":"9475","lat":"36.3261","long":"-117.9551","pm25":""},{"location_name":"Division Street","location_id":"9476","lat":"40.7142","long":"-73.995","pm25":""},{"location_name":"Dixie","location_id":"9477","lat":"32.6833","long":"-93.8617","pm25":""},{"location_name":"Doncaster A630 Cleveland Street","location_id":"9479","lat":"53.518867","long":"-1.138073","pm25":""},{"location_name":"Dordrecht-Bamendaweg","location_id":"9480","lat":"51.8007","long":"4.70824","pm25":""},{"location_name":"Downtown Sacramento","location_id":"9484","lat":"38.56844","long":"-121.49311","pm25":""},{"location_name":"Drenas","location_id":"9487","lat":"42.62557","long":"20.89621","pm25":""},{"location_name":"Duluth-WDSE","location_id":"9489","lat":"46.8183","long":"-92.0892","pm25":""},{"location_name":"Dumbarton Roadside","location_id":"9490","lat":"55.943195","long":"-4.55973","pm25":""},{"location_name":"Dumfries","location_id":"9491","lat":"55.070034","long":"-3.614233","pm25":""},{"location_name":"Dunkirk","location_id":"9493","lat":"42.4992","long":"-79.32","pm25":""},{"location_name":"Durango Complex","location_id":"9495","lat":"33.4265","long":"-112.1181","pm25":""},{"location_name":"Durham Armory","location_id":"9497","lat":"36.032955","long":"-78.90404","pm25":""},{"location_name":"Dushanbe","location_id":"9498","lat":"38.55767","long":"68.77592","pm25":""},{"location_name":"Duszniki-Zdr\u00f3j","location_id":"9499","lat":"50.402645","long":"16.393318","pm25":""},{"location_name":"Dutchtown","location_id":"9500","lat":"30.2294","long":"-90.9656","pm25":""},{"location_name":"Dysart","location_id":"9501","lat":"33.6369","long":"-112.3394","pm25":""},{"location_name":"Dzia\u0142oszyn","location_id":"9502","lat":"50.972168","long":"14.941319","pm25":""},{"location_name":"Dzier\u017coni\u00f3w - Pi\u0142sudskiego","location_id":"9503","lat":"50.73282","long":"16.64805","pm25":""},{"location_name":"D\u0105browa G\u00f3rnicza, ul. Tysi\u0105clecia 25a","location_id":"9504","lat":"50.32911","long":"19.231222","pm25":""},{"location_name":"D\u0119bica-Grottgera-WIOS","location_id":"9505","lat":"50.054787","long":"21.416256","pm25":""},{"location_name":"E Providence","location_id":"9506","lat":"41.8403","long":"-71.3617","pm25":""},{"location_name":"E Syracuse","location_id":"9507","lat":"43.0528","long":"-76.0597","pm25":""},{"location_name":"E. Milton - Blue Hil","location_id":"9509","lat":"42.2117","long":"-71.1144","pm25":""},{"location_name":"E6 Alna senter","location_id":"9514","lat":"59.92556","long":"10.850367","pm25":""},{"location_name":"E6-Tiller","location_id":"9515","lat":"63.3576","long":"10.3719","pm25":""},{"location_name":"EAGLEMT","location_id":"9517","lat":"34.4544","long":"-94.1433","pm25":""},{"location_name":"EAST BAY","location_id":"9519","lat":"27.853897","long":"-82.383415","pm25":""},{"location_name":"EAST VINTON ELEMENTA","location_id":"9521","lat":"37.2856","long":"-79.8842","pm25":""},{"location_name":"ELDOSPGS","location_id":"9530","lat":"37.70097","long":"-94.03474","pm25":""},{"location_name":"Erie","location_id":"9533","lat":"42.1428","long":"-80.0372","pm25":""},{"location_name":"ES0001R","location_id":"9534","lat":"39.54694","long":"-4.35056","pm25":""},{"location_name":"ES0005R","location_id":"9535","lat":"42.72056","long":"-8.92361","pm25":""},{"location_name":"ES0006R","location_id":"9536","lat":"39.87528","long":"4.31639","pm25":""},{"location_name":"ES0007R","location_id":"9537","lat":"37.23722","long":"-3.53417","pm25":""},{"location_name":"ES0008R","location_id":"9538","lat":"43.43917","long":"-4.85","pm25":""},{"location_name":"ES0009R","location_id":"9539","lat":"41.27417","long":"-3.1425","pm25":""},{"location_name":"ES0010R","location_id":"9540","lat":"42.31917","long":"3.31583","pm25":""},{"location_name":"ES0011R","location_id":"9541","lat":"38.47278","long":"-6.92361","pm25":""},{"location_name":"ES0012R","location_id":"9542","lat":"39.08278","long":"-1.10111","pm25":""},{"location_name":"ES0013R","location_id":"9543","lat":"41.23889","long":"-5.8975","pm25":""},{"location_name":"ES0014R","location_id":"9544","lat":"41.39389","long":"0.73472","pm25":""},{"location_name":"ES0016R","location_id":"9545","lat":"42.63472","long":"-7.70472","pm25":""},{"location_name":"ES0017R","location_id":"9546","lat":"37.05194","long":"-6.55528","pm25":""},{"location_name":"ES0041A","location_id":"9547","lat":"43.261112","long":"-2.9447222","pm25":""},{"location_name":"ES0110A","location_id":"9548","lat":"43.302776","long":"-2.9772222","pm25":""},{"location_name":"ES0115A","location_id":"9549","lat":"40.424168","long":"-3.7122223","pm25":""},{"location_name":"ES0118A","location_id":"9550","lat":"40.421665","long":"-3.6822221","pm25":""},{"location_name":"ES0120A","location_id":"9551","lat":"40.451668","long":"-3.6772223","pm25":""},{"location_name":"ES0124A","location_id":"9552","lat":"40.44","long":"-3.6391666","pm25":""},{"location_name":"ES0125A","location_id":"9553","lat":"40.346943","long":"-3.705","pm25":""},{"location_name":"ES0126A","location_id":"9554","lat":"40.394722","long":"-3.7319443","pm25":""},{"location_name":"ES0296A","location_id":"9555","lat":"39.74731","long":"3.01488","pm25":""},{"location_name":"ES0316A","location_id":"9556","lat":"40.94667","long":"-0.29083","pm25":""},{"location_name":"ES0556A","location_id":"9560","lat":"36.17943","long":"-5.37697","pm25":""},{"location_name":"ES0557A","location_id":"9561","lat":"36.18621","long":"-5.38081","pm25":""},{"location_name":"ES0584A","location_id":"9562","lat":"41.482018","long":"2.1882966","pm25":""},{"location_name":"ES0587A","location_id":"9563","lat":"43.320835","long":"-3.1130555","pm25":""},{"location_name":"ES0588A","location_id":"9564","lat":"43.320557","long":"-3.0738888","pm25":""},{"location_name":"ES0624A","location_id":"9565","lat":"36.84745","long":"-2.03819","pm25":""},{"location_name":"ES0629A","location_id":"9566","lat":"36.18562","long":"-5.48893","pm25":""},{"location_name":"ES0633A","location_id":"9567","lat":"36.1747","long":"-5.43277","pm25":""},{"location_name":"ES0634A","location_id":"9568","lat":"36.21204","long":"-5.43027","pm25":""},{"location_name":"ES0651A","location_id":"9569","lat":"37.603333","long":"-0.91333336","pm25":""},{"location_name":"ES0691A","location_id":"9570","lat":"41.40388","long":"2.2045226","pm25":""},{"location_name":"ES0692A","location_id":"9571","lat":"41.370502","long":"2.114973","pm25":""},{"location_name":"ES0694A","location_id":"9572","lat":"41.39216","long":"2.0098023","pm25":""},{"location_name":"ES0712A","location_id":"9573","lat":"36.17538","long":"-5.48083","pm25":""},{"location_name":"ES0785A","location_id":"9575","lat":"37.26725","long":"-6.91905","pm25":""},{"location_name":"ES0787A","location_id":"9576","lat":"37.19033","long":"-6.90453","pm25":""},{"location_name":"ES0805A","location_id":"9577","lat":"43.24111","long":"-2.8841667","pm25":""},{"location_name":"ES0813A","location_id":"9578","lat":"40.84194","long":"-0.0575","pm25":""},{"location_name":"ES0817A","location_id":"9579","lat":"37.38425","long":"-5.95962","pm25":""},{"location_name":"ES0822A","location_id":"9580","lat":"37.27964","long":"-6.93807","pm25":""},{"location_name":"ES0823A","location_id":"9581","lat":"37.18568","long":"-6.96414","pm25":""},{"location_name":"ES0824A","location_id":"9582","lat":"43.3069","long":"-5.705672","pm25":""},{"location_name":"ES0825A","location_id":"9583","lat":"43.306656","long":"-5.689716","pm25":""},{"location_name":"ES0827A","location_id":"9584","lat":"37.3154","long":"-6.84463","pm25":""},{"location_name":"ES0873A","location_id":"9585","lat":"28.03512","long":"-15.41631","pm25":""},{"location_name":"ES0879A","location_id":"9586","lat":"43.550304","long":"-5.89886","pm25":""},{"location_name":"ES0880A","location_id":"9587","lat":"43.5519","long":"-5.918","pm25":""},{"location_name":"ES0886A","location_id":"9588","lat":"28.029852","long":"-15.416086","pm25":""},{"location_name":"ES0890A","location_id":"9589","lat":"37.39452","long":"-6.0031","pm25":""},{"location_name":"ES0892A","location_id":"9590","lat":"37.19977","long":"-6.92027","pm25":""},{"location_name":"ES0893A","location_id":"9591","lat":"36.1821","long":"-5.41141","pm25":""},{"location_name":"ES0894A","location_id":"9592","lat":"36.20442","long":"-5.40471","pm25":""},{"location_name":"ES0926A","location_id":"9593","lat":"38.10814","long":"-4.9268","pm25":""},{"location_name":"ES0971A","location_id":"9594","lat":"41.450768","long":"1.9748873","pm25":""},{"location_name":"ES1018A","location_id":"9595","lat":"41.556114","long":"2.0074012","pm25":""},{"location_name":"ES1037A","location_id":"9596","lat":"43.3675","long":"-4.04278","pm25":""},{"location_name":"ES1038A","location_id":"9597","lat":"43.34639","long":"-4.06417","pm25":""},{"location_name":"ES1039A","location_id":"9598","lat":"43.35583","long":"-4.06361","pm25":""},{"location_name":"ES1044A","location_id":"9599","lat":"41.67028","long":"-0.87111","pm25":""},{"location_name":"ES1047A","location_id":"9600","lat":"41.65139","long":"-0.91611","pm25":""},{"location_name":"ES1067A","location_id":"9601","lat":"37.21925","long":"-6.88858","pm25":""},{"location_name":"ES1072A","location_id":"9602","lat":"36.15937","long":"-5.34836","pm25":""},{"location_name":"ES1074A","location_id":"9603","lat":"36.20388","long":"-5.38371","pm25":""},{"location_name":"ES1076A","location_id":"9604","lat":"36.19048","long":"-5.43576","pm25":""},{"location_name":"ES1090A","location_id":"9605","lat":"41.67417","long":"-0.86417","pm25":""},{"location_name":"ES1093A","location_id":"9606","lat":"39.78995","long":"3.07413","pm25":""},{"location_name":"ES1095A","location_id":"9608","lat":"39.89092","long":"4.252975","pm25":""},{"location_name":"ES1096A","location_id":"9609","lat":"42.351944","long":"-7.8769445","pm25":""},{"location_name":"ES1117A","location_id":"9610","lat":"41.11209","long":"1.1518244","pm25":""},{"location_name":"ES1120A","location_id":"9611","lat":"41.11588","long":"1.1919755","pm25":""},{"location_name":"ES1122A","location_id":"9612","lat":"41.19359","long":"1.2367028","pm25":""},{"location_name":"ES1123A","location_id":"9613","lat":"41.154922","long":"1.2177176","pm25":""},{"location_name":"ES1124A","location_id":"9614","lat":"41.15945","long":"1.2397038","pm25":""},{"location_name":"ES1125A","location_id":"9615","lat":"41.73028","long":"1.8253064","pm25":""},{"location_name":"ES1126A","location_id":"9616","lat":"41.47541","long":"1.9212034","pm25":""},{"location_name":"ES1130A","location_id":"9617","lat":"41.28833","long":"-0.32667","pm25":""},{"location_name":"ES1131A","location_id":"9618","lat":"28.462173","long":"-16.261894","pm25":""},{"location_name":"ES1135A","location_id":"9619","lat":"41.577625","long":"1.6258934","pm25":""},{"location_name":"ES1137A","location_id":"9620","lat":"42.219166","long":"-8.741944","pm25":""},{"location_name":"ES1138A","location_id":"9621","lat":"43.36778","long":"-8.418889","pm25":""},{"location_name":"ES1148A","location_id":"9622","lat":"41.42562","long":"2.2222447","pm25":""},{"location_name":"ES1160A","location_id":"9623","lat":"42.35083","long":"-3.67556","pm25":""},{"location_name":"ES1161A","location_id":"9624","lat":"42.60389","long":"-5.587222","pm25":""},{"location_name":"ES1162A","location_id":"9625","lat":"41.316387","long":"-4.909167","pm25":""},{"location_name":"ES1163A","location_id":"9626","lat":"42.684444","long":"-2.9175","pm25":""},{"location_name":"ES1169A","location_id":"9627","lat":"36.20879","long":"-5.39138","pm25":""},{"location_name":"ES1181A","location_id":"9628","lat":"39.48111","long":"-0.44722223","pm25":""},{"location_name":"ES1182A","location_id":"9629","lat":"38.966667","long":"-0.19","pm25":""},{"location_name":"ES1185A","location_id":"9630","lat":"39.66722","long":"-0.23472223","pm25":""},{"location_name":"ES1193A","location_id":"9631","lat":"40.42","long":"-3.7491667","pm25":""},{"location_name":"ES1201A","location_id":"9632","lat":"42.391975","long":"2.8421385","pm25":""},{"location_name":"ES1208A","location_id":"9633","lat":"41.15078","long":"1.1201719","pm25":""},{"location_name":"ES1215A","location_id":"9634","lat":"40.706707","long":"0.5816515","pm25":""},{"location_name":"ES1222A","location_id":"9635","lat":"41.691273","long":"2.440945","pm25":""},{"location_name":"ES1225A","location_id":"9636","lat":"41.615795","long":"0.6157259","pm25":""},{"location_name":"ES1231A","location_id":"9637","lat":"41.47677","long":"2.0889773","pm25":""},{"location_name":"ES1239A","location_id":"9638","lat":"39.456112","long":"-0.37583333","pm25":""},{"location_name":"ES1244A","location_id":"9639","lat":"43.2675","long":"-2.9183333","pm25":""},{"location_name":"ES1246A","location_id":"9640","lat":"38.91382","long":"1.41426","pm25":""},{"location_name":"ES1247A","location_id":"9641","lat":"38.90648","long":"1.43537","pm25":""},{"location_name":"ES1248A","location_id":"9642","lat":"42.40538","long":"1.13","pm25":""},{"location_name":"ES1253A","location_id":"9643","lat":"38.09293","long":"-3.78392","pm25":""},{"location_name":"ES1256A","location_id":"9644","lat":"37.26016","long":"-6.92546","pm25":""},{"location_name":"ES1258A","location_id":"9645","lat":"37.28156","long":"-6.83384","pm25":""},{"location_name":"ES1259A","location_id":"9646","lat":"37.35844","long":"-6.67846","pm25":""},{"location_name":"ES1262A","location_id":"9647","lat":"41.561176","long":"2.1014051","pm25":""},{"location_name":"ES1268A","location_id":"9648","lat":"43.35829","long":"-5.86643","pm25":""},{"location_name":"ES1269A","location_id":"9649","lat":"43.36653","long":"-5.83303","pm25":""},{"location_name":"ES1270A","location_id":"9650","lat":"43.535187","long":"-5.658337","pm25":""},{"location_name":"ES1271A","location_id":"9651","lat":"43.538864","long":"-5.698921","pm25":""},{"location_name":"ES1272A","location_id":"9652","lat":"43.52986","long":"-5.673498","pm25":""},{"location_name":"ES1275A","location_id":"9653","lat":"41.68905","long":"2.4957466","pm25":""},{"location_name":"ES1277A","location_id":"9654","lat":"38.68065","long":"-4.10832","pm25":""},{"location_name":"ES1278A","location_id":"9655","lat":"38.68925","long":"-4.11151","pm25":""},{"location_name":"ES1279A","location_id":"9656","lat":"38.68198","long":"-4.08858","pm25":""},{"location_name":"ES1287A","location_id":"9657","lat":"42.795277","long":"-4.840833","pm25":""},{"location_name":"ES1297A","location_id":"9658","lat":"42.802776","long":"-5.623611","pm25":""},{"location_name":"ES1310A","location_id":"9659","lat":"42.312077","long":"2.214273","pm25":""},{"location_name":"ES1311A","location_id":"9660","lat":"41.958675","long":"3.2128544","pm25":""},{"location_name":"ES1312A","location_id":"9661","lat":"41.10368","long":"1.200765","pm25":""},{"location_name":"ES1328A","location_id":"9663","lat":"37.25258","long":"-6.94219","pm25":""},{"location_name":"ES1339A","location_id":"9664","lat":"41.219036","long":"1.7212487","pm25":""},{"location_name":"ES1340A","location_id":"9665","lat":"37.25336","long":"-6.93514","pm25":""},{"location_name":"ES1346A","location_id":"9666","lat":"42.688057","long":"-2.9405556","pm25":""},{"location_name":"ES1347A","location_id":"9667","lat":"42.14326","long":"2.510207","pm25":""},{"location_name":"ES1348A","location_id":"9668","lat":"42.368317","long":"1.7767832","pm25":""},{"location_name":"ES1349A","location_id":"9669","lat":"43.144444","long":"-2.9633334","pm25":""},{"location_name":"ES1353A","location_id":"9670","lat":"43.294117","long":"-5.679632","pm25":""},{"location_name":"ES1358A","location_id":"9672","lat":"43.53777","long":"-5.646307","pm25":""},{"location_name":"ES1365A","location_id":"9673","lat":"38.70272","long":"-4.112","pm25":""},{"location_name":"ES1370A","location_id":"9674","lat":"36.74312","long":"-3.5173","pm25":""},{"location_name":"ES1379A","location_id":"9675","lat":"41.058205","long":"0.4397117","pm25":""},{"location_name":"ES1386A","location_id":"9676","lat":"40.01278","long":"-0.05722222","pm25":""},{"location_name":"ES1387A","location_id":"9677","lat":"39.962776","long":"-0.23333333","pm25":""},{"location_name":"ES1393A","location_id":"9678","lat":"36.84133","long":"-2.44672","pm25":""},{"location_name":"ES1396A","location_id":"9679","lat":"41.378803","long":"2.1330981","pm25":""},{"location_name":"ES1397A","location_id":"9680","lat":"42.003277","long":"2.287272","pm25":""},{"location_name":"ES1400A","location_id":"9681","lat":"41.50556","long":"-0.15194","pm25":""},{"location_name":"ES1417A","location_id":"9682","lat":"42.13611","long":"-0.40389","pm25":""},{"location_name":"ES1418A","location_id":"9683","lat":"41.76278","long":"-1.14333","pm25":""},{"location_name":"ES1421A","location_id":"9684","lat":"40.33639","long":"-1.10667","pm25":""},{"location_name":"ES1422A","location_id":"9685","lat":"40.419167","long":"-3.7033334","pm25":""},{"location_name":"ES1423A","location_id":"9686","lat":"37.69361","long":"-1.0647222","pm25":""},{"location_name":"ES1424A","location_id":"9687","lat":"43.55885","long":"-5.92748","pm25":""},{"location_name":"ES1425A","location_id":"9688","lat":"37.37525","long":"-6.00558","pm25":""},{"location_name":"ES1426A","location_id":"9689","lat":"40.408054","long":"-3.6452777","pm25":""},{"location_name":"ES1428A","location_id":"9690","lat":"39.959167","long":"-0.03611111","pm25":""},{"location_name":"ES1432A","location_id":"9691","lat":"43.1788","long":"-6.5527","pm25":""},{"location_name":"ES1433A","location_id":"9692","lat":"43.275635","long":"-5.59599","pm25":""},{"location_name":"ES1435A","location_id":"9693","lat":"40.416668","long":"-0.24916665","pm25":""},{"location_name":"ES1437A","location_id":"9694","lat":"40.691666","long":"0.08472222","pm25":""},{"location_name":"ES1438A","location_id":"9695","lat":"41.38534","long":"2.153822","pm25":""},{"location_name":"ES1441A","location_id":"9696","lat":"40.637222","long":"-0.09111111","pm25":""},{"location_name":"ES1442A","location_id":"9697","lat":"43.064167","long":"-2.49","pm25":""},{"location_name":"ES1443A","location_id":"9698","lat":"42.33611","long":"-3.63611","pm25":""},{"location_name":"ES1445A","location_id":"9699","lat":"39.981945","long":"0.01055555","pm25":""},{"location_name":"ES1450A","location_id":"9700","lat":"37.39831","long":"-5.95165","pm25":""},{"location_name":"ES1453A","location_id":"9701","lat":"41.44735","long":"2.2095113","pm25":""},{"location_name":"ES1472A","location_id":"9702","lat":"42.80722","long":"-1.65139","pm25":""},{"location_name":"ES1479A","location_id":"9703","lat":"36.50602","long":"-6.26857","pm25":""},{"location_name":"ES1480A","location_id":"9704","lat":"41.398743","long":"2.1533852","pm25":""},{"location_name":"ES1489A","location_id":"9705","lat":"42.87528","long":"-3.2313888","pm25":""},{"location_name":"ES1490A","location_id":"9706","lat":"43.172222","long":"-2.6358333","pm25":""},{"location_name":"ES1491A","location_id":"9707","lat":"43.406113","long":"-2.703889","pm25":""},{"location_name":"ES1492A","location_id":"9708","lat":"42.855556","long":"-2.6680555","pm25":""},{"location_name":"ES1494A","location_id":"9709","lat":"43.322777","long":"-1.9602778","pm25":""},{"location_name":"ES1498A","location_id":"9710","lat":"43.130833","long":"-2.0777779","pm25":""},{"location_name":"ES1499A","location_id":"9711","lat":"43.048332","long":"-2.191111","pm25":""},{"location_name":"ES1501A","location_id":"9712","lat":"43.18","long":"-2.2680554","pm25":""},{"location_name":"ES1502A","location_id":"9713","lat":"42.85472","long":"-2.6805556","pm25":""},{"location_name":"ES1516A","location_id":"9714","lat":"36.52283","long":"-6.22517","pm25":""},{"location_name":"ES1517A","location_id":"9715","lat":"39.83379","long":"3.1443","pm25":""},{"location_name":"ES1518A","location_id":"9716","lat":"39.83962","long":"3.02705","pm25":""},{"location_name":"ES1519A","location_id":"9717","lat":"37.42986","long":"-5.98039","pm25":""},{"location_name":"ES1521A","location_id":"9718","lat":"40.478333","long":"-3.7113888","pm25":""},{"location_name":"ES1525A","location_id":"9719","lat":"40.44528","long":"-3.706389","pm25":""},{"location_name":"ES1529A","location_id":"9720","lat":"43.46778","long":"-3.79028","pm25":""},{"location_name":"ES1530A","location_id":"9721","lat":"43.01194","long":"-4.13556","pm25":""},{"location_name":"ES1531A","location_id":"9722","lat":"43.15333","long":"-4.25306","pm25":""},{"location_name":"ES1532A","location_id":"9723","lat":"40.388054","long":"-3.651389","pm25":""},{"location_name":"ES1535A","location_id":"9724","lat":"38.97928","long":"-1.85213","pm25":""},{"location_name":"ES1536A","location_id":"9725","lat":"40.57099","long":"-3.26461","pm25":""},{"location_name":"ES1537A","location_id":"9726","lat":"40.62984","long":"-3.17159","pm25":""},{"location_name":"ES1542A","location_id":"9727","lat":"40.55472","long":"0.37277776","pm25":""},{"location_name":"ES1543A","location_id":"9728","lat":"40.735","long":"-0.16944444","pm25":""},{"location_name":"ES1544A","location_id":"9729","lat":"42.849167","long":"-2.4772222","pm25":""},{"location_name":"ES1549A","location_id":"9732","lat":"36.76972","long":"-2.81097","pm25":""},{"location_name":"ES1551A","location_id":"9733","lat":"41.512676","long":"2.1253836","pm25":""},{"location_name":"ES1560A","location_id":"9734","lat":"37.1961","long":"-3.61266","pm25":""},{"location_name":"ES1563A","location_id":"9735","lat":"40.47917","long":"-3.37778","pm25":""},{"location_name":"ES1564A","location_id":"9736","lat":"40.54056","long":"-3.64472","pm25":""},{"location_name":"ES1565A","location_id":"9737","lat":"40.28111","long":"-3.80167","pm25":""},{"location_name":"ES1567A","location_id":"9738","lat":"40.33972","long":"-3.73583","pm25":""},{"location_name":"ES1568A","location_id":"9739","lat":"40.32417","long":"-3.87639","pm25":""},{"location_name":"ES1569A","location_id":"9740","lat":"37.68889","long":"-1.7011111","pm25":""},{"location_name":"ES1572A","location_id":"9741","lat":"43.372677","long":"-5.872797","pm25":""},{"location_name":"ES1573A","location_id":"9742","lat":"28.133732","long":"-15.432823","pm25":""},{"location_name":"ES1576A","location_id":"9743","lat":"43.40444","long":"-3.84194","pm25":""},{"location_name":"ES1577A","location_id":"9744","lat":"43.42083","long":"-3.84111","pm25":""},{"location_name":"ES1578A","location_id":"9745","lat":"43.3825","long":"-3.22056","pm25":""},{"location_name":"ES1579A","location_id":"9746","lat":"43.26444","long":"-4.06278","pm25":""},{"location_name":"ES1580A","location_id":"9747","lat":"43.46056","long":"-3.80861","pm25":""},{"location_name":"ES1588A","location_id":"9748","lat":"41.906647","long":"1.1929748","pm25":""},{"location_name":"ES1593A","location_id":"9750","lat":"36.46059","long":"-6.20307","pm25":""},{"location_name":"ES1595A","location_id":"9751","lat":"43.298332","long":"-2.9302778","pm25":""},{"location_name":"ES1596A","location_id":"9752","lat":"41.66639","long":"-4.715","pm25":""},{"location_name":"ES1597A","location_id":"9753","lat":"41.683334","long":"-4.7411113","pm25":""},{"location_name":"ES1598A","location_id":"9754","lat":"43.213055","long":"-3.1344445","pm25":""},{"location_name":"ES1599A","location_id":"9755","lat":"43.250557","long":"-2.155","pm25":""},{"location_name":"ES1601A","location_id":"9756","lat":"38.88763","long":"-7.01145","pm25":""},{"location_name":"ES1602A","location_id":"9757","lat":"42.46389","long":"-2.42778","pm25":""},{"location_name":"ES1604A","location_id":"9758","lat":"39.56332","long":"2.62055","pm25":""},{"location_name":"ES1610A","location_id":"9759","lat":"39.57008","long":"2.65583","pm25":""},{"location_name":"ES1611A","location_id":"9760","lat":"40.03328","long":"-3.5916445","pm25":""},{"location_name":"ES1612A","location_id":"9761","lat":"40.44778","long":"-3.86722","pm25":""},{"location_name":"ES1613A","location_id":"9762","lat":"40.66639","long":"-3.77222","pm25":""},{"location_name":"ES1615A","location_id":"9763","lat":"39.47278","long":"-6.36028","pm25":""},{"location_name":"ES1616A","location_id":"9764","lat":"39.84917","long":"-5.93972","pm25":""},{"location_name":"ES1617A","location_id":"9765","lat":"39.15","long":"-0.45777777","pm25":""},{"location_name":"ES1618A","location_id":"9766","lat":"40.979168","long":"-5.665278","pm25":""},{"location_name":"ES1619A","location_id":"9767","lat":"39.478054","long":"-0.36833334","pm25":""},{"location_name":"ES1620A","location_id":"9768","lat":"36.66086","long":"-6.11449","pm25":""},{"location_name":"ES1623A","location_id":"9769","lat":"38.70639","long":"-0.46694443","pm25":""},{"location_name":"ES1624A","location_id":"9770","lat":"38.24222","long":"-0.68277776","pm25":""},{"location_name":"ES1625A","location_id":"9771","lat":"39.509445","long":"-0.41777778","pm25":""},{"location_name":"ES1627A","location_id":"9772","lat":"37.975555","long":"-1.2308333","pm25":""},{"location_name":"ES1630A","location_id":"9773","lat":"37.34075","long":"-6.04246","pm25":""},{"location_name":"ES1631A","location_id":"9774","lat":"41.645557","long":"-4.7302775","pm25":""},{"location_name":"ES1632A","location_id":"9775","lat":"41.620556","long":"-4.7466664","pm25":""},{"location_name":"ES1633A","location_id":"9776","lat":"37.99361","long":"-1.1447222","pm25":""},{"location_name":"ES1634A","location_id":"9777","lat":"36.17315","long":"-5.34194","pm25":""},{"location_name":"ES1635A","location_id":"9778","lat":"38.359444","long":"-0.47194445","pm25":""},{"location_name":"ES1636A","location_id":"9779","lat":"41.656113","long":"-4.733889","pm25":""},{"location_name":"ES1637A","location_id":"9780","lat":"36.16174","long":"-5.44255","pm25":""},{"location_name":"ES1638A","location_id":"9781","lat":"37.34719","long":"-5.97963","pm25":""},{"location_name":"ES1640A","location_id":"9782","lat":"37.34246","long":"-5.83372","pm25":""},{"location_name":"ES1641A","location_id":"9783","lat":"41.63528","long":"-0.89361","pm25":""},{"location_name":"ES1642A","location_id":"9784","lat":"41.935665","long":"2.2385683","pm25":""},{"location_name":"ES1643A","location_id":"9785","lat":"41.766666","long":"-2.4666667","pm25":""},{"location_name":"ES1644A","location_id":"9786","lat":"37.38808","long":"-5.99149","pm25":""},{"location_name":"ES1645A","location_id":"9787","lat":"40.474724","long":"-3.575","pm25":""},{"location_name":"ES1648A","location_id":"9788","lat":"36.23386","long":"-5.6635","pm25":""},{"location_name":"ES1649A","location_id":"9789","lat":"42.17583","long":"-1.74333","pm25":""},{"location_name":"ES1651A","location_id":"9790","lat":"43.25612","long":"-5.77594","pm25":""},{"location_name":"ES1653A","location_id":"9791","lat":"37.28449","long":"-5.91384","pm25":""},{"location_name":"ES1654A","location_id":"9792","lat":"37.99435","long":"-5.66687","pm25":""},{"location_name":"ES1656A","location_id":"9793","lat":"37.78255","long":"-3.78157","pm25":""},{"location_name":"ES1658A","location_id":"9794","lat":"37.27148","long":"-6.92462","pm25":""},{"location_name":"ES1661A","location_id":"9795","lat":"42.07472","long":"-1.62694","pm25":""},{"location_name":"ES1662A","location_id":"9796","lat":"42.30833","long":"-1.80833","pm25":""},{"location_name":"ES1664A","location_id":"9797","lat":"36.13623","long":"-5.45343","pm25":""},{"location_name":"ES1666A","location_id":"9798","lat":"41.11739","long":"1.2416497","pm25":""},{"location_name":"ES1670A","location_id":"9799","lat":"39.558613","long":"-1.2813889","pm25":""},{"location_name":"ES1671A","location_id":"9800","lat":"39.708057","long":"-0.83194447","pm25":""},{"location_name":"ES1672A","location_id":"9801","lat":"42.518333","long":"-2.6194444","pm25":""},{"location_name":"ES1673A","location_id":"9802","lat":"42.843613","long":"-2.6613889","pm25":""},{"location_name":"ES1675A","location_id":"9803","lat":"38.57139","long":"-0.14666666","pm25":""},{"location_name":"ES1677A","location_id":"9804","lat":"38.08472","long":"-0.8527778","pm25":""},{"location_name":"ES1679A","location_id":"9805","lat":"41.386414","long":"2.1874168","pm25":""},{"location_name":"ES1684A","location_id":"9806","lat":"41.492085","long":"2.0424972","pm25":""},{"location_name":"ES1685A","location_id":"9807","lat":"40.051945","long":"-0.18972223","pm25":""},{"location_name":"ES1687A","location_id":"9808","lat":"40.06222","long":"0.07277777","pm25":""},{"location_name":"ES1688A","location_id":"9809","lat":"39.892223","long":"-0.065","pm25":""},{"location_name":"ES1689A","location_id":"9810","lat":"40.054165","long":"-0.46833333","pm25":""},{"location_name":"ES1690A","location_id":"9811","lat":"40.269444","long":"-0.07888888","pm25":""},{"location_name":"ES1691A","location_id":"9812","lat":"39.930557","long":"-0.60333335","pm25":""},{"location_name":"ES1697A","location_id":"9813","lat":"43.309444","long":"-2.011111","pm25":""},{"location_name":"ES1709A","location_id":"9814","lat":"38.934723","long":"-0.44138888","pm25":""},{"location_name":"ES1711A","location_id":"9815","lat":"38.788055","long":"-0.69722223","pm25":""},{"location_name":"ES1712A","location_id":"9816","lat":"43.299168","long":"-2.9872222","pm25":""},{"location_name":"ES1713A","location_id":"9817","lat":"43.255","long":"-2.9022222","pm25":""},{"location_name":"ES1718A","location_id":"9818","lat":"38.174397","long":"-3.01022","pm25":""},{"location_name":"ES1740A","location_id":"9819","lat":"42.81222","long":"-1.64","pm25":""},{"location_name":"ES1741A","location_id":"9820","lat":"27.763653","long":"-15.563851","pm25":""},{"location_name":"ES1742A","location_id":"9821","lat":"27.772598","long":"-15.541881","pm25":""},{"location_name":"ES1744A","location_id":"9822","lat":"27.86907","long":"-15.38715","pm25":""},{"location_name":"ES1745A","location_id":"9823","lat":"27.897638","long":"-15.445028","pm25":""},{"location_name":"ES1746A","location_id":"9824","lat":"42.34167","long":"-2.23167","pm25":""},{"location_name":"ES1747A","location_id":"9825","lat":"42.82694","long":"-1.64944","pm25":""},{"location_name":"ES1749A","location_id":"9826","lat":"42.89444","long":"-2.16583","pm25":""},{"location_name":"ES1750A","location_id":"9827","lat":"36.71964","long":"-4.4475","pm25":""},{"location_name":"ES1751A","location_id":"9828","lat":"36.72956","long":"-4.46553","pm25":""},{"location_name":"ES1752A","location_id":"9829","lat":"40.455","long":"-3.48417","pm25":""},{"location_name":"ES1753A","location_id":"9830","lat":"42.34","long":"-2.05972","pm25":""},{"location_name":"ES1754A","location_id":"9831","lat":"40.643005","long":"0.28844598","pm25":""},{"location_name":"ES1755A","location_id":"9832","lat":"42.58056","long":"-1.2825","pm25":""},{"location_name":"ES1756A","location_id":"9833","lat":"28.376713","long":"-16.361929","pm25":""},{"location_name":"ES1759A","location_id":"9834","lat":"28.451021","long":"-16.277693","pm25":""},{"location_name":"ES1760A","location_id":"9835","lat":"28.112486","long":"-16.577578","pm25":""},{"location_name":"ES1761A","location_id":"9836","lat":"28.080008","long":"-16.559855","pm25":""},{"location_name":"ES1762A","location_id":"9837","lat":"28.047333","long":"-16.536049","pm25":""},{"location_name":"ES1763A","location_id":"9838","lat":"27.801277","long":"-15.461157","pm25":""},{"location_name":"ES1764A","location_id":"9839","lat":"28.380537","long":"-16.371986","pm25":""},{"location_name":"ES1765A","location_id":"9840","lat":"39.684723","long":"-0.27888888","pm25":""},{"location_name":"ES1766A","location_id":"9841","lat":"28.145094","long":"-16.523687","pm25":""},{"location_name":"ES1767A","location_id":"9842","lat":"28.07255","long":"-16.653023","pm25":""},{"location_name":"ES1768A","location_id":"9843","lat":"28.007738","long":"-16.655912","pm25":""},{"location_name":"ES1769A","location_id":"9844","lat":"28.111374","long":"-16.471624","pm25":""},{"location_name":"ES1772A","location_id":"9845","lat":"28.393408","long":"-16.3581","pm25":""},{"location_name":"ES1773A","location_id":"9846","lat":"41.202232","long":"1.6722","pm25":""},{"location_name":"ES1778A","location_id":"9847","lat":"41.779343","long":"2.3580189","pm25":""},{"location_name":"ES1779A","location_id":"9848","lat":"42.43889","long":"-2.25028","pm25":""},{"location_name":"ES1781A","location_id":"9849","lat":"36.68855","long":"-6.11724","pm25":""},{"location_name":"ES1785A","location_id":"9850","lat":"36.9231","long":"-2.46322","pm25":""},{"location_name":"ES1786A","location_id":"9851","lat":"36.86495","long":"-2.3905","pm25":""},{"location_name":"ES1790A","location_id":"9852","lat":"42.542778","long":"-6.584722","pm25":""},{"location_name":"ES1792A","location_id":"9853","lat":"37.13379","long":"-6.80745","pm25":""},{"location_name":"ES1793A","location_id":"9854","lat":"37.10409","long":"-6.73408","pm25":""},{"location_name":"ES1799A","location_id":"9855","lat":"37.89261","long":"-4.76234","pm25":""},{"location_name":"ES1800A","location_id":"9856","lat":"37.90274","long":"-4.77958","pm25":""},{"location_name":"ES1801A","location_id":"9857","lat":"40.30083","long":"-3.45889","pm25":""},{"location_name":"ES1802A","location_id":"9858","lat":"40.91028","long":"-3.46667","pm25":""},{"location_name":"ES1803A","location_id":"9859","lat":"40.63389","long":"-4.01333","pm25":""},{"location_name":"ES1805A","location_id":"9860","lat":"40.78083","long":"-3.7025","pm25":""},{"location_name":"ES1806A","location_id":"9861","lat":"40.28694","long":"-3.22222","pm25":""},{"location_name":"ES1807A","location_id":"9862","lat":"40.35853","long":"-3.54414","pm25":""},{"location_name":"ES1808A","location_id":"9863","lat":"40.36889","long":"-4.39694","pm25":""},{"location_name":"ES1809A","location_id":"9864","lat":"40.18528","long":"-3.67972","pm25":""},{"location_name":"ES1810A","location_id":"9865","lat":"40.25194","long":"-4.27472","pm25":""},{"location_name":"ES1811A","location_id":"9866","lat":"40.16722","long":"-3.27667","pm25":""},{"location_name":"ES1812A","location_id":"9867","lat":"41.27838","long":"1.1799166","pm25":""},{"location_name":"ES1813A","location_id":"9868","lat":"41.100693","long":"0.7551003","pm25":""},{"location_name":"ES1814A","location_id":"9869","lat":"41.549168","long":"2.21205","pm25":""},{"location_name":"ES1815A","location_id":"9870","lat":"41.346825","long":"1.6865755","pm25":""},{"location_name":"ES1816A","location_id":"9871","lat":"41.54716","long":"2.4432538","pm25":""},{"location_name":"ES1817A","location_id":"9872","lat":"41.526707","long":"2.1837952","pm25":""},{"location_name":"ES1818A","location_id":"9873","lat":"39.86806","long":"-4.02083","pm25":""},{"location_name":"ES1819A","location_id":"9874","lat":"38.9075","long":"-6.33806","pm25":""},{"location_name":"ES1820A","location_id":"9875","lat":"38.42917","long":"-6.395","pm25":""},{"location_name":"ES1821A","location_id":"9876","lat":"36.73975","long":"-5.74372","pm25":""},{"location_name":"ES1822A","location_id":"9877","lat":"36.79449","long":"-5.53162","pm25":""},{"location_name":"ES1824A","location_id":"9878","lat":"37.78444","long":"-3.81032","pm25":""},{"location_name":"ES1825A","location_id":"9879","lat":"38.99323","long":"1.30894","pm25":""},{"location_name":"ES1826A","location_id":"9880","lat":"39.551388","long":"-0.46083334","pm25":""},{"location_name":"ES1827A","location_id":"9881","lat":"39.67766","long":"2.68665","pm25":""},{"location_name":"ES1828A","location_id":"9882","lat":"40.00944","long":"3.85648","pm25":""},{"location_name":"ES1829A","location_id":"9883","lat":"39.6331","long":"2.63044","pm25":""},{"location_name":"ES1831A","location_id":"9884","lat":"38.93492","long":"1.43181","pm25":""},{"location_name":"ES1834A","location_id":"9887","lat":"39.988888","long":"-0.02611111","pm25":""},{"location_name":"ES1835A","location_id":"9888","lat":"36.95","long":"-1.96148","pm25":""},{"location_name":"ES1836A","location_id":"9889","lat":"41.64222","long":"-0.86194","pm25":""},{"location_name":"ES1837A","location_id":"9890","lat":"41.64833","long":"-0.88389","pm25":""},{"location_name":"ES1838A","location_id":"9891","lat":"40.59333","long":"-3.50306","pm25":""},{"location_name":"ES1845A","location_id":"9892","lat":"36.99678","long":"-1.89535","pm25":""},{"location_name":"ES1849A","location_id":"9893","lat":"38.259167","long":"-0.7175","pm25":""},{"location_name":"ES1851A","location_id":"9894","lat":"42.09791","long":"1.8482373","pm25":""},{"location_name":"ES1853A","location_id":"9895","lat":"41.24489","long":"1.6177046","pm25":""},{"location_name":"ES1854A","location_id":"9896","lat":"41.008213","long":"0.8310847","pm25":""},{"location_name":"ES1855A","location_id":"9897","lat":"41.009506","long":"0.91287583","pm25":""},{"location_name":"ES1856A","location_id":"9898","lat":"41.42608","long":"2.1479921","pm25":""},{"location_name":"ES1857A","location_id":"9899","lat":"38.99389","long":"-3.93778","pm25":""},{"location_name":"ES1858A","location_id":"9900","lat":"40.06185","long":"-2.12972","pm25":""},{"location_name":"ES1859A","location_id":"9901","lat":"39.95856","long":"-4.8457","pm25":""},{"location_name":"ES1860A","location_id":"9902","lat":"37.55502","long":"-6.03616","pm25":""},{"location_name":"ES1863A","location_id":"9903","lat":"28.97699","long":"-13.547584","pm25":""},{"location_name":"ES1864A","location_id":"9904","lat":"28.99031","long":"-13.51655","pm25":""},{"location_name":"ES1865A","location_id":"9905","lat":"28.500256","long":"-13.852395","pm25":""},{"location_name":"ES1866A","location_id":"9906","lat":"28.502762","long":"-13.8537","pm25":""},{"location_name":"ES1867A","location_id":"9907","lat":"43.480556","long":"-8.241389","pm25":""},{"location_name":"ES1868A","location_id":"9908","lat":"42.87583","long":"-8.559167","pm25":""},{"location_name":"ES1869A","location_id":"9909","lat":"40.43","long":"-3.54583","pm25":""},{"location_name":"ES1877A","location_id":"9910","lat":"39.94528","long":"-0.05638888","pm25":""},{"location_name":"ES1878A","location_id":"9911","lat":"37.0161","long":"-6.57042","pm25":""},{"location_name":"ES1879A","location_id":"9912","lat":"41.22528","long":"-0.36472","pm25":""},{"location_name":"ES1882A","location_id":"9913","lat":"38.114723","long":"-1.8686111","pm25":""},{"location_name":"ES1883A","location_id":"9914","lat":"42.45778","long":"0.18194","pm25":""},{"location_name":"ES1884A","location_id":"9915","lat":"39.634167","long":"-0.26583332","pm25":""},{"location_name":"ES1885A","location_id":"9916","lat":"39.480278","long":"-0.3363889","pm25":""},{"location_name":"ES1886A","location_id":"9917","lat":"39.427223","long":"-0.7838889","pm25":""},{"location_name":"ES1889A","location_id":"9918","lat":"40.960835","long":"-5.6397223","pm25":""},{"location_name":"ES1890A","location_id":"9919","lat":"40.34194","long":"-3.83389","pm25":""},{"location_name":"ES1891A","location_id":"9920","lat":"41.598667","long":"2.2871177","pm25":""},{"location_name":"ES1892A","location_id":"9921","lat":"41.443985","long":"2.2378752","pm25":""},{"location_name":"ES1897A","location_id":"9922","lat":"36.72785","long":"-4.56095","pm25":""},{"location_name":"ES1898A","location_id":"9923","lat":"36.9623","long":"-4.84483","pm25":""},{"location_name":"ES1899A","location_id":"9924","lat":"41.308403","long":"1.6473399","pm25":""},{"location_name":"ES1901A","location_id":"9925","lat":"42.88778","long":"-8.530833","pm25":""},{"location_name":"ES1903A","location_id":"9926","lat":"41.313477","long":"2.0138247","pm25":""},{"location_name":"ES1905A","location_id":"9927","lat":"42.998055","long":"-7.55","pm25":""},{"location_name":"ES1910A","location_id":"9928","lat":"41.303112","long":"1.991524","pm25":""},{"location_name":"ES1911A","location_id":"9929","lat":"39.705276","long":"-0.33666667","pm25":""},{"location_name":"ES1912A","location_id":"9930","lat":"39.4575","long":"-0.34277776","pm25":""},{"location_name":"ES1913A","location_id":"9931","lat":"38.451668","long":"-1.0647222","pm25":""},{"location_name":"ES1914A","location_id":"9932","lat":"38.454723","long":"-0.80333334","pm25":""},{"location_name":"ES1915A","location_id":"9933","lat":"38.34028","long":"-0.50666666","pm25":""},{"location_name":"ES1917A","location_id":"9934","lat":"40.099445","long":"-1.2538888","pm25":""},{"location_name":"ES1919A","location_id":"9935","lat":"28.003645","long":"-15.411851","pm25":""},{"location_name":"ES1920A","location_id":"9936","lat":"28.33722","long":"-16.39972","pm25":""},{"location_name":"ES1921A","location_id":"9937","lat":"37.603054","long":"-0.9752778","pm25":""},{"location_name":"ES1922A","location_id":"9938","lat":"42.019444","long":"-4.5383334","pm25":""},{"location_name":"ES1923A","location_id":"9939","lat":"41.846035","long":"2.2175756","pm25":""},{"location_name":"ES1924A","location_id":"9940","lat":"37.16568","long":"-3.6001","pm25":""},{"location_name":"ES1925A","location_id":"9941","lat":"36.1801","long":"-5.3825","pm25":""},{"location_name":"ES1927A","location_id":"9942","lat":"41.509724","long":"-5.746389","pm25":""},{"location_name":"ES1929A","location_id":"9943","lat":"41.321495","long":"2.0977252","pm25":""},{"location_name":"ES1930A","location_id":"9944","lat":"40.902695","long":"0.80979544","pm25":""},{"location_name":"ES1937A","location_id":"9945","lat":"40.398056","long":"-3.6866667","pm25":""},{"location_name":"ES1938A","location_id":"9946","lat":"40.439724","long":"-3.6902778","pm25":""},{"location_name":"ES1939A","location_id":"9947","lat":"40.40972","long":"-3.6855555","pm25":""},{"location_name":"ES1940A","location_id":"9948","lat":"40.46583","long":"-3.6883333","pm25":""},{"location_name":"ES1941A","location_id":"9949","lat":"40.372776","long":"-3.6119444","pm25":""},{"location_name":"ES1942A","location_id":"9950","lat":"40.4625","long":"-3.5805554","pm25":""},{"location_name":"ES1943A","location_id":"9951","lat":"40.384724","long":"-3.718611","pm25":""},{"location_name":"ES1944A","location_id":"9952","lat":"40.494167","long":"-3.6602778","pm25":""},{"location_name":"ES1945A","location_id":"9953","lat":"40.518055","long":"-3.7744443","pm25":""},{"location_name":"ES1946A","location_id":"9954","lat":"40.465","long":"-3.6088889","pm25":""},{"location_name":"ES1947A","location_id":"9955","lat":"40.500557","long":"-3.6897223","pm25":""},{"location_name":"ES1948A","location_id":"9956","lat":"40.939552","long":"0.831337","pm25":""},{"location_name":"ES1952A","location_id":"9957","lat":"28.111265","long":"-15.520924","pm25":""},{"location_name":"ES1954A","location_id":"9958","lat":"28.383097","long":"-16.57067","pm25":""},{"location_name":"ES1955A","location_id":"9959","lat":"28.96787","long":"-13.555856","pm25":""},{"location_name":"ES1956A","location_id":"9960","lat":"28.645395","long":"-17.771555","pm25":""},{"location_name":"ES1963A","location_id":"9961","lat":"40.11922","long":"-3.83279","pm25":""},{"location_name":"ES1964A","location_id":"9962","lat":"41.38664","long":"2.0573926","pm25":""},{"location_name":"ES1967A","location_id":"9963","lat":"40.955555","long":"-4.1105556","pm25":""},{"location_name":"ES1968A","location_id":"9964","lat":"38.351112","long":"-0.5138889","pm25":""},{"location_name":"ES1969A","location_id":"9965","lat":"39.823612","long":"-0.24444444","pm25":""},{"location_name":"ES1970A","location_id":"9966","lat":"39.45028","long":"-0.3963889","pm25":""},{"location_name":"ES1971A","location_id":"9967","lat":"38.13793","long":"-4.90397","pm25":""},{"location_name":"ES1972A","location_id":"9968","lat":"38.13246","long":"-4.80173","pm25":""},{"location_name":"ES1973A","location_id":"9969","lat":"37.13556","long":"-3.61925","pm25":""},{"location_name":"ES1974A","location_id":"9970","lat":"43.516586","long":"-5.67065","pm25":""},{"location_name":"ES1975A","location_id":"9971","lat":"28.45816","long":"-16.278776","pm25":""},{"location_name":"ES1976A","location_id":"9972","lat":"28.461788","long":"-16.27662","pm25":""},{"location_name":"ES1977A","location_id":"9973","lat":"27.89833","long":"-15.48833","pm25":""},{"location_name":"ES1978A","location_id":"9974","lat":"28.49838","long":"-13.86083","pm25":""},{"location_name":"ES1979A","location_id":"9975","lat":"28.667711","long":"-17.775553","pm25":""},{"location_name":"ES1980A","location_id":"9976","lat":"28.685984","long":"-17.764587","pm25":""},{"location_name":"ES1982A","location_id":"9977","lat":"42.051342","long":"0.72955567","pm25":""},{"location_name":"ES1983A","location_id":"9978","lat":"41.32177","long":"2.0821407","pm25":""},{"location_name":"ES1986A","location_id":"9979","lat":"41.665554","long":"-3.6888888","pm25":""},{"location_name":"ES1987A","location_id":"9980","lat":"42.951946","long":"-3.4752777","pm25":""},{"location_name":"ES1988A","location_id":"9981","lat":"42.57528","long":"-5.566389","pm25":""},{"location_name":"ES1989A","location_id":"9982","lat":"43.04139","long":"-5.089722","pm25":""},{"location_name":"ES1990A","location_id":"9983","lat":"40.56972","long":"-6.223889","pm25":""},{"location_name":"ES1991A","location_id":"9984","lat":"41.72361","long":"-2.8569443","pm25":""},{"location_name":"ES1992A","location_id":"9985","lat":"41.387486","long":"2.1151497","pm25":""},{"location_name":"ES1995A","location_id":"9986","lat":"39.54588","long":"2.69971","pm25":""},{"location_name":"ES1996A","location_id":"9987","lat":"37.19342","long":"-1.9854","pm25":""},{"location_name":"ES1997A","location_id":"9988","lat":"40.07778","long":"-6.14722","pm25":""},{"location_name":"ES1999A","location_id":"9989","lat":"41.976387","long":"2.8165474","pm25":""},{"location_name":"ES2000A","location_id":"9990","lat":"28.457954","long":"-16.26333","pm25":""},{"location_name":"ES2001A","location_id":"9991","lat":"39.260834","long":"-0.9344444","pm25":""},{"location_name":"ES2002A","location_id":"9992","lat":"28.52722","long":"-14.00444","pm25":""},{"location_name":"ES2003A","location_id":"9993","lat":"28.455376","long":"-16.27675","pm25":""},{"location_name":"ES2004A","location_id":"9994","lat":"28.026318","long":"-15.414657","pm25":""},{"location_name":"ES2007A","location_id":"9995","lat":"37.574444","long":"-0.9266667","pm25":""},{"location_name":"ES2008A","location_id":"9996","lat":"37.99111","long":"-0.69","pm25":""},{"location_name":"ES2010A","location_id":"9997","lat":"41.63","long":"-4.740556","pm25":""},{"location_name":"ES2011A","location_id":"9998","lat":"41.400772","long":"1.9996347","pm25":""},{"location_name":"ES2012A","location_id":"9999","lat":"41.415318","long":"1.9905212","pm25":""},{"location_name":"ES2014A","location_id":"10000","lat":"42.06167","long":"-7.4085417","pm25":""},{"location_name":"ES2015A","location_id":"10001","lat":"42.181427","long":"-8.523931","pm25":""},{"location_name":"ES2017A","location_id":"10002","lat":"40.55282","long":"0.5299825","pm25":""},{"location_name":"ES2018A","location_id":"10003","lat":"39.782223","long":"-0.35916665","pm25":""},{"location_name":"ES2019A","location_id":"10004","lat":"39.564724","long":"-0.6255556","pm25":""},{"location_name":"ES2020A","location_id":"10005","lat":"28.45666","long":"-16.271835","pm25":""},{"location_name":"ES2021A","location_id":"10006","lat":"28.46301","long":"-16.26488","pm25":""},{"location_name":"ES2022A","location_id":"10007","lat":"28.38016","long":"-16.36833","pm25":""},{"location_name":"ES2023A","location_id":"10008","lat":"28.8051","long":"-17.78255","pm25":""},{"location_name":"ES2024A","location_id":"10009","lat":"27.831766","long":"-17.92167","pm25":""},{"location_name":"ES2025A","location_id":"10010","lat":"28.50616","long":"-13.84898","pm25":""},{"location_name":"ES2026A","location_id":"10011","lat":"36.8951","long":"-2.04672","pm25":""},{"location_name":"ES2028A","location_id":"10012","lat":"40.31285","long":"-3.71724","pm25":""},{"location_name":"ES2029A","location_id":"10013","lat":"40.66472","long":"-4.70083","pm25":""},{"location_name":"ES2030A","location_id":"10014","lat":"36.511","long":"-4.863","pm25":""},{"location_name":"ES2031A","location_id":"10015","lat":"36.7073","long":"-4.446","pm25":""},{"location_name":"ES2034A","location_id":"10016","lat":"41.544106","long":"0.82993317","pm25":""},{"location_name":"ES2038A","location_id":"10018","lat":"28.459314","long":"-16.270206","pm25":""},{"location_name":"ES2040A","location_id":"10019","lat":"37.1388","long":"-1.8422","pm25":""},{"location_name":"ES2041A","location_id":"10020","lat":"41.91614","long":"0.191101","pm25":""},{"location_name":"ES2042A","location_id":"10021","lat":"41.61417","long":"-4.77222","pm25":""},{"location_name":"ES2044A","location_id":"10022","lat":"28.09905","long":"-17.12051","pm25":""},{"location_name":"ES2047A","location_id":"10023","lat":"37.8926","long":"-4.7801","pm25":""},{"location_name":"ES2051A","location_id":"10024","lat":"43.4015","long":"-5.80287","pm25":""},{"location_name":"ES2053A","location_id":"10025","lat":"28.09012","long":"-17.1181","pm25":""},{"location_name":"ES2054A","location_id":"10026","lat":"43.57045","long":"-5.95828","pm25":""},{"location_name":"ES2058A","location_id":"10028","lat":"43.2553","long":"-2.97344","pm25":""},{"location_name":"ES2061A","location_id":"10029","lat":"42.71648","long":"-8.644105","pm25":""},{"location_name":"ES2063A","location_id":"10030","lat":"42.2224","long":"-8.711082","pm25":""},{"location_name":"ES2064A","location_id":"10031","lat":"41.65917","long":"-0.9068","pm25":""},{"location_name":"ES2065A","location_id":"10032","lat":"39.830235","long":"2.9007194","pm25":""},{"location_name":"ES2066A","location_id":"10033","lat":"36.9581","long":"-2.1592","pm25":""},{"location_name":"ES2067A","location_id":"10034","lat":"37.0047","long":"-1.9344","pm25":""},{"location_name":"ES2068A","location_id":"10035","lat":"43.0819","long":"-1.9127","pm25":""},{"location_name":"ES2069A","location_id":"10036","lat":"43.5229","long":"-5.689452","pm25":""},{"location_name":"ES2074A","location_id":"10037","lat":"28.47544","long":"-16.25853","pm25":""},{"location_name":"ES2075A","location_id":"10038","lat":"43.34565","long":"-5.96967","pm25":""},{"location_name":"ETOWN2","location_id":"10039","lat":"37.7064","long":"-85.8517","pm25":""},{"location_name":"Eagle Mountain Lake","location_id":"10042","lat":"32.9881","long":"-97.4764","pm25":""},{"location_name":"Ealing Horn Lane","location_id":"10044","lat":"51.51895","long":"-0.265617","pm25":""},{"location_name":"East Chicago Post Of","location_id":"10046","lat":"41.628613","long":"-87.46139","pm25":""},{"location_name":"East Hartford","location_id":"10047","lat":"41.7847","long":"-72.6297","pm25":""},{"location_name":"East High School","location_id":"10048","lat":"41.063526","long":"-81.468956","pm25":""},{"location_name":"East Liverpool","location_id":"10049","lat":"40.631973","long":"-80.547295","pm25":""},{"location_name":"Eastbourne","location_id":"10052","lat":"50.80578","long":"0.271611","pm25":""},{"location_name":"Eastern","location_id":"10053","lat":"22.282778","long":"114.219444","pm25":""},{"location_name":"Eastlake","location_id":"10054","lat":"41.673004","long":"-81.422455","pm25":""},{"location_name":"Eastman Ross N Robin","location_id":"10055","lat":"36.532616","long":"-82.516304","pm25":""},{"location_name":"Eau Claire","location_id":"10058","lat":"44.7614","long":"-91.413","pm25":""},{"location_name":"Edgar Evins","location_id":"10060","lat":"36.0388","long":"-85.7331","pm25":""},{"location_name":"Edgewood","location_id":"10061","lat":"39.41","long":"-76.2967","pm25":""},{"location_name":"Edinburgh St Leonards","location_id":"10062","lat":"55.945587","long":"-3.182186","pm25":""},{"location_name":"Edison","location_id":"10063","lat":"35.345608","long":"-118.85182","pm25":""},{"location_name":"Eibergen-Lintveldseweg","location_id":"10064","lat":"52.0918","long":"6.60537","pm25":""},{"location_name":"Eilif Dues vei","location_id":"10065","lat":"59.90608","long":"10.61195","pm25":""},{"location_name":"Eindhoven-Genovevalaan","location_id":"10066","lat":"51.4687","long":"5.47235","pm25":""},{"location_name":"Eindhoven-Noordbrabantlaan","location_id":"10067","lat":"51.4442","long":"5.44483","pm25":""},{"location_name":"Eisenhower Park","location_id":"10068","lat":"40.7447","long":"-73.5869","pm25":""},{"location_name":"El Cajon - Lexington","location_id":"10073","lat":"32.789562","long":"-116.94422","pm25":""},{"location_name":"El Centro - 9th Stre","location_id":"10075","lat":"32.7917","long":"-115.5617","pm25":""},{"location_name":"El Paso UTEP C12","location_id":"10077","lat":"31.768057","long":"-106.501114","pm25":""},{"location_name":"El Rio - Rio Mesa Sc","location_id":"10078","lat":"34.2653","long":"-119.1336","pm25":""},{"location_name":"Elgeseter","location_id":"10080","lat":"63.41924","long":"10.395945","pm25":""},{"location_name":"Eliza Howell- Roadwa","location_id":"10083","lat":"42.38599","long":"-83.26632","pm25":""},{"location_name":"Elizabeth","location_id":"10084","lat":"40.662388","long":"-74.21481","pm25":""},{"location_name":"Elizabeth Trailer","location_id":"10085","lat":"40.64144","long":"-74.20837","pm25":""},{"location_name":"Elk Grove","location_id":"10086","lat":"38.30259","long":"-121.42084","pm25":""},{"location_name":"Elkhart-Prairie St.","location_id":"10088","lat":"41.656944","long":"-85.96833","pm25":""},{"location_name":"Elko","location_id":"10090","lat":"40.83833","long":"-115.76601","pm25":""},{"location_name":"Ellensburg-Ruby St","location_id":"10091","lat":"46.9936","long":"-120.545","pm25":""},{"location_name":"Ellyson Industrial P","location_id":"10092","lat":"30.525","long":"-87.2044","pm25":""},{"location_name":"Eloy","location_id":"10093","lat":"32.75764","long":"-111.55486","pm25":""},{"location_name":"Ely","location_id":"10094","lat":"47.9464","long":"-91.4953","pm25":""},{"location_name":"Emmetsburg, ILCC","location_id":"10096","lat":"43.1233","long":"-94.6933","pm25":""},{"location_name":"Emporia","location_id":"10097","lat":"40.0025","long":"-85.6569","pm25":""},{"location_name":"Enoch","location_id":"10098","lat":"37.747444","long":"-113.05553","pm25":""},{"location_name":"Enschede-Winkelhorst","location_id":"10099","lat":"52.2345","long":"6.91949","pm25":""},{"location_name":"Enterprise - US Fore","location_id":"10100","lat":"45.42635","long":"-117.29607","pm25":""},{"location_name":"Erda","location_id":"10103","lat":"40.600555","long":"-112.355","pm25":""},{"location_name":"Eskdalemuir","location_id":"10111","lat":"55.31531","long":"-3.206111","pm25":""},{"location_name":"Essex","location_id":"10112","lat":"39.310833","long":"-76.47444","pm25":""},{"location_name":"Estaci\u00f3n Abasolo","location_id":"10113","lat":"20.450916","long":"-101.52869","pm25":""},{"location_name":"Estaci\u00f3n Bomberos","location_id":"10114","lat":"20.67495","long":"-101.35595","pm25":""},{"location_name":"Estaci\u00f3n CICEG","location_id":"10115","lat":"21.10179","long":"-101.6347","pm25":""},{"location_name":"Estaci\u00f3n Cruz Roja","location_id":"10116","lat":"20.578558","long":"-101.19886","pm25":""},{"location_name":"Estaci\u00f3n DIF","location_id":"10117","lat":"20.558153","long":"-101.20485","pm25":""},{"location_name":"Estaci\u00f3n Facultad de","location_id":"10118","lat":"21.133894","long":"-101.68025","pm25":""},{"location_name":"Estaci\u00f3n Guanajuato","location_id":"10119","lat":"21.017675","long":"-101.257515","pm25":""},{"location_name":"Estaci\u00f3n Hospital Ge","location_id":"10120","lat":"20.9479","long":"-101.4258","pm25":""},{"location_name":"Estaci\u00f3n Nativitas","location_id":"10121","lat":"20.565228","long":"-101.18824","pm25":""},{"location_name":"Estaci\u00f3n Pur\u00edsima de","location_id":"10122","lat":"21.03439","long":"-101.866585","pm25":""},{"location_name":"Estaci\u00f3n San Juanico","location_id":"10123","lat":"20.537683","long":"-100.83994","pm25":""},{"location_name":"Estaci\u00f3n San Luis de","location_id":"10124","lat":"21.298874","long":"-100.51557","pm25":""},{"location_name":"Estaci\u00f3n San Miguel","location_id":"10125","lat":"20.914812","long":"-100.74384","pm25":""},{"location_name":"Estaci\u00f3n Secundaria","location_id":"10126","lat":"20.6924","long":"-101.36487","pm25":""},{"location_name":"Estaci\u00f3n Seguridad P","location_id":"10127","lat":"20.518316","long":"-100.81591","pm25":""},{"location_name":"Estaci\u00f3n T21","location_id":"10128","lat":"21.108683","long":"-101.68863","pm25":""},{"location_name":"Estaci\u00f3n Tecnol\u00f3gico","location_id":"10129","lat":"20.545427","long":"-100.80707","pm25":""},{"location_name":"Estaci\u00f3n Te\u00f3dula","location_id":"10130","lat":"20.65794","long":"-101.34915","pm25":""},{"location_name":"Eugene - Amazon Park","location_id":"10131","lat":"44.0263","long":"-123.08377","pm25":""},{"location_name":"Eugene - Highway 99","location_id":"10132","lat":"44.067223","long":"-123.14135","pm25":""},{"location_name":"Eugene - Wilkes Dr.","location_id":"10133","lat":"44.1158","long":"-123.12107","pm25":""},{"location_name":"Evansville-Buena Vis","location_id":"10135","lat":"38.0133","long":"-87.5772","pm25":""},{"location_name":"Evansville-Lloyd","location_id":"10136","lat":"37.977222","long":"-87.59639","pm25":""},{"location_name":"Exeter Roadside","location_id":"10138","lat":"50.725082","long":"-3.532465","pm25":""},{"location_name":"FAB","location_id":"10139","lat":"39.9603","long":"-75.1424","pm25":""},{"location_name":"FBHWWTP","location_id":"10142","lat":"30.6575","long":"-81.464165","pm25":""},{"location_name":"FEBBIO","location_id":"10143","lat":"44.3007","long":"10.431","pm25":""},{"location_name":"FI00027","location_id":"10147","lat":"64.99473","long":"25.47926","pm25":""},{"location_name":"FI00066","location_id":"10148","lat":"60.98781","long":"25.64954","pm25":""},{"location_name":"FI00080","location_id":"10150","lat":"61.23807","long":"28.87369","pm25":""},{"location_name":"FI00179","location_id":"10151","lat":"61.33169","long":"22.1433","pm25":""},{"location_name":"FI00184","location_id":"10152","lat":"61.31495","long":"22.13671","pm25":""},{"location_name":"FI00208","location_id":"10154","lat":"60.313595","long":"24.689476","pm25":""},{"location_name":"FI00273","location_id":"10155","lat":"61.12838","long":"28.83776","pm25":""},{"location_name":"FI00280","location_id":"10156","lat":"61.05748","long":"28.24585","pm25":""},{"location_name":"FI00283","location_id":"10157","lat":"61.04082","long":"28.1765","pm25":""},{"location_name":"FI00301","location_id":"10158","lat":"65.04338","long":"25.4979","pm25":""},{"location_name":"FI00339","location_id":"10159","lat":"60.36005","long":"25.56605","pm25":""},{"location_name":"FI00349","location_id":"10160","lat":"59.77923","long":"21.37395","pm25":""},{"location_name":"FI00352","location_id":"10161","lat":"66.3217","long":"29.40157","pm25":""},{"location_name":"FI00356","location_id":"10162","lat":"67.96735","long":"24.112219","pm25":""},{"location_name":"FI00357","location_id":"10163","lat":"68.47701","long":"28.3031","pm25":""},{"location_name":"FI00370","location_id":"10165","lat":"60.28995","long":"25.03953","pm25":""},{"location_name":"FI00378","location_id":"10166","lat":"61.07194","long":"28.26409","pm25":""},{"location_name":"FI00397","location_id":"10167","lat":"63.67912","long":"22.71837","pm25":""},{"location_name":"FI00404","location_id":"10168","lat":"63.83764","long":"23.1316","pm25":""},{"location_name":"FI00424","location_id":"10169","lat":"61.18892","long":"28.77012","pm25":""},{"location_name":"FI00425","location_id":"10170","lat":"60.18739","long":"24.9506","pm25":""},{"location_name":"FI00428","location_id":"10171","lat":"63.1431","long":"31.04695","pm25":""},{"location_name":"FI00431","location_id":"10172","lat":"62.28999","long":"25.70917","pm25":""},{"location_name":"FI00433","location_id":"10173","lat":"61.15304","long":"28.81014","pm25":""},{"location_name":"FI00434","location_id":"10174","lat":"61.11709","long":"28.49849","pm25":""},{"location_name":"FI00438","location_id":"10175","lat":"60.51316","long":"26.94621","pm25":""},{"location_name":"FI00446","location_id":"10176","lat":"65.00997","long":"25.47132","pm25":""},{"location_name":"FI00455","location_id":"10177","lat":"60.96704","long":"25.65489","pm25":""},{"location_name":"FI00460","location_id":"10178","lat":"60.42532","long":"22.09611","pm25":""},{"location_name":"FI00465","location_id":"10180","lat":"63.09515","long":"21.61832","pm25":""},{"location_name":"FI00549","location_id":"10181","lat":"61.49873","long":"23.73569","pm25":""},{"location_name":"FI00558","location_id":"10182","lat":"62.8935","long":"27.6883","pm25":""},{"location_name":"FI00564","location_id":"10183","lat":"60.16964","long":"24.93924","pm25":""},{"location_name":"FI00570","location_id":"10184","lat":"64.68337","long":"24.48162","pm25":""},{"location_name":"FI00586","location_id":"10185","lat":"63.10121","long":"21.60407","pm25":""},{"location_name":"FI00606","location_id":"10187","lat":"61.05576","long":"28.18431","pm25":""},{"location_name":"FI00621","location_id":"10188","lat":"61.86111","long":"24.28333","pm25":""},{"location_name":"FI00761","location_id":"10189","lat":"60.25145","long":"24.06287","pm25":""},{"location_name":"FI00781","location_id":"10190","lat":"60.22393","long":"25.10244","pm25":""},{"location_name":"FI00801","location_id":"10191","lat":"61.4991","long":"23.80221","pm25":""},{"location_name":"FI00838","location_id":"10192","lat":"61.50854","long":"23.67583","pm25":""},{"location_name":"FI00839","location_id":"10193","lat":"62.88205","long":"27.66197","pm25":""},{"location_name":"FI00841","location_id":"10194","lat":"60.22024","long":"24.81133","pm25":""},{"location_name":"FI00867","location_id":"10195","lat":"60.97907","long":"25.59109","pm25":""},{"location_name":"FI00893","location_id":"10196","lat":"60.53002","long":"27.6754","pm25":""},{"location_name":"FI00902","location_id":"10197","lat":"60.19644","long":"24.95198","pm25":""},{"location_name":"FIVCO","location_id":"10198","lat":"38.4592","long":"-82.6339","pm25":""},{"location_name":"FLAMINIA","location_id":"10199","lat":"44.0521","long":"12.5757","pm25":""},{"location_name":"FLINT","location_id":"10200","lat":"43.0289","long":"-83.6694","pm25":""},{"location_name":"FR01005","location_id":"10202","lat":"49.32472","long":"6.0761056","pm25":""},{"location_name":"FR01011","location_id":"10204","lat":"49.119427","long":"6.1808314","pm25":""},{"location_name":"FR01012","location_id":"10205","lat":"49.110256","long":"6.2233396","pm25":""},{"location_name":"FR01014","location_id":"10206","lat":"48.914993","long":"6.058337","pm25":""},{"location_name":"FR01015","location_id":"10207","lat":"48.8847","long":"6.051393","pm25":""},{"location_name":"FR01016","location_id":"10208","lat":"48.886414","long":"6.093614","pm25":""},{"location_name":"FR01018","location_id":"10209","lat":"49.10749","long":"6.122773","pm25":""},{"location_name":"FR01019","location_id":"10210","lat":"49.36861","long":"6.160835","pm25":""},{"location_name":"FR01020","location_id":"10211","lat":"49.358315","long":"6.156945","pm25":""},{"location_name":"FR01021","location_id":"10212","lat":"49.39446","long":"6.2013936","pm25":""},{"location_name":"FR01022","location_id":"10213","lat":"49.131126","long":"6.207224","pm25":""},{"location_name":"FR01059","location_id":"10214","lat":"49.33742","long":"6.0820704","pm25":""},{"location_name":"FR01060","location_id":"10215","lat":"49.168846","long":"6.2126675","pm25":""},{"location_name":"FR01064","location_id":"10216","lat":"49.125072","long":"6.1812177","pm25":""},{"location_name":"FR01065","location_id":"10217","lat":"49.16779","long":"5.3874574","pm25":""},{"location_name":"FR02001","location_id":"10218","lat":"43.485863","long":"5.171942","pm25":""},{"location_name":"FR02003","location_id":"10219","lat":"43.386974","long":"5.160282","pm25":""},{"location_name":"FR02004","location_id":"10220","lat":"43.41667","long":"5.043052","pm25":""},{"location_name":"FR02005","location_id":"10221","lat":"43.405186","long":"5.0514965","pm25":""},{"location_name":"FR02006","location_id":"10222","lat":"43.36112","long":"5.0247173","pm25":""},{"location_name":"FR02008","location_id":"10223","lat":"43.40225","long":"4.9822183","pm25":""},{"location_name":"FR02009","location_id":"10224","lat":"43.40029","long":"4.796393","pm25":""},{"location_name":"FR02011","location_id":"10225","lat":"43.43748","long":"4.9436088","pm25":""},{"location_name":"FR02012","location_id":"10226","lat":"43.509453","long":"4.982775","pm25":""},{"location_name":"FR02013","location_id":"10227","lat":"43.458874","long":"4.9341674","pm25":""},{"location_name":"FR02019","location_id":"10228","lat":"43.457245","long":"5.244302","pm25":""},{"location_name":"FR02020","location_id":"10229","lat":"43.51056","long":"5.2197237","pm25":""},{"location_name":"FR02021","location_id":"10230","lat":"43.331394","long":"5.117774","pm25":""},{"location_name":"FR02022","location_id":"10231","lat":"43.675556","long":"4.6286144","pm25":""},{"location_name":"FR02024","location_id":"10232","lat":"43.457222","long":"4.426667","pm25":""},{"location_name":"FR02026","location_id":"10233","lat":"43.58498","long":"5.006392","pm25":""},{"location_name":"FR02028","location_id":"10234","lat":"43.385994","long":"5.0269456","pm25":""},{"location_name":"FR02029","location_id":"10235","lat":"43.399574","long":"5.11472","pm25":""},{"location_name":"FR02033","location_id":"10236","lat":"43.34054","long":"5.058611","pm25":""},{"location_name":"FR02041","location_id":"10237","lat":"43.638966","long":"5.0999966","pm25":""},{"location_name":"FR03006","location_id":"10239","lat":"43.27635","long":"5.397671","pm25":""},{"location_name":"FR03014","location_id":"10240","lat":"43.348053","long":"5.3606515","pm25":""},{"location_name":"FR03021","location_id":"10241","lat":"43.524044","long":"5.449576","pm25":""},{"location_name":"FR03027","location_id":"10242","lat":"43.335182","long":"5.7273617","pm25":""},{"location_name":"FR03029","location_id":"10243","lat":"43.530296","long":"5.4413834","pm25":""},{"location_name":"FR03030","location_id":"10244","lat":"43.45346","long":"5.467102","pm25":""},{"location_name":"FR03032","location_id":"10245","lat":"43.29479","long":"5.571738","pm25":""},{"location_name":"FR03037","location_id":"10246","lat":"43.28315","long":"5.5120897","pm25":""},{"location_name":"FR03043","location_id":"10247","lat":"43.3061","long":"5.3957934","pm25":""},{"location_name":"FR03048","location_id":"10248","lat":"43.555756","long":"5.461802","pm25":""},{"location_name":"FR03060","location_id":"10249","lat":"43.101604","long":"5.875386","pm25":""},{"location_name":"FR03067","location_id":"10250","lat":"43.398724","long":"6.0761056","pm25":""},{"location_name":"FR03068","location_id":"10251","lat":"43.126785","long":"5.921937","pm25":""},{"location_name":"FR03069","location_id":"10252","lat":"43.119705","long":"6.131801","pm25":""},{"location_name":"FR03070","location_id":"10253","lat":"43.43781","long":"6.7683926","pm25":""},{"location_name":"FR03071","location_id":"10254","lat":"43.131046","long":"5.924237","pm25":""},{"location_name":"FR03080","location_id":"10255","lat":"43.949757","long":"4.8050795","pm25":""},{"location_name":"FR03084","location_id":"10256","lat":"43.960167","long":"4.8572087","pm25":""},{"location_name":"FR03086","location_id":"10257","lat":"43.880062","long":"5.362502","pm25":""},{"location_name":"FR03087","location_id":"10258","lat":"43.937077","long":"4.824932","pm25":""},{"location_name":"FR03088","location_id":"10259","lat":"44.06044","long":"5.0674233","pm25":""},{"location_name":"FR04002","location_id":"10260","lat":"48.92969","long":"2.2947195","pm25":""},{"location_name":"FR04004","location_id":"10261","lat":"48.89167","long":"2.346669","pm25":""},{"location_name":"FR04014","location_id":"10263","lat":"48.837242","long":"2.3939025","pm25":""},{"location_name":"FR04017","location_id":"10264","lat":"48.881393","long":"2.2780557","pm25":""},{"location_name":"FR04018","location_id":"10265","lat":"48.903896","long":"2.3847036","pm25":""},{"location_name":"FR04023","location_id":"10266","lat":"49.04641","long":"2.0430565","pm25":""},{"location_name":"FR04024","location_id":"10267","lat":"48.990856","long":"2.44472","pm25":""},{"location_name":"FR04029","location_id":"10268","lat":"48.799152","long":"2.1305523","pm25":""},{"location_name":"FR04031","location_id":"10269","lat":"48.868866","long":"2.3119402","pm25":""},{"location_name":"FR04034","location_id":"10270","lat":"48.775772","long":"2.3758013","pm25":""},{"location_name":"FR04037","location_id":"10271","lat":"48.82861","long":"2.3602786","pm25":""},{"location_name":"FR04038","location_id":"10272","lat":"48.581936","long":"1.883336","pm25":""},{"location_name":"FR04048","location_id":"10273","lat":"49.100258","long":"2.3438933","pm25":""},{"location_name":"FR04049","location_id":"10274","lat":"48.67942","long":"2.1655598","pm25":""},{"location_name":"FR04051","location_id":"10275","lat":"48.951405","long":"2.2236087","pm25":""},{"location_name":"FR04058","location_id":"10276","lat":"48.925266","long":"2.3566673","pm25":""},{"location_name":"FR04059","location_id":"10277","lat":"48.937244","long":"2.361671","pm25":""},{"location_name":"FR04060","location_id":"10278","lat":"48.8572","long":"2.2933","pm25":""},{"location_name":"FR04063","location_id":"10279","lat":"48.996395","long":"1.7032956","pm25":""},{"location_name":"FR04066","location_id":"10280","lat":"48.36414","long":"2.23694","pm25":""},{"location_name":"FR04069","location_id":"10281","lat":"48.54139","long":"2.6613848","pm25":""},{"location_name":"FR04071","location_id":"10282","lat":"48.856396","long":"2.3352783","pm25":""},{"location_name":"FR04098","location_id":"10283","lat":"48.84026","long":"2.6352797","pm25":""},{"location_name":"FR04099","location_id":"10284","lat":"48.840553","long":"2.4844437","pm25":""},{"location_name":"FR04100","location_id":"10285","lat":"48.881924","long":"2.5072248","pm25":""},{"location_name":"FR04101","location_id":"10286","lat":"48.81637","long":"2.5175016","pm25":""},{"location_name":"FR04118","location_id":"10287","lat":"48.870285","long":"2.3325026","pm25":""},{"location_name":"FR04122","location_id":"10288","lat":"48.528065","long":"2.6536143","pm25":""},{"location_name":"FR04123","location_id":"10289","lat":"48.90224","long":"2.3908303","pm25":""},{"location_name":"FR04131","location_id":"10290","lat":"48.873333","long":"2.330278","pm25":""},{"location_name":"FR04135","location_id":"10291","lat":"48.83795","long":"2.4080598","pm25":""},{"location_name":"FR04141","location_id":"10292","lat":"48.85279","long":"2.360557","pm25":""},{"location_name":"FR04142","location_id":"10293","lat":"49.028038","long":"2.750282","pm25":""},{"location_name":"FR04149","location_id":"10296","lat":"48.7067","long":"2.4571977","pm25":""},{"location_name":"FR04150","location_id":"10297","lat":"48.891376","long":"2.24056","pm25":""},{"location_name":"FR04156","location_id":"10298","lat":"48.902477","long":"2.4524996","pm25":""},{"location_name":"FR04158","location_id":"10299","lat":"49.063072","long":"1.8663847","pm25":""},{"location_name":"FR04173","location_id":"10300","lat":"48.805542","long":"3.0844464","pm25":""},{"location_name":"FR04179","location_id":"10301","lat":"48.830383","long":"2.26989","pm25":""},{"location_name":"FR04180","location_id":"10302","lat":"48.64091","long":"2.2687223","pm25":""},{"location_name":"FR04181","location_id":"10303","lat":"48.633728","long":"1.830533","pm25":""},{"location_name":"FR04319","location_id":"10304","lat":"48.955536","long":"2.5752814","pm25":""},{"location_name":"FR04323","location_id":"10305","lat":"48.627197","long":"2.4291704","pm25":""},{"location_name":"FR04324","location_id":"10306","lat":"48.76168","long":"3.0583324","pm25":""},{"location_name":"FR04328","location_id":"10307","lat":"48.35471","long":"2.6452959","pm25":""},{"location_name":"FR04329","location_id":"10308","lat":"48.838604","long":"2.412785","pm25":""},{"location_name":"FR05010","location_id":"10309","lat":"49.528923","long":"0.35873324","pm25":""},{"location_name":"FR05037","location_id":"10310","lat":"49.503906","long":"0.17573114","pm25":""},{"location_name":"FR05056","location_id":"10312","lat":"49.473736","long":"0.5261576","pm25":""},{"location_name":"FR05069","location_id":"10313","lat":"49.487682","long":"0.45175558","pm25":""},{"location_name":"FR05070","location_id":"10314","lat":"49.505013","long":"0.20169424","pm25":""},{"location_name":"FR05072","location_id":"10315","lat":"49.503845","long":"0.08461402","pm25":""},{"location_name":"FR05074","location_id":"10316","lat":"49.48961","long":"0.10070294","pm25":""},{"location_name":"FR05078","location_id":"10317","lat":"49.498302","long":"0.14270636","pm25":""},{"location_name":"FR05080","location_id":"10318","lat":"49.503613","long":"0.2668724","pm25":""},{"location_name":"FR05081","location_id":"10319","lat":"49.50402","long":"0.41159368","pm25":""},{"location_name":"FR05082","location_id":"10320","lat":"49.348015","long":"0.10925311","pm25":""},{"location_name":"FR05083","location_id":"10321","lat":"49.50274","long":"0.23248579","pm25":""},{"location_name":"FR05084","location_id":"10322","lat":"49.493343","long":"0.57185316","pm25":""},{"location_name":"FR05085","location_id":"10323","lat":"49.51213","long":"0.53903586","pm25":""},{"location_name":"FR05087","location_id":"10324","lat":"49.498295","long":"0.758833","pm25":""},{"location_name":"FR05088","location_id":"10325","lat":"49.74999","long":"0.4159002","pm25":""},{"location_name":"FR05089","location_id":"10326","lat":"49.50017","long":"0.11090331","pm25":""},{"location_name":"FR05090","location_id":"10327","lat":"49.514694","long":"0.100645445","pm25":""},{"location_name":"FR06001","location_id":"10328","lat":"50.35853","long":"3.508038","pm25":""},{"location_name":"FR06003","location_id":"10329","lat":"50.378242","long":"3.0658603","pm25":""},{"location_name":"FR06006","location_id":"10330","lat":"50.36426","long":"3.5227344","pm25":""},{"location_name":"FR06007","location_id":"10331","lat":"50.279377","long":"3.9769137","pm25":""},{"location_name":"FR06011","location_id":"10333","lat":"50.322754","long":"3.3959281","pm25":""},{"location_name":"FR06133","location_id":"10334","lat":"50.092266","long":"3.8500266","pm25":""},{"location_name":"FR06134","location_id":"10335","lat":"50.456486","long":"3.4279442","pm25":""},{"location_name":"FR07004","location_id":"10337","lat":"45.797264","long":"3.1138303","pm25":""},{"location_name":"FR07009","location_id":"10338","lat":"45.772144","long":"3.0875006","pm25":""},{"location_name":"FR07022","location_id":"10340","lat":"46.652645","long":"3.6006632","pm25":""},{"location_name":"FR07028","location_id":"10341","lat":"45.92932","long":"2.82981","pm25":""},{"location_name":"FR07031","location_id":"10342","lat":"45.104702","long":"3.2773595","pm25":""},{"location_name":"FR07034","location_id":"10344","lat":"45.775715","long":"3.0962503","pm25":""},{"location_name":"FR07039","location_id":"10345","lat":"45.774776","long":"3.0629675","pm25":""},{"location_name":"FR07048","location_id":"10347","lat":"46.659058","long":"3.249314","pm25":""},{"location_name":"FR07051","location_id":"10348","lat":"45.769012","long":"3.155","pm25":""},{"location_name":"FR07052","location_id":"10349","lat":"44.92009","long":"2.441082","pm25":""},{"location_name":"FR07053","location_id":"10350","lat":"45.780415","long":"3.1115935","pm25":""},{"location_name":"FR07054","location_id":"10351","lat":"45.03898","long":"3.8870013","pm25":""},{"location_name":"FR08003","location_id":"10352","lat":"43.611652","long":"3.864723","pm25":""},{"location_name":"FR08004","location_id":"10353","lat":"43.60502","long":"3.8745954","pm25":""},{"location_name":"FR08016","location_id":"10354","lat":"43.591553","long":"3.8868935","pm25":""},{"location_name":"FR08017","location_id":"10355","lat":"43.5706","long":"3.9115522","pm25":""},{"location_name":"FR08018","location_id":"10356","lat":"43.695366","long":"3.8008168","pm25":""},{"location_name":"FR08020","location_id":"10357","lat":"43.67575","long":"4.0884213","pm25":""},{"location_name":"FR08022","location_id":"10358","lat":"43.287727","long":"3.504831","pm25":""},{"location_name":"FR08023","location_id":"10359","lat":"43.40682","long":"3.1888037","pm25":""},{"location_name":"FR08030","location_id":"10362","lat":"43.609962","long":"3.8986075","pm25":""},{"location_name":"FR08209","location_id":"10364","lat":"43.942898","long":"4.6796837","pm25":""},{"location_name":"FR08252","location_id":"10365","lat":"44.05353","long":"4.6973624","pm25":""},{"location_name":"FR08614","location_id":"10366","lat":"43.834393","long":"4.3742204","pm25":""},{"location_name":"FR08616","location_id":"10367","lat":"43.829857","long":"4.3619857","pm25":""},{"location_name":"FR08617","location_id":"10368","lat":"43.92537","long":"4.265812","pm25":""},{"location_name":"FR08712","location_id":"10370","lat":"42.719803","long":"2.8398712","pm25":""},{"location_name":"FR08713","location_id":"10371","lat":"42.684025","long":"2.9034538","pm25":""},{"location_name":"FR08714","location_id":"10372","lat":"42.695778","long":"2.899699","pm25":""},{"location_name":"FR09003","location_id":"10373","lat":"46.162556","long":"-1.153603","pm25":""},{"location_name":"FR09008","location_id":"10374","lat":"46.135128","long":"-1.1170461","pm25":""},{"location_name":"FR09015","location_id":"10375","lat":"46.586933","long":"0.3585832","pm25":""},{"location_name":"FR09016","location_id":"10376","lat":"45.608807","long":"0.09972198","pm25":""},{"location_name":"FR09019","location_id":"10378","lat":"46.329563","long":"-0.4588891","pm25":""},{"location_name":"FR09103","location_id":"10379","lat":"45.647438","long":"0.16716659","pm25":""},{"location_name":"FR09106","location_id":"10380","lat":"45.65146","long":"0.1623669","pm25":""},{"location_name":"FR09203","location_id":"10381","lat":"46.16164","long":"-1.2112075","pm25":""},{"location_name":"FR09301","location_id":"10382","lat":"46.82435","long":"-0.13546056","pm25":""},{"location_name":"FR09302","location_id":"10383","lat":"46.143158","long":"-0.39604205","pm25":""},{"location_name":"FR09399","location_id":"10384","lat":"46.321747","long":"-0.4659723","pm25":""},{"location_name":"FR09404","location_id":"10386","lat":"46.583908","long":"0.34555584","pm25":""},{"location_name":"FR10004","location_id":"10387","lat":"51.048573","long":"2.4200435","pm25":""},{"location_name":"FR10012","location_id":"10388","lat":"51.01942","long":"2.2509894","pm25":""},{"location_name":"FR10016","location_id":"10389","lat":"50.947315","long":"1.8430824","pm25":""},{"location_name":"FR10025","location_id":"10390","lat":"50.949863","long":"1.7691691","pm25":""},{"location_name":"FR10026","location_id":"10391","lat":"50.957787","long":"1.8900824","pm25":""},{"location_name":"FR10028","location_id":"10392","lat":"50.981037","long":"2.1431737","pm25":""},{"location_name":"FR10029","location_id":"10393","lat":"50.995907","long":"2.365994","pm25":""},{"location_name":"FR10032","location_id":"10394","lat":"50.69432","long":"1.5765703","pm25":""},{"location_name":"FR10034","location_id":"10395","lat":"51.024452","long":"2.3021486","pm25":""},{"location_name":"FR10041","location_id":"10396","lat":"50.748238","long":"2.259784","pm25":""},{"location_name":"FR10132","location_id":"10397","lat":"50.610485","long":"1.9914482","pm25":""},{"location_name":"FR11007","location_id":"10398","lat":"50.6408","long":"3.0747714","pm25":""},{"location_name":"FR11016","location_id":"10399","lat":"50.670017","long":"3.076559","pm25":""},{"location_name":"FR11025","location_id":"10400","lat":"50.62804","long":"3.0903125","pm25":""},{"location_name":"FR11026","location_id":"10401","lat":"50.775455","long":"3.125679","pm25":""},{"location_name":"FR11034","location_id":"10404","lat":"50.706554","long":"3.180656","pm25":""},{"location_name":"FR11114","location_id":"10405","lat":"50.597713","long":"3.049457","pm25":""},{"location_name":"FR12004","location_id":"10406","lat":"43.575546","long":"1.4186106","pm25":""},{"location_name":"FR12015","location_id":"10407","lat":"43.094456","long":"0.74472225","pm25":""},{"location_name":"FR12016","location_id":"10408","lat":"43.10639","long":"0.71888936","pm25":""},{"location_name":"FR12020","location_id":"10409","lat":"43.630253","long":"0.17972234","pm25":""},{"location_name":"FR12021","location_id":"10410","lat":"43.62362","long":"1.438607","pm25":""},{"location_name":"FR12026","location_id":"10411","lat":"43.928055","long":"2.146111","pm25":""},{"location_name":"FR12029","location_id":"10412","lat":"43.88362","long":"0.84500027","pm25":""},{"location_name":"FR12030","location_id":"10413","lat":"43.587193","long":"1.4438891","pm25":""},{"location_name":"FR12031","location_id":"10414","lat":"43.441395","long":"1.8219451","pm25":""},{"location_name":"FR12039","location_id":"10415","lat":"43.560837","long":"1.3950028","pm25":""},{"location_name":"FR12040","location_id":"10416","lat":"43.55693","long":"1.4063934","pm25":""},{"location_name":"FR12041","location_id":"10417","lat":"43.457504","long":"1.5711085","pm25":""},{"location_name":"FR12042","location_id":"10418","lat":"43.096947","long":"-0.03888897","pm25":""},{"location_name":"FR12044","location_id":"10419","lat":"43.63402","long":"1.3760034","pm25":""},{"location_name":"FR12045","location_id":"10420","lat":"43.09498","long":"-0.051944003","pm25":""},{"location_name":"FR12047","location_id":"10421","lat":"43.803867","long":"1.5958302","pm25":""},{"location_name":"FR12052","location_id":"10422","lat":"43.23029","long":"0.06222199","pm25":""},{"location_name":"FR12053","location_id":"10423","lat":"43.610546","long":"2.2299957","pm25":""},{"location_name":"FR12054","location_id":"10424","lat":"43.64306","long":"1.4676496","pm25":""},{"location_name":"FR14008","location_id":"10428","lat":"49.90778","long":"4.6299977","pm25":""},{"location_name":"FR14010","location_id":"10429","lat":"49.282192","long":"4.0511146","pm25":""},{"location_name":"FR14011","location_id":"10430","lat":"49.250713","long":"4.0230603","pm25":""},{"location_name":"FR14012","location_id":"10431","lat":"49.224144","long":"4.0205536","pm25":""},{"location_name":"FR14022","location_id":"10432","lat":"48.9622","long":"4.36","pm25":""},{"location_name":"FR14028","location_id":"10433","lat":"49.046116","long":"3.955911","pm25":""},{"location_name":"FR14029","location_id":"10434","lat":"48.726612","long":"4.594784","pm25":""},{"location_name":"FR14031","location_id":"10435","lat":"48.301674","long":"4.076941","pm25":""},{"location_name":"FR14032","location_id":"10436","lat":"48.299164","long":"4.1172214","pm25":""},{"location_name":"FR14033","location_id":"10437","lat":"48.29498","long":"4.050279","pm25":""},{"location_name":"FR14042","location_id":"10438","lat":"48.64584","long":"4.9661117","pm25":""},{"location_name":"FR14051","location_id":"10439","lat":"49.745285","long":"4.7191644","pm25":""},{"location_name":"FR15013","location_id":"10441","lat":"45.079525","long":"5.7286553","pm25":""},{"location_name":"FR15018","location_id":"10443","lat":"45.360157","long":"5.5894165","pm25":""},{"location_name":"FR15031","location_id":"10444","lat":"44.997005","long":"6.469397","pm25":""},{"location_name":"FR15038","location_id":"10445","lat":"45.182827","long":"5.7530985","pm25":""},{"location_name":"FR15039","location_id":"10446","lat":"45.158382","long":"5.703763","pm25":""},{"location_name":"FR15043","location_id":"10447","lat":"45.16193","long":"5.7355995","pm25":""},{"location_name":"FR15045","location_id":"10448","lat":"45.057827","long":"5.676697","pm25":""},{"location_name":"FR15046","location_id":"10449","lat":"45.180676","long":"5.7200584","pm25":""},{"location_name":"FR15048","location_id":"10450","lat":"45.279682","long":"5.8822045","pm25":""},{"location_name":"FR16001","location_id":"10451","lat":"48.60879","long":"7.7089195","pm25":""},{"location_name":"FR16017","location_id":"10452","lat":"48.91936","long":"8.158455","pm25":""},{"location_name":"FR16029","location_id":"10453","lat":"48.610332","long":"7.781629","pm25":""},{"location_name":"FR16031","location_id":"10454","lat":"48.857285","long":"7.3141727","pm25":""},{"location_name":"FR16034","location_id":"10455","lat":"48.59043","long":"7.744987","pm25":""},{"location_name":"FR16038","location_id":"10456","lat":"48.570347","long":"7.7663307","pm25":""},{"location_name":"FR16040","location_id":"10457","lat":"48.575993","long":"7.727479","pm25":""},{"location_name":"FR16041","location_id":"10458","lat":"48.51569","long":"7.687818","pm25":""},{"location_name":"FR16052","location_id":"10459","lat":"47.810944","long":"7.105557","pm25":""},{"location_name":"FR16054","location_id":"10460","lat":"48.07463","long":"7.3506713","pm25":""},{"location_name":"FR16057","location_id":"10461","lat":"47.757465","long":"7.347294","pm25":""},{"location_name":"FR16059","location_id":"10462","lat":"47.820232","long":"7.5386796","pm25":""},{"location_name":"FR16060","location_id":"10463","lat":"47.59494","long":"7.5681715","pm25":""},{"location_name":"FR16064","location_id":"10464","lat":"48.065388","long":"7.333136","pm25":""},{"location_name":"FR16065","location_id":"10465","lat":"47.72309","long":"7.3416076","pm25":""},{"location_name":"FR16066","location_id":"10466","lat":"47.73741","long":"7.3090796","pm25":""},{"location_name":"FR16067","location_id":"10467","lat":"47.802197","long":"7.122841","pm25":""},{"location_name":"FR16069","location_id":"10468","lat":"47.74768","long":"7.321368","pm25":""},{"location_name":"FR16302","location_id":"10469","lat":"48.49301","long":"7.1298027","pm25":""},{"location_name":"FR18019","location_id":"10470","lat":"49.27639","long":"2.4821708","pm25":""},{"location_name":"FR18035","location_id":"10471","lat":"49.868885","long":"2.2398055","pm25":""},{"location_name":"FR18039","location_id":"10472","lat":"50.129425","long":"1.610832","pm25":""},{"location_name":"FR18042","location_id":"10473","lat":"49.851337","long":"3.2839983","pm25":""},{"location_name":"FR18043","location_id":"10474","lat":"49.259567","long":"2.4744005","pm25":""},{"location_name":"FR18045","location_id":"10475","lat":"49.696674","long":"2.8011358","pm25":""},{"location_name":"FR18053","location_id":"10476","lat":"49.9025","long":"2.3046","pm25":""},{"location_name":"FR18079","location_id":"10478","lat":"49.87722","long":"2.2825","pm25":""},{"location_name":"FR18080","location_id":"10479","lat":"49.842823","long":"3.2814379","pm25":""},{"location_name":"FR18089","location_id":"10480","lat":"49.435955","long":"2.084289","pm25":""},{"location_name":"FR19002","location_id":"10481","lat":"48.108654","long":"-1.665764","pm25":""},{"location_name":"FR19007","location_id":"10482","lat":"48.107513","long":"-1.6791669","pm25":""},{"location_name":"FR19008","location_id":"10483","lat":"47.831932","long":"-1.8363271","pm25":""},{"location_name":"FR19010","location_id":"10484","lat":"48.110813","long":"-1.6828231","pm25":""},{"location_name":"FR19012","location_id":"10485","lat":"48.3864","long":"-4.4868155","pm25":""},{"location_name":"FR19014","location_id":"10486","lat":"48.39964","long":"-4.467232","pm25":""},{"location_name":"FR19015","location_id":"10487","lat":"48.40906","long":"-4.4751105","pm25":""},{"location_name":"FR19017","location_id":"10488","lat":"48.089695","long":"-1.6590266","pm25":""},{"location_name":"FR19021","location_id":"10489","lat":"47.75221","long":"-3.3756533","pm25":""},{"location_name":"FR19032","location_id":"10490","lat":"47.742485","long":"-3.3948054","pm25":""},{"location_name":"FR19033","location_id":"10491","lat":"47.648888","long":"-2.7638915","pm25":""},{"location_name":"FR19052","location_id":"10492","lat":"47.996124","long":"-4.0997224","pm25":""},{"location_name":"FR19061","location_id":"10493","lat":"48.51349","long":"-2.7495275","pm25":""},{"location_name":"FR20013","location_id":"10495","lat":"45.72005","long":"4.818159","pm25":""},{"location_name":"FR20017","location_id":"10496","lat":"45.735287","long":"4.829792","pm25":""},{"location_name":"FR20019","location_id":"10497","lat":"45.758358","long":"4.886215","pm25":""},{"location_name":"FR20029","location_id":"10498","lat":"45.66389","long":"4.845899","pm25":""},{"location_name":"FR20031","location_id":"10499","lat":"45.70782","long":"4.864404","pm25":""},{"location_name":"FR20037","location_id":"10501","lat":"45.60189","long":"4.802196","pm25":""},{"location_name":"FR20046","location_id":"10503","lat":"45.77891","long":"4.9246993","pm25":""},{"location_name":"FR20047","location_id":"10504","lat":"45.82325","long":"4.953957","pm25":""},{"location_name":"FR20048","location_id":"10505","lat":"45.75328","long":"5.0722027","pm25":""},{"location_name":"FR20049","location_id":"10506","lat":"45.961426","long":"4.465714","pm25":""},{"location_name":"FR20062","location_id":"10509","lat":"45.757732","long":"4.8542175","pm25":""},{"location_name":"FR20069","location_id":"10510","lat":"45.774837","long":"4.8985763","pm25":""},{"location_name":"FR21001","location_id":"10511","lat":"49.19222","long":"-0.39118308","pm25":""},{"location_name":"FR21016","location_id":"10512","lat":"49.175278","long":"-0.353611","pm25":""},{"location_name":"FR21019","location_id":"10513","lat":"49.151695","long":"-0.3527783","pm25":""},{"location_name":"FR21021","location_id":"10514","lat":"49.14723","long":"0.22722167","pm25":""},{"location_name":"FR21031","location_id":"10515","lat":"48.44554","long":"0.11083324","pm25":""},{"location_name":"FR21035","location_id":"10516","lat":"49.636383","long":"-1.6266693","pm25":""},{"location_name":"FR21040","location_id":"10517","lat":"49.11637","long":"-1.0847247","pm25":""},{"location_name":"FR21050","location_id":"10518","lat":"48.645008","long":"-0.45833305","pm25":""},{"location_name":"FR21060","location_id":"10519","lat":"49.11719","long":"-0.16966571","pm25":""},{"location_name":"FR22009","location_id":"10520","lat":"49.165733","long":"6.716883","pm25":""},{"location_name":"FR22011","location_id":"10521","lat":"49.15839","long":"6.7316604","pm25":""},{"location_name":"FR22014","location_id":"10522","lat":"49.19539","long":"6.9574428","pm25":""},{"location_name":"FR22019","location_id":"10523","lat":"49.22039","long":"6.9258313","pm25":""},{"location_name":"FR22022","location_id":"10524","lat":"49.11837","long":"7.0835395","pm25":""},{"location_name":"FR22054","location_id":"10525","lat":"49.187405","long":"6.9108653","pm25":""},{"location_name":"FR23001","location_id":"10526","lat":"47.32412","long":"-2.0815673","pm25":""},{"location_name":"FR23003","location_id":"10527","lat":"47.32284","long":"-2.0398495","pm25":""},{"location_name":"FR23004","location_id":"10528","lat":"47.3173","long":"-2.0733027","pm25":""},{"location_name":"FR23068","location_id":"10529","lat":"47.24746","long":"-1.936615","pm25":""},{"location_name":"FR23069","location_id":"10530","lat":"47.360764","long":"-1.954752","pm25":""},{"location_name":"FR23070","location_id":"10531","lat":"47.283184","long":"-1.7831649","pm25":""},{"location_name":"FR23075","location_id":"10532","lat":"47.315716","long":"-2.1907663","pm25":""},{"location_name":"FR23078","location_id":"10533","lat":"47.054443","long":"-0.886111","pm25":""},{"location_name":"FR23107","location_id":"10534","lat":"47.252766","long":"-1.5733364","pm25":""},{"location_name":"FR23110","location_id":"10535","lat":"47.264107","long":"-2.2498577","pm25":""},{"location_name":"FR23120","location_id":"10536","lat":"47.46854","long":"-0.5560527","pm25":""},{"location_name":"FR23123","location_id":"10537","lat":"48.06941","long":"-0.76769215","pm25":""},{"location_name":"FR23124","location_id":"10538","lat":"46.656715","long":"-0.7436811","pm25":""},{"location_name":"FR23140","location_id":"10539","lat":"47.20439","long":"-1.5528278","pm25":""},{"location_name":"FR23149","location_id":"10540","lat":"47.28611","long":"-2.0322857","pm25":""},{"location_name":"FR23150","location_id":"10541","lat":"47.447403","long":"-0.5500672","pm25":""},{"location_name":"FR23152","location_id":"10542","lat":"46.66072","long":"-1.4368284","pm25":""},{"location_name":"FR23153","location_id":"10543","lat":"47.331547","long":"-2.1516268","pm25":""},{"location_name":"FR23157","location_id":"10544","lat":"47.146076","long":"-1.6902701","pm25":""},{"location_name":"FR23163","location_id":"10545","lat":"47.92189","long":"0.15182516","pm25":""},{"location_name":"FR23174","location_id":"10546","lat":"47.98891","long":"0.19598275","pm25":""},{"location_name":"FR23175","location_id":"10547","lat":"47.43015","long":"-0.61006385","pm25":""},{"location_name":"FR23177","location_id":"10548","lat":"47.787712","long":"-0.44404444","pm25":""},{"location_name":"FR23178","location_id":"10549","lat":"47.319187","long":"-2.0669515","pm25":""},{"location_name":"FR23181","location_id":"10550","lat":"47.273067","long":"-2.2230518","pm25":""},{"location_name":"FR23182","location_id":"10551","lat":"47.97105","long":"0.22142214","pm25":""},{"location_name":"FR23188","location_id":"10552","lat":"47.222515","long":"-1.5375025","pm25":""},{"location_name":"FR23230","location_id":"10553","lat":"47.25307","long":"-2.3320713","pm25":""},{"location_name":"FR24007","location_id":"10554","lat":"43.59975","long":"7.094723","pm25":""},{"location_name":"FR24009","location_id":"10555","lat":"43.562527","long":"7.0072184","pm25":""},{"location_name":"FR24011","location_id":"10556","lat":"43.686077","long":"7.2119446","pm25":""},{"location_name":"FR24015","location_id":"10558","lat":"43.657814","long":"6.9209533","pm25":""},{"location_name":"FR24018","location_id":"10559","lat":"43.8353","long":"5.7858334","pm25":""},{"location_name":"FR24021","location_id":"10560","lat":"43.786617","long":"7.373282","pm25":""},{"location_name":"FR24023","location_id":"10561","lat":"43.79336","long":"7.3313937","pm25":""},{"location_name":"FR24033","location_id":"10562","lat":"44.55522","long":"6.0730605","pm25":""},{"location_name":"FR24035","location_id":"10563","lat":"43.689262","long":"7.242083","pm25":""},{"location_name":"FR24036","location_id":"10564","lat":"43.702057","long":"7.286262","pm25":""},{"location_name":"FR24038","location_id":"10565","lat":"44.54863","long":"6.067302","pm25":""},{"location_name":"FR24039","location_id":"10566","lat":"43.93352","long":"5.7117043","pm25":""},{"location_name":"FR24040","location_id":"10567","lat":"43.791935","long":"7.0483346","pm25":""},{"location_name":"FR25011","location_id":"10568","lat":"49.383118","long":"1.0257592","pm25":""},{"location_name":"FR25035","location_id":"10569","lat":"49.358196","long":"1.0078559","pm25":""},{"location_name":"FR25036","location_id":"10570","lat":"49.442436","long":"1.0936899","pm25":""},{"location_name":"FR25039","location_id":"10571","lat":"49.02132","long":"1.1483164","pm25":""},{"location_name":"FR25040","location_id":"10572","lat":"49.40621","long":"1.1551526","pm25":""},{"location_name":"FR25043","location_id":"10573","lat":"49.40054","long":"1.0988282","pm25":""},{"location_name":"FR25045","location_id":"10574","lat":"49.91634","long":"0.9571819","pm25":""},{"location_name":"FR25048","location_id":"10575","lat":"49.428066","long":"1.0577753","pm25":""},{"location_name":"FR25049","location_id":"10576","lat":"49.304867","long":"1.2143695","pm25":""},{"location_name":"FR25050","location_id":"10577","lat":"49.781204","long":"1.3450834","pm25":""},{"location_name":"FR25051","location_id":"10578","lat":"49.91802","long":"1.0739719","pm25":""},{"location_name":"FR26005","location_id":"10580","lat":"47.30804","long":"5.066112","pm25":""},{"location_name":"FR26010","location_id":"10581","lat":"47.34555","long":"5.002224","pm25":""},{"location_name":"FR26012","location_id":"10582","lat":"47.275017","long":"4.09833","pm25":""},{"location_name":"FR26014","location_id":"10583","lat":"47.340252","long":"5.0583324","pm25":""},{"location_name":"FR26016","location_id":"10584","lat":"48.200584","long":"3.2772248","pm25":""},{"location_name":"FR26017","location_id":"10585","lat":"46.996666","long":"3.1708374","pm25":""},{"location_name":"FR26019","location_id":"10586","lat":"47.800568","long":"3.5763907","pm25":""},{"location_name":"FR26035","location_id":"10587","lat":"47.137215","long":"4.9505796","pm25":""},{"location_name":"FR26043","location_id":"10588","lat":"47.31547","long":"5.037429","pm25":""},{"location_name":"FR27002","location_id":"10589","lat":"45.367794","long":"4.8051515","pm25":""},{"location_name":"FR27003","location_id":"10590","lat":"45.454506","long":"4.766524","pm25":""},{"location_name":"FR27005","location_id":"10591","lat":"45.31962","long":"4.772866","pm25":""},{"location_name":"FR27007","location_id":"10592","lat":"45.60824","long":"5.270874","pm25":""},{"location_name":"FR27008","location_id":"10593","lat":"45.35321","long":"4.804819","pm25":""},{"location_name":"FR27010","location_id":"10594","lat":"45.46087","long":"5.1810784","pm25":""},{"location_name":"FR28010","location_id":"10595","lat":"50.449165","long":"2.9000044","pm25":""},{"location_name":"FR28022","location_id":"10596","lat":"50.308872","long":"2.80737","pm25":""},{"location_name":"FR28028","location_id":"10597","lat":"50.535404","long":"2.635693","pm25":""},{"location_name":"FR28033","location_id":"10598","lat":"50.489704","long":"2.6664243","pm25":""},{"location_name":"FR29423","location_id":"10599","lat":"46.04111","long":"4.0746593","pm25":""},{"location_name":"FR29424","location_id":"10600","lat":"45.42009","long":"4.3954206","pm25":""},{"location_name":"FR29426","location_id":"10601","lat":"45.475296","long":"4.5150046","pm25":""},{"location_name":"FR29429","location_id":"10603","lat":"45.533405","long":"4.6239433","pm25":""},{"location_name":"FR29439","location_id":"10604","lat":"45.481785","long":"4.4296646","pm25":""},{"location_name":"FR30016","location_id":"10605","lat":"48.685825","long":"6.175109","pm25":""},{"location_name":"FR30018","location_id":"10606","lat":"48.02461","long":"6.585837","pm25":""},{"location_name":"FR30019","location_id":"10607","lat":"48.172794","long":"6.452814","pm25":""},{"location_name":"FR30020","location_id":"10608","lat":"48.775833","long":"5.1627884","pm25":""},{"location_name":"FR30021","location_id":"10609","lat":"48.6215","long":"6.194926","pm25":""},{"location_name":"FR30023","location_id":"10610","lat":"48.633316","long":"6.304826","pm25":""},{"location_name":"FR30026","location_id":"10611","lat":"48.584846","long":"6.483896","pm25":""},{"location_name":"FR30027","location_id":"10612","lat":"48.56547","long":"6.1295824","pm25":""},{"location_name":"FR30028","location_id":"10613","lat":"48.051098","long":"7.0111175","pm25":""},{"location_name":"FR30029","location_id":"10614","lat":"48.193638","long":"5.9372263","pm25":""},{"location_name":"FR30030","location_id":"10615","lat":"48.614906","long":"6.1076727","pm25":""},{"location_name":"FR30032","location_id":"10616","lat":"48.69472","long":"6.9652762","pm25":""},{"location_name":"FR30033","location_id":"10617","lat":"49.065838","long":"5.785555","pm25":""},{"location_name":"FR30034","location_id":"10618","lat":"48.688198","long":"6.1904345","pm25":""},{"location_name":"FR30036","location_id":"10619","lat":"48.696323","long":"6.1461205","pm25":""},{"location_name":"FR30037","location_id":"10620","lat":"48.656937","long":"6.1360235","pm25":""},{"location_name":"FR31001","location_id":"10622","lat":"44.861412","long":"-0.5794439","pm25":""},{"location_name":"FR31002","location_id":"10623","lat":"44.80057","long":"-0.588056","pm25":""},{"location_name":"FR31003","location_id":"10624","lat":"44.849693","long":"-0.54388857","pm25":""},{"location_name":"FR31006","location_id":"10626","lat":"44.84139","long":"-0.65","pm25":""},{"location_name":"FR31007","location_id":"10627","lat":"44.900303","long":"-0.5147221","pm25":""},{"location_name":"FR31008","location_id":"10628","lat":"44.86555","long":"-0.93944013","pm25":""},{"location_name":"FR31010","location_id":"10629","lat":"45.01225","long":"-0.52833337","pm25":""},{"location_name":"FR31013","location_id":"10630","lat":"43.310806","long":"-0.3911112","pm25":""},{"location_name":"FR31016","location_id":"10632","lat":"43.479736","long":"-1.4880593","pm25":""},{"location_name":"FR31017","location_id":"10633","lat":"43.49414","long":"-1.5277737","pm25":""},{"location_name":"FR31020","location_id":"10634","lat":"43.410538","long":"-0.6169441","pm25":""},{"location_name":"FR31021","location_id":"10635","lat":"43.37611","long":"-0.536944","pm25":""},{"location_name":"FR31022","location_id":"10636","lat":"43.409687","long":"-0.67166674","pm25":""},{"location_name":"FR31023","location_id":"10637","lat":"43.434155","long":"-0.6919444","pm25":""},{"location_name":"FR31024","location_id":"10638","lat":"43.37692","long":"-0.609444","pm25":""},{"location_name":"FR31026","location_id":"10639","lat":"43.83835","long":"-0.81083286","pm25":""},{"location_name":"FR31033","location_id":"10643","lat":"45.189728","long":"0.72722214","pm25":""},{"location_name":"FR31034","location_id":"10644","lat":"45.012222","long":"-0.529722","pm25":""},{"location_name":"FR31036","location_id":"10645","lat":"43.70472","long":"-1.0386142","pm25":""},{"location_name":"FR31039","location_id":"10646","lat":"43.31107","long":"-0.35211894","pm25":""},{"location_name":"FR31040","location_id":"10647","lat":"44.508667","long":"0.14250335","pm25":""},{"location_name":"FR31041","location_id":"10648","lat":"43.896053","long":"-0.49061668","pm25":""},{"location_name":"FR31043","location_id":"10649","lat":"43.47022","long":"-1.5538429","pm25":""},{"location_name":"FR32001","location_id":"10650","lat":"46.78247","long":"4.8472643","pm25":""},{"location_name":"FR32002","location_id":"10651","lat":"46.82109","long":"4.8350024","pm25":""},{"location_name":"FR32005","location_id":"10652","lat":"46.66664","long":"4.366666","pm25":""},{"location_name":"FR32006","location_id":"10653","lat":"46.3161","long":"4.839997","pm25":""},{"location_name":"FR32007","location_id":"10654","lat":"46.802216","long":"4.4175014","pm25":""},{"location_name":"FR33101","location_id":"10656","lat":"45.564735","long":"5.928333","pm25":""},{"location_name":"FR33102","location_id":"10657","lat":"45.596676","long":"5.918613","pm25":""},{"location_name":"FR33105","location_id":"10658","lat":"45.56945","long":"5.9329863","pm25":""},{"location_name":"FR33111","location_id":"10659","lat":"45.274723","long":"6.349722","pm25":""},{"location_name":"FR33120","location_id":"10661","lat":"45.92251","long":"6.870001","pm25":""},{"location_name":"FR33121","location_id":"10662","lat":"45.675","long":"6.3897257","pm25":""},{"location_name":"FR33122","location_id":"10663","lat":"45.535862","long":"6.4711127","pm25":""},{"location_name":"FR33201","location_id":"10664","lat":"45.895256","long":"6.1183357","pm25":""},{"location_name":"FR33202","location_id":"10665","lat":"45.916946","long":"6.135556","pm25":""},{"location_name":"FR33203","location_id":"10666","lat":"45.9097","long":"6.1182456","pm25":""},{"location_name":"FR33211","location_id":"10667","lat":"46.19583","long":"6.240556","pm25":""},{"location_name":"FR33212","location_id":"10668","lat":"46.193672","long":"6.2148595","pm25":""},{"location_name":"FR33220","location_id":"10669","lat":"45.923634","long":"6.713613","pm25":""},{"location_name":"FR33232","location_id":"10670","lat":"45.907196","long":"6.845836","pm25":""},{"location_name":"FR33302","location_id":"10671","lat":"46.07222","long":"5.8208313","pm25":""},{"location_name":"FR33305","location_id":"10672","lat":"46.211643","long":"5.2263894","pm25":""},{"location_name":"FR34013","location_id":"10673","lat":"47.907078","long":"1.9011406","pm25":""},{"location_name":"FR34014","location_id":"10674","lat":"47.917374","long":"1.9662595","pm25":""},{"location_name":"FR34017","location_id":"10675","lat":"47.95896","long":"2.0092888","pm25":""},{"location_name":"FR34018","location_id":"10676","lat":"47.99793","long":"2.7195148","pm25":""},{"location_name":"FR34024","location_id":"10677","lat":"47.34415","long":"0.6537759","pm25":""},{"location_name":"FR34025","location_id":"10678","lat":"47.419086","long":"0.6829406","pm25":""},{"location_name":"FR34026","location_id":"10679","lat":"47.46945","long":"0.7169436","pm25":""},{"location_name":"FR34028","location_id":"10680","lat":"47.394646","long":"0.70487297","pm25":""},{"location_name":"FR34029","location_id":"10681","lat":"47.837784","long":"1.944655","pm25":""},{"location_name":"FR34030","location_id":"10682","lat":"47.07503","long":"2.4071796","pm25":""},{"location_name":"FR34032","location_id":"10683","lat":"47.0828","long":"2.405329","pm25":""},{"location_name":"FR34038","location_id":"10684","lat":"46.81482","long":"2.610082","pm25":""},{"location_name":"FR34041","location_id":"10685","lat":"48.444412","long":"1.5101489","pm25":""},{"location_name":"FR34043","location_id":"10687","lat":"48.39117","long":"1.9556234","pm25":""},{"location_name":"FR34046","location_id":"10688","lat":"48.73141","long":"1.3638852","pm25":""},{"location_name":"FR34047","location_id":"10689","lat":"48.76091","long":"1.2336473","pm25":""},{"location_name":"FR34051","location_id":"10690","lat":"46.79828","long":"1.6931267","pm25":""},{"location_name":"FR34054","location_id":"10691","lat":"47.170143","long":"1.4096812","pm25":""},{"location_name":"FR34056","location_id":"10692","lat":"46.864532","long":"1.7719538","pm25":""},{"location_name":"FR34057","location_id":"10693","lat":"46.942966","long":"2.003261","pm25":""},{"location_name":"FR34061","location_id":"10694","lat":"47.594517","long":"1.3017397","pm25":""},{"location_name":"FR35002","location_id":"10695","lat":"45.890007","long":"0.9000041","pm25":""},{"location_name":"FR35004","location_id":"10697","lat":"45.15876","long":"1.537224","pm25":""},{"location_name":"FR35005","location_id":"10698","lat":"46.169975","long":"1.869996","pm25":""},{"location_name":"FR35006","location_id":"10699","lat":"45.26002","long":"1.7599972","pm25":""},{"location_name":"FR35007","location_id":"10700","lat":"45.869995","long":"1.3100042","pm25":""},{"location_name":"FR35010","location_id":"10701","lat":"45.83333","long":"1.216804","pm25":""},{"location_name":"FR35012","location_id":"10702","lat":"45.80998","long":"2.0599988","pm25":""},{"location_name":"FR35019","location_id":"10703","lat":"45.87581","long":"0.82388896","pm25":""},{"location_name":"FR36001","location_id":"10705","lat":"44.870262","long":"4.876289","pm25":""},{"location_name":"FR36002","location_id":"10706","lat":"44.93351","long":"4.8934827","pm25":""},{"location_name":"FR36007","location_id":"10708","lat":"44.67595","long":"4.673584","pm25":""},{"location_name":"FR36019","location_id":"10709","lat":"45.04247","long":"5.044301","pm25":""},{"location_name":"FR36021","location_id":"10710","lat":"44.56943","long":"5.278968","pm25":""},{"location_name":"FR37001","location_id":"10711","lat":"16.256104","long":"-61.590294","pm25":""},{"location_name":"FR37007","location_id":"10713","lat":"16.25067","long":"-61.52795","pm25":""},{"location_name":"FR38002","location_id":"10715","lat":"-20.903284","long":"55.468365","pm25":""},{"location_name":"FR38008","location_id":"10716","lat":"-20.884737","long":"55.45381","pm25":""},{"location_name":"FR38009","location_id":"10717","lat":"-20.910585","long":"55.61901","pm25":""},{"location_name":"FR38011","location_id":"10718","lat":"-21.334423","long":"55.459023","pm25":""},{"location_name":"FR38014","location_id":"10719","lat":"-21.312918","long":"55.4742","pm25":""},{"location_name":"FR38016","location_id":"10720","lat":"-21.204836","long":"55.58263","pm25":""},{"location_name":"FR38017","location_id":"10721","lat":"-21.294338","long":"55.627903","pm25":""},{"location_name":"FR38018","location_id":"10722","lat":"-20.949768","long":"55.313854","pm25":""},{"location_name":"FR38020","location_id":"10723","lat":"-21.009739","long":"55.27271","pm25":""},{"location_name":"FR38021","location_id":"10724","lat":"-21.03213","long":"55.232555","pm25":""},{"location_name":"FR38023","location_id":"10725","lat":"-21.331663","long":"55.478962","pm25":""},{"location_name":"FR38098","location_id":"10727","lat":"-21.277094","long":"55.403057","pm25":""},{"location_name":"FR39003","location_id":"10728","lat":"14.603527","long":"-61.04124","pm25":""},{"location_name":"FR39009","location_id":"10730","lat":"14.610743","long":"-61.002613","pm25":""},{"location_name":"FR39014","location_id":"10733","lat":"14.468832","long":"-60.927425","pm25":""},{"location_name":"FR39015","location_id":"10734","lat":"14.6661","long":"-61.1518","pm25":""},{"location_name":"FR39016","location_id":"10735","lat":"14.6781","long":"-60.939102","pm25":""},{"location_name":"FR39017","location_id":"10736","lat":"14.600572","long":"-61.08571","pm25":""},{"location_name":"FR40007","location_id":"10738","lat":"4.848161","long":"-52.32381","pm25":""},{"location_name":"FR40008","location_id":"10739","lat":"4.9378443","long":"-52.32094","pm25":""},{"location_name":"FR41001","location_id":"10740","lat":"41.924656","long":"8.735694","pm25":""},{"location_name":"FR41002","location_id":"10741","lat":"42.69789","long":"9.446414","pm25":""},{"location_name":"FR41003","location_id":"10742","lat":"41.964413","long":"8.820279","pm25":""},{"location_name":"FR41004","location_id":"10743","lat":"42.535797","long":"9.475968","pm25":""},{"location_name":"FR41007","location_id":"10744","lat":"41.94925","long":"8.757586","pm25":""},{"location_name":"FR41017","location_id":"10745","lat":"42.671345","long":"9.434646","pm25":""},{"location_name":"FR41024","location_id":"10748","lat":"42.236088","long":"9.190035","pm25":""},{"location_name":"FR82001","location_id":"10749","lat":"47.235996","long":"6.023608","pm25":""},{"location_name":"FR82005","location_id":"10751","lat":"47.234592","long":"6.076474","pm25":""},{"location_name":"FR82006","location_id":"10752","lat":"47.2474","long":"6.0154157","pm25":""},{"location_name":"FR82010","location_id":"10753","lat":"47.510303","long":"6.7940035","pm25":""},{"location_name":"FR82012","location_id":"10754","lat":"47.538208","long":"6.868357","pm25":""},{"location_name":"FR82020","location_id":"10755","lat":"47.64066","long":"6.859275","pm25":""},{"location_name":"FR82030","location_id":"10757","lat":"47.29464","long":"6.8258576","pm25":""},{"location_name":"FR82040","location_id":"10758","lat":"47.09675","long":"5.496387","pm25":""},{"location_name":"FR82041","location_id":"10759","lat":"47.0426","long":"5.400896","pm25":""},{"location_name":"FR82042","location_id":"10760","lat":"47.06561","long":"5.4150267","pm25":""},{"location_name":"FR82043","location_id":"10761","lat":"47.147236","long":"5.556116","pm25":""},{"location_name":"FR82050","location_id":"10762","lat":"46.671326","long":"5.5568075","pm25":""},{"location_name":"FR82060","location_id":"10763","lat":"47.620014","long":"6.15761","pm25":""},{"location_name":"FR82070","location_id":"10764","lat":"47.35127","long":"6.3597217","pm25":""},{"location_name":"FRANCHINI-ANGELONI","location_id":"10765","lat":"44.1414","long":"12.2447","pm25":""},{"location_name":"FRANCONIA","location_id":"10766","lat":"38.7717","long":"-77.1089","pm25":""},{"location_name":"FRAYSER","location_id":"10769","lat":"35.2175","long":"-90.0194","pm25":""},{"location_name":"Fair Hill","location_id":"10772","lat":"39.7011","long":"-75.86","pm25":""},{"location_name":"Fairfield","location_id":"10773","lat":"38.227066","long":"-122.07562","pm25":""},{"location_name":"Fairgrounds","location_id":"10774","lat":"32.0475","long":"-110.7739","pm25":""},{"location_name":"Fairhaven2","location_id":"10775","lat":"41.6454","long":"-70.898","pm25":""},{"location_name":"Fairland","location_id":"10776","lat":"39.613365","long":"-85.87067","pm25":""},{"location_name":"Falcon Field Police","location_id":"10778","lat":"33.4522","long":"-111.7331","pm25":""},{"location_name":"Fall River","location_id":"10779","lat":"41.6833","long":"-71.1697","pm25":""},{"location_name":"Fallon","location_id":"10780","lat":"39.47247","long":"-118.78362","pm25":""},{"location_name":"Faro","location_id":"10781","lat":"42.098904","long":"11.817692","pm25":""},{"location_name":"Farrell","location_id":"10783","lat":"41.215","long":"-80.485","pm25":""},{"location_name":"Fayetteville","location_id":"10787","lat":"36.011703","long":"-94.167435","pm25":""},{"location_name":"Felton Cal-Fire","location_id":"10789","lat":"37.0481","long":"-122.0746","pm25":""},{"location_name":"Ferentino","location_id":"10790","lat":"41.69","long":"13.250411","pm25":""},{"location_name":"Fermi","location_id":"10791","lat":"41.864193","long":"12.469531","pm25":""},{"location_name":"Fernley","location_id":"10793","lat":"39.602737","long":"-119.247856","pm25":""},{"location_name":"Fijnaart-Zwingelspaansedijk","location_id":"10794","lat":"51.6537","long":"4.51527","pm25":""},{"location_name":"Fire Station 13","location_id":"10795","lat":"41.471783","long":"-81.65679","pm25":""},{"location_name":"Firearms Training","location_id":"10796","lat":"38.23158","long":"-85.82675","pm25":""},{"location_name":"Fiumaretta","location_id":"10798","lat":"42.102158","long":"11.784358","pm25":""},{"location_name":"Fiumicino Porto","location_id":"10799","lat":"41.77485","long":"12.223413","pm25":""},{"location_name":"Fiumicino Villa Guglielmi","location_id":"10800","lat":"41.76819","long":"12.237048","pm25":""},{"location_name":"Fl. Baptist Children","location_id":"10801","lat":"28.0294","long":"-81.9719","pm25":""},{"location_name":"Flagler County","location_id":"10802","lat":"29.489082","long":"-81.27683","pm25":""},{"location_name":"Flagstaff Middle Sch","location_id":"10803","lat":"35.206112","long":"-111.65278","pm25":""},{"location_name":"Flemington","location_id":"10805","lat":"40.51525","long":"-74.806755","pm25":""},{"location_name":"Flora","location_id":"10806","lat":"40.540558","long":"-86.553055","pm25":""},{"location_name":"Florence","location_id":"10807","lat":"40.4447","long":"-80.42","pm25":""},{"location_name":"Florianka RPN","location_id":"10808","lat":"50.551895","long":"22.98286","pm25":""},{"location_name":"Floyd Dryden","location_id":"10809","lat":"58.38889","long":"-134.56555","pm25":""},{"location_name":"Fond du Lac","location_id":"10814","lat":"46.713696","long":"-92.51172","pm25":""},{"location_name":"Fontana - Arrow High","location_id":"10815","lat":"34.100132","long":"-117.49198","pm25":""},{"location_name":"Fontechiari","location_id":"10816","lat":"41.67","long":"13.674472","pm25":""},{"location_name":"Forest Park","location_id":"10817","lat":"38.631058","long":"-90.28114","pm25":""},{"location_name":"Fort Bragg High Scho","location_id":"10818","lat":"39.43734","long":"-123.78766","pm25":""},{"location_name":"Fort Collins - CSU -","location_id":"10819","lat":"40.5764","long":"-105.0794","pm25":""},{"location_name":"Fort Collins - West","location_id":"10820","lat":"40.59254","long":"-105.1411","pm25":""},{"location_name":"Fort Independence Me","location_id":"10821","lat":"36.8028","long":"-118.1167","pm25":""},{"location_name":"Fort Lee Near Road","location_id":"10823","lat":"40.85355","long":"-73.9661","pm25":""},{"location_name":"Fort Wayne-Beacon St","location_id":"10825","lat":"41.094967","long":"-85.101814","pm25":""},{"location_name":"Fort William","location_id":"10826","lat":"56.82266","long":"-5.101102","pm25":""},{"location_name":"Fountain Hills","location_id":"10828","lat":"33.611","long":"-111.7253","pm25":""},{"location_name":"Francia","location_id":"10829","lat":"41.94745","long":"12.469588","pm25":""},{"location_name":"Freedom 7 Elementary","location_id":"10833","lat":"28.3108","long":"-80.6156","pm25":""},{"location_name":"Freemansburg","location_id":"10835","lat":"40.6281","long":"-75.3411","pm25":""},{"location_name":"French Settlement","location_id":"10837","lat":"30.315","long":"-90.8114","pm25":""},{"location_name":"French Town - Beckwi","location_id":"10838","lat":"47.012905","long":"-114.22427","pm25":""},{"location_name":"Fresh Kills","location_id":"10839","lat":"40.5802","long":"-74.1994","pm25":""},{"location_name":"Fresno - Drummond St","location_id":"10840","lat":"36.7056","long":"-119.7414","pm25":""},{"location_name":"Fresno - Garland","location_id":"10841","lat":"36.78538","long":"-119.77321","pm25":""},{"location_name":"Frisco C31","location_id":"10843","lat":"33.1325","long":"-96.7861","pm25":""},{"location_name":"Front Street","location_id":"10844","lat":"39.13198","long":"-94.53128","pm25":""},{"location_name":"Frosinone Mazzini","location_id":"10845","lat":"41.639668","long":"13.348913","pm25":""},{"location_name":"Frosinone Scalo","location_id":"10846","lat":"41.62","long":"13.33081","pm25":""},{"location_name":"Ft McD Yuma Frank-AZ","location_id":"10848","lat":"33.6292","long":"-111.6769","pm25":""},{"location_name":"Ft. Collins - CSU Fa","location_id":"10849","lat":"40.57126","long":"-105.079765","pm25":""},{"location_name":"Ft. Gibson","location_id":"10850","lat":"35.775803","long":"-95.28716","pm25":""},{"location_name":"Ft. Worth Northwest","location_id":"10851","lat":"32.805817","long":"-97.35657","pm25":""},{"location_name":"Fulton","location_id":"10853","lat":"43.28428","long":"-76.46318","pm25":""},{"location_name":"Furulund","location_id":"10855","lat":"59.057304","long":"9.695568","pm25":""},{"location_name":"G.T.Craig","location_id":"10857","lat":"41.49219","long":"-81.67855","pm25":""},{"location_name":"GANDY","location_id":"10859","lat":"27.8928","long":"-82.5383","pm25":""},{"location_name":"GARDINIER","location_id":"10861","lat":"27.864273","long":"-82.38336","pm25":""},{"location_name":"GARINGER","location_id":"10862","lat":"35.2411","long":"-80.7831","pm25":""},{"location_name":"GAVELLO","location_id":"10863","lat":"44.9288","long":"11.1789","pm25":""},{"location_name":"GC_MAD","location_id":"10876","lat":"38.7045","long":"-90.1397","pm25":""},{"location_name":"GERBIDO","location_id":"10877","lat":"45.0559","long":"9.7479","pm25":""},{"location_name":"GHERARDI","location_id":"10878","lat":"44.8397","long":"11.9613","pm25":""},{"location_name":"GIARDINI","location_id":"10879","lat":"44.637","long":"10.9057","pm25":""},{"location_name":"GIARDINI MARGHERITA","location_id":"10880","lat":"44.4836","long":"11.355","pm25":""},{"location_name":"GIORDANI-FARNESE","location_id":"10881","lat":"45.0488","long":"9.6933","pm25":""},{"location_name":"GPORT YC","location_id":"10882","lat":"30.39","long":"-89.0497","pm25":""},{"location_name":"GRAND RAPIDS","location_id":"10884","lat":"42.9847","long":"-85.6711","pm25":""},{"location_name":"GREEN BAY E HIGH","location_id":"10886","lat":"44.5167","long":"-87.9939","pm25":""},{"location_name":"Gaeta","location_id":"10889","lat":"41.223076","long":"13.570481","pm25":""},{"location_name":"Gainesville","location_id":"10890","lat":"34.3003","long":"-83.8139","pm25":""},{"location_name":"Gajew","location_id":"10891","lat":"52.14325","long":"19.233225","pm25":""},{"location_name":"Galleria","location_id":"10892","lat":"41.50466","long":"-81.690186","pm25":""},{"location_name":"Galveston Airport C1","location_id":"10894","lat":"29.2631","long":"-94.8564","pm25":""},{"location_name":"Garden","location_id":"10897","lat":"61.20586","long":"-149.8246","pm25":""},{"location_name":"Garden City","location_id":"10898","lat":"43.64789","long":"-116.26941","pm25":""},{"location_name":"Garden Valley","location_id":"10899","lat":"44.1045","long":"-115.97239","pm25":""},{"location_name":"Gardiner","location_id":"10900","lat":"44.23062","long":"-69.785","pm25":""},{"location_name":"Gartnerl\u00f8kka","location_id":"10901","lat":"58.14703","long":"7.98662","pm25":""},{"location_name":"Gary-IITRI","location_id":"10902","lat":"41.6067","long":"-87.3047","pm25":""},{"location_name":"Garyville","location_id":"10903","lat":"30.0494","long":"-90.6367","pm25":""},{"location_name":"Geleen-Asterstraat","location_id":"10906","lat":"50.9844","long":"5.82223","pm25":""},{"location_name":"Geleen-Vouershof","location_id":"10907","lat":"50.9631","long":"5.8107","pm25":""},{"location_name":"Georgia Station","location_id":"10909","lat":"33.1787","long":"-84.4052","pm25":""},{"location_name":"Geronimo","location_id":"10910","lat":"32.25","long":"-110.9667","pm25":""},{"location_name":"Gilory - 9th Street","location_id":"10911","lat":"36.999573","long":"-121.574684","pm25":""},{"location_name":"Gjilan","location_id":"10913","lat":"42.461143","long":"21.467201","pm25":""},{"location_name":"Glacier NP","location_id":"10914","lat":"48.5103","long":"-113.9956","pm25":""},{"location_name":"Glasgow Great Western Road","location_id":"10915","lat":"55.87204","long":"-4.270936","pm25":""},{"location_name":"Glasgow High Street","location_id":"10916","lat":"55.860935","long":"-4.238214","pm25":""},{"location_name":"Glasgow Kerbside","location_id":"10917","lat":"55.85917","long":"-4.258889","pm25":""},{"location_name":"Glasgow Townhead","location_id":"10918","lat":"55.865784","long":"-4.243631","pm25":""},{"location_name":"Glazebury","location_id":"10919","lat":"53.46008","long":"-2.472056","pm25":""},{"location_name":"Glen Oaks","location_id":"10921","lat":"36.19347","long":"-116.00758","pm25":""},{"location_name":"Glendale Community C","location_id":"10922","lat":"33.5694","long":"-112.1915","pm25":""},{"location_name":"Glendora - Laurel","location_id":"10923","lat":"34.1439","long":"-117.8508","pm25":""},{"location_name":"Glenpool","location_id":"10924","lat":"35.9525","long":"-96.0033","pm25":""},{"location_name":"Gliwice, ul. Mewy 34","location_id":"10926","lat":"50.27933","long":"18.655764","pm25":""},{"location_name":"Globeville","location_id":"10927","lat":"39.78562","long":"-104.98847","pm25":""},{"location_name":"Gocza\u0142kowice Zdr\u00f3j, ul. Parkowa","location_id":"10928","lat":"49.93785","long":"18.975594","pm25":""},{"location_name":"Golden - NREL - 2054","location_id":"10929","lat":"39.7419","long":"-105.1786","pm25":""},{"location_name":"Goleta","location_id":"10931","lat":"34.4453","long":"-119.8278","pm25":""},{"location_name":"Goodland","location_id":"10933","lat":"39.3428","long":"-101.702995","pm25":""},{"location_name":"Gorz\u00f3w Wlkp. ul. Kosynier\u00f3w Gdy\u0144skich","location_id":"10934","lat":"52.738213","long":"15.228667","pm25":""},{"location_name":"Gothic","location_id":"10935","lat":"38.9564","long":"-106.9858","pm25":""},{"location_name":"Granbury C73","location_id":"10937","lat":"32.4419","long":"-97.8033","pm25":""},{"location_name":"Grand Canyon NP","location_id":"10938","lat":"36.055","long":"-112.1531","pm25":""},{"location_name":"Grand Portage","location_id":"10940","lat":"47.9721","long":"-89.6908","pm25":""},{"location_name":"Grand Teton NP - Sci","location_id":"10941","lat":"43.67083","long":"-110.5994","pm25":""},{"location_name":"Grangemouth","location_id":"10942","lat":"56.01032","long":"-3.704399","pm25":""},{"location_name":"Grangemouth Moray","location_id":"10943","lat":"56.01314","long":"-3.710833","pm25":""},{"location_name":"Granger-Beckley St.","location_id":"10944","lat":"41.75487","long":"-86.11009","pm25":""},{"location_name":"Grangeville","location_id":"10945","lat":"45.9313","long":"-116.1152","pm25":""},{"location_name":"Granica-KPN","location_id":"10946","lat":"52.28586","long":"20.454653","pm25":""},{"location_name":"Grants Pass - Parksi","location_id":"10947","lat":"42.43415","long":"-123.348465","pm25":""},{"location_name":"Grapevine Fairway C7","location_id":"10948","lat":"32.98426","long":"-97.063705","pm25":""},{"location_name":"Grass Valley","location_id":"10949","lat":"39.2344","long":"-121.0556","pm25":""},{"location_name":"Great Basin NP","location_id":"10950","lat":"39.0053","long":"-114.2158","pm25":""},{"location_name":"Great Falls Overlook","location_id":"10952","lat":"47.494316","long":"-111.303314","pm25":""},{"location_name":"Greeley - Weld Co. T","location_id":"10953","lat":"40.3861","long":"-104.7367","pm25":""},{"location_name":"Greeley Hospital","location_id":"10954","lat":"40.4147","long":"-104.7061","pm25":""},{"location_name":"Green Valley","location_id":"10955","lat":"31.8794","long":"-110.9964","pm25":""},{"location_name":"GreenValley","location_id":"10956","lat":"36.048706","long":"-115.05294","pm25":""},{"location_name":"Greenfield","location_id":"10957","lat":"42.605816","long":"-72.59669","pm25":""},{"location_name":"Greenock A8 Roadside","location_id":"10958","lat":"55.94408","long":"-4.734421","pm25":""},{"location_name":"Greensburg","location_id":"10959","lat":"40.3053","long":"-79.5061","pm25":""},{"location_name":"Greenville C1006\/198","location_id":"10960","lat":"33.153076","long":"-96.11556","pm25":""},{"location_name":"Greenville-ESC","location_id":"10961","lat":"34.8439","long":"-82.4146","pm25":""},{"location_name":"Gridley","location_id":"10965","lat":"39.32756","long":"-121.66881","pm25":""},{"location_name":"Grimmerhaugen","location_id":"10966","lat":"62.47217","long":"6.15682","pm25":""},{"location_name":"Groningen-Europaweg","location_id":"10967","lat":"53.2178","long":"6.5789","pm25":""},{"location_name":"Groningen-Nijensteinheerd","location_id":"10968","lat":"53.2465","long":"6.60894","pm25":""},{"location_name":"Groton Fort Griswold","location_id":"10969","lat":"41.3536","long":"-72.0789","pm25":""},{"location_name":"Grudzi\u0105dz Airpointer","location_id":"10970","lat":"53.49355","long":"18.762138","pm25":""},{"location_name":"Guatemala City","location_id":"10973","lat":"14.989397","long":"-90.52241","pm25":""},{"location_name":"Guidonia","location_id":"10974","lat":"41.995678","long":"12.726371","pm25":""},{"location_name":"Guty Du\u017ce","location_id":"10975","lat":"52.943172","long":"21.288168","pm25":""},{"location_name":"Gwinnett Tech","location_id":"10976","lat":"33.9636","long":"-84.0664","pm25":""},{"location_name":"HAMPTON","location_id":"10982","lat":"37.103683","long":"-76.38695","pm25":""},{"location_name":"HARRINGTON BCH","location_id":"10985","lat":"43.4981","long":"-87.81","pm25":""},{"location_name":"HATTIEAVEN","location_id":"10986","lat":"36.1106","long":"-80.2267","pm25":""},{"location_name":"HAZ2","location_id":"10987","lat":"37.2831","long":"-83.2203","pm25":""},{"location_name":"HERNANDO","location_id":"10989","lat":"34.820557","long":"-89.98778","pm25":""},{"location_name":"HICKORY","location_id":"10990","lat":"35.72889","long":"-81.365555","pm25":""},{"location_name":"Higley","location_id":"10991","lat":"33.3107","long":"-111.7225","pm25":""},{"location_name":"HOUGHTON LAKE","location_id":"10994","lat":"44.3106","long":"-84.8919","pm25":""},{"location_name":"HOUSTON","location_id":"10995","lat":"38.1761","long":"-89.7883","pm25":""},{"location_name":"HR0002A","location_id":"10996","lat":"45.479057","long":"16.780666","pm25":""},{"location_name":"HR0003A","location_id":"10997","lat":"45.558792","long":"18.698769","pm25":""},{"location_name":"HR0005A","location_id":"10998","lat":"45.320793","long":"14.483511","pm25":""},{"location_name":"HR0006A","location_id":"10999","lat":"45.458126","long":"16.388355","pm25":""},{"location_name":"HR0007A","location_id":"11000","lat":"45.80034","long":"15.974072","pm25":""},{"location_name":"HR0009A","location_id":"11001","lat":"45.764946","long":"16.00647","pm25":""},{"location_name":"HR0010A","location_id":"11002","lat":"45.159473","long":"17.9951","pm25":""},{"location_name":"HR0011A","location_id":"11003","lat":"45.69803","long":"18.834639","pm25":""},{"location_name":"HR0012A","location_id":"11004","lat":"46.169056","long":"15.660639","pm25":""},{"location_name":"HR0013A","location_id":"11005","lat":"44.899334","long":"15.609777","pm25":""},{"location_name":"HR0014A","location_id":"11006","lat":"45.59348","long":"14.630464","pm25":""},{"location_name":"HR0015A","location_id":"11007","lat":"45.291203","long":"13.749778","pm25":""},{"location_name":"HR0018A","location_id":"11008","lat":"43.031334","long":"16.115973","pm25":""},{"location_name":"HR0020A","location_id":"11009","lat":"42.6447","long":"18.122612","pm25":""},{"location_name":"HR0022A","location_id":"11010","lat":"43.510654","long":"16.44934","pm25":""},{"location_name":"HR0023A","location_id":"11011","lat":"43.54812","long":"16.434961","pm25":""},{"location_name":"HR0025A","location_id":"11012","lat":"44.86247","long":"13.816858","pm25":""},{"location_name":"HR0026A","location_id":"11013","lat":"45.714844","long":"16.068254","pm25":""},{"location_name":"HU-Beltsville","location_id":"11015","lat":"39.0553","long":"-76.8783","pm25":""},{"location_name":"HU0022A","location_id":"11017","lat":"47.430836","long":"19.184174","pm25":""},{"location_name":"HU0023A","location_id":"11018","lat":"47.513332","long":"21.624445","pm25":""},{"location_name":"HU0024A","location_id":"11019","lat":"47.68528","long":"17.639444","pm25":""},{"location_name":"HU0025A","location_id":"11020","lat":"47.676113","long":"17.64974","pm25":""},{"location_name":"HU0026A","location_id":"11021","lat":"48.247223","long":"20.616404","pm25":""},{"location_name":"HU0027A","location_id":"11022","lat":"48.106915","long":"20.78998","pm25":""},{"location_name":"HU0028A","location_id":"11023","lat":"47.961113","long":"21.70584","pm25":""},{"location_name":"HU0029A","location_id":"11024","lat":"46.080276","long":"18.211123","pm25":""},{"location_name":"HU0030A","location_id":"11025","lat":"46.07111","long":"18.225286","pm25":""},{"location_name":"HU0031A","location_id":"11026","lat":"47.55722","long":"18.420835","pm25":""},{"location_name":"HU0032A","location_id":"11027","lat":"47.306667","long":"18.920002","pm25":""},{"location_name":"HU0033A","location_id":"11028","lat":"46.976112","long":"18.936113","pm25":""},{"location_name":"HU0034A","location_id":"11029","lat":"47.09111","long":"17.901121","pm25":""},{"location_name":"HU0035A","location_id":"11030","lat":"47.691944","long":"16.575008","pm25":""},{"location_name":"HU0036A","location_id":"11031","lat":"47.561943","long":"18.960009","pm25":""},{"location_name":"HU0037A","location_id":"11032","lat":"47.105278","long":"17.556665","pm25":""},{"location_name":"HU0038A","location_id":"11033","lat":"48.218056","long":"20.703058","pm25":""},{"location_name":"HU0039A","location_id":"11034","lat":"47.790005","long":"18.746134","pm25":""},{"location_name":"HU0040A","location_id":"11035","lat":"47.671947","long":"16.838896","pm25":""},{"location_name":"HU0041A","location_id":"11036","lat":"47.508057","long":"19.028067","pm25":""},{"location_name":"HU0042A","location_id":"11037","lat":"47.541943","long":"19.146122","pm25":""},{"location_name":"HU0044A","location_id":"11038","lat":"48.47389","long":"21.21168","pm25":""},{"location_name":"HU0045A","location_id":"11039","lat":"47.491943","long":"19.087782","pm25":""},{"location_name":"HU0057A","location_id":"11040","lat":"46.266613","long":"20.153053","pm25":""},{"location_name":"HVILLE","location_id":"11043","lat":"36.2975","long":"-86.6525","pm25":""},{"location_name":"Haarlem-Schipholweg","location_id":"11044","lat":"52.3705","long":"4.64232","pm25":""},{"location_name":"Hackney","location_id":"11045","lat":"39.6323","long":"-81.6701","pm25":""},{"location_name":"Hafod-yr-ynys Roadside","location_id":"11046","lat":"51.68058","long":"-3.133508","pm25":""},{"location_name":"Hagerstown","location_id":"11047","lat":"39.5656","long":"-77.7219","pm25":""},{"location_name":"Hamilton PS 46","location_id":"11051","lat":"46.24362","long":"-114.15889","pm25":""},{"location_name":"Hammond-141st St","location_id":"11052","lat":"41.6394","long":"-87.4936","pm25":""},{"location_name":"Hammond-167th St","location_id":"11053","lat":"41.594425","long":"-87.49504","pm25":""},{"location_name":"Hamshire C64","location_id":"11054","lat":"29.863953","long":"-94.3178","pm25":""},{"location_name":"Hanford - S. Irwin S","location_id":"11055","lat":"36.3144","long":"-119.6436","pm25":""},{"location_name":"Hani i Elezit","location_id":"11056","lat":"42.15396","long":"21.29601","pm25":""},{"location_name":"Hansjordnesbukta","location_id":"11057","lat":"69.65625","long":"18.96372","pm25":""},{"location_name":"Happy Hill","location_id":"11058","lat":"36.513054","long":"-82.55046","pm25":""},{"location_name":"Haringey Roadside","location_id":"11059","lat":"51.5993","long":"-0.068218","pm25":""},{"location_name":"Harriman","location_id":"11061","lat":"35.9386","long":"-84.5439","pm25":""},{"location_name":"Harrisburg","location_id":"11062","lat":"40.24699","long":"-76.846985","pm25":""},{"location_name":"Harrison Township","location_id":"11063","lat":"40.613865","long":"-79.72957","pm25":""},{"location_name":"Harrisville","location_id":"11064","lat":"41.3028","long":"-111.9883","pm25":""},{"location_name":"Hartford-Huntley","location_id":"11066","lat":"41.771442","long":"-72.679924","pm25":""},{"location_name":"Harvard Yards","location_id":"11068","lat":"41.446682","long":"-81.66242","pm25":""},{"location_name":"Hat Yai, Hat Yai","location_id":"11069","lat":"7.0100007","long":"100.29","pm25":""},{"location_name":"Hattiesburg","location_id":"11070","lat":"31.322779","long":"-89.2875","pm25":""},{"location_name":"Haukenes","location_id":"11071","lat":"59.2024","long":"9.48708","pm25":""},{"location_name":"Haverhill","location_id":"11072","lat":"42.7708","long":"-71.1028","pm25":""},{"location_name":"Havre","location_id":"11073","lat":"48.551018","long":"-109.67748","pm25":""},{"location_name":"Hawaii Volcanoes NP","location_id":"11074","lat":"19.4308","long":"-155.2578","pm25":""},{"location_name":"Haws Athletic Center","location_id":"11075","lat":"32.7592","long":"-97.3414","pm25":""},{"location_name":"Hawthorne","location_id":"11076","lat":"40.7335","long":"-111.8717","pm25":""},{"location_name":"Hayden","location_id":"11077","lat":"33.006268","long":"-110.78648","pm25":""},{"location_name":"Hayward","location_id":"11078","lat":"37.6547","long":"-122.0317","pm25":""},{"location_name":"Healdton","location_id":"11079","lat":"34.2569","long":"-97.4742","pm25":""},{"location_name":"Heerlen-Jamboreepad","location_id":"11081","lat":"50.9003","long":"5.98685","pm25":""},{"location_name":"Heerlen-Looierstraat","location_id":"11082","lat":"50.888","long":"5.9705","pm25":""},{"location_name":"Hellendoorn-Luttenbergerweg","location_id":"11083","lat":"52.3883","long":"6.40293","pm25":""},{"location_name":"Helmsburg","location_id":"11084","lat":"39.263912","long":"-86.29226","pm25":""},{"location_name":"Herculaneum, Mott St","location_id":"11085","lat":"38.263393","long":"-90.37967","pm25":""},{"location_name":"Heritage Park","location_id":"11087","lat":"38.8386","long":"-94.7464","pm25":""},{"location_name":"Hershey","location_id":"11090","lat":"40.2722","long":"-76.6814","pm25":""},{"location_name":"Hesperia - Olive Str","location_id":"11091","lat":"34.416508","long":"-117.2856","pm25":""},{"location_name":"Hiawatha","location_id":"11092","lat":"41.15778","long":"-108.619446","pm25":""},{"location_name":"Hidden Valley","location_id":"11093","lat":"32.88476","long":"-112.03705","pm25":""},{"location_name":"High Muffles","location_id":"11095","lat":"54.334946","long":"-0.80855","pm25":""},{"location_name":"High School","location_id":"11096","lat":"33.508","long":"-111.8378","pm25":""},{"location_name":"Highland Reservoir -","location_id":"11097","lat":"39.5689","long":"-104.9572","pm25":""},{"location_name":"Hillcrest","location_id":"11098","lat":"34.7518","long":"-82.2567","pm25":""},{"location_name":"Hillcrest HS","location_id":"11099","lat":"37.25607","long":"-93.29969","pm25":""},{"location_name":"Hillsboro - Hare Fie","location_id":"11100","lat":"45.5285","long":"-122.9724","pm25":""},{"location_name":"Hilo","location_id":"11101","lat":"19.717562","long":"-155.11053","pm25":""},{"location_name":"Hinds CC","location_id":"11103","lat":"32.346905","long":"-90.22593","pm25":""},{"location_name":"Hiran Ruchi, Thon Buri","location_id":"11104","lat":"13.732878","long":"100.486015","pm25":""},{"location_name":"Hjortnes","location_id":"11105","lat":"59.91132","long":"10.70407","pm25":""},{"location_name":"Hobbs Jefferson","location_id":"11106","lat":"32.7267","long":"-103.1233","pm25":""},{"location_name":"Hoek v. Holland-Berghaven","location_id":"11107","lat":"51.9778","long":"4.12194","pm25":""},{"location_name":"Holbrook","location_id":"11108","lat":"39.82","long":"-80.2897","pm25":""},{"location_name":"Holiday","location_id":"11110","lat":"28.1953","long":"-82.7578","pm25":""},{"location_name":"Holman Rd","location_id":"11112","lat":"32.4247","long":"-106.6742","pm25":""},{"location_name":"Holta","location_id":"11113","lat":"58.25602","long":"8.35935","pm25":""},{"location_name":"Holtsville","location_id":"11114","lat":"40.8278","long":"-73.0575","pm25":""},{"location_name":"Honiton","location_id":"11117","lat":"50.792286","long":"-3.196702","pm25":""},{"location_name":"Honolulu","location_id":"11118","lat":"21.3103","long":"-157.8581","pm25":""},{"location_name":"Hoofddorp-Hoofdweg","location_id":"11120","lat":"52.3275","long":"4.71501","pm25":""},{"location_name":"Hoogvliet-Leemkuil","location_id":"11121","lat":"51.8674","long":"4.35524","pm25":""},{"location_name":"Hookstown","location_id":"11122","lat":"40.5625","long":"-80.5042","pm25":""},{"location_name":"Hope","location_id":"11124","lat":"39.294323","long":"-85.766846","pm25":""},{"location_name":"Horicon Wildlife Are","location_id":"11125","lat":"43.46611","long":"-88.62111","pm25":""},{"location_name":"Horley","location_id":"11126","lat":"51.165867","long":"-0.167734","pm25":""},{"location_name":"Horn Point","location_id":"11127","lat":"38.5876","long":"-76.1408","pm25":""},{"location_name":"Horse Rock","location_id":"11129","lat":"39.483616","long":"-79.02638","pm25":""},{"location_name":"Horst a\/d Maas-Hoogheide","location_id":"11130","lat":"51.4541","long":"6.1082","pm25":""},{"location_name":"Horton Station","location_id":"11131","lat":"37.3297","long":"-80.5578","pm25":""},{"location_name":"Horyniec-Zdr\u00f3j-Park","location_id":"11132","lat":"50.1921","long":"23.361425","pm25":""},{"location_name":"Houston","location_id":"11134","lat":"40.269","long":"-80.244","pm25":""},{"location_name":"Houston Aldine C8","location_id":"11135","lat":"29.9011","long":"-95.3261","pm25":""},{"location_name":"Houston Bayland Park","location_id":"11137","lat":"29.6958","long":"-95.4992","pm25":""},{"location_name":"Houston Croquet C409","location_id":"11139","lat":"29.62389","long":"-95.47417","pm25":""},{"location_name":"Houston Deer Park C3","location_id":"11140","lat":"29.670025","long":"-95.12851","pm25":""},{"location_name":"Houston East C1","location_id":"11141","lat":"29.7681","long":"-95.2206","pm25":""},{"location_name":"Houston Monroe C406","location_id":"11143","lat":"29.625557","long":"-95.26722","pm25":""},{"location_name":"Houston North Waysid","location_id":"11145","lat":"29.8281","long":"-95.2842","pm25":""},{"location_name":"Houston Park Place C","location_id":"11147","lat":"29.68639","long":"-95.29472","pm25":""},{"location_name":"Houston Westhollow C","location_id":"11150","lat":"29.7233","long":"-95.6358","pm25":""},{"location_name":"Howard County Near R","location_id":"11153","lat":"39.143196","long":"-76.84619","pm25":""},{"location_name":"Hoxeyville","location_id":"11155","lat":"44.1809","long":"-85.739","pm25":""},{"location_name":"Huai Kon, Chaloem Phra Kiat","location_id":"11156","lat":"19.540054","long":"101.0483","pm25":""},{"location_name":"Huai Pong, Mueang","location_id":"11157","lat":"12.735202","long":"101.13567","pm25":""},{"location_name":"Huijbergen-Vennekenstraat","location_id":"11159","lat":"51.4344","long":"4.35984","pm25":""},{"location_name":"Hull Freetown","location_id":"11160","lat":"53.74878","long":"-0.341222","pm25":""},{"location_name":"Hull Holderness Road","location_id":"11161","lat":"53.758972","long":"-0.305749","pm25":""},{"location_name":"Humboldt Mountain -","location_id":"11163","lat":"33.9828","long":"-111.7987","pm25":""},{"location_name":"Huntington Wildlife","location_id":"11164","lat":"43.97","long":"-74.22","pm25":""},{"location_name":"Hurdal25","location_id":"11167","lat":"60.37288","long":"11.07407","pm25":""},{"location_name":"Huron","location_id":"11168","lat":"36.1994","long":"-120.0991","pm25":""},{"location_name":"Hurricane","location_id":"11169","lat":"37.179","long":"-113.3052","pm25":""},{"location_name":"Hurst Road","location_id":"11170","lat":"64.76297","long":"-147.3103","pm25":""},{"location_name":"I25 Denver","location_id":"11174","lat":"39.732143","long":"-105.01531","pm25":""},{"location_name":"IE0001R","location_id":"11175","lat":"51.938057","long":"-10.240833","pm25":""},{"location_name":"IE001AP","location_id":"11176","lat":"53.336296","long":"-6.30902","pm25":""},{"location_name":"IE001BP","location_id":"11177","lat":"51.91111","long":"-8.475","pm25":""},{"location_name":"IE001CM","location_id":"11178","lat":"53.036125","long":"-7.288675","pm25":""},{"location_name":"IE001DM","location_id":"11179","lat":"52.4985","long":"-6.57075","pm25":""},{"location_name":"IE0028A","location_id":"11180","lat":"53.35389","long":"-6.278056","pm25":""},{"location_name":"IE002AP","location_id":"11181","lat":"53.372044","long":"-6.175326","pm25":""},{"location_name":"IE0031R","location_id":"11182","lat":"54.326668","long":"-9.904444","pm25":""},{"location_name":"IE0036A","location_id":"11183","lat":"53.333332","long":"-6.366667","pm25":""},{"location_name":"IE003AP","location_id":"11184","lat":"53.39025","long":"-6.305266","pm25":""},{"location_name":"IE0090A","location_id":"11185","lat":"54.066113","long":"-6.883056","pm25":""},{"location_name":"IE0095A","location_id":"11186","lat":"53.35278","long":"-6.366667","pm25":""},{"location_name":"IE0098A","location_id":"11187","lat":"53.341667","long":"-6.288889","pm25":""},{"location_name":"IE0110A","location_id":"11189","lat":"51.881943","long":"-8.456667","pm25":""},{"location_name":"IE0111A","location_id":"11190","lat":"53.106945","long":"-7.196389","pm25":""},{"location_name":"IE0118A","location_id":"11191","lat":"53.851112","long":"-9.299722","pm25":""},{"location_name":"IE0127A","location_id":"11192","lat":"53.31389","long":"-6.249167","pm25":""},{"location_name":"IE0131A","location_id":"11193","lat":"53.385635","long":"-6.369934","pm25":""},{"location_name":"IE0140A","location_id":"11197","lat":"53.27481","long":"-6.222367","pm25":""},{"location_name":"IE0141A","location_id":"11198","lat":"53.18722","long":"-6.121667","pm25":""},{"location_name":"IE0147A","location_id":"11200","lat":"52.638798","long":"-7.268114","pm25":""},{"location_name":"IMGW \u0141eba - R\u0105bka","location_id":"11203","lat":"54.75414","long":"17.534529","pm25":""},{"location_name":"IMGW-Jarczew","location_id":"11204","lat":"51.814365","long":"21.972376","pm25":""},{"location_name":"ISONZO","location_id":"11205","lat":"44.8425","long":"11.6131","pm25":""},{"location_name":"Idaho City","location_id":"11207","lat":"43.823017","long":"-115.838554","pm25":""},{"location_name":"Idaho Falls \/ Penfor","location_id":"11208","lat":"43.4683","long":"-112.0531","pm25":""},{"location_name":"Incline","location_id":"11209","lat":"39.25044","long":"-119.95674","pm25":""},{"location_name":"Indian River Lagoon","location_id":"11210","lat":"27.8492","long":"-80.4554","pm25":""},{"location_name":"Indio - Jackson Stre","location_id":"11212","lat":"33.708565","long":"-116.21539","pm25":""},{"location_name":"Indio-29 Palms","location_id":"11213","lat":"33.71969","long":"-116.1897","pm25":""},{"location_name":"Indpls - I-70 E","location_id":"11214","lat":"39.787933","long":"-86.13088","pm25":""},{"location_name":"Indpls- Illinois St","location_id":"11215","lat":"39.768055","long":"-86.16","pm25":""},{"location_name":"Indpls-Ft. Harrison","location_id":"11217","lat":"39.8589","long":"-86.0214","pm25":""},{"location_name":"Indpls-Harding St","location_id":"11218","lat":"39.7489","long":"-86.1861","pm25":""},{"location_name":"Indpls-W.18th St","location_id":"11219","lat":"39.7889","long":"-86.2147","pm25":""},{"location_name":"Indpls-Washington Pa","location_id":"11220","lat":"39.8108","long":"-86.1147","pm25":""},{"location_name":"Inglefield","location_id":"11221","lat":"38.1139","long":"-87.5369","pm25":""},{"location_name":"Inowroc\u0142aw Airpointer","location_id":"11222","lat":"52.79312","long":"18.241043","pm25":""},{"location_name":"Intarapitak Rd., Thon Buri","location_id":"11223","lat":"13.727559","long":"100.4866","pm25":""},{"location_name":"Inverness","location_id":"11224","lat":"57.481308","long":"-4.241451","pm25":""},{"location_name":"Iowa City, Hoover Sc","location_id":"11225","lat":"41.658195","long":"-91.50347","pm25":""},{"location_name":"Irmo","location_id":"11226","lat":"34.0511","long":"-81.155","pm25":""},{"location_name":"Ironton - ODOT","location_id":"11227","lat":"38.508114","long":"-82.6593","pm25":""},{"location_name":"Italy C1044","location_id":"11230","lat":"32.1772","long":"-96.8711","pm25":""},{"location_name":"Ivanhoe C414","location_id":"11231","lat":"31.7864","long":"-106.3242","pm25":""},{"location_name":"JAMES S. LONG PARK","location_id":"11234","lat":"38.8553","long":"-77.6356","pm25":""},{"location_name":"JAMESVIL","location_id":"11235","lat":"35.8111","long":"-76.9067","pm25":""},{"location_name":"JERSEYVL","location_id":"11237","lat":"39.10144","long":"-90.3445","pm25":""},{"location_name":"JOHNSTON","location_id":"11239","lat":"35.59095","long":"-78.4622","pm25":""},{"location_name":"JPRECC","location_id":"11240","lat":"37.0581","long":"-88.5725","pm25":""},{"location_name":"Jackson","location_id":"11244","lat":"33.3422","long":"-81.7886","pm25":""},{"location_name":"Jackson - Clinton","location_id":"11245","lat":"38.342606","long":"-120.76443","pm25":""},{"location_name":"Jackson Road","location_id":"11247","lat":"27.0892","long":"-82.3625","pm25":""},{"location_name":"Jacobs","location_id":"11248","lat":"40.776943","long":"-124.1775","pm25":""},{"location_name":"Jakarta Central","location_id":"11249","lat":"-6.182536","long":"106.834236","pm25":""},{"location_name":"James Town Mobile","location_id":"11251","lat":"41.55643","long":"-109.53044","pm25":""},{"location_name":"Jaros\u0142aw-PWSTE-WIOS","location_id":"11252","lat":"50.01208","long":"22.674772","pm25":""},{"location_name":"Jaslo-Sikorskiego-WIOS","location_id":"11253","lat":"49.744884","long":"21.454617","pm25":""},{"location_name":"Jawor","location_id":"11254","lat":"51.049213","long":"16.202316","pm25":""},{"location_name":"Jean","location_id":"11255","lat":"35.785664","long":"-115.357086","pm25":""},{"location_name":"Jefferson","location_id":"11256","lat":"35.1441","long":"-106.6044","pm25":""},{"location_name":"Jeffersonville - Bat","location_id":"11258","lat":"38.288193","long":"-85.74134","pm25":""},{"location_name":"Jelenia G\u00f3ra - Ogi\u0144skiego","location_id":"11259","lat":"50.913433","long":"15.765608","pm25":""},{"location_name":"Jenkins Avenue","location_id":"11260","lat":"32.88229","long":"-79.97754","pm25":""},{"location_name":"Jerome Mack","location_id":"11262","lat":"36.141876","long":"-115.07874","pm25":""},{"location_name":"Jersey City","location_id":"11263","lat":"40.73169","long":"-74.06657","pm25":""},{"location_name":"Jersey City FH","location_id":"11264","lat":"40.725452","long":"-74.05229","pm25":""},{"location_name":"Joe Neal","location_id":"11266","lat":"36.27059","long":"-115.23828","pm25":""},{"location_name":"John A. Chesnut Sr.","location_id":"11267","lat":"28.0903","long":"-82.7008","pm25":""},{"location_name":"John Day Dayton St","location_id":"11268","lat":"44.418","long":"-118.9513","pm25":""},{"location_name":"Johnson County","location_id":"11269","lat":"43.87483","long":"-106.50974","pm25":""},{"location_name":"Johnstown","location_id":"11270","lat":"40.3097","long":"-78.9158","pm25":""},{"location_name":"Joliet","location_id":"11271","lat":"41.526886","long":"-88.11647","pm25":""},{"location_name":"Joshua Tree NP - Bla","location_id":"11273","lat":"34.0714","long":"-116.3906","pm25":""},{"location_name":"Joshua Tree NP - Cot","location_id":"11274","lat":"33.7472","long":"-115.8201","pm25":""},{"location_name":"Juel Spring","location_id":"11277","lat":"42.373","long":"-109.563","pm25":""},{"location_name":"K-Ko\u017ale automat 1","location_id":"11279","lat":"50.34961","long":"18.236574","pm25":""},{"location_name":"KAHULUI","location_id":"11281","lat":"20.869444","long":"-156.49242","pm25":""},{"location_name":"KALAMAZOO","location_id":"11282","lat":"42.2781","long":"-85.5419","pm25":""},{"location_name":"KILLENS","location_id":"11284","lat":"38.9847","long":"-75.5556","pm25":""},{"location_name":"KM\u015a Puszcza Borecka","location_id":"11286","lat":"54.12482","long":"22.038055","pm25":""},{"location_name":"KNI-Topeka","location_id":"11287","lat":"39.0242","long":"-95.7114","pm25":""},{"location_name":"KNIGHT_P","location_id":"11288","lat":"38.0889","long":"-88.625","pm25":""},{"location_name":"KS Hawaii","location_id":"11290","lat":"19.611916","long":"-155.05504","pm25":""},{"location_name":"Kalispell Flathead E","location_id":"11292","lat":"48.2025","long":"-114.30556","pm25":""},{"location_name":"Kalisz-Wyszynskiego","location_id":"11293","lat":"51.749054","long":"18.04839","pm25":""},{"location_name":"Kamiah-ID","location_id":"11294","lat":"46.2094","long":"-116.0275","pm25":""},{"location_name":"Kane Exp. Forest","location_id":"11298","lat":"41.598","long":"-78.7674","pm25":""},{"location_name":"Kannik","location_id":"11299","lat":"58.96415","long":"5.72785","pm25":""},{"location_name":"Kapolei","location_id":"11300","lat":"21.3236","long":"-158.0886","pm25":""},{"location_name":"Karl Eriksens plass","location_id":"11307","lat":"62.470623","long":"6.153501","pm25":""},{"location_name":"Karnack C85","location_id":"11308","lat":"32.6706","long":"-94.1681","pm25":""},{"location_name":"Karpdalen","location_id":"11309","lat":"69.65617","long":"30.42147","pm25":""},{"location_name":"Kasz\u00f3w","location_id":"11312","lat":"50.02503","long":"19.726833","pm25":""},{"location_name":"Katowice, ul. Kossutha 6","location_id":"11313","lat":"50.26461","long":"18.975027","pm25":""},{"location_name":"Katowice, ul. Plebiscytowa\/A4","location_id":"11314","lat":"50.246796","long":"19.019468","pm25":""},{"location_name":"Kaufman C71","location_id":"11316","lat":"32.565","long":"-96.3175","pm25":""},{"location_name":"Keeler","location_id":"11320","lat":"36.4878","long":"-117.871","pm25":""},{"location_name":"Keene","location_id":"11321","lat":"42.93052","long":"-72.27233","pm25":""},{"location_name":"Keller C17","location_id":"11322","lat":"32.922497","long":"-97.28209","pm25":""},{"location_name":"Kennedy Meadows","location_id":"11325","lat":"36.0214","long":"-118.137","pm25":""},{"location_name":"Kenner","location_id":"11326","lat":"30.0411","long":"-90.2728","pm25":""},{"location_name":"Kennewick-Metaline","location_id":"11328","lat":"46.2183","long":"-119.2015","pm25":""},{"location_name":"Kent-James & Central","location_id":"11331","lat":"47.3861","long":"-122.2302","pm25":""},{"location_name":"Kernville","location_id":"11333","lat":"35.755","long":"-118.4175","pm25":""},{"location_name":"Ketchum","location_id":"11335","lat":"43.682556","long":"-114.37109","pm25":""},{"location_name":"Khlong Chan, Bang kapi","location_id":"11338","lat":"13.78152","long":"100.63655","pm25":""},{"location_name":"Khlong Nueng, Khlong Luang","location_id":"11339","lat":"14.040299","long":"100.60874","pm25":""},{"location_name":"Kielce, ul. Targowa","location_id":"11341","lat":"50.878998","long":"20.633692","pm25":""},{"location_name":"Kihei, Maui","location_id":"11342","lat":"20.7808","long":"-156.4461","pm25":""},{"location_name":"Killeen C1047","location_id":"11343","lat":"31.088001","long":"-97.67973","pm25":""},{"location_name":"King Greenleaf Rec C","location_id":"11345","lat":"38.87516","long":"-77.01282","pm25":""},{"location_name":"Kingery Near-road #1","location_id":"11346","lat":"41.5786","long":"-87.55739","pm25":""},{"location_name":"Kingsport","location_id":"11347","lat":"36.5408","long":"-82.5217","pm25":""},{"location_name":"Kirkeveien","location_id":"11350","lat":"59.93233","long":"10.72447","pm25":""},{"location_name":"Kittanning","location_id":"11351","lat":"40.8142","long":"-79.565","pm25":""},{"location_name":"Klamath Falls - Pete","location_id":"11352","lat":"42.190296","long":"-121.73137","pm25":""},{"location_name":"Klosterhaugen","location_id":"11353","lat":"60.395927","long":"5.312674","pm25":""},{"location_name":"Knarrdalstranda","location_id":"11354","lat":"59.13354","long":"9.6219","pm25":""},{"location_name":"Kokomo - E. Vaile Av","location_id":"11355","lat":"40.48135","long":"-86.10972","pm25":""},{"location_name":"Kollumerwaard-Hooge Zuidwal","location_id":"11356","lat":"53.3304","long":"6.27681","pm25":""},{"location_name":"Kona","location_id":"11358","lat":"19.5097","long":"-155.9133","pm25":""},{"location_name":"Koniczynka","location_id":"11360","lat":"53.080647","long":"18.684258","pm25":""},{"location_name":"Konin-Wyszynskiego","location_id":"11361","lat":"52.22563","long":"18.269035","pm25":""},{"location_name":"Konstancin-Jeziorna-Wierzejewskiego","location_id":"11362","lat":"52.080624","long":"21.111185","pm25":""},{"location_name":"Konsul Wilds vei","location_id":"11363","lat":"58.129295","long":"7.972886","pm25":""},{"location_name":"Kooker Park","location_id":"11364","lat":"30.356112","long":"-81.63556","pm25":""},{"location_name":"Koper","location_id":"11365","lat":"45.54297","long":"13.713539","pm25":""},{"location_name":"Koszalin_ArmiiKrajowej","location_id":"11366","lat":"54.193985","long":"16.172544","pm25":""},{"location_name":"Koszalin_Chopina","location_id":"11367","lat":"54.19412","long":"16.21166","pm25":""},{"location_name":"Kozieglowy-os.Lesne","location_id":"11368","lat":"52.44933","long":"16.999683","pm25":""},{"location_name":"Krak\u00f3w, Aleja Krasi\u0144skiego","location_id":"11370","lat":"50.05768","long":"19.92619","pm25":""},{"location_name":"Krak\u00f3w, os. Piast\u00f3w","location_id":"11371","lat":"50.098507","long":"20.018269","pm25":""},{"location_name":"Krak\u00f3w, os. Swoszowice","location_id":"11372","lat":"49.991444","long":"19.936792","pm25":""},{"location_name":"Krak\u00f3w, os. Wad\u00f3w","location_id":"11373","lat":"50.10057","long":"20.12256","pm25":""},{"location_name":"Krak\u00f3w, ul. Bujaka","location_id":"11374","lat":"50.010574","long":"19.949188","pm25":""},{"location_name":"Krak\u00f3w, ul. Bulwarowa","location_id":"11375","lat":"50.06931","long":"20.053492","pm25":""},{"location_name":"Krak\u00f3w, ul. Dietla","location_id":"11376","lat":"50.057446","long":"19.946009","pm25":""},{"location_name":"Krak\u00f3w, ul. Z\u0142oty R\u00f3g","location_id":"11377","lat":"50.081196","long":"19.895357","pm25":""},{"location_name":"Kransen","location_id":"11378","lat":"59.43347","long":"10.661762","pm25":""},{"location_name":"Kremlin","location_id":"11379","lat":"36.512295","long":"-97.84563","pm25":""},{"location_name":"Krempna-MPN-WIOS","location_id":"11380","lat":"49.511295","long":"21.498606","pm25":""},{"location_name":"Krosno-Klet\u00f3wki","location_id":"11381","lat":"49.69017","long":"21.7497","pm25":""},{"location_name":"Krynica, ul. Bulwary Dietla","location_id":"11382","lat":"49.416977","long":"20.956146","pm25":""},{"location_name":"Kutno-1 Maja 7","location_id":"11384","lat":"52.231728","long":"19.353743","pm25":""},{"location_name":"Kutztown","location_id":"11385","lat":"40.51408","long":"-75.7897","pm25":""},{"location_name":"Kuwait City","location_id":"11386","lat":"29.292316","long":"48.04768","pm25":""},{"location_name":"Kwai Chung","location_id":"11387","lat":"22.357222","long":"114.12972","pm25":""},{"location_name":"Kwun Tong","location_id":"11388","lat":"22.313334","long":"114.224724","pm25":""},{"location_name":"K\u00e5rvatn","location_id":"11389","lat":"62.78246","long":"8.87658","pm25":""},{"location_name":"K\u0142odzko - Szkolna","location_id":"11392","lat":"50.433495","long":"16.65366","pm25":""},{"location_name":"LABP","location_id":"11395","lat":"40.0917","long":"-75.0978","pm25":""},{"location_name":"LACROSSE DOT","location_id":"11396","lat":"43.7781","long":"-91.225","pm25":""},{"location_name":"LANSING FILLEY ST","location_id":"11400","lat":"42.76138","long":"-84.56287","pm25":""},{"location_name":"LAX-Hastings","location_id":"11402","lat":"33.95507","long":"-118.43046","pm25":""},{"location_name":"LEEDS","location_id":"11403","lat":"33.5453","long":"-86.5492","pm25":""},{"location_name":"LEGGETT","location_id":"11404","lat":"35.988277","long":"-77.5843","pm25":""},{"location_name":"LEHI","location_id":"11405","lat":"33.4745","long":"-111.8051","pm25":""},{"location_name":"LEMONT","location_id":"11406","lat":"41.6681","long":"-87.9906","pm25":""},{"location_name":"LENOIR","location_id":"11407","lat":"35.9359","long":"-81.5306","pm25":""},{"location_name":"LEWES","location_id":"11409","lat":"38.7833","long":"-75.1667","pm25":""},{"location_name":"LIBERTY","location_id":"11411","lat":"39.303055","long":"-94.37639","pm25":""},{"location_name":"LLCHD BAM","location_id":"11414","lat":"40.812557","long":"-96.675735","pm25":""},{"location_name":"LOCKLAND","location_id":"11416","lat":"36.1767","long":"-86.7386","pm25":""},{"location_name":"LOUDONMS","location_id":"11417","lat":"35.7197","long":"-84.3417","pm25":""},{"location_name":"LSU","location_id":"11418","lat":"30.4197","long":"-91.1819","pm25":""},{"location_name":"LT00001","location_id":"11419","lat":"54.677624","long":"25.285187","pm25":""},{"location_name":"LT00002","location_id":"11420","lat":"54.68611","long":"25.210835","pm25":""},{"location_name":"LT00003","location_id":"11421","lat":"54.71528","long":"25.289444","pm25":""},{"location_name":"LT00004","location_id":"11422","lat":"54.673332","long":"25.248903","pm25":""},{"location_name":"LT00012","location_id":"11423","lat":"55.725","long":"24.36557","pm25":""},{"location_name":"LT00021","location_id":"11424","lat":"56.31944","long":"22.87084","pm25":""},{"location_name":"LT00022","location_id":"11425","lat":"55.937836","long":"23.308027","pm25":""},{"location_name":"LT00023","location_id":"11426","lat":"56.309723","long":"22.33139","pm25":""},{"location_name":"LT00031","location_id":"11427","lat":"55.70778","long":"21.141111","pm25":""},{"location_name":"LT00033","location_id":"11428","lat":"55.69","long":"21.17946","pm25":""},{"location_name":"LT00041","location_id":"11429","lat":"54.895126","long":"23.986221","pm25":""},{"location_name":"LT00042","location_id":"11430","lat":"55.072224","long":"24.283894","pm25":""},{"location_name":"LT00043","location_id":"11431","lat":"55.28","long":"23.95778","pm25":""},{"location_name":"LT00044","location_id":"11432","lat":"54.883614","long":"23.835835","pm25":""},{"location_name":"LT00051","location_id":"11433","lat":"55.463333","long":"26.00417","pm25":""},{"location_name":"LT00052","location_id":"11434","lat":"54.0925","long":"24.289728","pm25":""},{"location_name":"LT00053","location_id":"11435","lat":"56.008335","long":"21.886948","pm25":""},{"location_name":"LU0101A","location_id":"11436","lat":"49.59769","long":"6.13759","pm25":""},{"location_name":"LU0102A","location_id":"11437","lat":"49.50504","long":"5.97694","pm25":""},{"location_name":"LU0103A","location_id":"11438","lat":"49.94396","long":"6.17591","pm25":""},{"location_name":"LU0104A","location_id":"11439","lat":"49.73181","long":"5.84714","pm25":""},{"location_name":"LU0105A","location_id":"11440","lat":"49.72226","long":"6.30533","pm25":""},{"location_name":"LU0109A","location_id":"11442","lat":"49.61157","long":"6.11847","pm25":""},{"location_name":"LUGAGNANO","location_id":"11443","lat":"44.8239","long":"9.8304","pm25":""},{"location_name":"LUMS 2","location_id":"11444","lat":"39.5511","long":"-75.7308","pm25":""},{"location_name":"LV0007A","location_id":"11445","lat":"57.404633","long":"21.59199","pm25":""},{"location_name":"LV0008A","location_id":"11446","lat":"56.510204","long":"27.333368","pm25":""},{"location_name":"LV0012A","location_id":"11447","lat":"56.523174","long":"21.004694","pm25":""},{"location_name":"LV0019A","location_id":"11448","lat":"56.950607","long":"24.115871","pm25":""},{"location_name":"LWATTOWR","location_id":"11449","lat":"35.8145","long":"-80.2627","pm25":""},{"location_name":"LYNN","location_id":"11450","lat":"42.4747","long":"-70.9719","pm25":""},{"location_name":"La Casa NCORE - 4545","location_id":"11451","lat":"39.7794","long":"-105.00523","pm25":""},{"location_name":"La Grande Hall & N S","location_id":"11454","lat":"45.3235","long":"-118.0778","pm25":""},{"location_name":"La Habra","location_id":"11455","lat":"33.92506","long":"-117.95258","pm25":""},{"location_name":"LaPorte-E. Lincolnwa","location_id":"11462","lat":"41.6292","long":"-86.6847","pm25":""},{"location_name":"Lab Annex","location_id":"11463","lat":"25.798332","long":"-80.21028","pm25":""},{"location_name":"Lacey-College St","location_id":"11464","lat":"47.0293","long":"-122.8215","pm25":""},{"location_name":"Lacrosse-Hill St","location_id":"11466","lat":"46.8153","long":"-117.8739","pm25":""},{"location_name":"Ladue","location_id":"11467","lat":"38.650257","long":"-90.350464","pm25":""},{"location_name":"Ladybower","location_id":"11468","lat":"53.40337","long":"-1.752006","pm25":""},{"location_name":"Lafayette","location_id":"11469","lat":"30.2258","long":"-92.0428","pm25":""},{"location_name":"Lahore","location_id":"11471","lat":"31.560078","long":"74.33589","pm25":""},{"location_name":"Lake City","location_id":"11473","lat":"30.1783","long":"-82.6192","pm25":""},{"location_name":"Lake Elsinore - W. F","location_id":"11474","lat":"33.676537","long":"-117.331024","pm25":""},{"location_name":"Lake Forest Park-Tow","location_id":"11475","lat":"47.755","long":"-122.2806","pm25":""},{"location_name":"Lake Ilo","location_id":"11476","lat":"47.34259","long":"-102.645996","pm25":""},{"location_name":"Lake Jackson C1016","location_id":"11477","lat":"29.043758","long":"-95.472946","pm25":""},{"location_name":"Lake Sugema","location_id":"11479","lat":"40.6933","long":"-92.0061","pm25":""},{"location_name":"Lakeview - Center &","location_id":"11480","lat":"42.189217","long":"-120.353966","pm25":""},{"location_name":"Lakeville - Near Roa","location_id":"11481","lat":"44.706123","long":"-93.285805","pm25":""},{"location_name":"Lancaster","location_id":"11482","lat":"40.0467","long":"-76.2833","pm25":""},{"location_name":"Lancaster DW","location_id":"11483","lat":"40.0439","long":"-76.1125","pm25":""},{"location_name":"Lancaster-Division","location_id":"11484","lat":"34.66959","long":"-118.13069","pm25":""},{"location_name":"Laney College","location_id":"11485","lat":"37.793625","long":"-122.263374","pm25":""},{"location_name":"Lang C408","location_id":"11486","lat":"29.834167","long":"-95.48917","pm25":""},{"location_name":"Lantana Preserve","location_id":"11487","lat":"26.593807","long":"-80.058914","pm25":""},{"location_name":"Lapwai","location_id":"11489","lat":"46.3972","long":"-116.8062","pm25":""},{"location_name":"Laramie County Mobil","location_id":"11490","lat":"41.08536","long":"-104.52277","pm25":""},{"location_name":"Laramie Temporary PM","location_id":"11492","lat":"41.32","long":"-105.62","pm25":""},{"location_name":"Laredo C44","location_id":"11494","lat":"27.517403","long":"-99.51524","pm25":""},{"location_name":"Las Cruces ED","location_id":"11497","lat":"32.310333","long":"-106.75121","pm25":""},{"location_name":"Las Flores Canyon","location_id":"11498","lat":"34.4897","long":"-120.0458","pm25":""},{"location_name":"Las Vegas Paiute","location_id":"11500","lat":"36.357777","long":"-115.36139","pm25":""},{"location_name":"Lassen Volcanic NP","location_id":"11501","lat":"40.5403","long":"-121.5764","pm25":""},{"location_name":"Lat Phrao Rd., Wang Thonglang","location_id":"11502","lat":"13.792635","long":"100.59608","pm25":""},{"location_name":"Latina-Scalo","location_id":"11503","lat":"41.53143","long":"12.946064","pm25":""},{"location_name":"Laurel","location_id":"11504","lat":"61.181118","long":"-149.834","pm25":""},{"location_name":"Laurel Hill","location_id":"11505","lat":"39.9878","long":"-79.2514","pm25":""},{"location_name":"Laurel Oaks Elementa","location_id":"11506","lat":"26.2992","long":"-81.72","pm25":""},{"location_name":"Lawrenceville","location_id":"11509","lat":"40.4656","long":"-79.9611","pm25":""},{"location_name":"Lawton North","location_id":"11510","lat":"34.633","long":"-98.4288","pm25":""},{"location_name":"Leamington Spa","location_id":"11511","lat":"52.28881","long":"-1.533119","pm25":""},{"location_name":"Leamington Spa Rugby Road","location_id":"11512","lat":"52.294884","long":"-1.542911","pm25":""},{"location_name":"Leavenworth-Evans St","location_id":"11513","lat":"47.5988","long":"-120.6647","pm25":""},{"location_name":"Leavenworth-U.S. Pen","location_id":"11514","lat":"39.3275","long":"-94.9513","pm25":""},{"location_name":"Lebanon","location_id":"11516","lat":"43.629604","long":"-72.3095","pm25":""},{"location_name":"Lebec","location_id":"11517","lat":"34.8416","long":"-118.8647","pm25":""},{"location_name":"Lee Vining","location_id":"11519","lat":"37.96207","long":"-119.12028","pm25":""},{"location_name":"Leech Lake Nation: C","location_id":"11520","lat":"47.38443","long":"-94.60166","pm25":""},{"location_name":"Leeds Centre","location_id":"11521","lat":"53.80378","long":"-1.546472","pm25":""},{"location_name":"Leeds Headingley Kerbside","location_id":"11522","lat":"53.819973","long":"-1.576361","pm25":""},{"location_name":"Legionowo-Zegrzy\u0144ska","location_id":"11523","lat":"52.407578","long":"20.955929","pm25":""},{"location_name":"Legnica - Rzeczypospolitej","location_id":"11524","lat":"51.204502","long":"16.180513","pm25":""},{"location_name":"Leicester A594 Roadside","location_id":"11525","lat":"52.638676","long":"-1.124228","pm25":""},{"location_name":"Leicester University","location_id":"11526","lat":"52.619823","long":"-1.127311","pm25":""},{"location_name":"Leiret","location_id":"11528","lat":"60.883644","long":"11.5593","pm25":""},{"location_name":"Lemmon Valley","location_id":"11529","lat":"39.645287","long":"-119.84005","pm25":""},{"location_name":"Lensmannsdalen","location_id":"11531","lat":"59.15927","long":"9.63565","pm25":""},{"location_name":"Leo HS","location_id":"11532","lat":"41.221416","long":"-85.01682","pm25":""},{"location_name":"Leominster","location_id":"11533","lat":"52.22174","long":"-2.736665","pm25":""},{"location_name":"Leonessa","location_id":"11534","lat":"42.572594","long":"12.961982","pm25":""},{"location_name":"Leopold","location_id":"11536","lat":"38.1131","long":"-86.6036","pm25":""},{"location_name":"Lerwick","location_id":"11537","lat":"60.13922","long":"-1.185319","pm25":""},{"location_name":"Lewiston","location_id":"11539","lat":"46.4085","long":"-116.9914","pm25":""},{"location_name":"Lewistown","location_id":"11540","lat":"47.04854","long":"-109.455315","pm25":""},{"location_name":"Libby Courthouse","location_id":"11541","lat":"48.3841","long":"-115.548","pm25":""},{"location_name":"Liberty (SAHS)","location_id":"11542","lat":"40.3239","long":"-79.8683","pm25":""},{"location_name":"Lido Park; McKinley","location_id":"11544","lat":"27.3072","long":"-82.5703","pm25":""},{"location_name":"Lillehammer barnehage","location_id":"11545","lat":"61.12087","long":"10.46563","pm25":""},{"location_name":"Lima","location_id":"11546","lat":"40.771","long":"-84.0539","pm25":""},{"location_name":"Lincoln","location_id":"11548","lat":"46.955997","long":"-112.655396","pm25":""},{"location_name":"Linda","location_id":"11550","lat":"36.349377","long":"-116.03197","pm25":""},{"location_name":"Lindon","location_id":"11551","lat":"40.3414","long":"-111.7136","pm25":""},{"location_name":"Livermore - Rincon","location_id":"11554","lat":"37.687527","long":"-121.78422","pm25":""},{"location_name":"Liverpool Speke","location_id":"11556","lat":"53.34633","long":"-2.844333","pm25":""},{"location_name":"Lizard Tail","location_id":"11557","lat":"36.5432","long":"-117.9418","pm25":""},{"location_name":"Ljubljana Be\u017eigrad","location_id":"11558","lat":"46.0655","long":"14.512704","pm25":""},{"location_name":"Loddefjord","location_id":"11559","lat":"60.361134","long":"5.23686","pm25":""},{"location_name":"Lommedalen","location_id":"11560","lat":"59.9524","long":"10.487777","pm25":""},{"location_name":"Lompoc H Street","location_id":"11561","lat":"34.6378","long":"-120.4567","pm25":""},{"location_name":"Lompoc HS&P","location_id":"11562","lat":"34.7256","long":"-120.4278","pm25":""},{"location_name":"Lomza Sikorskiego 48\/94","location_id":"11563","lat":"53.181393","long":"22.05438","pm25":""},{"location_name":"London","location_id":"11564","lat":"39.78819","long":"-83.47606","pm25":""},{"location_name":"London Bexley","location_id":"11565","lat":"51.46603","long":"0.184806","pm25":""},{"location_name":"London Bloomsbury","location_id":"11566","lat":"51.52229","long":"-0.125889","pm25":""},{"location_name":"London Eltham","location_id":"11567","lat":"51.45258","long":"0.070766","pm25":""},{"location_name":"London Haringey Priory Park South","location_id":"11568","lat":"51.58413","long":"-0.125254","pm25":""},{"location_name":"London Harlington","location_id":"11569","lat":"51.48879","long":"-0.441614","pm25":""},{"location_name":"London Hillingdon","location_id":"11571","lat":"51.49633","long":"-0.460861","pm25":""},{"location_name":"London Marylebone Road","location_id":"11572","lat":"51.52253","long":"-0.154611","pm25":""},{"location_name":"London N. Kensington","location_id":"11573","lat":"51.52105","long":"-0.213492","pm25":""},{"location_name":"London Teddington Bushy Park","location_id":"11575","lat":"51.425285","long":"-0.345606","pm25":""},{"location_name":"London Westminster","location_id":"11576","lat":"51.49467","long":"-0.131931","pm25":""},{"location_name":"Londonderry - Moose","location_id":"11577","lat":"42.86253","long":"-71.38014","pm25":""},{"location_name":"Long Beach - Hudson","location_id":"11579","lat":"33.802418","long":"-118.21993","pm25":""},{"location_name":"Long Creek","location_id":"11580","lat":"34.805","long":"-83.2375","pm25":""},{"location_name":"Longmont","location_id":"11581","lat":"40.164585","long":"-105.10086","pm25":""},{"location_name":"Longview C19\/C127","location_id":"11582","lat":"32.37868","long":"-94.71181","pm25":""},{"location_name":"Longview-30th Ave","location_id":"11583","lat":"46.1394","long":"-122.9619","pm25":""},{"location_name":"Look Rock - GSMNP","location_id":"11584","lat":"35.6322","long":"-83.9422","pm25":""},{"location_name":"Los Angeles - N. Mai","location_id":"11586","lat":"34.06643","long":"-118.22675","pm25":""},{"location_name":"Los Gatos","location_id":"11588","lat":"37.2267","long":"-121.9786","pm25":""},{"location_name":"Loudonville","location_id":"11591","lat":"42.6769","long":"-73.7556","pm25":""},{"location_name":"Lough Navar","location_id":"11592","lat":"54.43951","long":"-7.900328","pm25":""},{"location_name":"Luba\u0144 - Mieszka II","location_id":"11595","lat":"51.11901","long":"15.275539","pm25":""},{"location_name":"Lublin ul. Obywatelska","location_id":"11597","lat":"51.25943","long":"22.569134","pm25":""},{"location_name":"Lublin-Podmiejska","location_id":"11598","lat":"51.163544","long":"22.598608","pm25":""},{"location_name":"Lubliniec, ul. ks. Szyma\u0142y","location_id":"11599","lat":"50.675694","long":"18.682064","pm25":""},{"location_name":"Lucerne Valley","location_id":"11600","lat":"34.4101","long":"-116.906876","pm25":""},{"location_name":"Lullington Heath","location_id":"11601","lat":"50.7937","long":"0.18125","pm25":""},{"location_name":"Luton A505 Roadside","location_id":"11602","lat":"51.892292","long":"-0.46211","pm25":""},{"location_name":"Lynchburg Ferry C101","location_id":"11603","lat":"29.7644","long":"-95.0781","pm25":""},{"location_name":"Lynn Lane","location_id":"11605","lat":"36.1336","long":"-95.7636","pm25":""},{"location_name":"Lynnwood-212th","location_id":"11607","lat":"47.8064","long":"-122.3167","pm25":""},{"location_name":"Lyons","location_id":"11608","lat":"44.778744","long":"-122.61705","pm25":""},{"location_name":"M.K. Goddard","location_id":"11611","lat":"41.4271","long":"-80.1451","pm25":""},{"location_name":"MA","location_id":"11612","lat":"40.712063","long":"-112.11112","pm25":""},{"location_name":"MADISON EAST","location_id":"11613","lat":"43.1008","long":"-89.3572","pm25":""},{"location_name":"MALCANTONE","location_id":"11614","lat":"44.8909","long":"10.3996","pm25":""},{"location_name":"MARION","location_id":"11618","lat":"35.1967","long":"-90.1911","pm25":""},{"location_name":"MARYVILL","location_id":"11622","lat":"38.7267","long":"-89.9592","pm25":""},{"location_name":"MATH & SCIENCE CTR","location_id":"11623","lat":"37.55652","long":"-77.40027","pm25":""},{"location_name":"MCADORY","location_id":"11625","lat":"33.3311","long":"-87.0036","pm25":""},{"location_name":"MENDNHAL","location_id":"11626","lat":"36.109005","long":"-79.802315","pm25":""},{"location_name":"MICMAC","location_id":"11629","lat":"46.6964","long":"-68.0331","pm25":""},{"location_name":"MILITARY PARK","location_id":"11631","lat":"42.312077","long":"-83.10347","pm25":""},{"location_name":"MILWAUKEE 16TH ST","location_id":"11632","lat":"43.0178","long":"-87.9333","pm25":""},{"location_name":"MILWAUKEE SER DNR","location_id":"11634","lat":"43.0611","long":"-87.9125","pm25":""},{"location_name":"MK0030A","location_id":"11635","lat":"42.00361","long":"21.46362","pm25":""},{"location_name":"MK0031A","location_id":"11636","lat":"41.97833","long":"21.47","pm25":""},{"location_name":"MK0034A","location_id":"11637","lat":"41.91389","long":"22.41585","pm25":""},{"location_name":"MK0035A","location_id":"11638","lat":"41.51445","long":"20.95862","pm25":""},{"location_name":"MK0036A","location_id":"11639","lat":"42.13556","long":"21.71474","pm25":""},{"location_name":"MK0037A","location_id":"11640","lat":"41.04","long":"21.3564","pm25":""},{"location_name":"MK0038A","location_id":"11641","lat":"41.03028","long":"21.33667","pm25":""},{"location_name":"MK0040A","location_id":"11642","lat":"41.70583","long":"21.76529","pm25":""},{"location_name":"MK0041A","location_id":"11643","lat":"42.00444","long":"20.96807","pm25":""},{"location_name":"MK0042A","location_id":"11644","lat":"41.53583","long":"20.6989","pm25":""},{"location_name":"MK0043A","location_id":"11645","lat":"41.99917","long":"21.44084","pm25":""},{"location_name":"MK0044A","location_id":"11646","lat":"41.44056","long":"22.00723","pm25":""},{"location_name":"MK0045A","location_id":"11647","lat":"41.98744","long":"21.6525","pm25":""},{"location_name":"MK0047A","location_id":"11648","lat":"41.992","long":"21.423","pm25":""},{"location_name":"MK0048A","location_id":"11649","lat":"42.006","long":"21.387","pm25":""},{"location_name":"MLK","location_id":"11650","lat":"39.7394","long":"-75.5581","pm25":""},{"location_name":"MMCA81006","location_id":"11651","lat":"41.8392","long":"-122.85124","pm25":""},{"location_name":"MMCA81008","location_id":"11652","lat":"38.71376","long":"-120.59104","pm25":""},{"location_name":"MMCA81009","location_id":"11653","lat":"39.40387","long":"-120.19571","pm25":""},{"location_name":"MMCA81010","location_id":"11654","lat":"40.700996","long":"-122.33729","pm25":""},{"location_name":"MMCA81014","location_id":"11656","lat":"35.407936","long":"-120.54662","pm25":""},{"location_name":"MMCA81015","location_id":"11657","lat":"38.61096","long":"-122.86886","pm25":""},{"location_name":"MMCA81017","location_id":"11659","lat":"39.035194","long":"-120.12483","pm25":""},{"location_name":"MMCA81024","location_id":"11661","lat":"41.047035","long":"-123.675156","pm25":""},{"location_name":"MMCA81026","location_id":"11662","lat":"41.528053","long":"-122.3645","pm25":""},{"location_name":"MMCA81030","location_id":"11664","lat":"38.93322","long":"-119.97182","pm25":""},{"location_name":"MMCA81032","location_id":"11665","lat":"38.21148","long":"-122.13297","pm25":""},{"location_name":"MMCA81033","location_id":"11666","lat":"38.80428","long":"-123.018166","pm25":""},{"location_name":"MMCA81036","location_id":"11667","lat":"38.7531","long":"-122.62216","pm25":""},{"location_name":"MMCA81039","location_id":"11668","lat":"35.50349","long":"-119.27255","pm25":""},{"location_name":"MMCA81042","location_id":"11669","lat":"38.510715","long":"-122.80597","pm25":""},{"location_name":"MMCA81046","location_id":"11670","lat":"38.507553","long":"-122.47908","pm25":""},{"location_name":"MMNPS1017","location_id":"11672","lat":"41.426785","long":"-122.38115","pm25":""},{"location_name":"MON","location_id":"11676","lat":"39.988842","long":"-75.20721","pm25":""},{"location_name":"MONROE STERLING ST P","location_id":"11677","lat":"41.92357","long":"-83.345856","pm25":""},{"location_name":"MONTEBELLO","location_id":"11679","lat":"44.7866","long":"10.3365","pm25":""},{"location_name":"MONTG","location_id":"11680","lat":"32.4069","long":"-86.2564","pm25":""},{"location_name":"MT00004","location_id":"11686","lat":"35.85229","long":"14.538986","pm25":""},{"location_name":"MT00005","location_id":"11687","lat":"35.895836","long":"14.489986","pm25":""},{"location_name":"MT00007","location_id":"11688","lat":"36.06707","long":"14.197153","pm25":""},{"location_name":"MT00008","location_id":"11689","lat":"35.89002","long":"14.434464","pm25":""},{"location_name":"MTSP","location_id":"11690","lat":"39.4751","long":"-91.78899","pm25":""},{"location_name":"MUNRO STREET","location_id":"11691","lat":"27.955133","long":"-82.46953","pm25":""},{"location_name":"Maassluis-Kwartellaan","location_id":"11694","lat":"51.932","long":"4.22802","pm25":""},{"location_name":"Maastricht-A2 Kasteel Hillenraadweg","location_id":"11695","lat":"50.8598","long":"5.71381","pm25":""},{"location_name":"Maastricht-A2 Nassaulaan","location_id":"11696","lat":"50.8459","long":"5.71475","pm25":""},{"location_name":"Maastricht-Hoge Fronten","location_id":"11697","lat":"50.8521","long":"5.6758","pm25":""},{"location_name":"Mace Head","location_id":"11698","lat":"53.326443","long":"-9.903917","pm25":""},{"location_name":"Mackville","location_id":"11699","lat":"37.7046","long":"-85.0485","pm25":""},{"location_name":"Macon Forestry","location_id":"11700","lat":"32.8031","long":"-83.5447","pm25":""},{"location_name":"Madawaska PSB","location_id":"11701","lat":"47.3553","long":"-68.3211","pm25":""},{"location_name":"Made","location_id":"11702","lat":"39.464718","long":"-84.40377","pm25":""},{"location_name":"Madera - Pump Yard","location_id":"11703","lat":"36.8669","long":"-120.01","pm25":""},{"location_name":"Madera-City","location_id":"11704","lat":"36.9533","long":"-120.0341","pm25":""},{"location_name":"Madisonville","location_id":"11706","lat":"30.4293","long":"-90.1997","pm25":""},{"location_name":"Madras - Westside Sc","location_id":"11707","lat":"44.6306","long":"-121.1316","pm25":""},{"location_name":"Mae Mo, Mae Mo","location_id":"11708","lat":"18.27968","long":"99.66315","pm25":""},{"location_name":"Magna Grecia","location_id":"11709","lat":"41.883064","long":"12.508939","pm25":""},{"location_name":"Maha Chai, Mueang","location_id":"11710","lat":"13.550478","long":"100.26425","pm25":""},{"location_name":"Makham Tia, Mueang","location_id":"11712","lat":"9.136808","long":"99.32072","pm25":""},{"location_name":"Malagrotta","location_id":"11713","lat":"41.874893","long":"12.345598","pm25":""},{"location_name":"Malta","location_id":"11714","lat":"48.31751","long":"-107.86247","pm25":""},{"location_name":"Mammoth Cave NP","location_id":"11715","lat":"37.1314","long":"-86.1481","pm25":""},{"location_name":"Mammoth Lakes","location_id":"11716","lat":"37.645718","long":"-118.966515","pm25":""},{"location_name":"Manchester Piccadilly","location_id":"11717","lat":"53.48152","long":"-2.237881","pm25":""},{"location_name":"Manchester Sharston","location_id":"11718","lat":"53.371307","long":"-2.239218","pm25":""},{"location_name":"Manglerud","location_id":"11720","lat":"59.89869","long":"10.81495","pm25":""},{"location_name":"Manhattan\/IS143","location_id":"11721","lat":"40.8492","long":"-73.9319","pm25":""},{"location_name":"Manitou Springs","location_id":"11722","lat":"38.853096","long":"-104.90128","pm25":""},{"location_name":"Mannford","location_id":"11723","lat":"36.1053","long":"-96.3608","pm25":""},{"location_name":"Manse","location_id":"11724","lat":"36.212788","long":"-115.994804","pm25":""},{"location_name":"Manteca","location_id":"11725","lat":"37.8027","long":"-121.2208","pm25":""},{"location_name":"Manvel Croix Park C8","location_id":"11726","lat":"29.5203","long":"-95.3925","pm25":""},{"location_name":"Map Ta Phut, Mueang","location_id":"11728","lat":"","long":"","pm25":""},{"location_name":"Maple Falls-Azure Wa","location_id":"11729","lat":"48.9477","long":"-122.1471","pm25":""},{"location_name":"Marcus Hook","location_id":"11731","lat":"39.818714","long":"-75.41397","pm25":""},{"location_name":"Maribor center","location_id":"11732","lat":"46.558838","long":"15.651241","pm25":""},{"location_name":"Maricopa","location_id":"11733","lat":"33.06115","long":"-112.05204","pm25":""},{"location_name":"Maricopa - Stanilaus","location_id":"11734","lat":"35.0544","long":"-119.4039","pm25":""},{"location_name":"Marshall","location_id":"11740","lat":"44.4572","long":"-95.835","pm25":""},{"location_name":"Marysville-7th Ave","location_id":"11744","lat":"48.055","long":"-122.1758","pm25":""},{"location_name":"Maspeth","location_id":"11746","lat":"40.7269","long":"-73.8933","pm25":""},{"location_name":"Mayaguez 59","location_id":"11747","lat":"18.214167","long":"-67.144165","pm25":""},{"location_name":"Mayo Clinic","location_id":"11749","lat":"30.2603","long":"-81.4533","pm25":""},{"location_name":"Ma\u0142ogoszcz, ul. S\u0142oneczna","location_id":"11751","lat":"50.809563","long":"20.2661","pm25":""},{"location_name":"McAlester","location_id":"11752","lat":"34.906082","long":"-95.79413","pm25":""},{"location_name":"McCall","location_id":"11753","lat":"44.890198","long":"-116.1065","pm25":""},{"location_name":"McDonough","location_id":"11754","lat":"33.4347","long":"-84.1617","pm25":""},{"location_name":"McMillan NCORE","location_id":"11755","lat":"38.92185","long":"-77.013176","pm25":""},{"location_name":"Medford Welch & Jack","location_id":"11758","lat":"42.33155","long":"-122.880264","pm25":""},{"location_name":"Melbourne","location_id":"11760","lat":"28.0542","long":"-80.6283","pm25":""},{"location_name":"Meraux","location_id":"11764","lat":"29.94","long":"-89.92","pm25":""},{"location_name":"Merced - S. Coffee A","location_id":"11766","lat":"37.2817","long":"-120.4336","pm25":""},{"location_name":"Mesa - Brooks Reserv","location_id":"11771","lat":"33.4105","long":"-111.8651","pm25":""},{"location_name":"Mesa 2 \/Nipomo","location_id":"11772","lat":"35.02079","long":"-120.56389","pm25":""},{"location_name":"Mesa Verde NP","location_id":"11773","lat":"37.1983","long":"-108.4903","pm25":""},{"location_name":"Mesa-Pepoit Way (tem","location_id":"11774","lat":"46.5754","long":"-119.0021","pm25":""},{"location_name":"Methodist Hill","location_id":"11777","lat":"39.9611","long":"-77.4756","pm25":""},{"location_name":"Miami","location_id":"11780","lat":"36.922222","long":"-94.83889","pm25":""},{"location_name":"Miami Golf Course","location_id":"11783","lat":"33.419018","long":"-110.829666","pm25":""},{"location_name":"Miami Jones Ranch","location_id":"11784","lat":"33.3855","long":"-110.86726","pm25":""},{"location_name":"Miami Town Site","location_id":"11786","lat":"33.397434","long":"-110.87445","pm25":""},{"location_name":"Michigan City-4th St","location_id":"11787","lat":"41.7169","long":"-86.9075","pm25":""},{"location_name":"Middleport","location_id":"11788","lat":"43.2189","long":"-78.4792","pm25":""},{"location_name":"Middlesbrough","location_id":"11789","lat":"54.569298","long":"-1.220874","pm25":""},{"location_name":"Midlothian OFW C52","location_id":"11792","lat":"32.482082","long":"-97.026924","pm25":""},{"location_name":"Mielec-Biernackiego-WIOS","location_id":"11793","lat":"50.29913","long":"21.440943","pm25":""},{"location_name":"Mill Site","location_id":"11797","lat":"36.4581","long":"-117.8519","pm25":""},{"location_name":"Millbrook","location_id":"11798","lat":"41.7856","long":"-73.6947","pm25":""},{"location_name":"Millbrook NCore","location_id":"11799","lat":"35.85611","long":"-78.574165","pm25":""},{"location_name":"Miller State Park","location_id":"11801","lat":"42.86183","long":"-71.878624","pm25":""},{"location_name":"Millington","location_id":"11802","lat":"39.3052","long":"-75.7972","pm25":""},{"location_name":"Millville","location_id":"11803","lat":"39.42227","long":"-75.0252","pm25":""},{"location_name":"Minidoka National Hi","location_id":"11805","lat":"42.68","long":"-114.2525","pm25":""},{"location_name":"Minneapolis - Bottin","location_id":"11806","lat":"45.01361","long":"-93.27205","pm25":""},{"location_name":"Minneapolis-Downtown","location_id":"11807","lat":"44.979","long":"-93.2737","pm25":""},{"location_name":"Minneapolis-Lowry Av","location_id":"11808","lat":"45.0121","long":"-93.276695","pm25":""},{"location_name":"Minneapolis-Near Roa","location_id":"11809","lat":"44.9653","long":"-93.2551","pm25":""},{"location_name":"Minneapolis-Pacific","location_id":"11810","lat":"45.008297","long":"-93.27704","pm25":""},{"location_name":"Minneapolis-Phillips","location_id":"11811","lat":"44.9536","long":"-93.2581","pm25":""},{"location_name":"Minnesundvegen, Gj\u00f8vik","location_id":"11812","lat":"60.79089","long":"10.6967","pm25":""},{"location_name":"Mira Loma - Van Bure","location_id":"11813","lat":"33.996387","long":"-117.4925","pm25":""},{"location_name":"Mission C43","location_id":"11815","lat":"26.226227","long":"-98.29107","pm25":""},{"location_name":"Mission Viejo","location_id":"11816","lat":"33.62999","long":"-117.67587","pm25":""},{"location_name":"Missoula Boyd Park","location_id":"11817","lat":"46.842297","long":"-114.020546","pm25":""},{"location_name":"Mitrovice","location_id":"11818","lat":"42.891792","long":"20.868937","pm25":""},{"location_name":"Mi\u0144sk Mazowiecki-Kazikowskiego","location_id":"11819","lat":"52.178764","long":"21.560968","pm25":""},{"location_name":"Mobile-Pomeroy","location_id":"11820","lat":"46.474438","long":"-117.61476","pm25":""},{"location_name":"Mobile-White Salmon","location_id":"11821","lat":"45.73593","long":"-121.488396","pm25":""},{"location_name":"Modesto - 14th Stree","location_id":"11827","lat":"37.642166","long":"-120.99421","pm25":""},{"location_name":"Mogilno,Ko\u015bciuszki","location_id":"11828","lat":"52.65684","long":"17.949566","pm25":""},{"location_name":"Moheia Vest","location_id":"11830","lat":"66.31219","long":"14.149923","pm25":""},{"location_name":"Mojave - 923 Poole S","location_id":"11832","lat":"35.05045","long":"-118.14778","pm25":""},{"location_name":"Mong Kok","location_id":"11834","lat":"22.3225","long":"114.168335","pm25":""},{"location_name":"Mono Shore","location_id":"11837","lat":"38.0697","long":"-118.9477","pm25":""},{"location_name":"Monroe","location_id":"11838","lat":"32.5097","long":"-92.0461","pm25":""},{"location_name":"Monrovia","location_id":"11839","lat":"39.5756","long":"-86.4778","pm25":""},{"location_name":"Monte Romano","location_id":"11841","lat":"42.268562","long":"11.910914","pm25":""},{"location_name":"Montevallo","location_id":"11843","lat":"33.0928","long":"-86.8072","pm25":""},{"location_name":"Montoursville","location_id":"11844","lat":"41.2508","long":"-76.9239","pm25":""},{"location_name":"Moore","location_id":"11845","lat":"35.32","long":"-97.4883","pm25":""},{"location_name":"Moran","location_id":"11846","lat":"39.4864","long":"-79.0638","pm25":""},{"location_name":"Morro Bay","location_id":"11847","lat":"35.36639","long":"-120.8426","pm25":""},{"location_name":"Moscow","location_id":"11849","lat":"46.7282","long":"-116.9546","pm25":""},{"location_name":"Moses Lake-Balsam St","location_id":"11850","lat":"47.1303","long":"-119.2726","pm25":""},{"location_name":"Moshannon","location_id":"11851","lat":"41.1175","long":"-78.5261","pm25":""},{"location_name":"Mountain View","location_id":"11852","lat":"19.5698","long":"-155.0806","pm25":""},{"location_name":"Moxa Arch","location_id":"11853","lat":"41.7506","long":"-109.7897","pm25":""},{"location_name":"Mt Ninham","location_id":"11856","lat":"41.4561","long":"-73.7103","pm25":""},{"location_name":"Mt Rainier- Jackson","location_id":"11857","lat":"46.7841","long":"-121.7403","pm25":""},{"location_name":"Mt Vernon-2nd Ave","location_id":"11858","lat":"48.4102","long":"-122.3376","pm25":""},{"location_name":"Mud Run","location_id":"11860","lat":"39.85567","long":"-83.99773","pm25":""},{"location_name":"Murphy Ridge","location_id":"11862","lat":"41.3694","long":"-111.0419","pm25":""},{"location_name":"Murska Sobota","location_id":"11863","lat":"46.6525","long":"16.1961","pm25":""},{"location_name":"Muscatine, Greenwood","location_id":"11864","lat":"41.4192","long":"-91.0708","pm25":""},{"location_name":"Muscatine, High Scho","location_id":"11865","lat":"41.4014","long":"-91.0684","pm25":""},{"location_name":"Muscatine, Musser Pa","location_id":"11866","lat":"41.4078","long":"-91.0625","pm25":""},{"location_name":"Myton","location_id":"11870","lat":"40.2169","long":"-110.1823","pm25":""},{"location_name":"NCORE","location_id":"11872","lat":"46.8505","long":"-111.98717","pm25":""},{"location_name":"NCore","location_id":"11873","lat":"64.8458","long":"-147.72726","pm25":""},{"location_name":"NCore - White Mounta","location_id":"11874","lat":"37.360703","long":"-118.33083","pm25":""},{"location_name":"NEA","location_id":"11875","lat":"40.0767","long":"-75.0108","pm25":""},{"location_name":"NEW","location_id":"11876","lat":"39.99139","long":"-75.08083","pm25":""},{"location_name":"NEWKIRK","location_id":"11879","lat":"36.9567","long":"-97.0344","pm25":""},{"location_name":"NEWTWN","location_id":"11881","lat":"38.065","long":"-84.5","pm25":""},{"location_name":"NKU","location_id":"11884","lat":"39.0217","long":"-84.4744","pm25":""},{"location_name":"NLRAP","location_id":"11885","lat":"34.8306","long":"-92.2594","pm25":""},{"location_name":"NMH48217","location_id":"11888","lat":"42.26167","long":"-83.15789","pm25":""},{"location_name":"NO. BHAM","location_id":"11890","lat":"33.5531","long":"-86.815","pm25":""},{"location_name":"NORFOLK - NOAA","location_id":"11891","lat":"36.85555","long":"-76.30135","pm25":""},{"location_name":"NORMAL","location_id":"11892","lat":"40.5169","long":"-88.9975","pm25":""},{"location_name":"NORTHBRK","location_id":"11893","lat":"42.1406","long":"-87.7994","pm25":""},{"location_name":"NR","location_id":"11894","lat":"40.66284","long":"-111.901794","pm25":""},{"location_name":"NR-285","location_id":"11895","lat":"33.698612","long":"-84.272606","pm25":""},{"location_name":"NR-Georgia Tech","location_id":"11896","lat":"33.778316","long":"-84.39142","pm25":""},{"location_name":"Na An, Mueang","location_id":"11898","lat":"13.763936","long":"100.529076","pm25":""},{"location_name":"Na Chak, Mueang","location_id":"11899","lat":"18.12614","long":"100.1654","pm25":""},{"location_name":"Na Mueang, Mueang","location_id":"11900","lat":"13.532555","long":"99.81487","pm25":""},{"location_name":"Na Phra Lan, Chaloem Phra Kiat","location_id":"11901","lat":"14.683085","long":"100.87514","pm25":""},{"location_name":"Nai Wiang, Mueang","location_id":"11902","lat":"","long":"","pm25":""},{"location_name":"Nampa Fire Station","location_id":"11904","lat":"43.58031","long":"-116.562675","pm25":""},{"location_name":"Napa - Napa Valley C","location_id":"11906","lat":"38.27885","long":"-122.275024","pm25":""},{"location_name":"Naperville","location_id":"11907","lat":"41.7714","long":"-88.1522","pm25":""},{"location_name":"Narberth","location_id":"11908","lat":"51.781784","long":"-4.691462","pm25":""},{"location_name":"Narragansett","location_id":"11909","lat":"41.4942","long":"-71.4219","pm25":""},{"location_name":"Navajo Lake","location_id":"11912","lat":"36.8097","long":"-107.6517","pm25":""},{"location_name":"Na\u0142\u0119cz\u00f3wMOB","location_id":"11913","lat":"51.28493","long":"22.210241","pm25":""},{"location_name":"Neah Bay 2-Makah Tri","location_id":"11914","lat":"48.36606","long":"-124.61005","pm25":""},{"location_name":"Near Road","location_id":"11915","lat":"41.829494","long":"-71.41746","pm25":""},{"location_name":"Near Road OKC","location_id":"11916","lat":"35.502968","long":"-97.577675","pm25":""},{"location_name":"Nederland C1035","location_id":"11917","lat":"29.9786","long":"-94.0111","pm25":""},{"location_name":"Nedre Langgate","location_id":"11918","lat":"59.263725","long":"10.411165","pm25":""},{"location_name":"New Albany","location_id":"11921","lat":"38.3081","long":"-85.8342","pm25":""},{"location_name":"New Castle","location_id":"11922","lat":"40.9958","long":"-80.3467","pm25":""},{"location_name":"New Garden","location_id":"11923","lat":"39.8344","long":"-75.7678","pm25":""},{"location_name":"New Haven - Criscuol","location_id":"11924","lat":"41.30129","long":"-72.90269","pm25":""},{"location_name":"New Milford","location_id":"11925","lat":"41.867336","long":"-75.6866","pm25":""},{"location_name":"New Roads","location_id":"11926","lat":"30.6817","long":"-91.3661","pm25":""},{"location_name":"NewCastle","location_id":"11927","lat":"43.8814","long":"-104.1919","pm25":""},{"location_name":"Newark Firehouse","location_id":"11928","lat":"40.72099","long":"-74.192894","pm25":""},{"location_name":"Newburgh","location_id":"11929","lat":"41.4994","long":"-74.0097","pm25":""},{"location_name":"Newcastle Centre","location_id":"11931","lat":"54.97825","long":"-1.610528","pm25":""},{"location_name":"Newcastle Cradlewell Roadside","location_id":"11932","lat":"54.986404","long":"-1.595362","pm25":""},{"location_name":"Newport","location_id":"11934","lat":"51.601204","long":"-2.977281","pm25":""},{"location_name":"Nez Perce Tribe","location_id":"11936","lat":"46.2756","long":"-116.0216","pm25":""},{"location_name":"Nicks Lake","location_id":"11938","lat":"43.6856","long":"-74.9864","pm25":""},{"location_name":"Nijmegen-Graafseweg","location_id":"11940","lat":"51.8414","long":"5.85778","pm25":""},{"location_name":"Nijmegen-Ruyterstraat","location_id":"11941","lat":"51.8382","long":"5.85694","pm25":""},{"location_name":"Niland - English Roa","location_id":"11942","lat":"33.2136","long":"-115.5444","pm25":""},{"location_name":"Nipomo Mesa CDF","location_id":"11943","lat":"35.04676","long":"-120.58777","pm25":""},{"location_name":"Nipomo RP","location_id":"11944","lat":"35.0315","long":"-120.50101","pm25":""},{"location_name":"Nisko-Szklarniowa-WIOS","location_id":"11946","lat":"50.529892","long":"22.112467","pm25":""},{"location_name":"Noblesville-191st St","location_id":"11947","lat":"40.068333","long":"-85.9925","pm25":""},{"location_name":"Noen Phra, Mueang","location_id":"11948","lat":"12.705355","long":"101.18184","pm25":""},{"location_name":"Nogales Post Office","location_id":"11949","lat":"31.337204","long":"-110.93672","pm25":""},{"location_name":"Norristown","location_id":"11951","lat":"40.1122","long":"-75.3092","pm25":""},{"location_name":"North Beach","location_id":"11953","lat":"36.542233","long":"-117.99005","pm25":""},{"location_name":"North Bend-North Ben","location_id":"11954","lat":"47.4902","long":"-121.7727","pm25":""},{"location_name":"North OKC","location_id":"11955","lat":"35.6128","long":"-97.4722","pm25":""},{"location_name":"North Phoenix","location_id":"11956","lat":"33.5603","long":"-112.0663","pm25":""},{"location_name":"North Valley","location_id":"11959","lat":"35.1878","long":"-106.6039","pm25":""},{"location_name":"NorthAdams","location_id":"11960","lat":"42.702225","long":"-73.11041","pm25":""},{"location_name":"Northampton","location_id":"11961","lat":"36.511707","long":"-77.65539","pm25":""},{"location_name":"Northwest Harris Co.","location_id":"11963","lat":"30.0394","long":"-95.6739","pm25":""},{"location_name":"Norwich Lakenfields","location_id":"11965","lat":"52.614193","long":"1.301976","pm25":""},{"location_name":"Nottingham Centre","location_id":"11967","lat":"52.95473","long":"-1.146447","pm25":""},{"location_name":"Nottingham Western Boulevard","location_id":"11968","lat":"52.969376","long":"-1.188851","pm25":""},{"location_name":"Nova Gorica","location_id":"11969","lat":"45.955513","long":"13.652398","pm25":""},{"location_name":"Nowa Ruda - Jeziorna","location_id":"11970","lat":"50.581493","long":"16.498245","pm25":""},{"location_name":"Nowa S\u00f3l, ul. T. Ko\u015bciuszki","location_id":"11972","lat":"51.808662","long":"15.708193","pm25":""},{"location_name":"Nowiny, ul. Parkowa","location_id":"11973","lat":"50.82311","long":"20.533506","pm25":""},{"location_name":"Nowy S\u0105cz, ul. Nadbrze\u017cna","location_id":"11974","lat":"49.61928","long":"20.714403","pm25":""},{"location_name":"Nowy Targ, Plac S\u0142owackiego","location_id":"11975","lat":"49.483597","long":"20.028992","pm25":""},{"location_name":"Nursery Rd.","location_id":"11976","lat":"47.715385","long":"-116.82725","pm25":""},{"location_name":"Nygaardsgata","location_id":"11977","lat":"59.21019","long":"10.940097","pm25":""},{"location_name":"Nysa manualna 3","location_id":"11978","lat":"50.45899","long":"17.331905","pm25":""},{"location_name":"ORGILL","location_id":"11982","lat":"35.3772","long":"-89.8319","pm25":""},{"location_name":"OSTELLATO","location_id":"11984","lat":"44.7409","long":"11.9419","pm25":""},{"location_name":"OWENPRI","location_id":"11986","lat":"37.7808","long":"-87.0756","pm25":""},{"location_name":"Oak Harbor-SW 6th (U","location_id":"11987","lat":"48.2944","long":"-122.66","pm25":""},{"location_name":"Oakland","location_id":"11988","lat":"37.74306","long":"-122.16991","pm25":""},{"location_name":"Oakland West","location_id":"11989","lat":"37.8148","long":"-122.2824","pm25":""},{"location_name":"Oakridge - Willamett","location_id":"11990","lat":"43.74436","long":"-122.48051","pm25":""},{"location_name":"Ocean View","location_id":"11992","lat":"19.117561","long":"-155.77814","pm25":""},{"location_name":"Ogden Dunes","location_id":"11998","lat":"41.6175","long":"-87.1992","pm25":""},{"location_name":"Oildale - 3311 Manor","location_id":"12001","lat":"35.438034","long":"-119.016785","pm25":""},{"location_name":"Ojai - Ojai Ave.","location_id":"12002","lat":"34.4483","long":"-119.2303","pm25":""},{"location_name":"Olancha","location_id":"12003","lat":"36.2676","long":"-117.993","pm25":""},{"location_name":"Olav V gate","location_id":"12004","lat":"67.2755","long":"14.419057","pm25":""},{"location_name":"Oldbury Birmingham Road","location_id":"12005","lat":"52.502438","long":"-2.003497","pm25":""},{"location_name":"Oldtown","location_id":"12006","lat":"39.2981","long":"-76.6047","pm25":""},{"location_name":"Olesno automat 4","location_id":"12007","lat":"50.876984","long":"18.416878","pm25":""},{"location_name":"Om Noi, Krathum Baen","location_id":"12008","lat":"13.705459","long":"100.315674","pm25":""},{"location_name":"Omak-Colville Tribe","location_id":"12009","lat":"48.39999","long":"-119.51896","pm25":""},{"location_name":"Ontario Near Road","location_id":"12011","lat":"34.068115","long":"-117.525795","pm25":""},{"location_name":"Opole automat 5","location_id":"12012","lat":"50.666737","long":"17.899137","pm25":""},{"location_name":"Opole manualna 4","location_id":"12013","lat":"50.676857","long":"17.950277","pm25":""},{"location_name":"Orange Grove","location_id":"12014","lat":"32.322575","long":"-111.03771","pm25":""},{"location_name":"Osceola Co. Fire Sta","location_id":"12017","lat":"28.3478","long":"-81.6367","pm25":""},{"location_name":"Osceola National For","location_id":"12018","lat":"30.1972","long":"-82.445","pm25":""},{"location_name":"Osiecz\u00f3w","location_id":"12019","lat":"51.31763","long":"15.431719","pm25":""},{"location_name":"Otay Mesa - Donovan","location_id":"12020","lat":"32.57936","long":"-116.92949","pm25":""},{"location_name":"Otwock-Brzozowa","location_id":"12021","lat":"52.115726","long":"21.237297","pm25":""},{"location_name":"Oude Meer-Aalsmeerderdijk","location_id":"12022","lat":"52.28","long":"4.77077","pm25":""},{"location_name":"Ouray","location_id":"12023","lat":"40.054848","long":"-109.68737","pm25":""},{"location_name":"Oxford","location_id":"12024","lat":"39.5327","long":"-84.7286","pm25":""},{"location_name":"Oxford Centre Roadside","location_id":"12025","lat":"51.751743","long":"-1.257463","pm25":""},{"location_name":"Oxford St Ebbes","location_id":"12026","lat":"51.744804","long":"-1.260278","pm25":""},{"location_name":"O\u0142awa - \u017bo\u0142nierzy AK","location_id":"12028","lat":"50.942074","long":"17.291332","pm25":""},{"location_name":"P2","location_id":"12029","lat":"39.5958","long":"-110.77","pm25":""},{"location_name":"PARADIGNA","location_id":"12031","lat":"44.8413","long":"10.3446","pm25":""},{"location_name":"PARCO BERTOZZI","location_id":"12032","lat":"44.2856","long":"11.8734","pm25":""},{"location_name":"PARCO EDILCARANI","location_id":"12033","lat":"44.5404","long":"10.7924","pm25":""},{"location_name":"PARCO FERRARI","location_id":"12034","lat":"44.6516","long":"10.9073","pm25":""},{"location_name":"PARCO MONTECUCCO","location_id":"12035","lat":"45.0385","long":"9.6693","pm25":""},{"location_name":"PARCO RESISTENZA","location_id":"12036","lat":"44.2152","long":"12.0482","pm25":""},{"location_name":"PARR","location_id":"12038","lat":"34.7561","long":"-92.2758","pm25":""},{"location_name":"PASCAGOULA","location_id":"12039","lat":"30.3775","long":"-88.5339","pm25":""},{"location_name":"PC South Girard Scho","location_id":"12040","lat":"32.437027","long":"-84.99966","pm25":""},{"location_name":"PECK","location_id":"12041","lat":"37.4769","long":"-97.3664","pm25":""},{"location_name":"PEORIA_H","location_id":"12043","lat":"40.745","long":"-89.5861","pm25":""},{"location_name":"PEORIA_J","location_id":"12044","lat":"40.6978","long":"-89.5889","pm25":""},{"location_name":"Perkinstown","location_id":"12046","lat":"45.2039","long":"-90.6","pm25":""},{"location_name":"PIKE2001","location_id":"12050","lat":"37.4828","long":"-82.5353","pm25":""},{"location_name":"PITTAGCT","location_id":"12051","lat":"35.641277","long":"-77.36012","pm25":""},{"location_name":"POMPANO_BEACH","location_id":"12053","lat":"26.2906","long":"-80.0969","pm25":""},{"location_name":"PORT HURON","location_id":"12054","lat":"42.9533","long":"-82.4564","pm25":""},{"location_name":"PORTA SAN FELICE","location_id":"12055","lat":"44.5","long":"11.3285","pm25":""},{"location_name":"POTAWATOMI","location_id":"12056","lat":"45.5639","long":"-88.81","pm25":""},{"location_name":"Pryor","location_id":"12057","lat":"36.2283","long":"-95.25","pm25":""},{"location_name":"PT01021","location_id":"12059","lat":"41.199722","long":"-8.644722","pm25":""},{"location_name":"PT01023","location_id":"12060","lat":"41.20667","long":"-8.552778","pm25":""},{"location_name":"PT01024","location_id":"12061","lat":"41.235558","long":"-8.618611","pm25":""},{"location_name":"PT01025","location_id":"12062","lat":"41.232224","long":"-8.713056","pm25":""},{"location_name":"PT01028","location_id":"12063","lat":"41.164444","long":"-8.589444","pm25":""},{"location_name":"PT01030","location_id":"12064","lat":"41.18611","long":"-8.663056","pm25":""},{"location_name":"PT01031","location_id":"12065","lat":"41.25222","long":"-8.660556","pm25":""},{"location_name":"PT01034","location_id":"12066","lat":"41.218056","long":"-8.632222","pm25":""},{"location_name":"PT01041","location_id":"12067","lat":"41.54972","long":"-8.405833","pm25":""},{"location_name":"PT01042","location_id":"12068","lat":"41.569443","long":"-8.456944","pm25":""},{"location_name":"PT01043","location_id":"12069","lat":"41.2075","long":"-8.338056","pm25":""},{"location_name":"PT01044","location_id":"12070","lat":"41.274166","long":"-8.376111","pm25":""},{"location_name":"PT01046","location_id":"12071","lat":"41.449722","long":"-8.296389","pm25":""},{"location_name":"PT01047","location_id":"12072","lat":"41.802223","long":"-8.693889","pm25":""},{"location_name":"PT01048","location_id":"12073","lat":"41.371387","long":"-7.790833","pm25":""},{"location_name":"PT01050","location_id":"12074","lat":"41.1475","long":"-8.658889","pm25":""},{"location_name":"PT01051","location_id":"12075","lat":"41.308613","long":"-8.720833","pm25":""},{"location_name":"PT01052","location_id":"12076","lat":"41.18778","long":"-8.672222","pm25":""},{"location_name":"PT01053","location_id":"12077","lat":"41.09667","long":"-8.555833","pm25":""},{"location_name":"PT01054","location_id":"12078","lat":"40.999443","long":"-8.623333","pm25":""},{"location_name":"PT01055","location_id":"12079","lat":"41.18778","long":"-8.671944","pm25":""},{"location_name":"PT02004","location_id":"12080","lat":"40.756668","long":"-8.572778","pm25":""},{"location_name":"PT02006","location_id":"12081","lat":"40.21472","long":"-8.401667","pm25":""},{"location_name":"PT02016","location_id":"12082","lat":"40.206944","long":"-8.410833","pm25":""},{"location_name":"PT02017","location_id":"12083","lat":"40.635555","long":"-8.646667","pm25":""},{"location_name":"PT02018","location_id":"12084","lat":"40.58972","long":"-8.670556","pm25":""},{"location_name":"PT02019","location_id":"12085","lat":"39.92389","long":"-8.891667","pm25":""},{"location_name":"PT02020","location_id":"12086","lat":"40.233055","long":"-7.301944","pm25":""},{"location_name":"PT02021","location_id":"12087","lat":"40.64111","long":"-8.100556","pm25":""},{"location_name":"PT03055","location_id":"12089","lat":"38.666668","long":"-9.047778","pm25":""},{"location_name":"PT03063","location_id":"12090","lat":"38.619446","long":"-9.081111","pm25":""},{"location_name":"PT03070","location_id":"12091","lat":"38.894722","long":"-9.1175","pm25":""},{"location_name":"PT03071","location_id":"12092","lat":"38.76889","long":"-9.108056","pm25":""},{"location_name":"PT03072","location_id":"12093","lat":"38.74861","long":"-9.148889","pm25":""},{"location_name":"PT03075","location_id":"12094","lat":"38.72028","long":"-9.145833","pm25":""},{"location_name":"PT03082","location_id":"12095","lat":"38.738888","long":"-9.2075","pm25":""},{"location_name":"PT03083","location_id":"12096","lat":"38.663612","long":"-9.157778","pm25":""},{"location_name":"PT03084","location_id":"12097","lat":"38.754166","long":"-9.230833","pm25":""},{"location_name":"PT03085","location_id":"12098","lat":"38.829723","long":"-9.164444","pm25":""},{"location_name":"PT03087","location_id":"12099","lat":"38.705","long":"-9.210278","pm25":""},{"location_name":"PT03089","location_id":"12100","lat":"38.785","long":"-9.347222","pm25":""},{"location_name":"PT03091","location_id":"12101","lat":"38.6975","long":"-9.323333","pm25":""},{"location_name":"PT03093","location_id":"12102","lat":"38.529167","long":"-8.894167","pm25":""},{"location_name":"PT03094","location_id":"12103","lat":"38.524166","long":"-8.894167","pm25":""},{"location_name":"PT03095","location_id":"12104","lat":"38.65861","long":"-9.066944","pm25":""},{"location_name":"PT03096","location_id":"12105","lat":"39.3525","long":"-8.466111","pm25":""},{"location_name":"PT03097","location_id":"12106","lat":"38.802223","long":"-9.182222","pm25":""},{"location_name":"PT03099","location_id":"12107","lat":"38.635555","long":"-8.690556","pm25":""},{"location_name":"PT03100","location_id":"12108","lat":"38.748055","long":"-9.2025","pm25":""},{"location_name":"PT03101","location_id":"12109","lat":"38.89611","long":"-9.040278","pm25":""},{"location_name":"PT03102","location_id":"12110","lat":"39.27833","long":"-9.245556","pm25":""},{"location_name":"PT03103","location_id":"12111","lat":"38.65","long":"-9.048611","pm25":""},{"location_name":"PT03104","location_id":"12112","lat":"38.70139","long":"-9.429444","pm25":""},{"location_name":"PT04001","location_id":"12113","lat":"37.954166","long":"-8.838056","pm25":""},{"location_name":"PT04002","location_id":"12114","lat":"38.076942","long":"-8.798611","pm25":""},{"location_name":"PT04003","location_id":"12115","lat":"37.871113","long":"-8.723889","pm25":""},{"location_name":"PT04004","location_id":"12116","lat":"38.02","long":"-8.6975","pm25":""},{"location_name":"PT04006","location_id":"12117","lat":"38.615","long":"-7.3975","pm25":""},{"location_name":"PT05007","location_id":"12118","lat":"37.015","long":"-7.926667","pm25":""},{"location_name":"PT05008","location_id":"12119","lat":"37.091667","long":"-8.249722","pm25":""},{"location_name":"PT05011","location_id":"12120","lat":"37.138332","long":"-8.542222","pm25":""},{"location_name":"PT05012","location_id":"12121","lat":"37.3125","long":"-7.678611","pm25":""},{"location_name":"PT06004","location_id":"12122","lat":"32.648888","long":"-16.883057","pm25":""},{"location_name":"PT06005","location_id":"12123","lat":"32.649723","long":"-16.918333","pm25":""},{"location_name":"PT06008","location_id":"12124","lat":"32.807777","long":"-16.886389","pm25":""},{"location_name":"PT07001","location_id":"12125","lat":"38.605","long":"-28.63139","pm25":""},{"location_name":"PUBLIC HEALTH","location_id":"12126","lat":"41.9767","long":"-91.6878","pm25":""},{"location_name":"Pabianice-Polfa","location_id":"12131","lat":"51.66798","long":"19.368683","pm25":""},{"location_name":"Padonia","location_id":"12133","lat":"39.462","long":"-76.6316","pm25":""},{"location_name":"Pahala","location_id":"12134","lat":"19.2065","long":"-155.4689","pm25":""},{"location_name":"Painesville - JFS","location_id":"12136","lat":"41.72681","long":"-81.24216","pm25":""},{"location_name":"Pak Nam Pho, Mueang","location_id":"12137","lat":"15.707849","long":"100.13193","pm25":""},{"location_name":"Pak Nam, Mueang","location_id":"12138","lat":"","long":"","pm25":""},{"location_name":"Pak Phriao, Mueang","location_id":"12139","lat":"14.523537","long":"100.92917","pm25":""},{"location_name":"Palatka","location_id":"12141","lat":"29.686666","long":"-81.65639","pm25":""},{"location_name":"Palisade Ozone","location_id":"12142","lat":"39.1306","long":"-108.3139","pm25":""},{"location_name":"Palm Springs - Fire","location_id":"12143","lat":"33.852604","long":"-116.54096","pm25":""},{"location_name":"Palo Duro","location_id":"12145","lat":"34.8803","long":"-101.6649","pm25":""},{"location_name":"Palo Verde","location_id":"12146","lat":"36.173416","long":"-115.332726","pm25":""},{"location_name":"Paonia","location_id":"12148","lat":"38.8763","long":"-107.6022","pm25":""},{"location_name":"Paradise - Airport","location_id":"12149","lat":"39.708454","long":"-121.61731","pm25":""},{"location_name":"Paradise Road","location_id":"12150","lat":"34.5414","long":"-119.7906","pm25":""},{"location_name":"Paradise Theater","location_id":"12151","lat":"39.77919","long":"-121.59135","pm25":""},{"location_name":"Parker County C76","location_id":"12153","lat":"32.8686","long":"-97.9058","pm25":""},{"location_name":"Parkgate (Eagle Rive","location_id":"12154","lat":"61.3267","long":"-149.5697","pm25":""},{"location_name":"Parklane","location_id":"12155","lat":"34.0939","long":"-80.9622","pm25":""},{"location_name":"Parkway East (Near R","location_id":"12156","lat":"40.43743","long":"-79.86357","pm25":""},{"location_name":"Parlier","location_id":"12157","lat":"36.5975","long":"-119.5036","pm25":""},{"location_name":"Parsons","location_id":"12158","lat":"39.0905","long":"-79.6617","pm25":""},{"location_name":"Parzniewice","location_id":"12159","lat":"51.291176","long":"19.517555","pm25":""},{"location_name":"Pasadena","location_id":"12160","lat":"34.13263","long":"-118.127144","pm25":""},{"location_name":"Paso Robles - Santa","location_id":"12162","lat":"35.61467","long":"-120.65691","pm25":""},{"location_name":"Paul Meyer","location_id":"12167","lat":"36.106388","long":"-115.253334","pm25":""},{"location_name":"Paul Spur Chemical L","location_id":"12169","lat":"31.3658","long":"-109.7309","pm25":""},{"location_name":"Paw Park","location_id":"12170","lat":"27.3503","long":"-82.4797","pm25":""},{"location_name":"Payson Well Site","location_id":"12173","lat":"34.22934","long":"-111.3297","pm25":""},{"location_name":"Pearl City","location_id":"12174","lat":"21.392834","long":"-157.96913","pm25":""},{"location_name":"Peckville","location_id":"12175","lat":"41.4789","long":"-75.5781","pm25":""},{"location_name":"Peebles","location_id":"12178","lat":"55.65747","long":"-3.196527","pm25":""},{"location_name":"Peje","location_id":"12179","lat":"42.65969","long":"20.284597","pm25":""},{"location_name":"Pembroke Exchange St","location_id":"12180","lat":"43.13246","long":"-71.458244","pm25":""},{"location_name":"Pendleton - McKay Cr","location_id":"12181","lat":"45.65223","long":"-118.82304","pm25":""},{"location_name":"Penn State","location_id":"12182","lat":"40.7208","long":"-77.9319","pm25":""},{"location_name":"Pensacola NAS","location_id":"12184","lat":"30.3681","long":"-87.2708","pm25":""},{"location_name":"Pepsi Place","location_id":"12185","lat":"30.262808","long":"-81.606834","pm25":""},{"location_name":"Perch River","location_id":"12186","lat":"44.0878","long":"-75.9744","pm25":""},{"location_name":"Perdue","location_id":"12187","lat":"25.5864","long":"-80.3269","pm25":""},{"location_name":"Perimeter","location_id":"12188","lat":"25.785473","long":"-80.2842","pm25":""},{"location_name":"Perris","location_id":"12190","lat":"33.78933","long":"-117.22764","pm25":""},{"location_name":"Peshawar","location_id":"12191","lat":"34.00585","long":"71.53775","pm25":""},{"location_name":"Petrified Forest NP","location_id":"12192","lat":"34.8225","long":"-109.8919","pm25":""},{"location_name":"Pfizer Lab","location_id":"12193","lat":"40.868","long":"-73.8782","pm25":""},{"location_name":"Phaya Thai, Khet Phaya Thai","location_id":"12195","lat":"13.780444","long":"100.537796","pm25":""},{"location_name":"Phelan - Beekley Roa","location_id":"12196","lat":"34.425053","long":"-117.58981","pm25":""},{"location_name":"Philippine-Stelleweg","location_id":"12197","lat":"51.2945","long":"3.74948","pm25":""},{"location_name":"Phoenix JLG Supersit","location_id":"12198","lat":"33.5036","long":"-112.095","pm25":""},{"location_name":"Phora Durbar Kathman","location_id":"12199","lat":"27.712463","long":"85.315704","pm25":""},{"location_name":"Phra Bat, Mueang","location_id":"12200","lat":"18.286776","long":"99.50632","pm25":""},{"location_name":"Piaski-Krzyzowka","location_id":"12201","lat":"52.50139","long":"17.773464","pm25":""},{"location_name":"Piast\u00f3w-Pu\u0142askiego","location_id":"12202","lat":"52.191727","long":"20.837488","pm25":""},{"location_name":"Pico Rivera","location_id":"12203","lat":"34.010284","long":"-118.06848","pm25":""},{"location_name":"Pierre","location_id":"12204","lat":"44.373787","long":"-100.28727","pm25":""},{"location_name":"Pila, ul. Kusocinkiego","location_id":"12206","lat":"53.154408","long":"16.759571","pm25":""},{"location_name":"Pilot Point C1032","location_id":"12207","lat":"33.4107","long":"-96.9437","pm25":""},{"location_name":"Pinal Air Park","location_id":"12208","lat":"32.50831","long":"-111.30806","pm25":""},{"location_name":"Pinal County Housing","location_id":"12209","lat":"32.891056","long":"-111.5705","pm25":""},{"location_name":"Pinedale","location_id":"12210","lat":"42.8698","long":"-109.8708","pm25":""},{"location_name":"Pinedale Gaseous","location_id":"12211","lat":"42.8698","long":"-109.8708","pm25":""},{"location_name":"Pinehurst","location_id":"12212","lat":"47.536713","long":"-116.23687","pm25":""},{"location_name":"Piney Run","location_id":"12213","lat":"39.7058","long":"-79.0119","pm25":""},{"location_name":"Pinnacle Peak Club H","location_id":"12214","lat":"33.7123","long":"-111.8527","pm25":""},{"location_name":"Pinnacle State Park","location_id":"12215","lat":"42.0972","long":"-77.2103","pm25":""},{"location_name":"Pinnacles NM","location_id":"12216","lat":"36.485","long":"-121.1556","pm25":""},{"location_name":"Piotrk\u00f3w Tryb.-Krakowskie Przedmie\u015bcie","location_id":"12217","lat":"51.404408","long":"19.696957","pm25":""},{"location_name":"Piru - Pacific","location_id":"12218","lat":"34.4044","long":"-118.81","pm25":""},{"location_name":"Piseco Lake","location_id":"12219","lat":"43.4556","long":"-74.515","pm25":""},{"location_name":"PittsfieldES","location_id":"12222","lat":"42.453033","long":"-73.23878","pm25":""},{"location_name":"Placerville","location_id":"12223","lat":"38.72528","long":"-120.82192","pm25":""},{"location_name":"Pleasanton - Owens C","location_id":"12225","lat":"37.70122","long":"-121.90302","pm25":""},{"location_name":"Pleszew, Al. Mickiewicza","location_id":"12226","lat":"51.884922","long":"17.791105","pm25":""},{"location_name":"Pluak Daeng, Pluak Daeng","location_id":"12227","lat":"12.97378","long":"101.212845","pm25":""},{"location_name":"Plummer","location_id":"12229","lat":"38.9856","long":"-86.99","pm25":""},{"location_name":"Plummer CDA Tribe","location_id":"12230","lat":"47.3386","long":"-116.8859","pm25":""},{"location_name":"Plymouth Centre","location_id":"12231","lat":"50.37167","long":"-4.142361","pm25":""},{"location_name":"Pocatello Garrett an","location_id":"12235","lat":"42.8767","long":"-112.4603","pm25":""},{"location_name":"Pocatello STP","location_id":"12236","lat":"42.9164","long":"-112.5158","pm25":""},{"location_name":"Polson-MT","location_id":"12238","lat":"47.6925","long":"-114.0122","pm25":""},{"location_name":"Pomona","location_id":"12240","lat":"34.0667","long":"-117.7506","pm25":""},{"location_name":"Ponca City","location_id":"12241","lat":"36.69719","long":"-97.081276","pm25":""},{"location_name":"Port Allen","location_id":"12243","lat":"30.5019","long":"-91.2111","pm25":""},{"location_name":"Port Angeles-E 5th S","location_id":"12244","lat":"48.115","long":"-123.43643","pm25":""},{"location_name":"Port Arthur West C28","location_id":"12245","lat":"29.8942","long":"-93.9875","pm25":""},{"location_name":"Port Manatee","location_id":"12247","lat":"27.63861","long":"-82.547775","pm25":""},{"location_name":"Port Talbot Margam","location_id":"12249","lat":"51.58395","long":"-3.770822","pm25":""},{"location_name":"Port Townsend-San Ju","location_id":"12250","lat":"48.1291","long":"-122.7789","pm25":""},{"location_name":"Portage-Hwy 12","location_id":"12252","lat":"41.6167","long":"-87.1458","pm25":""},{"location_name":"Porterville-NFS","location_id":"12253","lat":"36.0319","long":"-119.055","pm25":""},{"location_name":"Portland - Deering O","location_id":"12255","lat":"43.660248","long":"-70.26897","pm25":""},{"location_name":"Portland - SE Lafaye","location_id":"12256","lat":"45.49664","long":"-122.602875","pm25":""},{"location_name":"Portland - Sauvie Is","location_id":"12257","lat":"45.76853","long":"-122.7721","pm25":""},{"location_name":"Portland Near Road","location_id":"12259","lat":"45.39916","long":"-122.7455","pm25":""},{"location_name":"Portola","location_id":"12260","lat":"39.808334","long":"-120.471664","pm25":""},{"location_name":"Portsmouth","location_id":"12261","lat":"43.07537","long":"-70.74802","pm25":""},{"location_name":"Posterholt-Vlodropperweg","location_id":"12263","lat":"51.1192","long":"6.0424","pm25":""},{"location_name":"Potato Creek State P","location_id":"12265","lat":"41.5517","long":"-86.3706","pm25":""},{"location_name":"Potosi","location_id":"12267","lat":"42.69213","long":"-90.69637","pm25":""},{"location_name":"Poznan-Dabrowskiego","location_id":"12268","lat":"52.42032","long":"16.877289","pm25":""},{"location_name":"Poznan-Polanka","location_id":"12269","lat":"52.398174","long":"16.959518","pm25":""},{"location_name":"Pozna\u0144 - RatajeMOB","location_id":"12270","lat":"52.391727","long":"16.998577","pm25":""},{"location_name":"Po\u0142aniec, ul. Ruszcza\u0144ska","location_id":"12271","lat":"50.429012","long":"21.277367","pm25":""},{"location_name":"Pratu Chai, Phra Nakhon Si Ayutthayal","location_id":"12273","lat":"14.349367","long":"100.568535","pm25":""},{"location_name":"Preble County","location_id":"12274","lat":"39.83562","long":"-84.72049","pm25":""},{"location_name":"Preneste","location_id":"12275","lat":"41.886017","long":"12.541614","pm25":""},{"location_name":"Prescott Pioneer Par","location_id":"12277","lat":"34.61205","long":"-112.46321","pm25":""},{"location_name":"Presque Isle Riversi","location_id":"12278","lat":"46.6823","long":"-68.0162","pm25":""},{"location_name":"Prestebakke","location_id":"12279","lat":"58.99677","long":"11.52769","pm25":""},{"location_name":"Preston","location_id":"12280","lat":"53.76559","long":"-2.680353","pm25":""},{"location_name":"Preston PM25 BAM","location_id":"12281","lat":"42.082222","long":"-111.86417","pm25":""},{"location_name":"Pride","location_id":"12283","lat":"30.7008","long":"-91.0561","pm25":""},{"location_name":"Prince Edward","location_id":"12284","lat":"37.17","long":"-78.31","pm25":""},{"location_name":"Prineville - Davidso","location_id":"12285","lat":"44.299786","long":"-120.84477","pm25":""},{"location_name":"Prishtine - IHMK","location_id":"12286","lat":"42.648872","long":"21.137121","pm25":""},{"location_name":"Prishtine, Rilindje","location_id":"12287","lat":"42.659657","long":"21.157309","pm25":""},{"location_name":"Pristina","location_id":"12288","lat":"42.661995","long":"21.15055","pm25":""},{"location_name":"Prizren","location_id":"12289","lat":"42.21586","long":"20.741556","pm25":""},{"location_name":"Prudnik mobilna","location_id":"12292","lat":"50.320858","long":"17.59191","pm25":""},{"location_name":"Przemysl-Grunwaldzka-WIOS","location_id":"12293","lat":"49.78434","long":"22.756239","pm25":""},{"location_name":"Pubpla, Wang Thonglang","location_id":"12294","lat":"13.76963","long":"100.61456","pm25":""},{"location_name":"Pullman-Dexter Ave","location_id":"12296","lat":"46.7245","long":"-117.1801","pm25":""},{"location_name":"Puyallup-128th St","location_id":"12298","lat":"47.1405","long":"-122.2992","pm25":""},{"location_name":"Pu\u0142awy ul. Karpi\u0144skiego","location_id":"12300","lat":"51.41905","long":"21.961088","pm25":""},{"location_name":"P\u0142ock-Gimnazjum","location_id":"12301","lat":"52.55628","long":"19.687672","pm25":""},{"location_name":"P\u0142ock-Reja","location_id":"12302","lat":"52.550938","long":"19.709791","pm25":""},{"location_name":"Quaker City","location_id":"12304","lat":"39.9428","long":"-81.3373","pm25":""},{"location_name":"Queen Valley","location_id":"12305","lat":"33.2894","long":"-111.2928","pm25":""},{"location_name":"Queens","location_id":"12306","lat":"40.7375","long":"-73.8244","pm25":""},{"location_name":"Queens Near-road","location_id":"12307","lat":"40.739265","long":"-73.817696","pm25":""},{"location_name":"Quincy 3rd","location_id":"12308","lat":"47.24126","long":"-119.84595","pm25":""},{"location_name":"Quincy BAM","location_id":"12309","lat":"39.9369","long":"-120.9478","pm25":""},{"location_name":"REMESINA","location_id":"12311","lat":"44.8004","long":"10.8843","pm25":""},{"location_name":"RG_SOUTH","location_id":"12312","lat":"38.75961","long":"-94.57983","pm25":""},{"location_name":"RHINELANDER","location_id":"12313","lat":"45.6453","long":"-89.4125","pm25":""},{"location_name":"RIT","location_id":"12314","lat":"39.922516","long":"-75.18678","pm25":""},{"location_name":"RIVER_Terrace","location_id":"12315","lat":"38.895683","long":"-76.95809","pm25":""},{"location_name":"ROCKWELL","location_id":"12316","lat":"35.55187","long":"-80.39504","pm25":""},{"location_name":"ROCK_IS","location_id":"12317","lat":"41.5144","long":"-90.5172","pm25":""},{"location_name":"ROLAND","location_id":"12319","lat":"35.40814","long":"-94.524414","pm25":""},{"location_name":"ROMA","location_id":"12320","lat":"44.216","long":"12.0575","pm25":""},{"location_name":"RS0030A","location_id":"12323","lat":"43.31655","long":"21.913548","pm25":""},{"location_name":"RS0031A","location_id":"12324","lat":"45.238644","long":"19.835705","pm25":""},{"location_name":"RS0032A","location_id":"12325","lat":"44.82112","long":"20.459112","pm25":""},{"location_name":"RS0033A","location_id":"12326","lat":"43.322556","long":"21.919025","pm25":""},{"location_name":"RS0034A","location_id":"12327","lat":"45.821484","long":"20.454008","pm25":""},{"location_name":"RS0036A","location_id":"12328","lat":"44.80318","long":"20.400152","pm25":""},{"location_name":"RT","location_id":"12329","lat":"36.139706","long":"-115.17565","pm25":""},{"location_name":"RUTLAND","location_id":"12331","lat":"43.60853","long":"-72.98246","pm25":""},{"location_name":"Racib\u00f3rz, Wojska Polskiego 8","location_id":"12332","lat":"50.09114","long":"18.21626","pm25":""},{"location_name":"Radom-Tochtermana","location_id":"12334","lat":"51.399082","long":"21.147474","pm25":""},{"location_name":"Radomsko-Rolna2","location_id":"12335","lat":"51.06744","long":"19.448694","pm25":""},{"location_name":"Rahway PM","location_id":"12336","lat":"40.603943","long":"-74.27618","pm25":""},{"location_name":"Rama IV Rd., Pathum Wan","location_id":"12338","lat":"13.72983","long":"100.53649","pm25":""},{"location_name":"Rambergan","location_id":"12340","lat":"69.65428","long":"18.95636","pm25":""},{"location_name":"Ranchos","location_id":"12341","lat":"38.89761","long":"-119.7321","pm25":""},{"location_name":"Rangely, CO","location_id":"12342","lat":"40.08694","long":"-108.761","pm25":""},{"location_name":"Raymond-4th St","location_id":"12344","lat":"46.688217","long":"-123.731766","pm25":""},{"location_name":"Reading Airport","location_id":"12345","lat":"40.3833","long":"-75.9686","pm25":""},{"location_name":"Reading New Town","location_id":"12347","lat":"51.45309","long":"-0.944067","pm25":""},{"location_name":"Red Bluff - Walnut o","location_id":"12348","lat":"40.170918","long":"-122.25567","pm25":""},{"location_name":"Red Lake Nation","location_id":"12349","lat":"47.87816","long":"-95.029175","pm25":""},{"location_name":"Red Mountain","location_id":"12350","lat":"33.5079","long":"-111.7546","pm25":""},{"location_name":"Redding","location_id":"12351","lat":"40.5497","long":"-122.3792","pm25":""},{"location_name":"Redhills\/Shandon","location_id":"12352","lat":"35.64366","long":"-120.23134","pm25":""},{"location_name":"Redlands - Dearborn","location_id":"12353","lat":"34.059628","long":"-117.14735","pm25":""},{"location_name":"Redwash","location_id":"12354","lat":"40.204433","long":"-109.35321","pm25":""},{"location_name":"Redwood City","location_id":"12355","lat":"37.4828","long":"-122.2022","pm25":""},{"location_name":"Remount","location_id":"12357","lat":"35.21317","long":"-80.874084","pm25":""},{"location_name":"Reno3","location_id":"12359","lat":"39.52507","long":"-119.80775","pm25":""},{"location_name":"Research Farm","location_id":"12360","lat":"44.348602","long":"-96.8073","pm25":""},{"location_name":"Reseda","location_id":"12361","lat":"34.1992","long":"-118.5331","pm25":""},{"location_name":"Residence for Dept. of Primary Industries and Mines","location_id":"12362","lat":"13.652157","long":"100.53184","pm25":""},{"location_name":"Richmond - 7th St","location_id":"12365","lat":"37.9478","long":"-122.3636","pm25":""},{"location_name":"Ridderkerk-Hogeweg","location_id":"12366","lat":"51.8694","long":"4.58006","pm25":""},{"location_name":"Rider Trail I-70","location_id":"12367","lat":"38.75264","long":"-90.44884","pm25":""},{"location_name":"Rider University","location_id":"12368","lat":"40.283092","long":"-74.742645","pm25":""},{"location_name":"Rieti 1","location_id":"12369","lat":"42.404095","long":"12.858224","pm25":""},{"location_name":"Rifle Ozone","location_id":"12370","lat":"39.5418","long":"-107.7841","pm25":""},{"location_name":"Rifle Particulate","location_id":"12371","lat":"39.5318","long":"-107.7823","pm25":""},{"location_name":"Rillito","location_id":"12372","lat":"32.41434","long":"-111.15454","pm25":""},{"location_name":"Ringsakervegen","location_id":"12374","lat":"60.88593","long":"10.93785","pm25":""},{"location_name":"Rio Vista","location_id":"12377","lat":"38.2183","long":"-121.77","pm25":""},{"location_name":"Ritzville-Alder St","location_id":"12378","lat":"47.128","long":"-118.3819","pm25":""},{"location_name":"Riverside","location_id":"12380","lat":"35.0508","long":"-85.2931","pm25":""},{"location_name":"Riverside - Rubidoux","location_id":"12381","lat":"33.99945","long":"-117.41583","pm25":""},{"location_name":"Riviera Beach","location_id":"12382","lat":"39.158882","long":"-76.51137","pm25":""},{"location_name":"Roanoke Elem. School","location_id":"12383","lat":"40.9606","long":"-85.3803","pm25":""},{"location_name":"Rochester","location_id":"12384","lat":"43.1461","long":"-77.5481","pm25":""},{"location_name":"Rochester Stoke","location_id":"12385","lat":"51.45617","long":"0.634889","pm25":""},{"location_name":"Rockford","location_id":"12386","lat":"42.267002","long":"-89.08917","pm25":""},{"location_name":"Rockingham","location_id":"12387","lat":"38.4772","long":"-78.8167","pm25":""},{"location_name":"Rockland Cty","location_id":"12388","lat":"41.18208","long":"-74.02819","pm25":""},{"location_name":"Rockville","location_id":"12389","lat":"39.1144","long":"-77.1069","pm25":""},{"location_name":"Rockwall Heath C69","location_id":"12390","lat":"32.9361","long":"-96.4592","pm25":""},{"location_name":"Rocky Flats - N - 16","location_id":"12392","lat":"39.9128","long":"-105.1883","pm25":""},{"location_name":"Rocky Mountain NP","location_id":"12393","lat":"40.2778","long":"-105.5453","pm25":""},{"location_name":"Rolland, \u00c5sane","location_id":"12394","lat":"60.462666","long":"5.332447","pm25":""},{"location_name":"Rome","location_id":"12395","lat":"34.26054","long":"-85.32333","pm25":""},{"location_name":"Rome-Kraftsman","location_id":"12396","lat":"34.243645","long":"-85.32595","pm25":""},{"location_name":"Roosvelt","location_id":"12399","lat":"40.2943","long":"-110.009","pm25":""},{"location_name":"Rosalia-Josephine St","location_id":"12400","lat":"47.2313","long":"-117.3685","pm25":""},{"location_name":"Rose Elementary","location_id":"12401","lat":"32.1731","long":"-110.9797","pm25":""},{"location_name":"Rose Park","location_id":"12402","lat":"40.7955","long":"-111.9309","pm25":""},{"location_name":"Roseburg - Garden Va","location_id":"12403","lat":"43.2266","long":"-123.36479","pm25":""},{"location_name":"Rosenstiel","location_id":"12404","lat":"25.7325","long":"-80.1622","pm25":""},{"location_name":"Roseville - N.Sunris","location_id":"12405","lat":"38.74643","long":"-121.26498","pm25":""},{"location_name":"Rossiter Pump House","location_id":"12407","lat":"46.6588","long":"-112.0131","pm25":""},{"location_name":"Rossville","location_id":"12408","lat":"34.9789","long":"-85.3009","pm25":""},{"location_name":"Rotterdam Noord -Statenweg","location_id":"12409","lat":"51.9271","long":"4.46134","pm25":""},{"location_name":"Rotterdam Zuid-Pleinweg","location_id":"12410","lat":"51.8911","long":"4.48069","pm25":""},{"location_name":"Rotterdam Zuid-Zwartewaalstraat","location_id":"12411","lat":"51.8936","long":"4.48753","pm25":""},{"location_name":"Rotterdam-Oost Sidelinge A13","location_id":"12412","lat":"51.9385","long":"4.43069","pm25":""},{"location_name":"Rotterdam-Schiedamsevest","location_id":"12413","lat":"51.9142","long":"4.47992","pm25":""},{"location_name":"Rte 9 Del. City","location_id":"12416","lat":"39.595","long":"-75.611","pm25":""},{"location_name":"Rutgers University","location_id":"12418","lat":"40.46218","long":"-74.429436","pm25":""},{"location_name":"Rv 4, Aker sykehus","location_id":"12419","lat":"59.94103","long":"10.79803","pm25":""},{"location_name":"Rybnik, ul. Borki 37 d","location_id":"12420","lat":"50.11118","long":"18.516138","pm25":""},{"location_name":"Ryman\u00f3w-Zdr\u00f3j-Samorz\u0105d","location_id":"12421","lat":"49.54654","long":"21.851006","pm25":""},{"location_name":"Rzesz\u00f3w-Nowe Miasto","location_id":"12422","lat":"50.024242","long":"22.010574","pm25":""},{"location_name":"Rzesz\u00f3w-Pi\u0142sudskiego","location_id":"12423","lat":"50.040676","long":"22.004656","pm25":""},{"location_name":"R\u00e5dal","location_id":"12424","lat":"60.29427","long":"5.324619","pm25":""},{"location_name":"S. LAZZARO","location_id":"12426","lat":"44.689","long":"10.6636","pm25":""},{"location_name":"S. ROCCO","location_id":"12427","lat":"44.8737","long":"10.6648","pm25":""},{"location_name":"S.Agostino","location_id":"12428","lat":"42.159946","long":"11.742631","pm25":""},{"location_name":"S.Gordiano","location_id":"12429","lat":"42.07361","long":"11.815916","pm25":""},{"location_name":"SAN CLEMENTE","location_id":"12433","lat":"43.9318","long":"12.6273","pm25":""},{"location_name":"SAN FRANCESCO","location_id":"12434","lat":"44.5422","long":"10.8199","pm25":""},{"location_name":"SAN LAZZARO","location_id":"12436","lat":"44.4672","long":"11.4166","pm25":""},{"location_name":"SAN LEO","location_id":"12437","lat":"43.9072","long":"12.4012","pm25":""},{"location_name":"SAN PIETRO CAPOFIUME","location_id":"12439","lat":"44.6542","long":"11.6248","pm25":""},{"location_name":"SAND ISLAND 2 - ANUE","location_id":"12440","lat":"21.3039","long":"-157.8711","pm25":""},{"location_name":"SARAGAT","location_id":"12442","lat":"44.926","long":"10.3719","pm25":""},{"location_name":"SAVIGNANO","location_id":"12445","lat":"44.0969","long":"12.4033","pm25":""},{"location_name":"SAVIGNANO DI RIGO","location_id":"12446","lat":"43.9274","long":"12.2248","pm25":""},{"location_name":"SEAFORD","location_id":"12449","lat":"38.6444","long":"-75.6131","pm25":""},{"location_name":"SENEY","location_id":"12450","lat":"46.2889","long":"-85.9503","pm25":""},{"location_name":"SETRPC 40 Sabine Pas","location_id":"12451","lat":"29.7181","long":"-93.8969","pm25":""},{"location_name":"SETRPC 43 Jefferson","location_id":"12452","lat":"29.9425","long":"-94.0006","pm25":""},{"location_name":"SHELBY FARMS","location_id":"12456","lat":"35.15159","long":"-89.85022","pm25":""},{"location_name":"SHIRLEY PLANTATION","location_id":"12458","lat":"37.3419","long":"-77.2608","pm25":""},{"location_name":"SIMMONS PARK","location_id":"12459","lat":"27.7403","long":"-82.4656","pm25":""},{"location_name":"SK0001A","location_id":"12461","lat":"48.12502","long":"17.12561","pm25":""},{"location_name":"SK0002A","location_id":"12462","lat":"48.15843","long":"17.128677","pm25":""},{"location_name":"SK0002R","location_id":"12463","lat":"48.942223","long":"19.592232","pm25":""},{"location_name":"SK0004A","location_id":"12464","lat":"48.144733","long":"17.113619","pm25":""},{"location_name":"SK0004R","location_id":"12465","lat":"49.15278","long":"20.291117","pm25":""},{"location_name":"SK0006R","location_id":"12466","lat":"49.04222","long":"22.259731","pm25":""},{"location_name":"SK0007R","location_id":"12467","lat":"47.96","long":"17.860563","pm25":""},{"location_name":"SK0008A","location_id":"12468","lat":"49.079166","long":"19.302525","pm25":""},{"location_name":"SK0013A","location_id":"12469","lat":"48.666946","long":"18.530848","pm25":""},{"location_name":"SK0016A","location_id":"12470","lat":"48.755","long":"21.246122","pm25":""},{"location_name":"SK0018A","location_id":"12471","lat":"48.59222","long":"21.175285","pm25":""},{"location_name":"SK0020A","location_id":"12472","lat":"49.211945","long":"18.771114","pm25":""},{"location_name":"SK0021A","location_id":"12473","lat":"48.680557","long":"17.363344","pm25":""},{"location_name":"SK0022A","location_id":"12474","lat":"48.58361","long":"19.951685","pm25":""},{"location_name":"SK0025A","location_id":"12475","lat":"48.63111","long":"20.240284","pm25":""},{"location_name":"SK0027A","location_id":"12476","lat":"48.733055","long":"18.756395","pm25":""},{"location_name":"SK0030A","location_id":"12477","lat":"48.874165","long":"21.837503","pm25":""},{"location_name":"SK0031A","location_id":"12478","lat":"48.88639","long":"21.687502","pm25":""},{"location_name":"SK0037A","location_id":"12479","lat":"48.930836","long":"21.913622","pm25":""},{"location_name":"SK0039A","location_id":"12480","lat":"49.066944","long":"18.921947","pm25":""},{"location_name":"SK0041A","location_id":"12481","lat":"49.066666","long":"20.25","pm25":""},{"location_name":"SK0042A","location_id":"12482","lat":"48.783333","long":"20.992231","pm25":""},{"location_name":"SK0045A","location_id":"12483","lat":"48.37111","long":"17.585018","pm25":""},{"location_name":"SK0047A","location_id":"12484","lat":"48.89639","long":"18.041393","pm25":""},{"location_name":"SK0048A","location_id":"12485","lat":"48.166668","long":"17.116667","pm25":""},{"location_name":"SK0050A","location_id":"12486","lat":"48.782654","long":"18.62808","pm25":""},{"location_name":"SK0134A","location_id":"12487","lat":"48.28305","long":"18.14112","pm25":""},{"location_name":"SK0214A","location_id":"12488","lat":"48.735","long":"19.154999","pm25":""},{"location_name":"SK0262A","location_id":"12489","lat":"48.558056","long":"19.156668","pm25":""},{"location_name":"SK0263A","location_id":"12490","lat":"48.733334","long":"19.115278","pm25":""},{"location_name":"SK0264A","location_id":"12491","lat":"48.691113","long":"21.286388","pm25":""},{"location_name":"SK0265A","location_id":"12492","lat":"48.915558","long":"20.42389","pm25":""},{"location_name":"SK0266A","location_id":"12493","lat":"48.993332","long":"21.2675","pm25":""},{"location_name":"SK0267A","location_id":"12494","lat":"48.72627","long":"21.258837","pm25":""},{"location_name":"SK0268A","location_id":"12495","lat":"48.59956","long":"18.84246","pm25":""},{"location_name":"SK0269A","location_id":"12496","lat":"48.309456","long":"18.076832","pm25":""},{"location_name":"SK0406A","location_id":"12497","lat":"48.935","long":"22.27361","pm25":""},{"location_name":"SK0407A","location_id":"12498","lat":"48.43667","long":"17.019722","pm25":""},{"location_name":"SMITHLD","location_id":"12501","lat":"37.1556","long":"-88.3931","pm25":""},{"location_name":"South Fayette","location_id":"12504","lat":"40.3819","long":"-80.1856","pm25":""},{"location_name":"SPABC14 COBACH","location_id":"12505","lat":"32.6336","long":"-115.5042","pm25":""},{"location_name":"SPRINGFIELDSP","location_id":"12517","lat":"42.120247","long":"-72.58499","pm25":""},{"location_name":"SPRNGDLE","location_id":"12519","lat":"36.1797","long":"-94.1167","pm25":""},{"location_name":"STILWELL CASTNET & N","location_id":"12522","lat":"35.7506","long":"-94.6697","pm25":""},{"location_name":"Sacaton","location_id":"12525","lat":"33.08","long":"-111.739296","pm25":""},{"location_name":"Saguaro Monument","location_id":"12527","lat":"32.1764","long":"-110.7378","pm25":""},{"location_name":"Salamonie Reservoir","location_id":"12528","lat":"40.816","long":"-85.6611","pm25":""},{"location_name":"Salem - State Hospit","location_id":"12529","lat":"44.943115","long":"-123.005936","pm25":""},{"location_name":"Salford Eccles","location_id":"12530","lat":"53.48481","long":"-2.334139","pm25":""},{"location_name":"Salladasburg","location_id":"12532","lat":"41.266193","long":"-77.230934","pm25":""},{"location_name":"Salmon PM2.5","location_id":"12533","lat":"45.1787","long":"-113.893","pm25":""},{"location_name":"Saltash Callington Road","location_id":"12534","lat":"50.411465","long":"-4.227678","pm25":""},{"location_name":"Samae Dam, Bang Khun Thian","location_id":"12535","lat":"13.668461","long":"100.50581","pm25":""},{"location_name":"San Andreas","location_id":"12537","lat":"38.20185","long":"-120.680275","pm25":""},{"location_name":"San Antonio","location_id":"12538","lat":"28.3322","long":"-82.3056","pm25":""},{"location_name":"San Antonio Northwes","location_id":"12539","lat":"29.515","long":"-98.62","pm25":""},{"location_name":"San Antonio Old Hwy9","location_id":"12540","lat":"29.423933","long":"-98.580505","pm25":""},{"location_name":"San Antonio Palo Alt","location_id":"12541","lat":"29.332804","long":"-98.5514","pm25":""},{"location_name":"San Bernadino - 4th","location_id":"12543","lat":"34.106678","long":"-117.27406","pm25":""},{"location_name":"San Diego - Kearny V","location_id":"12545","lat":"32.845467","long":"-117.12389","pm25":""},{"location_name":"San Diego - Sherman","location_id":"12546","lat":"32.71018","long":"-117.14266","pm25":""},{"location_name":"San Francisco","location_id":"12547","lat":"37.7658","long":"-122.3978","pm25":""},{"location_name":"San Jose","location_id":"12549","lat":"9.949488","long":"-84.142876","pm25":""},{"location_name":"San Jose - Jackson S","location_id":"12550","lat":"37.3483","long":"-121.8947","pm25":""},{"location_name":"San Jose - Knox Ave","location_id":"12551","lat":"37.338203","long":"-121.84989","pm25":""},{"location_name":"San Luis Obispo - Hi","location_id":"12552","lat":"35.25651","long":"-120.6693","pm25":""},{"location_name":"San Luis Rio Colorad","location_id":"12553","lat":"32.4667","long":"-114.76876","pm25":""},{"location_name":"San Martin","location_id":"12554","lat":"37.0792","long":"-121.5994","pm25":""},{"location_name":"San Pablo - Rumrill","location_id":"12557","lat":"37.9604","long":"-122.3571","pm25":""},{"location_name":"San Rafael","location_id":"12558","lat":"37.9722","long":"-122.5189","pm25":""},{"location_name":"San Ramon","location_id":"12559","lat":"37.74365","long":"-121.93419","pm25":""},{"location_name":"Sandcut","location_id":"12561","lat":"39.5642","long":"-87.3253","pm25":""},{"location_name":"Sandhill","location_id":"12562","lat":"34.1311","long":"-80.8683","pm25":""},{"location_name":"Sandpoint U of I","location_id":"12563","lat":"48.29182","long":"-116.55656","pm25":""},{"location_name":"Sandve","location_id":"12564","lat":"59.19722","long":"5.20148","pm25":""},{"location_name":"Sandy Roadside","location_id":"12565","lat":"52.132416","long":"-0.300306","pm25":""},{"location_name":"Santa Barbara","location_id":"12566","lat":"34.4278","long":"-119.6903","pm25":""},{"location_name":"Santa Clarita","location_id":"12569","lat":"34.3833","long":"-118.5283","pm25":""},{"location_name":"Santa Fe Airport","location_id":"12572","lat":"35.6198","long":"-106.0797","pm25":""},{"location_name":"Santa Maria - Broadw","location_id":"12573","lat":"34.94287","long":"-120.43561","pm25":""},{"location_name":"Santa Teresa","location_id":"12575","lat":"31.7878","long":"-106.6828","pm25":""},{"location_name":"Santa Ynez","location_id":"12576","lat":"34.60582","long":"-120.07506","pm25":""},{"location_name":"Santee Sioux","location_id":"12577","lat":"42.8292","long":"-97.8541","pm25":""},{"location_name":"Saratoga BAM","location_id":"12579","lat":"41.452133","long":"-106.81393","pm25":""},{"location_name":"Sateng, Mueang","location_id":"12581","lat":"6.549994","long":"101.28","pm25":""},{"location_name":"Saul Martinez","location_id":"12582","lat":"33.572018","long":"-116.06382","pm25":""},{"location_name":"Savannah East Presid","location_id":"12583","lat":"32.0683","long":"-81.0489","pm25":""},{"location_name":"Savannah L&A","location_id":"12584","lat":"32.0903","long":"-81.1306","pm25":""},{"location_name":"Savannahs","location_id":"12585","lat":"27.38908","long":"-80.311035","pm25":""},{"location_name":"Sawgrass Lake Park","location_id":"12586","lat":"27.83441","long":"-82.66525","pm25":""},{"location_name":"Schancheholen","location_id":"12587","lat":"58.951878","long":"5.721875","pm25":""},{"location_name":"Schiedam-Alphons Arienstraat","location_id":"12588","lat":"51.9214","long":"4.40139","pm25":""},{"location_name":"Scranton","location_id":"12591","lat":"41.4428","long":"-75.6231","pm25":""},{"location_name":"Scunthorpe Town","location_id":"12592","lat":"53.58634","long":"-0.636811","pm25":""},{"location_name":"Seabrook Friendship","location_id":"12593","lat":"29.5831","long":"-95.0156","pm25":""},{"location_name":"Seattle-10th & Welle","location_id":"12595","lat":"47.59722","long":"-122.319725","pm25":""},{"location_name":"Seattle-Beacon Hill","location_id":"12596","lat":"47.568237","long":"-122.308624","pm25":""},{"location_name":"Seattle-Duwamish","location_id":"12597","lat":"47.562","long":"-122.3405","pm25":""},{"location_name":"Seattle-South Park","location_id":"12598","lat":"47.5309","long":"-122.3208","pm25":""},{"location_name":"Sebastopol","location_id":"12599","lat":"38.403767","long":"-122.81829","pm25":""},{"location_name":"Sedgwick","location_id":"12600","lat":"37.8975","long":"-97.49207","pm25":""},{"location_name":"Seeley Elementary Sc","location_id":"12601","lat":"47.17563","long":"-113.47618","pm25":""},{"location_name":"Seiling","location_id":"12602","lat":"36.1589","long":"-98.9353","pm25":""},{"location_name":"Seljestad Rv83","location_id":"12604","lat":"68.79223","long":"16.537424","pm25":""},{"location_name":"Seminole Community C","location_id":"12608","lat":"28.7456","long":"-81.31","pm25":""},{"location_name":"Semora DRR","location_id":"12609","lat":"36.489944","long":"-79.058525","pm25":""},{"location_name":"Senior Center","location_id":"12610","lat":"33.4883","long":"-111.855","pm25":""},{"location_name":"Sentrum","location_id":"12611","lat":"68.435394","long":"17.42489","pm25":""},{"location_name":"Sequoia and Kings Ca","location_id":"12612","lat":"36.4894","long":"-118.8269","pm25":""},{"location_name":"Sha Tin","location_id":"12613","lat":"22.376389","long":"114.18445","pm25":""},{"location_name":"Shady Cove - Shady C","location_id":"12614","lat":"42.623226","long":"-122.81016","pm25":""},{"location_name":"Shadyside PSD","location_id":"12615","lat":"39.9679","long":"-80.7464","pm25":""},{"location_name":"Shafter - Walker Str","location_id":"12616","lat":"35.50349","long":"-119.27264","pm25":""},{"location_name":"Shakopee","location_id":"12617","lat":"44.7894","long":"-93.5125","pm25":""},{"location_name":"Sham Shui Po","location_id":"12618","lat":"22.330278","long":"114.159164","pm25":""},{"location_name":"Shasta Lake City","location_id":"12620","lat":"40.6894","long":"-122.4024","pm25":""},{"location_name":"Shaw Crompton Way","location_id":"12621","lat":"53.579285","long":"-2.093786","pm25":""},{"location_name":"Sheffield Barnsley Road","location_id":"12623","lat":"53.40495","long":"-1.455815","pm25":""},{"location_name":"Sheffield Devonshire Green","location_id":"12624","lat":"53.37862","long":"-1.478096","pm25":""},{"location_name":"Sheffield Elementary","location_id":"12625","lat":"30.4758","long":"-81.5869","pm25":""},{"location_name":"Sheffield Tinsley","location_id":"12626","lat":"53.41058","long":"-1.396139","pm25":""},{"location_name":"Sheldon Station","location_id":"12628","lat":"40.55476","long":"-96.78035","pm25":""},{"location_name":"Shelton-W Franklin","location_id":"12629","lat":"47.21355","long":"-123.10081","pm25":""},{"location_name":"Shenandoah NP","location_id":"12630","lat":"38.5231","long":"-78.4347","pm25":""},{"location_name":"Sheridan","location_id":"12631","lat":"44.934","long":"-106.8472","pm25":""},{"location_name":"Sheridan PD","location_id":"12633","lat":"44.815144","long":"-106.95593","pm25":""},{"location_name":"Shoshone Bannock Tri","location_id":"12635","lat":"42.589832","long":"-112.458885","pm25":""},{"location_name":"Shreveport Airport","location_id":"12636","lat":"32.5364","long":"-93.7492","pm25":""},{"location_name":"Shuttlesworth","location_id":"12637","lat":"33.565277","long":"-86.79639","pm25":""},{"location_name":"Si Phum, Mueang","location_id":"12638","lat":"18.791092","long":"98.98866","pm25":""},{"location_name":"Si Racha, Si Racha","location_id":"12639","lat":"13.173601","long":"100.9277","pm25":""},{"location_name":"Sibton","location_id":"12640","lat":"52.2944","long":"1.463497","pm25":""},{"location_name":"Sidney 201","location_id":"12641","lat":"47.8679","long":"-104.676865","pm25":""},{"location_name":"Siedlce-Konarskiego","location_id":"12643","lat":"52.172146","long":"22.282001","pm25":""},{"location_name":"Sikes Elementary Sch","location_id":"12644","lat":"27.94","long":"-82.0003","pm25":""},{"location_name":"Simi Valley - Cochra","location_id":"12647","lat":"34.2775","long":"-118.6847","pm25":""},{"location_name":"Sinclair In-Town","location_id":"12649","lat":"41.78237","long":"-107.12083","pm25":""},{"location_name":"Sioux Falls","location_id":"12651","lat":"43.54792","long":"-96.70077","pm25":""},{"location_name":"Sipayik-ME","location_id":"12652","lat":"44.9636","long":"-67.0608","pm25":""},{"location_name":"Sisters Forest Servi","location_id":"12653","lat":"44.2921","long":"-121.5555","pm25":""},{"location_name":"Skar\u017cysko-Kamienna, MOBILNA","location_id":"12654","lat":"51.1211","long":"20.88063","pm25":""},{"location_name":"Skawina, os. Ogrody","location_id":"12655","lat":"49.971046","long":"19.830421","pm25":""},{"location_name":"Skiatook","location_id":"12656","lat":"36.35586","long":"-96.01243","pm25":""},{"location_name":"Skyland DRR","location_id":"12657","lat":"35.48186","long":"-82.509865","pm25":""},{"location_name":"Skyland Drive","location_id":"12658","lat":"36.52102","long":"-82.516304","pm25":""},{"location_name":"Skyline Park C72","location_id":"12659","lat":"31.893888","long":"-106.42555","pm25":""},{"location_name":"Sk\u00f8yen","location_id":"12660","lat":"59.91975","long":"10.68973","pm25":""},{"location_name":"Sloughhouse","location_id":"12661","lat":"38.494476","long":"-121.21113","pm25":""},{"location_name":"Smestad","location_id":"12662","lat":"59.93255","long":"10.66984","pm25":""},{"location_name":"Smithfield","location_id":"12663","lat":"41.842777","long":"-111.85194","pm25":""},{"location_name":"Smolary Bytnickie","location_id":"12664","lat":"52.172222","long":"15.206667","pm25":""},{"location_name":"Socorro Hueco C49","location_id":"12665","lat":"31.66752","long":"-106.28774","pm25":""},{"location_name":"Soda Springs Monsant","location_id":"12666","lat":"42.6953","long":"-111.5939","pm25":""},{"location_name":"Soda Springs PM25","location_id":"12667","lat":"42.65167","long":"-111.61472","pm25":""},{"location_name":"Sofienbergparken","location_id":"12669","lat":"59.92295","long":"10.76573","pm25":""},{"location_name":"Solano Drive","location_id":"12670","lat":"32.3169","long":"-106.7669","pm25":""},{"location_name":"Solheim","location_id":"12672","lat":"59.92861","long":"10.953203","pm25":""},{"location_name":"Song Khanong, Phra Pradaeng","location_id":"12674","lat":"13.664026","long":"100.5434","pm25":""},{"location_name":"Sonora - Barretta St","location_id":"12676","lat":"37.98178","long":"-120.37855","pm25":""},{"location_name":"Sop Pat, Mae Mo","location_id":"12677","lat":"18.247768","long":"99.76689","pm25":""},{"location_name":"Sosnowiec, ul. Lubelska 51","location_id":"12679","lat":"50.285957","long":"19.184399","pm25":""},{"location_name":"South Bend-Shields D","location_id":"12681","lat":"41.6967","long":"-86.2147","pm25":""},{"location_name":"South DeKalb","location_id":"12683","lat":"33.6906","long":"-84.2731","pm25":""},{"location_name":"South Lake Tahoe - S","location_id":"12684","lat":"38.94498","long":"-119.97061","pm25":""},{"location_name":"South Long Beach","location_id":"12685","lat":"33.79222","long":"-118.17528","pm25":""},{"location_name":"South Pass","location_id":"12686","lat":"42.5275","long":"-108.7203","pm25":""},{"location_name":"South Phoenix","location_id":"12687","lat":"33.4033","long":"-112.0731","pm25":""},{"location_name":"South Reno","location_id":"12688","lat":"39.469227","long":"-119.77539","pm25":""},{"location_name":"South Scottsdale","location_id":"12689","lat":"33.4797","long":"-111.9172","pm25":""},{"location_name":"South Tucson","location_id":"12690","lat":"32.20215","long":"-110.96792","pm25":""},{"location_name":"South Valley","location_id":"12691","lat":"35.0186","long":"-106.6519","pm25":""},{"location_name":"Southampton A33","location_id":"12692","lat":"50.920265","long":"-1.463484","pm25":""},{"location_name":"Southampton Centre","location_id":"12693","lat":"50.90814","long":"-1.395778","pm25":""},{"location_name":"Southend-on-Sea","location_id":"12694","lat":"51.544205","long":"0.678408","pm25":""},{"location_name":"Southport DRR","location_id":"12696","lat":"33.942223","long":"-78.019165","pm25":""},{"location_name":"Southwark A2 Old Kent Road","location_id":"12698","lat":"51.4805","long":"-0.05955","pm25":""},{"location_name":"Spanish Fork","location_id":"12700","lat":"40.1364","long":"-111.6602","pm25":""},{"location_name":"Spanish Springs","location_id":"12701","lat":"39.621464","long":"-119.718735","pm25":""},{"location_name":"Sparks","location_id":"12702","lat":"39.54092","long":"-119.746765","pm25":""},{"location_name":"Speedwell","location_id":"12703","lat":"36.47","long":"-83.83","pm25":""},{"location_name":"Spokane-Augusta Ave","location_id":"12705","lat":"47.6725","long":"-117.3649","pm25":""},{"location_name":"Spokane-E Broadway A","location_id":"12706","lat":"47.663963","long":"-117.25765","pm25":""},{"location_name":"Spokane-Monroe St.","location_id":"12708","lat":"47.6997","long":"-117.4263","pm25":""},{"location_name":"Springfield Ag","location_id":"12710","lat":"39.83192","long":"-89.644165","pm25":""},{"location_name":"Springfield City Hal","location_id":"12711","lat":"44.046684","long":"-123.01774","pm25":""},{"location_name":"Springfield PM","location_id":"12712","lat":"39.92882","long":"-83.80949","pm25":""},{"location_name":"Springville","location_id":"12713","lat":"36.1358","long":"-118.8108","pm25":""},{"location_name":"Spruce Pine","location_id":"12714","lat":"35.912487","long":"-82.06208","pm25":""},{"location_name":"St Helens Linkway","location_id":"12715","lat":"53.451824","long":"-2.742134","pm25":""},{"location_name":"St Osyth","location_id":"12716","lat":"51.77798","long":"1.049031","pm25":""},{"location_name":"St Regis Mohawk-NY","location_id":"12718","lat":"44.9806","long":"-74.6953","pm25":""},{"location_name":"St Theodosius","location_id":"12719","lat":"41.477013","long":"-81.68238","pm25":""},{"location_name":"St. Andrews Park","location_id":"12720","lat":"30.1289","long":"-85.7381","pm25":""},{"location_name":"St. Cloud","location_id":"12722","lat":"45.55","long":"-94.1333","pm25":""},{"location_name":"St. Joseph","location_id":"12723","lat":"39.74167","long":"-94.85833","pm25":""},{"location_name":"St. Lukes Meridian","location_id":"12724","lat":"43.6007","long":"-116.347855","pm25":""},{"location_name":"St. Maries","location_id":"12725","lat":"47.3167","long":"-116.5703","pm25":""},{"location_name":"St. Marks Wildlife R","location_id":"12726","lat":"30.0842","long":"-84.1617","pm25":""},{"location_name":"St. Martinville","location_id":"12727","lat":"30.008886","long":"-91.8696","pm25":""},{"location_name":"St. Michael","location_id":"12728","lat":"45.2108","long":"-93.6686","pm25":""},{"location_name":"St. Paul - Downtown","location_id":"12729","lat":"44.9507","long":"-93.0985","pm25":""},{"location_name":"St. Paul-Harding H.S","location_id":"12730","lat":"44.9594","long":"-93.0356","pm25":""},{"location_name":"St. Petersburg Colle","location_id":"12732","lat":"27.9711","long":"-82.7361","pm25":""},{"location_name":"St. Philips","location_id":"12733","lat":"38.0053","long":"-87.7183","pm25":""},{"location_name":"St.Croix","location_id":"12734","lat":"59.2103","long":"10.9454","pm25":""},{"location_name":"StJohns","location_id":"12735","lat":"33.29015","long":"-112.159874","pm25":""},{"location_name":"Stanfield","location_id":"12738","lat":"32.881195","long":"-111.962","pm25":""},{"location_name":"Stanford-le-Hope Roadside","location_id":"12739","lat":"51.518166","long":"0.439548","pm25":""},{"location_name":"Starachowice, ul. Z\u0142ota","location_id":"12741","lat":"51.05061","long":"21.084175","pm25":""},{"location_name":"State College","location_id":"12742","lat":"40.8114","long":"-77.8769","pm25":""},{"location_name":"Station 160 North","location_id":"12743","lat":"36.34435","long":"-79.81614","pm25":""},{"location_name":"Stener Heyerdahl","location_id":"12746","lat":"58.14888","long":"7.99183","pm25":""},{"location_name":"Steubenville","location_id":"12747","lat":"40.36645","long":"-80.61569","pm25":""},{"location_name":"Stillwater","location_id":"12748","lat":"43.0122","long":"-73.6492","pm25":""},{"location_name":"Stockton","location_id":"12749","lat":"42.2869","long":"-89.9997","pm25":""},{"location_name":"Stockton - Hazelton","location_id":"12750","lat":"37.95075","long":"-121.26897","pm25":""},{"location_name":"Stockton-on-Tees A1305 Roadside","location_id":"12751","lat":"54.56582","long":"-1.3159","pm25":""},{"location_name":"Stockton-on-Tees Eaglescliffe","location_id":"12752","lat":"54.516666","long":"-1.358547","pm25":""},{"location_name":"Stoke-on-Trent A50 Roadside","location_id":"12753","lat":"52.980434","long":"-2.111898","pm25":""},{"location_name":"Stoke-on-Trent Centre","location_id":"12754","lat":"53.02821","long":"-2.175133","pm25":""},{"location_name":"Storrington Roadside","location_id":"12755","lat":"50.91693","long":"-0.449548","pm25":""},{"location_name":"Strathvaich","location_id":"12757","lat":"57.734455","long":"-4.776583","pm25":""},{"location_name":"Strongstown","location_id":"12758","lat":"40.5633","long":"-78.92","pm25":""},{"location_name":"Substation","location_id":"12759","lat":"36.7969","long":"-108.4725","pm25":""},{"location_name":"Sucha Beskidzka, ul. Nieszczy\u0144skiej","location_id":"12760","lat":"49.74313","long":"19.60034","pm25":""},{"location_name":"Sul\u0119cin ul. Dudka","location_id":"12765","lat":"52.43772","long":"15.122444","pm25":""},{"location_name":"Sumatra","location_id":"12766","lat":"30.1103","long":"-84.9903","pm25":""},{"location_name":"Sunderland Silksworth","location_id":"12768","lat":"54.88361","long":"-1.406878","pm25":""},{"location_name":"Sunderland Wessington Way","location_id":"12769","lat":"54.91839","long":"-1.408391","pm25":""},{"location_name":"Sunnyside-S 16th","location_id":"12770","lat":"46.32033","long":"-119.9981","pm25":""},{"location_name":"Sunrise Acres","location_id":"12771","lat":"36.163963","long":"-115.11393","pm25":""},{"location_name":"Suwa\u0142ki, ul. Pu\u0142askiego 26","location_id":"12774","lat":"54.116055","long":"22.93875","pm25":""},{"location_name":"Svanvik","location_id":"12775","lat":"69.45505","long":"30.04075","pm25":""},{"location_name":"Swansea Roadside","location_id":"12778","lat":"51.632694","long":"-3.947374","pm25":""},{"location_name":"Sweet Home - Fire De","location_id":"12779","lat":"44.3958","long":"-122.7305","pm25":""},{"location_name":"Swiftwater","location_id":"12780","lat":"41.0831","long":"-75.3283","pm25":""},{"location_name":"Sycamore","location_id":"12781","lat":"39.2787","long":"-84.36612","pm25":""},{"location_name":"Szar\u00f3w, ul. Spokojna","location_id":"12783","lat":"50.0075","long":"20.259167","pm25":""},{"location_name":"Szczecin_Andrzejewskiego","location_id":"12784","lat":"53.380974","long":"14.663347","pm25":""},{"location_name":"Szczecin_Budzysza Wosia","location_id":"12785","lat":"53.447","long":"14.508","pm25":""},{"location_name":"Szczecin_Pi\u0142sudskiego","location_id":"12786","lat":"53.43217","long":"14.5539","pm25":""},{"location_name":"Szczecinek_Przemys\u0142owa","location_id":"12788","lat":"53.6989","long":"16.704573","pm25":""},{"location_name":"Szymbark","location_id":"12789","lat":"49.633713","long":"21.116833","pm25":""},{"location_name":"TAIT CUMMINS","location_id":"12793","lat":"41.94867","long":"-91.63954","pm25":""},{"location_name":"TECUMSEH","location_id":"12795","lat":"41.9956","long":"-83.9467","pm25":""},{"location_name":"TIMAVO","location_id":"12798","lat":"44.6996","long":"10.6228","pm25":""},{"location_name":"TK Gregg","location_id":"12799","lat":"34.9556","long":"-81.9248","pm25":""},{"location_name":"TOR","location_id":"12800","lat":"40.054173","long":"-74.98517","pm25":""},{"location_name":"TRINITY ST MARKS","location_id":"12802","lat":"42.295822","long":"-83.12943","pm25":""},{"location_name":"TROUT LAKE","location_id":"12803","lat":"46.0481","long":"-89.6536","pm25":""},{"location_name":"TRURO","location_id":"12804","lat":"41.9756","long":"-70.0239","pm25":""},{"location_name":"Tacoma-Alexander Ave","location_id":"12807","lat":"47.2656","long":"-122.3858","pm25":""},{"location_name":"Tacoma-L St","location_id":"12808","lat":"47.1864","long":"-122.4517","pm25":""},{"location_name":"Tacoma-S 36th St","location_id":"12809","lat":"47.22634","long":"-122.46256","pm25":""},{"location_name":"Taft","location_id":"12810","lat":"39.12886","long":"-84.50404","pm25":""},{"location_name":"Tahoe City","location_id":"12811","lat":"39.166","long":"-120.1488","pm25":""},{"location_name":"Taholah-Quinault Tri","location_id":"12812","lat":"47.3398","long":"-124.2918","pm25":""},{"location_name":"Tai Po","location_id":"12813","lat":"22.450834","long":"114.164444","pm25":""},{"location_name":"TakomaRec","location_id":"12814","lat":"38.9701","long":"-77.016716","pm25":""},{"location_name":"Talat Yai, Mueang","location_id":"12815","lat":"7.881636","long":"98.39429","pm25":""},{"location_name":"Tallahassee Communit","location_id":"12817","lat":"30.4397","long":"-84.3483","pm25":""},{"location_name":"Tangerine & Camino d","location_id":"12818","lat":"32.4253","long":"-111.0669","pm25":""},{"location_name":"Taos Fire Station","location_id":"12819","lat":"36.3833","long":"-105.5833","pm25":""},{"location_name":"Tap Mun","location_id":"12820","lat":"22.47139","long":"114.36083","pm25":""},{"location_name":"Tarn\u00f3w, ul. Bitwy pod Studziankami","location_id":"12822","lat":"50.02017","long":"21.004168","pm25":""},{"location_name":"Tarn\u00f3w, ul. Ks. Romana Sitko","location_id":"12823","lat":"50.018253","long":"20.992579","pm25":""},{"location_name":"Taylorsville Liledou","location_id":"12825","lat":"35.9138","long":"-81.191","pm25":""},{"location_name":"Temecula (Lake Skinn","location_id":"12828","lat":"33.5831","long":"-117.0722","pm25":""},{"location_name":"Tempe","location_id":"12829","lat":"33.4124","long":"-111.9347","pm25":""},{"location_name":"Temple Georgia C1045","location_id":"12830","lat":"31.122526","long":"-97.43116","pm25":""},{"location_name":"Terre Haute-Lafayett","location_id":"12831","lat":"39.4861","long":"-87.4014","pm25":""},{"location_name":"Tha Pradu, Mueng","location_id":"12835","lat":"12.680919","long":"101.273575","pm25":""},{"location_name":"The Dalles - Cherry","location_id":"12836","lat":"45.60242","long":"-121.203384","pm25":""},{"location_name":"Theodore Roosevelt N","location_id":"12838","lat":"46.9497","long":"-103.5144","pm25":""},{"location_name":"Thibodaux","location_id":"12839","lat":"29.7639","long":"-90.7653","pm25":""},{"location_name":"Thirty Third","location_id":"12840","lat":"33.461807","long":"-112.128044","pm25":""},{"location_name":"Thompson Falls HS","location_id":"12842","lat":"47.594395","long":"-115.323746","pm25":""},{"location_name":"Thousand Oaks - Moor","location_id":"12843","lat":"34.21","long":"-118.8694","pm25":""},{"location_name":"Thunder Basin","location_id":"12844","lat":"44.6633","long":"-105.2875","pm25":""},{"location_name":"Thung Sukhla, Si Racha","location_id":"12845","lat":"13.119234","long":"100.9185","pm25":""},{"location_name":"Thurrock","location_id":"12846","lat":"51.47707","long":"0.317969","pm25":""},{"location_name":"Tiburtina","location_id":"12847","lat":"41.910255","long":"12.54887","pm25":""},{"location_name":"Timpanogos Cave","location_id":"12848","lat":"40.44194","long":"-111.71341","pm25":""},{"location_name":"Tioga County","location_id":"12849","lat":"41.6447","long":"-76.9392","pm25":""},{"location_name":"Tishomingo","location_id":"12850","lat":"34.198875","long":"-96.67308","pm25":""},{"location_name":"Tolfa","location_id":"12854","lat":"42.152225","long":"11.93583","pm25":""},{"location_name":"Toll","location_id":"12856","lat":"39.399837","long":"-119.73961","pm25":""},{"location_name":"Tonawanda II","location_id":"12858","lat":"42.9981","long":"-78.8993","pm25":""},{"location_name":"Tonto National Monum","location_id":"12859","lat":"33.654724","long":"-111.10741","pm25":""},{"location_name":"Toppenish-Yakama Tri","location_id":"12861","lat":"46.3802","long":"-120.3326","pm25":""},{"location_name":"Toru\u0144 Airpointer","location_id":"12864","lat":"53.01226","long":"18.606203","pm25":""},{"location_name":"Toru\u0144 POLICJA","location_id":"12865","lat":"53.02865","long":"18.666103","pm25":""},{"location_name":"Toru\u0144, KASZOWNIK","location_id":"12866","lat":"53.017628","long":"18.612808","pm25":""},{"location_name":"Torvet","location_id":"12868","lat":"63.43038","long":"10.39355","pm25":""},{"location_name":"Towanda","location_id":"12869","lat":"41.705227","long":"-76.512726","pm25":""},{"location_name":"Tower Hamlets Roadside","location_id":"12870","lat":"51.52253","long":"-0.042155","pm25":""},{"location_name":"TracyAP","location_id":"12871","lat":"37.6825","long":"-121.4406","pm25":""},{"location_name":"Tramway","location_id":"12874","lat":"35.185","long":"-106.5077","pm25":""},{"location_name":"Tranquillity","location_id":"12875","lat":"36.6324","long":"-120.3822","pm25":""},{"location_name":"Trbovlje","location_id":"12876","lat":"46.138744","long":"15.035197","pm25":""},{"location_name":"Trenton","location_id":"12877","lat":"33.7397","long":"-81.8536","pm25":""},{"location_name":"Triple Oak - Near Ro","location_id":"12879","lat":"35.8652","long":"-78.8197","pm25":""},{"location_name":"Trollhaugen","location_id":"12880","lat":"-72.0117","long":"2.5351","pm25":""},{"location_name":"Trona - Athol and Te","location_id":"12881","lat":"35.774456","long":"-117.37211","pm25":""},{"location_name":"Troost","location_id":"12882","lat":"39.10465","long":"-94.57055","pm25":""},{"location_name":"Truckee BAM","location_id":"12883","lat":"39.3386","long":"-120.1703","pm25":""},{"location_name":"Trzebinia, os. Zwi\u0105zku Walki M\u0142odych","location_id":"12885","lat":"50.159405","long":"19.477465","pm25":""},{"location_name":"Tseung Kwan O","location_id":"12886","lat":"22.317778","long":"114.259445","pm25":""},{"location_name":"Tsuen Wan","location_id":"12887","lat":"22.371666","long":"114.11444","pm25":""},{"location_name":"Tuen Mun","location_id":"12888","lat":"22.391111","long":"113.97667","pm25":""},{"location_name":"Tukwila_Allentown","location_id":"12889","lat":"47.498535","long":"-122.27838","pm25":""},{"location_name":"Tulalip-Totem Beach","location_id":"12890","lat":"48.06534","long":"-122.285194","pm25":""},{"location_name":"Tulsa","location_id":"12891","lat":"36.2067","long":"-95.9764","pm25":""},{"location_name":"Tulsa 0175","location_id":"12892","lat":"36.149876","long":"-96.011665","pm25":""},{"location_name":"Tulsa 0179","location_id":"12893","lat":"36.15483","long":"-96.01585","pm25":""},{"location_name":"Tulsa 0235","location_id":"12894","lat":"36.126945","long":"-95.99894","pm25":""},{"location_name":"Tung Chung","location_id":"12896","lat":"22.288889","long":"113.94361","pm25":""},{"location_name":"Tunkhannock","location_id":"12897","lat":"41.605244","long":"-75.95774","pm25":""},{"location_name":"Turlock - S. Minaret","location_id":"12899","lat":"37.4883","long":"-120.8358","pm25":""},{"location_name":"Tustervatn","location_id":"12902","lat":"65.83089","long":"13.90655","pm25":""},{"location_name":"Twin Falls PM25","location_id":"12904","lat":"42.56509","long":"-114.49472","pm25":""},{"location_name":"Twisp-Glover St","location_id":"12905","lat":"48.3645","long":"-120.1211","pm25":""},{"location_name":"Tychy, ul. To\u0142stoja 1","location_id":"12906","lat":"50.099903","long":"18.990236","pm25":""},{"location_name":"Tyler Airport Reloca","location_id":"12907","lat":"32.34401","long":"-95.41575","pm25":""},{"location_name":"UC1","location_id":"12911","lat":"42.75152","long":"-96.70721","pm25":""},{"location_name":"US Diplomatic Post: Addis Ababa Central","location_id":"12917","lat":"9.058498","long":"38.761642","pm25":""},{"location_name":"US Diplomatic Post: Addis Ababa School","location_id":"12918","lat":"8.996519","long":"38.725433","pm25":""},{"location_name":"US Diplomatic Post: Algiers","location_id":"12919","lat":"36.7558","long":"3.039114","pm25":""},{"location_name":"US Diplomatic Post: Amman","location_id":"12920","lat":"31.945389","long":"35.880554","pm25":""},{"location_name":"US Diplomatic Post: Ashgabat","location_id":"12921","lat":"37.941856","long":"58.387943","pm25":""},{"location_name":"US Diplomatic Post: Baghdad","location_id":"12923","lat":"33.29872","long":"44.395916","pm25":""},{"location_name":"US Diplomatic Post: Bishkek","location_id":"12924","lat":"42.8273","long":"74.5833","pm25":""},{"location_name":"US Diplomatic Post: Chennai","location_id":"12925","lat":"13.08784","long":"80.27847","pm25":""},{"location_name":"US Diplomatic Post: Colombo","location_id":"12926","lat":"6.913253","long":"79.84869","pm25":""},{"location_name":"US Diplomatic Post: Curacao","location_id":"12927","lat":"12.1696","long":"-68.99","pm25":""},{"location_name":"US Diplomatic Post: Dushanbe","location_id":"12929","lat":"38.57971","long":"68.71217","pm25":""},{"location_name":"US Diplomatic Post: Embassy Kathmandu","location_id":"12930","lat":"27.738703","long":"85.336205","pm25":""},{"location_name":"US Diplomatic Post: Guatemala City","location_id":"12931","lat":"14.607198","long":"-90.51425","pm25":""},{"location_name":"US Diplomatic Post: Hanoi","location_id":"12932","lat":"21.021938","long":"105.81881","pm25":""},{"location_name":"US Diplomatic Post: Ho Chi Minh City","location_id":"12933","lat":"10.782773","long":"106.700035","pm25":""},{"location_name":"US Diplomatic Post: Hyderabad","location_id":"12934","lat":"17.38405","long":"78.45636","pm25":""},{"location_name":"US Diplomatic Post: Islamabad","location_id":"12935","lat":"33.7235","long":"73.11822","pm25":""},{"location_name":"US Diplomatic Post: Jakarta Central","location_id":"12936","lat":"-6.182536","long":"106.834236","pm25":""},{"location_name":"US Diplomatic Post: Jakarta South","location_id":"12937","lat":"-6.236704","long":"106.79324","pm25":""},{"location_name":"US Diplomatic Post: Kampala","location_id":"12938","lat":"0.300225","long":"32.591553","pm25":""},{"location_name":"US Diplomatic Post: Karachi","location_id":"12939","lat":"24.8415","long":"67.0091","pm25":""},{"location_name":"US Diplomatic Post: Kolkata","location_id":"12940","lat":"22.56263","long":"88.36304","pm25":""},{"location_name":"US Diplomatic Post: Kuwait City","location_id":"12941","lat":"29.292316","long":"48.04768","pm25":""},{"location_name":"US Diplomatic Post: Lima","location_id":"12942","lat":"-12.099398","long":"-76.96888","pm25":""},{"location_name":"US Diplomatic Post: Mumbai","location_id":"12943","lat":"19.07283","long":"72.88261","pm25":""},{"location_name":"US Diplomatic Post: New Delhi","location_id":"12944","lat":"28.63576","long":"77.22445","pm25":""},{"location_name":"US Diplomatic Post: Pristina","location_id":"12945","lat":"42.661995","long":"21.15055","pm25":""},{"location_name":"US Diplomatic Post: Rangoon","location_id":"12946","lat":"16.8256","long":"96.1445","pm25":""},{"location_name":"US Diplomatic Post: Tashkent","location_id":"12947","lat":"41.3672","long":"69.2725","pm25":""},{"location_name":"US Diplomatic Post: Ulaanbaatar","location_id":"12948","lat":"47.928387","long":"106.92947","pm25":""},{"location_name":"Utica","location_id":"12949","lat":"43.0994","long":"-75.225","pm25":""},{"location_name":"Ukiah District Offic","location_id":"12950","lat":"39.145733","long":"-123.202995","pm25":""},{"location_name":"Ukiah Library","location_id":"12951","lat":"39.15048","long":"-123.20653","pm25":""},{"location_name":"Ulaanbaatar","location_id":"12952","lat":"47.928387","long":"106.92947","pm25":""},{"location_name":"Underhill","location_id":"12955","lat":"44.52839","long":"-72.86897","pm25":""},{"location_name":"Union","location_id":"12956","lat":"36.918243","long":"-95.632126","pm25":""},{"location_name":"Uniontown","location_id":"12957","lat":"39.917664","long":"-79.8055","pm25":""},{"location_name":"Unionville","location_id":"12958","lat":"43.61","long":"-83.36","pm25":""},{"location_name":"Unit0269","location_id":"12960","lat":"38.979282","long":"-105.35306","pm25":""},{"location_name":"Unit1029","location_id":"12963","lat":"41.728584","long":"-122.521614","pm25":""},{"location_name":"United Ave","location_id":"12967","lat":"33.7206","long":"-84.3578","pm25":""},{"location_name":"Upland","location_id":"12970","lat":"34.10366","long":"-117.6291","pm25":""},{"location_name":"Ustro\u0144, ul. Sanatoryjna 7","location_id":"12974","lat":"49.71973","long":"18.826721","pm25":""},{"location_name":"Ute 1","location_id":"12975","lat":"37.13678","long":"-107.62863","pm25":""},{"location_name":"Ute 3","location_id":"12976","lat":"37.10258","long":"-107.87022","pm25":""},{"location_name":"Utrecht-Erzeijstraat","location_id":"12977","lat":"52.0677","long":"5.12051","pm25":""},{"location_name":"Utrecht-Griftpark","location_id":"12978","lat":"52.1013","long":"5.12818","pm25":""},{"location_name":"Utrecht-de Jongweg","location_id":"12979","lat":"52.105","long":"5.12446","pm25":""},{"location_name":"Uxbridge","location_id":"12980","lat":"42.0997","long":"-71.62","pm25":""},{"location_name":"VERUCCHIO","location_id":"12984","lat":"44.0139","long":"12.421","pm25":""},{"location_name":"VIA CHIARINI","location_id":"12985","lat":"44.5001","long":"11.2861","pm25":""},{"location_name":"VILLA FULVIA","location_id":"12987","lat":"44.8243","long":"11.6496","pm25":""},{"location_name":"V_VIEW","location_id":"12990","lat":"26.0732","long":"-80.3386","pm25":""},{"location_name":"Vacaville","location_id":"12991","lat":"38.3525","long":"-121.9617","pm25":""},{"location_name":"Valdosta","location_id":"12992","lat":"30.8486","long":"-83.2933","pm25":""},{"location_name":"Vallejo","location_id":"12995","lat":"38.10251","long":"-122.237976","pm25":""},{"location_name":"Valley Central","location_id":"12996","lat":"41.5231","long":"-74.215","pm25":""},{"location_name":"Valthermond-Noorderdiep","location_id":"12997","lat":"52.8757","long":"6.93243","pm25":""},{"location_name":"Vancouver-NE 84th Av","location_id":"12999","lat":"45.64336","long":"-122.58737","pm25":""},{"location_name":"Vangsveien, Hamar","location_id":"13000","lat":"60.79646","long":"11.09777","pm25":""},{"location_name":"Veldhoven-Europalaan","location_id":"13003","lat":"51.4074","long":"5.39333","pm25":""},{"location_name":"Velsen-Reijndersweg","location_id":"13004","lat":"52.4789","long":"4.57934","pm25":""},{"location_name":"Velsen-Staalstraat","location_id":"13005","lat":"52.4744","long":"4.6288","pm25":""},{"location_name":"Vernal #4","location_id":"13006","lat":"40.46472","long":"-109.56083","pm25":""},{"location_name":"Via Tasso","location_id":"13007","lat":"41.464024","long":"12.913039","pm25":""},{"location_name":"Viale De Chirico","location_id":"13008","lat":"41.45113","long":"12.891731","pm25":""},{"location_name":"Victoria C87","location_id":"13010","lat":"28.8358","long":"-97.0056","pm25":""},{"location_name":"Victorville - Park A","location_id":"13011","lat":"34.51","long":"-117.3306","pm25":""},{"location_name":"Vientiane","location_id":"13013","lat":"17.896122","long":"102.64","pm25":""},{"location_name":"Vigernes","location_id":"13014","lat":"59.95548","long":"11.073983","pm25":""},{"location_name":"Viking Lake State Pa","location_id":"13015","lat":"40.97","long":"-95.045","pm25":""},{"location_name":"Villa Ada","location_id":"13016","lat":"41.932873","long":"12.506971","pm25":""},{"location_name":"Vincennes","location_id":"13020","lat":"38.7408","long":"-87.4853","pm25":""},{"location_name":"Vinton","location_id":"13021","lat":"30.2278","long":"-93.5797","pm25":""},{"location_name":"Virginia","location_id":"13022","lat":"47.5212","long":"-92.5393","pm25":""},{"location_name":"Visalia - N. Church","location_id":"13023","lat":"36.33252","long":"-119.29095","pm25":""},{"location_name":"Viterbo","location_id":"13024","lat":"42.42206","long":"12.109125","pm25":""},{"location_name":"Vollgata","location_id":"13027","lat":"59.27897","long":"11.12228","pm25":""},{"location_name":"Voyageurs NP","location_id":"13028","lat":"48.4128","long":"-92.8292","pm25":""},{"location_name":"Vredepeel-Vredeweg","location_id":"13029","lat":"51.5405","long":"5.85307","pm25":""},{"location_name":"V\u00e5land","location_id":"13030","lat":"58.96173","long":"5.73147","pm25":""},{"location_name":"W Greenwich","location_id":"13031","lat":"41.615","long":"-71.7197","pm25":""},{"location_name":"W OWEN SCH","location_id":"13032","lat":"35.041416","long":"-78.95311","pm25":""},{"location_name":"WARE","location_id":"13034","lat":"42.2983","long":"-72.3344","pm25":""},{"location_name":"WATSON","location_id":"13037","lat":"38.0608","long":"-85.8961","pm25":""},{"location_name":"WAUKESHA - CLEVELAND","location_id":"13038","lat":"43.0203","long":"-88.215","pm25":""},{"location_name":"WAVELAND","location_id":"13039","lat":"30.3008","long":"-89.3958","pm25":""},{"location_name":"WEST OLIVE","location_id":"13042","lat":"42.923603","long":"-86.19652","pm25":""},{"location_name":"WESTSIDE - 9 Mile","location_id":"13043","lat":"35.0641","long":"-106.76129","pm25":""},{"location_name":"WHlthDpt","location_id":"13045","lat":"37.7011","long":"-97.3139","pm25":""},{"location_name":"WIND CAVE","location_id":"13047","lat":"43.557613","long":"-103.48366","pm25":""},{"location_name":"WIO\u015a Elbl\u0105g ul. Ba\u017cy\u0144skiego","location_id":"13048","lat":"54.167847","long":"19.410942","pm25":""},{"location_name":"WIO\u015a E\u0142k","location_id":"13049","lat":"53.828457","long":"22.34845","pm25":""},{"location_name":"WIO\u015a Go\u0142dap ul. Ja\u0107wieska","location_id":"13050","lat":"54.30591","long":"22.30768","pm25":""},{"location_name":"WIO\u015a Go\u0142dap-Uzdrowisko","location_id":"13051","lat":"54.328175","long":"22.332172","pm25":""},{"location_name":"WIO\u015a Olsztyn ul. Puszkina","location_id":"13052","lat":"53.789234","long":"20.486074","pm25":""},{"location_name":"WIO\u015a Ostr\u00f3da Pi\u0142sudskiego","location_id":"13053","lat":"53.69463","long":"19.968891","pm25":""},{"location_name":"Willits Justice Cent","location_id":"13054","lat":"39.411743","long":"-123.35266","pm25":""},{"location_name":"WY\/KC","location_id":"13058","lat":"39.1175","long":"-94.6356","pm25":""},{"location_name":"WYLAM","location_id":"13059","lat":"33.4997","long":"-86.9242","pm25":""},{"location_name":"Waco C1037","location_id":"13060","lat":"31.6531","long":"-97.0706","pm25":""},{"location_name":"Wadsworth-NV","location_id":"13061","lat":"39.6367","long":"-119.2889","pm25":""},{"location_name":"Walla Walla-12th St","location_id":"13062","lat":"46.0588","long":"-118.3514","pm25":""},{"location_name":"Walsall Woodlands","location_id":"13064","lat":"52.60562","long":"-2.030523","pm25":""},{"location_name":"Walter Johnson","location_id":"13065","lat":"36.169758","long":"-115.26304","pm25":""},{"location_name":"Wampanoag Laboratory","location_id":"13067","lat":"41.3306","long":"-70.7859","pm25":""},{"location_name":"Wamsutter","location_id":"13068","lat":"41.6778","long":"-108.0242","pm25":""},{"location_name":"Wang Yen, Plaeng Yao","location_id":"13069","lat":"13.588554","long":"101.28636","pm25":""},{"location_name":"Ward","location_id":"13070","lat":"32.36253","long":"-88.27792","pm25":""},{"location_name":"Warner Robins","location_id":"13071","lat":"32.6056","long":"-83.5979","pm25":""},{"location_name":"Warrington","location_id":"13072","lat":"53.38928","long":"-2.615358","pm25":""},{"location_name":"Warszawa-Bajkowa","location_id":"13073","lat":"52.188473","long":"21.176233","pm25":""},{"location_name":"Warszawa-Chro\u015bcickiego","location_id":"13074","lat":"52.20774","long":"20.906073","pm25":""},{"location_name":"Warszawa-Komunikacyjna","location_id":"13075","lat":"52.2193","long":"21.004725","pm25":""},{"location_name":"Warszawa-Podle\u015bna","location_id":"13076","lat":"52.280937","long":"20.962156","pm25":""},{"location_name":"Warszawa-Targ\u00f3wek","location_id":"13077","lat":"52.290863","long":"21.042458","pm25":""},{"location_name":"Warszawa-To\u0142stoja","location_id":"13078","lat":"52.285072","long":"20.933018","pm25":""},{"location_name":"Warszawa-Ursyn\u00f3w","location_id":"13079","lat":"52.16077","long":"21.03382","pm25":""},{"location_name":"Wash. Crossing","location_id":"13080","lat":"40.3125","long":"-74.8729","pm25":""},{"location_name":"Waterbury","location_id":"13081","lat":"41.5503","long":"-73.0442","pm25":""},{"location_name":"Waterloo, Water Towe","location_id":"13082","lat":"42.5014","long":"-92.3158","pm25":""},{"location_name":"Watertown","location_id":"13083","lat":"44.89965","long":"-97.1288","pm25":""},{"location_name":"Wa\u0142brzych - Wysockiego","location_id":"13088","lat":"50.76873","long":"16.269676","pm25":""},{"location_name":"Weaverville","location_id":"13090","lat":"40.734722","long":"-122.94111","pm25":""},{"location_name":"Wekerom-Riemterdijk","location_id":"13092","lat":"52.1116","long":"5.70842","pm25":""},{"location_name":"Welby - 78th Ave. &","location_id":"13093","lat":"39.8392","long":"-104.9489","pm25":""},{"location_name":"Welch - 12400 W. Hwy","location_id":"13094","lat":"39.6389","long":"-105.1389","pm25":""},{"location_name":"Wellpinit-Spokane Tr","location_id":"13095","lat":"47.8852","long":"-117.9886","pm25":""},{"location_name":"Wenatchee-Fifth St","location_id":"13096","lat":"47.43061","long":"-120.34195","pm25":""},{"location_name":"West 43rd","location_id":"13097","lat":"33.4064","long":"-112.1443","pm25":""},{"location_name":"West Chandler Fire S","location_id":"13099","lat":"33.299","long":"-111.8843","pm25":""},{"location_name":"West Duluth","location_id":"13100","lat":"46.74389","long":"-92.16695","pm25":""},{"location_name":"West Los Angeles - V","location_id":"13102","lat":"34.051098","long":"-118.45638","pm25":""},{"location_name":"West Mesa","location_id":"13103","lat":"32.11","long":"-106.51","pm25":""},{"location_name":"West Orange C9\/C141","location_id":"13104","lat":"30.0844","long":"-93.7617","pm25":""},{"location_name":"West Phoenix","location_id":"13105","lat":"33.4838","long":"-112.1426","pm25":""},{"location_name":"West Union","location_id":"13106","lat":"38.79471","long":"-83.53399","pm25":""},{"location_name":"West Yellowstone Par","location_id":"13107","lat":"44.657013","long":"-111.089615","pm25":""},{"location_name":"Westlake","location_id":"13108","lat":"30.2625","long":"-93.285","pm25":""},{"location_name":"Westmaas-Groeneweg","location_id":"13109","lat":"51.7866","long":"4.45053","pm25":""},{"location_name":"Westmorland - 570 Co","location_id":"13110","lat":"33.0325","long":"-115.6225","pm25":""},{"location_name":"Westport","location_id":"13111","lat":"41.1189","long":"-73.3369","pm25":""},{"location_name":"Weybourne","location_id":"13114","lat":"52.95049","long":"1.122017","pm25":""},{"location_name":"White Fish Dead End","location_id":"13115","lat":"48.400524","long":"-114.335976","pm25":""},{"location_name":"White Plains","location_id":"13117","lat":"41.0522","long":"-73.7642","pm25":""},{"location_name":"White Springs","location_id":"13118","lat":"30.4264","long":"-82.7947","pm25":""},{"location_name":"White Swan-Yakama Tr","location_id":"13120","lat":"46.37543","long":"-120.72932","pm25":""},{"location_name":"Whiteface Mtn","location_id":"13121","lat":"44.3647","long":"-73.9017","pm25":""},{"location_name":"Whiterocks","location_id":"13122","lat":"40.4838","long":"-109.9062","pm25":""},{"location_name":"Whitestown","location_id":"13123","lat":"39.9975","long":"-86.39528","pm25":""},{"location_name":"Wiang Phang Kham, Mae Sai","location_id":"13124","lat":"19.909996","long":"99.83","pm25":""},{"location_name":"Wiang Yong, Mueang","location_id":"13125","lat":"18.564722","long":"99.01115","pm25":""},{"location_name":"Wiang, Mueang","location_id":"13126","lat":"19.190056","long":"100.17033","pm25":""},{"location_name":"Wicken Fen","location_id":"13127","lat":"52.2985","long":"0.290917","pm25":""},{"location_name":"Widnes Milton Road","location_id":"13128","lat":"53.36539","long":"-2.73168","pm25":""},{"location_name":"Widuchowa","location_id":"13129","lat":"53.122326","long":"14.382222","pm25":""},{"location_name":"Wieringerwerf-Medemblikkerweg","location_id":"13130","lat":"52.8037","long":"5.05051","pm25":""},{"location_name":"Wigan Centre","location_id":"13131","lat":"53.54914","long":"-2.638139","pm25":""},{"location_name":"Wijk aan Zee-Burgemeester Rothestraat","location_id":"13132","lat":"52.494","long":"4.60199","pm25":""},{"location_name":"Wijnandsrade-Opfergeltstraat","location_id":"13133","lat":"50.9023","long":"5.88175","pm25":""},{"location_name":"Wilkes-Barre","location_id":"13135","lat":"41.2658","long":"-75.8464","pm25":""},{"location_name":"Williams Middle Scho","location_id":"13136","lat":"34.2143","long":"-79.7673","pm25":""},{"location_name":"Williamson","location_id":"13137","lat":"43.2303","long":"-77.1728","pm25":""},{"location_name":"Willows-Colusa","location_id":"13138","lat":"39.53387","long":"-122.190834","pm25":""},{"location_name":"Winegard Elementary","location_id":"13140","lat":"28.4544","long":"-81.3814","pm25":""},{"location_name":"Winkler Pump Station","location_id":"13141","lat":"26.6028","long":"-81.8789","pm25":""},{"location_name":"Winter Park","location_id":"13142","lat":"28.5997","long":"-81.3628","pm25":""},{"location_name":"Winthrop-Chewuch Rd","location_id":"13144","lat":"48.4772","long":"-120.1906","pm25":""},{"location_name":"Wirral Tranmere","location_id":"13145","lat":"53.37287","long":"-3.022722","pm25":""},{"location_name":"Wodzis\u0142aw \u015al\u0105ski, ul. Ga\u0142czy\u0144skiego 1","location_id":"13146","lat":"50.00763","long":"18.455547","pm25":""},{"location_name":"Woodland","location_id":"13148","lat":"38.6619","long":"-121.7278","pm25":""},{"location_name":"Woodstock","location_id":"13150","lat":"43.945","long":"-71.7008","pm25":""},{"location_name":"Worcester","location_id":"13151","lat":"42.2742","long":"-71.8758","pm25":""},{"location_name":"Worthing A27 Roadside","location_id":"13152","lat":"50.832947","long":"-0.379916","pm25":""},{"location_name":"Wrexham","location_id":"13153","lat":"53.04222","long":"-3.002778","pm25":""},{"location_name":"Wroc\u0142aw - Bartnicza","location_id":"13154","lat":"51.115932","long":"17.141125","pm25":""},{"location_name":"Wroc\u0142aw - Korzeniowskiego","location_id":"13155","lat":"51.12938","long":"17.02925","pm25":""},{"location_name":"Wroc\u0142aw - Wi\u015bniowa","location_id":"13156","lat":"51.086224","long":"17.01269","pm25":""},{"location_name":"Wschowa ul. Kazimierza Wielkiego","location_id":"13157","lat":"51.79972","long":"16.3175","pm25":""},{"location_name":"W\u0142oc\u0142awek OKRZEI","location_id":"13158","lat":"52.658466","long":"19.059315","pm25":""},{"location_name":"W\u0142oc\u0142awek, ul. Kaliska","location_id":"13159","lat":"52.637394","long":"19.044485","pm25":""},{"location_name":"YMCA - Marion County","location_id":"13162","lat":"29.1708","long":"-82.1008","pm25":""},{"location_name":"York","location_id":"13163","lat":"39.9653","long":"-76.6994","pm25":""},{"location_name":"YPSILANTI","location_id":"13164","lat":"42.24","long":"-83.5997","pm25":""},{"location_name":"YPT Campbell Ranch","location_id":"13165","lat":"39.063034","long":"-119.2044","pm25":""},{"location_name":"Yacolt-Yacolt Rd","location_id":"13166","lat":"45.8639","long":"-122.41089","pm25":""},{"location_name":"Yakima-4th Ave","location_id":"13167","lat":"46.59495","long":"-120.51228","pm25":""},{"location_name":"Yankee Road","location_id":"13168","lat":"39.472435","long":"-84.39495","pm25":""},{"location_name":"Yarner Wood","location_id":"13169","lat":"50.5976","long":"-3.71651","pm25":""},{"location_name":"Yellowstone NP","location_id":"13172","lat":"44.5597","long":"-110.4006","pm25":""},{"location_name":"Yellowstone- Old Fai","location_id":"13173","lat":"44.373055","long":"-110.83083","pm25":""},{"location_name":"York Bootham","location_id":"13177","lat":"53.967514","long":"-1.086514","pm25":""},{"location_name":"York DW","location_id":"13178","lat":"39.8608","long":"-76.4619","pm25":""},{"location_name":"York Fishergate","location_id":"13179","lat":"53.95189","long":"-1.075861","pm25":""},{"location_name":"York Landfill","location_id":"13180","lat":"34.977","long":"-81.207","pm25":""},{"location_name":"Yosemite NP Turtleba","location_id":"13182","lat":"37.7133","long":"-119.7061","pm25":""},{"location_name":"Yosemite Village - V","location_id":"13183","lat":"37.748707","long":"-119.5871","pm25":""},{"location_name":"Youngstown - Head St","location_id":"13184","lat":"41.09594","long":"-80.65847","pm25":""},{"location_name":"Youngstown - Laird A","location_id":"13185","lat":"41.23172","long":"-80.80116","pm25":""},{"location_name":"Youngstown - Oakhill","location_id":"13186","lat":"41.096157","long":"-80.658905","pm25":""},{"location_name":"Yreka","location_id":"13187","lat":"41.72679","long":"-122.63359","pm25":""},{"location_name":"Yuba City","location_id":"13188","lat":"39.13868","long":"-121.61884","pm25":""},{"location_name":"Yuen Long","location_id":"13189","lat":"22.445278","long":"114.02278","pm25":""},{"location_name":"Yukon","location_id":"13190","lat":"35.4794","long":"-97.7508","pm25":""},{"location_name":"Yulee","location_id":"13191","lat":"30.62673","long":"-81.53597","pm25":""},{"location_name":"Yuma Supersite","location_id":"13192","lat":"32.690277","long":"-114.61444","pm25":""},{"location_name":"ZALAMELLA","location_id":"13194","lat":"44.4278","long":"12.1865","pm25":""},{"location_name":"Zaandam-Wagenschotpad","location_id":"13196","lat":"52.448","long":"4.81671","pm25":""},{"location_name":"Zaanstad-Hemkade","location_id":"13197","lat":"52.4202","long":"4.83206","pm25":""},{"location_name":"Zabierz\u00f3w, ul. Wapienna","location_id":"13198","lat":"50.116028","long":"19.800638","pm25":""},{"location_name":"Zabrze, ul. M. Curie-Sk\u0142odowskiej 34","location_id":"13199","lat":"50.3165","long":"18.772375","pm25":""},{"location_name":"Zagorje","location_id":"13200","lat":"46.131073","long":"14.996085","pm25":""},{"location_name":"Zakopane, ul. Sienkiewicza","location_id":"13201","lat":"49.293564","long":"19.960083","pm25":""},{"location_name":"Zamo\u015b\u0107 ul. Hrubieszowska 69A","location_id":"13202","lat":"50.71663","long":"23.290247","pm25":""},{"location_name":"Zawiercie, ul. K.I.Ga\u0142czy\u0144skiego 3","location_id":"13203","lat":"50.493046","long":"19.439013","pm25":""},{"location_name":"Zayante Fire Station","location_id":"13204","lat":"37.067","long":"-122.057205","pm25":""},{"location_name":"Zdzieszowice automat 2","location_id":"13205","lat":"50.423534","long":"18.120739","pm25":""},{"location_name":"Zegveld-Oude Meije","location_id":"13207","lat":"52.138","long":"4.83819","pm25":""},{"location_name":"Zeppelinfjellet","location_id":"13208","lat":"78.90669","long":"11.88899","pm25":""},{"location_name":"Zgierz-\u015ar\u00f3dmie\u015bcie","location_id":"13209","lat":"51.856693","long":"19.42123","pm25":""},{"location_name":"Zgorzelec - Bohater\u00f3w Getta","location_id":"13210","lat":"51.15039","long":"15.008175","pm25":""},{"location_name":"Zielona G\u00f3ra ul. Kr\u00f3tka","location_id":"13211","lat":"51.93978","long":"15.518861","pm25":""},{"location_name":"Zierikzee-Lange Slikweg","location_id":"13212","lat":"51.6347","long":"3.91662","pm25":""},{"location_name":"Zion NP","location_id":"13213","lat":"37.1983","long":"-113.1506","pm25":""},{"location_name":"Zuni Hills","location_id":"13214","lat":"33.68674","long":"-112.29417","pm25":""},{"location_name":"Z\u0105bkowice \u015al\u0105skie","location_id":"13215","lat":"50.592323","long":"16.819786","pm25":""},{"location_name":"Z\u0142oty Potok, Le\u015bnicz\u00f3wka","location_id":"13216","lat":"50.710888","long":"19.458797","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Gda\u0144ska 16","location_id":"13234","lat":"51.77541","long":"19.4509","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Jana Paw\u0142a II 15","location_id":"13235","lat":"51.754612","long":"19.434925","pm25":""},{"location_name":"\u0141\u00f3d\u017a-Widzew","location_id":"13236","lat":"51.75805","long":"19.529785","pm25":""},{"location_name":"\u015anie\u017cka","location_id":"13237","lat":"50.73639","long":"15.739722","pm25":""},{"location_name":"\u017bary, ul. Szymanowskiego 8","location_id":"13241","lat":"51.642654","long":"15.127808","pm25":""},{"location_name":"\u017bory, Os. Gen. W\u0142adys\u0142awa Sikorskiego 52_(2)","location_id":"13242","lat":"50.029415","long":"18.689528","pm25":""},{"location_name":"\u017byrard\u00f3w-Roosevelta","location_id":"13243","lat":"52.05381","long":"20.429892","pm25":""},{"location_name":"\u017bywiec, ul. Kopernika  83 a","location_id":"13244","lat":"49.6716","long":"19.234446","pm25":""},{"location_name":"\u0410\u043b\u0442\u0430\u0439","location_id":"13246","lat":"46.376526","long":"96.26234","pm25":""},{"location_name":"\u0410\u0440\u0432\u0430\u0439\u0445\u044d\u044d\u0440","location_id":"13247","lat":"46.258915","long":"102.78922","pm25":""},{"location_name":"\u0411\u0430\u0440\u0443\u0443\u043d-\u0423\u0440\u0442","location_id":"13248","lat":"46.680305","long":"113.28025","pm25":""},{"location_name":"\u0411\u0430\u044f\u043d\u0445\u043e\u043d\u0433\u043e\u0440","location_id":"13249","lat":"46.19711","long":"100.720085","pm25":""},{"location_name":"\u0411\u0443\u043b\u0433\u0430\u043d","location_id":"13251","lat":"48.818222","long":"103.51867","pm25":""},{"location_name":"\u0414\u0430\u043b\u0430\u043d\u0437\u0430\u0434\u0433\u0430\u0434","location_id":"13258","lat":"43.56761","long":"104.42267","pm25":""},{"location_name":"\u0414\u0430\u0440\u0445\u0430\u043d","location_id":"13259","lat":"49.49039","long":"105.9065","pm25":""},{"location_name":"\u0417\u0443\u0443\u043d\u043c\u043e\u0434","location_id":"13265","lat":"47.71039","long":"106.95365","pm25":""},{"location_name":"\u0417\u04af\u04af\u043d\u0445\u0430\u0440\u0430\u0430","location_id":"13266","lat":"48.866665","long":"106.85","pm25":""},{"location_name":"\u041c\u0430\u043d\u0434\u0430\u043b\u0433\u043e\u0432\u044c","location_id":"13276","lat":"45.767113","long":"106.27489","pm25":""},{"location_name":"\u041c\u04e9\u0440\u04e9\u043d","location_id":"13279","lat":"49.638863","long":"100.16653","pm25":""},{"location_name":"\u0421\u0430\u0439\u043d\u0448\u0430\u043d\u0434","location_id":"13288","lat":"45.06664","long":"110.146385","pm25":""},{"location_name":"\u0421\u04af\u0445\u0431\u0430\u0430\u0442\u0430\u0440","location_id":"13295","lat":"50.239693","long":"106.19278","pm25":""},{"location_name":"\u0423\u0411-11","location_id":"13299","lat":"47.95143","long":"106.904076","pm25":""},{"location_name":"\u0423\u0411-6","location_id":"13301","lat":"47.91345","long":"106.97203","pm25":""},{"location_name":"\u0423\u0411-9","location_id":"13302","lat":"47.981915","long":"106.94051","pm25":""},{"location_name":"\u0423\u043b\u0430\u0430\u043d\u0433\u043e\u043c","location_id":"13303","lat":"49.971943","long":"92.07736","pm25":""},{"location_name":"\u0423\u043b\u0438\u0430\u0441\u0442\u0430\u0439","location_id":"13304","lat":"47.72689","long":"96.84739","pm25":""},{"location_name":"\u0425\u043e\u0432\u0434","location_id":"13306","lat":"47.996","long":"91.63392","pm25":""},{"location_name":"\u0426\u044d\u0446\u044d\u0440\u043b\u044d\u0433","location_id":"13307","lat":"47.472195","long":"101.46245","pm25":""},{"location_name":"\u0427\u043e\u0439\u0431\u0430\u043b\u0441\u0430\u043d","location_id":"13310","lat":"48.080555","long":"114.53758","pm25":""},{"location_name":"\u0427\u043e\u0439\u0440","location_id":"13311","lat":"46.357777","long":"108.24611","pm25":""},{"location_name":"\u0428\u0430\u0440\u044b\u043d \u0433\u043e\u043b","location_id":"13313","lat":"49.261444","long":"106.41189","pm25":""},{"location_name":"\u042d\u0440\u0434\u044d\u043d\u044d\u04422","location_id":"13315","lat":"49.017056","long":"104.02814","pm25":""},{"location_name":"\u04e8\u043b\u0433\u0438\u0439","location_id":"13318","lat":"48.969196","long":"89.96494","pm25":""},{"location_name":"\u04e8\u043d\u0434\u04e9\u0440\u0445\u0430\u0430\u043d","location_id":"13319","lat":"47.32397","long":"110.64867","pm25":""},{"location_name":"Albany","location_id":"13329","lat":"31.5767","long":"-84.1002","pm25":""},{"location_name":"Baytown Garth C1017","location_id":"13332","lat":"29.823318","long":"-94.98379","pm25":""},{"location_name":"Bethel","location_id":"13333","lat":"60.79583","long":"-161.767","pm25":""},{"location_name":"Bristol","location_id":"13334","lat":"40.1072","long":"-74.8822","pm25":""},{"location_name":"Chengdu","location_id":"13335","lat":"30.6247","long":"104.06839","pm25":""},{"location_name":"Concord","location_id":"13337","lat":"43.2186","long":"-71.5153","pm25":""},{"location_name":"Elizabeth","location_id":"13338","lat":"-34.698494","long":"138.69577","pm25":""},{"location_name":"Erie","location_id":"13339","lat":"41.644066","long":"-83.54625","pm25":""},{"location_name":"Guty Du\u017ce","location_id":"13341","lat":"52.943054","long":"21.289167","pm25":""},{"location_name":"Jackson","location_id":"13343","lat":"35.705338","long":"-88.81959","pm25":""},{"location_name":"Jerome Mack","location_id":"13344","lat":"36.141876","long":"-115.07874","pm25":""},{"location_name":"Joshua Tree NP - Cot","location_id":"13345","lat":"33.74127","long":"-115.82041","pm25":""},{"location_name":"Lancaster","location_id":"13347","lat":"47.7889","long":"-116.8044","pm25":""},{"location_name":"Lone Pine","location_id":"13348","lat":"36.609","long":"-118.0578","pm25":""},{"location_name":"MARYVILL","location_id":"13349","lat":"35.7683","long":"-83.9422","pm25":""},{"location_name":"NCORE","location_id":"13351","lat":"41.2474","long":"-95.9731","pm25":""},{"location_name":"NCore - White Mounta","location_id":"13352","lat":"37.360703","long":"-118.33083","pm25":""},{"location_name":"New Albany","location_id":"13353","lat":"40.0845","long":"-82.81552","pm25":""},{"location_name":"Olancha","location_id":"13354","lat":"36.280598","long":"-118.01166","pm25":""},{"location_name":"Port Manatee","location_id":"13356","lat":"27.6331","long":"-82.5458","pm25":""},{"location_name":"SYDNEY","location_id":"13359","lat":"27.9659","long":"-82.23061","pm25":""},{"location_name":"Stuart","location_id":"13362","lat":"27.172459","long":"-80.24069","pm25":""},{"location_name":"Wiang, Mueang","location_id":"13367","lat":"19.909243","long":"99.82336","pm25":""},{"location_name":"York","location_id":"13368","lat":"34.9356","long":"-81.2283","pm25":""},{"location_name":"Albany","location_id":"13376","lat":"42.6425","long":"-73.7547","pm25":""},{"location_name":"Buffalo","location_id":"13377","lat":"42.8781","long":"-78.8094","pm25":""},{"location_name":"CBD","location_id":"13378","lat":"-28.756224","long":"32.04924","pm25":""},{"location_name":"CLEVELAND","location_id":"13379","lat":"33.7556","long":"-90.7275","pm25":""},{"location_name":"JERSEYVL","location_id":"13383","lat":"39.1097","long":"-90.3286","pm25":""},{"location_name":"Jackson NCORE","location_id":"13384","lat":"32.32911","long":"-90.182724","pm25":""},{"location_name":"Lewiston","location_id":"13385","lat":"44.089355","long":"-70.214134","pm25":""},{"location_name":"Lima","location_id":"13386","lat":"-12.099398","long":"-76.96888","pm25":""},{"location_name":"Loretto","location_id":"13387","lat":"35.116867","long":"-87.41972","pm25":""},{"location_name":"NCORE","location_id":"13390","lat":"26.054047","long":"-80.25761","pm25":""},{"location_name":"Near Road","location_id":"13391","lat":"26.131256","long":"-80.16785","pm25":""},{"location_name":"Pico Rivera","location_id":"13393","lat":"34.0131","long":"-118.0592","pm25":""},{"location_name":"Pinehurst","location_id":"13394","lat":"36.6972","long":"-119.0189","pm25":""},{"location_name":"SHELDAHL","location_id":"13395","lat":"41.849434","long":"-93.69762","pm25":""},{"location_name":"Auburn M St SE","location_id":"13399","lat":"47.2875","long":"-122.2144","pm25":""},{"location_name":"Chester","location_id":"13400","lat":"40.78763","long":"-74.6763","pm25":""},{"location_name":"FR39014","location_id":"13402","lat":"14.6662","long":"-61.1501","pm25":""},{"location_name":"Greenfield","location_id":"13403","lat":"36.32693","long":"-121.24579","pm25":""},{"location_name":"Lincoln","location_id":"13404","lat":"38.89","long":"-121.3","pm25":""},{"location_name":"West Union","location_id":"13407","lat":"39.210884","long":"-87.66842","pm25":""},{"location_name":"\u042d\u0440\u0434\u044d\u043d\u044d\u04421","location_id":"13408","lat":"49.01939","long":"104.04528","pm25":""},{"location_name":"Armidale","location_id":"13413","lat":"-30.508333","long":"151.66139","pm25":""},{"location_name":"Lang C408","location_id":"13415","lat":"29.8342","long":"-95.4892","pm25":""},{"location_name":"Wampanoag Laboratory","location_id":"13416","lat":"41.3306","long":"-70.788895","pm25":""},{"location_name":"Bill Stanley","location_id":"13419","lat":"36.3619","long":"-118.0108","pm25":""},{"location_name":"La Union","location_id":"13420","lat":"31.9306","long":"-106.6306","pm25":""},{"location_name":"Shell Cut","location_id":"13421","lat":"36.3663","long":"-117.8976","pm25":""},{"location_name":"Columbia","location_id":"13429","lat":"35.65188","long":"-87.0096","pm25":""},{"location_name":"Lake Jackson C1016","location_id":"13430","lat":"29.0436","long":"-95.4736","pm25":""},{"location_name":"Near Road","location_id":"13431","lat":"38.1935","long":"-85.7121","pm25":""},{"location_name":"Portsmouth","location_id":"13432","lat":"50.82881","long":"-1.068583","pm25":""},{"location_name":"Lebanon","location_id":"13440","lat":"39.42689","long":"-84.20077","pm25":""},{"location_name":"Douglas Red Cross","location_id":"13454","lat":"31.3492","long":"-109.53968","pm25":""},{"location_name":"Houston Croquet C409","location_id":"13455","lat":"29.6239","long":"-95.4742","pm25":""},{"location_name":"Near Road","location_id":"13457","lat":"43.59393","long":"-116.38125","pm25":""},{"location_name":"Valparaiso","location_id":"13476","lat":"41.5114","long":"-87.0353","pm25":""},{"location_name":"Herriman #3","location_id":"13493","lat":"40.496407","long":"-112.03631","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"13500","lat":"34.7496","long":"113.5991","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"13508","lat":"27.8528","long":"113.13","pm25":""},{"location_name":"ES1547A","location_id":"9731","lat":"37.25497","long":"-1.78174","pm25":""},{"location_name":"Alphington","location_id":"13511","lat":"-37.778408","long":"145.0306","pm25":""},{"location_name":"Bairnsdale ","location_id":"13512","lat":"-37.82601","long":"147.6355","pm25":""},{"location_name":"Box Hill","location_id":"13513","lat":"-37.828728","long":"145.1324","pm25":""},{"location_name":"Bright","location_id":"13514","lat":"-36.732243","long":"146.97105","pm25":""},{"location_name":"Brighton","location_id":"13515","lat":"-37.913548","long":"144.998","pm25":""},{"location_name":"Brooklyn","location_id":"13516","lat":"-37.822098","long":"144.8471","pm25":""},{"location_name":"B\u00e6rum Golfklubb","location_id":"13517","lat":"59.9601","long":"10.49027","pm25":""},{"location_name":"Churchill","location_id":"13518","lat":"-38.304314","long":"146.41493","pm25":""},{"location_name":"Coolaroo","location_id":"13519","lat":"-37.65995","long":"144.9411","pm25":""},{"location_name":"Dallas","location_id":"13520","lat":"-37.66945","long":"144.9444","pm25":""},{"location_name":"Dandenong","location_id":"13521","lat":"-37.98576","long":"145.1987","pm25":""},{"location_name":"Footscray","location_id":"13522","lat":"-37.80488","long":"144.8728","pm25":""},{"location_name":"Geelong South","location_id":"13523","lat":"-38.17356","long":"144.3703","pm25":""},{"location_name":"Go\u0142uch\u00f3w Uj\u0119cie Wody","location_id":"13524","lat":"50.621483","long":"20.614058","pm25":""},{"location_name":"Grajewo - mobilne ","location_id":"13525","lat":"53.648556","long":"22.452223","pm25":""},{"location_name":"Ho Chi Minh City","location_id":"13526","lat":"10.782773","long":"106.700035","pm25":""},{"location_name":"J\u0119drzej\u00f3w, MOBILNA","location_id":"13527","lat":"50.643673","long":"20.284885","pm25":""},{"location_name":"Kolkata","location_id":"13528","lat":"22.56263","long":"88.36304","pm25":""},{"location_name":"Long Beach Signal Hi","location_id":"13529","lat":"33.793713","long":"-118.17102","pm25":""},{"location_name":"MB center","location_id":"13530","lat":"46.558838","long":"15.651241","pm25":""},{"location_name":"MMCA81051","location_id":"13531","lat":"35.527187","long":"-120.52879","pm25":""},{"location_name":"Macleod","location_id":"13532","lat":"-37.722477","long":"145.0576","pm25":""},{"location_name":"McMillan Reservoir","location_id":"13533","lat":"38.92185","long":"-77.013176","pm25":""},{"location_name":"Melbourne CBD","location_id":"13534","lat":"-37.807396","long":"144.97","pm25":""},{"location_name":"Melton","location_id":"13535","lat":"-37.706455","long":"144.5669","pm25":""},{"location_name":"Moe","location_id":"13536","lat":"-38.186466","long":"146.25833","pm25":""},{"location_name":"Mooroolbark","location_id":"13537","lat":"-37.774967","long":"145.3285","pm25":""},{"location_name":"Morwell East","location_id":"13538","lat":"-38.229393","long":"146.42445","pm25":""},{"location_name":"Morwell South","location_id":"13539","lat":"-38.239292","long":"146.3873","pm25":""},{"location_name":"Mumbai","location_id":"13540","lat":"19.07283","long":"72.88261","pm25":""},{"location_name":"New Delhi","location_id":"13541","lat":"28.63576","long":"77.22445","pm25":""},{"location_name":"Nicholson","location_id":"13542","lat":"-37.815998","long":"147.73941","pm25":""},{"location_name":"North Holywood","location_id":"13543","lat":"34.181976","long":"-118.36304","pm25":""},{"location_name":"Olkusz, ul. Cegielniana","location_id":"13544","lat":"50.284","long":"19.564045","pm25":""},{"location_name":"Omeo","location_id":"13545","lat":"-37.101734","long":"147.59213","pm25":""},{"location_name":"Ostrowiec \u015awi\u0119tokrzyski, MOBILNA","location_id":"13546","lat":"50.946705","long":"21.394491","pm25":""},{"location_name":"O\u015bwi\u0119cim, ul. J. Bema","location_id":"13547","lat":"50.033085","long":"19.245275","pm25":""},{"location_name":"Polanczyk-mobilna","location_id":"13548","lat":"49.374207","long":"22.439453","pm25":""},{"location_name":"Rabka-Zdr\u00f3j, ul. Orkana","location_id":"13549","lat":"49.608646","long":"19.966007","pm25":""},{"location_name":"Rosedale","location_id":"13550","lat":"-38.15588","long":"146.7842","pm25":""},{"location_name":"Swift's Creek","location_id":"13551","lat":"-37.261112","long":"147.7215","pm25":""},{"location_name":"Traralgon","location_id":"13552","lat":"-38.194283","long":"146.53146","pm25":""},{"location_name":"US Diplomatic Post: Lahore","location_id":"13553","lat":"31.560078","long":"74.33589","pm25":""},{"location_name":"US Diplomatic Post: Phora Durbar Kathmandu","location_id":"13554","lat":"27.712463","long":"85.315704","pm25":""},{"location_name":"WIO\u015a Biskupiec-Mobilna","location_id":"13555","lat":"53.860703","long":"20.957891","pm25":""},{"location_name":"Wangaratta","location_id":"13556","lat":"-36.36926","long":"146.3133","pm25":""},{"location_name":"Yinnar","location_id":"13557","lat":"-38.32076","long":"146.3278","pm25":""},{"location_name":"\u5bcc\u533a\u73af\u4fdd\u5c40(\u505c\u8fd0191231)","location_id":"13562","lat":"47.203","long":"123.6261","pm25":""},{"location_name":"\u5bcc\u533a\u9752\u5c11\u5e74\u6d3b\u52a8\u4e2d\u5fc3(\u542f\u7528191231)","location_id":"13563","lat":"47.2075","long":"123.6333","pm25":""},{"location_name":"\u5e02\u7b2c\u4e03\u4e2d\u5b66(\u542f\u7528200103)","location_id":"13564","lat":"35.4053","long":"116.5909","pm25":""},{"location_name":"\u679c\u6811\u573a(\u5bf9\u7167\u70b9)","location_id":"13565","lat":"40.1097","long":"113.3819","pm25":""},{"location_name":"\u6b66\u529f\u5c71\u6c14\u8c61\u7ad9(\u5bf9\u7167\u70b9)","location_id":"13566","lat":"27.4948","long":"114.0944","pm25":""},{"location_name":"\u725f\u5e73\u68c0\u5bdf\u9662(\u542f\u7528170519)","location_id":"13567","lat":"37.4014","long":"121.5992","pm25":""},{"location_name":"\u73af\u4fdd\u5c40(\u505c\u8fd0191231)","location_id":"13568","lat":"50.4269","long":"124.1186","pm25":""},{"location_name":"\u7b2c\u4e8c\u4eba\u6c11\u533b\u9662(145\u642c\u8fc1\u542f\u7528200102)","location_id":"13569","lat":"40.0995","long":"113.2802","pm25":""},{"location_name":"\u7ea2\u65d7\u793e\u533a(\u542f\u7528191231)","location_id":"13570","lat":"50.4278","long":"124.1175","pm25":""},{"location_name":"\u8292\u5e02\u4eba\u6c11\u653f\u5e9c\u7efc\u5408\u697c(\u542f\u7528200103)","location_id":"13571","lat":"24.4335","long":"98.589","pm25":""},{"location_name":"\u957f\u6c5f\u4ea7\u4e1a\u56ed\uff08\u5e76\u884c145\uff09","location_id":"13572","lat":"29.8683","long":"114.338","pm25":""},{"location_name":"Aberdeen","location_id":"13573","lat":"45.468597","long":"-98.494064","pm25":""},{"location_name":"Cleveland Near Road","location_id":"8877","lat":"41.4409","long":"-81.4949","pm25":""},{"location_name":"Provolt - Seed Orcha","location_id":"12291","lat":"42.290092","long":"-123.2321","pm25":""},{"location_name":"Wodonga","location_id":"13588","lat":"-36.11458","long":"146.85092","pm25":""},{"location_name":"Orbost","location_id":"13590","lat":"-37.707848","long":"148.457","pm25":""},{"location_name":"\u5357\u660c\u7ecf\u5f00\u533a\u6851\u6d77\u4ea7\u4e1a\u56ed(\u65b0\u589e191231)","location_id":"13594","lat":"28.7031","long":"115.9721","pm25":""},{"location_name":"Bia\u0142a-Kmicica","location_id":"13598","lat":"52.602535","long":"19.6451","pm25":""},{"location_name":"\u673a\u7535\u5b66\u6821(\u542f\u7528170322)","location_id":"13599","lat":"28.6064","long":"115.9083","pm25":""},{"location_name":"\u6b66\u672f\u5b66\u6821(\u5bf9\u7167\u70b9)","location_id":"13600","lat":"28.7994","long":"115.742","pm25":""},{"location_name":"Karachi","location_id":"13601","lat":"24.8415","long":"67.0091","pm25":""},{"location_name":"\u5e02\u76d1\u6d4b\u7ad9","location_id":"13609","lat":"22.9394","long":"112.0369","pm25":""},{"location_name":"Makham Tia, Mueang","location_id":"4181","lat":"9.136808","long":"99.32072","pm25":""},{"location_name":"Peshawar","location_id":"4752","lat":"34.00585","long":"71.53775","pm25":""},{"location_name":"Northfield (gases only)","location_id":"13625","lat":"-34.862015","long":"138.62292","pm25":""},{"location_name":"Nai Mueang, Mueang","location_id":"13631","lat":"16.44533","long":"102.83525","pm25":""},{"location_name":"Kamiah","location_id":"13633","lat":"46.2094","long":"-116.0275","pm25":""},{"location_name":"Grand Junction - Pow","location_id":"10939","lat":"39.0636","long":"-108.5611","pm25":""},{"location_name":"QUINCY","location_id":"12303","lat":"39.9175","long":"-91.3358","pm25":""},{"location_name":"\u5e02\u653f\u5e9c","location_id":"13637","lat":"27.7044","long":"111.9892","pm25":""}]}

# %%
x["Locations"][0]
# Out:
# {'location_name': 'Anand Kala Kshetram, Rajamahendravaram - APPCB',
#  'location_id': 'site_1399',
#  'lat': '16.9872867',
#  'long': '81.7363176',
#  'pm25': '38'}

# %%
x["Locations"][0]["location_name"]
# Out:
# 'Anand Kala Kshetram, Rajamahendravaram - APPCB'

# %%
float(x["Locations"][0]["long"])
# Out:
# 81.7363176

# %%
len(x["Locations"])
# Out:
# 10426

# %%
location_name=[]
lat=[]
long=[]
pm25=[]
for i in range(len(x["Locations"])):
    location_name.append(x["Locations"][i]["location_name"])
    try:
        lat.append(float(x["Locations"][i]["lat"]))
    except:
        lat.append(np.nan)
    try:
        long.append(float(x["Locations"][i]["long"]))
    except: 
        long.append(np.nan)
    try:
        pm25.append(float(x["Locations"][i]["pm25"]))
    except:
        pm25.append(np.nan)

# %%
df=pd.DataFrame([])

# %%
df["location_name"]=location_name
df["lat"]=lat
df["long"]=long
df["pm25"]=pm25

# %%
df.isnull().sum()
# Out:
# location_name        0
# lat                  9
# long                 9
# pm25             10224
# dtype: int64

# %%
len(df)
# Out:
# 10426

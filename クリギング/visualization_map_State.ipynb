# %%
#!pip install geopandas

# %%
#!pip install descartes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as  gpd
import os
import descartes
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/masanoritakahashi/Documents/aqi/MAP'

# %%
#https://www.diva-gis.org/gdata

#cities=gpd.read_file("/Users/masanoritakahashi/Documents/aqi/Kriging/India_SHP/INDIA.shp")
states=gpd.read_file("/Users/masanoritakahashi/Documents/aqi/MAP/IND_adm/IND_adm1.shp")
#city_name=pd.read_csv("india-city2.csv")
#values=pd.read_csv("Dec1-2_all_states.csv")
values=pd.read_csv("state_pm25_12091741.csv")

# %%
values
# Out:
#                      state  value
# 0      Andaman and Nicobar     -1
# 1           Andhra Pradesh     -1
# 2        Arunachal Pradesh     -1
# 3                    Assam     50
# 4                    Bihar     69
# 5               Chandigarh    110
# 6             Chhattisgarh     -1
# 7   Dadra and Nagar Haveli     -1
# 8            Daman and Diu     -1
# 9                    Delhi    131
# 10                     Goa     -1
# 11                 Gujarat     74
# 12                 Haryana    124
# 13        Himachal Pradesh     91
# 14       Jammu and Kashmir     -1
# 15               Jharkhand    133
# 16               Karnataka     29
# 17                  Kerala     -1
# 18             Lakshadweep     -1
# 19          Madhya Pradesh     49
# 20             Maharashtra     50
# 21                 Manipur     35
# 22               Meghalaya     -1
# 23                 Mizoram     15
# 24                Nagaland     -1
# 25                  Orissa     84
# ...

# %%
states["value"]=values["value"]

# %%
#first layer
ax=states.plot(color="grey", figsize=(10,10))
states[states["value"]>0].plot(ax=ax, figsize=(10,10), column="value", legend=True, cmap="OrRd")
ax.set_title("India State PM2.5 Map(Dec 9, 17:41)")
## save fig
plt.savefig("geopandas_nan_plotting.png", dpi=200)
